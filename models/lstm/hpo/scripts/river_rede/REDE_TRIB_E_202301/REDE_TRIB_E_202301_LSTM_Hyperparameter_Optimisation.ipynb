# %% [markdown]
# # 0. Station Information
# * Station Name: REDE_TRIB_E_202301
# * Water Quality Data Link: https://environment.data.gov.uk/hydrology/station/E06319A

# %% [markdown]
# ## 0. Import the Relevant Libraries

# %%
# Force installation of Syne-Tune and a compatible NumPy version (may require restarting the session after running this cell before running below import cell)
# !pip install numpy==1.26.1 syne_tune --force-reinstall -q # ignore potential error messages if listed dependencies do not match imports
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 69.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.3/254.3 kB 26.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 102.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 115.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 127.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/131.7 MB 19.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 33.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 27.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 27.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 76.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.6/293.6 MB 3.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.1 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# torch 2.10.0+cu128 requires nvidia-nccl-cu12==2.27.5; platform_system == "Linux", but you have nvidia-nccl-cu12 2.29.7 which is incompatible.
# datasets 4.0.0 requires dill<0.3.9,>=0.3.0, but you have dill 0.4.1 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# music21 9.9.1 requires numpy>=1.26.4, but you have numpy 1.26.1 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.1 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.1 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.1 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.1 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.1 which is incompatible.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.1 which is incompatible.

# %%
# Import relevant libraries (Note: May require running of above cell to ensure compatibility of NumPy and Syne-Tune)
import torch
import logging
logging.basicConfig(level=logging.INFO)
import numpy as np
import matplotlib.pyplot as plt
from syne_tune import StoppingCriterion, Tuner
from syne_tune.backend.python_backend.python_backend import PythonBackend
from syne_tune.config_space import loguniform, randint, choice, uniform
from syne_tune.experiments import load_experiment
from syne_tune.optimizer.baselines import ASHA
import pandas as pd
from pathlib import Path

# %% [markdown]
# ##1. Specify Epoch Ranges and Reduction Factor for Hyperparameter Optimisation (HPO)

# %%
# Specify the minimum and maximum number of epochs for which a trial is allowed to run during HPO
min_number_of_epochs = 2
max_number_of_epochs = 10

# Define the reduction factor for the Asynchronous Successive Halving Algorithm (ASHA)
eta = 2 # Set to 2 so that 50% of trials are stopped at each rung of the scheduler

# %% [markdown]
# ##2. Define the Tune Function to Optimise Hyperparameters for Ammonium Prediction

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on ammonium_t_96 targets
def ammonium_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Load the raw data from the project GitHub into a Pandas DataFrame and set index as DateTime
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/river_rede/REDE_TRIB_E_202301/df_parameters_preprocessed.zip")
    parameter_path = "/content" / data_path / "df_parameters_preprocessed.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "ammonium"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ## 3. Define the Configuration Space for Hyperparameter Search

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %% [markdown]
# ##4. Define the Resources Available for HPO

# %%
# Define the number of parallel workers available to evaluate trials concurrently
n_workers = max(1, torch.cuda.device_count()) # Uses all available GPUs for parallel trials or defaults to 1 worker if running on CPU

# Define the maximum number of trials to test
max_number_of_trials = 30

# Define the stopping criterion for HPO
stop_criterion = StoppingCriterion(max_num_trials_started=max_number_of_trials)

# %% [markdown]
# ##5. Define Asynchronous Successive Halving Algorithm (ASHA) for HPO

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %% [markdown]
# ##6. Initialise and Run the Tuner for Ammonium HPO

# %%
# Instruct the searcher to run each trial as a Python function
trial_backend = PythonBackend(
    tune_function=ammonium_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-18-11-44-11-993
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-18-11-44-11-993
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-18-11-44-11-993
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [11:44:13] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay
#         0 InProgress     0        0.00001           64           2      0.2       0.00001
# 1 trials running, 0 finished (0 until the end), 20.13s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     5        0.00001           64           2      0.2       0.00001      5          0.036489    29.627498
# 1 trials running, 0 finished (0 until the end), 40.15s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     9        0.00001           64           2      0.2       0.00001      9          0.035068    47.921186
# 1 trials running, 0 finished (0 until the end), 60.17s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:45:13] 🚀 Trial 1 started - config: learning_rate=7.308025960424871e-05, num_hiddens=64, num_layers=2, dropout=0.4947481624998921, weight_decay=1.1291898874838293e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.036130    52.548030
#         1 InProgress     1       0.000073           64           2 0.494748      0.000011      1          0.036813     6.594717
# 1 trials running, 1 finished (0 until the end), 80.19s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:45:33] 🚀 Trial 2 started - config: learning_rate=3.321006847685349e-05, num_hiddens=64, num_layers=3, dropout=0.42345430317266664, weight_decay=0.00014314331908653091
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011      3          0.044100    15.646835
#         2 InProgress     1       0.000033           64           3 0.423454      0.000143      1          0.041201     7.179876
# 1 trials running, 2 finished (0 until the end), 100.21s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011      3          0.044100    15.646835
#         2 InProgress     5       0.000033           64           3 0.423454      0.000143      5          0.040927    27.833499
# 1 trials running, 2 finished (0 until the end), 120.23s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:46:28] 🚀 Trial 3 started - config: learning_rate=7.474641461623584e-05, num_hiddens=128, num_layers=2, dropout=0.33795372050600914, weight_decay=0.0002534670900327498
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011    3.0          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143    9.0          0.044373    49.026002
#         3 InProgress     0       0.000075          128           2 0.337954      0.000253      -                 -            -
# 1 trials running, 3 finished (0 until the end), 140.26s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011      3          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143      9          0.044373    49.026002
#         3 InProgress     2       0.000075          128           2 0.337954      0.000253      2          0.036079    12.172537
# 1 trials running, 3 finished (0 until the end), 160.28s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011      3          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143      9          0.044373    49.026002
#         3 InProgress     6       0.000075          128           2 0.337954      0.000253      6          0.041627    32.832716
# 1 trials running, 3 finished (0 until the end), 180.30s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:47:23] 🚀 Trial 4 started - config: learning_rate=5.8441264310788945e-05, num_hiddens=32, num_layers=2, dropout=0.3596800884204939, weight_decay=5.485366027537286e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011    3.0          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143    9.0          0.044373    49.026002
#         3    Stopped     9       0.000075          128           2 0.337954      0.000253    9.0          0.050023    48.170652
#         4 InProgress     0       0.000058           32           2 0.359680      0.000055      -                 -            -
# 1 trials running, 4 finished (0 until the end), 200.33s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:47:38] 🚀 Trial 5 started - config: learning_rate=0.00030577111797979286, num_hiddens=32, num_layers=2, dropout=0.2522289558215123, weight_decay=1.4142952846617337e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011    3.0          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143    9.0          0.044373    49.026002
#         3    Stopped     9       0.000075          128           2 0.337954      0.000253    9.0          0.050023    48.170652
#         4    Stopped     1       0.000058           32           2 0.359680      0.000055    1.0          0.037012     6.482337
#         5 InProgress     0       0.000306           32           2 0.252229      0.000014      -                 -            -
# 1 trials running, 5 finished (0 until the end), 220.36s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:47:53] 🚀 Trial 6 started - config: learning_rate=0.0002361450369943303, num_hiddens=64, num_layers=3, dropout=0.32966093314687706, weight_decay=0.00010137550761376395
# [11:48:08] 🚀 Trial 7 started - config: learning_rate=0.00015228086729997747, num_hiddens=256, num_layers=2, dropout=0.2964966330756875, weight_decay=0.0004136873167529493
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011    3.0          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143    9.0          0.044373    49.026002
#         3    Stopped     9       0.000075          128           2 0.337954      0.000253    9.0          0.050023    48.170652
#         4    Stopped     1       0.000058           32           2 0.359680      0.000055    1.0          0.037012     6.482337
#         5    Stopped     2       0.000306           32           2 0.252229      0.000014    2.0          0.041291    10.832504
#         6    Stopped     1       0.000236           64           3 0.329661      0.000101    1.0          0.043912     6.919048
#         7 InProgress     0       0.000152          256           2 0.296497      0.000414      -                 -            -
# 1 trials running, 7 finished (0 until the end), 240.40s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:48:28] 🚀 Trial 8 started - config: learning_rate=2.712442658122013e-05, num_hiddens=64, num_layers=2, dropout=0.3224846741279974, weight_decay=0.00014179884580379048
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011    3.0          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143    9.0          0.044373    49.026002
#         3    Stopped     9       0.000075          128           2 0.337954      0.000253    9.0          0.050023    48.170652
#         4    Stopped     1       0.000058           32           2 0.359680      0.000055    1.0          0.037012     6.482337
#         5    Stopped     2       0.000306           32           2 0.252229      0.000014    2.0          0.041291    10.832504
#         6    Stopped     1       0.000236           64           3 0.329661      0.000101    1.0          0.043912     6.919048
#         7    Stopped     1       0.000152          256           2 0.296497      0.000414    1.0          0.037035    13.342440
#         8 InProgress     0       0.000027           64           2 0.322485      0.000142      -                 -            -
# 1 trials running, 8 finished (0 until the end), 260.43s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:48:43] 🚀 Trial 9 started - config: learning_rate=2.13769173879782e-05, num_hiddens=32, num_layers=4, dropout=0.3364002535837457, weight_decay=2.8207991113717975e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011    3.0          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143    9.0          0.044373    49.026002
#         3    Stopped     9       0.000075          128           2 0.337954      0.000253    9.0          0.050023    48.170652
#         4    Stopped     1       0.000058           32           2 0.359680      0.000055    1.0          0.037012     6.482337
#         5    Stopped     2       0.000306           32           2 0.252229      0.000014    2.0          0.041291    10.832504
#         6    Stopped     1       0.000236           64           3 0.329661      0.000101    1.0          0.043912     6.919048
#         7    Stopped     1       0.000152          256           2 0.296497      0.000414    1.0          0.037035    13.342440
#         8    Stopped     1       0.000027           64           2 0.322485      0.000142    1.0          0.050335     6.530416
#         9 InProgress     0       0.000021           32           4 0.336400      0.000028      -                 -            -
# 1 trials running, 9 finished (0 until the end), 280.46s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:48:58] 🚀 Trial 10 started - config: learning_rate=9.700782082569593e-05, num_hiddens=32, num_layers=3, dropout=0.48159254730886875, weight_decay=1.314445994147126e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011    3.0          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143    9.0          0.044373    49.026002
#         3    Stopped     9       0.000075          128           2 0.337954      0.000253    9.0          0.050023    48.170652
#         4    Stopped     1       0.000058           32           2 0.359680      0.000055    1.0          0.037012     6.482337
#         5    Stopped     2       0.000306           32           2 0.252229      0.000014    2.0          0.041291    10.832504
#         6    Stopped     1       0.000236           64           3 0.329661      0.000101    1.0          0.043912     6.919048
#         7    Stopped     1       0.000152          256           2 0.296497      0.000414    1.0          0.037035    13.342440
#         8    Stopped     1       0.000027           64           2 0.322485      0.000142    1.0          0.050335     6.530416
#         9    Stopped     1       0.000021           32           4 0.336400      0.000028    1.0          0.067844     7.501026
#        10 InProgress     0       0.000097           32           3 0.481593      0.000013      -                 -            -
# 1 trials running, 10 finished (0 until the end), 300.48s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:49:23] 🚀 Trial 11 started - config: learning_rate=2.2003532931260238e-05, num_hiddens=256, num_layers=2, dropout=0.38465412977463287, weight_decay=0.00011229912520092363
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011    3.0          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143    9.0          0.044373    49.026002
#         3    Stopped     9       0.000075          128           2 0.337954      0.000253    9.0          0.050023    48.170652
#         4    Stopped     1       0.000058           32           2 0.359680      0.000055    1.0          0.037012     6.482337
#         5    Stopped     2       0.000306           32           2 0.252229      0.000014    2.0          0.041291    10.832504
#         6    Stopped     1       0.000236           64           3 0.329661      0.000101    1.0          0.043912     6.919048
#         7    Stopped     1       0.000152          256           2 0.296497      0.000414    1.0          0.037035    13.342440
#         8    Stopped     1       0.000027           64           2 0.322485      0.000142    1.0          0.050335     6.530416
#         9    Stopped     1       0.000021           32           4 0.336400      0.000028    1.0          0.067844     7.501026
#        10    Stopped     3       0.000097           32           3 0.481593      0.000013    3.0          0.040960    17.342103
#        11 InProgress     0       0.000022          256           2 0.384654      0.000112      -                 -            -
# 1 trials running, 11 finished (0 until the end), 320.52s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:49:43] 🚀 Trial 12 started - config: learning_rate=0.00010146648344416165, num_hiddens=32, num_layers=2, dropout=0.2590058345001183, weight_decay=6.806643589390399e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011    3.0          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143    9.0          0.044373    49.026002
#         3    Stopped     9       0.000075          128           2 0.337954      0.000253    9.0          0.050023    48.170652
#         4    Stopped     1       0.000058           32           2 0.359680      0.000055    1.0          0.037012     6.482337
#         5    Stopped     2       0.000306           32           2 0.252229      0.000014    2.0          0.041291    10.832504
#         6    Stopped     1       0.000236           64           3 0.329661      0.000101    1.0          0.043912     6.919048
#         7    Stopped     1       0.000152          256           2 0.296497      0.000414    1.0          0.037035    13.342440
#         8    Stopped     1       0.000027           64           2 0.322485      0.000142    1.0          0.050335     6.530416
#         9    Stopped     1       0.000021           32           4 0.336400      0.000028    1.0          0.067844     7.501026
#        10    Stopped     3       0.000097           32           3 0.481593      0.000013    3.0          0.040960    17.342103
#        11    Stopped     1       0.000022          256           2 0.384654      0.000112    1.0          0.038684    13.469121
#        12 InProgress     0       0.000101           32           2 0.259006      0.000068      -                 -            -
# 1 trials running, 12 finished (0 until the end), 340.55s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011      3          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143      9          0.044373    49.026002
#         3    Stopped     9       0.000075          128           2 0.337954      0.000253      9          0.050023    48.170652
#         4    Stopped     1       0.000058           32           2 0.359680      0.000055      1          0.037012     6.482337
#         5    Stopped     2       0.000306           32           2 0.252229      0.000014      2          0.041291    10.832504
#         6    Stopped     1       0.000236           64           3 0.329661      0.000101      1          0.043912     6.919048
#         7    Stopped     1       0.000152          256           2 0.296497      0.000414      1          0.037035    13.342440
#         8    Stopped     1       0.000027           64           2 0.322485      0.000142      1          0.050335     6.530416
#         9    Stopped     1       0.000021           32           4 0.336400      0.000028      1          0.067844     7.501026
#        10    Stopped     3       0.000097           32           3 0.481593      0.000013      3          0.040960    17.342103
#        11    Stopped     1       0.000022          256           2 0.384654      0.000112      1          0.038684    13.469121
#        12 InProgress     4       0.000101           32           2 0.259006      0.000068      4          0.045321    20.392479
# 1 trials running, 12 finished (0 until the end), 360.57s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011      3          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143      9          0.044373    49.026002
#         3    Stopped     9       0.000075          128           2 0.337954      0.000253      9          0.050023    48.170652
#         4    Stopped     1       0.000058           32           2 0.359680      0.000055      1          0.037012     6.482337
#         5    Stopped     2       0.000306           32           2 0.252229      0.000014      2          0.041291    10.832504
#         6    Stopped     1       0.000236           64           3 0.329661      0.000101      1          0.043912     6.919048
#         7    Stopped     1       0.000152          256           2 0.296497      0.000414      1          0.037035    13.342440
#         8    Stopped     1       0.000027           64           2 0.322485      0.000142      1          0.050335     6.530416
#         9    Stopped     1       0.000021           32           4 0.336400      0.000028      1          0.067844     7.501026
#        10    Stopped     3       0.000097           32           3 0.481593      0.000013      3          0.040960    17.342103
#        11    Stopped     1       0.000022          256           2 0.384654      0.000112      1          0.038684    13.469121
#        12 InProgress     8       0.000101           32           2 0.259006      0.000068      8          0.044556    38.657851
# 1 trials running, 12 finished (0 until the end), 380.61s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:50:33] 🚀 Trial 13 started - config: learning_rate=0.0001740329631383715, num_hiddens=32, num_layers=4, dropout=0.3535816917499217, weight_decay=3.916271513668673e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011      3          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143      9          0.044373    49.026002
#         3    Stopped     9       0.000075          128           2 0.337954      0.000253      9          0.050023    48.170652
#         4    Stopped     1       0.000058           32           2 0.359680      0.000055      1          0.037012     6.482337
#         5    Stopped     2       0.000306           32           2 0.252229      0.000014      2          0.041291    10.832504
#         6    Stopped     1       0.000236           64           3 0.329661      0.000101      1          0.043912     6.919048
#         7    Stopped     1       0.000152          256           2 0.296497      0.000414      1          0.037035    13.342440
#         8    Stopped     1       0.000027           64           2 0.322485      0.000142      1          0.050335     6.530416
#         9    Stopped     1       0.000021           32           4 0.336400      0.000028      1          0.067844     7.501026
#        10    Stopped     3       0.000097           32           3 0.481593      0.000013      3          0.040960    17.342103
#        11    Stopped     1       0.000022          256           2 0.384654      0.000112      1          0.038684    13.469121
#        12    Stopped     9       0.000101           32           2 0.259006      0.000068      9          0.047929    43.424333
#        13 InProgress     1       0.000174           32           4 0.353582      0.000039      1          0.035786     7.444581
# 1 trials running, 13 finished (0 until the end), 400.64s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:50:58] 🚀 Trial 14 started - config: learning_rate=1.2032258811880265e-05, num_hiddens=256, num_layers=4, dropout=0.3455963299787531, weight_decay=0.00047935505285859564
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011    3.0          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143    9.0          0.044373    49.026002
#         3    Stopped     9       0.000075          128           2 0.337954      0.000253    9.0          0.050023    48.170652
#         4    Stopped     1       0.000058           32           2 0.359680      0.000055    1.0          0.037012     6.482337
#         5    Stopped     2       0.000306           32           2 0.252229      0.000014    2.0          0.041291    10.832504
#         6    Stopped     1       0.000236           64           3 0.329661      0.000101    1.0          0.043912     6.919048
#         7    Stopped     1       0.000152          256           2 0.296497      0.000414    1.0          0.037035    13.342440
#         8    Stopped     1       0.000027           64           2 0.322485      0.000142    1.0          0.050335     6.530416
#         9    Stopped     1       0.000021           32           4 0.336400      0.000028    1.0          0.067844     7.501026
#        10    Stopped     3       0.000097           32           3 0.481593      0.000013    3.0          0.040960    17.342103
#        11    Stopped     1       0.000022          256           2 0.384654      0.000112    1.0          0.038684    13.469121
#        12    Stopped     9       0.000101           32           2 0.259006      0.000068    9.0          0.047929    43.424333
#        13    Stopped     3       0.000174           32           4 0.353582      0.000039    3.0          0.057628    18.149025
#        14 InProgress     0       0.000012          256           4 0.345596      0.000479      -                 -            -
# 1 trials running, 14 finished (0 until the end), 420.65s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:51:23] 🚀 Trial 15 started - config: learning_rate=1.0235065529197756e-05, num_hiddens=64, num_layers=2, dropout=0.465761160204186, weight_decay=2.3200118529025267e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011    3.0          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143    9.0          0.044373    49.026002
#         3    Stopped     9       0.000075          128           2 0.337954      0.000253    9.0          0.050023    48.170652
#         4    Stopped     1       0.000058           32           2 0.359680      0.000055    1.0          0.037012     6.482337
#         5    Stopped     2       0.000306           32           2 0.252229      0.000014    2.0          0.041291    10.832504
#         6    Stopped     1       0.000236           64           3 0.329661      0.000101    1.0          0.043912     6.919048
#         7    Stopped     1       0.000152          256           2 0.296497      0.000414    1.0          0.037035    13.342440
#         8    Stopped     1       0.000027           64           2 0.322485      0.000142    1.0          0.050335     6.530416
#         9    Stopped     1       0.000021           32           4 0.336400      0.000028    1.0          0.067844     7.501026
#        10    Stopped     3       0.000097           32           3 0.481593      0.000013    3.0          0.040960    17.342103
#        11    Stopped     1       0.000022          256           2 0.384654      0.000112    1.0          0.038684    13.469121
#        12    Stopped     9       0.000101           32           2 0.259006      0.000068    9.0          0.047929    43.424333
#        13    Stopped     3       0.000174           32           4 0.353582      0.000039    3.0          0.057628    18.149025
#        14    Stopped     1       0.000012          256           4 0.345596      0.000479    1.0          0.073267    20.586304
#        15 InProgress     0       0.000010           64           2 0.465761      0.000023      -                 -            -
# 1 trials running, 15 finished (0 until the end), 440.69s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:51:38] 🚀 Trial 16 started - config: learning_rate=1.0752564678318645e-05, num_hiddens=128, num_layers=4, dropout=0.46069740727406955, weight_decay=1.1465945664677904e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011    3.0          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143    9.0          0.044373    49.026002
#         3    Stopped     9       0.000075          128           2 0.337954      0.000253    9.0          0.050023    48.170652
#         4    Stopped     1       0.000058           32           2 0.359680      0.000055    1.0          0.037012     6.482337
#         5    Stopped     2       0.000306           32           2 0.252229      0.000014    2.0          0.041291    10.832504
#         6    Stopped     1       0.000236           64           3 0.329661      0.000101    1.0          0.043912     6.919048
#         7    Stopped     1       0.000152          256           2 0.296497      0.000414    1.0          0.037035    13.342440
#         8    Stopped     1       0.000027           64           2 0.322485      0.000142    1.0          0.050335     6.530416
#         9    Stopped     1       0.000021           32           4 0.336400      0.000028    1.0          0.067844     7.501026
#        10    Stopped     3       0.000097           32           3 0.481593      0.000013    3.0          0.040960    17.342103
#        11    Stopped     1       0.000022          256           2 0.384654      0.000112    1.0          0.038684    13.469121
#        12    Stopped     9       0.000101           32           2 0.259006      0.000068    9.0          0.047929    43.424333
#        13    Stopped     3       0.000174           32           4 0.353582      0.000039    3.0          0.057628    18.149025
#        14    Stopped     1       0.000012          256           4 0.345596      0.000479    1.0          0.073267    20.586304
#        15    Stopped     1       0.000010           64           2 0.465761      0.000023    1.0          0.067885     6.496889
#        16 InProgress     0       0.000011          128           4 0.460697      0.000011      -                 -            -
# 1 trials running, 16 finished (0 until the end), 460.72s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:51:53] 🚀 Trial 17 started - config: learning_rate=0.0002927833838085426, num_hiddens=64, num_layers=2, dropout=0.4290021551798745, weight_decay=2.2237594370151787e-05
# [11:52:08] 🚀 Trial 18 started - config: learning_rate=0.00014438242654564055, num_hiddens=256, num_layers=2, dropout=0.2675579956937379, weight_decay=1.977173671461343e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011    3.0          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143    9.0          0.044373    49.026002
#         3    Stopped     9       0.000075          128           2 0.337954      0.000253    9.0          0.050023    48.170652
#         4    Stopped     1       0.000058           32           2 0.359680      0.000055    1.0          0.037012     6.482337
#         5    Stopped     2       0.000306           32           2 0.252229      0.000014    2.0          0.041291    10.832504
#         6    Stopped     1       0.000236           64           3 0.329661      0.000101    1.0          0.043912     6.919048
#         7    Stopped     1       0.000152          256           2 0.296497      0.000414    1.0          0.037035    13.342440
#         8    Stopped     1       0.000027           64           2 0.322485      0.000142    1.0          0.050335     6.530416
#         9    Stopped     1       0.000021           32           4 0.336400      0.000028    1.0          0.067844     7.501026
#        10    Stopped     3       0.000097           32           3 0.481593      0.000013    3.0          0.040960    17.342103
#        11    Stopped     1       0.000022          256           2 0.384654      0.000112    1.0          0.038684    13.469121
#        12    Stopped     9       0.000101           32           2 0.259006      0.000068    9.0          0.047929    43.424333
#        13    Stopped     3       0.000174           32           4 0.353582      0.000039    3.0          0.057628    18.149025
#        14    Stopped     1       0.000012          256           4 0.345596      0.000479    1.0          0.073267    20.586304
#        15    Stopped     1       0.000010           64           2 0.465761      0.000023    1.0          0.067885     6.496889
#        16    Stopped     1       0.000011          128           4 0.460697      0.000011    1.0          0.058791     8.670125
#        17    Stopped     1       0.000293           64           2 0.429002      0.000022    1.0          0.038914     6.389223
#        18 InProgress     0       0.000144          256           2 0.267558      0.000020      -                 -            -
# 1 trials running, 18 finished (0 until the end), 480.78s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:52:28] 🚀 Trial 19 started - config: learning_rate=6.0911801216863336e-05, num_hiddens=256, num_layers=4, dropout=0.38271372930739056, weight_decay=2.0521399186703975e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011    3.0          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143    9.0          0.044373    49.026002
#         3    Stopped     9       0.000075          128           2 0.337954      0.000253    9.0          0.050023    48.170652
#         4    Stopped     1       0.000058           32           2 0.359680      0.000055    1.0          0.037012     6.482337
#         5    Stopped     2       0.000306           32           2 0.252229      0.000014    2.0          0.041291    10.832504
#         6    Stopped     1       0.000236           64           3 0.329661      0.000101    1.0          0.043912     6.919048
#         7    Stopped     1       0.000152          256           2 0.296497      0.000414    1.0          0.037035    13.342440
#         8    Stopped     1       0.000027           64           2 0.322485      0.000142    1.0          0.050335     6.530416
#         9    Stopped     1       0.000021           32           4 0.336400      0.000028    1.0          0.067844     7.501026
#        10    Stopped     3       0.000097           32           3 0.481593      0.000013    3.0          0.040960    17.342103
#        11    Stopped     1       0.000022          256           2 0.384654      0.000112    1.0          0.038684    13.469121
#        12    Stopped     9       0.000101           32           2 0.259006      0.000068    9.0          0.047929    43.424333
#        13    Stopped     3       0.000174           32           4 0.353582      0.000039    3.0          0.057628    18.149025
#        14    Stopped     1       0.000012          256           4 0.345596      0.000479    1.0          0.073267    20.586304
#        15    Stopped     1       0.000010           64           2 0.465761      0.000023    1.0          0.067885     6.496889
#        16    Stopped     1       0.000011          128           4 0.460697      0.000011    1.0          0.058791     8.670125
#        17    Stopped     1       0.000293           64           2 0.429002      0.000022    1.0          0.038914     6.389223
#        18    Stopped     1       0.000144          256           2 0.267558      0.000020    1.0          0.037574    13.252436
#        19 InProgress     0       0.000061          256           4 0.382714      0.000021      -                 -            -
# 1 trials running, 19 finished (0 until the end), 500.81s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.036130    52.548030
#         1    Stopped     3       0.000073           64           2 0.494748      0.000011    3.0          0.044100    15.646835
#         2    Stopped     9       0.000033           64           3 0.423454      0.000143    9.0          0.044373    49.026002
#         3    Stopped     9       0.000075          128           2 0.337954      0.000253    9.0          0.050023    48.170652
#         4    Stopped     1       0.000058           32           2 0.359680      0.000055    1.0          0.037012     6.482337
#         5    Stopped     2       0.000306           32           2 0.252229      0.000014    2.0          0.041291    10.832504
#         6    Stopped     1       0.000236           64           3 0.329661      0.000101    1.0          0.043912     6.919048
#         7    Stopped     1       0.000152          256           2 0.296497      0.000
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-18-11-44-11-993
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-18-11-44-11-993
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##7. Load Results from HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
ammonium_results_path = "/root/syne-tune/python-entrypoint-2026-03-18-11-44-11-993/results.csv.zip"

# Save the results to a Pandas DataFrame
ammonium_results = pd.read_csv(ammonium_results_path)

# %% [markdown]
# ##8. Save the Ammonium HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
ammonium_hpo_results_path = Path("/content/REDE_TRIB_E_202301_ammonium_hpo_results.csv")

# Save the DataFrame to a csv file
ammonium_results.to_csv(ammonium_hpo_results_path, index=True)

# %% [markdown]
# ## 9. Define the Config Space, Scheduler, and Tune Function for Dissolved Oxygen HPO

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on ammonium_t_96 targets
def oxygen_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Load the raw data from the project GitHub into a Pandas DataFrame and set index as DateTime
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/river_rede/REDE_TRIB_E_202301/df_parameters_preprocessed.zip")
    parameter_path = "/content" / data_path / "df_parameters_preprocessed.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "oxygen_conc"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ##10. Initialise and Run the Tuner for Oxygen HPO

# %%
# Instruct the searcher to run each trial as a Python function
oxygen_trial_backend = PythonBackend(
    tune_function=oxygen_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=oxygen_trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-18-12-24-05-784
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-18-12-24-05-784
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-18-12-24-05-784
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [12:24:06] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay
#         0 InProgress     0        0.00001           64           2      0.2       0.00001
# 1 trials running, 0 finished (0 until the end), 20.13s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     5        0.00001           64           2      0.2       0.00001      5          0.076899    29.748805
# 1 trials running, 0 finished (0 until the end), 40.15s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     9        0.00001           64           2      0.2       0.00001      9          0.076748    48.510966
# 1 trials running, 0 finished (0 until the end), 60.17s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [12:25:06] 🚀 Trial 1 started - config: learning_rate=3.0373755478140186e-05, num_hiddens=128, num_layers=4, dropout=0.4055133016894279, weight_decay=0.00037073086314772907
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10        0.00001           64           2 0.200000      0.000010     10          0.077654    53.218629
#         1 InProgress     1        0.00003          128           4 0.405513      0.000371      1          0.077171     8.941850
# 1 trials running, 1 finished (0 until the end), 80.19s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [12:25:36] 🚀 Trial 2 started - config: learning_rate=2.0431585637762482e-05, num_hiddens=256, num_layers=3, dropout=0.2967385139952643, weight_decay=4.530597511498848e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10        0.00001           64           2 0.200000      0.000010   10.0          0.077654    53.218629
#         1    Stopped     3        0.00003          128           4 0.405513      0.000371    3.0          0.077313    22.482088
#         2 InProgress     0        0.00002          256           3 0.296739      0.000045      -                 -            -
# 1 trials running, 2 finished (0 until the end), 100.21s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10        0.00001           64           2 0.200000      0.000010     10          0.077654    53.218629
#         1    Stopped     3        0.00003          128           4 0.405513      0.000371      3          0.077313    22.482088
#         2 InProgress     1        0.00002          256           3 0.296739      0.000045      1          0.075870    17.259125
# 1 trials running, 2 finished (0 until the end), 120.23s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10        0.00001           64           2 0.200000      0.000010     10          0.077654    53.218629
#         1    Stopped     3        0.00003          128           4 0.405513      0.000371      3          0.077313    22.482088
#         2 InProgress     2        0.00002          256           3 0.296739      0.000045      2          0.077176    31.756453
# 1 trials running, 2 finished (0 until the end), 140.25s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10        0.00001           64           2 0.200000      0.000010     10          0.077654    53.218629
#         1    Stopped     3        0.00003          128           4 0.405513      0.000371      3          0.077313    22.482088
#         2 InProgress     4        0.00002          256           3 0.296739      0.000045      4          0.075170    60.195288
# 1 trials running, 2 finished (0 until the end), 160.27s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10        0.00001           64           2 0.200000      0.000010     10          0.077654    53.218629
#         1    Stopped     3        0.00003          128           4 0.405513      0.000371      3          0.077313    22.482088
#         2 InProgress     5        0.00002          256           3 0.296739      0.000045      5          0.075900    74.575358
# 1 trials running, 2 finished (0 until the end), 180.28s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10        0.00001           64           2 0.200000      0.000010     10          0.077654    53.218629
#         1    Stopped     3        0.00003          128           4 0.405513      0.000371      3          0.077313    22.482088
#         2 InProgress     6        0.00002          256           3 0.296739      0.000045      6          0.076560    89.082818
# 1 trials running, 2 finished (0 until the end), 200.30s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10        0.00001           64           2 0.200000      0.000010     10          0.077654    53.218629
#         1    Stopped     3        0.00003          128           4 0.405513      0.000371      3          0.077313    22.482088
#         2 InProgress     8        0.00002          256           3 0.296739      0.000045      8          0.082747   117.731292
# 1 trials running, 2 finished (0 until the end), 220.33s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [12:27:56] 🚀 Trial 3 started - config: learning_rate=0.0001349997620473828, num_hiddens=32, num_layers=4, dropout=0.474894932559849, weight_decay=0.00017003186206363845
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371    3.0          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045    9.0          0.080566   132.157120
#         3 InProgress     0       0.000135           32           4 0.474895      0.000170      -                 -            -
# 1 trials running, 3 finished (0 until the end), 240.35s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [12:28:11] 🚀 Trial 4 started - config: learning_rate=0.0001721747135413316, num_hiddens=32, num_layers=3, dropout=0.2878031654733515, weight_decay=0.00011138304496322107
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371    3.0          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045    9.0          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170    1.0          0.080505     7.456738
#         4 InProgress     0       0.000172           32           3 0.287803      0.000111      -                 -            -
# 1 trials running, 4 finished (0 until the end), 260.37s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [12:28:26] 🚀 Trial 5 started - config: learning_rate=5.4490220998050116e-05, num_hiddens=128, num_layers=3, dropout=0.23674146696038556, weight_decay=0.0001710157450693804
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371      3          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045      9          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170      1          0.080505     7.456738
#         4    Stopped     1       0.000172           32           3 0.287803      0.000111      1          0.077961     7.109667
#         5 InProgress     1       0.000054          128           3 0.236741      0.000171      1          0.076516     8.004487
# 1 trials running, 5 finished (0 until the end), 280.42s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371      3          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045      9          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170      1          0.080505     7.456738
#         4    Stopped     1       0.000172           32           3 0.287803      0.000111      1          0.077961     7.109667
#         5 InProgress     4       0.000054          128           3 0.236741      0.000171      4          0.079526    25.483137
# 1 trials running, 5 finished (0 until the end), 300.44s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371      3          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045      9          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170      1          0.080505     7.456738
#         4    Stopped     1       0.000172           32           3 0.287803      0.000111      1          0.077961     7.109667
#         5 InProgress     8       0.000054          128           3 0.236741      0.000171      8          0.075729    48.904028
# 1 trials running, 5 finished (0 until the end), 320.46s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [12:29:32] 🚀 Trial 6 started - config: learning_rate=4.706622599219284e-05, num_hiddens=64, num_layers=4, dropout=0.26393034409649424, weight_decay=0.00041003755988296863
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371    3.0          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045    9.0          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170    1.0          0.080505     7.456738
#         4    Stopped     1       0.000172           32           3 0.287803      0.000111    1.0          0.077961     7.109667
#         5    Stopped    10       0.000054          128           3 0.236741      0.000171   10.0          0.080330    60.711894
#         6 InProgress     0       0.000047           64           4 0.263930      0.000410      -                 -            -
# 1 trials running, 6 finished (0 until the end), 340.49s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [12:29:47] 🚀 Trial 7 started - config: learning_rate=1.200187141320253e-05, num_hiddens=256, num_layers=2, dropout=0.37776112395808115, weight_decay=0.00013854093372995432
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371    3.0          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045    9.0          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170    1.0          0.080505     7.456738
#         4    Stopped     1       0.000172           32           3 0.287803      0.000111    1.0          0.077961     7.109667
#         5    Stopped    10       0.000054          128           3 0.236741      0.000171   10.0          0.080330    60.711894
#         6    Stopped     1       0.000047           64           4 0.263930      0.000410    1.0          0.080480     7.777727
#         7 InProgress     0       0.000012          256           2 0.377761      0.000139      -                 -            -
# 1 trials running, 7 finished (0 until the end), 360.51s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [12:30:07] 🚀 Trial 8 started - config: learning_rate=2.4900018113521004e-05, num_hiddens=64, num_layers=3, dropout=0.2696312571523408, weight_decay=0.0001453245004908215
# [12:30:22] 🚀 Trial 9 started - config: learning_rate=4.641088617934352e-05, num_hiddens=64, num_layers=2, dropout=0.3964674725923719, weight_decay=0.00017526500971231637
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371    3.0          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045    9.0          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170    1.0          0.080505     7.456738
#         4    Stopped     1       0.000172           32           3 0.287803      0.000111    1.0          0.077961     7.109667
#         5    Stopped    10       0.000054          128           3 0.236741      0.000171   10.0          0.080330    60.711894
#         6    Stopped     1       0.000047           64           4 0.263930      0.000410    1.0          0.080480     7.777727
#         7    Stopped     1       0.000012          256           2 0.377761      0.000139    1.0          0.078802    13.487100
#         8    Stopped     1       0.000025           64           3 0.269631      0.000145    1.0          0.078009     7.235096
#         9 InProgress     0       0.000046           64           2 0.396467      0.000175      -                 -            -
# 1 trials running, 9 finished (0 until the end), 380.56s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371      3          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045      9          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170      1          0.080505     7.456738
#         4    Stopped     1       0.000172           32           3 0.287803      0.000111      1          0.077961     7.109667
#         5    Stopped    10       0.000054          128           3 0.236741      0.000171     10          0.080330    60.711894
#         6    Stopped     1       0.000047           64           4 0.263930      0.000410      1          0.080480     7.777727
#         7    Stopped     1       0.000012          256           2 0.377761      0.000139      1          0.078802    13.487100
#         8    Stopped     1       0.000025           64           3 0.269631      0.000145      1          0.078009     7.235096
#         9 InProgress     2       0.000046           64           2 0.396467      0.000175      2          0.080686    11.414370
# 1 trials running, 9 finished (0 until the end), 400.58s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [12:30:47] 🚀 Trial 10 started - config: learning_rate=3.06163758112307e-05, num_hiddens=128, num_layers=2, dropout=0.44701209347451554, weight_decay=0.0004318733998016872
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371      3          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045      9          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170      1          0.080505     7.456738
#         4    Stopped     1       0.000172           32           3 0.287803      0.000111      1          0.077961     7.109667
#         5    Stopped    10       0.000054          128           3 0.236741      0.000171     10          0.080330    60.711894
#         6    Stopped     1       0.000047           64           4 0.263930      0.000410      1          0.080480     7.777727
#         7    Stopped     1       0.000012          256           2 0.377761      0.000139      1          0.078802    13.487100
#         8    Stopped     1       0.000025           64           3 0.269631      0.000145      1          0.078009     7.235096
#         9    Stopped     4       0.000046           64           2 0.396467      0.000175      4          0.080874    20.484051
#        10 InProgress     1       0.000031          128           2 0.447012      0.000432      1          0.076181     7.174143
# 1 trials running, 10 finished (0 until the end), 420.60s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [12:31:12] 🚀 Trial 11 started - config: learning_rate=1.794834452143703e-05, num_hiddens=256, num_layers=2, dropout=0.3378201440227935, weight_decay=1.4810138072219614e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371    3.0          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045    9.0          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170    1.0          0.080505     7.456738
#         4    Stopped     1       0.000172           32           3 0.287803      0.000111    1.0          0.077961     7.109667
#         5    Stopped    10       0.000054          128           3 0.236741      0.000171   10.0          0.080330    60.711894
#         6    Stopped     1       0.000047           64           4 0.263930      0.000410    1.0          0.080480     7.777727
#         7    Stopped     1       0.000012          256           2 0.377761      0.000139    1.0          0.078802    13.487100
#         8    Stopped     1       0.000025           64           3 0.269631      0.000145    1.0          0.078009     7.235096
#         9    Stopped     4       0.000046           64           2 0.396467      0.000175    4.0          0.080874    20.484051
#        10    Stopped     3       0.000031          128           2 0.447012      0.000432    3.0          0.077512    17.567583
#        11 InProgress     0       0.000018          256           2 0.337820      0.000015      -                 -            -
# 1 trials running, 11 finished (0 until the end), 440.62s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371      3          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045      9          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170      1          0.080505     7.456738
#         4    Stopped     1       0.000172           32           3 0.287803      0.000111      1          0.077961     7.109667
#         5    Stopped    10       0.000054          128           3 0.236741      0.000171     10          0.080330    60.711894
#         6    Stopped     1       0.000047           64           4 0.263930      0.000410      1          0.080480     7.777727
#         7    Stopped     1       0.000012          256           2 0.377761      0.000139      1          0.078802    13.487100
#         8    Stopped     1       0.000025           64           3 0.269631      0.000145      1          0.078009     7.235096
#         9    Stopped     4       0.000046           64           2 0.396467      0.000175      4          0.080874    20.484051
#        10    Stopped     3       0.000031          128           2 0.447012      0.000432      3          0.077512    17.567583
#        11 InProgress     2       0.000018          256           2 0.337820      0.000015      2          0.075711    24.507638
# 1 trials running, 11 finished (0 until the end), 460.64s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371      3          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045      9          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170      1          0.080505     7.456738
#         4    Stopped     1       0.000172           32           3 0.287803      0.000111      1          0.077961     7.109667
#         5    Stopped    10       0.000054          128           3 0.236741      0.000171     10          0.080330    60.711894
#         6    Stopped     1       0.000047           64           4 0.263930      0.000410      1          0.080480     7.777727
#         7    Stopped     1       0.000012          256           2 0.377761      0.000139      1          0.078802    13.487100
#         8    Stopped     1       0.000025           64           3 0.269631      0.000145      1          0.078009     7.235096
#         9    Stopped     4       0.000046           64           2 0.396467      0.000175      4          0.080874    20.484051
#        10    Stopped     3       0.000031          128           2 0.447012      0.000432      3          0.077512    17.567583
#        11 InProgress     3       0.000018          256           2 0.337820      0.000015      3          0.075023    35.460295
# 1 trials running, 11 finished (0 until the end), 480.67s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371      3          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045      9          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170      1          0.080505     7.456738
#         4    Stopped     1       0.000172           32           3 0.287803      0.000111      1          0.077961     7.109667
#         5    Stopped    10       0.000054          128           3 0.236741      0.000171     10          0.080330    60.711894
#         6    Stopped     1       0.000047           64           4 0.263930      0.000410      1          0.080480     7.777727
#         7    Stopped     1       0.000012          256           2 0.377761      0.000139      1          0.078802    13.487100
#         8    Stopped     1       0.000025           64           3 0.269631      0.000145      1          0.078009     7.235096
#         9    Stopped     4       0.000046           64           2 0.396467      0.000175      4          0.080874    20.484051
#        10    Stopped     3       0.000031          128           2 0.447012      0.000432      3          0.077512    17.567583
#        11 InProgress     5       0.000018          256           2 0.337820      0.000015      5          0.077157    57.560403
# 1 trials running, 11 finished (0 until the end), 500.69s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371      3          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045      9          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170      1          0.080505     7.456738
#         4    Stopped     1       0.000172           32           3 0.287803      0.000111      1          0.077961     7.109667
#         5    Stopped    10       0.000054          128           3 0.236741      0.000171     10          0.080330    60.711894
#         6    Stopped     1       0.000047           64           4 0.263930      0.000410      1          0.080480     7.777727
#         7    Stopped     1       0.000012          256           2 0.377761      0.000139      1          0.078802    13.487100
#         8    Stopped     1       0.000025           64           3 0.269631      0.000145      1          0.078009     7.235096
#         9    Stopped     4       0.000046           64           2 0.396467      0.000175      4          0.080874    20.484051
#        10    Stopped     3       0.000031          128           2 0.447012      0.000432      3          0.077512    17.567583
#        11 InProgress     7       0.000018          256           2 0.337820      0.000015      7          0.079129    79.622556
# 1 trials running, 11 finished (0 until the end), 520.71s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [12:33:02] 🚀 Trial 12 started - config: learning_rate=0.0002219606329292501, num_hiddens=32, num_layers=2, dropout=0.48304503383621494, weight_decay=0.00013614784537701054
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371    3.0          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045    9.0          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170    1.0          0.080505     7.456738
#         4    Stopped     1       0.000172           32           3 0.287803      0.000111    1.0          0.077961     7.109667
#         5    Stopped    10       0.000054          128           3 0.236741      0.000171   10.0          0.080330    60.711894
#         6    Stopped     1       0.000047           64           4 0.263930      0.000410    1.0          0.080480     7.777727
#         7    Stopped     1       0.000012          256           2 0.377761      0.000139    1.0          0.078802    13.487100
#         8    Stopped     1       0.000025           64           3 0.269631      0.000145    1.0          0.078009     7.235096
#         9    Stopped     4       0.000046           64           2 0.396467      0.000175    4.0          0.080874    20.484051
#        10    Stopped     3       0.000031          128           2 0.447012      0.000432    3.0          0.077512    17.567583
#        11    Stopped     9       0.000018          256           2 0.337820      0.000015    9.0          0.080601   101.627506
#        12 InProgress     0       0.000222           32           2 0.483045      0.000136      -                 -            -
# 1 trials running, 12 finished (0 until the end), 540.76s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [12:33:17] 🚀 Trial 13 started - config: learning_rate=3.855341060094848e-05, num_hiddens=128, num_layers=4, dropout=0.24403980009894644, weight_decay=0.00015483384248440727
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371    3.0          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045    9.0          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170    1.0          0.080505     7.456738
#         4    Stopped     1       0.000172           32           3 0.287803      0.000111    1.0          0.077961     7.109667
#         5    Stopped    10       0.000054          128           3 0.236741      0.000171   10.0          0.080330    60.711894
#         6    Stopped     1       0.000047           64           4 0.263930      0.000410    1.0          0.080480     7.777727
#         7    Stopped     1       0.000012          256           2 0.377761      0.000139    1.0          0.078802    13.487100
#         8    Stopped     1       0.000025           64           3 0.269631      0.000145    1.0          0.078009     7.235096
#         9    Stopped     4       0.000046           64           2 0.396467      0.000175    4.0          0.080874    20.484051
#        10    Stopped     3       0.000031          128           2 0.447012      0.000432    3.0          0.077512    17.567583
#        11    Stopped     9       0.000018          256           2 0.337820      0.000015    9.0          0.080601   101.627506
#        12    Stopped     1       0.000222           32           2 0.483045      0.000136    1.0          0.078726     6.520308
#        13 InProgress     0       0.000039          128           4 0.244040      0.000155      -                 -            -
# 1 trials running, 13 finished (0 until the end), 560.79s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371      3          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045      9          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170      1          0.080505     7.456738
#         4    Stopped     1       0.000172           32           3 0.287803      0.000111      1          0.077961     7.109667
#         5    Stopped    10       0.000054          128           3 0.236741      0.000171     10          0.080330    60.711894
#         6    Stopped     1       0.000047           64           4 0.263930      0.000410      1          0.080480     7.777727
#         7    Stopped     1       0.000012          256           2 0.377761      0.000139      1          0.078802    13.487100
#         8    Stopped     1       0.000025           64           3 0.269631      0.000145      1          0.078009     7.235096
#         9    Stopped     4       0.000046           64           2 0.396467      0.000175      4          0.080874    20.484051
#        10    Stopped     3       0.000031          128           2 0.447012      0.000432      3          0.077512    17.567583
#        11    Stopped     9       0.000018          256           2 0.337820      0.000015      9          0.080601   101.627506
#        12    Stopped     1       0.000222           32           2 0.483045      0.000136      1          0.078726     6.520308
#        13 InProgress     2       0.000039          128           4 0.244040      0.000155      2          0.076171    15.677812
# 1 trials running, 13 finished (0 until the end), 580.81s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371      3          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045      9          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170      1          0.080505     7.456738
#         4    Stopped     1       0.000172           32           3 0.287803      0.000111      1          0.077961     7.109667
#         5    Stopped    10       0.000054          128           3 0.236741      0.000171     10          0.080330    60.711894
#         6    Stopped     1       0.000047           64           4 0.263930      0.000410      1          0.080480     7.777727
#         7    Stopped     1       0.000012          256           2 0.377761      0.000139      1          0.078802    13.487100
#         8    Stopped     1       0.000025           64           3 0.269631      0.000145      1          0.078009     7.235096
#         9    Stopped     4       0.000046           64           2 0.396467      0.000175      4          0.080874    20.484051
#        10    Stopped     3       0.000031          128           2 0.447012      0.000432      3          0.077512    17.567583
#        11    Stopped     9       0.000018          256           2 0.337820      0.000015      9          0.080601   101.627506
#        12    Stopped     1       0.000222           32           2 0.483045      0.000136      1          0.078726     6.520308
#        13 InProgress     5       0.000039          128           4 0.244040      0.000155      5          0.074919    35.508102
# 1 trials running, 13 finished (0 until the end), 600.85s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371      3          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045      9          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170      1          0.080505     7.456738
#         4    Stopped     1       0.000172           32           3 0.287803      0.000111      1          0.077961     7.109667
#         5    Stopped    10       0.000054          128           3 0.236741      0.000171     10          0.080330    60.711894
#         6    Stopped     1       0.000047           64           4 0.263930      0.000410      1          0.080480     7.777727
#         7    Stopped     1       0.000012          256           2 0.377761      0.000139      1          0.078802    13.487100
#         8    Stopped     1       0.000025           64           3 0.269631      0.000145      1          0.078009     7.235096
#         9    Stopped     4       0.000046           64           2 0.396467      0.000175      4          0.080874    20.484051
#        10    Stopped     3       0.000031          128           2 0.447012      0.000432      3          0.077512    17.567583
#        11    Stopped     9       0.000018          256           2 0.337820      0.000015      9          0.080601   101.627506
#        12    Stopped     1       0.000222           32           2 0.483045      0.000136      1          0.078726     6.520308
#        13 InProgress     8       0.000039          128           4 0.244040      0.000155      8          0.074570    55.547098
# 1 trials running, 13 finished (0 until the end), 620.88s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [12:34:32] 🚀 Trial 14 started - config: learning_rate=0.00010837879746473028, num_hiddens=32, num_layers=4, dropout=0.3901309819196027, weight_decay=1.4460462774314663e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371    3.0          0.077313    22.482088
#         2    Stopped     9       0.000020          256           3 0.296739      0.000045    9.0          0.080566   132.157120
#         3    Stopped     1       0.000135           32           4 0.474895      0.000170    1.0          0.080505     7.456738
#         4    Stopped     1       0.000172           32           3 0.287803      0.000111    1.0          0.077961     7.109667
#         5    Stopped    10       0.000054          128           3 0.236741      0.000171   10.0          0.080330    60.711894
#         6    Stopped     1       0.000047           64           4 0.263930      0.000410    1.0          0.080480     7.777727
#         7    Stopped     1       0.000012          256           2 0.377761      0.000139    1.0          0.078802    13.487100
#         8    Stopped     1       0.000025           64           3 0.269631      0.000145    1.0          0.078009     7.235096
#         9    Stopped     4       0.000046           64           2 0.396467      0.000175    4.0          0.080874    20.484051
#        10    Stopped     3       0.000031          128           2 0.447012      0.000432    3.0          0.077512    17.567583
#        11    Stopped     9       0.000018          256           2 0.337820      0.000015    9.0          0.080601   101.627506
#        12    Stopped     1       0.000222           32           2 0.483045      0.000136    1.0          0.078726     6.520308
#        13    Stopped    10       0.000039          128           4 0.244040      0.000155   10.0          0.077719    69.011555
#        14 InProgress     0       0.000108           32           4 0.390131      0.000014      -                 -            -
# 1 trials running, 14 finished (0 until the end), 640.91s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [12:34:47] 🚀 Trial 15 started - config: learning_rate=0.00011563190005089363, num_hiddens=32, num_layers=4, dropout=0.25916301080229076, weight_decay=0.000251803154749357
# [12:35:02] 🚀 Trial 16 started - config: learning_rate=0.00021842004769160385, num_hiddens=64, num_layers=3, dropout=0.26562156913118834, weight_decay=0.0003493065491031024
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.077654    53.218629
#         1    Stopped     3       0.000030          128           4 0.405513      0.000371    3.0          0.077313    22.482088
# ...
#        11    Stopped     9       0.000018          256           2 0.337820      0.000015      9          0.080601   101.627506
#        12    Stopped     1       0.000222           32           2 0.483045      0.000136      1          0.078726     6.520308
#        13    Stopped    10       0.000039          128           4 0.244040      0.000155     10          0.077719    69.011555
#        14    Stopped     1       0.000108           32           4 0.390131      0.000014      1          0.082066     7.432326
#        15    Stopped     1       0.000116           32           4 0.259163      0.000252      1          0.080808     7.459349
#        16    Stopped    10       0.000218           64           3 0.265622      0.000349     10          0.077281    55.275530
#        17    Stopped     3       0.000369           64           2 0.223855      0.000014      3          0.079016    15.869094
#        18  Completed    10       0.000036          256           2 0.440128      0.000198     10          0.072944   111.643752
#        19    Stopped     1       0.000031           32           4 0.390772      0.000014      1          0.093583     7.649832
#        20    Stopped     1       0.000189          256           2 0.354916      0.000015      1          0.080750    13.494234
#        19    Stopped     1       0.000031           32           4 0.390772      0.000014    1.0          0.093583     7.649832
#        20    Stopped     1       0.000189          256           2 0.354916      0.000015    1.0          0.080750    13.494234
#        21    Stopped     1       0.000211          128           2 0.485632      0.000031    1.0          0.078930     7.335443
#        22    Stopped     9       0.000204          128           4 0.240110      0.000097    9.0          0.084262    62.631262
#        23    Stopped     1       0.000133           32           3 0.358737      0.000143    1.0          0.081468     6.973238
#        24    Stopped     1       0.000012          256           4 0.233897      0.000158    1.0          0.080333    21.569940
#        25    Stopped     9       0.000070          256           3 0.240439      0.000070    9.0          0.081244   133.927181
#        26    Stopped     1       0.000026          128           3 0.357726      0.000140    1.0          0.077555     8.000899
#        27    Stopped     1       0.000038           32           2 0.453951      0.000452    1.0          0.087014     6.592455
#        28    Stopped     3       0.000033          256           4 0.329481      0.000031    3.0          0.076866    57.858536
#        29    Stopped     3       0.000086           64           3 0.374001      0.000050    3.0          0.077895    18.041260
#        30 InProgress     0       0.000023           64           3 0.467668      0.000041      -                 -            -
# 1 trials running, 30 finished (1 until the end), 1287.21s wallclock-time
#
# validation_error: best 0.07294407486915588 for trial-id 18
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-18-12-24-05-784
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-18-12-24-05-784
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##11. Load Results from Dissolved Oxygen HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
oxygen_results_path = "/root/syne-tune/python-entrypoint-2026-03-18-12-24-05-784/results.csv.zip"

# Save the results to a Pandas DataFrame
oxygen_results = pd.read_csv(oxygen_results_path)

# %% [markdown]
# ##12. Save the Oxygen HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
oxygen_hpo_results_path = Path("/content/REDE_TRIB_E_202301_oxygen_hpo_results.csv")

# Save the DataFrame to a csv file
oxygen_results.to_csv(oxygen_hpo_results_path, index=True)

# %% [markdown]
# ## 13. Define the Config Space, Scheduler, and Tune Function for Temperature HPO

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on temperature_t_96 targets
def temperature_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Load the raw data from the project GitHub into a Pandas DataFrame and set index as DateTime
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/river_rede/REDE_TRIB_E_202301/df_parameters_preprocessed.zip")
    parameter_path = "/content" / data_path / "df_parameters_preprocessed.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "temperature"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ##14. Initialise and Run the Tuner for Temperature HPO

# %%
# Instruct the searcher to run each trial as a Python function
temperature_trial_backend = PythonBackend(
    tune_function=temperature_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=temperature_trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-18-12-58-32-206
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-18-12-58-32-206
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-18-12-58-32-206
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [12:58:33] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     1        0.00001           64           2      0.2       0.00001      1          0.110637     6.664411
# 1 trials running, 0 finished (0 until the end), 20.02s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     5        0.00001           64           2      0.2       0.00001      5          0.060372    25.426148
# 1 trials running, 0 finished (0 until the end), 40.04s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [12:59:28] 🚀 Trial 1 started - config: learning_rate=0.00012089502954917851, num_hiddens=256, num_layers=3, dropout=0.3292356114597742, weight_decay=3.56322379379925e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058559    49.263143
#         1 InProgress     0       0.000121          256           3 0.329236      0.000036      -                 -            -
# 1 trials running, 1 finished (0 until the end), 60.06s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058559    49.263143
#         1 InProgress     0       0.000121          256           3 0.329236      0.000036      -                 -            -
# 1 trials running, 1 finished (0 until the end), 80.07s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1 InProgress     2       0.000121          256           3 0.329236      0.000036      2          0.057652    32.270899
# 1 trials running, 1 finished (0 until the end), 100.10s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1 InProgress     3       0.000121          256           3 0.329236      0.000036      3          0.057711    46.679772
# 1 trials running, 1 finished (0 until the end), 120.12s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1 InProgress     5       0.000121          256           3 0.329236      0.000036      5          0.063368    75.583357
# 1 trials running, 1 finished (0 until the end), 140.14s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1 InProgress     6       0.000121          256           3 0.329236      0.000036      6          0.063996    90.398200
# 1 trials running, 1 finished (0 until the end), 160.16s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1 InProgress     7       0.000121          256           3 0.329236      0.000036      7          0.074581   104.916975
# 1 trials running, 1 finished (0 until the end), 180.18s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [13:01:48] 🚀 Trial 2 started - config: learning_rate=2.2133117326217626e-05, num_hiddens=128, num_layers=3, dropout=0.36771452970802915, weight_decay=3.432000490050053e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036    9.0          0.069139   134.191966
#         2 InProgress     0       0.000022          128           3 0.367715      0.000034      -                 -            -
# 1 trials running, 2 finished (0 until the end), 200.21s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036      9          0.069139   134.191966
#         2 InProgress     2       0.000022          128           3 0.367715      0.000034      2          0.058988    13.843977
# 1 trials running, 2 finished (0 until the end), 220.23s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036      9          0.069139   134.191966
#         2 InProgress     5       0.000022          128           3 0.367715      0.000034      5          0.057597    31.339489
# 1 trials running, 2 finished (0 until the end), 240.25s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036      9          0.069139   134.191966
#         2 InProgress     9       0.000022          128           3 0.367715      0.000034      9          0.059279    55.037319
# 1 trials running, 2 finished (0 until the end), 260.27s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [13:02:58] ✅ Trial 2 completed!
# [13:02:58] 🚀 Trial 3 started - config: learning_rate=0.00010768021205603312, num_hiddens=128, num_layers=3, dropout=0.24639273183491564, weight_decay=4.942233653097015e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036    9.0          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034   10.0          0.059408    61.064840
#         3 InProgress     0       0.000108          128           3 0.246393      0.000049      -                 -            -
# 1 trials running, 3 finished (1 until the end), 280.29s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036      9          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034     10          0.059408    61.064840
#         3 InProgress     4       0.000108          128           3 0.246393      0.000049      4          0.061746    25.929657
# 1 trials running, 3 finished (1 until the end), 300.33s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036      9          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034     10          0.059408    61.064840
#         3 InProgress     7       0.000108          128           3 0.246393      0.000049      7          0.070965    43.801636
# 1 trials running, 3 finished (1 until the end), 320.35s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [13:03:58] 🚀 Trial 4 started - config: learning_rate=1.0832857647021482e-05, num_hiddens=64, num_layers=3, dropout=0.2106137524557312, weight_decay=1.2398310134531955e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036    9.0          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034   10.0          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049    9.0          0.074442    55.759587
#         4 InProgress     0       0.000011           64           3 0.210614      0.000012      -                 -            -
# 1 trials running, 4 finished (1 until the end), 340.38s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [13:04:13] 🚀 Trial 5 started - config: learning_rate=0.00012595690018317793, num_hiddens=32, num_layers=3, dropout=0.45533843307394106, weight_decay=1.1299973449148439e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036      9          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034     10          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049      9          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012      1          0.075511     7.333220
#         5 InProgress     1       0.000126           32           3 0.455338      0.000011      1          0.059873     7.041897
# 1 trials running, 5 finished (1 until the end), 360.41s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [13:04:38] 🚀 Trial 6 started - config: learning_rate=1.754460302076211e-05, num_hiddens=128, num_layers=2, dropout=0.2817202456186093, weight_decay=3.0221445571978874e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036    9.0          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034   10.0          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049    9.0          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012    1.0          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011    3.0          0.060244    17.226537
#         6 InProgress     0       0.000018          128           2 0.281720      0.000030      -                 -            -
# 1 trials running, 6 finished (1 until the end), 380.42s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [13:04:53] 🚀 Trial 7 started - config: learning_rate=0.00019303430661190397, num_hiddens=256, num_layers=4, dropout=0.3944351324579536, weight_decay=1.9427047868284168e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036    9.0          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034   10.0          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049    9.0          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012    1.0          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011    3.0          0.060244    17.226537
#         6    Stopped     1       0.000018          128           2 0.281720      0.000030    1.0          0.061419     7.383254
#         7 InProgress     0       0.000193          256           4 0.394435      0.000019      -                 -            -
# 1 trials running, 7 finished (1 until the end), 400.46s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036      9          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034     10          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049      9          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012      1          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011      3          0.060244    17.226537
#         6    Stopped     1       0.000018          128           2 0.281720      0.000030      1          0.061419     7.383254
#         7 InProgress     1       0.000193          256           4 0.394435      0.000019      1          0.058775    21.003090
# 1 trials running, 7 finished (1 until the end), 420.48s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036      9          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034     10          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049      9          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012      1          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011      3          0.060244    17.226537
#         6    Stopped     1       0.000018          128           2 0.281720      0.000030      1          0.061419     7.383254
#         7 InProgress     2       0.000193          256           4 0.394435      0.000019      2          0.057530    38.973690
# 1 trials running, 7 finished (1 until the end), 440.50s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [13:05:58] 🚀 Trial 8 started - config: learning_rate=4.6991714766467454e-05, num_hiddens=256, num_layers=4, dropout=0.39510245778425945, weight_decay=5.188515593375845e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036    9.0          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034   10.0          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049    9.0          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012    1.0          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011    3.0          0.060244    17.226537
#         6    Stopped     1       0.000018          128           2 0.281720      0.000030    1.0          0.061419     7.383254
#         7    Stopped     3       0.000193          256           4 0.394435      0.000019    3.0          0.077034    56.676375
#         8 InProgress     0       0.000047          256           4 0.395102      0.000052      -                 -            -
# 1 trials running, 8 finished (1 until the end), 460.53s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036      9          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034     10          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049      9          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012      1          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011      3          0.060244    17.226537
#         6    Stopped     1       0.000018          128           2 0.281720      0.000030      1          0.061419     7.383254
#         7    Stopped     3       0.000193          256           4 0.394435      0.000019      3          0.077034    56.676375
#         8 InProgress     1       0.000047          256           4 0.395102      0.000052      1          0.059311    21.111703
# 1 trials running, 8 finished (1 until the end), 480.55s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036      9          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034     10          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049      9          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012      1          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011      3          0.060244    17.226537
#         6    Stopped     1       0.000018          128           2 0.281720      0.000030      1          0.061419     7.383254
#         7    Stopped     3       0.000193          256           4 0.394435      0.000019      3          0.077034    56.676375
#         8 InProgress     2       0.000047          256           4 0.395102      0.000052      2          0.059250    39.128590
# 1 trials running, 8 finished (1 until the end), 500.58s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [13:07:03] 🚀 Trial 9 started - config: learning_rate=4.150424853316521e-05, num_hiddens=256, num_layers=2, dropout=0.3363970485136798, weight_decay=1.4592484682428072e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036    9.0          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034   10.0          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049    9.0          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012    1.0          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011    3.0          0.060244    17.226537
#         6    Stopped     1       0.000018          128           2 0.281720      0.000030    1.0          0.061419     7.383254
#         7    Stopped     3       0.000193          256           4 0.394435      0.000019    3.0          0.077034    56.676375
#         8    Stopped     3       0.000047          256           4 0.395102      0.000052    3.0          0.058773    56.844392
#         9 InProgress     0       0.000042          256           2 0.336397      0.000015      -                 -            -
# 1 trials running, 9 finished (1 until the end), 520.61s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036      9          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034     10          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049      9          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012      1          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011      3          0.060244    17.226537
#         6    Stopped     1       0.000018          128           2 0.281720      0.000030      1          0.061419     7.383254
#         7    Stopped     3       0.000193          256           4 0.394435      0.000019      3          0.077034    56.676375
#         8    Stopped     3       0.000047          256           4 0.395102      0.000052      3          0.058773    56.844392
#         9 InProgress     1       0.000042          256           2 0.336397      0.000015      1          0.058610    13.861999
# 1 trials running, 9 finished (1 until the end), 540.63s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036      9          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034     10          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049      9          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012      1          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011      3          0.060244    17.226537
#         6    Stopped     1       0.000018          128           2 0.281720      0.000030      1          0.061419     7.383254
#         7    Stopped     3       0.000193          256           4 0.394435      0.000019      3          0.077034    56.676375
#         8    Stopped     3       0.000047          256           4 0.395102      0.000052      3          0.058773    56.844392
#         9 InProgress     3       0.000042          256           2 0.336397      0.000015      3          0.057093    35.982095
# 1 trials running, 9 finished (1 until the end), 560.66s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036      9          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034     10          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049      9          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012      1          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011      3          0.060244    17.226537
#         6    Stopped     1       0.000018          128           2 0.281720      0.000030      1          0.061419     7.383254
#         7    Stopped     3       0.000193          256           4 0.394435      0.000019      3          0.077034    56.676375
#         8    Stopped     3       0.000047          256           4 0.395102      0.000052      3          0.058773    56.844392
#         9 InProgress     5       0.000042          256           2 0.336397      0.000015      5          0.057867    58.094731
# 1 trials running, 9 finished (1 until the end), 580.68s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036      9          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034     10          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049      9          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012      1          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011      3          0.060244    17.226537
#         6    Stopped     1       0.000018          128           2 0.281720      0.000030      1          0.061419     7.383254
#         7    Stopped     3       0.000193          256           4 0.394435      0.000019      3          0.077034    56.676375
#         8    Stopped     3       0.000047          256           4 0.395102      0.000052      3          0.058773    56.844392
#         9 InProgress     7       0.000042          256           2 0.336397      0.000015      7          0.061531    80.344670
# 1 trials running, 9 finished (1 until the end), 600.71s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036      9          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034     10          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049      9          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012      1          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011      3          0.060244    17.226537
#         6    Stopped     1       0.000018          128           2 0.281720      0.000030      1          0.061419     7.383254
#         7    Stopped     3       0.000193          256           4 0.394435      0.000019      3          0.077034    56.676375
#         8    Stopped     3       0.000047          256           4 0.395102      0.000052      3          0.058773    56.844392
#         9 InProgress     8       0.000042          256           2 0.336397      0.000015      8          0.066430    91.450501
# 1 trials running, 9 finished (1 until the end), 620.73s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [13:08:53] 🚀 Trial 10 started - config: learning_rate=0.00013927080856289002, num_hiddens=256, num_layers=3, dropout=0.20913689804159458, weight_decay=1.3033794799335322e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036    9.0          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034   10.0          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049    9.0          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012    1.0          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011    3.0          0.060244    17.226537
#         6    Stopped     1       0.000018          128           2 0.281720      0.000030    1.0          0.061419     7.383254
#         7    Stopped     3       0.000193          256           4 0.394435      0.000019    3.0          0.077034    56.676375
#         8    Stopped     3       0.000047          256           4 0.395102      0.000052    3.0          0.058773    56.844392
#         9    Stopped     9       0.000042          256           2 0.336397      0.000015    9.0          0.071309   102.674532
#        10 InProgress     0       0.000139          256           3 0.209137      0.000013      -                 -            -
# 1 trials running, 10 finished (1 until the end), 640.75s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [13:09:18] 🚀 Trial 11 started - config: learning_rate=0.000497161209246554, num_hiddens=64, num_layers=3, dropout=0.27596124487356416, weight_decay=6.59859277705829e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036    9.0          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034   10.0          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049    9.0          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012    1.0          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011    3.0          0.060244    17.226537
#         6    Stopped     1       0.000018          128           2 0.281720      0.000030    1.0          0.061419     7.383254
#         7    Stopped     3       0.000193          256           4 0.394435      0.000019    3.0          0.077034    56.676375
#         8    Stopped     3       0.000047          256           4 0.395102      0.000052    3.0          0.058773    56.844392
#         9    Stopped     9       0.000042          256           2 0.336397      0.000015    9.0          0.071309   102.674532
#        10    Stopped     1       0.000139          256           3 0.209137      0.000013    1.0          0.061193    17.232611
#        11 InProgress     0       0.000497           64           3 0.275961      0.000066      -                 -            -
# 1 trials running, 11 finished (1 until the end), 660.78s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [13:09:43] 🚀 Trial 12 started - config: learning_rate=2.8762916041662392e-05, num_hiddens=128, num_layers=4, dropout=0.3247824533404723, weight_decay=1.0183714750820833e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036    9.0          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034   10.0          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049    9.0          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012    1.0          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011    3.0          0.060244    17.226537
#         6    Stopped     1       0.000018          128           2 0.281720      0.000030    1.0          0.061419     7.383254
#         7    Stopped     3       0.000193          256           4 0.394435      0.000019    3.0          0.077034    56.676375
#         8    Stopped     3       0.000047          256           4 0.395102      0.000052    3.0          0.058773    56.844392
#         9    Stopped     9       0.000042          256           2 0.336397      0.000015    9.0          0.071309   102.674532
#        10    Stopped     1       0.000139          256           3 0.209137      0.000013    1.0          0.061193    17.232611
#        11    Stopped     3       0.000497           64           3 0.275961      0.000066    3.0          0.063009    17.705737
#        12 InProgress     0       0.000029          128           4 0.324782      0.000010      -                 -            -
# 1 trials running, 12 finished (1 until the end), 680.81s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [13:09:58] 🚀 Trial 13 started - config: learning_rate=0.00029652635712311046, num_hiddens=128, num_layers=4, dropout=0.4327462162757886, weight_decay=2.5544805063822086e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036    9.0          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034   10.0          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049    9.0          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012    1.0          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011    3.0          0.060244    17.226537
#         6    Stopped     1       0.000018          128           2 0.281720      0.000030    1.0          0.061419     7.383254
#         7    Stopped     3       0.000193          256           4 0.394435      0.000019    3.0          0.077034    56.676375
#         8    Stopped     3       0.000047          256           4 0.395102      0.000052    3.0          0.058773    56.844392
#         9    Stopped     9       0.000042          256           2 0.336397      0.000015    9.0          0.071309   102.674532
#        10    Stopped     1       0.000139          256           3 0.209137      0.000013    1.0          0.061193    17.232611
#        11    Stopped     3       0.000497           64           3 0.275961      0.000066    3.0          0.063009    17.705737
#        12    Stopped     1       0.000029          128           4 0.324782      0.000010    1.0          0.060787     8.820257
#        13 InProgress     0       0.000297          128           4 0.432746      0.000026      -                 -            -
# 1 trials running, 13 finished (1 until the end), 700.84s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [13:10:13] 🚀 Trial 14 started - config: learning_rate=0.0003638900290613518, num_hiddens=32, num_layers=3, dropout=0.4444306539920995, weight_decay=1.7836242901235143e-05
# [13:10:28] 🚀 Trial 15 started - config: learning_rate=0.00013241151384616443, num_hiddens=256, num_layers=3, dropout=0.4705715059098006, weight_decay=3.504512675797797e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036    9.0          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034   10.0          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049    9.0          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012    1.0          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011    3.0          0.060244    17.226537
#         6    Stopped     1       0.000018          128           2 0.281720      0.000030    1.0          0.061419     7.383254
#         7    Stopped     3       0.000193          256           4 0.394435      0.000019    3.0          0.077034    56.676375
#         8    Stopped     3       0.000047          256           4 0.395102      0.000052    3.0          0.058773    56.844392
#         9    Stopped     9       0.000042          256           2 0.336397      0.000015    9.0          0.071309   102.674532
#        10    Stopped     1       0.000139          256           3 0.209137      0.000013    1.0          0.061193    17.232611
#        11    Stopped     3       0.000497           64           3 0.275961      0.000066    3.0          0.063009    17.705737
#        12    Stopped     1       0.000029          128           4 0.324782      0.000010    1.0          0.060787     8.820257
#        13    Stopped     1       0.000297          128           4 0.432746      0.000026    1.0          0.061009     8.860141
#        14    Stopped     1       0.000364           32           3 0.444431      0.000018    1.0          0.061891     7.031767
#        15 InProgress     0       0.000132          256           3 0.470572      0.000035      -                 -            -
# 1 trials running, 15 finished (1 until the end), 720.90s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ...
#        12    Stopped     1       0.000029          128           4 0.324782      0.000010    1.0          0.060787     8.820257
#        13    Stopped     1       0.000297          128           4 0.432746      0.000026    1.0          0.061009     8.860141
#        14    Stopped     1       0.000364           32           3 0.444431      0.000018    1.0          0.061891     7.031767
#        15    Stopped     3       0.000132          256           3 0.470572      0.000035    3.0          0.058201    46.305680
#        16    Stopped    10       0.000033          256           2 0.365724      0.000334   10.0          0.057210   110.726697
#        17    Stopped     3       0.000448           64           3 0.409066      0.000013    3.0          0.069949    17.475075
wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036      9          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034     10          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049      9          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012      1          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011      3          0.060244    17.226537
#         6    Stopped     1       0.000018          128           2 0.281720      0.000030      1          0.061419     7.383254
#         7    Stopped     3       0.000193          256           4 0.394435      0.000019      3          0.077034    56.676375
#         8    Stopped     3       0.000047          256           4 0.395102      0.000052      3          0.058773    56.844392
#         9    Stopped     9       0.000042          256           2 0.336397      0.000015      9          0.071309   102.674532
#        10    Stopped     1       0.000139          256           3 0.209137      0.000013      1          0.061193    17.232611
#        11    Stopped     3       0.000497           64           3 0.275961      0.000066      3          0.063009    17.705737
#        12    Stopped     1       0.000029          128           4 0.324782      0.000010      1          0.060787     8.820257
#        13    Stopped     1       0.000297          128           4 0.432746      0.000026      1          0.061009     8.860141
#        14    Stopped     1       0.000364           32           3 0.444431      0.000018      1          0.061891     7.031767
#        15    Stopped     3       0.000132          256           3 0.470572      0.000035      3          0.058201    46.305680
#        16    Stopped    10       0.000033          256           2 0.365724      0.000334     10          0.057210   110.726697
#        17    Stopped     3       0.000448           64           3 0.409066      0.000013      3          0.069949    17.475075
#        18    Stopped     1       0.000060           32           3 0.481141      0.000027      1          0.062083     6.837637
#        19    Stopped     3       0.000053           64           3 0.200492      0.000018      3          0.059712    17.414868
#        20    Stopped     3       0.000123          128           4 0.396420      0.000013      3          0.058127    22.065485
#        21    Stopped     1       0.000355           64           4 0.325335      0.000050      1          0.063661     8.020976
#        22    Stopped     1       0.000446           32           3 0.311175      0.000264      1          0.065313     6.979777
#        23    Stopped     1       0.000036           32           3 0.416295      0.000010      1          0.064405     7.049445
#        24    Stopped     1       0.000141          256           3 0.458140      0.000206      1          0.060141    17.445672
#        25    Stopped     3       0.000061           64           3 0.456776      0.000085      3          0.059155    17.626859
#        26    Stopped     1       0.000432           32           3 0.367632      0.000063      1          0.064014     7.064584
#        27    Stopped     3       0.000196          128           2 0.206027      0.000110      3          0.058390    17.457569
#        28    Stopped     1       0.000017           64           2 0.383065      0.000023      1          0.069851     6.829779
#        29 InProgress     2       0.000122          256           4 0.205235      0.000074      2          0.057268    39.234710
# 1 trials running, 29 finished (1 until the end), 1181.84s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [13:18:29] 🚀 Trial 30 started - config: learning_rate=0.00023365936068273525, num_hiddens=32, num_layers=4, dropout=0.2426787914461027, weight_decay=0.00034935431954080285
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🎉🎉🎉 HYPERPARAMETER OPTIMIZATION COMPLETE!
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# --------------------
# Resource summary (last result is reported):
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058559    49.263143
#         1    Stopped     9       0.000121          256           3 0.329236      0.000036    9.0          0.069139   134.191966
#         2  Completed    10       0.000022          128           3 0.367715      0.000034   10.0          0.059408    61.064840
#         3    Stopped     9       0.000108          128           3 0.246393      0.000049    9.0          0.074442    55.759587
#         4    Stopped     1       0.000011           64           3 0.210614      0.000012    1.0          0.075511     7.333220
#         5    Stopped     3       0.000126           32           3 0.455338      0.000011    3.0          0.060244    17.226537
#         6    Stopped     1       0.000018          128           2 0.281720      0.000030    1.0          0.061419     7.383254
#         7    Stopped     3       0.000193          256           4 0.394435      0.000019    3.0          0.077034    56.676375
#         8    Stopped     3       0.000047          256           4 0.395102      0.000052    3.0          0.058773    56.844392
#         9    Stopped     9       0.000042          256           2 0.336397      0.000015    9.0          0.071309   102.674532
#        10    Stopped     1       0.000139          256           3 0.209137      0.000013    1.0          0.061193    17.232611
#        11    Stopped     3       0.000497           64           3 0.275961      0.000066    3.0          0.063009    17.705737
#        12    Stopped     1       0.000029          128           4 0.324782      0.000010    1.0          0.060787     8.820257
#        13    Stopped     1       0.000297          128           4 0.432746      0.000026    1.0          0.061009     8.860141
#        14    Stopped     1       0.000364           32           3 0.444431      0.000018    1.0          0.061891     7.031767
#        15    Stopped     3       0.000132          256           3 0.470572      0.000035    3.0          0.058201    46.305680
#        16    Stopped    10       0.000033          256           2 0.365724      0.000334   10.0          0.057210   110.726697
#        17    Stopped     3       0.000448           64           3 0.409066      0.000013    3.0          0.069949    17.475075
#        18    Stopped     1       0.000060           32           3 0.481141      0.000027    1.0          0.062083     6.837637
#        19    Stopped     3       0.000053           64           3 0.200492      0.000018    3.0          0.059712    17.414868
#        20    Stopped     3       0.000123          128           4 0.396420      0.000013    3.0          0.058127    22.065485
#        21    Stopped     1       0.000355           64           4 0.325335      0.000050    1.0          0.063661     8.020976
#        22    Stopped     1       0.000446           32           3 0.311175      0.000264    1.0          0.065313     6.979777
#        23    Stopped     1       0.000036           32           3 0.416295      0.000010    1.0          0.064405     7.049445
#        24    Stopped     1       0.000141          256           3 0.458140      0.000206    1.0          0.060141    17.445672
#        25    Stopped     3       0.000061           64           3 0.456776      0.000085    3.0          0.059155    17.626859
#        26    Stopped     1       0.000432           32           3 0.367632      0.000063    1.0          0.064014     7.064584
#        27    Stopped     3       0.000196          128           2 0.206027      0.000110    3.0          0.058390    17.457569
#        28    Stopped     1       0.000017           64           2 0.383065      0.000023    1.0          0.069851     6.829779
#        29    Stopped     3       0.000122          256           4 0.205235      0.000074    3.0          0.062006    56.918875
#        30 InProgress     0       0.000234           32           4 0.242679      0.000349      -                 -            -
# 1 trials running, 30 finished (1 until the end), 1196.88s wallclock-time
#
# validation_error: best 0.05635862797498703 for trial-id 3
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-18-12-58-32-206
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-18-12-58-32-206
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##15. Load Results from Temperature HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
temperature_results_path = "/root/syne-tune/python-entrypoint-2026-03-18-12-58-32-206/results.csv.zip"

# Save the results to a Pandas DataFrame
temperature_results = pd.read_csv(temperature_results_path)

# %% [markdown]
# ##16. Save the Temperature HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
temperature_hpo_results_path = Path("/content/REDE_TRIB_E_202301_temperature_hpo_results.csv")

# Save the DataFrame to a csv file
temperature_results.to_csv(temperature_hpo_results_path, index=True)
