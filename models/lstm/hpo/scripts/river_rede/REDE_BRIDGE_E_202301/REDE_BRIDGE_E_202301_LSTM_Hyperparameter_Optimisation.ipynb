# %% [markdown]
# # 0. Station Information
# * Station Name: REDE_BRIDGE_E_202301
# * Water Quality Data Link: https://environment.data.gov.uk/hydrology/station/E05524A

# %% [markdown]
# ## 0. Import the Relevant Libraries

# %%
# Force installation of Syne-Tune and a compatible NumPy version (may require restarting the session after running this cell before running below import cell)
# !pip install numpy==1.26.1 syne_tune --force-reinstall -q # ignore potential error messages if listed dependencies do not match imports
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 83.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.3/254.3 kB 23.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 151.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 138.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 132.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/131.7 MB 17.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 34.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 28.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 25.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 75.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.6/293.6 MB 3.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.1 which is incompatible.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.1 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.1 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# music21 9.9.1 requires numpy>=1.26.4, but you have numpy 1.26.1 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.1 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.1 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.1 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# datasets 4.0.0 requires dill<0.3.9,>=0.3.0, but you have dill 0.4.1 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# torch 2.10.0+cu128 requires nvidia-nccl-cu12==2.27.5; platform_system == "Linux", but you have nvidia-nccl-cu12 2.29.7 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.1 which is incompatible.

# %%
# Import relevant libraries (Note: May require running of above cell to ensure compatibility of NumPy and Syne-Tune)
import torch
import logging
logging.basicConfig(level=logging.INFO)
import numpy as np
import matplotlib.pyplot as plt
from syne_tune import StoppingCriterion, Tuner
from syne_tune.backend.python_backend.python_backend import PythonBackend
from syne_tune.config_space import loguniform, randint, choice, uniform
from syne_tune.experiments import load_experiment
from syne_tune.optimizer.baselines import ASHA
import pandas as pd
from pathlib import Path

# %% [markdown]
# ##1. Specify Epoch Ranges and Reduction Factor for Hyperparameter Optimisation (HPO)

# %%
# Specify the minimum and maximum number of epochs for which a trial is allowed to run during HPO
min_number_of_epochs = 2
max_number_of_epochs = 10

# Define the reduction factor for the Asynchronous Successive Halving Algorithm (ASHA)
eta = 2 # Set to 2 so that 50% of trials are stopped at each rung of the scheduler

# %% [markdown]
# ##2. Define the Tune Function to Optimise Hyperparameters for Ammonium Prediction

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on ammonium_t_96 targets
def ammonium_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Load the raw data from the project GitHub into a Pandas DataFrame and set index as DateTime
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/river_rede/REDE_BRIDGE_E_202301/REDE_BRIDGE_E_202301_preprocessed_data.zip")
    parameter_path = "/content" / data_path / "REDE_BRIDGE_E_202301_preprocessed_data.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "ammonium"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ## 3. Define the Configuration Space for Hyperparameter Search

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %% [markdown]
# ##4. Define the Resources Available for HPO

# %%
# Define the number of parallel workers available to evaluate trials concurrently
n_workers = max(1, torch.cuda.device_count()) # Uses all available GPUs for parallel trials or defaults to 1 worker if running on CPU

# Define the maximum number of trials to test
max_number_of_trials = 30

# Define the stopping criterion for HPO
stop_criterion = StoppingCriterion(max_num_trials_started=max_number_of_trials)

# %% [markdown]
# ##5. Define Asynchronous Successive Halving Algorithm (ASHA) for HPO

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %% [markdown]
# ##6. Initialise and Run the Tuner for Ammonium HPO

# %%
# Instruct the searcher to run each trial as a Python function
trial_backend = PythonBackend(
    tune_function=ammonium_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-19-14-54-10-202
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-19-14-54-10-202
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-19-14-54-10-202
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [14:54:10] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay
#         0 InProgress     0        0.00001           64           2      0.2       0.00001
# 1 trials running, 0 finished (0 until the end), 20.02s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     5        0.00001           64           2      0.2       0.00001      5          0.012396    28.932364
# 1 trials running, 0 finished (0 until the end), 40.04s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     9        0.00001           64           2      0.2       0.00001      9          0.011774    47.215966
# 1 trials running, 0 finished (0 until the end), 60.06s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:55:10] ✅ Trial 0 completed!
# [14:55:10] 🚀 Trial 1 started - config: learning_rate=1.9608438388697437e-05, num_hiddens=128, num_layers=2, dropout=0.25530645255911083, weight_decay=0.00012223357437952665
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10        0.00001           64           2 0.200000      0.000010     10          0.011449    51.674216
#         1 InProgress     1        0.00002          128           2 0.255306      0.000122      1          0.013454     6.969644
# 1 trials running, 1 finished (1 until the end), 80.08s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10        0.00001           64           2 0.200000      0.000010     10          0.011449    51.674216
#         1 InProgress     5        0.00002          128           2 0.255306      0.000122      5          0.010658    26.337265
# 1 trials running, 1 finished (1 until the end), 100.10s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10        0.00001           64           2 0.200000      0.000010     10          0.011449    51.674216
#         1 InProgress     9        0.00002          128           2 0.255306      0.000122      9          0.011332    46.286278
# 1 trials running, 1 finished (1 until the end), 120.12s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:56:10] ✅ Trial 1 completed!
# [14:56:10] 🚀 Trial 2 started - config: learning_rate=0.00030198958158057006, num_hiddens=64, num_layers=4, dropout=0.22396271377795965, weight_decay=9.994097660706523e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122     10          0.010241    51.222056
#         2 InProgress     1       0.000302           64           4 0.223963      0.000100      1          0.012371     7.426726
# 1 trials running, 2 finished (2 until the end), 140.15s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122     10          0.010241    51.222056
#         2 InProgress     5       0.000302           64           4 0.223963      0.000100      5          0.012972    29.068228
# 1 trials running, 2 finished (2 until the end), 160.18s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122     10          0.010241    51.222056
#         2 InProgress     8       0.000302           64           4 0.223963      0.000100      8          0.012180    45.547825
# 1 trials running, 2 finished (2 until the end), 180.20s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:57:10] 🚀 Trial 3 started - config: learning_rate=0.00015869444920155933, num_hiddens=256, num_layers=2, dropout=0.40390921018867765, weight_decay=8.335813293654245e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122   10.0          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100    9.0          0.012816    51.199508
#         3 InProgress     0       0.000159          256           2 0.403909      0.000083      -                 -            -
# 1 trials running, 3 finished (2 until the end), 200.22s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122     10          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100      9          0.012816    51.199508
#         3 InProgress     2       0.000159          256           2 0.403909      0.000083      2          0.011212    23.631843
# 1 trials running, 3 finished (2 until the end), 220.24s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122     10          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100      9          0.012816    51.199508
#         3 InProgress     4       0.000159          256           2 0.403909      0.000083      4          0.010732    44.310352
# 1 trials running, 3 finished (2 until the end), 240.27s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122     10          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100      9          0.012816    51.199508
#         3 InProgress     6       0.000159          256           2 0.403909      0.000083      6          0.010705    65.378504
# 1 trials running, 3 finished (2 until the end), 260.29s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122     10          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100      9          0.012816    51.199508
#         3 InProgress     8       0.000159          256           2 0.403909      0.000083      8          0.010338    86.116443
# 1 trials running, 3 finished (2 until the end), 280.33s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:58:55] 🚀 Trial 4 started - config: learning_rate=3.693801103322236e-05, num_hiddens=64, num_layers=3, dropout=0.3610713497656692, weight_decay=0.00019011467555541504
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122   10.0          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100    9.0          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083    9.0          0.013210    96.699258
#         4 InProgress     0       0.000037           64           3 0.361071      0.000190      -                 -            -
# 1 trials running, 4 finished (2 until the end), 300.34s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:59:10] 🚀 Trial 5 started - config: learning_rate=5.9523834037719855e-05, num_hiddens=256, num_layers=3, dropout=0.3676465430502531, weight_decay=2.6759534107276533e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122   10.0          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100    9.0          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083    9.0          0.013210    96.699258
#         4    Stopped     1       0.000037           64           3 0.361071      0.000190    1.0          0.021149     6.980532
#         5 InProgress     0       0.000060          256           3 0.367647      0.000027      -                 -            -
# 1 trials running, 5 finished (2 until the end), 320.37s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122     10          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100      9          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083      9          0.013210    96.699258
#         4    Stopped     1       0.000037           64           3 0.361071      0.000190      1          0.021149     6.980532
#         5 InProgress     2       0.000060          256           3 0.367647      0.000027      2          0.009659    30.827558
# 1 trials running, 5 finished (2 until the end), 340.39s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:00:01] 🚀 Trial 6 started - config: learning_rate=4.463411822642945e-05, num_hiddens=64, num_layers=3, dropout=0.4803180531373549, weight_decay=1.196415966256922e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122   10.0          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100    9.0          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083    9.0          0.013210    96.699258
#         4    Stopped     1       0.000037           64           3 0.361071      0.000190    1.0          0.021149     6.980532
#         5    Stopped     3       0.000060          256           3 0.367647      0.000027    3.0          0.011292    44.621271
#         6 InProgress     0       0.000045           64           3 0.480318      0.000012      -                 -            -
# 1 trials running, 6 finished (2 until the end), 360.41s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:00:16] 🚀 Trial 7 started - config: learning_rate=0.00022191102122183775, num_hiddens=256, num_layers=3, dropout=0.2050975393773407, weight_decay=6.915224230267574e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122   10.0          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100    9.0          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083    9.0          0.013210    96.699258
#         4    Stopped     1       0.000037           64           3 0.361071      0.000190    1.0          0.021149     6.980532
#         5    Stopped     3       0.000060          256           3 0.367647      0.000027    3.0          0.011292    44.621271
#         6    Stopped     1       0.000045           64           3 0.480318      0.000012    1.0          0.014827     7.005019
#         7 InProgress     0       0.000222          256           3 0.205098      0.000069      -                 -            -
# 1 trials running, 7 finished (2 until the end), 380.45s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122     10          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100      9          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083      9          0.013210    96.699258
#         4    Stopped     1       0.000037           64           3 0.361071      0.000190      1          0.021149     6.980532
#         5    Stopped     3       0.000060          256           3 0.367647      0.000027      3          0.011292    44.621271
#         6    Stopped     1       0.000045           64           3 0.480318      0.000012      1          0.014827     7.005019
#         7 InProgress     1       0.000222          256           3 0.205098      0.000069      1          0.012158    16.848743
# 1 trials running, 7 finished (2 until the end), 400.47s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:01:06] 🚀 Trial 8 started - config: learning_rate=7.211849515353732e-05, num_hiddens=128, num_layers=2, dropout=0.20322675720869787, weight_decay=0.0003373763280630907
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122   10.0          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100    9.0          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083    9.0          0.013210    96.699258
#         4    Stopped     1       0.000037           64           3 0.361071      0.000190    1.0          0.021149     6.980532
#         5    Stopped     3       0.000060          256           3 0.367647      0.000027    3.0          0.011292    44.621271
#         6    Stopped     1       0.000045           64           3 0.480318      0.000012    1.0          0.014827     7.005019
#         7    Stopped     3       0.000222          256           3 0.205098      0.000069    3.0          0.012731    44.593621
#         8 InProgress     0       0.000072          128           2 0.203227      0.000337      -                 -            -
# 1 trials running, 8 finished (2 until the end), 420.49s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:01:21] 🚀 Trial 9 started - config: learning_rate=2.094764904620434e-05, num_hiddens=256, num_layers=4, dropout=0.30189341698067496, weight_decay=0.0001179358418567768
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122   10.0          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100    9.0          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083    9.0          0.013210    96.699258
#         4    Stopped     1       0.000037           64           3 0.361071      0.000190    1.0          0.021149     6.980532
#         5    Stopped     3       0.000060          256           3 0.367647      0.000027    3.0          0.011292    44.621271
#         6    Stopped     1       0.000045           64           3 0.480318      0.000012    1.0          0.014827     7.005019
#         7    Stopped     3       0.000222          256           3 0.205098      0.000069    3.0          0.012731    44.593621
#         8    Stopped     1       0.000072          128           2 0.203227      0.000337    1.0          0.014371     6.951048
#         9 InProgress     0       0.000021          256           4 0.301893      0.000118      -                 -            -
# 1 trials running, 9 finished (2 until the end), 440.52s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:01:46] 🚀 Trial 10 started - config: learning_rate=3.3170281225980846e-05, num_hiddens=64, num_layers=2, dropout=0.45638418271338743, weight_decay=0.000324424235422181
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122   10.0          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100    9.0          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083    9.0          0.013210    96.699258
#         4    Stopped     1       0.000037           64           3 0.361071      0.000190    1.0          0.021149     6.980532
#         5    Stopped     3       0.000060          256           3 0.367647      0.000027    3.0          0.011292    44.621271
#         6    Stopped     1       0.000045           64           3 0.480318      0.000012    1.0          0.014827     7.005019
#         7    Stopped     3       0.000222          256           3 0.205098      0.000069    3.0          0.012731    44.593621
#         8    Stopped     1       0.000072          128           2 0.203227      0.000337    1.0          0.014371     6.951048
#         9    Stopped     1       0.000021          256           4 0.301893      0.000118    1.0          0.022702    20.836660
#        10 InProgress     0       0.000033           64           2 0.456384      0.000324      -                 -            -
# 1 trials running, 10 finished (2 until the end), 460.55s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:02:01] 🚀 Trial 11 started - config: learning_rate=0.00031972704492043544, num_hiddens=256, num_layers=3, dropout=0.3849030972458577, weight_decay=3.604249241197584e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122   10.0          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100    9.0          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083    9.0          0.013210    96.699258
#         4    Stopped     1       0.000037           64           3 0.361071      0.000190    1.0          0.021149     6.980532
#         5    Stopped     3       0.000060          256           3 0.367647      0.000027    3.0          0.011292    44.621271
#         6    Stopped     1       0.000045           64           3 0.480318      0.000012    1.0          0.014827     7.005019
#         7    Stopped     3       0.000222          256           3 0.205098      0.000069    3.0          0.012731    44.593621
#         8    Stopped     1       0.000072          128           2 0.203227      0.000337    1.0          0.014371     6.951048
#         9    Stopped     1       0.000021          256           4 0.301893      0.000118    1.0          0.022702    20.836660
#        10    Stopped     1       0.000033           64           2 0.456384      0.000324    1.0          0.017713     6.397189
#        11 InProgress     0       0.000320          256           3 0.384903      0.000036      -                 -            -
# 1 trials running, 11 finished (2 until the end), 480.58s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122     10          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100      9          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083      9          0.013210    96.699258
#         4    Stopped     1       0.000037           64           3 0.361071      0.000190      1          0.021149     6.980532
#         5    Stopped     3       0.000060          256           3 0.367647      0.000027      3          0.011292    44.621271
#         6    Stopped     1       0.000045           64           3 0.480318      0.000012      1          0.014827     7.005019
#         7    Stopped     3       0.000222          256           3 0.205098      0.000069      3          0.012731    44.593621
#         8    Stopped     1       0.000072          128           2 0.203227      0.000337      1          0.014371     6.951048
#         9    Stopped     1       0.000021          256           4 0.301893      0.000118      1          0.022702    20.836660
#        10    Stopped     1       0.000033           64           2 0.456384      0.000324      1          0.017713     6.397189
#        11 InProgress     1       0.000320          256           3 0.384903      0.000036      1          0.011951    16.915343
# 1 trials running, 11 finished (2 until the end), 500.60s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122     10          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100      9          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083      9          0.013210    96.699258
#         4    Stopped     1       0.000037           64           3 0.361071      0.000190      1          0.021149     6.980532
#         5    Stopped     3       0.000060          256           3 0.367647      0.000027      3          0.011292    44.621271
#         6    Stopped     1       0.000045           64           3 0.480318      0.000012      1          0.014827     7.005019
#         7    Stopped     3       0.000222          256           3 0.205098      0.000069      3          0.012731    44.593621
#         8    Stopped     1       0.000072          128           2 0.203227      0.000337      1          0.014371     6.951048
#         9    Stopped     1       0.000021          256           4 0.301893      0.000118      1          0.022702    20.836660
#        10    Stopped     1       0.000033           64           2 0.456384      0.000324      1          0.017713     6.397189
#        11 InProgress     2       0.000320          256           3 0.384903      0.000036      2          0.009097    31.074715
# 1 trials running, 11 finished (2 until the end), 520.63s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:02:51] 🚀 Trial 12 started - config: learning_rate=6.259507866036e-05, num_hiddens=64, num_layers=4, dropout=0.4679197766067932, weight_decay=1.4871974319141806e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122     10          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100      9          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083      9          0.013210    96.699258
#         4    Stopped     1       0.000037           64           3 0.361071      0.000190      1          0.021149     6.980532
#         5    Stopped     3       0.000060          256           3 0.367647      0.000027      3          0.011292    44.621271
#         6    Stopped     1       0.000045           64           3 0.480318      0.000012      1          0.014827     7.005019
#         7    Stopped     3       0.000222          256           3 0.205098      0.000069      3          0.012731    44.593621
#         8    Stopped     1       0.000072          128           2 0.203227      0.000337      1          0.014371     6.951048
#         9    Stopped     1       0.000021          256           4 0.301893      0.000118      1          0.022702    20.836660
#        10    Stopped     1       0.000033           64           2 0.456384      0.000324      1          0.017713     6.397189
#        11    Stopped     3       0.000320          256           3 0.384903      0.000036      3          0.012765    45.096920
#        12 InProgress     1       0.000063           64           4 0.467920      0.000015      1          0.012353     7.545807
# 1 trials running, 12 finished (2 until the end), 540.66s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:03:16] 🚀 Trial 13 started - config: learning_rate=1.0034649804597545e-05, num_hiddens=256, num_layers=4, dropout=0.3645497384159059, weight_decay=4.57068747640461e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122   10.0          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100    9.0          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083    9.0          0.013210    96.699258
#         4    Stopped     1       0.000037           64           3 0.361071      0.000190    1.0          0.021149     6.980532
#         5    Stopped     3       0.000060          256           3 0.367647      0.000027    3.0          0.011292    44.621271
#         6    Stopped     1       0.000045           64           3 0.480318      0.000012    1.0          0.014827     7.005019
#         7    Stopped     3       0.000222          256           3 0.205098      0.000069    3.0          0.012731    44.593621
#         8    Stopped     1       0.000072          128           2 0.203227      0.000337    1.0          0.014371     6.951048
#         9    Stopped     1       0.000021          256           4 0.301893      0.000118    1.0          0.022702    20.836660
#        10    Stopped     1       0.000033           64           2 0.456384      0.000324    1.0          0.017713     6.397189
#        11    Stopped     3       0.000320          256           3 0.384903      0.000036    3.0          0.012765    45.096920
#        12    Stopped     3       0.000063           64           4 0.467920      0.000015    3.0          0.011525    18.514797
#        13 InProgress     0       0.000010          256           4 0.364550      0.000046      -                 -            -
# 1 trials running, 13 finished (2 until the end), 560.67s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:03:41] 🚀 Trial 14 started - config: learning_rate=0.00036743474228574435, num_hiddens=32, num_layers=3, dropout=0.22442463303172874, weight_decay=2.876150420985983e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122   10.0          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100    9.0          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083    9.0          0.013210    96.699258
#         4    Stopped     1       0.000037           64           3 0.361071      0.000190    1.0          0.021149     6.980532
#         5    Stopped     3       0.000060          256           3 0.367647      0.000027    3.0          0.011292    44.621271
#         6    Stopped     1       0.000045           64           3 0.480318      0.000012    1.0          0.014827     7.005019
#         7    Stopped     3       0.000222          256           3 0.205098      0.000069    3.0          0.012731    44.593621
#         8    Stopped     1       0.000072          128           2 0.203227      0.000337    1.0          0.014371     6.951048
#         9    Stopped     1       0.000021          256           4 0.301893      0.000118    1.0          0.022702    20.836660
#        10    Stopped     1       0.000033           64           2 0.456384      0.000324    1.0          0.017713     6.397189
#        11    Stopped     3       0.000320          256           3 0.384903      0.000036    3.0          0.012765    45.096920
#        12    Stopped     3       0.000063           64           4 0.467920      0.000015    3.0          0.011525    18.514797
#        13    Stopped     1       0.000010          256           4 0.364550      0.000046    1.0          0.020331    20.453012
#        14 InProgress     0       0.000367           32           3 0.224425      0.000029      -                 -            -
# 1 trials running, 14 finished (2 until the end), 580.71s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122     10          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100      9          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083      9          0.013210    96.699258
#         4    Stopped     1       0.000037           64           3 0.361071      0.000190      1          0.021149     6.980532
#         5    Stopped     3       0.000060          256           3 0.367647      0.000027      3          0.011292    44.621271
#         6    Stopped     1       0.000045           64           3 0.480318      0.000012      1          0.014827     7.005019
#         7    Stopped     3       0.000222          256           3 0.205098      0.000069      3          0.012731    44.593621
#         8    Stopped     1       0.000072          128           2 0.203227      0.000337      1          0.014371     6.951048
#         9    Stopped     1       0.000021          256           4 0.301893      0.000118      1          0.022702    20.836660
#        10    Stopped     1       0.000033           64           2 0.456384      0.000324      1          0.017713     6.397189
#        11    Stopped     3       0.000320          256           3 0.384903      0.000036      3          0.012765    45.096920
#        12    Stopped     3       0.000063           64           4 0.467920      0.000015      3          0.011525    18.514797
#        13    Stopped     1       0.000010          256           4 0.364550      0.000046      1          0.020331    20.453012
#        14 InProgress     3       0.000367           32           3 0.224425      0.000029      3          0.010389    16.533323
# 1 trials running, 14 finished (2 until the end), 600.73s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122     10          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100      9          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083      9          0.013210    96.699258
#         4    Stopped     1       0.000037           64           3 0.361071      0.000190      1          0.021149     6.980532
#         5    Stopped     3       0.000060          256           3 0.367647      0.000027      3          0.011292    44.621271
#         6    Stopped     1       0.000045           64           3 0.480318      0.000012      1          0.014827     7.005019
#         7    Stopped     3       0.000222          256           3 0.205098      0.000069      3          0.012731    44.593621
#         8    Stopped     1       0.000072          128           2 0.203227      0.000337      1          0.014371     6.951048
#         9    Stopped     1       0.000021          256           4 0.301893      0.000118      1          0.022702    20.836660
#        10    Stopped     1       0.000033           64           2 0.456384      0.000324      1          0.017713     6.397189
#        11    Stopped     3       0.000320          256           3 0.384903      0.000036      3          0.012765    45.096920
#        12    Stopped     3       0.000063           64           4 0.467920      0.000015      3          0.011525    18.514797
#        13    Stopped     1       0.000010          256           4 0.364550      0.000046      1          0.020331    20.453012
#        14 InProgress     8       0.000367           32           3 0.224425      0.000029      8          0.011493    40.790398
# 1 trials running, 14 finished (2 until the end), 620.78s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:04:36] 🚀 Trial 15 started - config: learning_rate=2.889425462508453e-05, num_hiddens=128, num_layers=2, dropout=0.35950104150455364, weight_decay=9.056123975353505e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122   10.0          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100    9.0          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083    9.0          0.013210    96.699258
#         4    Stopped     1       0.000037           64           3 0.361071      0.000190    1.0          0.021149     6.980532
#         5    Stopped     3       0.000060          256           3 0.367647      0.000027    3.0          0.011292    44.621271
#         6    Stopped     1       0.000045           64           3 0.480318      0.000012    1.0          0.014827     7.005019
#         7    Stopped     3       0.000222          256           3 0.205098      0.000069    3.0          0.012731    44.593621
#         8    Stopped     1       0.000072          128           2 0.203227      0.000337    1.0          0.014371     6.951048
#         9    Stopped     1       0.000021          256           4 0.301893      0.000118    1.0          0.022702    20.836660
#        10    Stopped     1       0.000033           64           2 0.456384      0.000324    1.0          0.017713     6.397189
#        11    Stopped     3       0.000320          256           3 0.384903      0.000036    3.0          0.012765    45.096920
#        12    Stopped     3       0.000063           64           4 0.467920      0.000015    3.0          0.011525    18.514797
#        13    Stopped     1       0.000010          256           4 0.364550      0.000046    1.0          0.020331    20.453012
#        14    Stopped    10       0.000367           32           3 0.224425      0.000029   10.0          0.009703    50.529964
#        15 InProgress     0       0.000029          128           2 0.359501      0.000091      -                 -            -
# 1 trials running, 15 finished (2 until the end), 640.79s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122     10          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100      9          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083      9          0.013210    96.699258
#         4    Stopped     1       0.000037           64           3 0.361071      0.000190      1          0.021149     6.980532
#         5    Stopped     3       0.000060          256           3 0.367647      0.000027      3          0.011292    44.621271
#         6    Stopped     1       0.000045           64           3 0.480318      0.000012      1          0.014827     7.005019
#         7    Stopped     3       0.000222          256           3 0.205098      0.000069      3          0.012731    44.593621
#         8    Stopped     1       0.000072          128           2 0.203227      0.000337      1          0.014371     6.951048
#         9    Stopped     1       0.000021          256           4 0.301893      0.000118      1          0.022702    20.836660
#        10    Stopped     1       0.000033           64           2 0.456384      0.000324      1          0.017713     6.397189
#        11    Stopped     3       0.000320          256           3 0.384903      0.000036      3          0.012765    45.096920
#        12    Stopped     3       0.000063           64           4 0.467920      0.000015      3          0.011525    18.514797
#        13    Stopped     1       0.000010          256           4 0.364550      0.000046      1          0.020331    20.453012
# ...
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011449    51.674216
#         1  Completed    10       0.000020          128           2 0.255306      0.000122   10.0          0.010241    51.222056
#         2    Stopped     9       0.000302           64           4 0.223963      0.000100    9.0          0.012816    51.199508
#         3    Stopped     9       0.000159          256           2 0.403909      0.000083    9.0          0.013210    96.699258
#         4    Stopped     1       0.000037           64           3 0.361071      0.000190    1.0          0.021149     6.980532
#         5    Stopped     3       0.000060          256           3 0.367647      0.000027    3.0          0.011292    44.621271
#         6    Stopped     1       0.000045           64           3 0.480318      0.000012    1.0          0.014827     7.005019
#         7    Stopped     3       0.000222          256           3 0.205098      0.000069    3.0          0.012731    44.593621
#         8    Stopped     1       0.000072          128           2 0.203227      0.000337    1.0          0.014371     6.951048
#         9    Stopped     1       0.000021          256           4 0.301893      0.000118    1.0          0.022702    20.836660
#        10    Stopped     1       0.000033           64           2 0.456384      0.000324    1.0          0.017713     6.397189
#        11    Stopped     3       0.000320          256           3 0.384903      0.000036    3.0          0.012765    45.096920
#        12    Stopped     3       0.000063           64           4 0.467920      0.000015    3.0          0.011525    18.514797
#        13    Stopped     1       0.000010          256           4 0.364550      0.000046    1.0          0.020331    20.453012
#        14    Stopped    10       0.000367           32           3 0.224425      0.000029   10.0          0.009703    50.529964
#        15  Completed    10       0.000029          128           2 0.359501      0.000091   10.0          0.009924    51.502604
#        16    Stopped     1       0.000107           32           4 0.247491      0.000023    1.0          0.013222     7.184163
#        17  Completed    10       0.000024          128           3 0.203903      0.000026   10.0          0.010294    58.322428
#        18    Stopped     3       0.000112          128           3 0.255210      0.000065    3.0          0.011537    19.080089
#        19    Stopped     1       0.000030           64           3 0.485871      0.000091    1.0          0.020076     6.934541
#        20    Stopped     1       0.000146          256           4 0.221020      0.000198    1.0          0.026830    20.189102
#        21    Stopped     1       0.000195           64           4 0.207414      0.000249    1.0          0.026393     7.458880
#        22    Stopped     1       0.000169          128           2 0.353498      0.000460    1.0          0.015750     6.840659
#        23    Stopped     3       0.000215          256           3 0.470182      0.000089    3.0          0.013217    43.988011
#        24    Stopped    10       0.000055          256           2 0.402330      0.000011   10.0          0.010401   105.417514
#        25    Stopped     9       0.000238          128           4 0.479075      0.000047    9.0          0.012342    59.367144
#        26    Stopped     1       0.000053           64           2 0.232738      0.000014    1.0          0.012796     6.365201
#        27    Stopped     1       0.000011           32           4 0.359025      0.000163    1.0          0.026345     7.128358
#        28    Stopped     1       0.000105          256           3 0.232118      0.000311    1.0          0.021424    16.800655
#        29    Stopped     1       0.000049           64           2 0.460395      0.000060    1.0          0.013468     6.388743
#        30 InProgress     0       0.000050           64           2 0.361033      0.000033      -                 -            -
# 1 trials running, 30 finished (4 until the end), 1156.84s wallclock-time
#
# validation_error: best 0.008696985431015491 for trial-id 24
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-19-14-54-10-202
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-19-14-54-10-202
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##7. Load Results from HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
ammonium_results_path = "/root/syne-tune/python-entrypoint-2026-03-19-14-54-10-202/results.csv.zip"

# Save the results to a Pandas DataFrame
ammonium_results = pd.read_csv(ammonium_results_path)

# %% [markdown]
# ##8. Save the Ammonium HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
ammonium_hpo_results_path = Path("/content/REDE_BRIDGE_E_202301_ammonium_hpo_results.csv")

# Save the DataFrame to a csv file
ammonium_results.to_csv(ammonium_hpo_results_path, index=True)

# %% [markdown]
# ## 9. Define the Config Space, Scheduler, and Tune Function for Dissolved Oxygen HPO

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on ammonium_t_96 targets
def oxygen_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Load the raw data from the project GitHub into a Pandas DataFrame and set index as DateTime
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/river_rede/REDE_BRIDGE_E_202301/REDE_BRIDGE_E_202301_preprocessed_data.zip")
    parameter_path = "/content" / data_path / "REDE_BRIDGE_E_202301_preprocessed_data.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "oxygen_conc"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ##10. Initialise and Run the Tuner for Oxygen HPO

# %%
# Instruct the searcher to run each trial as a Python function
oxygen_trial_backend = PythonBackend(
    tune_function=oxygen_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=oxygen_trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-19-15-15-24-509
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-19-15-15-24-509
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-19-15-15-24-509
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [15:15:25] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     1        0.00001           64           2      0.2       0.00001      1          0.099407     6.488088
# 1 trials running, 0 finished (0 until the end), 20.02s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     6        0.00001           64           2      0.2       0.00001      6          0.070386    28.722365
# 1 trials running, 0 finished (0 until the end), 40.04s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:16:20] ✅ Trial 0 completed!
# [15:16:20] 🚀 Trial 1 started - config: learning_rate=0.00023191570716732716, num_hiddens=128, num_layers=4, dropout=0.48618925429669785, weight_decay=0.00015726100306417466
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.068856    46.668134
#         1 InProgress     0       0.000232          128           4 0.486189      0.000157      -                 -            -
# 1 trials running, 1 finished (1 until the end), 60.06s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.068856    46.668134
#         1 InProgress     2       0.000232          128           4 0.486189      0.000157      2          0.068174    14.966738
# 1 trials running, 1 finished (1 until the end), 80.08s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.068856    46.668134
#         1 InProgress     5       0.000232          128           4 0.486189      0.000157      5          0.070158    33.641904
# 1 trials running, 1 finished (1 until the end), 100.10s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.068856    46.668134
#         1 InProgress     8       0.000232          128           4 0.486189      0.000157      8          0.070183    52.615509
# 1 trials running, 1 finished (1 until the end), 120.13s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:17:25] 🚀 Trial 2 started - config: learning_rate=2.7333654337734526e-05, num_hiddens=256, num_layers=2, dropout=0.25942979603140404, weight_decay=1.0117128961100658e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157    9.0          0.070295    59.097092
#         2 InProgress     0       0.000027          256           2 0.259430      0.000010      -                 -            -
# 1 trials running, 2 finished (1 until the end), 140.14s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157      9          0.070295    59.097092
#         2 InProgress     2       0.000027          256           2 0.259430      0.000010      2          0.068158    23.728871
# 1 trials running, 2 finished (1 until the end), 160.16s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157      9          0.070295    59.097092
#         2 InProgress     4       0.000027          256           2 0.259430      0.000010      4          0.067895    44.383343
# 1 trials running, 2 finished (1 until the end), 180.18s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157      9          0.070295    59.097092
#         2 InProgress     6       0.000027          256           2 0.259430      0.000010      6          0.068367    65.390093
# 1 trials running, 2 finished (1 until the end), 200.20s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157      9          0.070295    59.097092
#         2 InProgress     8       0.000027          256           2 0.259430      0.000010      8          0.070530    86.283215
# 1 trials running, 2 finished (1 until the end), 220.22s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:19:10] 🚀 Trial 3 started - config: learning_rate=9.465515913159308e-05, num_hiddens=256, num_layers=2, dropout=0.34502127120850135, weight_decay=5.366689033956839e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157    9.0          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010    9.0          0.073605    96.917017
#         3 InProgress     0       0.000095          256           2 0.345021      0.000054      -                 -            -
# 1 trials running, 3 finished (1 until the end), 240.25s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157      9          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010      9          0.073605    96.917017
#         3 InProgress     2       0.000095          256           2 0.345021      0.000054      2          0.067180    23.676909
# 1 trials running, 3 finished (1 until the end), 260.27s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157      9          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010      9          0.073605    96.917017
#         3 InProgress     4       0.000095          256           2 0.345021      0.000054      4          0.067389    44.549482
# 1 trials running, 3 finished (1 until the end), 280.29s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157      9          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010      9          0.073605    96.917017
#         3 InProgress     5       0.000095          256           2 0.345021      0.000054      5          0.069450    55.043580
# 1 trials running, 3 finished (1 until the end), 300.31s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157      9          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010      9          0.073605    96.917017
#         3 InProgress     7       0.000095          256           2 0.345021      0.000054      7          0.075828    76.530697
# 1 trials running, 3 finished (1 until the end), 320.33s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:20:55] 🚀 Trial 4 started - config: learning_rate=0.00016625194977768862, num_hiddens=256, num_layers=4, dropout=0.3356666348618814, weight_decay=0.00011000744857381883
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157    9.0          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010    9.0          0.073605    96.917017
#         3    Stopped     9       0.000095          256           2 0.345021      0.000054    9.0          0.080086    98.267260
#         4 InProgress     0       0.000166          256           4 0.335667      0.000110      -                 -            -
# 1 trials running, 4 finished (1 until the end), 340.36s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:21:20] 🚀 Trial 5 started - config: learning_rate=0.0003452656013499097, num_hiddens=32, num_layers=3, dropout=0.2006022321074647, weight_decay=3.0174437367567665e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157    9.0          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010    9.0          0.073605    96.917017
#         3    Stopped     9       0.000095          256           2 0.345021      0.000054    9.0          0.080086    98.267260
#         4    Stopped     1       0.000166          256           4 0.335667      0.000110    1.0          0.070219    20.499720
#         5 InProgress     0       0.000345           32           3 0.200602      0.000030      -                 -            -
# 1 trials running, 5 finished (1 until the end), 360.38s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:21:35] 🚀 Trial 6 started - config: learning_rate=9.294609129991292e-05, num_hiddens=32, num_layers=2, dropout=0.4129902915258873, weight_decay=0.00045490901998776896
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157    9.0          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010    9.0          0.073605    96.917017
#         3    Stopped     9       0.000095          256           2 0.345021      0.000054    9.0          0.080086    98.267260
#         4    Stopped     1       0.000166          256           4 0.335667      0.000110    1.0          0.070219    20.499720
#         5    Stopped     1       0.000345           32           3 0.200602      0.000030    1.0          0.071883     6.774255
#         6 InProgress     0       0.000093           32           2 0.412990      0.000455      -                 -            -
# 1 trials running, 6 finished (1 until the end), 380.40s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:21:50] 🚀 Trial 7 started - config: learning_rate=1.5138206476236983e-05, num_hiddens=256, num_layers=2, dropout=0.41687717637793675, weight_decay=0.00018077930038212957
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157    9.0          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010    9.0          0.073605    96.917017
#         3    Stopped     9       0.000095          256           2 0.345021      0.000054    9.0          0.080086    98.267260
#         4    Stopped     1       0.000166          256           4 0.335667      0.000110    1.0          0.070219    20.499720
#         5    Stopped     1       0.000345           32           3 0.200602      0.000030    1.0          0.071883     6.774255
#         6    Stopped     1       0.000093           32           2 0.412990      0.000455    1.0          0.075629     6.450967
#         7 InProgress     0       0.000015          256           2 0.416877      0.000181      -                 -            -
# 1 trials running, 7 finished (1 until the end), 400.43s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:22:10] 🚀 Trial 8 started - config: learning_rate=2.0538115600398546e-05, num_hiddens=128, num_layers=3, dropout=0.35936488994088356, weight_decay=7.277418581345382e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157    9.0          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010    9.0          0.073605    96.917017
#         3    Stopped     9       0.000095          256           2 0.345021      0.000054    9.0          0.080086    98.267260
#         4    Stopped     1       0.000166          256           4 0.335667      0.000110    1.0          0.070219    20.499720
#         5    Stopped     1       0.000345           32           3 0.200602      0.000030    1.0          0.071883     6.774255
#         6    Stopped     1       0.000093           32           2 0.412990      0.000455    1.0          0.075629     6.450967
#         7    Stopped     1       0.000015          256           2 0.416877      0.000181    1.0          0.072945    12.893450
#         8 InProgress     0       0.000021          128           3 0.359365      0.000073      -                 -            -
# 1 trials running, 8 finished (1 until the end), 420.45s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:22:25] 🚀 Trial 9 started - config: learning_rate=0.0002967846684040331, num_hiddens=64, num_layers=2, dropout=0.4495233094677708, weight_decay=0.00010627408167033562
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157      9          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010      9          0.073605    96.917017
#         3    Stopped     9       0.000095          256           2 0.345021      0.000054      9          0.080086    98.267260
#         4    Stopped     1       0.000166          256           4 0.335667      0.000110      1          0.070219    20.499720
#         5    Stopped     1       0.000345           32           3 0.200602      0.000030      1          0.071883     6.774255
#         6    Stopped     1       0.000093           32           2 0.412990      0.000455      1          0.075629     6.450967
#         7    Stopped     1       0.000015          256           2 0.416877      0.000181      1          0.072945    12.893450
#         8    Stopped     1       0.000021          128           3 0.359365      0.000073      1          0.073350     7.788931
#         9 InProgress     2       0.000297           64           2 0.449523      0.000106      2          0.071416    10.842600
# 1 trials running, 9 finished (1 until the end), 440.50s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:22:45] 🚀 Trial 10 started - config: learning_rate=0.0004084795747339762, num_hiddens=32, num_layers=4, dropout=0.32355196618728754, weight_decay=9.776087093948238e-05
# [15:23:00] 🚀 Trial 11 started - config: learning_rate=0.0002377441104498406, num_hiddens=64, num_layers=4, dropout=0.23436970289366413, weight_decay=0.00023992091983665443
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157    9.0          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010    9.0          0.073605    96.917017
#         3    Stopped     9       0.000095          256           2 0.345021      0.000054    9.0          0.080086    98.267260
#         4    Stopped     1       0.000166          256           4 0.335667      0.000110    1.0          0.070219    20.499720
#         5    Stopped     1       0.000345           32           3 0.200602      0.000030    1.0          0.071883     6.774255
#         6    Stopped     1       0.000093           32           2 0.412990      0.000455    1.0          0.075629     6.450967
#         7    Stopped     1       0.000015          256           2 0.416877      0.000181    1.0          0.072945    12.893450
#         8    Stopped     1       0.000021          128           3 0.359365      0.000073    1.0          0.073350     7.788931
#         9    Stopped     3       0.000297           64           2 0.449523      0.000106    3.0          0.069405    15.223440
#        10    Stopped     1       0.000408           32           4 0.323552      0.000098    1.0          0.074908     7.101846
#        11 InProgress     0       0.000238           64           4 0.234370      0.000240      -                 -            -
# 1 trials running, 11 finished (1 until the end), 460.54s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:23:15] 🚀 Trial 12 started - config: learning_rate=8.118439607711455e-05, num_hiddens=64, num_layers=2, dropout=0.2782057949804734, weight_decay=0.00011394836962628137
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157    9.0          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010    9.0          0.073605    96.917017
#         3    Stopped     9       0.000095          256           2 0.345021      0.000054    9.0          0.080086    98.267260
#         4    Stopped     1       0.000166          256           4 0.335667      0.000110    1.0          0.070219    20.499720
#         5    Stopped     1       0.000345           32           3 0.200602      0.000030    1.0          0.071883     6.774255
#         6    Stopped     1       0.000093           32           2 0.412990      0.000455    1.0          0.075629     6.450967
#         7    Stopped     1       0.000015          256           2 0.416877      0.000181    1.0          0.072945    12.893450
#         8    Stopped     1       0.000021          128           3 0.359365      0.000073    1.0          0.073350     7.788931
#         9    Stopped     3       0.000297           64           2 0.449523      0.000106    3.0          0.069405    15.223440
#        10    Stopped     1       0.000408           32           4 0.323552      0.000098    1.0          0.074908     7.101846
#        11    Stopped     1       0.000238           64           4 0.234370      0.000240    1.0          0.071247     7.495528
#        12 InProgress     0       0.000081           64           2 0.278206      0.000114      -                 -            -
# 1 trials running, 12 finished (1 until the end), 480.56s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:23:30] 🚀 Trial 13 started - config: learning_rate=1.8874129083053145e-05, num_hiddens=64, num_layers=4, dropout=0.31921496202527655, weight_decay=7.976175538250955e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157    9.0          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010    9.0          0.073605    96.917017
#         3    Stopped     9       0.000095          256           2 0.345021      0.000054    9.0          0.080086    98.267260
#         4    Stopped     1       0.000166          256           4 0.335667      0.000110    1.0          0.070219    20.499720
#         5    Stopped     1       0.000345           32           3 0.200602      0.000030    1.0          0.071883     6.774255
#         6    Stopped     1       0.000093           32           2 0.412990      0.000455    1.0          0.075629     6.450967
#         7    Stopped     1       0.000015          256           2 0.416877      0.000181    1.0          0.072945    12.893450
#         8    Stopped     1       0.000021          128           3 0.359365      0.000073    1.0          0.073350     7.788931
#         9    Stopped     3       0.000297           64           2 0.449523      0.000106    3.0          0.069405    15.223440
#        10    Stopped     1       0.000408           32           4 0.323552      0.000098    1.0          0.074908     7.101846
#        11    Stopped     1       0.000238           64           4 0.234370      0.000240    1.0          0.071247     7.495528
#        12    Stopped     1       0.000081           64           2 0.278206      0.000114    1.0          0.070725     6.380412
#        13 InProgress     0       0.000019           64           4 0.319215      0.000080      -                 -            -
# 1 trials running, 13 finished (1 until the end), 500.59s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:23:45] 🚀 Trial 14 started - config: learning_rate=6.201059529124846e-05, num_hiddens=256, num_layers=3, dropout=0.3382615520937763, weight_decay=0.00023377015659679923
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157    9.0          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010    9.0          0.073605    96.917017
#         3    Stopped     9       0.000095          256           2 0.345021      0.000054    9.0          0.080086    98.267260
#         4    Stopped     1       0.000166          256           4 0.335667      0.000110    1.0          0.070219    20.499720
#         5    Stopped     1       0.000345           32           3 0.200602      0.000030    1.0          0.071883     6.774255
#         6    Stopped     1       0.000093           32           2 0.412990      0.000455    1.0          0.075629     6.450967
#         7    Stopped     1       0.000015          256           2 0.416877      0.000181    1.0          0.072945    12.893450
#         8    Stopped     1       0.000021          128           3 0.359365      0.000073    1.0          0.073350     7.788931
#         9    Stopped     3       0.000297           64           2 0.449523      0.000106    3.0          0.069405    15.223440
#        10    Stopped     1       0.000408           32           4 0.323552      0.000098    1.0          0.074908     7.101846
#        11    Stopped     1       0.000238           64           4 0.234370      0.000240    1.0          0.071247     7.495528
#        12    Stopped     1       0.000081           64           2 0.278206      0.000114    1.0          0.070725     6.380412
#        13    Stopped     1       0.000019           64           4 0.319215      0.000080    1.0          0.075388     7.507101
#        14 InProgress     0       0.000062          256           3 0.338262      0.000234      -                 -            -
# 1 trials running, 14 finished (1 until the end), 520.62s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157      9          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010      9          0.073605    96.917017
#         3    Stopped     9       0.000095          256           2 0.345021      0.000054      9          0.080086    98.267260
#         4    Stopped     1       0.000166          256           4 0.335667      0.000110      1          0.070219    20.499720
#         5    Stopped     1       0.000345           32           3 0.200602      0.000030      1          0.071883     6.774255
#         6    Stopped     1       0.000093           32           2 0.412990      0.000455      1          0.075629     6.450967
#         7    Stopped     1       0.000015          256           2 0.416877      0.000181      1          0.072945    12.893450
#         8    Stopped     1       0.000021          128           3 0.359365      0.000073      1          0.073350     7.788931
#         9    Stopped     3       0.000297           64           2 0.449523      0.000106      3          0.069405    15.223440
#        10    Stopped     1       0.000408           32           4 0.323552      0.000098      1          0.074908     7.101846
#        11    Stopped     1       0.000238           64           4 0.234370      0.000240      1          0.071247     7.495528
#        12    Stopped     1       0.000081           64           2 0.278206      0.000114      1          0.070725     6.380412
#        13    Stopped     1       0.000019           64           4 0.319215      0.000080      1          0.075388     7.507101
#        14 InProgress     2       0.000062          256           3 0.338262      0.000234      2          0.070196    30.736205
# 1 trials running, 14 finished (1 until the end), 540.65s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157      9          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010      9          0.073605    96.917017
#         3    Stopped     9       0.000095          256           2 0.345021      0.000054      9          0.080086    98.267260
#         4    Stopped     1       0.000166          256           4 0.335667      0.000110      1          0.070219    20.499720
#         5    Stopped     1       0.000345           32           3 0.200602      0.000030      1          0.071883     6.774255
#         6    Stopped     1       0.000093           32           2 0.412990      0.000455      1          0.075629     6.450967
#         7    Stopped     1       0.000015          256           2 0.416877      0.000181      1          0.072945    12.893450
#         8    Stopped     1       0.000021          128           3 0.359365      0.000073      1          0.073350     7.788931
#         9    Stopped     3       0.000297           64           2 0.449523      0.000106      3          0.069405    15.223440
#        10    Stopped     1       0.000408           32           4 0.323552      0.000098      1          0.074908     7.101846
#        11    Stopped     1       0.000238           64           4 0.234370      0.000240      1          0.071247     7.495528
#        12    Stopped     1       0.000081           64           2 0.278206      0.000114      1          0.070725     6.380412
#        13    Stopped     1       0.000019           64           4 0.319215      0.000080      1          0.075388     7.507101
#        14 InProgress     3       0.000062          256           3 0.338262      0.000234      3          0.068260    44.393424
# 1 trials running, 14 finished (1 until the end), 560.68s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157      9          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010      9          0.073605    96.917017
#         3    Stopped     9       0.000095          256           2 0.345021      0.000054      9          0.080086    98.267260
#         4    Stopped     1       0.000166          256           4 0.335667      0.000110      1          0.070219    20.499720
#         5    Stopped     1       0.000345           32           3 0.200602      0.000030      1          0.071883     6.774255
#         6    Stopped     1       0.000093           32           2 0.412990      0.000455      1          0.075629     6.450967
#         7    Stopped     1       0.000015          256           2 0.416877      0.000181      1          0.072945    12.893450
#         8    Stopped     1       0.000021          128           3 0.359365      0.000073      1          0.073350     7.788931
#         9    Stopped     3       0.000297           64           2 0.449523      0.000106      3          0.069405    15.223440
#        10    Stopped     1       0.000408           32           4 0.323552      0.000098      1          0.074908     7.101846
#        11    Stopped     1       0.000238           64           4 0.234370      0.000240      1          0.071247     7.495528
#        12    Stopped     1       0.000081           64           2 0.278206      0.000114      1          0.070725     6.380412
#        13    Stopped     1       0.000019           64           4 0.319215      0.000080      1          0.075388     7.507101
#        14 InProgress     4       0.000062          256           3 0.338262      0.000234      4          0.067848    58.143376
# 1 trials running, 14 finished (1 until the end), 580.71s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157      9          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010      9          0.073605    96.917017
#         3    Stopped     9       0.000095          256           2 0.345021      0.000054      9          0.080086    98.267260
#         4    Stopped     1       0.000166          256           4 0.335667      0.000110      1          0.070219    20.499720
#         5    Stopped     1       0.000345           32           3 0.200602      0.000030      1          0.071883     6.774255
#         6    Stopped     1       0.000093           32           2 0.412990      0.000455      1          0.075629     6.450967
#         7    Stopped     1       0.000015          256           2 0.416877      0.000181      1          0.072945    12.893450
#         8    Stopped     1       0.000021          128           3 0.359365      0.000073      1          0.073350     7.788931
#         9    Stopped     3       0.000297           64           2 0.449523      0.000106      3          0.069405    15.223440
#        10    Stopped     1       0.000408           32           4 0.323552      0.000098      1          0.074908     7.101846
#        11    Stopped     1       0.000238           64           4 0.234370      0.000240      1          0.071247     7.495528
#        12    Stopped     1       0.000081           64           2 0.278206      0.000114      1          0.070725     6.380412
#        13    Stopped     1       0.000019           64           4 0.319215      0.000080      1          0.075388     7.507101
#        14 InProgress     6       0.000062          256           3 0.338262      0.000234      6          0.068083    85.885856
# 1 trials running, 14 finished (1 until the end), 600.74s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.068856    46.668134
#         1    Stopped     9       0.000232          128           4 0.486189      0.000157      9          0.070295    59.097092
#         2    Stopped     9       0.000027          256           2 0.259430      0.000010      9          0.073605    96.917017
#         3    Stopped     9       0.000095          256           2 0.345021      0.000054      9          0.080086    98.267260
#         4    Stopped     1       0.000166          256           4 0.335667      0.000110      1          0.070219    20.499720
#         5    Stopped     1       0.000345           32           3 0.200602      0.000030      1          0.071883     6.774255
#         6    Stopped     1       0.000093           32           2 0.412990      0.000455      1          0.075629     6.450967
#         7    Stopped     1       0.000015          256           2 0.416877      0.000181      1          0.072945    12.893450
#         8    Stopped     1       0.000021          128           3 0.359365      0.000073      1          0.073350     7.788931
#         9    Stopped     3       0.000297           64           2 0.449523      0.000106      3          0.069405    15.223440
#        10    Stopped     1       0.000408           32           4 0.323552      0.000
#        27    Stopped     1       0.000142           32           3 0.266244      0.000073    1.0          0.074956     6.726256
#        28    Stopped     3       0.000219          128           2 0.340291      0.000039    3.0          0.068461    16.646403
#        29    Stopped     3       0.000156          256           2 0.237909      0.000043    3.0          0.073292    33.690567
#        30 InProgress     0       0.000194          128           2 0.209467      0.000012      -                 -            -
# 1 trials running, 30 finished (3 until the end), 1191.81s wallclock-time
#
# validation_error: best 0.06664085388183594 for trial-id 14
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-19-15-15-24-509
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-19-15-15-24-509
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##11. Load Results from Dissolved Oxygen HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
oxygen_results_path = "/root/syne-tune/python-entrypoint-2026-03-19-15-15-24-509/results.csv.zip"

# Save the results to a Pandas DataFrame
oxygen_results = pd.read_csv(oxygen_results_path)

# %% [markdown]
# ##12. Save the Oxygen HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
oxygen_hpo_results_path = Path("/content/REDE_BRIDGE_E_202301_oxygen_hpo_results.csv")

# Save the DataFrame to a csv file
oxygen_results.to_csv(oxygen_hpo_results_path, index=True)

# %% [markdown]
# ## 13. Define the Config Space, Scheduler, and Tune Function for Temperature HPO

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on temperature_t_96 targets
def temperature_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Load the raw data from the project GitHub into a Pandas DataFrame and set index as DateTime
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/river_rede/REDE_BRIDGE_E_202301/REDE_BRIDGE_E_202301_preprocessed_data.zip")
    parameter_path = "/content" / data_path / "REDE_BRIDGE_E_202301_preprocessed_data.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "temperature"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ##14. Initialise and Run the Tuner for Temperature HPO

# %%
# Instruct the searcher to run each trial as a Python function
temperature_trial_backend = PythonBackend(
    tune_function=temperature_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=temperature_trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-19-15-38-33-469
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-19-15-38-33-469
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-19-15-38-33-469
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [15:38:34] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     1        0.00001           64           2      0.2       0.00001      1          0.108841     6.479297
# 1 trials running, 0 finished (0 until the end), 20.02s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     6        0.00001           64           2      0.2       0.00001      6          0.059811    28.686711
# 1 trials running, 0 finished (0 until the end), 40.04s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:39:30] ✅ Trial 0 completed!
# [15:39:30] 🚀 Trial 1 started - config: learning_rate=1.2835104478955747e-05, num_hiddens=128, num_layers=3, dropout=0.4959704506701204, weight_decay=1.8353708855811785e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2  0.20000      0.000010   10.0           0.05949    46.580486
#         1 InProgress     0       0.000013          128           3  0.49597      0.000018      -                 -            -
# 1 trials running, 1 finished (1 until the end), 60.06s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2  0.20000      0.000010     10          0.059490    46.580486
#         1 InProgress     2       0.000013          128           3  0.49597      0.000018      2          0.059271    13.488029
# 1 trials running, 1 finished (1 until the end), 80.08s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2  0.20000      0.000010     10           0.05949    46.580486
#         1 InProgress     5       0.000013          128           3  0.49597      0.000018      5           0.05821    30.233368
# 1 trials running, 1 finished (1 until the end), 100.10s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2  0.20000      0.000010     10          0.059490    46.580486
#         1 InProgress     9       0.000013          128           3  0.49597      0.000018      9          0.057806    53.135257
# 1 trials running, 1 finished (1 until the end), 120.13s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:40:35] ✅ Trial 1 completed!
# [15:40:35] 🚀 Trial 2 started - config: learning_rate=1.5377165692683344e-05, num_hiddens=256, num_layers=2, dropout=0.3736955802540054, weight_decay=1.415946790229146e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018   10.0          0.057606    58.774984
#         2 InProgress     0       0.000015          256           2 0.373696      0.000014      -                 -            -
# 1 trials running, 2 finished (2 until the end), 140.14s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018     10          0.057606    58.774984
#         2 InProgress     2       0.000015          256           2 0.373696      0.000014      2          0.059124    23.872414
# 1 trials running, 2 finished (2 until the end), 160.16s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018     10          0.057606    58.774984
#         2 InProgress     4       0.000015          256           2 0.373696      0.000014      4          0.058534    44.844188
# 1 trials running, 2 finished (2 until the end), 180.17s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018     10          0.057606    58.774984
#         2 InProgress     6       0.000015          256           2 0.373696      0.000014      6          0.058027    65.850366
# 1 trials running, 2 finished (2 until the end), 200.19s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018     10          0.057606    58.774984
#         2 InProgress     8       0.000015          256           2 0.373696      0.000014      8          0.058222    86.693300
# 1 trials running, 2 finished (2 until the end), 220.22s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:42:30] ✅ Trial 2 completed!
# [15:42:30] 🚀 Trial 3 started - config: learning_rate=3.4936615282150234e-05, num_hiddens=64, num_layers=3, dropout=0.4440638487134143, weight_decay=3.327389209413376e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018   10.0          0.057606    58.774984
#         2  Completed    10       0.000015          256           2 0.373696      0.000014   10.0          0.056646   107.774955
#         3 InProgress     0       0.000035           64           3 0.444064      0.000033      -                 -            -
# 1 trials running, 3 finished (3 until the end), 240.24s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018     10          0.057606    58.774984
#         2  Completed    10       0.000015          256           2 0.373696      0.000014     10          0.056646   107.774955
#         3 InProgress     2       0.000035           64           3 0.444064      0.000033      2          0.060816    12.141606
# 1 trials running, 3 finished (3 until the end), 260.26s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:42:55] 🚀 Trial 4 started - config: learning_rate=0.00048206167044015906, num_hiddens=128, num_layers=2, dropout=0.45920584115746454, weight_decay=4.85242076483437e-05
# [15:43:10] 🚀 Trial 5 started - config: learning_rate=2.4427801122456366e-05, num_hiddens=256, num_layers=4, dropout=0.41510775333659733, weight_decay=3.392666965108912e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018   10.0          0.057606    58.774984
#         2  Completed    10       0.000015          256           2 0.373696      0.000014   10.0          0.056646   107.774955
#         3    Stopped     3       0.000035           64           3 0.444064      0.000033    3.0          0.061038    17.139428
#         4    Stopped     1       0.000482          128           2 0.459206      0.000049    1.0          0.060159     6.986760
#         5 InProgress     0       0.000024          256           4 0.415108      0.000034      -                 -            -
# 1 trials running, 5 finished (3 until the end), 280.29s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018   10.0          0.057606    58.774984
#         2  Completed    10       0.000015          256           2 0.373696      0.000014   10.0          0.056646   107.774955
#         3    Stopped     3       0.000035           64           3 0.444064      0.000033    3.0          0.061038    17.139428
#         4    Stopped     1       0.000482          128           2 0.459206      0.000049    1.0          0.060159     6.986760
#         5 InProgress     0       0.000024          256           4 0.415108      0.000034      -                 -            -
# 1 trials running, 5 finished (3 until the end), 300.30s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:43:35] 🚀 Trial 6 started - config: learning_rate=0.0002480724484876448, num_hiddens=64, num_layers=2, dropout=0.20614515868875957, weight_decay=2.8524136664505274e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018     10          0.057606    58.774984
#         2  Completed    10       0.000015          256           2 0.373696      0.000014     10          0.056646   107.774955
#         3    Stopped     3       0.000035           64           3 0.444064      0.000033      3          0.061038    17.139428
#         4    Stopped     1       0.000482          128           2 0.459206      0.000049      1          0.060159     6.986760
#         5    Stopped     1       0.000024          256           4 0.415108      0.000034      1          0.060549    20.796680
#         6 InProgress     1       0.000248           64           2 0.206145      0.000029      1          0.058379     6.410304
# 1 trials running, 6 finished (3 until the end), 320.34s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:43:55] 🚀 Trial 7 started - config: learning_rate=1.5210861902152344e-05, num_hiddens=32, num_layers=2, dropout=0.28596965345689357, weight_decay=1.615991127041215e-05
# [15:44:10] 🚀 Trial 8 started - config: learning_rate=0.00021431303815590096, num_hiddens=32, num_layers=4, dropout=0.4018543604290683, weight_decay=8.323532219081621e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018   10.0          0.057606    58.774984
#         2  Completed    10       0.000015          256           2 0.373696      0.000014   10.0          0.056646   107.774955
#         3    Stopped     3       0.000035           64           3 0.444064      0.000033    3.0          0.061038    17.139428
#         4    Stopped     1       0.000482          128           2 0.459206      0.000049    1.0          0.060159     6.986760
#         5    Stopped     1       0.000024          256           4 0.415108      0.000034    1.0          0.060549    20.796680
#         6    Stopped     3       0.000248           64           2 0.206145      0.000029    3.0          0.060691    15.337182
#         7    Stopped     1       0.000015           32           2 0.285970      0.000016    1.0          0.122057     6.426691
#         8 InProgress     0       0.000214           32           4 0.401854      0.000083      -                 -            -
# 1 trials running, 8 finished (3 until the end), 340.37s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:44:25] 🚀 Trial 9 started - config: learning_rate=0.00013455064656433125, num_hiddens=128, num_layers=2, dropout=0.44469666524985724, weight_decay=3.37973492932023e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018   10.0          0.057606    58.774984
#         2  Completed    10       0.000015          256           2 0.373696      0.000014   10.0          0.056646   107.774955
#         3    Stopped     3       0.000035           64           3 0.444064      0.000033    3.0          0.061038    17.139428
#         4    Stopped     1       0.000482          128           2 0.459206      0.000049    1.0          0.060159     6.986760
#         5    Stopped     1       0.000024          256           4 0.415108      0.000034    1.0          0.060549    20.796680
#         6    Stopped     3       0.000248           64           2 0.206145      0.000029    3.0          0.060691    15.337182
#         7    Stopped     1       0.000015           32           2 0.285970      0.000016    1.0          0.122057     6.426691
#         8    Stopped     1       0.000214           32           4 0.401854      0.000083    1.0          0.062519     7.205456
#         9 InProgress     0       0.000135          128           2 0.444697      0.000034      -                 -            -
# 1 trials running, 9 finished (3 until the end), 360.40s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018     10          0.057606    58.774984
#         2  Completed    10       0.000015          256           2 0.373696      0.000014     10          0.056646   107.774955
#         3    Stopped     3       0.000035           64           3 0.444064      0.000033      3          0.061038    17.139428
#         4    Stopped     1       0.000482          128           2 0.459206      0.000049      1          0.060159     6.986760
#         5    Stopped     1       0.000024          256           4 0.415108      0.000034      1          0.060549    20.796680
#         6    Stopped     3       0.000248           64           2 0.206145      0.000029      3          0.060691    15.337182
#         7    Stopped     1       0.000015           32           2 0.285970      0.000016      1          0.122057     6.426691
#         8    Stopped     1       0.000214           32           4 0.401854      0.000083      1          0.062519     7.205456
#         9 InProgress     3       0.000135          128           2 0.444697      0.000034      3          0.057412    16.852068
# 1 trials running, 9 finished (3 until the end), 380.42s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018     10          0.057606    58.774984
#         2  Completed    10       0.000015          256           2 0.373696      0.000014     10          0.056646   107.774955
#         3    Stopped     3       0.000035           64           3 0.444064      0.000033      3          0.061038    17.139428
#         4    Stopped     1       0.000482          128           2 0.459206      0.000049      1          0.060159     6.986760
#         5    Stopped     1       0.000024          256           4 0.415108      0.000034      1          0.060549    20.796680
#         6    Stopped     3       0.000248           64           2 0.206145      0.000029      3          0.060691    15.337182
#         7    Stopped     1       0.000015           32           2 0.285970      0.000016      1          0.122057     6.426691
#         8    Stopped     1       0.000214           32           4 0.401854      0.000083      1          0.062519     7.205456
#         9 InProgress     7       0.000135          128           2 0.444697      0.000034      7          0.076020    36.446074
# 1 trials running, 9 finished (3 until the end), 400.46s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:45:20] 🚀 Trial 10 started - config: learning_rate=0.0002862329767419602, num_hiddens=256, num_layers=2, dropout=0.4628591240420874, weight_decay=2.9608503520407293e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018   10.0          0.057606    58.774984
#         2  Completed    10       0.000015          256           2 0.373696      0.000014   10.0          0.056646   107.774955
#         3    Stopped     3       0.000035           64           3 0.444064      0.000033    3.0          0.061038    17.139428
#         4    Stopped     1       0.000482          128           2 0.459206      0.000049    1.0          0.060159     6.986760
#         5    Stopped     1       0.000024          256           4 0.415108      0.000034    1.0          0.060549    20.796680
#         6    Stopped     3       0.000248           64           2 0.206145      0.000029    3.0          0.060691    15.337182
#         7    Stopped     1       0.000015           32           2 0.285970      0.000016    1.0          0.122057     6.426691
#         8    Stopped     1       0.000214           32           4 0.401854      0.000083    1.0          0.062519     7.205456
#         9    Stopped     9       0.000135          128           2 0.444697      0.000034    9.0          0.079219    46.336989
#        10 InProgress     0       0.000286          256           2 0.462859      0.000030      -                 -            -
# 1 trials running, 10 finished (3 until the end), 420.47s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018     10          0.057606    58.774984
#         2  Completed    10       0.000015          256           2 0.373696      0.000014     10          0.056646   107.774955
#         3    Stopped     3       0.000035           64           3 0.444064      0.000033      3          0.061038    17.139428
#         4    Stopped     1       0.000482          128           2 0.459206      0.000049      1          0.060159     6.986760
#         5    Stopped     1       0.000024          256           4 0.415108      0.000034      1          0.060549    20.796680
#         6    Stopped     3       0.000248           64           2 0.206145      0.000029      3          0.060691    15.337182
#         7    Stopped     1       0.000015           32           2 0.285970      0.000016      1          0.122057     6.426691
#         8    Stopped     1       0.000214           32           4 0.401854      0.000083      1          0.062519     7.205456
#         9    Stopped     9       0.000135          128           2 0.444697      0.000034      9          0.079219    46.336989
#        10 InProgress     2       0.000286          256           2 0.462859      0.000030      2          0.062306    23.900597
# 1 trials running, 10 finished (3 until the end), 440.50s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:46:00] 🚀 Trial 11 started - config: learning_rate=0.00011712277730660806, num_hiddens=256, num_layers=4, dropout=0.2170528596033564, weight_decay=4.378554085679304e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018   10.0          0.057606    58.774984
#         2  Completed    10       0.000015          256           2 0.373696      0.000014   10.0          0.056646   107.774955
#         3    Stopped     3       0.000035           64           3 0.444064      0.000033    3.0          0.061038    17.139428
#         4    Stopped     1       0.000482          128           2 0.459206      0.000049    1.0          0.060159     6.986760
#         5    Stopped     1       0.000024          256           4 0.415108      0.000034    1.0          0.060549    20.796680
#         6    Stopped     3       0.000248           64           2 0.206145      0.000029    3.0          0.060691    15.337182
#         7    Stopped     1       0.000015           32           2 0.285970      0.000016    1.0          0.122057     6.426691
#         8    Stopped     1       0.000214           32           4 0.401854      0.000083    1.0          0.062519     7.205456
#         9    Stopped     9       0.000135          128           2 0.444697      0.000034    9.0          0.079219    46.336989
#        10    Stopped     3       0.000286          256           2 0.462859      0.000030    3.0          0.059953    34.469408
#        11 InProgress     0       0.000117          256           4 0.217053      0.000044      -                 -            -
# 1 trials running, 11 finished (3 until the end), 460.53s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018     10          0.057606    58.774984
#         2  Completed    10       0.000015          256           2 0.373696      0.000014     10          0.056646   107.774955
#         3    Stopped     3       0.000035           64           3 0.444064      0.000033      3          0.061038    17.139428
#         4    Stopped     1       0.000482          128           2 0.459206      0.000049      1          0.060159     6.986760
#         5    Stopped     1       0.000024          256           4 0.415108      0.000034      1          0.060549    20.796680
#         6    Stopped     3       0.000248           64           2 0.206145      0.000029      3          0.060691    15.337182
#         7    Stopped     1       0.000015           32           2 0.285970      0.000016      1          0.122057     6.426691
#         8    Stopped     1       0.000214           32           4 0.401854      0.000083      1          0.062519     7.205456
#         9    Stopped     9       0.000135          128           2 0.444697      0.000034      9          0.079219    46.336989
#        10    Stopped     3       0.000286          256           2 0.462859      0.000030      3          0.059953    34.469408
#        11 InProgress     1       0.000117          256           4 0.217053      0.000044      1          0.059086    20.467944
# 1 trials running, 11 finished (3 until the end), 480.55s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018     10          0.057606    58.774984
#         2  Completed    10       0.000015          256           2 0.373696      0.000014     10          0.056646   107.774955
#         3    Stopped     3       0.000035           64           3 0.444064      0.000033      3          0.061038    17.139428
#         4    Stopped     1       0.000482          128           2 0.459206      0.000049      1          0.060159     6.986760
#         5    Stopped     1       0.000024          256           4 0.415108      0.000034      1          0.060549    20.796680
#         6    Stopped     3       0.000248           64           2 0.206145      0.000029      3          0.060691    15.337182
#         7    Stopped     1       0.000015           32           2 0.285970      0.000016      1          0.122057     6.426691
#         8    Stopped     1       0.000214           32           4 0.401854      0.000083      1          0.062519     7.205456
#         9    Stopped     9       0.000135          128           2 0.444697      0.000034      9          0.079219    46.336989
#        10    Stopped     3       0.000286          256           2 0.462859      0.000030      3          0.059953    34.469408
#        11 InProgress     2       0.000117          256           4 0.217053      0.000044      2          0.058843    37.870640
# 1 trials running, 11 finished (3 until the end), 500.58s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:47:00] 🚀 Trial 12 started - config: learning_rate=2.9701896310678678e-05, num_hiddens=128, num_layers=3, dropout=0.41148905987739076, weight_decay=2.1132277106103e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018   10.0          0.057606    58.774984
#         2  Completed    10       0.000015          256           2 0.373696      0.000014   10.0          0.056646   107.774955
#         3    Stopped     3       0.000035           64           3 0.444064      0.000033    3.0          0.061038    17.139428
#         4    Stopped     1       0.000482          128           2 0.459206      0.000049    1.0          0.060159     6.986760
#         5    Stopped     1       0.000024          256           4 0.415108      0.000034    1.0          0.060549    20.796680
#         6    Stopped     3       0.000248           64           2 0.206145      0.000029    3.0          0.060691    15.337182
#         7    Stopped     1       0.000015           32           2 0.285970      0.000016    1.0          0.122057     6.426691
#         8    Stopped     1       0.000214           32           4 0.401854      0.000083    1.0          0.062519     7.205456
#         9    Stopped     9       0.000135          128           2 0.444697      0.000034    9.0          0.079219    46.336989
#        10    Stopped     3       0.000286          256           2 0.462859      0.000030    3.0          0.059953    34.469408
#        11    Stopped     3       0.000117          256           4 0.217053      0.000044    3.0          0.059287    55.064545
#        12 InProgress     0       0.000030          128           3 0.411489      0.000021      -                 -            -
# 1 trials running, 12 finished (3 until the end), 520.61s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:47:15] 🚀 Trial 13 started - config: learning_rate=2.335982036071766e-05, num_hiddens=128, num_layers=3, dropout=0.2253461658099971, weight_decay=1.7349700290404915e-05
# [15:47:30] 🚀 Trial 14 started - config: learning_rate=3.628639270611646e-05, num_hiddens=256, num_layers=2, dropout=0.20207828578373965, weight_decay=0.00035529281101109075
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018   10.0          0.057606    58.774984
#         2  Completed    10       0.000015          256           2 0.373696      0.000014   10.0          0.056646   107.774955
#         3    Stopped     3       0.000035           64           3 0.444064      0.000033    3.0          0.061038    17.139428
#         4    Stopped     1       0.000482          128           2 0.459206      0.000049    1.0          0.060159     6.986760
#         5    Stopped     1       0.000024          256           4 0.415108      0.000034    1.0          0.060549    20.796680
#         6    Stopped     3       0.000248           64           2 0.206145      0.000029    3.0          0.060691    15.337182
#         7    Stopped     1       0.000015           32           2 0.285970      0.000016    1.0          0.122057     6.426691
#         8    Stopped     1       0.000214           32           4 0.401854      0.000083    1.0          0.062519     7.205456
#         9    Stopped     9       0.000135          128           2 0.444697      0.000034    9.0          0.079219    46.336989
#        10    Stopped     3       0.000286          256           2 0.462859      0.000030    3.0          0.059953    34.469408
#        11    Stopped     3       0.000117          256           4 0.217053      0.000044    3.0          0.059287    55.064545
#        12    Stopped     1       0.000030          128           3 0.411489      0.000021    1.0          0.059530     7.680494
#        13    Stopped     1       0.000023          128           3 0.225346      0.000017    1.0          0.059970     7.775867
#        14 InProgress     0       0.000036          256           2 0.202078      0.000355      -                 -            -
# 1 trials running, 14 finished (3 until the end), 540.65s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.059490    46.580486
#         1  Completed    10       0.000013          128           3 0.495970      0.000018     10          0.057606    58.774984
#         2  Completed    10       0.000015          256           2 0.373696      0.000
#         8    Stopped     1       0.000214           32           4 0.401854      0.000083    1.0          0.062519     7.205456
#         9    Stopped     9       0.000135          128           2 0.444697      0.000034    9.0          0.079219    46.336989
#        10    Stopped     3       0.000286          256           2 0.462859      0.000030    3.0          0.059953    34.469408
#        11    Stopped     3       0.000117          256           4 0.217053      0.000044    3.0          0.059287    55.064545
#        12    Stopped     1       0.000030          128           3 0.411489      0.000021    1.0          0.059530     7.680494
#        13    Stopped     1       0.000023          128           3 0.225346      0.000017    1.0          0.059970     7.775867
#        14  Completed    10       0.000036          256           2 0.202078      0.000355   10.0          0.057554   108.256711
#        15    Stopped     1       0.000115          128           2 0.285395      0.000058    1.0          0.059703     6.934594
#        16  Completed    10       0.000042          256           2 0.248528      0.000034   10.0          0.057937   107.069904
#        17    Stopped     1       0.000021           64           4 0.296854      0.000124    1.0          0.062701     7.513573
#        18    Stopped     1       0.000275           64           3 0.432621      0.000229    1.0          0.060543     6.931390
#        19    Stopped     3       0.000109           64           2 0.330201      0.000422    3.0          0.059753    15.388976
#        20    Stopped     9       0.000056          256           4 0.466942      0.000069    9.0          0.061263   156.485301
#        21    Stopped     1       0.000034           32           2 0.458246      0.000019    1.0          0.072359     6.372830
#        22    Stopped     3       0.000040          128           3 0.311970      0.000326    3.0          0.059287    18.924847
#        23    Stopped     1       0.000032           64           3 0.326496      0.000284    1.0          0.060484     6.969626
#        24    Stopped     1       0.000031           64           4 0.234304      0.000011    1.0          0.061159     7.566238
#        25    Stopped     1       0.000011          256           2 0.494721      0.000035    1.0          0.061204    13.000612
#        26    Stopped     9       0.000174           32           3 0.382614      0.000106    9.0          0.063307    45.609467
#        27    Stopped     1       0.000013          256           2 0.355526      0.000022    1.0          0.060007    13.375163
#        28    Stopped     1       0.000025          256           3 0.300923      0.000015    1.0          0.062720    16.758852
#        29    Stopped     1       0.000043           64           2 0.214879      0.000187    1.0          0.060428     6.410145
#        30 InProgress     0       0.000031           64           4 0.308895      0.000022      -                 -            -
# 1 trials running, 30 finished (5 until the end), 1196.94s wallclock-time
#
# validation_error: best 0.05659038573503494 for trial-id 16
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-19-15-38-33-469
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-19-15-38-33-469
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##15. Load Results from Temperature HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
temperature_results_path = "/root/syne-tune/python-entrypoint-2026-03-19-15-38-33-469/results.csv.zip"

# Save the results to a Pandas DataFrame
temperature_results = pd.read_csv(temperature_results_path)

# %% [markdown]
# ##16. Save the Temperature HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
temperature_hpo_results_path = Path("/content/REDE_BRIDGE_E_202301_temperature_hpo_results.csv")

# Save the DataFrame to a csv file
temperature_results.to_csv(temperature_hpo_results_path, index=True)
