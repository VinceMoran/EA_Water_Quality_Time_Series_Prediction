# %% [markdown]
# # 0. Station Information
# * Station Name: REDE_FOREST BRIDGE_E_202501
# * Water Quality Data Link: https://environment.data.gov.uk/hydrology/station/E95999A

# %% [markdown]
# ## 0. Import the Relevant Libraries

# %%
# Force installation of Syne-Tune and a compatible NumPy version (may require restarting the session after running this cell before running below import cell)
# !pip install numpy==1.26.1 syne_tune --force-reinstall -q # ignore potential error messages if listed dependencies do not match imports
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 162.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.3/254.3 kB 35.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 168.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 177.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 173.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/131.7 MB 18.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 39.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 37.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 33.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 70.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.6/293.6 MB 8.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.1 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.1 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.1 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.1 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.1 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.1 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# torch 2.10.0+cu128 requires nvidia-nccl-cu12==2.27.5; platform_system == "Linux", but you have nvidia-nccl-cu12 2.29.7 which is incompatible.
# music21 9.9.1 requires numpy>=1.26.4, but you have numpy 1.26.1 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.1 which is incompatible.
# datasets 4.0.0 requires dill<0.3.9,>=0.3.0, but you have dill 0.4.1 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.

# %%
# Import relevant libraries (Note: May require running of above cell to ensure compatibility of NumPy and Syne-Tune)
import torch
import logging
logging.basicConfig(level=logging.INFO)
import numpy as np
import matplotlib.pyplot as plt
from syne_tune import StoppingCriterion, Tuner
from syne_tune.backend.python_backend.python_backend import PythonBackend
from syne_tune.config_space import loguniform, randint, choice, uniform
from syne_tune.experiments import load_experiment
from syne_tune.optimizer.baselines import ASHA
import pandas as pd
from pathlib import Path

# %% [markdown]
# ##1. Specify Epoch Ranges and Reduction Factor for Hyperparameter Optimisation (HPO)

# %%
# Specify the minimum and maximum number of epochs for which a trial is allowed to run during HPO
min_number_of_epochs = 2
max_number_of_epochs = 10

# Define the reduction factor for the Asynchronous Successive Halving Algorithm (ASHA)
eta = 2 # Set to 2 so that 50% of trials are stopped at each rung of the scheduler

# %% [markdown]
# ##2. Define the Tune Function to Optimise Hyperparameters for Ammonium Prediction

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on ammonium_t_96 targets
def ammonium_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Load the raw data from the project GitHub into a Pandas DataFrame and set index as DateTime
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/river_rede/REDE_FOREST_BRIDGE_E_202501/df_parameters_preprocessed.zip")
    parameter_path = "/content" / data_path / "df_parameters_preprocessed.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "ammonium"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ## 3. Define the Configuration Space for Hyperparameter Search

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %% [markdown]
# ##4. Define the Resources Available for HPO

# %%
# Define the number of parallel workers available to evaluate trials concurrently
n_workers = max(1, torch.cuda.device_count()) # Uses all available GPUs for parallel trials or defaults to 1 worker if running on CPU

# Define the maximum number of trials to test
max_number_of_trials = 30

# Define the stopping criterion for HPO
stop_criterion = StoppingCriterion(max_num_trials_started=max_number_of_trials)

# %% [markdown]
# ##5. Define Asynchronous Successive Halving Algorithm (ASHA) for HPO

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %% [markdown]
# ##6. Initialise and Run the Tuner for Ammonium HPO

# %%
# Instruct the searcher to run each trial as a Python function
trial_backend = PythonBackend(
    tune_function=ammonium_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-16-16-12-25-255
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-16-16-12-25-255
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-16-16-12-25-255
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [16:12:27] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
# [16:12:42] 🚀 Trial 1 started - config: learning_rate=4.7204917923738224e-05, num_hiddens=32, num_layers=3, dropout=0.46202550095257217, weight_decay=1.007458541020175e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000       0.00001   10.0          0.068932     9.145621
#         1 InProgress     0       0.000047           32           3 0.462026       0.00001      -                 -            -
# 1 trials running, 1 finished (0 until the end), 20.12s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:12:47] 🚀 Trial 2 started - config: learning_rate=0.00014350632076078515, num_hiddens=64, num_layers=2, dropout=0.3731717240915643, weight_decay=9.643420654875594e-05
# [16:12:57] ✅ Trial 2 completed!
# [16:12:57] 🚀 Trial 3 started - config: learning_rate=0.00040903294861702893, num_hiddens=128, num_layers=3, dropout=0.345703158378319, weight_decay=1.2009240590867351e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.068932     9.145621
#         1    Stopped     4       0.000047           32           3 0.462026      0.000010      4          0.071412     3.003112
#         2  Completed    10       0.000144           64           2 0.373172      0.000096     10          0.049409     6.030151
#         3 InProgress     2       0.000409          128           3 0.345703      0.000012      2          0.062012     2.577869
# 1 trials running, 3 finished (1 until the end), 40.14s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:13:12] ✅ Trial 3 completed!
# [16:13:12] 🚀 Trial 4 started - config: learning_rate=2.1064105271996883e-05, num_hiddens=256, num_layers=4, dropout=0.3480967540482244, weight_decay=8.199332803687896e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.068932     9.145621
#         1    Stopped     4       0.000047           32           3 0.462026      0.000010      4          0.071412     3.003112
#         2  Completed    10       0.000144           64           2 0.373172      0.000096     10          0.049409     6.030151
#         3  Completed    10       0.000409          128           3 0.345703      0.000012     10          0.049635     9.426357
#         4 InProgress     2       0.000021          256           4 0.348097      0.000082      2          0.060876     6.037538
# 1 trials running, 4 finished (2 until the end), 60.15s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:13:42] ✅ Trial 4 completed!
# [16:13:42] 🚀 Trial 5 started - config: learning_rate=1.0679796284499593e-05, num_hiddens=256, num_layers=3, dropout=0.3137633858809984, weight_decay=0.0003202955043480575
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.068932     9.145621
#         1    Stopped     4       0.000047           32           3 0.462026      0.000010    4.0          0.071412     3.003112
#         2  Completed    10       0.000144           64           2 0.373172      0.000096   10.0          0.049409     6.030151
#         3  Completed    10       0.000409          128           3 0.345703      0.000012   10.0          0.049635     9.426357
#         4  Completed    10       0.000021          256           4 0.348097      0.000082   10.0          0.077346    26.175535
#         5 InProgress     0       0.000011          256           3 0.313763      0.000320      -                 -            -
# 1 trials running, 5 finished (3 until the end), 80.16s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:13:47] 🚀 Trial 6 started - config: learning_rate=0.00011248072504674067, num_hiddens=256, num_layers=2, dropout=0.331330702140563, weight_decay=1.3828373846434265e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.068932     9.145621
#         1    Stopped     4       0.000047           32           3 0.462026      0.000010      4          0.071412     3.003112
#         2  Completed    10       0.000144           64           2 0.373172      0.000096     10          0.049409     6.030151
#         3  Completed    10       0.000409          128           3 0.345703      0.000012     10          0.049635     9.426357
#         4  Completed    10       0.000021          256           4 0.348097      0.000082     10          0.077346    26.175535
#         5    Stopped     1       0.000011          256           3 0.313763      0.000320      1          0.120235     2.929296
#         6 InProgress     8       0.000112          256           2 0.331331      0.000014      8          0.043182    12.648299
# 1 trials running, 6 finished (3 until the end), 100.18s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:14:07] ✅ Trial 6 completed!
# [16:14:07] 🚀 Trial 7 started - config: learning_rate=6.460293731613849e-05, num_hiddens=256, num_layers=3, dropout=0.4022159875604524, weight_decay=0.00025982266045215905
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.068932     9.145621
#         1    Stopped     4       0.000047           32           3 0.462026      0.000010      4          0.071412     3.003112
#         2  Completed    10       0.000144           64           2 0.373172      0.000096     10          0.049409     6.030151
#         3  Completed    10       0.000409          128           3 0.345703      0.000012     10          0.049635     9.426357
#         4  Completed    10       0.000021          256           4 0.348097      0.000082     10          0.077346    26.175535
#         5    Stopped     1       0.000011          256           3 0.313763      0.000320      1          0.120235     2.929296
#         6  Completed    10       0.000112          256           2 0.331331      0.000014     10          0.045159    15.602677
#         7 InProgress     6       0.000065          256           3 0.402216      0.000260      6          0.072954    12.880416
# 1 trials running, 7 finished (4 until the end), 120.19s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:14:32] ✅ Trial 7 completed!
# [16:14:32] 🚀 Trial 8 started - config: learning_rate=0.00010215734488100585, num_hiddens=256, num_layers=4, dropout=0.4595854305247095, weight_decay=0.00014124743566125975
# [16:14:42] 🚀 Trial 9 started - config: learning_rate=0.00012290806562788648, num_hiddens=256, num_layers=3, dropout=0.2026426930777797, weight_decay=2.7320698467523737e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.068932     9.145621
#         1    Stopped     4       0.000047           32           3 0.462026      0.000010    4.0          0.071412     3.003112
#         2  Completed    10       0.000144           64           2 0.373172      0.000096   10.0          0.049409     6.030151
#         3  Completed    10       0.000409          128           3 0.345703      0.000012   10.0          0.049635     9.426357
#         4  Completed    10       0.000021          256           4 0.348097      0.000082   10.0          0.077346    26.175535
#         5    Stopped     1       0.000011          256           3 0.313763      0.000320    1.0          0.120235     2.929296
#         6  Completed    10       0.000112          256           2 0.331331      0.000014   10.0          0.045159    15.602677
#         7  Completed    10       0.000065          256           3 0.402216      0.000260   10.0          0.075811    20.893214
#         8    Stopped     2       0.000102          256           4 0.459585      0.000141    2.0          0.067955     5.945327
#         9 InProgress     0       0.000123          256           3 0.202643      0.000027      -                 -            -
# 1 trials running, 9 finished (5 until the end), 140.21s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:14:52] 🚀 Trial 10 started - config: learning_rate=2.0904015810701373e-05, num_hiddens=32, num_layers=4, dropout=0.3708084142193665, weight_decay=1.265628316956609e-05
# [16:14:57] 🚀 Trial 11 started - config: learning_rate=0.00016158362636604454, num_hiddens=32, num_layers=3, dropout=0.48847006942591004, weight_decay=6.196927448621176e-05
# [16:15:02] 🚀 Trial 12 started - config: learning_rate=1.3849425800455173e-05, num_hiddens=256, num_layers=2, dropout=0.4293624297547856, weight_decay=1.0251500065595317e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.068932     9.145621
#         1    Stopped     4       0.000047           32           3 0.462026      0.000010    4.0          0.071412     3.003112
#         2  Completed    10       0.000144           64           2 0.373172      0.000096   10.0          0.049409     6.030151
#         3  Completed    10       0.000409          128           3 0.345703      0.000012   10.0          0.049635     9.426357
#         4  Completed    10       0.000021          256           4 0.348097      0.000082   10.0          0.077346    26.175535
#         5    Stopped     1       0.000011          256           3 0.313763      0.000320    1.0          0.120235     2.929296
#         6  Completed    10       0.000112          256           2 0.331331      0.000014   10.0          0.045159    15.602677
#         7  Completed    10       0.000065          256           3 0.402216      0.000260   10.0          0.075811    20.893214
#         8    Stopped     2       0.000102          256           4 0.459585      0.000141    2.0          0.067955     5.945327
#         9    Stopped     3       0.000123          256           3 0.202643      0.000027    3.0          0.064966     6.885019
#        10    Stopped     3       0.000021           32           4 0.370808      0.000013    3.0          0.107272     2.600996
#        11    Stopped     4       0.000162           32           3 0.488470      0.000062    4.0          0.074563     3.019569
#        12 InProgress     0       0.000014          256           2 0.429362      0.000010      -                 -            -
# 1 trials running, 12 finished (5 until the end), 160.23s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:15:07] 🚀 Trial 13 started - config: learning_rate=0.0001292898151445842, num_hiddens=32, num_layers=4, dropout=0.25615797556360276, weight_decay=2.957844203653409e-05
# [16:15:12] 🚀 Trial 14 started - config: learning_rate=1.6017464249484e-05, num_hiddens=128, num_layers=3, dropout=0.3478061830646252, weight_decay=3.52878803358574e-05
# [16:15:17] 🚀 Trial 15 started - config: learning_rate=6.788654746633257e-05, num_hiddens=32, num_layers=4, dropout=0.40505633828914345, weight_decay=0.0004774465869887091
# [16:15:22] 🚀 Trial 16 started - config: learning_rate=1.470438447415209e-05, num_hiddens=128, num_layers=2, dropout=0.4349672567697235, weight_decay=0.00015730464774665873
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.068932     9.145621
#         1    Stopped     4       0.000047           32           3 0.462026      0.000010    4.0          0.071412     3.003112
#         2  Completed    10       0.000144           64           2 0.373172      0.000096   10.0          0.049409     6.030151
#         3  Completed    10       0.000409          128           3 0.345703      0.000012   10.0          0.049635     9.426357
#         4  Completed    10       0.000021          256           4 0.348097      0.000082   10.0          0.077346    26.175535
#         5    Stopped     1       0.000011          256           3 0.313763      0.000320    1.0          0.120235     2.929296
#         6  Completed    10       0.000112          256           2 0.331331      0.000014   10.0          0.045159    15.602677
#         7  Completed    10       0.000065          256           3 0.402216      0.000260   10.0          0.075811    20.893214
#         8    Stopped     2       0.000102          256           4 0.459585      0.000141    2.0          0.067955     5.945327
#         9    Stopped     3       0.000123          256           3 0.202643      0.000027    3.0          0.064966     6.885019
#        10    Stopped     3       0.000021           32           4 0.370808      0.000013    3.0          0.107272     2.600996
#        11    Stopped     4       0.000162           32           3 0.488470      0.000062    4.0          0.074563     3.019569
#        12    Stopped     1       0.000014          256           2 0.429362      0.000010    1.0          0.081093     2.378038
#        13    Stopped     3       0.000129           32           4 0.256158      0.000030    3.0          0.085089     2.639677
#        14    Stopped     2       0.000016          128           3 0.347806      0.000035    2.0          0.050903     2.613838
#        15    Stopped     3       0.000068           32           4 0.405056      0.000477    3.0          0.091609     2.594123
#        16 InProgress     0       0.000015          128           2 0.434967      0.000157      -                 -            -
# 1 trials running, 16 finished (5 until the end), 180.24s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:15:27] 🚀 Trial 17 started - config: learning_rate=0.00018881966714916505, num_hiddens=128, num_layers=4, dropout=0.29261574664163303, weight_decay=0.00016521212316328236
# [16:15:37] 🚀 Trial 18 started - config: learning_rate=0.00013073284436507953, num_hiddens=256, num_layers=4, dropout=0.35912732674938563, weight_decay=2.5011457439868175e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.068932     9.145621
#         1    Stopped     4       0.000047           32           3 0.462026      0.000010    4.0          0.071412     3.003112
#         2  Completed    10       0.000144           64           2 0.373172      0.000
#        17    Stopped     6       0.000189          128           4 0.292616      0.000165    6.0          0.081579     7.103209
#        18    Stopped     2       0.000131          256           4 0.359127      0.000025    2.0          0.066521     5.995472
#        19    Stopped     3       0.000431           64           4 0.495908      0.000449    3.0          0.095365     2.758219
#        20    Stopped     4       0.000479          256           2 0.482195      0.000208    4.0          0.084752     6.785765
#        21 InProgress     0       0.000010          128           3 0.386278      0.000124      -                 -            -
# 1 trials running, 21 finished (5 until the end), 220.29s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:16:07] 🚀 Trial 22 started - config: learning_rate=0.00012893855189585816, num_hiddens=256, num_layers=2, dropout=0.4379050159158536, weight_decay=0.00011938231320993022
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.068932     9.145621
#         1    Stopped     4       0.000047           32           3 0.462026      0.000010      4          0.071412     3.003112
#         2  Completed    10       0.000144           64           2 0.373172      0.000096     10          0.049409     6.030151
#         3  Completed    10       0.000409          128           3 0.345703      0.000012     10          0.049635     9.426357
#         4  Completed    10       0.000021          256           4 0.348097      0.000082     10          0.077346    26.175535
#         5    Stopped     1       0.000011          256           3 0.313763      0.000320      1          0.120235     2.929296
#         6  Completed    10       0.000112          256           2 0.331331      0.000014     10          0.045159    15.602677
#         7  Completed    10       0.000065          256           3 0.402216      0.000260     10          0.075811    20.893214
#         8    Stopped     2       0.000102          256           4 0.459585      0.000141      2          0.067955     5.945327
#         9    Stopped     3       0.000123          256           3 0.202643      0.000027      3          0.064966     6.885019
#        10    Stopped     3       0.000021           32           4 0.370808      0.000013      3          0.107272     2.600996
#        11    Stopped     4       0.000162           32           3 0.488470      0.000062      4          0.074563     3.019569
#        12    Stopped     1       0.000014          256           2 0.429362      0.000010      1          0.081093     2.378038
#        13    Stopped     3       0.000129           32           4 0.256158      0.000030      3          0.085089     2.639677
#        14    Stopped     2       0.000016          128           3 0.347806      0.000035      2          0.050903     2.613838
#        15    Stopped     3       0.000068           32           4 0.405056      0.000477      3          0.091609     2.594123
#        16    Stopped     3       0.000015          128           2 0.434967      0.000157      3          0.043716     2.890483
#        17    Stopped     6       0.000189          128           4 0.292616      0.000165      6          0.081579     7.103209
#        18    Stopped     2       0.000131          256           4 0.359127      0.000025      2          0.066521     5.995472
#        19    Stopped     3       0.000431           64           4 0.495908      0.000449      3          0.095365     2.758219
#        20    Stopped     4       0.000479          256           2 0.482195      0.000208      4          0.084752     6.785765
#        21    Stopped     2       0.000010          128           3 0.386278      0.000124      2          0.096233     2.569970
#        22 InProgress     8       0.000129          256           2 0.437905      0.000119      8          0.052843    12.698990
# 1 trials running, 22 finished (5 until the end), 240.31s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:16:27] ✅ Trial 22 completed!
# [16:16:27] 🚀 Trial 23 started - config: learning_rate=0.0004051918065763305, num_hiddens=32, num_layers=3, dropout=0.4842580013616308, weight_decay=3.259271946751702e-05
# [16:16:32] 🚀 Trial 24 started - config: learning_rate=1.9797437717971905e-05, num_hiddens=128, num_layers=4, dropout=0.2348577315575753, weight_decay=7.050042392774655e-05
# [16:16:37] 🚀 Trial 25 started - config: learning_rate=0.00013541468213124492, num_hiddens=32, num_layers=2, dropout=0.2259874788514407, weight_decay=1.6486740695586687e-05
# [16:16:42] 🚀 Trial 26 started - config: learning_rate=1.6160605245041285e-05, num_hiddens=64, num_layers=2, dropout=0.48323328660706616, weight_decay=2.350155997176002e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.068932     9.145621
#         1    Stopped     4       0.000047           32           3 0.462026      0.000
#         9    Stopped     3       0.000123          256           3 0.202643      0.000027    3.0          0.064966     6.885019
#        10    Stopped     3       0.000021           32           4 0.370808      0.000013    3.0          0.107272     2.600996
#        11    Stopped     4       0.000162           32           3 0.488470      0.000062    4.0          0.074563     3.019569
#        12    Stopped     1       0.000014          256           2 0.429362      0.000010    1.0          0.081093     2.378038
#        13    Stopped     3       0.000129           32           4 0.256158      0.000030    3.0          0.085089     2.639677
#        14    Stopped     2       0.000016          128           3 0.347806      0.000035    2.0          0.050903     2.613838
#        15    Stopped     3       0.000068           32           4 0.405056      0.000477    3.0          0.091609     2.594123
#        16    Stopped     3       0.000015          128           2 0.434967      0.000157    3.0          0.043716     2.890483
#        17    Stopped     6       0.000189          128           4 0.292616      0.000165    6.0          0.081579     7.103209
#        18    Stopped     2       0.000131          256           4 0.359127      0.000025    2.0          0.066521     5.995472
#        19    Stopped     3       0.000431           64           4 0.495908      0.000449    3.0          0.095365     2.758219
#        20    Stopped     4       0.000479          256           2 0.482195      0.000208    4.0          0.084752     6.785765
#        21    Stopped     2       0.000010          128           3 0.386278      0.000124    2.0          0.096233     2.569970
#        22  Completed    10       0.000129          256           2 0.437905      0.000119   10.0          0.054916    15.781658
#        23    Stopped     3       0.000405           32           3 0.484258      0.000033    3.0          0.058275     2.450452
#        24    Stopped     2       0.000020          128           4 0.234858      0.000071    2.0          0.062857     2.981461
#        25    Stopped     4       0.000135           32           2 0.225987      0.000016    4.0          0.056244     2.805901
#        26    Stopped     4       0.000016           64           2 0.483233      0.000024    4.0          0.057893     2.904725
#        27    Stopped     3       0.000014           64           3 0.467229      0.000039    3.0          0.076890     2.539817
#        28    Stopped     6       0.000032          128           4 0.221114      0.000144    6.0          0.078820     7.101643
#        29    Stopped     3       0.000027           64           4 0.399226      0.000314    3.0          0.074534     2.810469
#        30 InProgress     0       0.000012           64           4 0.260131      0.000028      -                 -            -
# 1 trials running, 30 finished (6 until the end), 280.36s wallclock-time
#
# validation_error: best 0.03943450376391411 for trial-id 6
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-16-16-12-25-255
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-16-16-12-25-255
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##7. Load Results from HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
ammonium_results_path = "/root/syne-tune/python-entrypoint-2026-03-16-16-12-25-255/results.csv.zip"

# Save the results to a Pandas DataFrame
ammonium_results = pd.read_csv(ammonium_results_path)

# %% [markdown]
# ##8. Save the Ammonium HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
ammonium_hpo_results_path = Path("/content/REDE_FOREST BRIDGE_E_202501_ammonium_HPO_results.csv")

# Save the DataFrame to a csv file
ammonium_results.to_csv(ammonium_hpo_results_path, index=True)

# %% [markdown]
# ## 9. Define the Config Space, Scheduler, and Tune Function for Dissolved Oxygen HPO

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on ammonium_t_96 targets
def oxygen_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Load the raw data from the project GitHub into a Pandas DataFrame and set index as DateTime
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/river_rede/REDE_FOREST_BRIDGE_E_202501/df_parameters_preprocessed.zip")
    parameter_path = "/content" / data_path / "df_parameters_preprocessed.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "oxygen_conc"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ##10. Initialise and Run the Tuner for Oxygen HPO

# %%
# Instruct the searcher to run each trial as a Python function
oxygen_trial_backend = PythonBackend(
    tune_function=oxygen_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=oxygen_trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-16-16-19-17-207
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-16-16-19-17-207
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-16-16-19-17-207
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [16:19:17] 🚀 Trial 0 started - config: learning_rate=1.2670928775961124e-05, num_hiddens=256, num_layers=2, dropout=0.2982274685457266, weight_decay=4.317179935686328e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     8       0.000013          256           2 0.298227      0.000043      8          0.080221    12.570454
# 1 trials running, 0 finished (0 until the end), 20.01s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:19:37] ✅ Trial 0 completed!
# [16:19:37] 🚀 Trial 1 started - config: learning_rate=1.0809274017217678e-05, num_hiddens=64, num_layers=4, dropout=0.362524162850826, weight_decay=0.00025407081995777985
# [16:19:42] 🚀 Trial 2 started - config: learning_rate=4.42880881001078e-05, num_hiddens=128, num_layers=2, dropout=0.45668982197189556, weight_decay=3.848353634945693e-05
# [16:19:52] 🚀 Trial 3 started - config: learning_rate=0.0004600796141165948, num_hiddens=256, num_layers=2, dropout=0.333371730741607, weight_decay=2.0644422541394314e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000013          256           2 0.298227      0.000043   10.0          0.076972    15.544447
#         1    Stopped     3       0.000011           64           4 0.362524      0.000254    3.0          0.106536     2.837695
#         2    Stopped    10       0.000044          128           2 0.456690      0.000038   10.0          0.066840     7.594119
#         3 InProgress     0       0.000460          256           2 0.333372      0.000021      -                 -            -
# 1 trials running, 3 finished (1 until the end), 40.02s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:20:12] ✅ Trial 3 completed!
# [16:20:12] 🚀 Trial 4 started - config: learning_rate=0.0001520682052945141, num_hiddens=64, num_layers=4, dropout=0.47566183462475825, weight_decay=0.00029057897941003516
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000013          256           2 0.298227      0.000043   10.0          0.076972    15.544447
#         1    Stopped     3       0.000011           64           4 0.362524      0.000254    3.0          0.106536     2.837695
#         2    Stopped    10       0.000044          128           2 0.456690      0.000038   10.0          0.066840     7.594119
#         3  Completed    10       0.000460          256           2 0.333372      0.000021   10.0          0.061247    15.630653
#         4 InProgress     0       0.000152           64           4 0.475662      0.000291      -                 -            -
# 1 trials running, 4 finished (2 until the end), 60.04s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:20:22] ✅ Trial 4 completed!
# [16:20:22] 🚀 Trial 5 started - config: learning_rate=1.200215885505398e-05, num_hiddens=256, num_layers=4, dropout=0.2656239453497879, weight_decay=0.00020493076164918302
# [16:20:32] 🚀 Trial 6 started - config: learning_rate=2.956343521070483e-05, num_hiddens=32, num_layers=3, dropout=0.4338115550670026, weight_decay=6.952105722853521e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000013          256           2 0.298227      0.000043   10.0          0.076972    15.544447
#         1    Stopped     3       0.000011           64           4 0.362524      0.000254    3.0          0.106536     2.837695
#         2    Stopped    10       0.000044          128           2 0.456690      0.000038   10.0          0.066840     7.594119
#         3  Completed    10       0.000460          256           2 0.333372      0.000021   10.0          0.061247    15.630653
#         4  Completed    10       0.000152           64           4 0.475662      0.000291   10.0          0.065905     7.261841
#         5    Stopped     2       0.000012          256           4 0.265624      0.000205    2.0          0.069123     5.927187
#         6 InProgress     0       0.000030           32           3 0.433812      0.000070      -                 -            -
# 1 trials running, 6 finished (3 until the end), 80.06s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:20:37] 🚀 Trial 7 started - config: learning_rate=0.0002287987434634543, num_hiddens=256, num_layers=2, dropout=0.3592185965560409, weight_decay=0.00010336969448209461
# [16:20:47] 🚀 Trial 8 started - config: learning_rate=6.092872060126122e-05, num_hiddens=256, num_layers=2, dropout=0.31974807248537335, weight_decay=0.0004147430166216626
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000013          256           2 0.298227      0.000043     10          0.076972    15.544447
#         1    Stopped     3       0.000011           64           4 0.362524      0.000254      3          0.106536     2.837695
#         2    Stopped    10       0.000044          128           2 0.456690      0.000038     10          0.066840     7.594119
#         3  Completed    10       0.000460          256           2 0.333372      0.000021     10          0.061247    15.630653
#         4  Completed    10       0.000152           64           4 0.475662      0.000291     10          0.065905     7.261841
#         5    Stopped     2       0.000012          256           4 0.265624      0.000205      2          0.069123     5.927187
#         6    Stopped     4       0.000030           32           3 0.433812      0.000070      4          0.087877     2.996447
#         7    Stopped     4       0.000229          256           2 0.359219      0.000103      4          0.064948     6.820114
#         8 InProgress     1       0.000061          256           2 0.319748      0.000415      1          0.080693     2.382092
# 1 trials running, 8 finished (3 until the end), 100.07s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:20:57] 🚀 Trial 9 started - config: learning_rate=0.0001625338735612741, num_hiddens=64, num_layers=3, dropout=0.3651705883062989, weight_decay=0.00023513223933267267
# [16:21:07] ✅ Trial 9 completed!
# [16:21:07] 🚀 Trial 10 started - config: learning_rate=8.28402432748589e-05, num_hiddens=64, num_layers=3, dropout=0.24265738991284314, weight_decay=7.94694174487426e-05
# [16:21:12] 🚀 Trial 11 started - config: learning_rate=0.00031510957428893633, num_hiddens=256, num_layers=2, dropout=0.24495273856699554, weight_decay=1.2313748398587193e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000013          256           2 0.298227      0.000043   10.0          0.076972    15.544447
#         1    Stopped     3       0.000011           64           4 0.362524      0.000254    3.0          0.106536     2.837695
#         2    Stopped    10       0.000044          128           2 0.456690      0.000038   10.0          0.066840     7.594119
#         3  Completed    10       0.000460          256           2 0.333372      0.000021   10.0          0.061247    15.630653
#         4  Completed    10       0.000152           64           4 0.475662      0.000291   10.0          0.065905     7.261841
#         5    Stopped     2       0.000012          256           4 0.265624      0.000205    2.0          0.069123     5.927187
#         6    Stopped     4       0.000030           32           3 0.433812      0.000070    4.0          0.087877     2.996447
#         7    Stopped     4       0.000229          256           2 0.359219      0.000103    4.0          0.064948     6.820114
#         8    Stopped     4       0.000061          256           2 0.319748      0.000415    4.0          0.069697     6.800771
#         9  Completed    10       0.000163           64           3 0.365171      0.000235   10.0          0.067240     6.669496
#        10    Stopped     3       0.000083           64           3 0.242657      0.000079    3.0          0.068475     2.593571
#        11 InProgress     0       0.000315          256           2 0.244953      0.000012      -                 -            -
# 1 trials running, 11 finished (4 until the end), 120.09s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16
wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:22:57] 🚀 Trial 22 started - config: learning_rate=7.200160186558634e-05, num_hiddens=128, num_layers=4, dropout=0.3196933556004189, weight_decay=0.0003133100443570021
# [16:23:12] ✅ Trial 22 completed!
# [16:23:12] 🚀 Trial 23 started - config: learning_rate=1.015670015928721e-05, num_hiddens=32, num_layers=2, dropout=0.3010667255911256, weight_decay=0.00047231699405256576
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000013          256           2 0.298227      0.000043   10.0          0.076972    15.544447
#         1    Stopped     3       0.000011           64           4 0.362524      0.000254    3.0          0.106536     2.837695
#         2    Stopped    10       0.000044          128           2 0.456690      0.000038   10.0          0.066840     7.594119
#         3  Completed    10       0.000460          256           2 0.333372      0.000021   10.0          0.061247    15.630653
#         4  Completed    10       0.000152           64           4 0.475662      0.000291   10.0          0.065905     7.261841
#         5    Stopped     2       0.000012          256           4 0.265624      0.000205    2.0          0.069123     5.927187
#         6    Stopped     4       0.000030           32           3 0.433812      0.000070    4.0          0.087877     2.996447
#         7    Stopped     4       0.000229          256           2 0.359219      0.000103    4.0          0.064948     6.820114
#         8    Stopped     4       0.000061          256           2 0.319748      0.000415    4.0          0.069697     6.800771
#         9  Completed    10       0.000163           64           3 0.365171      0.000235   10.0          0.067240     6.669496
#        10    Stopped     3       0.000083           64           3 0.242657      0.000079    3.0          0.068475     2.593571
#        11  Completed    10       0.000315          256           2 0.244953      0.000012   10.0          0.060370    15.649268
#        12    Stopped     2       0.000074          128           3 0.373876      0.000041    2.0          0.069818     2.575913
#        13    Stopped     3       0.000041           64           4 0.471255      0.000201    3.0          0.068474     2.752372
#        14    Stopped     3       0.000042           32           4 0.433485      0.000073    3.0          0.080242     2.650027
#        15    Stopped     4       0.000077           32           2 0.309502      0.000017    4.0          0.085233     2.787326
#        16  Completed    10       0.000205           64           4 0.474015      0.000057   10.0          0.068721     7.233078
#        17    Stopped     4       0.000165           64           2 0.354169      0.000023    4.0          0.067997     2.867051
#        18    Stopped     2       0.000029          128           4 0.391918      0.000055    2.0          0.071564     2.962281
#        19  Completed    10       0.000039          256           4 0.495933      0.000023   10.0          0.075917    26.143398
#        20    Stopped     3       0.000040           64           3 0.485805      0.000022    3.0          0.076979     2.565025
#        21    Stopped    10       0.000376          128           2 0.241514      0.000121   10.0          0.062040     7.673489
#        22  Completed    10       0.000072          128           4 0.319693      0.000313   10.0          0.069179    11.331693
#        23 InProgress     0       0.000010           32           2 0.301067      0.000472      -                 -            -
# 1 trials running, 23 finished (8 until the end), 240.21s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:23:17] 🚀 Trial 24 started - config: learning_rate=0.00015293481450360353, num_hiddens=128, num_layers=3, dropout=0.20515622563608946, weight_decay=0.00016123743167871426
# [16:23:22] 🚀 Trial 25 started - config: learning_rate=1.2798677985130043e-05, num_hiddens=128, num_layers=4, dropout=0.23711178255445475, weight_decay=2.5577487784613116e-05
# [16:23:27] 🚀 Trial 26 started - config: learning_rate=1.70694635008984e-05, num_hiddens=256, num_layers=2, dropout=0.4610119182083824, weight_decay=0.00025654094352893557
# [16:23:32] 🚀 Trial 27 started - config: learning_rate=0.00013726434489341218, num_hiddens=64, num_layers=3, dropout=0.287674169599842, weight_decay=0.000164202809432323
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000013          256           2 0.298227      0.000043   10.0          0.076972    15.544447
#         1    Stopped     3       0.000011           64           4 0.362524      0.000254    3.0          0.106536     2.837695
#         2    Stopped    10       0.000044          128           2 0.456690      0.000
#        13    Stopped     3       0.000041           64           4 0.471255      0.000201    3.0          0.068474     2.752372
#        14    Stopped     3       0.000042           32           4 0.433485      0.000073    3.0          0.080242     2.650027
#        15    Stopped     4       0.000077           32           2 0.309502      0.000017    4.0          0.085233     2.787326
#        16  Completed    10       0.000205           64           4 0.474015      0.000057   10.0          0.068721     7.233078
#        17    Stopped     4       0.000165           64           2 0.354169      0.000023    4.0          0.067997     2.867051
#        18    Stopped     2       0.000029          128           4 0.391918      0.000055    2.0          0.071564     2.962281
#        19  Completed    10       0.000039          256           4 0.495933      0.000023   10.0          0.075917    26.143398
#        20    Stopped     3       0.000040           64           3 0.485805      0.000022    3.0          0.076979     2.565025
#        21    Stopped    10       0.000376          128           2 0.241514      0.000121   10.0          0.062040     7.673489
#        22  Completed    10       0.000072          128           4 0.319693      0.000313   10.0          0.069179    11.331693
#        23    Stopped     4       0.000010           32           2 0.301067      0.000472    4.0          0.157472     2.840285
#        24    Stopped     2       0.000153          128           3 0.205156      0.000161    2.0          0.067107     2.577837
#        25    Stopped     2       0.000013          128           4 0.237112      0.000026    2.0          0.122919     2.976372
#        26    Stopped     1       0.000017          256           2 0.461012      0.000257    1.0          0.120237     2.404122
#        27  Completed    10       0.000137           64           3 0.287674      0.000164   10.0          0.063045     6.616479
#        28    Stopped     1       0.000034          256           2 0.228705      0.000029    1.0          0.093785     2.347620
#        29    Stopped     4       0.000179          256           2 0.210311      0.000247    4.0          0.066167     6.816276
#        30 InProgress     0       0.000265           32           2 0.201321      0.000087      -                 -            -
# 1 trials running, 30 finished (9 until the end), 280.27s wallclock-time
#
# validation_error: best 0.05627153813838959 for trial-id 21
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-16-16-19-17-207
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-16-16-19-17-207
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##11. Load Results from Dissolved Oxygen HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
oxygen_results_path = "/root/syne-tune/python-entrypoint-2026-03-16-16-19-17-207/results.csv.zip"

# Save the results to a Pandas DataFrame
oxygen_results = pd.read_csv(oxygen_results_path)

# %% [markdown]
# ##12. Save the Oxygen HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
oxygen_hpo_results_path = Path("/content/REDE_FOREST BRIDGE_E_202501_oxygen_HPO_results.csv")

# Save the DataFrame to a csv file
oxygen_results.to_csv(oxygen_hpo_results_path, index=True)

# %% [markdown]
# ## 13. Define the Config Space, Scheduler, and Tune Function for Temperature HPO

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on temperature_t_96 targets
def temperature_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Load the raw data from the project GitHub into a Pandas DataFrame and set index as DateTime
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/river_rede/REDE_FOREST_BRIDGE_E_202501/df_parameters_preprocessed.zip")
    parameter_path = "/content" / data_path / "df_parameters_preprocessed.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "temperature"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ##14. Initialise and Run the Tuner for Temperature HPO

# %%
# Instruct the searcher to run each trial as a Python function
temperature_trial_backend = PythonBackend(
    tune_function=temperature_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=temperature_trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-16-16-24-58-325
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-16-16-24-58-325
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-16-16-24-58-325
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [16:24:59] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
# [16:25:09] ✅ Trial 0 completed!
# [16:25:09] 🚀 Trial 1 started - config: learning_rate=9.678282202486262e-05, num_hiddens=64, num_layers=4, dropout=0.28009585333226095, weight_decay=0.00022901607537757863
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.060241     6.064122
#         1 InProgress     3       0.000097           64           4 0.280096      0.000229      3          0.066292     2.804450
# 1 trials running, 1 finished (1 until the end), 20.01s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:25:19] 🚀 Trial 2 started - config: learning_rate=4.878530932988702e-05, num_hiddens=128, num_layers=3, dropout=0.31974727566219435, weight_decay=0.00022221139161112438
# [16:25:34] ✅ Trial 2 completed!
# [16:25:34] 🚀 Trial 3 started - config: learning_rate=0.00020734245584577802, num_hiddens=64, num_layers=2, dropout=0.2873397212866114, weight_decay=1.2697205792138109e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.060241     6.064122
#         1    Stopped    10       0.000097           64           4 0.280096      0.000229   10.0          0.095342     7.375544
#         2  Completed    10       0.000049          128           3 0.319747      0.000222   10.0          0.076319     9.498755
#         3 InProgress     0       0.000207           64           2 0.287340      0.000013      -                 -            -
# 1 trials running, 3 finished (2 until the end), 40.02s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:25:39] 🚀 Trial 4 started - config: learning_rate=0.00046258522486253485, num_hiddens=64, num_layers=2, dropout=0.20571618476742, weight_decay=0.00038919547228861436
# [16:25:49] ✅ Trial 4 completed!
# [16:25:49] 🚀 Trial 5 started - config: learning_rate=0.00014036236707599462, num_hiddens=128, num_layers=4, dropout=0.21783078277726053, weight_decay=2.486012835859121e-05
# [16:25:54] 🚀 Trial 6 started - config: learning_rate=1.0298119621476755e-05, num_hiddens=64, num_layers=3, dropout=0.41566954598167116, weight_decay=3.592479266345606e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.060241     6.064122
#         1    Stopped    10       0.000097           64           4 0.280096      0.000229   10.0          0.095342     7.375544
#         2  Completed    10       0.000049          128           3 0.319747      0.000222   10.0          0.076319     9.498755
#         3    Stopped     4       0.000207           64           2 0.287340      0.000013    4.0          0.076817     2.842536
#         4  Completed    10       0.000463           64           2 0.205716      0.000389   10.0          0.087829     5.965354
#         5    Stopped     1       0.000140          128           4 0.217831      0.000025    1.0          0.063711     1.933307
#         6 InProgress     0       0.000010           64           3 0.415670      0.000036      -                 -            -
# 1 trials running, 6 finished (3 until the end), 60.04s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:25:59] 🚀 Trial 7 started - config: learning_rate=0.0002162489558834875, num_hiddens=256, num_layers=3, dropout=0.24681376534469415, weight_decay=2.818915628846414e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.060241     6.064122
#         1    Stopped    10       0.000097           64           4 0.280096      0.000229     10          0.095342     7.375544
#         2  Completed    10       0.000049          128           3 0.319747      0.000222     10          0.076319     9.498755
#         3    Stopped     4       0.000207           64           2 0.287340      0.000013      4          0.076817     2.842536
#         4  Completed    10       0.000463           64           2 0.205716      0.000389     10          0.087829     5.965354
#         5    Stopped     1       0.000140          128           4 0.217831      0.000025      1          0.063711     1.933307
#         6    Stopped     3       0.000010           64           3 0.415670      0.000036      3          0.073719     2.629461
#         7 InProgress     6       0.000216          256           3 0.246814      0.000028      6          0.082066    12.805499
# 1 trials running, 7 finished (3 until the end), 80.06s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:26:24] ✅ Trial 7 completed!
# [16:26:24] 🚀 Trial 8 started - config: learning_rate=0.00029124771477968066, num_hiddens=256, num_layers=4, dropout=0.43808461817273014, weight_decay=1.2429795610731775e-05
# [16:26:34] 🚀 Trial 9 started - config: learning_rate=2.151048080315908e-05, num_hiddens=128, num_layers=4, dropout=0.4934171187707851, weight_decay=0.00010770879445299486
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.060241     6.064122
#         1    Stopped    10       0.000097           64           4 0.280096      0.000229   10.0          0.095342     7.375544
#         2  Completed    10       0.000049          128           3 0.319747      0.000222   10.0          0.076319     9.498755
#         3    Stopped     4       0.000207           64           2 0.287340      0.000013    4.0          0.076817     2.842536
#         4  Completed    10       0.000463           64           2 0.205716      0.000389   10.0          0.087829     5.965354
#         5    Stopped     1       0.000140          128           4 0.217831      0.000025    1.0          0.063711     1.933307
#         6    Stopped     3       0.000010           64           3 0.415670      0.000036    3.0          0.073719     2.629461
#         7  Completed    10       0.000216          256           3 0.246814      0.000028   10.0          0.061048    20.820165
#         8    Stopped     2       0.000291          256           4 0.438085      0.000012    2.0          0.080938     5.988833
#         9 InProgress     0       0.000022          128           4 0.493417      0.000108      -                 -            -
# 1 trials running, 9 finished (4 until the end), 100.07s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:26:39] 🚀 Trial 10 started - config: learning_rate=0.00026379599882490396, num_hiddens=32, num_layers=2, dropout=0.4789760114700113, weight_decay=0.00037933545917755043
# [16:26:44] 🚀 Trial 11 started - config: learning_rate=1.0350956090951937e-05, num_hiddens=32, num_layers=2, dropout=0.26286078918320727, weight_decay=7.911762639161771e-05
# [16:26:49] 🚀 Trial 12 started - config: learning_rate=0.00010262738295361578, num_hiddens=128, num_layers=2, dropout=0.37343338809669, weight_decay=1.3347823899093733e-05
# [16:26:54] 🚀 Trial 13 started - config: learning_rate=8.010145684230315e-05, num_hiddens=32, num_layers=3, dropout=0.37998773427081545, weight_decay=0.00023171243287144224
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.060241     6.064122
#         1    Stopped    10       0.000097           64           4 0.280096      0.000229   10.0          0.095342     7.375544
#         2  Completed    10       0.000049          128           3 0.319747      0.000222   10.0          0.076319     9.498755
#         3    Stopped     4       0.000207           64           2 0.287340      0.000013    4.0          0.076817     2.842536
#         4  Completed    10       0.000463           64           2 0.205716      0.000389   10.0          0.087829     5.965354
#         5    Stopped     1       0.000140          128           4 0.217831      0.000025    1.0          0.063711     1.933307
#         6    Stopped     3       0.000010           64           3 0.415670      0.000036    3.0          0.073719     2.629461
#         7  Completed    10       0.000216          256           3 0.246814      0.000028   10.0          0.061048    20.820165
#         8    Stopped     2       0.000291          256           4 0.438085      0.000012    2.0          0.080938     5.988833
#         9    Stopped     2       0.000022          128           4 0.493417      0.000108    2.0          0.070817     2.976274
#        10    Stopped     4       0.000264           32           2 0.478976      0.000379    4.0          0.080790     2.770800
#        11    Stopped     4       0.000010           32           2 0.262861      0.000079    4.0          0.066314     2.832441
#        12    Stopped     3       0.000103          128           2 0.373433      0.000013    3.0          0.063549     2.917580
#        13 InProgress     0       0.000080           32           3 0.379988      0.000232      -                 -            -
# 1 trials running, 13 finished (4 until the end), 120.09s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:26:59] 🚀 Trial 14 started - config: learning_rate=5.105728966404802e-05, num_hiddens=64, num_layers=3, dropout=0.4082078979256297, weight_decay=2.885610792960891e-05
# [16:27:04] 🚀 Trial 15 started - config: learning_rate=0.00017907401281515604, num_hiddens=64, num_layers=4, dropout=0.4800935811353113, weight_decay=1.9276363868150427e-05
# [16:27:09] 🚀 Trial 16 started - config: learning_rate=1.9734343655789533e-05, num_hiddens=32, num_layers=4, dropout=0.22659443797204804, weight_decay=0.00044519537698807873
# [16:27:14] 🚀 Trial 17 started - config: learning_rate=5.711671817038504e-05, num_hiddens=256, num_layers=3, dropout=0.43471956642634607, weight_decay=1.1327670855443117e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.060241     6.064122
#         1    Stopped    10       0.000097           64           4 0.280096      0.000229   10.0          0.095342     7.375544
#         2  Completed    10       0.000049          128           3 0.319747      0.000222   10.0          0.076319     9.498755
#         3    Stopped     4       0.000207           64           2 0.287340      0.000013    4.0          0.076817     2.842536
#         4  Completed    10       0.000463           64           2 0.205716      0.000389   10.0          0.087829     5.965354
#         5    Stopped     1       0.000140          128           4 0.217831      0.000025    1.0          0.063711     1.933307
#         6    Stopped     3       0.000010           64           3 0.415670      0.000036    3.0          0.073719     2.629461
#         7  Completed    10       0.000216          256           3 0.246814      0.000028   10.0          0.061048    20.820165
#         8    Stopped     2       0.000291          256           4 0.438085      0.000012    2.0          0.080938     5.988833
#         9    Stopped     2       0.000022          128           4 0.493417      0.000108    2.0          0.070817     2.976274
#        10    Stopped     4       0.000264           32           2 0.478976      0.000379    4.0          0.080790     2.770800
#        11    Stopped     4       0.000010           32           2 0.262861      0.000079    4.0          0.066314     2.832441
#        12    Stopped     3       0.000103          128           2 0.373433      0.000013    3.0          0.063549     2.917580
#        13    Stopped     4       0.000080           32           3 0.379988      0.000232    4.0          0.064482     3.027037
#        14    Stopped     3       0.000051           64           3 0.408208      0.000029    3.0          0.060386     2.541056
#        15    Stopped     3       0.000179           64           4 0.480094      0.000019    3.0          0.090393     2.803845
#        16    Stopped     3       0.000020           32           4 0.226594      0.000445    3.0          0.118983     2.672525
#        17 InProgress     0       0.000057          256           3 0.434720      0.000011      -                 -            -
# 1 trials running, 17 finished (4 until the end), 140.11s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.060241     6.064122
#         1    Stopped    10       0.000097           64           4 0.280096      0.000229     10          0.095342     7.375544
#         2  Completed    10       0.000049          128           3 0.319747      0.000
-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.060241     6.064122
#         1    Stopped    10       0.000097           64           4 0.280096      0.000229     10          0.095342     7.375544
#         2  Completed    10       0.000049          128           3 0.319747      0.000222     10          0.076319     9.498755
#         3    Stopped     4       0.000207           64           2 0.287340      0.000013      4          0.076817     2.842536
#         4  Completed    10       0.000463           64           2 0.205716      0.000389     10          0.087829     5.965354
#         5    Stopped     1       0.000140          128           4 0.217831      0.000025      1          0.063711     1.933307
#         6    Stopped     3       0.000010           64           3 0.415670      0.000036      3          0.073719     2.629461
#         7  Completed    10       0.000216          256           3 0.246814      0.000028     10          0.061048    20.820165
#         8    Stopped     2       0.000291          256           4 0.438085      0.000012      2          0.080938     5.988833
#         9    Stopped     2       0.000022          128           4 0.493417      0.000108      2          0.070817     2.976274
#        10    Stopped     4       0.000264           32           2 0.478976      0.000379      4          0.080790     2.770800
#        11    Stopped     4       0.000010           32           2 0.262861      0.000079      4          0.066314     2.832441
#        12    Stopped     3       0.000103          128           2 0.373433      0.000013      3          0.063549     2.917580
#        13    Stopped     4       0.000080           32           3 0.379988      0.000232      4          0.064482     3.027037
#        14    Stopped     3       0.000051           64           3 0.408208      0.000029      3          0.060386     2.541056
#        15    Stopped     3       0.000179           64           4 0.480094      0.000019      3          0.090393     2.803845
#        16    Stopped     3       0.000020           32           4 0.226594      0.000445      3          0.118983     2.672525
#        17  Completed    10       0.000057          256           3 0.434720      0.000011     10          0.083795    20.801104
#        18    Stopped     3       0.000093           64           3 0.491533      0.000131      3          0.062118     2.522958
#        19  Completed    10       0.000221           64           2 0.219413      0.000156     10          0.088069     6.113121
#        20  Completed    10       0.000022          256           4 0.217952      0.000242     10          0.062662    25.804470
#        21    Stopped     3       0.000188           32           3 0.271955      0.000043      3          0.075461     2.468189
#        22  Completed    10       0.000029          256           4 0.343077      0.000141     10          0.069268    26.089572
#        23    Stopped     1       0.000018          128           4 0.403496      0.000027      1          0.082273     1.933024
#        24    Stopped     3       0.000013           64           4 0.318333      0.000064      3          0.103791     2.748106
#        25 InProgress     2       0.000227          128           3 0.327689      0.000050      2          0.068954     2.589380
# 1 trials running, 25 finished (8 until the end), 260.23s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:29:19] 🚀 Trial 26 started - config: learning_rate=2.9011208212696125e-05, num_hiddens=128, num_layers=3, dropout=0.26504455306819075, weight_decay=2.1680511760733795e-05
# [16:29:24] 🚀 Trial 27 started - config: learning_rate=6.062320151190414e-05, num_hiddens=32, num_layers=4, dropout=0.4705246322989464, weight_decay=0.00044306702504716395
# [16:29:29] 🚀 Trial 28 started - config: learning_rate=0.0003136280630476172, num_hiddens=32, num_layers=2, dropout=0.47249633766115573, weight_decay=1.4909364368007225e-05
# [16:29:34] 🚀 Trial 29 started - config: learning_rate=2.5985472196378027e-05, num_hiddens=128, num_layers=2, dropout=0.20582463125062353, weight_decay=0.0003151828298863821
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.060241     6.064122
#         1    Stopped    10       0.000097           64           4 0.280096      0.000229   10.0          0.095342     7.375544
#         2  Completed    10       0.000049          128           3 0.319747      0.000
#         7  Completed    10       0.000216          256           3 0.246814      0.000028   10.0          0.061048    20.820165
#         8    Stopped     2       0.000291          256           4 0.438085      0.000012    2.0          0.080938     5.988833
#         9    Stopped     2       0.000022          128           4 0.493417      0.000108    2.0          0.070817     2.976274
#        10    Stopped     4       0.000264           32           2 0.478976      0.000379    4.0          0.080790     2.770800
#        11    Stopped     4       0.000010           32           2 0.262861      0.000079    4.0          0.066314     2.832441
#        12    Stopped     3       0.000103          128           2 0.373433      0.000013    3.0          0.063549     2.917580
#        13    Stopped     4       0.000080           32           3 0.379988      0.000232    4.0          0.064482     3.027037
#        14    Stopped     3       0.000051           64           3 0.408208      0.000029    3.0          0.060386     2.541056
#        15    Stopped     3       0.000179           64           4 0.480094      0.000019    3.0          0.090393     2.803845
#        16    Stopped     3       0.000020           32           4 0.226594      0.000445    3.0          0.118983     2.672525
#        17  Completed    10       0.000057          256           3 0.434720      0.000011   10.0          0.083795    20.801104
#        18    Stopped     3       0.000093           64           3 0.491533      0.000131    3.0          0.062118     2.522958
#        19  Completed    10       0.000221           64           2 0.219413      0.000156   10.0          0.088069     6.113121
#        20  Completed    10       0.000022          256           4 0.217952      0.000242   10.0          0.062662    25.804470
#        21    Stopped     3       0.000188           32           3 0.271955      0.000043    3.0          0.075461     2.468189
#        22  Completed    10       0.000029          256           4 0.343077      0.000141   10.0          0.069268    26.089572
#        23    Stopped     1       0.000018          128           4 0.403496      0.000027    1.0          0.082273     1.933024
#        24    Stopped     3       0.000013           64           4 0.318333      0.000064    3.0          0.103791     2.748106
#        25    Stopped     8       0.000227          128           3 0.327689      0.000050    8.0          0.073795     7.793809
#        26    Stopped     2       0.000029          128           3 0.265045      0.000022    2.0          0.060823     2.550760
#        27    Stopped     3       0.000061           32           4 0.470525      0.000443    3.0          0.133565     2.619155
#        28    Stopped     4       0.000314           32           2 0.472496      0.000015    4.0          0.083543     2.747435
#        29    Stopped     3       0.000026          128           2 0.205825      0.000315    3.0          0.077412     2.902836
#        30 InProgress     0       0.000016          128           2 0.434898      0.000068      -                 -            -
# 1 trials running, 30 finished (8 until the end), 280.27s wallclock-time
#
# validation_error: best 0.05490027368068695 for trial-id 16
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-16-16-24-58-325
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-16-16-24-58-325
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##15. Load Results from Temperature HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
temperature_results_path = "/root/syne-tune/python-entrypoint-2026-03-16-16-24-58-325/results.csv.zip"

# Save the results to a Pandas DataFrame
temperature_results = pd.read_csv(temperature_results_path)

# %% [markdown]
# ##16. Save the Temperature HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
temperature_hpo_results_path = Path("/content/REDE_FOREST BRIDGE_E_202501_temperature_HPO_results.csv")

# Save the DataFrame to a csv file
temperature_results.to_csv(temperature_hpo_results_path, index=True)
