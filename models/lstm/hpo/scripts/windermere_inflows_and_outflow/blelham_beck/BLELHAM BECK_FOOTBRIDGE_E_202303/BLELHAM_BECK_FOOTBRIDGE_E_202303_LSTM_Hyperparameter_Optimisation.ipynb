# %% [markdown]
# # Station Information
#
# * Station name: BLELHAM BECK_FOOTBRIDGE_E_202303
# * Water Quality Data link: https://environment.data.gov.uk/hydrology/station/E02614A

# %% [markdown]
# ## 0. Import the Relevant Libraries

# %%
# Force installation of Syne-Tune and a compatible NumPy version (may require restarting the session after running this cell before running below import cell)
# !pip install numpy==1.26.1 syne_tune --force-reinstall -q # ignore potential error messages if listed dependencies do not match imports
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 115.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.3/254.3 kB 30.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 15.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 119.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 120.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 131.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/131.7 MB 19.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 33.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 27.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 28.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 70.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.6/293.6 MB 3.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.1 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.1 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# music21 9.9.1 requires numpy>=1.26.4, but you have numpy 1.26.1 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.1 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# datasets 4.0.0 requires dill<0.3.9,>=0.3.0, but you have dill 0.4.1 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.1 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.1 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.1 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.1 which is incompatible.
# torch 2.10.0+cu128 requires nvidia-nccl-cu12==2.27.5; platform_system == "Linux", but you have nvidia-nccl-cu12 2.29.7 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.

# %%
# Import relevant libraries (Note: May require running of above cell to ensure compatibility of NumPy and Syne-Tune)
import torch
import logging
logging.basicConfig(level=logging.INFO)
import numpy as np
import matplotlib.pyplot as plt
from syne_tune import StoppingCriterion, Tuner
from syne_tune.backend.python_backend.python_backend import PythonBackend
from syne_tune.config_space import loguniform, randint, choice, uniform
from syne_tune.experiments import load_experiment
from syne_tune.optimizer.baselines import ASHA
import pandas as pd
from pathlib import Path

# %% [markdown]
# ##1. Specify Epoch Ranges and Reduction Factor for Hyperparameter Optimisation (HPO)

# %%
# Specify the minimum and maximum number of epochs for which a trial is allowed to run during HPO
min_number_of_epochs = 2
max_number_of_epochs = 10

# Define the reduction factor for the Asynchronous Successive Halving Algorithm (ASHA)
eta = 2 # Set to 2 so that 50% of trials are stopped at each rung of the scheduler

# %% [markdown]
# ##2. Define the Tune Function to Optimise Hyperparameters for Ammonium Prediction

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on ammonium_t_96 targets
def ammonium_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Load the raw data from the project GitHub into a Pandas DataFrame and set index as DateTime
    # Create the path to the directory containing the data in the Jupyter notebook environment
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/windermere_inflows_and_outflow/blelham_beck/BLELHAM%20BECK_FOOTBRIDGE_E_202303/BLELHAM%20BECK_FOOTBRIDGE_E_202303_preprocessed_data.zip")
    # Assign the full filepath for the preprocessed data
    parameter_path = "/content" / data_path / "BLELHAM BECK_FOOTBRIDGE_E_202303_preprocessed_data.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "ammonium"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ## 3. Define the Configuration Space for Hyperparameter Search

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %% [markdown]
# ##4. Define the Resources Available for HPO

# %%
# Define the number of parallel workers available to evaluate trials concurrently
n_workers = max(1, torch.cuda.device_count()) # Uses all available GPUs for parallel trials or defaults to 1 worker if running on CPU

# Define the maximum number of trials to test
max_number_of_trials = 30

# Define the stopping criterion for HPO
stop_criterion = StoppingCriterion(max_num_trials_started=max_number_of_trials)

# %% [markdown]
# ##5. Define Asynchronous Successive Halving Algorithm (ASHA) for HPO

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %% [markdown]
# ##6. Initialise and Run the Tuner for Ammonium HPO

# %%
# Instruct the searcher to run each trial as a Python function
trial_backend = PythonBackend(
    tune_function=ammonium_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-20-14-15-36-453
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-20-14-15-36-453
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-20-14-15-36-453
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [14:15:37] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay
#         0 InProgress     0        0.00001           64           2      0.2       0.00001
# 1 trials running, 0 finished (0 until the end), 20.13s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     5        0.00001           64           2      0.2       0.00001      5          0.008792    27.641697
# 1 trials running, 0 finished (0 until the end), 40.16s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     9        0.00001           64           2      0.2       0.00001      9          0.011388    44.895832
# 1 trials running, 0 finished (0 until the end), 60.18s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:16:37] ✅ Trial 0 completed!
# [14:16:37] 🚀 Trial 1 started - config: learning_rate=2.7472409620621836e-05, num_hiddens=256, num_layers=4, dropout=0.24406574783220025, weight_decay=1.0368033898080867e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000       0.00001   10.0          0.011499    49.389965
#         1 InProgress     0       0.000027          256           4 0.244066       0.00001      -                 -            -
# 1 trials running, 1 finished (1 until the end), 80.19s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:17:02] 🚀 Trial 2 started - config: learning_rate=2.7565129215617733e-05, num_hiddens=128, num_layers=2, dropout=0.3657673276203036, weight_decay=0.0001538092509585489
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010    1.0          0.010121    19.827583
#         2 InProgress     0       0.000028          128           2 0.365767      0.000154      -                 -            -
# 1 trials running, 2 finished (1 until the end), 100.21s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:17:27] 🚀 Trial 3 started - config: learning_rate=4.684756694269948e-05, num_hiddens=64, num_layers=4, dropout=0.47931556727505575, weight_decay=7.41740691357723e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010    1.0          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154    3.0          0.010641    16.012149
#         3 InProgress     0       0.000047           64           4 0.479316      0.000074      -                 -            -
# 1 trials running, 3 finished (1 until the end), 120.23s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:17:52] 🚀 Trial 4 started - config: learning_rate=0.00033381972034900946, num_hiddens=32, num_layers=4, dropout=0.24260643479792254, weight_decay=1.9155055745709764e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010    1.0          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154    3.0          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074    3.0          0.012894    17.830254
#         4 InProgress     0       0.000334           32           4 0.242606      0.000019      -                 -            -
# 1 trials running, 4 finished (1 until the end), 140.25s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010      1          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154      3          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074      3          0.012894    17.830254
#         4 InProgress     2       0.000334           32           4 0.242606      0.000019      2          0.006867    11.914176
# 1 trials running, 4 finished (1 until the end), 160.27s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010      1          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154      3          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074      3          0.012894    17.830254
#         4 InProgress     6       0.000334           32           4 0.242606      0.000019      6          0.007212    32.130997
# 1 trials running, 4 finished (1 until the end), 180.29s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:18:52] ✅ Trial 4 completed!
# [14:18:52] 🚀 Trial 5 started - config: learning_rate=2.6392607927886773e-05, num_hiddens=128, num_layers=4, dropout=0.2899331512991441, weight_decay=9.701355988000603e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010    1.0          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154    3.0          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074    3.0          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019   10.0          0.008876    52.566023
#         5 InProgress     0       0.000026          128           4 0.289933      0.000097      -                 -            -
# 1 trials running, 5 finished (2 until the end), 200.33s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:19:07] 🚀 Trial 6 started - config: learning_rate=0.0003683504214647729, num_hiddens=128, num_layers=2, dropout=0.4132502805953796, weight_decay=3.708379333203568e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010    1.0          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154    3.0          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074    3.0          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019   10.0          0.008876    52.566023
#         5    Stopped     1       0.000026          128           4 0.289933      0.000097    1.0          0.010051     8.550737
#         6 InProgress     0       0.000368          128           2 0.413250      0.000037      -                 -            -
# 1 trials running, 6 finished (2 until the end), 220.36s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:19:22] 🚀 Trial 7 started - config: learning_rate=8.706461506896934e-05, num_hiddens=64, num_layers=3, dropout=0.46334147677986876, weight_decay=2.3133106444183e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010    1.0          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154    3.0          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074    3.0          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019   10.0          0.008876    52.566023
#         5    Stopped     1       0.000026          128           4 0.289933      0.000097    1.0          0.010051     8.550737
#         6    Stopped     1       0.000368          128           2 0.413250      0.000037    1.0          0.009524     6.697014
#         7 InProgress     0       0.000087           64           3 0.463341      0.000023      -                 -            -
# 1 trials running, 7 finished (2 until the end), 240.39s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:19:37] 🚀 Trial 8 started - config: learning_rate=5.715640301034949e-05, num_hiddens=256, num_layers=4, dropout=0.3804097875689736, weight_decay=1.6774647363293938e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010    1.0          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154    3.0          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074    3.0          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019   10.0          0.008876    52.566023
#         5    Stopped     1       0.000026          128           4 0.289933      0.000097    1.0          0.010051     8.550737
#         6    Stopped     1       0.000368          128           2 0.413250      0.000037    1.0          0.009524     6.697014
#         7    Stopped     1       0.000087           64           3 0.463341      0.000023    1.0          0.011278     6.826693
#         8 InProgress     0       0.000057          256           4 0.380410      0.000017      -                 -            -
# 1 trials running, 8 finished (2 until the end), 260.41s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:20:02] 🚀 Trial 9 started - config: learning_rate=4.975941920031037e-05, num_hiddens=64, num_layers=2, dropout=0.31762708115085836, weight_decay=2.5174827337917535e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010    1.0          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154    3.0          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074    3.0          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019   10.0          0.008876    52.566023
#         5    Stopped     1       0.000026          128           4 0.289933      0.000097    1.0          0.010051     8.550737
#         6    Stopped     1       0.000368          128           2 0.413250      0.000037    1.0          0.009524     6.697014
#         7    Stopped     1       0.000087           64           3 0.463341      0.000023    1.0          0.011278     6.826693
#         8    Stopped     1       0.000057          256           4 0.380410      0.000017    1.0          0.010302    19.977758
#         9 InProgress     0       0.000050           64           2 0.317627      0.000025      -                 -            -
# 1 trials running, 9 finished (2 until the end), 280.44s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:20:17] 🚀 Trial 10 started - config: learning_rate=0.00014518393350755753, num_hiddens=64, num_layers=4, dropout=0.3655009574133401, weight_decay=2.538029617548895e-05
# [14:20:32] 🚀 Trial 11 started - config: learning_rate=3.351855122787797e-05, num_hiddens=128, num_layers=4, dropout=0.4289803241871416, weight_decay=1.3972751347370064e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010    1.0          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154    3.0          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074    3.0          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019   10.0          0.008876    52.566023
#         5    Stopped     1       0.000026          128           4 0.289933      0.000097    1.0          0.010051     8.550737
#         6    Stopped     1       0.000368          128           2 0.413250      0.000037    1.0          0.009524     6.697014
#         7    Stopped     1       0.000087           64           3 0.463341      0.000023    1.0          0.011278     6.826693
#         8    Stopped     1       0.000057          256           4 0.380410      0.000017    1.0          0.010302    19.977758
#         9    Stopped     2       0.000050           64           2 0.317627      0.000025    2.0          0.010266    10.423088
#        10    Stopped     1       0.000145           64           4 0.365501      0.000025    1.0          0.009789     7.395520
#        11 InProgress     0       0.000034          128           4 0.428980      0.000014      -                 -            -
# 1 trials running, 11 finished (2 until the end), 300.48s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010      1          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154      3          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074      3          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019     10          0.008876    52.566023
#         5    Stopped     1       0.000026          128           4 0.289933      0.000097      1          0.010051     8.550737
#         6    Stopped     1       0.000368          128           2 0.413250      0.000037      1          0.009524     6.697014
#         7    Stopped     1       0.000087           64           3 0.463341      0.000023      1          0.011278     6.826693
#         8    Stopped     1       0.000057          256           4 0.380410      0.000017      1          0.010302    19.977758
#         9    Stopped     2       0.000050           64           2 0.317627      0.000025      2          0.010266    10.423088
#        10    Stopped     1       0.000145           64           4 0.365501      0.000025      1          0.009789     7.395520
#        11 InProgress     2       0.000034          128           4 0.428980      0.000014      2          0.010796    14.876814
# 1 trials running, 11 finished (2 until the end), 320.51s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010      1          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154      3          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074      3          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019     10          0.008876    52.566023
#         5    Stopped     1       0.000026          128           4 0.289933      0.000097      1          0.010051     8.550737
#         6    Stopped     1       0.000368          128           2 0.413250      0.000037      1          0.009524     6.697014
#         7    Stopped     1       0.000087           64           3 0.463341      0.000023      1          0.011278     6.826693
#         8    Stopped     1       0.000057          256           4 0.380410      0.000017      1          0.010302    19.977758
#         9    Stopped     2       0.000050           64           2 0.317627      0.000025      2          0.010266    10.423088
#        10    Stopped     1       0.000145           64           4 0.365501      0.000025      1          0.009789     7.395520
#        11 InProgress     5       0.000034          128           4 0.428980      0.000014      5          0.006598    33.902054
# 1 trials running, 11 finished (2 until the end), 340.53s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010      1          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154      3          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074      3          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019     10          0.008876    52.566023
#         5    Stopped     1       0.000026          128           4 0.289933      0.000097      1          0.010051     8.550737
#         6    Stopped     1       0.000368          128           2 0.413250      0.000037      1          0.009524     6.697014
#         7    Stopped     1       0.000087           64           3 0.463341      0.000023      1          0.011278     6.826693
#         8    Stopped     1       0.000057          256           4 0.380410      0.000017      1          0.010302    19.977758
#         9    Stopped     2       0.000050           64           2 0.317627      0.000025      2          0.010266    10.423088
#        10    Stopped     1       0.000145           64           4 0.365501      0.000025      1          0.009789     7.395520
#        11 InProgress     8       0.000034          128           4 0.428980      0.000014      8          0.006887    53.022741
# 1 trials running, 11 finished (2 until the end), 360.57s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:21:47] ✅ Trial 11 completed!
# [14:21:47] 🚀 Trial 12 started - config: learning_rate=2.601336589059935e-05, num_hiddens=32, num_layers=4, dropout=0.24782504132720126, weight_decay=1.337706498731824e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010    1.0          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154    3.0          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074    3.0          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019   10.0          0.008876    52.566023
#         5    Stopped     1       0.000026          128           4 0.289933      0.000097    1.0          0.010051     8.550737
#         6    Stopped     1       0.000368          128           2 0.413250      0.000037    1.0          0.009524     6.697014
#         7    Stopped     1       0.000087           64           3 0.463341      0.000023    1.0          0.011278     6.826693
#         8    Stopped     1       0.000057          256           4 0.380410      0.000017    1.0          0.010302    19.977758
#         9    Stopped     2       0.000050           64           2 0.317627      0.000025    2.0          0.010266    10.423088
#        10    Stopped     1       0.000145           64           4 0.365501      0.000025    1.0          0.009789     7.395520
#        11  Completed    10       0.000034          128           4 0.428980      0.000014   10.0          0.007195    65.881207
#        12 InProgress     0       0.000026           32           4 0.247825      0.000013      -                 -            -
# 1 trials running, 12 finished (3 until the end), 380.60s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:22:12] 🚀 Trial 13 started - config: learning_rate=0.00023368257635834807, num_hiddens=128, num_layers=4, dropout=0.3337175463272798, weight_decay=1.6412748289163195e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010    1.0          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154    3.0          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074    3.0          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019   10.0          0.008876    52.566023
#         5    Stopped     1       0.000026          128           4 0.289933      0.000097    1.0          0.010051     8.550737
#         6    Stopped     1       0.000368          128           2 0.413250      0.000037    1.0          0.009524     6.697014
#         7    Stopped     1       0.000087           64           3 0.463341      0.000023    1.0          0.011278     6.826693
#         8    Stopped     1       0.000057          256           4 0.380410      0.000017    1.0          0.010302    19.977758
#         9    Stopped     2       0.000050           64           2 0.317627      0.000025    2.0          0.010266    10.423088
#        10    Stopped     1       0.000145           64           4 0.365501      0.000025    1.0          0.009789     7.395520
#        11  Completed    10       0.000034          128           4 0.428980      0.000014   10.0          0.007195    65.881207
#        12    Stopped     3       0.000026           32           4 0.247825      0.000013    3.0          0.010295    17.203478
#        13 InProgress     0       0.000234          128           4 0.333718      0.000016      -                 -            -
# 1 trials running, 13 finished (3 until the end), 400.63s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:22:27] 🚀 Trial 14 started - config: learning_rate=1.685086036564529e-05, num_hiddens=256, num_layers=4, dropout=0.49181639361022966, weight_decay=0.0004208833573783113
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010    1.0          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154    3.0          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074    3.0          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019   10.0          0.008876    52.566023
#         5    Stopped     1       0.000026          128           4 0.289933      0.000097    1.0          0.010051     8.550737
#         6    Stopped     1       0.000368          128           2 0.413250      0.000037    1.0          0.009524     6.697014
#         7    Stopped     1       0.000087           64           3 0.463341      0.000023    1.0          0.011278     6.826693
#         8    Stopped     1       0.000057          256           4 0.380410      0.000017    1.0          0.010302    19.977758
#         9    Stopped     2       0.000050           64           2 0.317627      0.000025    2.0          0.010266    10.423088
#        10    Stopped     1       0.000145           64           4 0.365501      0.000025    1.0          0.009789     7.395520
#        11  Completed    10       0.000034          128           4 0.428980      0.000014   10.0          0.007195    65.881207
#        12    Stopped     3       0.000026           32           4 0.247825      0.000013    3.0          0.010295    17.203478
#        13    Stopped     1       0.000234          128           4 0.333718      0.000016    1.0          0.011140     8.278030
#        14 InProgress     0       0.000017          256           4 0.491816      0.000421      -                 -            -
# 1 trials running, 14 finished (3 until the end), 420.67s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010      1          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154      3          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074      3          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019     10          0.008876    52.566023
#         5    Stopped     1       0.000026          128           4 0.289933      0.000097      1          0.010051     8.550737
#         6    Stopped     1       0.000368          128           2 0.413250      0.000037      1          0.009524     6.697014
#         7    Stopped     1       0.000087           64           3 0.463341      0.000023      1          0.011278     6.826693
#         8    Stopped     1       0.000057          256           4 0.380410      0.000017      1          0.010302    19.977758
#         9    Stopped     2       0.000050           64           2 0.317627      0.000025      2          0.010266    10.423088
#        10    Stopped     1       0.000145           64           4 0.365501      0.000025      1          0.009789     7.395520
#        11  Completed    10       0.000034          128           4 0.428980      0.000014     10          0.007195    65.881207
#        12    Stopped     3       0.000026           32           4 0.247825      0.000013      3          0.010295    17.203478
#        13    Stopped     1       0.000234          128           4 0.333718      0.000016      1          0.011140     8.278030
#        14 InProgress     1       0.000017          256           4 0.491816      0.000421      1          0.005699    20.019786
# 1 trials running, 14 finished (3 until the end), 440.69s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010      1          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154      3          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074      3          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019     10          0.008876    52.566023
#         5    Stopped     1       0.000026          128           4 0.289933      0.000097      1          0.010051     8.550737
#         6    Stopped     1       0.000368          128           2 0.413250      0.000037      1          0.009524     6.697014
#         7    Stopped     1       0.000087           64           3 0.463341      0.000023      1          0.011278     6.826693
#         8    Stopped     1       0.000057          256           4 0.380410      0.000017      1          0.010302    19.977758
#         9    Stopped     2       0.000050           64           2 0.317627      0.000025      2          0.010266    10.423088
#        10    Stopped     1       0.000145           64           4 0.365501      0.000025      1          0.009789     7.395520
#        11  Completed    10       0.000034          128           4 0.428980      0.000014     10          0.007195    65.881207
#        12    Stopped     3       0.000026           32           4 0.247825      0.000013      3          0.010295    17.203478
#        13    Stopped     1       0.000234          128           4 0.333718      0.000016      1          0.011140     8.278030
#        14 InProgress     2       0.000017          256           4 0.491816      0.000421      2          0.007184    36.751917
# 1 trials running, 14 finished (3 until the end), 460.72s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010      1          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154      3          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074      3          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019     10          0.008876    52.566023
#         5    Stopped     1       0.000026          128           4 0.289933      0.000097      1          0.010051     8.550737
#         6    Stopped     1       0.000368          128           2 0.413250      0.000037      1          0.009524     6.697014
#         7    Stopped     1       0.000087           64           3 0.463341      0.000023      1          0.011278     6.826693
#         8    Stopped     1       0.000057          256           4 0.380410      0.000017      1          0.010302    19.977758
#         9    Stopped     2       0.000050           64           2 0.317627      0.000025      2          0.010266    10.423088
#        10    Stopped     1       0.000145           64           4 0.365501      0.000025      1          0.009789     7.395520
#        11  Completed    10       0.000034          128           4 0.428980      0.000014     10          0.007195    65.881207
#        12    Stopped     3       0.000026           32           4 0.247825      0.000013      3          0.010295    17.203478
#        13    Stopped     1       0.000234          128           4 0.333718      0.000016      1          0.011140     8.278030
#        14 InProgress     3       0.000017          256           4 0.491816      0.000421      3          0.007859    53.518484
# 1 trials running, 14 finished (3 until the end), 480.75s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010      1          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154      3          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074      3          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019     10          0.008876    52.566023
#         5    Stopped     1       0.000026          128           4 0.289933      0.000097      1          0.010051     8.550737
#         6    Stopped     1       0.000368          128           2 0.413250      0.000037      1          0.009524     6.697014
#         7    Stopped     1       0.000087           64           3 0.463341      0.000023      1          0.011278     6.826693
#         8    Stopped     1       0.000057          256           4 0.380410      0.000017      1          0.010302    19.977758
#         9    Stopped     2       0.000050           64           2 0.317627      0.000025      2          0.010266    10.423088
#        10    Stopped     1       0.000145           64           4 0.365501      0.000025      1          0.009789     7.395520
#        11  Completed    10       0.000034          128           4 0.428980      0.000014     10          0.007195    65.881207
#        12    Stopped     3       0.000026           32           4 0.247825      0.000013      3          0.010295    17.203478
#        13    Stopped     1       0.000234          128           4 0.333718      0.000016      1          0.011140     8.278030
#        14 InProgress     4       0.000017          256           4 0.491816      0.000421      4          0.007861    70.149502
# 1 trials running, 14 finished (3 until the end), 500.78s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010      1          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154      3          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074      3          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019     10          0.008876    52.566023
#         5    Stopped     1       0.000026          128           4 0.289933      0.000097      1          0.010051     8.550737
#         6    Stopped     1       0.000368          128           2 0.413250      0.000037      1          0.009524     6.697014
#         7    Stopped     1       0.000087           64           3 0.463341      0.000023      1          0.011278     6.826693
#         8    Stopped     1       0.000057          256           4 0.380410      0.000017      1          0.010302    19.977758
#         9    Stopped     2       0.000050           64           2 0.317627      0.000025      2          0.010266    10.423088
#        10    Stopped     1       0.000145           64           4 0.365501      0.000025      1          0.009789     7.395520
#        11  Completed    10       0.000034          128           4 0.428980      0.000014     10          0.007195    65.881207
#        12    Stopped     3       0.000026           32           4 0.247825      0.000013      3          0.010295    17.203478
#        13    Stopped     1       0.000234          128           4 0.333718      0.000016      1          0.011140     8.278030
#        14 InProgress     5       0.000017          256           4 0.491816      0.000421      5          0.006507    86.860580
# 1 trials running, 14 finished (3 until the end), 520.81s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010      1          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154      3          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074      3          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019     10          0.008876    52.566023
#         5    Stopped     1       0.000026          128           4 0.289933      0.000097      1          0.010051     8.550737
#         6    Stopped     1       0.000368          128           2 0.413250      0.000037      1          0.009524     6.697014
#         7    Stopped     1       0.000087           64           3 0.463341      0.000023      1          0.011278     6.826693
#         8    Stopped     1       0.000057          256           4 0.380410      0.000017      1          0.010302    19.977758
#         9    Stopped     2       0.000050           64           2 0.317627      0.000025      2          0.010266    10.423088
#        10    Stopped     1       0.000145           64           4 0.365501      0.000025      1          0.009789     7.395520
#        11  Completed    10       0.000034          128           4 0.428980      0.000014     10          0.007195    65.881207
#        12    Stopped     3       0.000026           32           4 0.247825      0.000013      3          0.010295    17.203478
#        13    Stopped     1       0.000234          128           4 0.333718      0.000016      1          0.011140     8.278030
#        14 InProgress     7       0.000017          256           4 0.491816      0.000421      7          0.007706   120.805785
# 1 trials running, 14 finished (3 until the end), 540.85s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010      1          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154      3          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074      3          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019     10          0.008876    52.566023
#         5    Stopped     1       0.000026          128           4 0.289933      0.000097      1          0.010051     8.550737
#         6    Stopped     1       0.000368          128           2 0.413250      0.000037      1          0.009524     6.697014
#         7    Stopped     1       0.000087           64           3 0.463341      0.000023      1          0.011278     6.826693
#         8    Stopped     1       0.000057          256           4 0.380410      0.000017      1          0.010302    19.977758
#         9    Stopped     2       0.000050           64           2 0.317627      0.000025      2          0.010266    10.423088
#        10    Stopped     1       0.000145           64           4 0.365501      0.000025      1          0.009789     7.395520
#        11  Completed    10       0.000034          128           4 0.428980      0.000014     10          0.007195    65.881207
#        12    Stopped     3       0.000026           32           4 0.247825      0.000013      3          0.010295    17.203478
#        13    Stopped     1       0.000234          128           4 0.333718      0.000016      1          0.011140     8.278030
#        14 InProgress     8       0.000017          256           4 0.491816      0.000421      8          0.005842   137.464389
# 1 trials running, 14 finished (3 until the end), 560.88s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ...
#        12    Stopped     3       0.000026           32           4 0.247825      0.000013      3          0.010295    17.203478
#        13    Stopped     1       0.000234          128           4 0.333718      0.000016      1          0.011140     8.278030
#        14  Completed    10       0.000017          256           4 0.491816      0.000421     10          0.007910   172.623944
#        15    Stopped     1       0.000212           64           2 0.313772      0.000054      1          0.012451     6.401149
#        16    Stopped     1       0.000149          256           3 0.237982      0.000248      1          0.010916    16.766139
#        17    Stopped     1       0.000296           64           3 0.310842      0.000024      1          0.019885     6.978338
#        18    Stopped     1       0.000155          256           2 0.456302      0.000054      1          0.017486    13.118733
#        19    Stopped     3       0.000217          256           4 0.387314      0.000013      3          0.011459    55.465032
#        20    Stopped     1       0.000039           64           2 0.480399      0.000019      1          0.010921     6.407201
#        21    Stopped     3       0.000368           32           3 0.344388      0.000080      3          0.011760    16.536430
#        22    Stopped     3       0.000026          128           3 0.290847      0.000269      3          0.010779    18.326239
#        23    Stopped     1       0.000351          128           3 0.287528      0.000254      1          0.013572     7.511436
#        24    Stopped     1       0.000399          256           2 0.311055      0.000018      1          0.009554    12.706997
#        25    Stopped     9       0.000014           64           3 0.279041      0.000129      9          0.010494    47.260108
#        26    Stopped     1       0.000256          128           2 0.266405      0.000066      1          0.011999     6.938041
#        27 InProgress     6       0.000095           32           3 0.434085      0.000026      6          0.005115    31.401380
# 1 trials running, 27 finished (4 until the end), 941.62s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:31:33] ✅ Trial 27 completed!
# [14:31:33] 🚀 Trial 28 started - config: learning_rate=0.00039654450392754496, num_hiddens=64, num_layers=2, dropout=0.4581755563962127, weight_decay=8.169859531236202e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.011499    49.389965
#         1    Stopped     1       0.000027          256           4 0.244066      0.000010    1.0          0.010121    19.827583
#         2    Stopped     3       0.000028          128           2 0.365767      0.000154    3.0          0.010641    16.012149
#         3    Stopped     3       0.000047           64           4 0.479316      0.000074    3.0          0.012894    17.830254
#         4  Completed    10       0.000334           32           4 0.242606      0.000019   10.0          0.008876    52.566023
#         5    Stopped     1       0.000026          128           4 0.289933      0.000097    1.0          0.010051     8.550737
#         6    Stopped     1       0.000368          128           2 0.413250      0.000037    1.0          0.009524     6.697014
#         7    Stopped     1       0.000087           64           3 0.463341      0.000023    1.0          0.011278     6.826693
#         8    Stopped     1       0.000057          256           4 0.380410      0.000017    1.0          0.010302    19.977758
#         9    Stopped     2       0.000050           64           2 0.317627      0.000025    2.0          0.010266    10.423088
#        10    Stopped     1       0.000145           64           4 0.365501      0.000
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-20-14-15-36-453
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-20-14-15-36-453
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##7. Load Results from HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
ammonium_results_path = "/root/syne-tune/python-entrypoint-2026-03-20-14-15-36-453/results.csv.zip"

# Save the results to a Pandas DataFrame
ammonium_results = pd.read_csv(ammonium_results_path)

# %% [markdown]
# ##8. Save the Ammonium HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
ammonium_hpo_results_path = Path("/content/BLELHAM BECK_FOOTBRIDGE_E_202303_ammonium_hpo_results.csv")

# Save the DataFrame to a csv file
ammonium_results.to_csv(ammonium_hpo_results_path, index=True)

# %% [markdown]
# ## 9. Define the Config Space, Scheduler, and Tune Function for Dissolved Oxygen HPO

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on ammonium_t_96 targets
def oxygen_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Load the raw data from the project GitHub into a Pandas DataFrame and set index as DateTime
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/windermere_inflows_and_outflow/blelham_beck/BLELHAM%20BECK_FOOTBRIDGE_E_202303/BLELHAM%20BECK_FOOTBRIDGE_E_202303_preprocessed_data.zip")
    # Assign the full filepath for the preprocessed data
    parameter_path = "/content" / data_path / "BLELHAM BECK_FOOTBRIDGE_E_202303_preprocessed_data.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "oxygen_conc"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ##10. Initialise and Run the Tuner for Oxygen HPO

# %%
# Instruct the searcher to run each trial as a Python function
oxygen_trial_backend = PythonBackend(
    tune_function=oxygen_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=oxygen_trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-20-14-46-18-933
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-20-14-46-18-933
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-20-14-46-18-933
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [14:46:20] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     1        0.00001           64           2      0.2       0.00001      1          0.064147     6.210097
# 1 trials running, 0 finished (0 until the end), 20.02s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     6        0.00001           64           2      0.2       0.00001      6          0.032196    27.833082
# 1 trials running, 0 finished (0 until the end), 40.04s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:47:10] 🚀 Trial 1 started - config: learning_rate=2.7436498692341284e-05, num_hiddens=32, num_layers=2, dropout=0.37992374571678544, weight_decay=0.00024101948673697774
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.030005    45.030673
#         1 InProgress     0       0.000027           32           2 0.379924      0.000241      -                 -            -
# 1 trials running, 1 finished (0 until the end), 60.06s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1 InProgress     4       0.000027           32           2 0.379924      0.000241      4          0.031218    18.853693
# 1 trials running, 1 finished (0 until the end), 80.08s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1 InProgress     9       0.000027           32           2 0.379924      0.000241      9          0.029799    40.034030
# 1 trials running, 1 finished (0 until the end), 100.11s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:48:00] ✅ Trial 1 completed!
# [14:48:00] 🚀 Trial 2 started - config: learning_rate=1.3993106343161e-05, num_hiddens=256, num_layers=3, dropout=0.33203496691922907, weight_decay=0.00010249036409612971
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241   10.0          0.030010    44.448909
#         2 InProgress     0       0.000014          256           3 0.332035      0.000102      -                 -            -
# 1 trials running, 2 finished (1 until the end), 120.13s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241     10          0.030010    44.448909
#         2 InProgress     2       0.000014          256           3 0.332035      0.000102      2          0.032003    29.229907
# 1 trials running, 2 finished (1 until the end), 140.15s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241     10          0.030010    44.448909
#         2 InProgress     3       0.000014          256           3 0.332035      0.000102      3          0.031866    42.592802
# 1 trials running, 2 finished (1 until the end), 160.17s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241     10          0.030010    44.448909
#         2 InProgress     5       0.000014          256           3 0.332035      0.000102      5          0.030932    69.043818
# 1 trials running, 2 finished (1 until the end), 180.19s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241     10          0.030010    44.448909
#         2 InProgress     6       0.000014          256           3 0.332035      0.000102      6          0.030368    82.461378
# 1 trials running, 2 finished (1 until the end), 200.20s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241     10          0.030010    44.448909
#         2 InProgress     8       0.000014          256           3 0.332035      0.000102      8          0.030029   109.110942
# 1 trials running, 2 finished (1 until the end), 220.22s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:50:10] 🚀 Trial 3 started - config: learning_rate=2.8654035859794386e-05, num_hiddens=256, num_layers=4, dropout=0.29543275692745335, weight_decay=4.8773357866361526e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241   10.0          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102    9.0          0.030216   122.279710
#         3 InProgress     0       0.000029          256           4 0.295433      0.000049      -                 -            -
# 1 trials running, 3 finished (1 until the end), 240.25s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241     10          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102      9          0.030216   122.279710
#         3 InProgress     1       0.000029          256           4 0.295433      0.000049      1          0.034324    19.623816
# 1 trials running, 3 finished (1 until the end), 260.27s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241     10          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102      9          0.030216   122.279710
#         3 InProgress     2       0.000029          256           4 0.295433      0.000049      2          0.031921    36.073011
# 1 trials running, 3 finished (1 until the end), 280.29s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241     10          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102      9          0.030216   122.279710
#         3 InProgress     3       0.000029          256           4 0.295433      0.000049      3          0.031230    52.616214
# 1 trials running, 3 finished (1 until the end), 300.32s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241     10          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102      9          0.030216   122.279710
#         3 InProgress     4       0.000029          256           4 0.295433      0.000049      4          0.031187    69.015680
# 1 trials running, 3 finished (1 until the end), 320.34s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241     10          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102      9          0.030216   122.279710
#         3 InProgress     5       0.000029          256           4 0.295433      0.000049      5          0.030444    85.320536
# 1 trials running, 3 finished (1 until the end), 340.36s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241     10          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102      9          0.030216   122.279710
#         3 InProgress     7       0.000029          256           4 0.295433      0.000049      7          0.031051   118.266854
# 1 trials running, 3 finished (1 until the end), 360.39s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241     10          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102      9          0.030216   122.279710
#         3 InProgress     8       0.000029          256           4 0.295433      0.000049      8          0.034607   134.794347
# 1 trials running, 3 finished (1 until the end), 380.41s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:52:51] 🚀 Trial 4 started - config: learning_rate=0.00020096294616401238, num_hiddens=128, num_layers=2, dropout=0.22687477900461406, weight_decay=4.035377594949573e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241   10.0          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102    9.0          0.030216   122.279710
#         3    Stopped     9       0.000029          256           4 0.295433      0.000049    9.0          0.030565   151.425496
#         4 InProgress     0       0.000201          128           2 0.226875      0.000040      -                 -            -
# 1 trials running, 4 finished (1 until the end), 400.43s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:53:16] 🚀 Trial 5 started - config: learning_rate=0.00019545889307938347, num_hiddens=128, num_layers=4, dropout=0.44731745438644765, weight_decay=9.514941554903737e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241   10.0          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102    9.0          0.030216   122.279710
#         3    Stopped     9       0.000029          256           4 0.295433      0.000049    9.0          0.030565   151.425496
#         4    Stopped     3       0.000201          128           2 0.226875      0.000040    3.0          0.040144    16.137876
#         5 InProgress     0       0.000195          128           4 0.447317      0.000095      -                 -            -
# 1 trials running, 5 finished (1 until the end), 420.46s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241     10          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102      9          0.030216   122.279710
#         3    Stopped     9       0.000029          256           4 0.295433      0.000049      9          0.030565   151.425496
#         4    Stopped     3       0.000201          128           2 0.226875      0.000040      3          0.040144    16.137876
#         5 InProgress     2       0.000195          128           4 0.447317      0.000095      2          0.031088    14.191702
# 1 trials running, 5 finished (1 until the end), 440.48s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:53:41] 🚀 Trial 6 started - config: learning_rate=0.00010899903573440307, num_hiddens=64, num_layers=3, dropout=0.3622044559750158, weight_decay=0.00011401232847791557
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241     10          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102      9          0.030216   122.279710
#         3    Stopped     9       0.000029          256           4 0.295433      0.000049      9          0.030565   151.425496
#         4    Stopped     3       0.000201          128           2 0.226875      0.000040      3          0.040144    16.137876
#         5    Stopped     3       0.000195          128           4 0.447317      0.000095      3          0.032127    20.400480
#         6 InProgress     1       0.000109           64           3 0.362204      0.000114      1          0.032265     6.803124
# 1 trials running, 6 finished (1 until the end), 460.50s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241     10          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102      9          0.030216   122.279710
#         3    Stopped     9       0.000029          256           4 0.295433      0.000049      9          0.030565   151.425496
#         4    Stopped     3       0.000201          128           2 0.226875      0.000040      3          0.040144    16.137876
#         5    Stopped     3       0.000195          128           4 0.447317      0.000095      3          0.032127    20.400480
#         6 InProgress     5       0.000109           64           3 0.362204      0.000114      5          0.030340    25.986426
# 1 trials running, 6 finished (1 until the end), 480.53s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:54:31] 🚀 Trial 7 started - config: learning_rate=6.816599998997292e-05, num_hiddens=256, num_layers=4, dropout=0.4931209014826645, weight_decay=0.00048192284328534067
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241   10.0          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102    9.0          0.030216   122.279710
#         3    Stopped     9       0.000029          256           4 0.295433      0.000049    9.0          0.030565   151.425496
#         4    Stopped     3       0.000201          128           2 0.226875      0.000040    3.0          0.040144    16.137876
#         5    Stopped     3       0.000195          128           4 0.447317      0.000095    3.0          0.032127    20.400480
#         6    Stopped     9       0.000109           64           3 0.362204      0.000114    9.0          0.031197    45.221246
#         7 InProgress     0       0.000068          256           4 0.493121      0.000482      -                 -            -
# 1 trials running, 7 finished (1 until the end), 500.56s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:54:56] 🚀 Trial 8 started - config: learning_rate=1.4564315169629001e-05, num_hiddens=128, num_layers=3, dropout=0.36643141184206973, weight_decay=1.3893794966838733e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241   10.0          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102    9.0          0.030216   122.279710
#         3    Stopped     9       0.000029          256           4 0.295433      0.000049    9.0          0.030565   151.425496
#         4    Stopped     3       0.000201          128           2 0.226875      0.000040    3.0          0.040144    16.137876
#         5    Stopped     3       0.000195          128           4 0.447317      0.000095    3.0          0.032127    20.400480
#         6    Stopped     9       0.000109           64           3 0.362204      0.000114    9.0          0.031197    45.221246
#         7    Stopped     1       0.000068          256           4 0.493121      0.000482    1.0          0.036290    19.704833
#         8 InProgress     0       0.000015          128           3 0.366431      0.000014      -                 -            -
# 1 trials running, 8 finished (1 until the end), 520.58s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:55:11] 🚀 Trial 9 started - config: learning_rate=0.00014173259781395707, num_hiddens=256, num_layers=4, dropout=0.3817589961017057, weight_decay=2.6189528794698868e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241   10.0          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102    9.0          0.030216   122.279710
#         3    Stopped     9       0.000029          256           4 0.295433      0.000049    9.0          0.030565   151.425496
#         4    Stopped     3       0.000201          128           2 0.226875      0.000040    3.0          0.040144    16.137876
#         5    Stopped     3       0.000195          128           4 0.447317      0.000095    3.0          0.032127    20.400480
#         6    Stopped     9       0.000109           64           3 0.362204      0.000114    9.0          0.031197    45.221246
#         7    Stopped     1       0.000068          256           4 0.493121      0.000482    1.0          0.036290    19.704833
#         8    Stopped     1       0.000015          128           3 0.366431      0.000014    1.0          0.035078     7.441967
#         9 InProgress     0       0.000142          256           4 0.381759      0.000026      -                 -            -
# 1 trials running, 9 finished (1 until the end), 540.61s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:55:36] 🚀 Trial 10 started - config: learning_rate=9.272142009883774e-05, num_hiddens=64, num_layers=4, dropout=0.44354999509090354, weight_decay=0.0003399535731208304
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241   10.0          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102    9.0          0.030216   122.279710
#         3    Stopped     9       0.000029          256           4 0.295433      0.000049    9.0          0.030565   151.425496
#         4    Stopped     3       0.000201          128           2 0.226875      0.000040    3.0          0.040144    16.137876
#         5    Stopped     3       0.000195          128           4 0.447317      0.000095    3.0          0.032127    20.400480
#         6    Stopped     9       0.000109           64           3 0.362204      0.000114    9.0          0.031197    45.221246
#         7    Stopped     1       0.000068          256           4 0.493121      0.000482    1.0          0.036290    19.704833
#         8    Stopped     1       0.000015          128           3 0.366431      0.000014    1.0          0.035078     7.441967
#         9    Stopped     1       0.000142          256           4 0.381759      0.000026    1.0          0.033983    19.720771
#        10 InProgress     0       0.000093           64           4 0.443550      0.000340      -                 -            -
# 1 trials running, 10 finished (1 until the end), 560.64s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:55:51] 🚀 Trial 11 started - config: learning_rate=1.5480508581447505e-05, num_hiddens=256, num_layers=3, dropout=0.36066650597545413, weight_decay=0.0003197172923699294
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241   10.0          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102    9.0          0.030216   122.279710
#         3    Stopped     9       0.000029          256           4 0.295433      0.000049    9.0          0.030565   151.425496
#         4    Stopped     3       0.000201          128           2 0.226875      0.000040    3.0          0.040144    16.137876
#         5    Stopped     3       0.000195          128           4 0.447317      0.000095    3.0          0.032127    20.400480
#         6    Stopped     9       0.000109           64           3 0.362204      0.000114    9.0          0.031197    45.221246
#         7    Stopped     1       0.000068          256           4 0.493121      0.000482    1.0          0.036290    19.704833
#         8    Stopped     1       0.000015          128           3 0.366431      0.000014    1.0          0.035078     7.441967
#         9    Stopped     1       0.000142          256           4 0.381759      0.000026    1.0          0.033983    19.720771
#        10    Stopped     1       0.000093           64           4 0.443550      0.000340    1.0          0.033577     7.234805
#        11 InProgress     0       0.000015          256           3 0.360667      0.000320      -                 -            -
# 1 trials running, 11 finished (1 until the end), 580.67s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:56:16] 🚀 Trial 12 started - config: learning_rate=0.00031848894497271587, num_hiddens=256, num_layers=2, dropout=0.36219858675973965, weight_decay=0.0003548731817806065
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241   10.0          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102    9.0          0.030216   122.279710
#         3    Stopped     9       0.000029          256           4 0.295433      0.000049    9.0          0.030565   151.425496
#         4    Stopped     3       0.000201          128           2 0.226875      0.000040    3.0          0.040144    16.137876
#         5    Stopped     3       0.000195          128           4 0.447317      0.000095    3.0          0.032127    20.400480
#         6    Stopped     9       0.000109           64           3 0.362204      0.000114    9.0          0.031197    45.221246
#         7    Stopped     1       0.000068          256           4 0.493121      0.000482    1.0          0.036290    19.704833
#         8    Stopped     1       0.000015          128           3 0.366431      0.000014    1.0          0.035078     7.441967
#         9    Stopped     1       0.000142          256           4 0.381759      0.000026    1.0          0.033983    19.720771
#        10    Stopped     1       0.000093           64           4 0.443550      0.000340    1.0          0.033577     7.234805
#        11    Stopped     1       0.000015          256           3 0.360667      0.000320    1.0          0.034698    16.194165
#        12 InProgress     0       0.000318          256           2 0.362199      0.000355      -                 -            -
# 1 trials running, 12 finished (1 until the end), 600.69s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241     10          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102      9          0.030216   122.279710
#         3    Stopped     9       0.000029          256           4 0.295433      0.000049      9          0.030565   151.425496
#         4    Stopped     3       0.000201          128           2 0.226875      0.000040      3          0.040144    16.137876
#         5    Stopped     3       0.000195          128           4 0.447317      0.000095      3          0.032127    20.400480
#         6    Stopped     9       0.000109           64           3 0.362204      0.000114      9          0.031197    45.221246
#         7    Stopped     1       0.000068          256           4 0.493121      0.000482      1          0.036290    19.704833
#         8    Stopped     1       0.000015          128           3 0.366431      0.000014      1          0.035078     7.441967
#         9    Stopped     1       0.000142          256           4 0.381759      0.000026      1          0.033983    19.720771
#        10    Stopped     1       0.000093           64           4 0.443550      0.000340      1          0.033577     7.234805
#        11    Stopped     1       0.000015          256           3 0.360667      0.000320      1          0.034698    16.194165
#        12 InProgress     1       0.000318          256           2 0.362199      0.000355      1          0.032849    12.630465
# 1 trials running, 12 finished (1 until the end), 620.72s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:56:56] 🚀 Trial 13 started - config: learning_rate=8.086775768804064e-05, num_hiddens=32, num_layers=4, dropout=0.3135568359584284, weight_decay=2.080287150806734e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241   10.0          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102    9.0          0.030216   122.279710
#         3    Stopped     9       0.000029          256           4 0.295433      0.000049    9.0          0.030565   151.425496
#         4    Stopped     3       0.000201          128           2 0.226875      0.000040    3.0          0.040144    16.137876
#         5    Stopped     3       0.000195          128           4 0.447317      0.000095    3.0          0.032127    20.400480
#         6    Stopped     9       0.000109           64           3 0.362204      0.000114    9.0          0.031197    45.221246
#         7    Stopped     1       0.000068          256           4 0.493121      0.000482    1.0          0.036290    19.704833
#         8    Stopped     1       0.000015          128           3 0.366431      0.000014    1.0          0.035078     7.441967
#         9    Stopped     1       0.000142          256           4 0.381759      0.000026    1.0          0.033983    19.720771
#        10    Stopped     1       0.000093           64           4 0.443550      0.000340    1.0          0.033577     7.234805
#        11    Stopped     1       0.000015          256           3 0.360667      0.000320    1.0          0.034698    16.194165
#        12    Stopped     3       0.000318          256           2 0.362199      0.000355    3.0          0.038759    32.508329
#        13 InProgress     0       0.000081           32           4 0.313557      0.000021      -                 -            -
# 1 trials running, 13 finished (1 until the end), 640.75s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [14:57:11] 🚀 Trial 14 started - config: learning_rate=0.00047362301226085715, num_hiddens=32, num_layers=4, dropout=0.4130183185495573, weight_decay=0.00026878524815568595
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241   10.0          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102    9.0          0.030216   122.279710
#         3    Stopped     9       0.000029          256           4 0.295433      0.000049    9.0          0.030565   151.425496
#         4    Stopped     3       0.000201          128           2 0.226875      0.000040    3.0          0.040144    16.137876
#         5    Stopped     3       0.000195          128           4 0.447317      0.000095    3.0          0.032127    20.400480
#         6    Stopped     9       0.000109           64           3 0.362204      0.000114    9.0          0.031197    45.221246
#         7    Stopped     1       0.000068          256           4 0.493121      0.000482    1.0          0.036290    19.704833
#         8    Stopped     1       0.000015          128           3 0.366431      0.000014    1.0          0.035078     7.441967
#         9    Stopped     1       0.000142          256           4 0.381759      0.000026    1.0          0.033983    19.720771
#        10    Stopped     1       0.000093           64           4 0.443550      0.000340    1.0          0.033577     7.234805
#        11    Stopped     1       0.000015          256           3 0.360667      0.000320    1.0          0.034698    16.194165
#        12    Stopped     3       0.000318          256           2 0.362199      0.000355    3.0          0.038759    32.508329
#        13    Stopped     1       0.000081           32           4 0.313557      0.000021    1.0          0.034355     6.923928
#        14 InProgress     0       0.000474           32           4 0.413018      0.000269      -                 -            -
# 1 trials running, 14 finished (1 until the end), 660.78s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241     10          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102      9          0.030216   122.279710
#         3    Stopped     9       0.000029          256           4 0.295433      0.000049      9          0.030565   151.425496
#         4    Stopped     3       0.000201          128           2 0.226875      0.000040      3          0.040144    16.137876
#         5    Stopped     3       0.000195          128           4 0.447317      0.000095      3          0.032127    20.400480
#         6    Stopped     9       0.000109           64           3 0.362204      0.000114      9          0.031197    45.221246
#         7    Stopped     1       0.000068          256           4 0.493121      0.000482      1          0.036290    19.704833
#         8    Stopped     1       0.000015          128           3 0.366431      0.000014      1          0.035078     7.441967
#         9    Stopped     1       0.000142          256           4 0.381759      0.000026      1          0.033983    19.720771
#        10    Stopped     1       0.000093           64           4 0.443550      0.000340      1          0.033577     7.234805
#        11    Stopped     1       0.000015          256           3 0.360667      0.000320      1          0.034698    16.194165
#        12    Stopped     3       0.000318          256           2 0.362199      0.000355      3          0.038759    32.508329
#        13    Stopped     1       0.000081           32           4 0.313557      0.000021      1          0.034355     6.923928
#        14 InProgress     3       0.000474           32           4 0.413018      0.000269      3          0.030794    16.971381
# 1 trials running, 14 finished (1 until the end), 680.81s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.030005    45.030673
#         1  Completed    10       0.000027           32           2 0.379924      0.000241     10          0.030010    44.448909
#         2    Stopped     9       0.000014          256           3 0.332035      0.000102      9          0.030216   122.279710
#         3    Stopped     9       0.000029          256           4 0.295433      0.000049      9          0.030565   151.425496
#         4    Stopped     3       0.000201          128           2 0.226875      0.000040      3          0.040144    16.137876
#         5    Stopped     3       0.000195          128           4 0.447317      0.000095      3          0.032127    20.400480
#         6    Stopped     9       0.000109           64           3 0.362204      0.000114      9          0.031197    45.221246
#         7    Stopped     1       0.000068          256           4 0.493121      0.000482      1          0.036290    19.704833
#         8    Stopped     1       0.000015          128           3 0.366431      0.000014      1          0.035078     7.441967
#         9    Stopped     1       0.000142          256           4 0.381759      0.000026      1          0.033983    19.720771
#        10    Stopped     1       0.000093           64           4 0.443550      0.000340      1          0.033577     7.234805
#        11    Stopped     1       0.000015          256           3 0.360667      0.000320      1          0.034698    16.194165
#        12    Stopped     3       0.000318          256           2 0.362199      0.000355      3          0.038759    32.508329
#        13    Stopped     1       0.000081           32           4 0.313557      0.000021      1          0.034355     6.923928
#        14 InProgress     7       0.000474           32           4 0.413018      0.000269      7          0.034443    36.899730
# 1 trials running, 14 finished (1 until the end), 700.87s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-20-14-46-18-933
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-20-14-46-18-933
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##11. Load Results from Dissolved Oxygen HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
oxygen_results_path = "/root/syne-tune/python-entrypoint-2026-03-20-14-46-18-933/results.csv.zip"

# Save the results to a Pandas DataFrame
oxygen_results = pd.read_csv(oxygen_results_path)

# %% [markdown]
# ##12. Save the Oxygen HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
oxygen_hpo_results_path = Path("/content/BLELHAM BECK_FOOTBRIDGE_E_202303_oxygen_hpo_results.csv")

# Save the DataFrame to a csv file
oxygen_results.to_csv(oxygen_hpo_results_path, index=True)

# %% [markdown]
# ## 13. Define the Config Space, Scheduler, and Tune Function for Temperature HPO

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on temperature_t_96 targets
def temperature_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Load the raw data from the project GitHub into a Pandas DataFrame and set index as DateTime
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/windermere_inflows_and_outflow/blelham_beck/BLELHAM%20BECK_FOOTBRIDGE_E_202303/BLELHAM%20BECK_FOOTBRIDGE_E_202303_preprocessed_data.zip")
    # Assign the full filepath for the preprocessed data
    parameter_path = "/content" / data_path / "BLELHAM BECK_FOOTBRIDGE_E_202303_preprocessed_data.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "temperature"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ##14. Initialise and Run the Tuner for Temperature HPO

# %%
# Instruct the searcher to run each trial as a Python function
temperature_trial_backend = PythonBackend(
    tune_function=temperature_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=temperature_trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-20-15-11-02-141
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-20-15-11-02-141
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-20-15-11-02-141
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [15:11:02] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     1        0.00001           64           2      0.2       0.00001      1          0.145893     6.299155
# 1 trials running, 0 finished (0 until the end), 20.02s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     6        0.00001           64           2      0.2       0.00001      6          0.049458     27.68115
# 1 trials running, 0 finished (0 until the end), 40.04s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:11:52] 🚀 Trial 1 started - config: learning_rate=1.0776104386748526e-05, num_hiddens=256, num_layers=3, dropout=0.20469494879582012, weight_decay=0.00035139249745840223
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.047325    44.858325
#         1 InProgress     0       0.000011          256           3 0.204695      0.000351      -                 -            -
# 1 trials running, 1 finished (0 until the end), 60.06s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.047325    44.858325
#         1 InProgress     1       0.000011          256           3 0.204695      0.000351      1          0.050057    16.047401
# 1 trials running, 1 finished (0 until the end), 80.08s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.047325    44.858325
#         1 InProgress     2       0.000011          256           3 0.204695      0.000351      2          0.046864    29.158313
# 1 trials running, 1 finished (0 until the end), 100.09s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.047325    44.858325
#         1 InProgress     4       0.000011          256           3 0.204695      0.000351      4          0.046061    55.458327
# 1 trials running, 1 finished (0 until the end), 120.11s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.047325    44.858325
#         1 InProgress     5       0.000011          256           3 0.204695      0.000351      5          0.045989    68.576688
# 1 trials running, 1 finished (0 until the end), 140.12s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.047325    44.858325
#         1 InProgress     7       0.000011          256           3 0.204695      0.000351      7          0.046021    95.070386
# 1 trials running, 1 finished (0 until the end), 160.14s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.047325    44.858325
#         1 InProgress     8       0.000011          256           3 0.204695      0.000351      8          0.045668   108.237748
# 1 trials running, 1 finished (0 until the end), 180.16s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:14:12] 🚀 Trial 2 started - config: learning_rate=5.655197507064895e-05, num_hiddens=128, num_layers=4, dropout=0.3628757259957044, weight_decay=1.3963206383975136e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351   10.0          0.045753   134.948370
#         2 InProgress     0       0.000057          128           4 0.362876      0.000014      -                 -            -
# 1 trials running, 2 finished (0 until the end), 200.18s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351     10          0.045753   134.948370
#         2 InProgress     2       0.000057          128           4 0.362876      0.000014      2          0.049051    14.329545
# 1 trials running, 2 finished (0 until the end), 220.21s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351     10          0.045753   134.948370
#         2 InProgress     6       0.000057          128           4 0.362876      0.000014      6          0.047718    38.804457
# 1 trials running, 2 finished (0 until the end), 240.25s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351     10          0.045753   134.948370
#         2 InProgress     9       0.000057          128           4 0.362876      0.000014      9          0.047763    56.896789
# 1 trials running, 2 finished (0 until the end), 260.27s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:15:22] ✅ Trial 2 completed!
# [15:15:22] 🚀 Trial 3 started - config: learning_rate=0.0003746675982559112, num_hiddens=256, num_layers=2, dropout=0.4351767023027554, weight_decay=0.0002299284763871946
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351   10.0          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014   10.0          0.046739    63.161248
#         3 InProgress     0       0.000375          256           2 0.435177      0.000230      -                 -            -
# 1 trials running, 3 finished (1 until the end), 280.28s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351     10          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014     10          0.046739    63.161248
#         3 InProgress     2       0.000375          256           2 0.435177      0.000230      2          0.045585    22.551806
# 1 trials running, 3 finished (1 until the end), 300.30s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351     10          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014     10          0.046739    63.161248
#         3 InProgress     4       0.000375          256           2 0.435177      0.000230      4          0.045929    42.510888
# 1 trials running, 3 finished (1 until the end), 320.32s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351     10          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014     10          0.046739    63.161248
#         3 InProgress     6       0.000375          256           2 0.435177      0.000230      6          0.044954    62.572314
# 1 trials running, 3 finished (1 until the end), 340.35s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351     10          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014     10          0.046739    63.161248
#         3 InProgress     8       0.000375          256           2 0.435177      0.000230      8          0.044964    83.469417
# 1 trials running, 3 finished (1 until the end), 360.37s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:17:13] 🚀 Trial 4 started - config: learning_rate=1.399800825401014e-05, num_hiddens=32, num_layers=2, dropout=0.3535476721638151, weight_decay=3.657524601931704e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351   10.0          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014   10.0          0.046739    63.161248
#         3    Stopped    10       0.000375          256           2 0.435177      0.000230   10.0          0.045751   104.578399
#         4 InProgress     0       0.000014           32           2 0.353548      0.000037      -                 -            -
# 1 trials running, 4 finished (1 until the end), 380.39s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:17:28] 🚀 Trial 5 started - config: learning_rate=0.00018275783378569172, num_hiddens=256, num_layers=4, dropout=0.21257636717572848, weight_decay=9.885773925527582e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351   10.0          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014   10.0          0.046739    63.161248
#         3    Stopped    10       0.000375          256           2 0.435177      0.000230   10.0          0.045751   104.578399
#         4    Stopped     1       0.000014           32           2 0.353548      0.000037    1.0          0.184846     6.408345
#         5 InProgress     0       0.000183          256           4 0.212576      0.000099      -                 -            -
# 1 trials running, 5 finished (1 until the end), 400.42s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351     10          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014     10          0.046739    63.161248
#         3    Stopped    10       0.000375          256           2 0.435177      0.000230     10          0.045751   104.578399
#         4    Stopped     1       0.000014           32           2 0.353548      0.000037      1          0.184846     6.408345
#         5 InProgress     1       0.000183          256           4 0.212576      0.000099      1          0.053830    20.692640
# 1 trials running, 5 finished (1 until the end), 420.44s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351     10          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014     10          0.046739    63.161248
#         3    Stopped    10       0.000375          256           2 0.435177      0.000230     10          0.045751   104.578399
#         4    Stopped     1       0.000014           32           2 0.353548      0.000037      1          0.184846     6.408345
#         5 InProgress     2       0.000183          256           4 0.212576      0.000099      2          0.048341    37.913486
# 1 trials running, 5 finished (1 until the end), 440.46s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:18:28] 🚀 Trial 6 started - config: learning_rate=0.00025114496962510386, num_hiddens=32, num_layers=2, dropout=0.26396396347632345, weight_decay=0.00018585121458168823
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351   10.0          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014   10.0          0.046739    63.161248
#         3    Stopped    10       0.000375          256           2 0.435177      0.000230   10.0          0.045751   104.578399
#         4    Stopped     1       0.000014           32           2 0.353548      0.000037    1.0          0.184846     6.408345
#         5    Stopped     3       0.000183          256           4 0.212576      0.000099    3.0          0.048564    55.328469
#         6 InProgress     0       0.000251           32           2 0.263964      0.000186      -                 -            -
# 1 trials running, 6 finished (1 until the end), 460.49s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351     10          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014     10          0.046739    63.161248
#         3    Stopped    10       0.000375          256           2 0.435177      0.000230     10          0.045751   104.578399
#         4    Stopped     1       0.000014           32           2 0.353548      0.000037      1          0.184846     6.408345
#         5    Stopped     3       0.000183          256           4 0.212576      0.000099      3          0.048564    55.328469
#         6 InProgress     5       0.000251           32           2 0.263964      0.000186      5          0.046464    23.900620
# 1 trials running, 6 finished (1 until the end), 480.53s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:19:18] 🚀 Trial 7 started - config: learning_rate=0.00023151322544332466, num_hiddens=32, num_layers=4, dropout=0.3706711176233974, weight_decay=1.0323631937034244e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351   10.0          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014   10.0          0.046739    63.161248
#         3    Stopped    10       0.000375          256           2 0.435177      0.000230   10.0          0.045751   104.578399
#         4    Stopped     1       0.000014           32           2 0.353548      0.000037    1.0          0.184846     6.408345
#         5    Stopped     3       0.000183          256           4 0.212576      0.000099    3.0          0.048564    55.328469
#         6    Stopped     9       0.000251           32           2 0.263964      0.000186    9.0          0.048341    41.704099
#         7 InProgress     0       0.000232           32           4 0.370671      0.000010      -                 -            -
# 1 trials running, 7 finished (1 until the end), 500.56s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:19:33] 🚀 Trial 8 started - config: learning_rate=0.00011582705582972305, num_hiddens=64, num_layers=2, dropout=0.41260543925757376, weight_decay=0.0002393418455415044
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351   10.0          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014   10.0          0.046739    63.161248
#         3    Stopped    10       0.000375          256           2 0.435177      0.000230   10.0          0.045751   104.578399
#         4    Stopped     1       0.000014           32           2 0.353548      0.000037    1.0          0.184846     6.408345
#         5    Stopped     3       0.000183          256           4 0.212576      0.000099    3.0          0.048564    55.328469
#         6    Stopped     9       0.000251           32           2 0.263964      0.000186    9.0          0.048341    41.704099
#         7    Stopped     1       0.000232           32           4 0.370671      0.000010    1.0          0.053780     7.110883
#         8 InProgress     0       0.000116           64           2 0.412605      0.000239      -                 -            -
# 1 trials running, 8 finished (1 until the end), 520.59s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:19:58] 🚀 Trial 9 started - config: learning_rate=3.6239439564828414e-05, num_hiddens=64, num_layers=4, dropout=0.2266455308126505, weight_decay=8.886547840328422e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351   10.0          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014   10.0          0.046739    63.161248
#         3    Stopped    10       0.000375          256           2 0.435177      0.000230   10.0          0.045751   104.578399
#         4    Stopped     1       0.000014           32           2 0.353548      0.000037    1.0          0.184846     6.408345
#         5    Stopped     3       0.000183          256           4 0.212576      0.000099    3.0          0.048564    55.328469
#         6    Stopped     9       0.000251           32           2 0.263964      0.000186    9.0          0.048341    41.704099
#         7    Stopped     1       0.000232           32           4 0.370671      0.000010    1.0          0.053780     7.110883
#         8    Stopped     4       0.000116           64           2 0.412605      0.000239    4.0          0.048492    19.970252
#         9 InProgress     0       0.000036           64           4 0.226646      0.000089      -                 -            -
# 1 trials running, 9 finished (1 until the end), 540.61s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:20:13] 🚀 Trial 10 started - config: learning_rate=8.869236356013192e-05, num_hiddens=32, num_layers=3, dropout=0.39299234101392244, weight_decay=1.3997094721569428e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351   10.0          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014   10.0          0.046739    63.161248
#         3    Stopped    10       0.000375          256           2 0.435177      0.000230   10.0          0.045751   104.578399
#         4    Stopped     1       0.000014           32           2 0.353548      0.000037    1.0          0.184846     6.408345
#         5    Stopped     3       0.000183          256           4 0.212576      0.000099    3.0          0.048564    55.328469
#         6    Stopped     9       0.000251           32           2 0.263964      0.000186    9.0          0.048341    41.704099
#         7    Stopped     1       0.000232           32           4 0.370671      0.000010    1.0          0.053780     7.110883
#         8    Stopped     4       0.000116           64           2 0.412605      0.000239    4.0          0.048492    19.970252
#         9    Stopped     1       0.000036           64           4 0.226646      0.000089    1.0          0.054200     7.704841
#        10 InProgress     0       0.000089           32           3 0.392992      0.000014      -                 -            -
# 1 trials running, 10 finished (1 until the end), 560.64s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:20:28] 🚀 Trial 11 started - config: learning_rate=1.1811950317602266e-05, num_hiddens=64, num_layers=4, dropout=0.3010678882792589, weight_decay=2.6015359166820977e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351   10.0          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014   10.0          0.046739    63.161248
#         3    Stopped    10       0.000375          256           2 0.435177      0.000230   10.0          0.045751   104.578399
#         4    Stopped     1       0.000014           32           2 0.353548      0.000037    1.0          0.184846     6.408345
#         5    Stopped     3       0.000183          256           4 0.212576      0.000099    3.0          0.048564    55.328469
#         6    Stopped     9       0.000251           32           2 0.263964      0.000186    9.0          0.048341    41.704099
#         7    Stopped     1       0.000232           32           4 0.370671      0.000010    1.0          0.053780     7.110883
#         8    Stopped     4       0.000116           64           2 0.412605      0.000239    4.0          0.048492    19.970252
#         9    Stopped     1       0.000036           64           4 0.226646      0.000089    1.0          0.054200     7.704841
#        10    Stopped     1       0.000089           32           3 0.392992      0.000014    1.0          0.054950     6.803979
#        11 InProgress     0       0.000012           64           4 0.301068      0.000026      -                 -            -
# 1 trials running, 11 finished (1 until the end), 580.67s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:20:43] 🚀 Trial 12 started - config: learning_rate=0.00019378690492254802, num_hiddens=32, num_layers=3, dropout=0.26632001852171006, weight_decay=6.132868308638607e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351     10          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014     10          0.046739    63.161248
#         3    Stopped    10       0.000375          256           2 0.435177      0.000230     10          0.045751   104.578399
#         4    Stopped     1       0.000014           32           2 0.353548      0.000037      1          0.184846     6.408345
#         5    Stopped     3       0.000183          256           4 0.212576      0.000099      3          0.048564    55.328469
#         6    Stopped     9       0.000251           32           2 0.263964      0.000186      9          0.048341    41.704099
#         7    Stopped     1       0.000232           32           4 0.370671      0.000010      1          0.053780     7.110883
#         8    Stopped     4       0.000116           64           2 0.412605      0.000239      4          0.048492    19.970252
#         9    Stopped     1       0.000036           64           4 0.226646      0.000089      1          0.054200     7.704841
#        10    Stopped     1       0.000089           32           3 0.392992      0.000014      1          0.054950     6.803979
#        11    Stopped     1       0.000012           64           4 0.301068      0.000026      1          0.065928     7.493922
#        12 InProgress     1       0.000194           32           3 0.266320      0.000061      1          0.050341     6.839089
# 1 trials running, 12 finished (1 until the end), 600.72s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:21:08] 🚀 Trial 13 started - config: learning_rate=0.00018292545278872707, num_hiddens=64, num_layers=3, dropout=0.4428954516142213, weight_decay=0.00014016723088817998
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351   10.0          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014   10.0          0.046739    63.161248
#         3    Stopped    10       0.000375          256           2 0.435177      0.000230   10.0          0.045751   104.578399
#         4    Stopped     1       0.000014           32           2 0.353548      0.000037    1.0          0.184846     6.408345
#         5    Stopped     3       0.000183          256           4 0.212576      0.000099    3.0          0.048564    55.328469
#         6    Stopped     9       0.000251           32           2 0.263964      0.000186    9.0          0.048341    41.704099
#         7    Stopped     1       0.000232           32           4 0.370671      0.000010    1.0          0.053780     7.110883
#         8    Stopped     4       0.000116           64           2 0.412605      0.000239    4.0          0.048492    19.970252
#         9    Stopped     1       0.000036           64           4 0.226646      0.000089    1.0          0.054200     7.704841
#        10    Stopped     1       0.000089           32           3 0.392992      0.000014    1.0          0.054950     6.803979
#        11    Stopped     1       0.000012           64           4 0.301068      0.000026    1.0          0.065928     7.493922
#        12    Stopped     3       0.000194           32           3 0.266320      0.000061    3.0          0.047279    16.572142
#        13 InProgress     0       0.000183           64           3 0.442895      0.000140      -                 -            -
# 1 trials running, 13 finished (1 until the end), 620.73s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:21:23] 🚀 Trial 14 started - config: learning_rate=5.934144544990175e-05, num_hiddens=64, num_layers=2, dropout=0.41854326544272963, weight_decay=5.860887004274323e-05
# [15:21:38] 🚀 Trial 15 started - config: learning_rate=0.00013722142188060435, num_hiddens=128, num_layers=2, dropout=0.4613641576809711, weight_decay=1.5355596249484598e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351   10.0          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014   10.0          0.046739    63.161248
#         3    Stopped    10       0.000375          256           2 0.435177      0.000230   10.0          0.045751   104.578399
#         4    Stopped     1       0.000014           32           2 0.353548      0.000037    1.0          0.184846     6.408345
#         5    Stopped     3       0.000183          256           4 0.212576      0.000099    3.0          0.048564    55.328469
#         6    Stopped     9       0.000251           32           2 0.263964      0.000186    9.0          0.048341    41.704099
#         7    Stopped     1       0.000232           32           4 0.370671      0.000010    1.0          0.053780     7.110883
#         8    Stopped     4       0.000116           64           2 0.412605      0.000239    4.0          0.048492    19.970252
#         9    Stopped     1       0.000036           64           4 0.226646      0.000089    1.0          0.054200     7.704841
#        10    Stopped     1       0.000089           32           3 0.392992      0.000014    1.0          0.054950     6.803979
#        11    Stopped     1       0.000012           64           4 0.301068      0.000026    1.0          0.065928     7.493922
#        12    Stopped     3       0.000194           32           3 0.266320      0.000061    3.0          0.047279    16.572142
#        13    Stopped     1       0.000183           64           3 0.442895      0.000140    1.0          0.051177     6.942074
#        14    Stopped     1       0.000059           64           2 0.418543      0.000059    1.0          0.051865     6.413013
#        15 InProgress     0       0.000137          128           2 0.461364      0.000015      -                 -            -
# 1 trials running, 15 finished (1 until the end), 640.80s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351     10          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014     10          0.046739    63.161248
#         3    Stopped    10       0.000375          256           2 0.435177      0.000230     10          0.045751   104.578399
#         4    Stopped     1       0.000014           32           2 0.353548      0.000037      1          0.184846     6.408345
#         5    Stopped     3       0.000183          256           4 0.212576      0.000099      3          0.048564    55.328469
#         6    Stopped     9       0.000251           32           2 0.263964      0.000186      9          0.048341    41.704099
#         7    Stopped     1       0.000232           32           4 0.370671      0.000010      1          0.053780     7.110883
#         8    Stopped     4       0.000116           64           2 0.412605      0.000239      4          0.048492    19.970252
#         9    Stopped     1       0.000036           64           4 0.226646      0.000089      1          0.054200     7.704841
#        10    Stopped     1       0.000089           32           3 0.392992      0.000014      1          0.054950     6.803979
#        11    Stopped     1       0.000012           64           4 0.301068      0.000026      1          0.065928     7.493922
#        12    Stopped     3       0.000194           32           3 0.266320      0.000061      3          0.047279    16.572142
#        13    Stopped     1       0.000183           64           3 0.442895      0.000140      1          0.051177     6.942074
#        14    Stopped     1       0.000059           64           2 0.418543      0.000059      1          0.051865     6.413013
#        15 InProgress     2       0.000137          128           2 0.461364      0.000015      2          0.045493    11.840059
# 1 trials running, 15 finished (1 until the end), 660.83s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:22:03] 🚀 Trial 16 started - config: learning_rate=4.646422896413982e-05, num_hiddens=64, num_layers=4, dropout=0.2896421085517544, weight_decay=0.00018135260985899235
# [15:22:18] 🚀 Trial 17 started - config: learning_rate=4.644363212495604e-05, num_hiddens=64, num_layers=2, dropout=0.25852647282671026, weight_decay=0.0002885678866830677
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351   10.0          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014   10.0          0.046739    63.161248
#         3    Stopped    10       0.000375          256           2 0.435177      0.000230   10.0          0.045751   104.578399
#         4    Stopped     1       0.000014           32           2 0.353548      0.000037    1.0          0.184846     6.408345
#         5    Stopped     3       0.000183          256           4 0.212576      0.000099    3.0          0.048564    55.328469
#         6    Stopped     9       0.000251           32           2 0.263964      0.000186    9.0          0.048341    41.704099
#         7    Stopped     1       0.000232           32           4 0.370671      0.000010    1.0          0.053780     7.110883
#         8    Stopped     4       0.000116           64           2 0.412605      0.000239    4.0          0.048492    19.970252
#         9    Stopped     1       0.000036           64           4 0.226646      0.000089    1.0          0.054200     7.704841
#        10    Stopped     1       0.000089           32           3 0.392992      0.000014    1.0          0.054950     6.803979
#        11    Stopped     1       0.000012           64           4 0.301068      0.000026    1.0          0.065928     7.493922
#        12    Stopped     3       0.000194           32           3 0.266320      0.000061    3.0          0.047279    16.572142
#        13    Stopped     1       0.000183           64           3 0.442895      0.000140    1.0          0.051177     6.942074
#        14    Stopped     1       0.000059           64           2 0.418543      0.000059    1.0          0.051865     6.413013
#        15    Stopped     3       0.000137          128           2 0.461364      0.000015    3.0          0.049427    16.776821
#        16    Stopped     1       0.000046           64           4 0.289642      0.000181    1.0          0.054096     7.630818
#        17 InProgress     0       0.000046           64           2 0.258526      0.000289      -                 -            -
# 1 trials running, 17 finished (1 until the end), 680.87s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:22:38] 🚀 Trial 18 started - config: learning_rate=4.500971810440651e-05, num_hiddens=128, num_layers=2, dropout=0.3505968077731675, weight_decay=2.7338042741072995e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351   10.0          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014   10.0          0.046739    63.161248
#         3    Stopped    10       0.000375          256           2 0.435177      0.000230   10.0          0.045751   104.578399
#         4    Stopped     1       0.000014           32           2 0.353548      0.000037    1.0          0.184846     6.408345
#         5    Stopped     3       0.000183          256           4 0.212576      0.000099    3.0          0.048564    55.328469
#         6    Stopped     9       0.000251           32           2 0.263964      0.000186    9.0          0.048341    41.704099
#         7    Stopped     1       0.000232           32           4 0.370671      0.000010    1.0          0.053780     7.110883
#         8    Stopped     4       0.000116           64           2 0.412605      0.000239    4.0          0.048492    19.970252
#         9    Stopped     1       0.000036           64           4 0.226646      0.000089    1.0          0.054200     7.704841
#        10    Stopped     1       0.000089           32           3 0.392992      0.000014    1.0          0.054950     6.803979
#        11    Stopped     1       0.000012           64           4 0.301068      0.000026    1.0          0.065928     7.493922
#        12    Stopped     3       0.000194           32           3 0.266320      0.000061    3.0          0.047279    16.572142
#        13    Stopped     1       0.000183           64           3 0.442895      0.000140    1.0          0.051177     6.942074
#        14    Stopped     1       0.000059           64           2 0.418543      0.000059    1.0          0.051865     6.413013
#        15    Stopped     3       0.000137          128           2 0.461364      0.000015    3.0          0.049427    16.776821
#        16    Stopped     1       0.000046           64           4 0.289642      0.000181    1.0          0.054096     7.630818
#        17    Stopped     3       0.000046           64           2 0.258526      0.000289    3.0          0.047867    15.338618
#        18 InProgress     0       0.000045          128           2 0.350597      0.000027      -                 -            -
# 1 trials running, 18 finished (1 until the end), 700.92s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.047325    44.858325
#        24    Stopped     3       0.000127           32           3 0.306371      0.000206      3          0.048381    16.548472
#        25    Stopped    10       0.000011          256           2 0.317327      0.000259     10          0.045110   105.774694
#        26    Stopped     1       0.000135           32           4 0.338274      0.000021      1          0.055626     7.207464
#        27    Stopped     1       0.000375           64           4 0.457176      0.000134      1          0.051453     7.462777
#        28 InProgress     1       0.000284          128           2 0.286258      0.000059      1          0.045888     6.869548
# 1 trials running, 28 finished (1 until the end), 1021.70s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:28:09] 🚀 Trial 29 started - config: learning_rate=1.1260998907858136e-05, num_hiddens=128, num_layers=4, dropout=0.40175594655409447, weight_decay=0.0002897947901302287
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351   10.0          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014   10.0          0.046739    63.161248
#         3    Stopped    10       0.000375          256           2 0.435177      0.000230   10.0          0.045751   104.578399
#         4    Stopped     1       0.000014           32           2 0.353548      0.000037    1.0          0.184846     6.408345
#         5    Stopped     3       0.000183          256           4 0.212576      0.000099    3.0          0.048564    55.328469
#         6    Stopped     9       0.000251           32           2 0.263964      0.000186    9.0          0.048341    41.704099
#         7    Stopped     1       0.000232           32           4 0.370671      0.000010    1.0          0.053780     7.110883
#         8    Stopped     4       0.000116           64           2 0.412605      0.000239    4.0          0.048492    19.970252
#         9    Stopped     1       0.000036           64           4 0.226646      0.000089    1.0          0.054200     7.704841
#        10    Stopped     1       0.000089           32           3 0.392992      0.000014    1.0          0.054950     6.803979
#        11    Stopped     1       0.000012           64           4 0.301068      0.000026    1.0          0.065928     7.493922
#        12    Stopped     3       0.000194           32           3 0.266320      0.000061    3.0          0.047279    16.572142
#        13    Stopped     1       0.000183           64           3 0.442895      0.000140    1.0          0.051177     6.942074
#        14    Stopped     1       0.000059           64           2 0.418543      0.000059    1.0          0.051865     6.413013
#        15    Stopped     3       0.000137          128           2 0.461364      0.000015    3.0          0.049427    16.776821
#        16    Stopped     1       0.000046           64           4 0.289642      0.000181    1.0          0.054096     7.630818
#        17    Stopped     3       0.000046           64           2 0.258526      0.000289    3.0          0.047867    15.338618
#        18    Stopped    10       0.000045          128           2 0.350597      0.000027   10.0          0.045601    50.253252
#        19    Stopped     1       0.000016           64           4 0.276883      0.000072    1.0          0.060705     7.383988
#        20    Stopped     1       0.000308           32           3 0.329604      0.000038    1.0          0.051188     6.727283
#        21    Stopped     1       0.000029           64           3 0.387187      0.000149    1.0          0.055692     6.826825
#        22    Stopped     1       0.000014          256           4 0.287875      0.000086    1.0          0.050922    20.168413
#        23    Stopped     1       0.000301           32           3 0.436656      0.000081    1.0          0.051969     6.718777
#        24    Stopped     3       0.000127           32           3 0.306371      0.000206    3.0          0.048381    16.548472
#        25    Stopped    10       0.000011          256           2 0.317327      0.000259   10.0          0.045110   105.774694
#        26    Stopped     1       0.000135           32           4 0.338274      0.000021    1.0          0.055626     7.207464
#        27    Stopped     1       0.000375           64           4 0.457176      0.000134    1.0          0.051453     7.462777
#        28    Stopped     3       0.000284          128           2 0.286258      0.000059    3.0          0.047391    16.507785
#        29 InProgress     0       0.000011          128           4 0.401756      0.000290      -                 -            -
# 1 trials running, 29 finished (1 until the end), 1041.71s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:28:24] 🚀 Trial 30 started - config: learning_rate=5.253732738585736e-05, num_hiddens=128, num_layers=2, dropout=0.3759352924652274, weight_decay=5.670262517324915e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🎉🎉🎉 HYPERPARAMETER OPTIMIZATION COMPLETE!
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# --------------------
# Resource summary (last result is reported):
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.047325    44.858325
#         1    Stopped    10       0.000011          256           3 0.204695      0.000351   10.0          0.045753   134.948370
#         2  Completed    10       0.000057          128           4 0.362876      0.000014   10.0          0.046739    63.161248
#         3    Stopped    10       0.000375          256           2 0.435177      0.000230   10.0          0.045751   104.578399
#         4    Stopped     1       0.000014           32           2 0.353548      0.000037    1.0          0.184846     6.408345
#         5    Stopped     3       0.000183          256           4 0.212576      0.000099    3.0          0.048564    55.328469
#         6    Stopped     9       0.000251           32           2 0.263964      0.000186    9.0          0.048341    41.704099
#         7    Stopped     1       0.000232           32           4 0.370671      0.000010    1.0          0.053780     7.110883
#         8    Stopped     4       0.000116           64           2 0.412605      0.000239    4.0          0.048492    19.970252
#         9    Stopped     1       0.000036           64           4 0.226646      0.000089    1.0          0.054200     7.704841
#        10    Stopped     1       0.000089           32           3 0.392992      0.000014    1.0          0.054950     6.803979
#        11    Stopped     1       0.000012           64           4 0.301068      0.000026    1.0          0.065928     7.493922
#        12    Stopped     3       0.000194           32           3 0.266320      0.000061    3.0          0.047279    16.572142
#        13    Stopped     1       0.000183           64           3 0.442895      0.000140    1.0          0.051177     6.942074
#        14    Stopped     1       0.000059           64           2 0.418543      0.000059    1.0          0.051865     6.413013
#        15    Stopped     3       0.000137          128           2 0.461364      0.000015    3.0          0.049427    16.776821
#        16    Stopped     1       0.000046           64           4 0.289642      0.000181    1.0          0.054096     7.630818
#        17    Stopped     3       0.000046           64           2 0.258526      0.000289    3.0          0.047867    15.338618
#        18    Stopped    10       0.000045          128           2 0.350597      0.000027   10.0          0.045601    50.253252
#        19    Stopped     1       0.000016           64           4 0.276883      0.000072    1.0          0.060705     7.383988
#        20    Stopped     1       0.000308           32           3 0.329604      0.000038    1.0          0.051188     6.727283
#        21    Stopped     1       0.000029           64           3 0.387187      0.000149    1.0          0.055692     6.826825
#        22    Stopped     1       0.000014          256           4 0.287875      0.000086    1.0          0.050922    20.168413
#        23    Stopped     1       0.000301           32           3 0.436656      0.000081    1.0          0.051969     6.718777
#        24    Stopped     3       0.000127           32           3 0.306371      0.000206    3.0          0.048381    16.548472
#        25    Stopped    10       0.000011          256           2 0.317327      0.000259   10.0          0.045110   105.774694
#        26    Stopped     1       0.000135           32           4 0.338274      0.000021    1.0          0.055626     7.207464
#        27    Stopped     1       0.000375           64           4 0.457176      0.000134    1.0          0.051453     7.462777
#        28    Stopped     3       0.000284          128           2 0.286258      0.000059    3.0          0.047391    16.507785
#        29    Stopped     1       0.000011          128           4 0.401756      0.000290    1.0          0.061277     8.508054
#        30 InProgress     0       0.000053          128           2 0.375935      0.000057      -                 -            -
# 1 trials running, 30 finished (1 until the end), 1041.75s wallclock-time
#
# validation_error: best 0.04490911215543747 for trial-id 25
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-20-15-11-02-141
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-20-15-11-02-141
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##15. Load Results from Temperature HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
temperature_results_path = "/root/syne-tune/python-entrypoint-2026-03-20-15-11-02-141/results.csv.zip"

# Save the results to a Pandas DataFrame
temperature_results = pd.read_csv(temperature_results_path)

# %% [markdown]
# ##16. Save the Temperature HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
temperature_hpo_results_path = Path("/content/BLELHAM BECK_FOOTBRIDGE_E_202303_temperature_hpo_results.csv")

# Save the DataFrame to a csv file
temperature_results.to_csv(temperature_hpo_results_path, index=True)
