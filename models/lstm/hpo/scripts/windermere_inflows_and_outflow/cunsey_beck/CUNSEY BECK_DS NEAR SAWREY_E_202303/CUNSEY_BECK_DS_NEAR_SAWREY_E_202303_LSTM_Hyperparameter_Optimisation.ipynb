# %% [markdown]
# # Station Information
#
# * Station name: CUNSEY BECK_DS NEAR SAWREY_E_202303
# * Water Quality Data link: https://environment.data.gov.uk/hydrology/station/E01730A

# %% [markdown]
# ## 0. Import the Relevant Libraries

# %%
# Force installation of Syne-Tune and a compatible NumPy version (may require restarting the session after running this cell before running below import cell)
# !pip install numpy==1.26.1 syne_tune --force-reinstall -q # ignore potential error messages if listed dependencies do not match imports
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 120.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.3/254.3 kB 25.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 147.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 157.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 160.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/131.7 MB 19.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 30.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 22.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 24.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 75.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.6/293.6 MB 3.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.1 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.1 which is incompatible.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.1 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.1 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# datasets 4.0.0 requires dill<0.3.9,>=0.3.0, but you have dill 0.4.1 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.1 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.1 which is incompatible.
# torch 2.10.0+cu128 requires nvidia-nccl-cu12==2.27.5; platform_system == "Linux", but you have nvidia-nccl-cu12 2.29.7 which is incompatible.
# music21 9.9.1 requires numpy>=1.26.4, but you have numpy 1.26.1 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.1 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.

# %%
# Import relevant libraries (Note: May require running of above cell to ensure compatibility of NumPy and Syne-Tune)
import torch
import logging
logging.basicConfig(level=logging.INFO)
import numpy as np
import matplotlib.pyplot as plt
from syne_tune import StoppingCriterion, Tuner
from syne_tune.backend.python_backend.python_backend import PythonBackend
from syne_tune.config_space import loguniform, randint, choice, uniform
from syne_tune.experiments import load_experiment
from syne_tune.optimizer.baselines import ASHA
import pandas as pd
from pathlib import Path

# %% [markdown]
# ##1. Specify Epoch Ranges and Reduction Factor for Hyperparameter Optimisation (HPO)

# %%
# Specify the minimum and maximum number of epochs for which a trial is allowed to run during HPO
min_number_of_epochs = 2
max_number_of_epochs = 10

# Define the reduction factor for the Asynchronous Successive Halving Algorithm (ASHA)
eta = 2 # Set to 2 so that 50% of trials are stopped at each rung of the scheduler

# %% [markdown]
# ##2. Define the Tune Function to Optimise Hyperparameters for Ammonium Prediction

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on ammonium_t_96 targets
def ammonium_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Create the path to the directory containing the data in the Jupyter notebook environment
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/windermere_inflows_and_outflow/cunsey_beck/CUNSEY%20BECK_DS%20NEAR%20SAWREY_E_202303/CUNSEY%20BECK_DS%20NEAR%20SAWREY_E_202303_preprocessed_data.zip")
    # Assign the full filepath for the preprocessed data
    parameter_path = "/content" / data_path / "CUNSEY BECK_DS NEAR SAWREY_E_202303_preprocessed_data.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "ammonium"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ## 3. Define the Configuration Space for Hyperparameter Search

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %% [markdown]
# ##4. Define the Resources Available for HPO

# %%
# Define the number of parallel workers available to evaluate trials concurrently
n_workers = max(1, torch.cuda.device_count()) # Uses all available GPUs for parallel trials or defaults to 1 worker if running on CPU

# Define the maximum number of trials to test
max_number_of_trials = 30

# Define the stopping criterion for HPO
stop_criterion = StoppingCriterion(max_num_trials_started=max_number_of_trials)

# %% [markdown]
# ##5. Define Asynchronous Successive Halving Algorithm (ASHA) for HPO

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %% [markdown]
# ##6. Initialise and Run the Tuner for Ammonium HPO

# %%
# Instruct the searcher to run each trial as a Python function
trial_backend = PythonBackend(
    tune_function=ammonium_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-26-15-30-42-165
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-26-15-30-42-165
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-26-15-30-42-165
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [15:30:42] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay
#         0 InProgress     0        0.00001           64           2      0.2       0.00001
# 1 trials running, 0 finished (0 until the end), 20.13s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     4        0.00001           64           2      0.2       0.00001      4          0.016797    25.046691
# 1 trials running, 0 finished (0 until the end), 40.16s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     9        0.00001           64           2      0.2       0.00001      9          0.023295    48.207155
# 1 trials running, 0 finished (0 until the end), 60.18s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:31:42] 🚀 Trial 1 started - config: learning_rate=0.00011515670114615606, num_hiddens=128, num_layers=3, dropout=0.3074734310196513, weight_decay=8.429282755121795e-05
# [15:31:57] 🚀 Trial 2 started - config: learning_rate=3.162524024703941e-05, num_hiddens=32, num_layers=3, dropout=0.33758336726672167, weight_decay=2.8195147237915443e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084    1.0          0.024534     8.082040
#         2 InProgress     0       0.000032           32           3 0.337583      0.000028      -                 -            -
# 1 trials running, 2 finished (0 until the end), 80.20s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084      1          0.024534     8.082040
#         2 InProgress     2       0.000032           32           3 0.337583      0.000028      2          0.012151    12.089239
# 1 trials running, 2 finished (0 until the end), 100.23s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:32:22] 🚀 Trial 3 started - config: learning_rate=0.0003466785749772679, num_hiddens=64, num_layers=3, dropout=0.27316271914164525, weight_decay=1.3917136422784955e-05
# [15:32:37] 🚀 Trial 4 started - config: learning_rate=4.094673179230359e-05, num_hiddens=128, num_layers=2, dropout=0.339185987569794, weight_decay=0.00027463091183886276
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084    1.0          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028    3.0          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014    1.0          0.015488     7.006066
#         4 InProgress     0       0.000041          128           2 0.339186      0.000275      -                 -            -
# 1 trials running, 4 finished (0 until the end), 120.25s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:32:52] 🚀 Trial 5 started - config: learning_rate=2.7067006155181034e-05, num_hiddens=64, num_layers=4, dropout=0.4522261436464642, weight_decay=3.624166357573716e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084    1.0          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028    3.0          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014    1.0          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275    1.0          0.013425     7.124139
#         5 InProgress     0       0.000027           64           4 0.452226      0.000036      -                 -            -
# 1 trials running, 5 finished (0 until the end), 140.27s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:33:17] 🚀 Trial 6 started - config: learning_rate=0.00015691505299838954, num_hiddens=32, num_layers=3, dropout=0.2191684079017335, weight_decay=1.3885279576192497e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084    1.0          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028    3.0          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014    1.0          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275    1.0          0.013425     7.124139
#         5    Stopped     3       0.000027           64           4 0.452226      0.000036    3.0          0.024608    18.922018
#         6 InProgress     0       0.000157           32           3 0.219168      0.000014      -                 -            -
# 1 trials running, 6 finished (0 until the end), 160.30s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:33:32] 🚀 Trial 7 started - config: learning_rate=0.00029363890670590446, num_hiddens=32, num_layers=4, dropout=0.40529394965491894, weight_decay=6.302912432524153e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084    1.0          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028    3.0          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014    1.0          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275    1.0          0.013425     7.124139
#         5    Stopped     3       0.000027           64           4 0.452226      0.000036    3.0          0.024608    18.922018
#         6    Stopped     1       0.000157           32           3 0.219168      0.000014    1.0          0.020180     6.980761
#         7 InProgress     0       0.000294           32           4 0.405294      0.000063      -                 -            -
# 1 trials running, 7 finished (0 until the end), 180.32s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:33:47] 🚀 Trial 8 started - config: learning_rate=0.00018721818316028038, num_hiddens=32, num_layers=4, dropout=0.28082861853202207, weight_decay=1.8746119862431744e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084    1.0          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028    3.0          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014    1.0          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275    1.0          0.013425     7.124139
#         5    Stopped     3       0.000027           64           4 0.452226      0.000036    3.0          0.024608    18.922018
#         6    Stopped     1       0.000157           32           3 0.219168      0.000014    1.0          0.020180     6.980761
#         7    Stopped     1       0.000294           32           4 0.405294      0.000063    1.0          0.012997     7.338634
#         8 InProgress     0       0.000187           32           4 0.280829      0.000019      -                 -            -
# 1 trials running, 8 finished (0 until the end), 200.35s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084      1          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028      3          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014      1          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275      1          0.013425     7.124139
#         5    Stopped     3       0.000027           64           4 0.452226      0.000036      3          0.024608    18.922018
#         6    Stopped     1       0.000157           32           3 0.219168      0.000014      1          0.020180     6.980761
#         7    Stopped     1       0.000294           32           4 0.405294      0.000063      1          0.012997     7.338634
#         8 InProgress     4       0.000187           32           4 0.280829      0.000019      4          0.020006    23.477203
# 1 trials running, 8 finished (0 until the end), 220.38s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084      1          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028      3          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014      1          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275      1          0.013425     7.124139
#         5    Stopped     3       0.000027           64           4 0.452226      0.000036      3          0.024608    18.922018
#         6    Stopped     1       0.000157           32           3 0.219168      0.000014      1          0.020180     6.980761
#         7    Stopped     1       0.000294           32           4 0.405294      0.000063      1          0.012997     7.338634
#         8 InProgress     8       0.000187           32           4 0.280829      0.000019      8          0.012173    44.951390
# 1 trials running, 8 finished (0 until the end), 240.40s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:34:47] 🚀 Trial 9 started - config: learning_rate=0.00013271172155400967, num_hiddens=32, num_layers=3, dropout=0.4413050066092693, weight_decay=1.001087000545077e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084    1.0          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028    3.0          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014    1.0          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275    1.0          0.013425     7.124139
#         5    Stopped     3       0.000027           64           4 0.452226      0.000036    3.0          0.024608    18.922018
#         6    Stopped     1       0.000157           32           3 0.219168      0.000014    1.0          0.020180     6.980761
#         7    Stopped     1       0.000294           32           4 0.405294      0.000063    1.0          0.012997     7.338634
#         8    Stopped    10       0.000187           32           4 0.280829      0.000019   10.0          0.014316    55.850553
#         9 InProgress     0       0.000133           32           3 0.441305      0.000010      -                 -            -
# 1 trials running, 9 finished (0 until the end), 260.44s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:35:03] 🚀 Trial 10 started - config: learning_rate=1.0387903427118065e-05, num_hiddens=32, num_layers=3, dropout=0.36594484502574753, weight_decay=1.7868744382481496e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084      1          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028      3          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014      1          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275      1          0.013425     7.124139
#         5    Stopped     3       0.000027           64           4 0.452226      0.000036      3          0.024608    18.922018
#         6    Stopped     1       0.000157           32           3 0.219168      0.000014      1          0.020180     6.980761
#         7    Stopped     1       0.000294           32           4 0.405294      0.000063      1          0.012997     7.338634
#         8    Stopped    10       0.000187           32           4 0.280829      0.000019     10          0.014316    55.850553
#         9    Stopped     1       0.000133           32           3 0.441305      0.000010      1          0.019344     6.962214
#        10 InProgress     1       0.000010           32           3 0.365945      0.000018      1          0.011532     6.857085
# 1 trials running, 10 finished (0 until the end), 280.48s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084      1          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028      3          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014      1          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275      1          0.013425     7.124139
#         5    Stopped     3       0.000027           64           4 0.452226      0.000036      3          0.024608    18.922018
#         6    Stopped     1       0.000157           32           3 0.219168      0.000014      1          0.020180     6.980761
#         7    Stopped     1       0.000294           32           4 0.405294      0.000063      1          0.012997     7.338634
#         8    Stopped    10       0.000187           32           4 0.280829      0.000019     10          0.014316    55.850553
#         9    Stopped     1       0.000133           32           3 0.441305      0.000010      1          0.019344     6.962214
#        10 InProgress     5       0.000010           32           3 0.365945      0.000018      5          0.011803    26.479388
# 1 trials running, 10 finished (0 until the end), 300.50s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084      1          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028      3          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014      1          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275      1          0.013425     7.124139
#         5    Stopped     3       0.000027           64           4 0.452226      0.000036      3          0.024608    18.922018
#         6    Stopped     1       0.000157           32           3 0.219168      0.000014      1          0.020180     6.980761
#         7    Stopped     1       0.000294           32           4 0.405294      0.000063      1          0.012997     7.338634
#         8    Stopped    10       0.000187           32           4 0.280829      0.000019     10          0.014316    55.850553
#         9    Stopped     1       0.000133           32           3 0.441305      0.000010      1          0.019344     6.962214
#        10 InProgress     9       0.000010           32           3 0.365945      0.000018      9          0.015409    46.596115
# 1 trials running, 10 finished (0 until the end), 320.52s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:36:03] ✅ Trial 10 completed!
# [15:36:03] 🚀 Trial 11 started - config: learning_rate=5.694548535164709e-05, num_hiddens=128, num_layers=3, dropout=0.44455074155409124, weight_decay=4.088596808909099e-05
# [15:36:18] 🚀 Trial 12 started - config: learning_rate=4.5065511824323046e-05, num_hiddens=64, num_layers=2, dropout=0.3220236361383065, weight_decay=0.00022701862789994084
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084    1.0          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028    3.0          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014    1.0          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275    1.0          0.013425     7.124139
#         5    Stopped     3       0.000027           64           4 0.452226      0.000036    3.0          0.024608    18.922018
#         6    Stopped     1       0.000157           32           3 0.219168      0.000014    1.0          0.020180     6.980761
#         7    Stopped     1       0.000294           32           4 0.405294      0.000063    1.0          0.012997     7.338634
#         8    Stopped    10       0.000187           32           4 0.280829      0.000019   10.0          0.014316    55.850553
#         9    Stopped     1       0.000133           32           3 0.441305      0.000010    1.0          0.019344     6.962214
#        10  Completed    10       0.000010           32           3 0.365945      0.000018   10.0          0.016378    51.515916
#        11    Stopped     1       0.000057          128           3 0.444551      0.000041    1.0          0.023187     7.960166
#        12 InProgress     0       0.000045           64           2 0.322024      0.000227      -                 -            -
# 1 trials running, 12 finished (1 until the end), 340.57s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:36:33] 🚀 Trial 13 started - config: learning_rate=0.0003899616254487251, num_hiddens=256, num_layers=2, dropout=0.32400224953576173, weight_decay=6.229942066119801e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084    1.0          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028    3.0          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014    1.0          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275    1.0          0.013425     7.124139
#         5    Stopped     3       0.000027           64           4 0.452226      0.000036    3.0          0.024608    18.922018
#         6    Stopped     1       0.000157           32           3 0.219168      0.000014    1.0          0.020180     6.980761
#         7    Stopped     1       0.000294           32           4 0.405294      0.000063    1.0          0.012997     7.338634
#         8    Stopped    10       0.000187           32           4 0.280829      0.000019   10.0          0.014316    55.850553
#         9    Stopped     1       0.000133           32           3 0.441305      0.000010    1.0          0.019344     6.962214
#        10  Completed    10       0.000010           32           3 0.365945      0.000018   10.0          0.016378    51.515916
#        11    Stopped     1       0.000057          128           3 0.444551      0.000041    1.0          0.023187     7.960166
#        12    Stopped     1       0.000045           64           2 0.322024      0.000227    1.0          0.013931     6.494296
#        13 InProgress     0       0.000390          256           2 0.324002      0.000062      -                 -            -
# 1 trials running, 13 finished (1 until the end), 360.59s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:36:53] 🚀 Trial 14 started - config: learning_rate=0.00018188113491644732, num_hiddens=256, num_layers=3, dropout=0.3588708457362757, weight_decay=0.00021701632025513022
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084    1.0          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028    3.0          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014    1.0          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275    1.0          0.013425     7.124139
#         5    Stopped     3       0.000027           64           4 0.452226      0.000036    3.0          0.024608    18.922018
#         6    Stopped     1       0.000157           32           3 0.219168      0.000014    1.0          0.020180     6.980761
#         7    Stopped     1       0.000294           32           4 0.405294      0.000063    1.0          0.012997     7.338634
#         8    Stopped    10       0.000187           32           4 0.280829      0.000019   10.0          0.014316    55.850553
#         9    Stopped     1       0.000133           32           3 0.441305      0.000010    1.0          0.019344     6.962214
#        10  Completed    10       0.000010           32           3 0.365945      0.000018   10.0          0.016378    51.515916
#        11    Stopped     1       0.000057          128           3 0.444551      0.000041    1.0          0.023187     7.960166
#        12    Stopped     1       0.000045           64           2 0.322024      0.000227    1.0          0.013931     6.494296
#        13    Stopped     1       0.000390          256           2 0.324002      0.000062    1.0          0.029603    13.147066
#        14 InProgress     0       0.000182          256           3 0.358871      0.000217      -                 -            -
# 1 trials running, 14 finished (1 until the end), 380.62s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:37:18] 🚀 Trial 15 started - config: learning_rate=0.00010473426386480466, num_hiddens=256, num_layers=2, dropout=0.4747354354867566, weight_decay=5.9584020963498574e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084    1.0          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028    3.0          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014    1.0          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275    1.0          0.013425     7.124139
#         5    Stopped     3       0.000027           64           4 0.452226      0.000036    3.0          0.024608    18.922018
#         6    Stopped     1       0.000157           32           3 0.219168      0.000014    1.0          0.020180     6.980761
#         7    Stopped     1       0.000294           32           4 0.405294      0.000063    1.0          0.012997     7.338634
#         8    Stopped    10       0.000187           32           4 0.280829      0.000019   10.0          0.014316    55.850553
#         9    Stopped     1       0.000133           32           3 0.441305      0.000010    1.0          0.019344     6.962214
#        10  Completed    10       0.000010           32           3 0.365945      0.000018   10.0          0.016378    51.515916
#        11    Stopped     1       0.000057          128           3 0.444551      0.000041    1.0          0.023187     7.960166
#        12    Stopped     1       0.000045           64           2 0.322024      0.000227    1.0          0.013931     6.494296
#        13    Stopped     1       0.000390          256           2 0.324002      0.000062    1.0          0.029603    13.147066
#        14    Stopped     1       0.000182          256           3 0.358871      0.000217    1.0          0.018328    16.868184
#        15 InProgress     0       0.000105          256           2 0.474735      0.000060      -                 -            -
# 1 trials running, 15 finished (1 until the end), 400.65s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:37:38] 🚀 Trial 16 started - config: learning_rate=3.9825619137810816e-05, num_hiddens=32, num_layers=3, dropout=0.4227535054459125, weight_decay=0.00012078837998370112
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084    1.0          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028    3.0          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014    1.0          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275    1.0          0.013425     7.124139
#         5    Stopped     3       0.000027           64           4 0.452226      0.000036    3.0          0.024608    18.922018
#         6    Stopped     1       0.000157           32           3 0.219168      0.000014    1.0          0.020180     6.980761
#         7    Stopped     1       0.000294           32           4 0.405294      0.000063    1.0          0.012997     7.338634
#         8    Stopped    10       0.000187           32           4 0.280829      0.000019   10.0          0.014316    55.850553
#         9    Stopped     1       0.000133           32           3 0.441305      0.000010    1.0          0.019344     6.962214
#        10  Completed    10       0.000010           32           3 0.365945      0.000018   10.0          0.016378    51.515916
#        11    Stopped     1       0.000057          128           3 0.444551      0.000041    1.0          0.023187     7.960166
#        12    Stopped     1       0.000045           64           2 0.322024      0.000227    1.0          0.013931     6.494296
#        13    Stopped     1       0.000390          256           2 0.324002      0.000062    1.0          0.029603    13.147066
#        14    Stopped     1       0.000182          256           3 0.358871      0.000217    1.0          0.018328    16.868184
#        15    Stopped     1       0.000105          256           2 0.474735      0.000060    1.0          0.018165    13.250252
#        16 InProgress     0       0.000040           32           3 0.422754      0.000121      -                 -            -
# 1 trials running, 16 finished (1 until the end), 420.68s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084      1          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028      3          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014      1          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275      1          0.013425     7.124139
#         5    Stopped     3       0.000027           64           4 0.452226      0.000036      3          0.024608    18.922018
#         6    Stopped     1       0.000157           32           3 0.219168      0.000014      1          0.020180     6.980761
#         7    Stopped     1       0.000294           32           4 0.405294      0.000063      1          0.012997     7.338634
#         8    Stopped    10       0.000187           32           4 0.280829      0.000019     10          0.014316    55.850553
#         9    Stopped     1       0.000133           32           3 0.441305      0.000010      1          0.019344     6.962214
#        10  Completed    10       0.000010           32           3 0.365945      0.000018     10          0.016378    51.515916
#        11    Stopped     1       0.000057          128           3 0.444551      0.000041      1          0.023187     7.960166
#        12    Stopped     1       0.000045           64           2 0.322024      0.000227      1          0.013931     6.494296
#        13    Stopped     1       0.000390          256           2 0.324002      0.000062      1          0.029603    13.147066
#        14    Stopped     1       0.000182          256           3 0.358871      0.000217      1          0.018328    16.868184
#        15    Stopped     1       0.000105          256           2 0.474735      0.000060      1          0.018165    13.250252
#        16 InProgress     2       0.000040           32           3 0.422754      0.000121      2          0.011455    11.988971
# 1 trials running, 16 finished (1 until the end), 440.71s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084      1          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028      3          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014      1          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275      1          0.013425     7.124139
#         5    Stopped     3       0.000027           64           4 0.452226      0.000036      3          0.024608    18.922018
#         6    Stopped     1       0.000157           32           3 0.219168      0.000014      1          0.020180     6.980761
#         7    Stopped     1       0.000294           32           4 0.405294      0.000063      1          0.012997     7.338634
#         8    Stopped    10       0.000187           32           4 0.280829      0.000019     10          0.014316    55.850553
#         9    Stopped     1       0.000133           32           3 0.441305      0.000010      1          0.019344     6.962214
#        10  Completed    10       0.000010           32           3 0.365945      0.000018     10          0.016378    51.515916
#        11    Stopped     1       0.000057          128           3 0.444551      0.000041      1          0.023187     7.960166
#        12    Stopped     1       0.000045           64           2 0.322024      0.000227      1          0.013931     6.494296
#        13    Stopped     1       0.000390          256           2 0.324002      0.000062      1          0.029603    13.147066
#        14    Stopped     1       0.000182          256           3 0.358871      0.000217      1          0.018328    16.868184
#        15    Stopped     1       0.000105          256           2 0.474735      0.000060      1          0.018165    13.250252
#        16 InProgress     6       0.000040           32           3 0.422754      0.000121      6          0.021649    31.820270
# 1 trials running, 16 finished (1 until the end), 460.75s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:38:33] 🚀 Trial 17 started - config: learning_rate=1.2974118442531248e-05, num_hiddens=256, num_layers=3, dropout=0.2471402482527485, weight_decay=8.203521552852157e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084    1.0          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028    3.0          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014    1.0          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275    1.0          0.013425     7.124139
#         5    Stopped     3       0.000027           64           4 0.452226      0.000036    3.0          0.024608    18.922018
#         6    Stopped     1       0.000157           32           3 0.219168      0.000014    1.0          0.020180     6.980761
#         7    Stopped     1       0.000294           32           4 0.405294      0.000063    1.0          0.012997     7.338634
#         8    Stopped    10       0.000187           32           4 0.280829      0.000019   10.0          0.014316    55.850553
#         9    Stopped     1       0.000133           32           3 0.441305      0.000010    1.0          0.019344     6.962214
#        10  Completed    10       0.000010           32           3 0.365945      0.000018   10.0          0.016378    51.515916
#        11    Stopped     1       0.000057          128           3 0.444551      0.000041    1.0          0.023187     7.960166
#        12    Stopped     1       0.000045           64           2 0.322024      0.000227    1.0          0.013931     6.494296
#        13    Stopped     1       0.000390          256           2 0.324002      0.000062    1.0          0.029603    13.147066
#        14    Stopped     1       0.000182          256           3 0.358871      0.000217    1.0          0.018328    16.868184
#        15    Stopped     1       0.000105          256           2 0.474735      0.000060    1.0          0.018165    13.250252
#        16    Stopped     9       0.000040           32           3 0.422754      0.000121    9.0          0.017407    46.806322
#        17 InProgress     0       0.000013          256           3 0.247140      0.000082      -                 -            -
# 1 trials running, 17 finished (1 until the end), 480.78s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084      1          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028      3          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014      1          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275      1          0.013425     7.124139
#         5    Stopped     3       0.000027           64           4 0.452226      0.000036      3          0.024608    18.922018
#         6    Stopped     1       0.000157           32           3 0.219168      0.000014      1          0.020180     6.980761
#         7    Stopped     1       0.000294           32           4 0.405294      0.000063      1          0.012997     7.338634
#         8    Stopped    10       0.000187           32           4 0.280829      0.000019     10          0.014316    55.850553
#         9    Stopped     1       0.000133           32           3 0.441305      0.000010      1          0.019344     6.962214
#        10  Completed    10       0.000010           32           3 0.365945      0.000018     10          0.016378    51.515916
#        11    Stopped     1       0.000057          128           3 0.444551      0.000041      1          0.023187     7.960166
#        12    Stopped     1       0.000045           64           2 0.322024      0.000227      1          0.013931     6.494296
#        13    Stopped     1       0.000390          256           2 0.324002      0.000062      1          0.029603    13.147066
#        14    Stopped     1       0.000182          256           3 0.358871      0.000217      1          0.018328    16.868184
#        15    Stopped     1       0.000105          256           2 0.474735      0.000060      1          0.018165    13.250252
#        16    Stopped     9       0.000040           32           3 0.422754      0.000121      9          0.017407    46.806322
#        17 InProgress     1       0.000013          256           3 0.247140      0.000082      1          0.012991    17.263927
# 1 trials running, 17 finished (1 until the end), 500.81s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.021571    52.911496
#         1    Stopped     1       0.000115          128           3 0.307473      0.000084      1          0.024534     8.082040
#         2    Stopped     3       0.000032           32           3 0.337583      0.000028      3          0.015356    16.961891
#         3    Stopped     1       0.000347           64           3 0.273163      0.000014      1          0.015488     7.006066
#         4    Stopped     1       0.000041          128           2 0.339186      0.000275      1          0.013425     7.124139
#         5    Stopped     3       0.000027           64           4 0.452226      0.000036      3          0.024608    18.922018
#         6    Stopped     1       0.000157           32           3 0.219168      0.000014      1          0.020180     6.980761
#         7    Stopped     1       0.000294           32           4 0.405294      0.000063      1          0.012997     7.338634
#         8    Stopped    10       0.000187           32           4 0.280829      0.000
PO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
ammonium_hpo_results_path = Path("/content/CUNSEY BECK_DS NEAR SAWREY_E_202303_ammonium_hpo_results.csv")

# Save the DataFrame to a csv file
ammonium_results.to_csv(ammonium_hpo_results_path, index=True)

# %% [markdown]
# ## 9. Define the Config Space, Scheduler, and Tune Function for Dissolved Oxygen HPO

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on ammonium_t_96 targets
def oxygen_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Create the path to the directory containing the data in the Jupyter notebook environment
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/windermere_inflows_and_outflow/cunsey_beck/CUNSEY%20BECK_DS%20NEAR%20SAWREY_E_202303/CUNSEY%20BECK_DS%20NEAR%20SAWREY_E_202303_preprocessed_data.zip")
    # Assign the full filepath for the preprocessed data
    parameter_path = "/content" / data_path / "CUNSEY BECK_DS NEAR SAWREY_E_202303_preprocessed_data.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "oxygen_conc"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ##10. Initialise and Run the Tuner for Oxygen HPO

# %%
# Instruct the searcher to run each trial as a Python function
oxygen_trial_backend = PythonBackend(
    tune_function=oxygen_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=oxygen_trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-26-15-56-36-229
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-26-15-56-36-229
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-26-15-56-36-229
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [15:56:38] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     1        0.00001           64           2      0.2       0.00001      1          0.045549     6.533203
# 1 trials running, 0 finished (0 until the end), 20.02s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     6        0.00001           64           2      0.2       0.00001      6          0.029503    29.556948
# 1 trials running, 0 finished (0 until the end), 40.04s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:57:33] ✅ Trial 0 completed!
# [15:57:33] 🚀 Trial 1 started - config: learning_rate=0.00018575572428967821, num_hiddens=32, num_layers=4, dropout=0.3759919045940313, weight_decay=0.00010328747411515529
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.027704    48.127388
#         1 InProgress     0       0.000186           32           4 0.375992      0.000103      -                 -            -
# 1 trials running, 1 finished (1 until the end), 60.06s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.027704    48.127388
#         1 InProgress     2       0.000186           32           4 0.375992      0.000103      2          0.028853    12.896906
# 1 trials running, 1 finished (1 until the end), 80.08s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.027704    48.127388
#         1 InProgress     6       0.000186           32           4 0.375992      0.000103      6          0.028509    34.836847
# 1 trials running, 1 finished (1 until the end), 100.10s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:58:33] 🚀 Trial 2 started - config: learning_rate=6.551134030627273e-05, num_hiddens=64, num_layers=3, dropout=0.26735773108231736, weight_decay=0.0004878367328634874
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103    9.0          0.029285    51.325574
#         2 InProgress     0       0.000066           64           3 0.267358      0.000488      -                 -            -
# 1 trials running, 2 finished (1 until the end), 120.13s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103      9          0.029285    51.325574
#         2 InProgress     2       0.000066           64           3 0.267358      0.000488      2          0.029522    12.189690
# 1 trials running, 2 finished (1 until the end), 140.16s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103      9          0.029285    51.325574
#         2 InProgress     6       0.000066           64           3 0.267358      0.000488      6          0.028535    32.586328
# 1 trials running, 2 finished (1 until the end), 160.18s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:59:33] ✅ Trial 2 completed!
# [15:59:33] 🚀 Trial 3 started - config: learning_rate=0.0004864425733055094, num_hiddens=32, num_layers=2, dropout=0.3887040629591122, weight_decay=0.00037268776201287686
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103    9.0          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488   10.0          0.028920    53.088605
#         3 InProgress     0       0.000486           32           2 0.388704      0.000373      -                 -            -
# 1 trials running, 3 finished (2 until the end), 180.21s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103      9          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488     10          0.028920    53.088605
#         3 InProgress     2       0.000486           32           2 0.388704      0.000373      2          0.029216    11.268729
# 1 trials running, 3 finished (2 until the end), 200.23s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103      9          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488     10          0.028920    53.088605
#         3 InProgress     7       0.000486           32           2 0.388704      0.000373      7          0.027659    34.142491
# 1 trials running, 3 finished (2 until the end), 220.26s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:00:23] 🚀 Trial 4 started - config: learning_rate=0.00023761080380500113, num_hiddens=128, num_layers=4, dropout=0.2392383673405698, weight_decay=2.7767014017533513e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103    9.0          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488   10.0          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373    9.0          0.029330    43.554284
#         4 InProgress     0       0.000238          128           4 0.239238      0.000028      -                 -            -
# 1 trials running, 4 finished (2 until the end), 240.28s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:00:38] 🚀 Trial 5 started - config: learning_rate=2.744113600066013e-05, num_hiddens=32, num_layers=3, dropout=0.4349696374978113, weight_decay=8.387828394172011e-05
# [16:00:53] 🚀 Trial 6 started - config: learning_rate=0.00024948190010710335, num_hiddens=32, num_layers=2, dropout=0.33301638465603434, weight_decay=3.183161324566529e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103    9.0          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488   10.0          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373    9.0          0.029330    43.554284
#         4    Stopped     1       0.000238          128           4 0.239238      0.000028    1.0          0.034023     8.728533
#         5    Stopped     1       0.000027           32           3 0.434970      0.000084    1.0          0.056370     6.913598
#         6 InProgress     0       0.000249           32           2 0.333016      0.000032      -                 -            -
# 1 trials running, 6 finished (2 until the end), 260.32s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103      9          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488     10          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373      9          0.029330    43.554284
#         4    Stopped     1       0.000238          128           4 0.239238      0.000028      1          0.034023     8.728533
#         5    Stopped     1       0.000027           32           3 0.434970      0.000084      1          0.056370     6.913598
#         6 InProgress     3       0.000249           32           2 0.333016      0.000032      3          0.027366    15.771208
# 1 trials running, 6 finished (2 until the end), 280.34s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103      9          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488     10          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373      9          0.029330    43.554284
#         4    Stopped     1       0.000238          128           4 0.239238      0.000028      1          0.034023     8.728533
#         5    Stopped     1       0.000027           32           3 0.434970      0.000084      1          0.056370     6.913598
#         6 InProgress     7       0.000249           32           2 0.333016      0.000032      7          0.030318    34.168169
# 1 trials running, 6 finished (2 until the end), 300.37s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:01:48] ✅ Trial 6 completed!
# [16:01:48] 🚀 Trial 7 started - config: learning_rate=5.325530712665353e-05, num_hiddens=32, num_layers=3, dropout=0.3293576520599121, weight_decay=3.9395153343594575e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103    9.0          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488   10.0          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373    9.0          0.029330    43.554284
#         4    Stopped     1       0.000238          128           4 0.239238      0.000028    1.0          0.034023     8.728533
#         5    Stopped     1       0.000027           32           3 0.434970      0.000084    1.0          0.056370     6.913598
#         6  Completed    10       0.000249           32           2 0.333016      0.000032   10.0          0.028542    48.176545
#         7 InProgress     0       0.000053           32           3 0.329358      0.000039      -                 -            -
# 1 trials running, 7 finished (3 until the end), 320.39s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:02:03] 🚀 Trial 8 started - config: learning_rate=0.00012213679167153728, num_hiddens=32, num_layers=4, dropout=0.32377570243540654, weight_decay=1.2744249449181077e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103    9.0          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488   10.0          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373    9.0          0.029330    43.554284
#         4    Stopped     1       0.000238          128           4 0.239238      0.000028    1.0          0.034023     8.728533
#         5    Stopped     1       0.000027           32           3 0.434970      0.000084    1.0          0.056370     6.913598
#         6  Completed    10       0.000249           32           2 0.333016      0.000032   10.0          0.028542    48.176545
#         7    Stopped     1       0.000053           32           3 0.329358      0.000039    1.0          0.046365     7.015317
#         8 InProgress     0       0.000122           32           4 0.323776      0.000013      -                 -            -
# 1 trials running, 8 finished (3 until the end), 340.42s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:02:18] 🚀 Trial 9 started - config: learning_rate=2.754649741705487e-05, num_hiddens=32, num_layers=4, dropout=0.3644917353141973, weight_decay=7.606138906649353e-05
# [16:02:33] 🚀 Trial 10 started - config: learning_rate=0.0004898326408892366, num_hiddens=128, num_layers=3, dropout=0.25246921234102465, weight_decay=0.0003646208662619089
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103    9.0          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488   10.0          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373    9.0          0.029330    43.554284
#         4    Stopped     1       0.000238          128           4 0.239238      0.000028    1.0          0.034023     8.728533
#         5    Stopped     1       0.000027           32           3 0.434970      0.000084    1.0          0.056370     6.913598
#         6  Completed    10       0.000249           32           2 0.333016      0.000032   10.0          0.028542    48.176545
#         7    Stopped     1       0.000053           32           3 0.329358      0.000039    1.0          0.046365     7.015317
#         8    Stopped     1       0.000122           32           4 0.323776      0.000013    1.0          0.040121     7.406115
#         9    Stopped     1       0.000028           32           4 0.364492      0.000076    1.0          0.059389     7.354061
#        10 InProgress     0       0.000490          128           3 0.252469      0.000365      -                 -            -
# 1 trials running, 10 finished (3 until the end), 360.47s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103      9          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488     10          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373      9          0.029330    43.554284
#         4    Stopped     1       0.000238          128           4 0.239238      0.000028      1          0.034023     8.728533
#         5    Stopped     1       0.000027           32           3 0.434970      0.000084      1          0.056370     6.913598
#         6  Completed    10       0.000249           32           2 0.333016      0.000032     10          0.028542    48.176545
#         7    Stopped     1       0.000053           32           3 0.329358      0.000039      1          0.046365     7.015317
#         8    Stopped     1       0.000122           32           4 0.323776      0.000013      1          0.040121     7.406115
#         9    Stopped     1       0.000028           32           4 0.364492      0.000076      1          0.059389     7.354061
#        10 InProgress     2       0.000490          128           3 0.252469      0.000365      2          0.039505    13.710311
# 1 trials running, 10 finished (3 until the end), 380.49s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103      9          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488     10          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373      9          0.029330    43.554284
#         4    Stopped     1       0.000238          128           4 0.239238      0.000028      1          0.034023     8.728533
#         5    Stopped     1       0.000027           32           3 0.434970      0.000084      1          0.056370     6.913598
#         6  Completed    10       0.000249           32           2 0.333016      0.000032     10          0.028542    48.176545
#         7    Stopped     1       0.000053           32           3 0.329358      0.000039      1          0.046365     7.015317
#         8    Stopped     1       0.000122           32           4 0.323776      0.000013      1          0.040121     7.406115
#         9    Stopped     1       0.000028           32           4 0.364492      0.000076      1          0.059389     7.354061
#        10 InProgress     5       0.000490          128           3 0.252469      0.000365      5          0.028932    30.633327
# 1 trials running, 10 finished (3 until the end), 400.52s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:03:33] 🚀 Trial 11 started - config: learning_rate=0.00014230342985853758, num_hiddens=128, num_layers=2, dropout=0.4216496356667817, weight_decay=3.439839849116118e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103    9.0          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488   10.0          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373    9.0          0.029330    43.554284
#         4    Stopped     1       0.000238          128           4 0.239238      0.000028    1.0          0.034023     8.728533
#         5    Stopped     1       0.000027           32           3 0.434970      0.000084    1.0          0.056370     6.913598
#         6  Completed    10       0.000249           32           2 0.333016      0.000032   10.0          0.028542    48.176545
#         7    Stopped     1       0.000053           32           3 0.329358      0.000039    1.0          0.046365     7.015317
#         8    Stopped     1       0.000122           32           4 0.323776      0.000013    1.0          0.040121     7.406115
#         9    Stopped     1       0.000028           32           4 0.364492      0.000076    1.0          0.059389     7.354061
#        10    Stopped     9       0.000490          128           3 0.252469      0.000365    9.0          0.031145    53.648742
#        11 InProgress     0       0.000142          128           2 0.421650      0.000034      -                 -            -
# 1 trials running, 11 finished (3 until the end), 420.57s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103      9          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488     10          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373      9          0.029330    43.554284
#         4    Stopped     1       0.000238          128           4 0.239238      0.000028      1          0.034023     8.728533
#         5    Stopped     1       0.000027           32           3 0.434970      0.000084      1          0.056370     6.913598
#         6  Completed    10       0.000249           32           2 0.333016      0.000032     10          0.028542    48.176545
#         7    Stopped     1       0.000053           32           3 0.329358      0.000039      1          0.046365     7.015317
#         8    Stopped     1       0.000122           32           4 0.323776      0.000013      1          0.040121     7.406115
#         9    Stopped     1       0.000028           32           4 0.364492      0.000076      1          0.059389     7.354061
#        10    Stopped     9       0.000490          128           3 0.252469      0.000365      9          0.031145    53.648742
#        11 InProgress     2       0.000142          128           2 0.421650      0.000034      2          0.026317    12.236172
# 1 trials running, 11 finished (3 until the end), 440.59s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103      9          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488     10          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373      9          0.029330    43.554284
#         4    Stopped     1       0.000238          128           4 0.239238      0.000028      1          0.034023     8.728533
#         5    Stopped     1       0.000027           32           3 0.434970      0.000084      1          0.056370     6.913598
#         6  Completed    10       0.000249           32           2 0.333016      0.000032     10          0.028542    48.176545
#         7    Stopped     1       0.000053           32           3 0.329358      0.000039      1          0.046365     7.015317
#         8    Stopped     1       0.000122           32           4 0.323776      0.000013      1          0.040121     7.406115
#         9    Stopped     1       0.000028           32           4 0.364492      0.000076      1          0.059389     7.354061
#        10    Stopped     9       0.000490          128           3 0.252469      0.000365      9          0.031145    53.648742
#        11 InProgress     6       0.000142          128           2 0.421650      0.000034      6          0.027655    32.302746
# 1 trials running, 11 finished (3 until the end), 460.62s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:04:33] ✅ Trial 11 completed!
# [16:04:33] 🚀 Trial 12 started - config: learning_rate=5.2453642827892256e-05, num_hiddens=64, num_layers=4, dropout=0.29859096217907466, weight_decay=0.0002845049353054135
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103    9.0          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488   10.0          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373    9.0          0.029330    43.554284
#         4    Stopped     1       0.000238          128           4 0.239238      0.000028    1.0          0.034023     8.728533
#         5    Stopped     1       0.000027           32           3 0.434970      0.000084    1.0          0.056370     6.913598
#         6  Completed    10       0.000249           32           2 0.333016      0.000032   10.0          0.028542    48.176545
#         7    Stopped     1       0.000053           32           3 0.329358      0.000039    1.0          0.046365     7.015317
#         8    Stopped     1       0.000122           32           4 0.323776      0.000013    1.0          0.040121     7.406115
#         9    Stopped     1       0.000028           32           4 0.364492      0.000076    1.0          0.059389     7.354061
#        10    Stopped     9       0.000490          128           3 0.252469      0.000365    9.0          0.031145    53.648742
#        11  Completed    10       0.000142          128           2 0.421650      0.000034   10.0          0.028091    52.426139
#        12 InProgress     0       0.000052           64           4 0.298591      0.000285      -                 -            -
# 1 trials running, 12 finished (4 until the end), 480.67s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:04:48] 🚀 Trial 13 started - config: learning_rate=6.217319580508709e-05, num_hiddens=32, num_layers=2, dropout=0.441050225372012, weight_decay=9.898754153353249e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103    9.0          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488   10.0          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373    9.0          0.029330    43.554284
#         4    Stopped     1       0.000238          128           4 0.239238      0.000028    1.0          0.034023     8.728533
#         5    Stopped     1       0.000027           32           3 0.434970      0.000084    1.0          0.056370     6.913598
#         6  Completed    10       0.000249           32           2 0.333016      0.000032   10.0          0.028542    48.176545
#         7    Stopped     1       0.000053           32           3 0.329358      0.000039    1.0          0.046365     7.015317
#         8    Stopped     1       0.000122           32           4 0.323776      0.000013    1.0          0.040121     7.406115
#         9    Stopped     1       0.000028           32           4 0.364492      0.000076    1.0          0.059389     7.354061
#        10    Stopped     9       0.000490          128           3 0.252469      0.000365    9.0          0.031145    53.648742
#        11  Completed    10       0.000142          128           2 0.421650      0.000034   10.0          0.028091    52.426139
#        12    Stopped     1       0.000052           64           4 0.298591      0.000285    1.0          0.034840     7.656372
#        13 InProgress     0       0.000062           32           2 0.441050      0.000099      -                 -            -
# 1 trials running, 13 finished (4 until the end), 500.70s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:05:03] 🚀 Trial 14 started - config: learning_rate=1.3752029841570954e-05, num_hiddens=64, num_layers=2, dropout=0.3953445566560121, weight_decay=0.00011782089516277674
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103    9.0          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488   10.0          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373    9.0          0.029330    43.554284
#         4    Stopped     1       0.000238          128           4 0.239238      0.000028    1.0          0.034023     8.728533
#         5    Stopped     1       0.000027           32           3 0.434970      0.000084    1.0          0.056370     6.913598
#         6  Completed    10       0.000249           32           2 0.333016      0.000032   10.0          0.028542    48.176545
#         7    Stopped     1       0.000053           32           3 0.329358      0.000039    1.0          0.046365     7.015317
#         8    Stopped     1       0.000122           32           4 0.323776      0.000013    1.0          0.040121     7.406115
#         9    Stopped     1       0.000028           32           4 0.364492      0.000076    1.0          0.059389     7.354061
#        10    Stopped     9       0.000490          128           3 0.252469      0.000365    9.0          0.031145    53.648742
#        11  Completed    10       0.000142          128           2 0.421650      0.000034   10.0          0.028091    52.426139
#        12    Stopped     1       0.000052           64           4 0.298591      0.000285    1.0          0.034840     7.656372
#        13    Stopped     1       0.000062           32           2 0.441050      0.000099    1.0          0.042026     6.470841
#        14 InProgress     0       0.000014           64           2 0.395345      0.000118      -                 -            -
# 1 trials running, 14 finished (4 until the end), 520.74s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:05:18] 🚀 Trial 15 started - config: learning_rate=7.535237492401645e-05, num_hiddens=64, num_layers=4, dropout=0.2553509296517769, weight_decay=0.00014801646043867392
# [16:05:33] 🚀 Trial 16 started - config: learning_rate=2.946865917804126e-05, num_hiddens=64, num_layers=2, dropout=0.35719375275814336, weight_decay=3.7693441528025506e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103    9.0          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488   10.0          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373    9.0          0.029330    43.554284
#         4    Stopped     1       0.000238          128           4 0.239238      0.000028    1.0          0.034023     8.728533
#         5    Stopped     1       0.000027           32           3 0.434970      0.000084    1.0          0.056370     6.913598
#         6  Completed    10       0.000249           32           2 0.333016      0.000032   10.0          0.028542    48.176545
#         7    Stopped     1       0.000053           32           3 0.329358      0.000039    1.0          0.046365     7.015317
#         8    Stopped     1       0.000122           32           4 0.323776      0.000013    1.0          0.040121     7.406115
#         9    Stopped     1       0.000028           32           4 0.364492      0.000076    1.0          0.059389     7.354061
#        10    Stopped     9       0.000490          128           3 0.252469      0.000365    9.0          0.031145    53.648742
#        11  Completed    10       0.000142          128           2 0.421650      0.000034   10.0          0.028091    52.426139
#        12    Stopped     1       0.000052           64           4 0.298591      0.000285    1.0          0.034840     7.656372
#        13    Stopped     1       0.000062           32           2 0.441050      0.000099    1.0          0.042026     6.470841
#        14    Stopped     1       0.000014           64           2 0.395345      0.000118    1.0          0.037610     6.542225
#        15    Stopped     1       0.000075           64           4 0.255351      0.000148    1.0          0.034105     7.578735
#        16 InProgress     0       0.000029           64           2 0.357194      0.000038      -                 -            -
# 1 trials running, 16 finished (4 until the end), 540.79s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:05:48] 🚀 Trial 17 started - config: learning_rate=0.00013852953778132102, num_hiddens=32, num_layers=2, dropout=0.26153922146939135, weight_decay=7.438709840036161e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103    9.0          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488   10.0          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373    9.0          0.029330    43.554284
#         4    Stopped     1       0.000238          128           4 0.239238      0.000028    1.0          0.034023     8.728533
#         5    Stopped     1       0.000027           32           3 0.434970      0.000084    1.0          0.056370     6.913598
#         6  Completed    10       0.000249           32           2 0.333016      0.000032   10.0          0.028542    48.176545
#         7    Stopped     1       0.000053           32           3 0.329358      0.000039    1.0          0.046365     7.015317
#         8    Stopped     1       0.000122           32           4 0.323776      0.000013    1.0          0.040121     7.406115
#         9    Stopped     1       0.000028           32           4 0.364492      0.000076    1.0          0.059389     7.354061
#        10    Stopped     9       0.000490          128           3 0.252469      0.000365    9.0          0.031145    53.648742
#        11  Completed    10       0.000142          128           2 0.421650      0.000034   10.0          0.028091    52.426139
#        12    Stopped     1       0.000052           64           4 0.298591      0.000285    1.0          0.034840     7.656372
#        13    Stopped     1       0.000062           32           2 0.441050      0.000099    1.0          0.042026     6.470841
#        14    Stopped     1       0.000014           64           2 0.395345      0.000118    1.0          0.037610     6.542225
#        15    Stopped     1       0.000075           64           4 0.255351      0.000148    1.0          0.034105     7.578735
#        16    Stopped     1       0.000029           64           2 0.357194      0.000038    1.0          0.036280     6.541768
#        17 InProgress     0       0.000139           32           2 0.261539      0.000074      -                 -            -
# 1 trials running, 17 finished (4 until the end), 560.84s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:06:09] 🚀 Trial 18 started - config: learning_rate=5.984405964765072e-05, num_hiddens=256, num_layers=4, dropout=0.33198133788201617, weight_decay=2.7129830489455852e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103    9.0          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488   10.0          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373    9.0          0.029330    43.554284
#         4    Stopped     1       0.000238          128           4 0.239238      0.000028    1.0          0.034023     8.728533
#         5    Stopped     1       0.000027           32           3 0.434970      0.000084    1.0          0.056370     6.913598
#         6  Completed    10       0.000249           32           2 0.333016      0.000032   10.0          0.028542    48.176545
#         7    Stopped     1       0.000053           32           3 0.329358      0.000039    1.0          0.046365     7.015317
#         8    Stopped     1       0.000122           32           4 0.323776      0.000013    1.0          0.040121     7.406115
#         9    Stopped     1       0.000028           32           4 0.364492      0.000076    1.0          0.059389     7.354061
#        10    Stopped     9       0.000490          128           3 0.252469      0.000365    9.0          0.031145    53.648742
#        11  Completed    10       0.000142          128           2 0.421650      0.000034   10.0          0.028091    52.426139
#        12    Stopped     1       0.000052           64           4 0.298591      0.000285    1.0          0.034840     7.656372
#        13    Stopped     1       0.000062           32           2 0.441050      0.000099    1.0          0.042026     6.470841
#        14    Stopped     1       0.000014           64           2 0.395345      0.000118    1.0          0.037610     6.542225
#        15    Stopped     1       0.000075           64           4 0.255351      0.000148    1.0          0.034105     7.578735
#        16    Stopped     1       0.000029           64           2 0.357194      0.000038    1.0          0.036280     6.541768
#        17    Stopped     3       0.000139           32           2 0.261539      0.000074    3.0          0.029177    15.481508
#        18 InProgress     0       0.000060          256           4 0.331981      0.000027      -                 -            -
# 1 trials running, 18 finished (4 until the end), 580.87s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103    9.0          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488   10.0          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373    9.0          0.029330    43.554284
#         4    Stopped     1       0.000238          128           4 0.239238      0.000028    1.0          0.034023     8.728533
#         5    Stopped     1       0.000027           32           3 0.434970      0.000084    1.0          0.056370     6.913598
#         6  Completed    10       0.000249           32           2 0.333016      0.000
#        21    Stopped     9       0.000219          128           3 0.250661      0.000016      9          0.032813    54.307383
#        22    Stopped     9       0.000115          256           3 0.222469      0.000089      9          0.032215   127.248277
#        23    Stopped     1       0.000016           32           2 0.349924      0.000337      1          0.071970     6.507767
#        24    Stopped     1       0.000267          128           3 0.320071      0.000439      1          0.034665     7.815408
#        25    Stopped     9       0.000324          256           3 0.283269      0.000030      9          0.032093   128.453471
#        26  Completed    10       0.000029          256           2 0.291938      0.000017     10          0.026543   110.699670
#        27    Stopped     1       0.000247           64           4 0.204256      0.000025      1          0.030625     7.701478
#        28 InProgress     1       0.000022          256           3 0.272778      0.000385      1          0.029944    16.841437
# 1 trials running, 28 finished (5 until the end), 1342.41s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:19:15] 🚀 Trial 29 started - config: learning_rate=2.8179491926160914e-05, num_hiddens=128, num_layers=3, dropout=0.3196079456581868, weight_decay=2.4331673216391482e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.027704    48.127388
#         1    Stopped     9       0.000186           32           4 0.375992      0.000103    9.0          0.029285    51.325574
#         2  Completed    10       0.000066           64           3 0.267358      0.000488   10.0          0.028920    53.088605
#         3    Stopped     9       0.000486           32           2 0.388704      0.000373    9.0          0.029330    43.554284
#         4    Stopped     1       0.000238          128           4 0.239238      0.000028    1.0          0.034023     8.728533
#         5    Stopped     1       0.000027           32           3 0.434970      0.000084    1.0          0.056370     6.913598
#         6  Completed    10       0.000249           32           2 0.333016      0.000032   10.0          0.028542    48.176545
#         7    Stopped     1       0.000053           32           3 0.329358      0.000039    1.0          0.046365     7.015317
#         8    Stopped     1       0.000122           32           4 0.323776      0.000013    1.0          0.040121     7.406115
#         9    Stopped     1       0.000028           32           4 0.364492      0.000076    1.0          0.059389     7.354061
#        10    Stopped     9       0.000490          128           3 0.252469      0.000365    9.0          0.031145    53.648742
#        11  Completed    10       0.000142          128           2 0.421650      0.000034   10.0          0.028091    52.426139
#        12    Stopped     1       0.000052           64           4 0.298591      0.000285    1.0          0.034840     7.656372
#        13    Stopped     1       0.000062           32           2 0.441050      0.000099    1.0          0.042026     6.470841
#        14    Stopped     1       0.000014           64           2 0.395345      0.000118    1.0          0.037610     6.542225
#        15    Stopped     1       0.000075           64           4 0.255351      0.000148    1.0          0.034105     7.578735
#        16    Stopped     1       0.000029           64           2 0.357194      0.000038    1.0          0.036280     6.541768
#        17    Stopped     3       0.000139           32           2 0.261539      0.000074    3.0          0.029177    15.481508
#        18    Stopped     9       0.000060          256           4 0.331981      0.000027    9.0          0.029941   162.710103
#        19    Stopped     1       0.000218          256           2 0.390558      0.000027    1.0          0.034130    13.078133
#        20    Stopped     3       0.000026          256           3 0.389427      0.000043    3.0          0.028665    44.564678
#        21    Stopped     9       0.000219          128           3 0.250661      0.000016    9.0          0.032813    54.307383
#        22    Stopped     9       0.000115          256           3 0.222469      0.000089    9.0          0.032215   127.248277
#        23    Stopped     1       0.000016           32           2 0.349924      0.000337    1.0          0.071970     6.507767
#        24    Stopped     1       0.000267          128           3 0.320071      0.000439    1.0          0.034665     7.815408
#        25    Stopped     9       0.000324          256           3 0.283269      0.000030    9.0          0.032093   128.453471
#        26  Completed    10       0.000029          256           2 0.291938      0.000017   10.0          0.026543   110.699670
#        27    Stopped     1       0.000247           64           4 0.204256      0.000025    1.0          0.030625     7.701478
#        28    Stopped     3       0.000022          256           3 0.272778      0.000385    3.0          0.029136    44.713332
#        29 InProgress     0       0.000028          128           3 0.319608      0.000024      -                 -            -
# 1 trials running, 29 finished (5 until the end), 1362.46s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:19:30] 🚀 Trial 30 started - config: learning_rate=1.4618336638166007e-05, num_hiddens=64, num_layers=3, dropout=0.2613364681828928, weight_decay=1.1444355775695314e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🎉🎉🎉 HYPERPARAMETER OPTIMIZATION COMPLETE!
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# --------------------
# Resource summary (last result is reported):
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0
PO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
oxygen_hpo_results_path = Path("/content/CUNSEY BECK_DS NEAR SAWREY_E_202303_oxygen_hpo_results.csv")

# Save the DataFrame to a csv file
oxygen_results.to_csv(oxygen_hpo_results_path, index=True)

# %% [markdown]
# ## 13. Define the Config Space, Scheduler, and Tune Function for Temperature HPO

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on temperature_t_96 targets
def temperature_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Create the path to the directory containing the data in the Jupyter notebook environment
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/windermere_inflows_and_outflow/cunsey_beck/CUNSEY%20BECK_DS%20NEAR%20SAWREY_E_202303/CUNSEY%20BECK_DS%20NEAR%20SAWREY_E_202303_preprocessed_data.zip")
    # Assign the full filepath for the preprocessed data
    parameter_path = "/content" / data_path / "CUNSEY BECK_DS NEAR SAWREY_E_202303_preprocessed_data.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "temperature"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ##14. Initialise and Run the Tuner for Temperature HPO

# %%
# Instruct the searcher to run each trial as a Python function
temperature_trial_backend = PythonBackend(
    tune_function=temperature_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=temperature_trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-26-16-25-24-631
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-26-16-25-24-631
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-26-16-25-24-631
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [16:25:25] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     1        0.00001           64           2      0.2       0.00001      1          0.102713      6.54573
# 1 trials running, 0 finished (0 until the end), 20.03s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     6        0.00001           64           2      0.2       0.00001      6          0.035445     29.55945
# 1 trials running, 0 finished (0 until the end), 40.05s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:26:20] ✅ Trial 0 completed!
# [16:26:20] 🚀 Trial 1 started - config: learning_rate=1.0350108737309358e-05, num_hiddens=32, num_layers=4, dropout=0.31995193108608727, weight_decay=2.836143864566013e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10        0.00001           64           2 0.200000      0.000010   10.0          0.033978    48.082882
#         1 InProgress     0        0.00001           32           4 0.319952      0.000028      -                 -            -
# 1 trials running, 1 finished (1 until the end), 60.07s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:26:35] 🚀 Trial 2 started - config: learning_rate=7.260896642989395e-05, num_hiddens=32, num_layers=4, dropout=0.3011490109447933, weight_decay=3.639429324326611e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028    1.0          0.174975     7.377751
#         2 InProgress     0       0.000073           32           4 0.301149      0.000036      -                 -            -
# 1 trials running, 2 finished (1 until the end), 80.10s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028      1          0.174975     7.377751
#         2 InProgress     3       0.000073           32           4 0.301149      0.000036      3          0.036523    18.189350
# 1 trials running, 2 finished (1 until the end), 100.12s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028      1          0.174975     7.377751
#         2 InProgress     7       0.000073           32           4 0.301149      0.000036      7          0.034782    39.762409
# 1 trials running, 2 finished (1 until the end), 120.15s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:27:40] ✅ Trial 2 completed!
# [16:27:40] 🚀 Trial 3 started - config: learning_rate=1.2184188050572278e-05, num_hiddens=64, num_layers=3, dropout=0.3860170675274126, weight_decay=2.4520266377894215e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028    1.0          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036   10.0          0.034803    56.063369
#         3 InProgress     0       0.000012           64           3 0.386017      0.000025      -                 -            -
# 1 trials running, 3 finished (2 until the end), 140.18s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028      1          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036     10          0.034803    56.063369
#         3 InProgress     2       0.000012           64           3 0.386017      0.000025      2          0.040976    12.337558
# 1 trials running, 3 finished (2 until the end), 160.20s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:28:05] 🚀 Trial 4 started - config: learning_rate=1.7342076599795687e-05, num_hiddens=32, num_layers=2, dropout=0.47721214910116966, weight_decay=3.8272167172525343e-05
# [16:28:20] 🚀 Trial 5 started - config: learning_rate=5.5721259153812604e-05, num_hiddens=32, num_layers=3, dropout=0.3823576381769095, weight_decay=0.00010297703232307427
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028    1.0          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036   10.0          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025    3.0          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038    1.0          0.127347     6.549432
#         5 InProgress     0       0.000056           32           3 0.382358      0.000103      -                 -            -
# 1 trials running, 5 finished (2 until the end), 180.22s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028      1          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036     10          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025      3          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038      1          0.127347     6.549432
#         5 InProgress     2       0.000056           32           3 0.382358      0.000103      2          0.038517    11.943028
# 1 trials running, 5 finished (2 until the end), 200.24s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:28:45] 🚀 Trial 6 started - config: learning_rate=0.000226542283345976, num_hiddens=256, num_layers=4, dropout=0.2122716876931092, weight_decay=0.00010421516281553019
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028    1.0          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036   10.0          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025    3.0          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038    1.0          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103    3.0          0.037634    16.824655
#         6 InProgress     0       0.000227          256           4 0.212272      0.000104      -                 -            -
# 1 trials running, 6 finished (2 until the end), 220.25s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028      1          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036     10          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025      3          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038      1          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103      3          0.037634    16.824655
#         6 InProgress     1       0.000227          256           4 0.212272      0.000104      1          0.035423    20.678449
# 1 trials running, 6 finished (2 until the end), 240.28s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028      1          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036     10          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025      3          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038      1          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103      3          0.037634    16.824655
#         6 InProgress     2       0.000227          256           4 0.212272      0.000104      2          0.039157    38.133907
# 1 trials running, 6 finished (2 until the end), 260.30s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028      1          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036     10          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025      3          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038      1          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103      3          0.037634    16.824655
#         6 InProgress     3       0.000227          256           4 0.212272      0.000104      3          0.033005    55.413035
# 1 trials running, 6 finished (2 until the end), 280.32s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028      1          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036     10          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025      3          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038      1          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103      3          0.037634    16.824655
#         6 InProgress     5       0.000227          256           4 0.212272      0.000104      5          0.033611    90.027140
# 1 trials running, 6 finished (2 until the end), 300.36s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028      1          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036     10          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025      3          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038      1          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103      3          0.037634    16.824655
#         6 InProgress     6       0.000227          256           4 0.212272      0.000104      6          0.031861   107.590453
# 1 trials running, 6 finished (2 until the end), 320.38s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028      1          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036     10          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025      3          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038      1          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103      3          0.037634    16.824655
#         6 InProgress     7       0.000227          256           4 0.212272      0.000104      7          0.034646   124.973513
# 1 trials running, 6 finished (2 until the end), 340.40s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028      1          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036     10          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025      3          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038      1          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103      3          0.037634    16.824655
#         6 InProgress     8       0.000227          256           4 0.212272      0.000104      8          0.034100   142.336671
# 1 trials running, 6 finished (2 until the end), 360.43s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:31:30] 🚀 Trial 7 started - config: learning_rate=0.00018401345722167056, num_hiddens=32, num_layers=4, dropout=0.3644149605461725, weight_decay=3.660661585834342e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028    1.0          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036   10.0          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025    3.0          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038    1.0          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103    3.0          0.037634    16.824655
#         6    Stopped     9       0.000227          256           4 0.212272      0.000104    9.0          0.034343   159.913586
#         7 InProgress     0       0.000184           32           4 0.364415      0.000037      -                 -            -
# 1 trials running, 7 finished (2 until the end), 380.45s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028      1          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036     10          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025      3          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038      1          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103      3          0.037634    16.824655
#         6    Stopped     9       0.000227          256           4 0.212272      0.000104      9          0.034343   159.913586
#         7 InProgress     4       0.000184           32           4 0.364415      0.000037      4          0.033730    23.527569
# 1 trials running, 7 finished (2 until the end), 400.50s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028      1          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036     10          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025      3          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038      1          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103      3          0.037634    16.824655
#         6    Stopped     9       0.000227          256           4 0.212272      0.000104      9          0.034343   159.913586
#         7 InProgress     8       0.000184           32           4 0.364415      0.000037      8          0.032930    45.139914
# 1 trials running, 7 finished (2 until the end), 420.52s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:32:36] ✅ Trial 7 completed!
# [16:32:36] 🚀 Trial 8 started - config: learning_rate=0.00042905389415589867, num_hiddens=64, num_layers=4, dropout=0.27304509291769585, weight_decay=3.077612158858165e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028    1.0          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036   10.0          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025    3.0          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038    1.0          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103    3.0          0.037634    16.824655
#         6    Stopped     9       0.000227          256           4 0.212272      0.000104    9.0          0.034343   159.913586
#         7  Completed    10       0.000184           32           4 0.364415      0.000037   10.0          0.032781    56.027315
#         8 InProgress     0       0.000429           64           4 0.273045      0.000031      -                 -            -
# 1 trials running, 8 finished (3 until the end), 440.55s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028      1          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036     10          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025      3          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038      1          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103      3          0.037634    16.824655
#         6    Stopped     9       0.000227          256           4 0.212272      0.000104      9          0.034343   159.913586
#         7  Completed    10       0.000184           32           4 0.364415      0.000037     10          0.032781    56.027315
#         8 InProgress     3       0.000429           64           4 0.273045      0.000031      3          0.033672    19.162081
# 1 trials running, 8 finished (3 until the end), 460.58s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028      1          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036     10          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025      3          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038      1          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103      3          0.037634    16.824655
#         6    Stopped     9       0.000227          256           4 0.212272      0.000104      9          0.034343   159.913586
#         7  Completed    10       0.000184           32           4 0.364415      0.000037     10          0.032781    56.027315
#         8 InProgress     6       0.000429           64           4 0.273045      0.000031      6          0.033451    36.270850
# 1 trials running, 8 finished (3 until the end), 480.63s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:33:41] ✅ Trial 8 completed!
# [16:33:41] 🚀 Trial 9 started - config: learning_rate=8.136800972476e-05, num_hiddens=64, num_layers=4, dropout=0.41459286171716725, weight_decay=0.00016889001593303453
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028    1.0          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036   10.0          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025    3.0          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038    1.0          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103    3.0          0.037634    16.824655
#         6    Stopped     9       0.000227          256           4 0.212272      0.000104    9.0          0.034343   159.913586
#         7  Completed    10       0.000184           32           4 0.364415      0.000037   10.0          0.032781    56.027315
#         8  Completed    10       0.000429           64           4 0.273045      0.000031   10.0          0.031449    58.803858
#         9 InProgress     0       0.000081           64           4 0.414593      0.000169      -                 -            -
# 1 trials running, 9 finished (4 until the end), 500.66s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:33:56] 🚀 Trial 10 started - config: learning_rate=1.1418166178495248e-05, num_hiddens=64, num_layers=3, dropout=0.35568775259667973, weight_decay=0.00042326918068517064
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028    1.0          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036   10.0          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025    3.0          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038    1.0          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103    3.0          0.037634    16.824655
#         6    Stopped     9       0.000227          256           4 0.212272      0.000104    9.0          0.034343   159.913586
#         7  Completed    10       0.000184           32           4 0.364415      0.000037   10.0          0.032781    56.027315
#         8  Completed    10       0.000429           64           4 0.273045      0.000031   10.0          0.031449    58.803858
#         9    Stopped     1       0.000081           64           4 0.414593      0.000169    1.0          0.041498     7.678205
#        10 InProgress     0       0.000011           64           3 0.355688      0.000423      -                 -            -
# 1 trials running, 10 finished (4 until the end), 520.69s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:34:11] 🚀 Trial 11 started - config: learning_rate=7.981098067657397e-05, num_hiddens=32, num_layers=3, dropout=0.23083696031191195, weight_decay=8.992007863402046e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028    1.0          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036   10.0          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025    3.0          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038    1.0          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103    3.0          0.037634    16.824655
#         6    Stopped     9       0.000227          256           4 0.212272      0.000104    9.0          0.034343   159.913586
#         7  Completed    10       0.000184           32           4 0.364415      0.000037   10.0          0.032781    56.027315
#         8  Completed    10       0.000429           64           4 0.273045      0.000031   10.0          0.031449    58.803858
#         9    Stopped     1       0.000081           64           4 0.414593      0.000169    1.0          0.041498     7.678205
#        10    Stopped     1       0.000011           64           3 0.355688      0.000423    1.0          0.060190     7.209464
#        11 InProgress     0       0.000080           32           3 0.230837      0.000090      -                 -            -
# 1 trials running, 11 finished (4 until the end), 540.72s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:34:36] 🚀 Trial 12 started - config: learning_rate=1.2449776788072332e-05, num_hiddens=128, num_layers=4, dropout=0.35302074820676804, weight_decay=0.0003369982571649086
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028    1.0          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036   10.0          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025    3.0          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038    1.0          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103    3.0          0.037634    16.824655
#         6    Stopped     9       0.000227          256           4 0.212272      0.000104    9.0          0.034343   159.913586
#         7  Completed    10       0.000184           32           4 0.364415      0.000037   10.0          0.032781    56.027315
#         8  Completed    10       0.000429           64           4 0.273045      0.000031   10.0          0.031449    58.803858
#         9    Stopped     1       0.000081           64           4 0.414593      0.000169    1.0          0.041498     7.678205
#        10    Stopped     1       0.000011           64           3 0.355688      0.000423    1.0          0.060190     7.209464
#        11    Stopped     3       0.000080           32           3 0.230837      0.000090    3.0          0.036417    16.745009
#        12 InProgress     0       0.000012          128           4 0.353021      0.000337      -                 -            -
# 1 trials running, 12 finished (4 until the end), 560.75s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028      1          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036     10          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025      3          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038      1          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103      3          0.037634    16.824655
#         6    Stopped     9       0.000227          256           4 0.212272      0.000104      9          0.034343   159.913586
#         7  Completed    10       0.000184           32           4 0.364415      0.000037     10          0.032781    56.027315
#         8  Completed    10       0.000429           64           4 0.273045      0.000031     10          0.031449    58.803858
#         9    Stopped     1       0.000081           64           4 0.414593      0.000169      1          0.041498     7.678205
#        10    Stopped     1       0.000011           64           3 0.355688      0.000423      1          0.060190     7.209464
#        11    Stopped     3       0.000080           32           3 0.230837      0.000090      3          0.036417    16.745009
#        12 InProgress     2       0.000012          128           4 0.353021      0.000337      2          0.036673    15.370757
# 1 trials running, 12 finished (4 until the end), 580.78s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:35:06] 🚀 Trial 13 started - config: learning_rate=1.3828372188306357e-05, num_hiddens=32, num_layers=4, dropout=0.28791232583476145, weight_decay=0.00011973656559425139
# [16:35:21] 🚀 Trial 14 started - config: learning_rate=1.4592298281915693e-05, num_hiddens=128, num_layers=4, dropout=0.35393600465013486, weight_decay=2.3451703358714963e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028    1.0          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036   10.0          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025    3.0          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038    1.0          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103    3.0          0.037634    16.824655
#         6    Stopped     9       0.000227          256           4 0.212272      0.000104    9.0          0.034343   159.913586
#         7  Completed    10       0.000184           32           4 0.364415      0.000037   10.0          0.032781    56.027315
#         8  Completed    10       0.000429           64           4 0.273045      0.000031   10.0          0.031449    58.803858
#         9    Stopped     1       0.000081           64           4 0.414593      0.000169    1.0          0.041498     7.678205
#        10    Stopped     1       0.000011           64           3 0.355688      0.000423    1.0          0.060190     7.209464
#        11    Stopped     3       0.000080           32           3 0.230837      0.000090    3.0          0.036417    16.745009
#        12    Stopped     3       0.000012          128           4 0.353021      0.000337    3.0          0.037799    21.808261
#        13    Stopped     1       0.000014           32           4 0.287912      0.000120    1.0          0.173007     7.337501
#        14 InProgress     0       0.000015          128           4 0.353936      0.000023      -                 -            -
# 1 trials running, 14 finished (4 until the end), 600.83s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:35:36] 🚀 Trial 15 started - config: learning_rate=2.4835172348106163e-05, num_hiddens=256, num_layers=4, dropout=0.46827381213449215, weight_decay=5.533159500993202e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028    1.0          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036   10.0          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025    3.0          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038    1.0          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103    3.0          0.037634    16.824655
#         6    Stopped     9       0.000227          256           4 0.212272      0.000104    9.0          0.034343   159.913586
#         7  Completed    10       0.000184           32           4 0.364415      0.000037   10.0          0.032781    56.027315
#         8  Completed    10       0.000429           64           4 0.273045      0.000031   10.0          0.031449    58.803858
#         9    Stopped     1       0.000081           64           4 0.414593      0.000169    1.0          0.041498     7.678205
#        10    Stopped     1       0.000011           64           3 0.355688      0.000423    1.0          0.060190     7.209464
#        11    Stopped     3       0.000080           32           3 0.230837      0.000090    3.0          0.036417    16.745009
#        12    Stopped     3       0.000012          128           4 0.353021      0.000337    3.0          0.037799    21.808261
#        13    Stopped     1       0.000014           32           4 0.287912      0.000120    1.0          0.173007     7.337501
#        14    Stopped     1       0.000015          128           4 0.353936      0.000023    1.0          0.042382     8.700863
#        15 InProgress     0       0.000025          256           4 0.468274      0.000055      -                 -            -
# 1 trials running, 15 finished (4 until the end), 620.86s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028      1          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036     10          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025      3          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038      1          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103      3          0.037634    16.824655
#         6    Stopped     9       0.000227          256           4 0.212272      0.000104      9          0.034343   159.913586
#         7  Completed    10       0.000184           32           4 0.364415      0.000037     10          0.032781    56.027315
#         8  Completed    10       0.000429           64           4 0.273045      0.000031     10          0.031449    58.803858
#         9    Stopped     1       0.000081           64           4 0.414593      0.000169      1          0.041498     7.678205
#        10    Stopped     1       0.000011           64           3 0.355688      0.000423      1          0.060190     7.209464
#        11    Stopped     3       0.000080           32           3 0.230837      0.000090      3          0.036417    16.745009
#        12    Stopped     3       0.000012          128           4 0.353021      0.000337      3          0.037799    21.808261
#        13    Stopped     1       0.000014           32           4 0.287912      0.000120      1          0.173007     7.337501
#        14    Stopped     1       0.000015          128           4 0.353936      0.000023      1          0.042382     8.700863
#        15 InProgress     1       0.000025          256           4 0.468274      0.000055      1          0.037969    20.755986
# 1 trials running, 15 finished (4 until the end), 640.89s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:52:13] 🚀 Trial 29 started - config: learning_rate=8.885039378042712e-05, num_hiddens=128, num_layers=2, dropout=0.42026758853156726, weight_decay=5.893616862010094e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028    1.0          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036   10.0          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025    3.0          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038    1.0          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103    3.0          0.037634    16.824655
#         6    Stopped     9       0.000227          256           4 0.212272      0.000104    9.0          0.034343   159.913586
#         7  Completed    10       0.000184           32           4 0.364415      0.000037   10.0          0.032781    56.027315
#         8  Completed    10       0.000429           64           4 0.273045      0.000031   10.0          0.031449    58.803858
#         9    Stopped     1       0.000081           64           4 0.414593      0.000169    1.0          0.041498     7.678205
#        10    Stopped     1       0.000011           64           3 0.355688      0.000423    1.0          0.060190     7.209464
#        11    Stopped     3       0.000080           32           3 0.230837      0.000090    3.0          0.036417    16.745009
#        12    Stopped     3       0.000012          128           4 0.353021      0.000337    3.0          0.037799    21.808261
#        13    Stopped     1       0.000014           32           4 0.287912      0.000120    1.0          0.173007     7.337501
#        14    Stopped     1       0.000015          128           4 0.353936      0.000023    1.0          0.042382     8.700863
#        15  Completed    10       0.000025          256           4 0.468274      0.000055   10.0          0.035176   178.011983
#        16    Stopped     1       0.000067           64           4 0.406729      0.000014    1.0          0.044811     7.688656
#        17    Stopped     9       0.000217           32           4 0.453657      0.000286    9.0          0.035104    50.437911
#        18  Completed    10       0.000196          256           2 0.319833      0.000209   10.0          0.031545   108.155800
#        19  Completed    10       0.000101          128           2 0.408319      0.000034   10.0          0.032695    53.183789
#        20    Stopped     1       0.000092           32           4 0.316379      0.000097    1.0          0.041698     7.314787
#        21  Completed    10       0.000178          128           2 0.279604      0.000037   10.0          0.032064    52.440493
#        22    Stopped     3       0.000026          256           4 0.248476      0.000292    3.0          0.034981    55.537053
#        23    Stopped     1       0.000073           32           3 0.345363      0.000043    1.0          0.039930     6.882348
#        24  Completed    10       0.000105          256           2 0.229460      0.000056   10.0          0.030651   107.944198
#        25  Completed    10       0.000013          256           3 0.312406      0.000129   10.0          0.032374   143.961921
#        26    Stopped     3       0.000021          256           4 0.298602      0.000449    3.0          0.035276    55.449237
#        27    Stopped     3       0.000023          256           4 0.424108      0.000015    3.0          0.036562    55.176533
#        28    Stopped     1       0.000269          256           4 0.398530      0.000300    1.0          0.038163    20.541981
#        29 InProgress     0       0.000089          128           2 0.420268      0.000059      -                 -            -
# 1 trials running, 29 finished (10 until the end), 1623.00s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:52:28] 🚀 Trial 30 started - config: learning_rate=2.9620360160531293e-05, num_hiddens=256, num_layers=4, dropout=0.38526758841472475, weight_decay=1.342482824955424e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🎉🎉🎉 HYPERPARAMETER OPTIMIZATION COMPLETE!
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# --------------------
# Resource summary (last result is reported):
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.033978    48.082882
#         1    Stopped     1       0.000010           32           4 0.319952      0.000028    1.0          0.174975     7.377751
#         2  Completed    10       0.000073           32           4 0.301149      0.000036   10.0          0.034803    56.063369
#         3    Stopped     3       0.000012           64           3 0.386017      0.000025    3.0          0.038587    17.458068
#         4    Stopped     1       0.000017           32           2 0.477212      0.000038    1.0          0.127347     6.549432
#         5    Stopped     3       0.000056           32           3 0.382358      0.000103    3.0          0.037634    16.824655
#         6    Stopped     9       0.000227          256           4 0.212272      0.000104    9.0          0.034343   159.913586
#         7  Completed    10       0.000184           32           4 0.364415      0.000037   10.0          0.032781    56.027315
#         8  Completed    10       0.000429           64           4 0.273045      0.000031   10.0          0.031449    58.803858
#         9    Stopped     1       0.000081           64           4 0.414593      0.000169    1.0          0.041498     7.678205
#        10    Stopped     1       0.000011           64           3 0.355688      0.000423    1.0          0.060190     7.209464
#        11    Stopped     3       0.000080           32           3 0.230837      0.000090    3.0          0.036417    16.745009
#        12    Stopped     3       0.000012          128           4 0.353021      0.000337    3.0          0.037799    21.808261
#        13    Stopped     1       0.000014           32           4 0.287912      0.000120    1.0          0.173007     7.337501
#        14    Stopped     1       0.000015          128           4 0.353936      0.000023    1.0          0.042382     8.700863
#        15  Completed    10       0.000025          256           4 0.468274      0.000055   10.0          0.035176   178.011983
#        16    Stopped     1       0.000067           64           4 0.406729      0.000014    1.0          0.044811     7.688656
#        17    Stopped     9       0.000217           32           4 0.453657      0.000286    9.0          0.035104    50.437911
#        18  Completed    10       0.000196          256           2 0.319833      0.000209   10.0          0.031545   108.155800
#        19  Completed    10       0.000101          128           2 0.408319      0.000034   10.0          0.032695    53.183789
#        20    Stopped     1       0.000092           32           4 0.316379      0.000097    1.0          0.041698     7.314787
#        21  Completed    10       0.000178          128           2 0.279604      0.000037   10.0          0.032064    52.440493
#        22    Stopped     3       0.000026          256           4 0.248476      0.000292    3.0          0.034981    55.537053
#        23    Stopped     1       0.000073           32           3 0.345363      0.000043    1.0          0.039930     6.882348
#        24  Completed    10       0.000105          256           2 0.229460      0.000056   10.0          0.030651   107.944198
#        25  Completed    10       0.000013          256           3 0.312406      0.000129   10.0          0.032374   143.961921
#        26    Stopped     3       0.000021          256           4 0.298602      0.000449    3.0          0.035276    55.449237
#        27    Stopped     3       0.000023          256           4 0.424108      0.000015    3.0          0.036562    55.176533
#        28    Stopped     1       0.000269          256           4 0.398530      0.000300    1.0          0.038163    20.541981
#        29    Stopped     1       0.000089          128           2 0.420268      0.000059    1.0          0.038430     7.104233
#        30 InProgress     0       0.000030          256           4 0.385268      0.000013      -                 -            -
# 1 trials running, 30 finished (10 until the end), 1623.04s wallclock-time
#
# validation_error: best 0.030035536736249924 for trial-id 24
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-26-16-25-24-631
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-26-16-25-24-631
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##15. Load Results from Temperature HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
temperature_results_path = "/root/syne-tune/python-entrypoint-2026-03-26-16-25-24-631/results.csv.zip"

# Save the results to a Pandas DataFrame
temperature_results = pd.read_csv(temperature_results_path)

# %% [markdown]
# ##16. Save the Temperature HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
temperature_hpo_results_path = Path("/content/CUNSEY BECK_DS NEAR SAWREY_E_202303_temperature_hpo_results.csv")

# Save the DataFrame to a csv file
temperature_results.to_csv(temperature_hpo_results_path, index=True)
