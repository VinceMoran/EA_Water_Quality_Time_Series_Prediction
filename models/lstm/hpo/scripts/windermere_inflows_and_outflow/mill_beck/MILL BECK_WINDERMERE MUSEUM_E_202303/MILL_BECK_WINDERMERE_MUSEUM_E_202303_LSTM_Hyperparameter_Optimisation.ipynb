# %% [markdown]
# # Station Information
#
# * Station name: MILL BECK_WINDERMERE MUSEUM_E_202303
# * Water Quality Data link: https://environment.data.gov.uk/hydrology/station/E04592A

# %% [markdown]
# ## 0. Import the Relevant Libraries

# %%
# Force installation of Syne-Tune and a compatible NumPy version (may require restarting the session after running this cell before running below import cell)
# !pip install numpy==1.26.1 syne_tune --force-reinstall -q # ignore potential error messages if listed dependencies do not match imports
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 114.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.3/254.3 kB 28.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 138.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 146.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 147.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/131.7 MB 20.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 34.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 28.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 27.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 76.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.6/293.6 MB 3.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.1 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.1 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# datasets 4.0.0 requires dill<0.3.9,>=0.3.0, but you have dill 0.4.1 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.1 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.1 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.1 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.1 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# torch 2.10.0+cu128 requires nvidia-nccl-cu12==2.27.5; platform_system == "Linux", but you have nvidia-nccl-cu12 2.29.7 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.1 which is incompatible.
# music21 9.9.1 requires numpy>=1.26.4, but you have numpy 1.26.1 which is incompatible.

# %%
# Import relevant libraries (Note: May require running of above cell to ensure compatibility of NumPy and Syne-Tune)
import torch
import logging
logging.basicConfig(level=logging.INFO)
import numpy as np
import matplotlib.pyplot as plt
from syne_tune import StoppingCriterion, Tuner
from syne_tune.backend.python_backend.python_backend import PythonBackend
from syne_tune.config_space import loguniform, randint, choice, uniform
from syne_tune.experiments import load_experiment
from syne_tune.optimizer.baselines import ASHA
import pandas as pd
from pathlib import Path

# %% [markdown]
# ##1. Specify Epoch Ranges and Reduction Factor for Hyperparameter Optimisation (HPO)

# %%
# Specify the minimum and maximum number of epochs for which a trial is allowed to run during HPO
min_number_of_epochs = 2
max_number_of_epochs = 10

# Define the reduction factor for the Asynchronous Successive Halving Algorithm (ASHA)
eta = 2 # Set to 2 so that 50% of trials are stopped at each rung of the scheduler

# %% [markdown]
# ##2. Define the Tune Function to Optimise Hyperparameters for Ammonium Prediction

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on ammonium_t_96 targets
def ammonium_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Create the path to the directory containing the data in the Jupyter notebook environment
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/windermere_inflows_and_outflow/mill_beck/MILL%20BECK_WINDERMERE%20MUSEUM_E_202303/MILL%20BECK_WINDERMERE%20MUSEUM_E_202303_preprocessed_data.zip")
    # Assign the full filepath for the preprocessed data
    parameter_path = "/content" / data_path / "MILL BECK_WINDERMERE MUSEUM_E_202303_preprocessed_data.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "ammonium"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ## 3. Define the Configuration Space for Hyperparameter Search

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %% [markdown]
# ##4. Define the Resources Available for HPO

# %%
# Define the number of parallel workers available to evaluate trials concurrently
n_workers = max(1, torch.cuda.device_count()) # Uses all available GPUs for parallel trials or defaults to 1 worker if running on CPU

# Define the maximum number of trials to test
max_number_of_trials = 30

# Define the stopping criterion for HPO
stop_criterion = StoppingCriterion(max_num_trials_started=max_number_of_trials)

# %% [markdown]
# ##5. Define Asynchronous Successive Halving Algorithm (ASHA) for HPO

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %% [markdown]
# ##6. Initialise and Run the Tuner for Ammonium HPO

# %%
# Instruct the searcher to run each trial as a Python function
trial_backend = PythonBackend(
    tune_function=ammonium_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-25-09-21-20-457
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-25-09-21-20-457
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-25-09-21-20-457
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [09:21:21] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     1        0.00001           64           2      0.2       0.00001      1          0.010229     9.047409
# 1 trials running, 0 finished (0 until the end), 20.14s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     8        0.00001           64           2      0.2       0.00001      8          0.008339    29.171175
# 1 trials running, 0 finished (0 until the end), 40.15s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:22:01] 🚀 Trial 1 started - config: learning_rate=1.8525548342128153e-05, num_hiddens=128, num_layers=4, dropout=0.3692474685661976, weight_decay=5.789723423077211e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.008968    35.157416
#         1 InProgress     2       0.000019          128           4 0.369247      0.000058      2          0.008160     9.825502
# 1 trials running, 1 finished (0 until the end), 60.17s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.008968    35.157416
#         1 InProgress     7       0.000019          128           4 0.369247      0.000058      7          0.006467    29.603959
# 1 trials running, 1 finished (0 until the end), 80.19s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:22:51] ✅ Trial 1 completed!
# [09:22:51] 🚀 Trial 2 started - config: learning_rate=0.0002252575632973721, num_hiddens=32, num_layers=4, dropout=0.43525609049810254, weight_decay=9.35230818789723e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.008968    35.157416
#         1  Completed    10       0.000019          128           4 0.369247      0.000058   10.0          0.006316    41.747530
#         2 InProgress     0       0.000225           32           4 0.435256      0.000094      -                 -            -
# 1 trials running, 2 finished (1 until the end), 100.21s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.008968    35.157416
#         1  Completed    10       0.000019          128           4 0.369247      0.000058     10          0.006316    41.747530
#         2 InProgress     5       0.000225           32           4 0.435256      0.000094      5          0.006378    18.001976
# 1 trials running, 2 finished (1 until the end), 120.24s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:23:31] ✅ Trial 2 completed!
# [09:23:31] 🚀 Trial 3 started - config: learning_rate=6.545142899518495e-05, num_hiddens=256, num_layers=4, dropout=0.23707249032736025, weight_decay=0.0002876382097427086
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.008968    35.157416
#         1  Completed    10       0.000019          128           4 0.369247      0.000058   10.0          0.006316    41.747530
#         2  Completed    10       0.000225           32           4 0.435256      0.000094   10.0          0.005624    34.413182
#         3 InProgress     0       0.000065          256           4 0.237072      0.000288      -                 -            -
# 1 trials running, 3 finished (2 until the end), 140.27s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:23:51] 🚀 Trial 4 started - config: learning_rate=8.689278523400666e-05, num_hiddens=256, num_layers=2, dropout=0.36538187832586067, weight_decay=0.00034204868177323
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.008968    35.157416
#         1  Completed    10       0.000019          128           4 0.369247      0.000058   10.0          0.006316    41.747530
#         2  Completed    10       0.000225           32           4 0.435256      0.000094   10.0          0.005624    34.413182
#         3    Stopped     1       0.000065          256           4 0.237072      0.000288    1.0          0.006775    12.978301
#         4 InProgress     0       0.000087          256           2 0.365382      0.000342      -                 -            -
# 1 trials running, 4 finished (2 until the end), 160.29s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:24:06] 🚀 Trial 5 started - config: learning_rate=1.0020910251007075e-05, num_hiddens=32, num_layers=3, dropout=0.28956615400208147, weight_decay=7.96079335609337e-05
# [09:24:16] 🚀 Trial 6 started - config: learning_rate=1.420226391357562e-05, num_hiddens=64, num_layers=3, dropout=0.32699503025391136, weight_decay=0.00016383540929916325
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.008968    35.157416
#         1  Completed    10       0.000019          128           4 0.369247      0.000058   10.0          0.006316    41.747530
#         2  Completed    10       0.000225           32           4 0.435256      0.000094   10.0          0.005624    34.413182
#         3    Stopped     1       0.000065          256           4 0.237072      0.000288    1.0          0.006775    12.978301
#         4    Stopped     1       0.000087          256           2 0.365382      0.000342    1.0          0.009583     8.498954
#         5    Stopped     1       0.000010           32           3 0.289566      0.000080    1.0          0.006809     4.699804
#         6 InProgress     0       0.000014           64           3 0.326995      0.000164      -                 -            -
# 1 trials running, 6 finished (2 until the end), 180.31s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:24:26] 🚀 Trial 7 started - config: learning_rate=5.2598905400835204e-05, num_hiddens=32, num_layers=3, dropout=0.3627414445250321, weight_decay=8.524853888094203e-05
# [09:24:36] 🚀 Trial 8 started - config: learning_rate=0.00013300886864396912, num_hiddens=128, num_layers=2, dropout=0.48703429796339837, weight_decay=5.342788317528066e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.008968    35.157416
#         1  Completed    10       0.000019          128           4 0.369247      0.000058   10.0          0.006316    41.747530
#         2  Completed    10       0.000225           32           4 0.435256      0.000094   10.0          0.005624    34.413182
#         3    Stopped     1       0.000065          256           4 0.237072      0.000288    1.0          0.006775    12.978301
#         4    Stopped     1       0.000087          256           2 0.365382      0.000342    1.0          0.009583     8.498954
#         5    Stopped     1       0.000010           32           3 0.289566      0.000080    1.0          0.006809     4.699804
#         6    Stopped     1       0.000014           64           3 0.326995      0.000164    1.0          0.007016     4.850300
#         7    Stopped     1       0.000053           32           3 0.362741      0.000085    1.0          0.008419     4.735730
#         8 InProgress     0       0.000133          128           2 0.487034      0.000053      -                 -            -
# 1 trials running, 8 finished (2 until the end), 200.34s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:24:46] 🚀 Trial 9 started - config: learning_rate=0.0004092391782664698, num_hiddens=128, num_layers=3, dropout=0.38919853591485243, weight_decay=0.000263748501123832
# [09:24:56] 🚀 Trial 10 started - config: learning_rate=7.390886865363269e-05, num_hiddens=32, num_layers=2, dropout=0.20979442663334874, weight_decay=1.2686082604070883e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.008968    35.157416
#         1  Completed    10       0.000019          128           4 0.369247      0.000058   10.0          0.006316    41.747530
#         2  Completed    10       0.000225           32           4 0.435256      0.000094   10.0          0.005624    34.413182
#         3    Stopped     1       0.000065          256           4 0.237072      0.000288    1.0          0.006775    12.978301
#         4    Stopped     1       0.000087          256           2 0.365382      0.000342    1.0          0.009583     8.498954
#         5    Stopped     1       0.000010           32           3 0.289566      0.000080    1.0          0.006809     4.699804
#         6    Stopped     1       0.000014           64           3 0.326995      0.000164    1.0          0.007016     4.850300
#         7    Stopped     1       0.000053           32           3 0.362741      0.000085    1.0          0.008419     4.735730
#         8    Stopped     1       0.000133          128           2 0.487034      0.000053    1.0          0.009696     4.866275
#         9    Stopped     1       0.000409          128           3 0.389199      0.000264    1.0          0.007480     5.402229
#        10 InProgress     0       0.000074           32           2 0.209794      0.000013      -                 -            -
# 1 trials running, 10 finished (2 until the end), 220.37s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:25:06] 🚀 Trial 11 started - config: learning_rate=1.556045414285318e-05, num_hiddens=256, num_layers=4, dropout=0.4161044236882719, weight_decay=4.937891407848338e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.008968    35.157416
#         1  Completed    10       0.000019          128           4 0.369247      0.000058   10.0          0.006316    41.747530
#         2  Completed    10       0.000225           32           4 0.435256      0.000094   10.0          0.005624    34.413182
#         3    Stopped     1       0.000065          256           4 0.237072      0.000288    1.0          0.006775    12.978301
#         4    Stopped     1       0.000087          256           2 0.365382      0.000342    1.0          0.009583     8.498954
#         5    Stopped     1       0.000010           32           3 0.289566      0.000080    1.0          0.006809     4.699804
#         6    Stopped     1       0.000014           64           3 0.326995      0.000164    1.0          0.007016     4.850300
#         7    Stopped     1       0.000053           32           3 0.362741      0.000085    1.0          0.008419     4.735730
#         8    Stopped     1       0.000133          128           2 0.487034      0.000053    1.0          0.009696     4.866275
#         9    Stopped     1       0.000409          128           3 0.389199      0.000264    1.0          0.007480     5.402229
#        10    Stopped     1       0.000074           32           2 0.209794      0.000013    1.0          0.008567     4.594557
#        11 InProgress     0       0.000016          256           4 0.416104      0.000049      -                 -            -
# 1 trials running, 11 finished (2 until the end), 240.39s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:25:26] 🚀 Trial 12 started - config: learning_rate=0.000456145486613637, num_hiddens=256, num_layers=2, dropout=0.4394250304289228, weight_decay=2.7477778072438816e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.008968    35.157416
#         1  Completed    10       0.000019          128           4 0.369247      0.000058   10.0          0.006316    41.747530
#         2  Completed    10       0.000225           32           4 0.435256      0.000094   10.0          0.005624    34.413182
#         3    Stopped     1       0.000065          256           4 0.237072      0.000288    1.0          0.006775    12.978301
#         4    Stopped     1       0.000087          256           2 0.365382      0.000342    1.0          0.009583     8.498954
#         5    Stopped     1       0.000010           32           3 0.289566      0.000080    1.0          0.006809     4.699804
#         6    Stopped     1       0.000014           64           3 0.326995      0.000164    1.0          0.007016     4.850300
#         7    Stopped     1       0.000053           32           3 0.362741      0.000085    1.0          0.008419     4.735730
#         8    Stopped     1       0.000133          128           2 0.487034      0.000053    1.0          0.009696     4.866275
#         9    Stopped     1       0.000409          128           3 0.389199      0.000264    1.0          0.007480     5.402229
#        10    Stopped     1       0.000074           32           2 0.209794      0.000013    1.0          0.008567     4.594557
#        11    Stopped     1       0.000016          256           4 0.416104      0.000049    1.0          0.008078    12.955192
#        12 InProgress     0       0.000456          256           2 0.439425      0.000027      -                 -            -
# 1 trials running, 12 finished (2 until the end), 260.42s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:25:41] 🚀 Trial 13 started - config: learning_rate=1.269828311380157e-05, num_hiddens=32, num_layers=2, dropout=0.36130390840139176, weight_decay=1.9185613920866685e-05
# [09:25:51] 🚀 Trial 14 started - config: learning_rate=1.2906157897028695e-05, num_hiddens=128, num_layers=2, dropout=0.3206724131050221, weight_decay=7.6879420550689e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.008968    35.157416
#         1  Completed    10       0.000019          128           4 0.369247      0.000058   10.0          0.006316    41.747530
#         2  Completed    10       0.000225           32           4 0.435256      0.000094   10.0          0.005624    34.413182
#         3    Stopped     1       0.000065          256           4 0.237072      0.000288    1.0          0.006775    12.978301
#         4    Stopped     1       0.000087          256           2 0.365382      0.000342    1.0          0.009583     8.498954
#         5    Stopped     1       0.000010           32           3 0.289566      0.000080    1.0          0.006809     4.699804
#         6    Stopped     1       0.000014           64           3 0.326995      0.000164    1.0          0.007016     4.850300
#         7    Stopped     1       0.000053           32           3 0.362741      0.000085    1.0          0.008419     4.735730
#         8    Stopped     1       0.000133          128           2 0.487034      0.000053    1.0          0.009696     4.866275
#         9    Stopped     1       0.000409          128           3 0.389199      0.000264    1.0          0.007480     5.402229
#        10    Stopped     1       0.000074           32           2 0.209794      0.000013    1.0          0.008567     4.594557
#        11    Stopped     1       0.000016          256           4 0.416104      0.000049    1.0          0.008078    12.955192
#        12    Stopped     1       0.000456          256           2 0.439425      0.000027    1.0          0.008056     8.664216
#        13    Stopped     1       0.000013           32           2 0.361304      0.000019    1.0          0.007680     4.495850
#        14 InProgress     0       0.000013          128           2 0.320672      0.000077      -                 -            -
# 1 trials running, 14 finished (2 until the end), 280.46s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:26:01] 🚀 Trial 15 started - config: learning_rate=4.631323334939972e-05, num_hiddens=32, num_layers=3, dropout=0.28555606203288797, weight_decay=1.8900451797474627e-05
# [09:26:11] 🚀 Trial 16 started - config: learning_rate=0.00014100281512136907, num_hiddens=32, num_layers=3, dropout=0.4111731241677274, weight_decay=3.839621632245457e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.008968    35.157416
#         1  Completed    10       0.000019          128           4 0.369247      0.000058   10.0          0.006316    41.747530
#         2  Completed    10       0.000225           32           4 0.435256      0.000094   10.0          0.005624    34.413182
#         3    Stopped     1       0.000065          256           4 0.237072      0.000288    1.0          0.006775    12.978301
#         4    Stopped     1       0.000087          256           2 0.365382      0.000342    1.0          0.009583     8.498954
#         5    Stopped     1       0.000010           32           3 0.289566      0.000080    1.0          0.006809     4.699804
#         6    Stopped     1       0.000014           64           3 0.326995      0.000164    1.0          0.007016     4.850300
#         7    Stopped     1       0.000053           32           3 0.362741      0.000085    1.0          0.008419     4.735730
#         8    Stopped     1       0.000133          128           2 0.487034      0.000053    1.0          0.009696     4.866275
#         9    Stopped     1       0.000409          128           3 0.389199      0.000264    1.0          0.007480     5.402229
#        10    Stopped     1       0.000074           32           2 0.209794      0.000013    1.0          0.008567     4.594557
#        11    Stopped     1       0.000016          256           4 0.416104      0.000049    1.0          0.008078    12.955192
#        12    Stopped     1       0.000456          256           2 0.439425      0.000027    1.0          0.008056     8.664216
#        13    Stopped     1       0.000013           32           2 0.361304      0.000019    1.0          0.007680     4.495850
#        14    Stopped     1       0.000013          128           2 0.320672      0.000077    1.0          0.009033     4.771944
#        15    Stopped     1       0.000046           32           3 0.285556      0.000019    1.0          0.009184     4.738597
#        16 InProgress     0       0.000141           32           3 0.411173      0.000038      -                 -            -
# 1 trials running, 16 finished (2 until the end), 300.48s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:26:21] 🚀 Trial 17 started - config: learning_rate=3.6242675617856714e-05, num_hiddens=128, num_layers=4, dropout=0.2537763767637466, weight_decay=1.4324120891582053e-05
# [09:26:31] 🚀 Trial 18 started - config: learning_rate=0.0001335470412535833, num_hiddens=256, num_layers=4, dropout=0.2786302464519385, weight_decay=0.00016082750944594043
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.008968    35.157416
#         1  Completed    10       0.000019          128           4 0.369247      0.000058   10.0          0.006316    41.747530
#         2  Completed    10       0.000225           32           4 0.435256      0.000094   10.0          0.005624    34.413182
#         3    Stopped     1       0.000065          256           4 0.237072      0.000288    1.0          0.006775    12.978301
#         4    Stopped     1       0.000087          256           2 0.365382      0.000342    1.0          0.009583     8.498954
#         5    Stopped     1       0.000010           32           3 0.289566      0.000080    1.0          0.006809     4.699804
#         6    Stopped     1       0.000014           64           3 0.326995      0.000164    1.0          0.007016     4.850300
#         7    Stopped     1       0.000053           32           3 0.362741      0.000085    1.0          0.008419     4.735730
#         8    Stopped     1       0.000133          128           2 0.487034      0.000053    1.0          0.009696     4.866275
#         9    Stopped     1       0.000409          128           3 0.389199      0.000264    1.0          0.007480     5.402229
#        10    Stopped     1       0.000074           32           2 0.209794      0.000013    1.0          0.008567     4.594557
#        11    Stopped     1       0.000016          256           4 0.416104      0.000049    1.0          0.008078    12.955192
#        12    Stopped     1       0.000456          256           2 0.439425      0.000027    1.0          0.008056     8.664216
#        13    Stopped     1       0.000013           32           2 0.361304      0.000019    1.0          0.007680     4.495850
#        14    Stopped     1       0.000013          128           2 0.320672      0.000077    1.0          0.009033     4.771944
#        15    Stopped     1       0.000046           32           3 0.285556      0.000019    1.0          0.009184     4.738597
#        16    Stopped     1       0.000141           32           3 0.411173      0.000038    1.0          0.008712     4.749941
#        17    Stopped     1       0.000036          128           4 0.253776      0.000014    1.0          0.010225     5.873563
#        18 InProgress     0       0.000134          256           4 0.278630      0.000161      -                 -            -
# 1 trials running, 18 finished (2 until the end), 320.52s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:26:51] 🚀 Trial 19 started - config: learning_rate=0.000465344852002413, num_hiddens=256, num_layers=4, dropout=0.3828651068017258, weight_decay=4.2579365668974735e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.008968    35.157416
#         1  Completed    10       0.000019          128           4 0.369247      0.000058   10.0          0.006316    41.747530
#         2  Completed    10       0.000225           32           4 0.435256      0.000094   10.0          0.005624    34.413182
#         3    Stopped     1       0.000065          256           4 0.237072      0.000288    1.0          0.006775    12.978301
#         4    Stopped     1       0.000087          256           2 0.365382      0.000342    1.0          0.009583     8.498954
#         5    Stopped     1       0.000010           32           3 0.289566      0.000080    1.0          0.006809     4.699804
#         6    Stopped     1       0.000014           64           3 0.326995      0.000164    1.0          0.007016     4.850300
#         7    Stopped     1       0.000053           32           3 0.362741      0.000085    1.0          0.008419     4.735730
#         8    Stopped     1       0.000133          128           2 0.487034      0.000053    1.0          0.009696     4.866275
#         9    Stopped     1       0.000409          128           3 0.389199      0.000264    1.0          0.007480     5.402229
#        10    Stopped     1       0.000074           32           2 0.209794      0.000013    1.0          0.008567     4.594557
#        11    Stopped     1       0.000016          256           4 0.416104      0.000049    1.0          0.008078    12.955192
#        12    Stopped     1       0.000456          256           2 0.439425      0.000027    1.0          0.008056     8.664216
#        13    Stopped     1       0.000013           32           2 0.361304      0.000019    1.0          0.007680     4.495850
#        14    Stopped     1       0.000013          128           2 0.320672      0.000077    1.0          0.009033     4.771944
#        15    Stopped     1       0.000046           32           3 0.285556      0.000019    1.0          0.009184     4.738597
#        16    Stopped     1       0.000141           32           3 0.411173      0.000038    1.0          0.008712     4.749941
#        17    Stopped     1       0.000036          128           4 0.253776      0.000014    1.0          0.010225     5.873563
#        18    Stopped     1       0.000134          256           4 0.278630      0.000161    1.0          0.008736    13.049180
#        19 InProgress     0       0.000465          256           4 0.382865      0.000043      -                 -            -
# 1 trials running, 19 finished (2 until the end), 340.54s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.008968    35.157416
#         1  Completed    10       0.000019          128           4 0.369247      0.000
#        24    Stopped     1       0.000021           64           3 0.245440      0.000023    1.0          0.009001     4.911562
#        25    Stopped     9       0.000019           64           3 0.264887      0.000460    9.0          0.006180    29.580504
#        26    Stopped     1       0.000052          256           4 0.288175      0.000101    1.0          0.007850    13.141291
#        27    Stopped     1       0.000463          128           3 0.222577      0.000305    1.0          0.007635     5.300426
#        28    Stopped     1       0.000015           64           2 0.460673      0.000217    1.0          0.009624     4.553323
#        29    Stopped     4       0.000032          128           3 0.218744      0.000016    4.0          0.010905    15.830242
#        30 InProgress     0       0.000072          128           4 0.323704      0.000341      -                 -            -
# 1 trials running, 30 finished (3 until the end), 621.03s wallclock-time
#
# validation_error: best 0.00562427518889308 for trial-id 2
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-25-09-21-20-457
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-25-09-21-20-457
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##7. Load Results from HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
ammonium_results_path = "/root/syne-tune/python-entrypoint-2026-03-25-09-21-20-457/results.csv.zip"

# Save the results to a Pandas DataFrame
ammonium_results = pd.read_csv(ammonium_results_path)

# %% [markdown]
# ##8. Save the Ammonium HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
ammonium_hpo_results_path = Path("/content/MILL BECK_WINDERMERE MUSEUM_E_202303_ammonium_hpo_results.csv")

# Save the DataFrame to a csv file
ammonium_results.to_csv(ammonium_hpo_results_path, index=True)

# %% [markdown]
# ## 9. Define the Config Space, Scheduler, and Tune Function for Dissolved Oxygen HPO

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on ammonium_t_96 targets
def oxygen_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Create the path to the directory containing the data in the Jupyter notebook environment
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/windermere_inflows_and_outflow/mill_beck/MILL%20BECK_WINDERMERE%20MUSEUM_E_202303/MILL%20BECK_WINDERMERE%20MUSEUM_E_202303_preprocessed_data.zip")
    # Assign the full filepath for the preprocessed data
    parameter_path = "/content" / data_path / "MILL BECK_WINDERMERE MUSEUM_E_202303_preprocessed_data.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "oxygen_conc"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ##10. Initialise and Run the Tuner for Oxygen HPO

# %%
# Instruct the searcher to run each trial as a Python function
oxygen_trial_backend = PythonBackend(
    tune_function=oxygen_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=oxygen_trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-25-09-33-29-100
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-25-09-33-29-100
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-25-09-33-29-100
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [09:33:29] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     3        0.00001           64           2      0.2       0.00001      3          0.060791     10.15479
# 1 trials running, 0 finished (0 until the end), 20.02s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:34:04] 🚀 Trial 1 started - config: learning_rate=0.00043738913383741456, num_hiddens=32, num_layers=2, dropout=0.25967105614520347, weight_decay=0.00010583601803781492
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058862    29.865994
#         1 InProgress     0       0.000437           32           2 0.259671      0.000106      -                 -            -
# 1 trials running, 1 finished (0 until the end), 40.04s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:34:19] 🚀 Trial 2 started - config: learning_rate=3.762741839716719e-05, num_hiddens=32, num_layers=4, dropout=0.4831665359934341, weight_decay=3.9689954347840865e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106    3.0          0.064570     9.752580
#         2 InProgress     0       0.000038           32           4 0.483167      0.000040      -                 -            -
# 1 trials running, 2 finished (0 until the end), 60.06s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106      3          0.064570     9.752580
#         2 InProgress     5       0.000038           32           4 0.483167      0.000040      5          0.064554    18.193299
# 1 trials running, 2 finished (0 until the end), 80.10s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:34:59] 🚀 Trial 3 started - config: learning_rate=0.0004240000856032125, num_hiddens=128, num_layers=4, dropout=0.471483700701305, weight_decay=2.3849277955183936e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106    3.0          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040   10.0          0.063477    34.884892
#         3 InProgress     0       0.000424          128           4 0.471484      0.000024      -                 -            -
# 1 trials running, 3 finished (0 until the end), 100.12s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106      3          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040     10          0.063477    34.884892
#         3 InProgress     4       0.000424          128           4 0.471484      0.000024      4          0.063491    17.795839
# 1 trials running, 3 finished (0 until the end), 120.14s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:35:45] 🚀 Trial 4 started - config: learning_rate=0.00013816353299676254, num_hiddens=128, num_layers=3, dropout=0.45390840124002696, weight_decay=0.0001177231893436544
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106    3.0          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040   10.0          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024    9.0          0.082108    37.487509
#         4 InProgress     0       0.000138          128           3 0.453908      0.000118      -                 -            -
# 1 trials running, 4 finished (0 until the end), 140.17s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106      3          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040     10          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024      9          0.082108    37.487509
#         4 InProgress     4       0.000138          128           3 0.453908      0.000118      4          0.064414    15.655480
# 1 trials running, 4 finished (0 until the end), 160.19s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:36:25] 🚀 Trial 5 started - config: learning_rate=7.980902615913209e-05, num_hiddens=128, num_layers=4, dropout=0.2565689147529365, weight_decay=0.00014333137551753201
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106    3.0          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040   10.0          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024    9.0          0.082108    37.487509
#         4    Stopped     9       0.000138          128           3 0.453908      0.000118    9.0          0.065933    32.733675
#         5 InProgress     0       0.000080          128           4 0.256569      0.000143      -                 -            -
# 1 trials running, 5 finished (0 until the end), 180.22s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106      3          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040     10          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024      9          0.082108    37.487509
#         4    Stopped     9       0.000138          128           3 0.453908      0.000118      9          0.065933    32.733675
#         5 InProgress     3       0.000080          128           4 0.256569      0.000143      3          0.060108    13.588734
# 1 trials running, 5 finished (0 until the end), 200.24s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106      3          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040     10          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024      9          0.082108    37.487509
#         4    Stopped     9       0.000138          128           3 0.453908      0.000118      9          0.065933    32.733675
#         5 InProgress     8       0.000080          128           4 0.256569      0.000143      8          0.065437    33.257986
# 1 trials running, 5 finished (0 until the end), 220.26s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:37:10] 🚀 Trial 6 started - config: learning_rate=1.1151824196344893e-05, num_hiddens=64, num_layers=3, dropout=0.24042556786104102, weight_decay=6.940719811521161e-05
# [09:37:20] 🚀 Trial 7 started - config: learning_rate=1.535382267217246e-05, num_hiddens=256, num_layers=2, dropout=0.21938796593513282, weight_decay=2.0351386153943835e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106    3.0          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040   10.0          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024    9.0          0.082108    37.487509
#         4    Stopped     9       0.000138          128           3 0.453908      0.000118    9.0          0.065933    32.733675
#         5    Stopped     9       0.000080          128           4 0.256569      0.000143    9.0          0.064017    37.153940
#         6    Stopped     1       0.000011           64           3 0.240426      0.000069    1.0          0.142804     4.825626
#         7 InProgress     0       0.000015          256           2 0.219388      0.000020      -                 -            -
# 1 trials running, 7 finished (0 until the end), 240.29s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106      3          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040     10          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024      9          0.082108    37.487509
#         4    Stopped     9       0.000138          128           3 0.453908      0.000118      9          0.065933    32.733675
#         5    Stopped     9       0.000080          128           4 0.256569      0.000143      9          0.064017    37.153940
#         6    Stopped     1       0.000011           64           3 0.240426      0.000069      1          0.142804     4.825626
#         7 InProgress     2       0.000015          256           2 0.219388      0.000020      2          0.058390    14.794594
# 1 trials running, 7 finished (0 until the end), 260.31s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106      3          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040     10          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024      9          0.082108    37.487509
#         4    Stopped     9       0.000138          128           3 0.453908      0.000118      9          0.065933    32.733675
#         5    Stopped     9       0.000080          128           4 0.256569      0.000143      9          0.064017    37.153940
#         6    Stopped     1       0.000011           64           3 0.240426      0.000069      1          0.142804     4.825626
#         7 InProgress     6       0.000015          256           2 0.219388      0.000020      6          0.060496    40.187617
# 1 trials running, 7 finished (0 until the end), 280.35s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106      3          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040     10          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024      9          0.082108    37.487509
#         4    Stopped     9       0.000138          128           3 0.453908      0.000118      9          0.065933    32.733675
#         5    Stopped     9       0.000080          128           4 0.256569      0.000143      9          0.064017    37.153940
#         6    Stopped     1       0.000011           64           3 0.240426      0.000069      1          0.142804     4.825626
#         7 InProgress     9       0.000015          256           2 0.219388      0.000020      9          0.060604    59.269901
# 1 trials running, 7 finished (0 until the end), 300.38s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:38:30] 🚀 Trial 8 started - config: learning_rate=3.8045593909113016e-05, num_hiddens=256, num_layers=3, dropout=0.3442454055877154, weight_decay=1.4393243484735277e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106      3          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040     10          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024      9          0.082108    37.487509
#         4    Stopped     9       0.000138          128           3 0.453908      0.000118      9          0.065933    32.733675
#         5    Stopped     9       0.000080          128           4 0.256569      0.000143      9          0.064017    37.153940
#         6    Stopped     1       0.000011           64           3 0.240426      0.000069      1          0.142804     4.825626
#         7    Stopped    10       0.000015          256           2 0.219388      0.000020     10          0.065633    65.844725
#         8 InProgress     1       0.000038          256           3 0.344245      0.000014      1          0.058651    10.722374
# 1 trials running, 8 finished (0 until the end), 320.40s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106      3          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040     10          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024      9          0.082108    37.487509
#         4    Stopped     9       0.000138          128           3 0.453908      0.000118      9          0.065933    32.733675
#         5    Stopped     9       0.000080          128           4 0.256569      0.000143      9          0.064017    37.153940
#         6    Stopped     1       0.000011           64           3 0.240426      0.000069      1          0.142804     4.825626
#         7    Stopped    10       0.000015          256           2 0.219388      0.000020     10          0.065633    65.844725
#         8 InProgress     3       0.000038          256           3 0.344245      0.000014      3          0.059364    27.315597
# 1 trials running, 8 finished (0 until the end), 340.43s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106      3          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040     10          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024      9          0.082108    37.487509
#         4    Stopped     9       0.000138          128           3 0.453908      0.000118      9          0.065933    32.733675
#         5    Stopped     9       0.000080          128           4 0.256569      0.000143      9          0.064017    37.153940
#         6    Stopped     1       0.000011           64           3 0.240426      0.000069      1          0.142804     4.825626
#         7    Stopped    10       0.000015          256           2 0.219388      0.000020     10          0.065633    65.844725
#         8 InProgress     5       0.000038          256           3 0.344245      0.000014      5          0.065838    44.144181
# 1 trials running, 8 finished (0 until the end), 360.46s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106      3          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040     10          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024      9          0.082108    37.487509
#         4    Stopped     9       0.000138          128           3 0.453908      0.000118      9          0.065933    32.733675
#         5    Stopped     9       0.000080          128           4 0.256569      0.000143      9          0.064017    37.153940
#         6    Stopped     1       0.000011           64           3 0.240426      0.000069      1          0.142804     4.825626
#         7    Stopped    10       0.000015          256           2 0.219388      0.000020     10          0.065633    65.844725
#         8 InProgress     8       0.000038          256           3 0.344245      0.000014      8          0.066839    69.326074
# 1 trials running, 8 finished (0 until the end), 380.49s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:39:55] 🚀 Trial 9 started - config: learning_rate=4.0287507706301455e-05, num_hiddens=256, num_layers=2, dropout=0.2026553847840239, weight_decay=4.252080797846921e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106    3.0          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040   10.0          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024    9.0          0.082108    37.487509
#         4    Stopped     9       0.000138          128           3 0.453908      0.000118    9.0          0.065933    32.733675
#         5    Stopped     9       0.000080          128           4 0.256569      0.000143    9.0          0.064017    37.153940
#         6    Stopped     1       0.000011           64           3 0.240426      0.000069    1.0          0.142804     4.825626
#         7    Stopped    10       0.000015          256           2 0.219388      0.000020   10.0          0.065633    65.844725
#         8    Stopped     9       0.000038          256           3 0.344245      0.000014    9.0          0.073866    77.756887
#         9 InProgress     0       0.000040          256           2 0.202655      0.000043      -                 -            -
# 1 trials running, 9 finished (0 until the end), 400.51s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106      3          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040     10          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024      9          0.082108    37.487509
#         4    Stopped     9       0.000138          128           3 0.453908      0.000118      9          0.065933    32.733675
#         5    Stopped     9       0.000080          128           4 0.256569      0.000143      9          0.064017    37.153940
#         6    Stopped     1       0.000011           64           3 0.240426      0.000069      1          0.142804     4.825626
#         7    Stopped    10       0.000015          256           2 0.219388      0.000020     10          0.065633    65.844725
#         8    Stopped     9       0.000038          256           3 0.344245      0.000014      9          0.073866    77.756887
#         9 InProgress     3       0.000040          256           2 0.202655      0.000043      3          0.058742    21.346260
# 1 trials running, 9 finished (0 until the end), 420.56s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106      3          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040     10          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024      9          0.082108    37.487509
#         4    Stopped     9       0.000138          128           3 0.453908      0.000118      9          0.065933    32.733675
#         5    Stopped     9       0.000080          128           4 0.256569      0.000143      9          0.064017    37.153940
#         6    Stopped     1       0.000011           64           3 0.240426      0.000069      1          0.142804     4.825626
#         7    Stopped    10       0.000015          256           2 0.219388      0.000020     10          0.065633    65.844725
#         8    Stopped     9       0.000038          256           3 0.344245      0.000014      9          0.073866    77.756887
#         9 InProgress     6       0.000040          256           2 0.202655      0.000043      6          0.061928    40.660128
# 1 trials running, 9 finished (0 until the end), 440.59s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:41:00] 🚀 Trial 10 started - config: learning_rate=2.800281245357886e-05, num_hiddens=64, num_layers=2, dropout=0.4088520177058568, weight_decay=7.434036479677276e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106    3.0          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040   10.0          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024    9.0          0.082108    37.487509
#         4    Stopped     9       0.000138          128           3 0.453908      0.000118    9.0          0.065933    32.733675
#         5    Stopped     9       0.000080          128           4 0.256569      0.000143    9.0          0.064017    37.153940
#         6    Stopped     1       0.000011           64           3 0.240426      0.000069    1.0          0.142804     4.825626
#         7    Stopped    10       0.000015          256           2 0.219388      0.000020   10.0          0.065633    65.844725
#         8    Stopped     9       0.000038          256           3 0.344245      0.000014    9.0          0.073866    77.756887
#         9    Stopped     9       0.000040          256           2 0.202655      0.000043    9.0          0.063854    59.929393
#        10 InProgress     0       0.000028           64           2 0.408852      0.000074      -                 -            -
# 1 trials running, 10 finished (0 until the end), 460.62s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:41:10] 🚀 Trial 11 started - config: learning_rate=1.8903613559973738e-05, num_hiddens=128, num_layers=2, dropout=0.27079506145936066, weight_decay=0.00010183263876626975
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106      3          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040     10          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024      9          0.082108    37.487509
#         4    Stopped     9       0.000138          128           3 0.453908      0.000118      9          0.065933    32.733675
#         5    Stopped     9       0.000080          128           4 0.256569      0.000143      9          0.064017    37.153940
#         6    Stopped     1       0.000011           64           3 0.240426      0.000069      1          0.142804     4.825626
#         7    Stopped    10       0.000015          256           2 0.219388      0.000020     10          0.065633    65.844725
#         8    Stopped     9       0.000038          256           3 0.344245      0.000014      9          0.073866    77.756887
#         9    Stopped     9       0.000040          256           2 0.202655      0.000043      9          0.063854    59.929393
#        10    Stopped     1       0.000028           64           2 0.408852      0.000074      1          0.061878     4.433778
#        11 InProgress     3       0.000019          128           2 0.270795      0.000102      3          0.057889    10.762154
# 1 trials running, 11 finished (0 until the end), 480.67s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106      3          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040     10          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024      9          0.082108    37.487509
#         4    Stopped     9       0.000138          128           3 0.453908      0.000118      9          0.065933    32.733675
#         5    Stopped     9       0.000080          128           4 0.256569      0.000143      9          0.064017    37.153940
#         6    Stopped     1       0.000011           64           3 0.240426      0.000069      1          0.142804     4.825626
#         7    Stopped    10       0.000015          256           2 0.219388      0.000020     10          0.065633    65.844725
#         8    Stopped     9       0.000038          256           3 0.344245      0.000014      9          0.073866    77.756887
#         9    Stopped     9       0.000040          256           2 0.202655      0.000043      9          0.063854    59.929393
#        10    Stopped     1       0.000028           64           2 0.408852      0.000074      1          0.061878     4.433778
#        11 InProgress     9       0.000019          128           2 0.270795      0.000102      9          0.060893    29.078850
# 1 trials running, 11 finished (0 until the end), 500.69s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:41:50] ✅ Trial 11 completed!
# [09:41:50] 🚀 Trial 12 started - config: learning_rate=8.876358451371422e-05, num_hiddens=128, num_layers=4, dropout=0.2698149344100846, weight_decay=1.0607990573675205e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106      3          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040     10          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024      9          0.082108    37.487509
#         4    Stopped     9       0.000138          128           3 0.453908      0.000118      9          0.065933    32.733675
#         5    Stopped     9       0.000080          128           4 0.256569      0.000143      9          0.064017    37.153940
#         6    Stopped     1       0.000011           64           3 0.240426      0.000069      1          0.142804     4.825626
#         7    Stopped    10       0.000015          256           2 0.219388      0.000020     10          0.065633    65.844725
#         8    Stopped     9       0.000038          256           3 0.344245      0.000014      9          0.073866    77.756887
#         9    Stopped     9       0.000040          256           2 0.202655      0.000043      9          0.063854    59.929393
#        10    Stopped     1       0.000028           64           2 0.408852      0.000074      1          0.061878     4.433778
#        11  Completed    10       0.000019          128           2 0.270795      0.000102     10          0.058502    32.098810
#        12 InProgress     2       0.000089          128           4 0.269815      0.000011      2          0.062097     9.747220
# 1 trials running, 12 finished (1 until the end), 520.73s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:42:10] 🚀 Trial 13 started - config: learning_rate=0.00020102047515491072, num_hiddens=128, num_layers=2, dropout=0.2150068540336543, weight_decay=5.0917313390033576e-05
# [09:42:25] 🚀 Trial 14 started - config: learning_rate=6.343566501829784e-05, num_hiddens=256, num_layers=3, dropout=0.45255122259472746, weight_decay=0.00021567415309438286
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000106    3.0          0.064570     9.752580
#         2    Stopped    10       0.000038           32           4 0.483167      0.000040   10.0          0.063477    34.884892
#         3    Stopped     9       0.000424          128           4 0.471484      0.000024    9.0          0.082108    37.487509
#         4    Stopped     9       0.000138          128           3 0.453908      0.000118    9.0          0.065933    32.733675
#         5    Stopped     9       0.000080          128           4 0.256569      0.000143    9.0          0.064017    37.153940
#         6    Stopped     1       0.000011           64           3 0.240426      0.000069    1.0          0.142804     4.825626
#         7    Stopped    10       0.000015          256           2 0.219388      0.000020   10.0          0.065633    65.844725
#         8    Stopped     9       0.000038          256           3 0.344245      0.000014    9.0          0.073866    77.756887
#         9    Stopped     9       0.000040          256           2 0.202655      0.000043    9.0          0.063854    59.929393
#        10    Stopped     1       0.000028           64           2 0.408852      0.000074    1.0          0.061878     4.433778
#        11  Completed    10       0.000019          128           2 0.270795      0.000102   10.0          0.058502    32.098810
#        12    Stopped     3       0.000089          128           4 0.269815      0.000011    3.0          0.064537    13.577824
#        13    Stopped     3       0.000201          128           2 0.215007      0.000051    3.0          0.066429    10.657336
#        14 InProgress     0       0.000063          256           3 0.452551      0.000216      -                 -            -
# 1 trials running, 14 finished (1 until the end), 540.77s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [09:42:40] 🚀 Trial 15 started - config: learning_rate=0.00021769749932198565, num_hiddens=128, num_layers=2, dropout=0.2704514052561478, weight_decay=1.21560410172204e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.058862    29.865994
#         1    Stopped     3       0.000437           32           2 0.259671      0.000
#        15    Stopped     3       0.000218          128           2 0.270451      0.000012    3.0          0.069060    10.731519
#        16    Stopped     9       0.000126          128           3 0.349000      0.000251    9.0          0.064547    32.956681
#        17    Stopped     1       0.000012          128           2 0.329533      0.000083    1.0          0.072995     4.835930
#        18    Stopped     1       0.000089           64           4 0.220413      0.000152    1.0          0.060716     5.222521
#        19    Stopped     1       0.000436           64           4 0.499305      0.000018    1.0          0.060331     5.180858
#        20    Stopped     3       0.000460          128           4 0.445917      0.000201    3.0          0.065545    13.529731
#        21    Stopped     1       0.000130          256           4 0.231405      0.000315    1.0          0.060255    12.962906
#        22    Stopped     1       0.000010           32           4 0.450958      0.000032    1.0          0.373101     5.039922
#        23    Stopped     3       0.000333          256           4 0.351260      0.000041    3.0          0.066300    34.467518
#        24    Stopped     1       0.000014           32           2 0.282142      0.000318    1.0          0.219616     4.523554
#        25    Stopped     9       0.000062           64           3 0.250507      0.000069    9.0          0.064787    29.476187
#        26    Stopped     1       0.000011           64           2 0.326901      0.000315    1.0          0.130267     4.469101
#        27    Stopped     1       0.000021          256           4 0.309102      0.000137    1.0          0.058847    13.136475
#        28  Completed    10       0.000023          128           2 0.414696      0.000055   10.0          0.060084    31.972394
#        29  Completed    10       0.000035          256           3 0.389937      0.000106   10.0          0.060240    88.753934
#        30 InProgress     0       0.000021           32           4 0.459862      0.000184      -                 -            -
# 1 trials running, 30 finished (3 until the end), 936.66s wallclock-time
#
# validation_error: best 0.05715367570519447 for trial-id 28
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-25-09-33-29-100
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-25-09-33-29-100
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##11. Load Results from Dissolved Oxygen HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
oxygen_results_path = "/root/syne-tune/python-entrypoint-2026-03-25-09-33-29-100/results.csv.zip"

# Save the results to a Pandas DataFrame
oxygen_results = pd.read_csv(oxygen_results_path)

# %% [markdown]
# ##12. Save the Oxygen HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
oxygen_hpo_results_path = Path("/content/MILL BECK_WINDERMERE MUSEUM_E_202303_oxygen_hpo_results.csv")

# Save the DataFrame to a csv file
oxygen_results.to_csv(oxygen_hpo_results_path, index=True)

# %% [markdown]
# ## 13. Define the Config Space, Scheduler, and Tune Function for Temperature HPO

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on temperature_t_96 targets
def temperature_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Create the path to the directory containing the data in the Jupyter notebook environment
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/windermere_inflows_and_outflow/mill_beck/MILL%20BECK_WINDERMERE%20MUSEUM_E_202303/MILL%20BECK_WINDERMERE%20MUSEUM_E_202303_preprocessed_data.zip")
    # Assign the full filepath for the preprocessed data
    parameter_path = "/content" / data_path / "MILL BECK_WINDERMERE MUSEUM_E_202303_preprocessed_data.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "temperature"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ##14. Initialise and Run the Tuner for Temperature HPO

# %%
# Instruct the searcher to run each trial as a Python function
temperature_trial_backend = PythonBackend(
    tune_function=temperature_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=temperature_trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-25-10-09-29-568
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-25-10-09-29-568
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-25-10-09-29-568
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [10:09:30] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     3        0.00001           64           2      0.2       0.00001      3          0.063045     9.986438
# 1 trials running, 0 finished (0 until the end), 20.02s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:10:05] ✅ Trial 0 completed!
# [10:10:05] 🚀 Trial 1 started - config: learning_rate=0.00011782014577571385, num_hiddens=128, num_layers=3, dropout=0.204920448389451, weight_decay=2.4961171499498332e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2  0.20000      0.000010   10.0          0.056808    29.422723
#         1 InProgress     0       0.000118          128           3  0.20492      0.000025      -                 -            -
# 1 trials running, 1 finished (1 until the end), 40.04s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2  0.20000      0.000010     10          0.056808    29.422723
#         1 InProgress     4       0.000118          128           3  0.20492      0.000025      4          0.069495    15.599984
# 1 trials running, 1 finished (1 until the end), 60.06s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:10:45] 🚀 Trial 2 started - config: learning_rate=0.00029359253134925075, num_hiddens=64, num_layers=3, dropout=0.31145141543619104, weight_decay=0.0004036646724325439
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025    9.0          0.078407    32.709403
#         2 InProgress     0       0.000294           64           3 0.311451      0.000404      -                 -            -
# 1 trials running, 2 finished (1 until the end), 80.09s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025      9          0.078407    32.709403
#         2 InProgress     4       0.000294           64           3 0.311451      0.000404      4          0.062049    14.099480
# 1 trials running, 2 finished (1 until the end), 100.11s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:11:25] ✅ Trial 2 completed!
# [10:11:25] 🚀 Trial 3 started - config: learning_rate=7.340740811297653e-05, num_hiddens=64, num_layers=2, dropout=0.22578243201380924, weight_decay=0.00034870953070924597
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025    9.0          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404   10.0          0.064559    32.503665
#         3 InProgress     0       0.000073           64           2 0.225782      0.000349      -                 -            -
# 1 trials running, 3 finished (2 until the end), 120.14s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:11:35] 🚀 Trial 4 started - config: learning_rate=0.00012968508497676235, num_hiddens=32, num_layers=4, dropout=0.3143321632585345, weight_decay=0.00033930584147160613
# [10:11:45] 🚀 Trial 5 started - config: learning_rate=0.00040215687851408063, num_hiddens=128, num_layers=4, dropout=0.3482752165149938, weight_decay=0.000472824971246074
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025    9.0          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404   10.0          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349    1.0          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339    1.0          0.060465     5.048560
#         5 InProgress     0       0.000402          128           4 0.348275      0.000473      -                 -            -
# 1 trials running, 5 finished (2 until the end), 140.16s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025      9          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404     10          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349      1          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339      1          0.060465     5.048560
#         5 InProgress     3       0.000402          128           4 0.348275      0.000473      3          0.058943    13.544545
# 1 trials running, 5 finished (2 until the end), 160.19s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025      9          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404     10          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349      1          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339      1          0.060465     5.048560
#         5 InProgress     8       0.000402          128           4 0.348275      0.000473      8          0.063244    33.151144
# 1 trials running, 5 finished (2 until the end), 180.21s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:12:35] ✅ Trial 5 completed!
# [10:12:35] 🚀 Trial 6 started - config: learning_rate=2.2021875510184483e-05, num_hiddens=64, num_layers=4, dropout=0.31488862882775026, weight_decay=7.845674332705224e-05
# [10:12:45] 🚀 Trial 7 started - config: learning_rate=3.62060755462021e-05, num_hiddens=256, num_layers=2, dropout=0.3225250562435868, weight_decay=7.203812395703114e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025    9.0          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404   10.0          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349    1.0          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339    1.0          0.060465     5.048560
#         5  Completed    10       0.000402          128           4 0.348275      0.000473   10.0          0.065542    40.987182
#         6    Stopped     1       0.000022           64           4 0.314889      0.000078    1.0          0.067471     5.202111
#         7 InProgress     0       0.000036          256           2 0.322525      0.000072      -                 -            -
# 1 trials running, 7 finished (3 until the end), 200.25s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:13:00] 🚀 Trial 8 started - config: learning_rate=1.3366390578467877e-05, num_hiddens=128, num_layers=4, dropout=0.24840673179500225, weight_decay=1.6440172887044492e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025    9.0          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404   10.0          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349    1.0          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339    1.0          0.060465     5.048560
#         5  Completed    10       0.000402          128           4 0.348275      0.000473   10.0          0.065542    40.987182
#         6    Stopped     1       0.000022           64           4 0.314889      0.000078    1.0          0.067471     5.202111
#         7    Stopped     1       0.000036          256           2 0.322525      0.000072    1.0          0.059242     8.663731
#         8 InProgress     0       0.000013          128           4 0.248407      0.000016      -                 -            -
# 1 trials running, 8 finished (3 until the end), 220.27s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:13:10] 🚀 Trial 9 started - config: learning_rate=0.0004012348601069944, num_hiddens=64, num_layers=4, dropout=0.2735708632905806, weight_decay=0.00033423055829437826
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025      9          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404     10          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349      1          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339      1          0.060465     5.048560
#         5  Completed    10       0.000402          128           4 0.348275      0.000473     10          0.065542    40.987182
#         6    Stopped     1       0.000022           64           4 0.314889      0.000078      1          0.067471     5.202111
#         7    Stopped     1       0.000036          256           2 0.322525      0.000072      1          0.059242     8.663731
#         8    Stopped     1       0.000013          128           4 0.248407      0.000016      1          0.067023     5.882371
#         9 InProgress     2       0.000401           64           4 0.273571      0.000334      2          0.058064     8.440116
# 1 trials running, 9 finished (3 until the end), 240.30s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:13:30] 🚀 Trial 10 started - config: learning_rate=2.852146365695293e-05, num_hiddens=128, num_layers=4, dropout=0.46680649194657137, weight_decay=1.2901269827206516e-05
# [10:13:40] 🚀 Trial 11 started - config: learning_rate=0.00013022607767757547, num_hiddens=128, num_layers=4, dropout=0.34685156672258943, weight_decay=1.3422201750959288e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025    9.0          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404   10.0          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349    1.0          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339    1.0          0.060465     5.048560
#         5  Completed    10       0.000402          128           4 0.348275      0.000473   10.0          0.065542    40.987182
#         6    Stopped     1       0.000022           64           4 0.314889      0.000078    1.0          0.067471     5.202111
#         7    Stopped     1       0.000036          256           2 0.322525      0.000072    1.0          0.059242     8.663731
#         8    Stopped     1       0.000013          128           4 0.248407      0.000016    1.0          0.067023     5.882371
#         9    Stopped     4       0.000401           64           4 0.273571      0.000334    4.0          0.062108    15.215293
#        10    Stopped     1       0.000029          128           4 0.466806      0.000013    1.0          0.062618     5.870872
#        11 InProgress     0       0.000130          128           4 0.346852      0.000013      -                 -            -
# 1 trials running, 11 finished (3 until the end), 260.33s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:13:50] 🚀 Trial 12 started - config: learning_rate=0.0002986315507160874, num_hiddens=256, num_layers=4, dropout=0.22480277494851053, weight_decay=3.438102526988799e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025    9.0          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404   10.0          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349    1.0          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339    1.0          0.060465     5.048560
#         5  Completed    10       0.000402          128           4 0.348275      0.000473   10.0          0.065542    40.987182
#         6    Stopped     1       0.000022           64           4 0.314889      0.000078    1.0          0.067471     5.202111
#         7    Stopped     1       0.000036          256           2 0.322525      0.000072    1.0          0.059242     8.663731
#         8    Stopped     1       0.000013          128           4 0.248407      0.000016    1.0          0.067023     5.882371
#         9    Stopped     4       0.000401           64           4 0.273571      0.000334    4.0          0.062108    15.215293
#        10    Stopped     1       0.000029          128           4 0.466806      0.000013    1.0          0.062618     5.870872
#        11    Stopped     1       0.000130          128           4 0.346852      0.000013    1.0          0.058911     5.862995
#        12 InProgress     0       0.000299          256           4 0.224803      0.000034      -                 -            -
# 1 trials running, 12 finished (3 until the end), 280.34s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025      9          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404     10          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349      1          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339      1          0.060465     5.048560
#         5  Completed    10       0.000402          128           4 0.348275      0.000473     10          0.065542    40.987182
#         6    Stopped     1       0.000022           64           4 0.314889      0.000078      1          0.067471     5.202111
#         7    Stopped     1       0.000036          256           2 0.322525      0.000072      1          0.059242     8.663731
#         8    Stopped     1       0.000013          128           4 0.248407      0.000016      1          0.067023     5.882371
#         9    Stopped     4       0.000401           64           4 0.273571      0.000334      4          0.062108    15.215293
#        10    Stopped     1       0.000029          128           4 0.466806      0.000013      1          0.062618     5.870872
#        11    Stopped     1       0.000130          128           4 0.346852      0.000013      1          0.058911     5.862995
#        12 InProgress     2       0.000299          256           4 0.224803      0.000034      2          0.062821    23.232903
# 1 trials running, 12 finished (3 until the end), 300.36s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:14:31] 🚀 Trial 13 started - config: learning_rate=1.7322108541781975e-05, num_hiddens=128, num_layers=4, dropout=0.44727045113020014, weight_decay=0.00040801047955408534
# [10:14:46] 🚀 Trial 14 started - config: learning_rate=2.282904398770329e-05, num_hiddens=32, num_layers=4, dropout=0.46201258658169564, weight_decay=1.665195836125715e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025    9.0          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404   10.0          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349    1.0          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339    1.0          0.060465     5.048560
#         5  Completed    10       0.000402          128           4 0.348275      0.000473   10.0          0.065542    40.987182
#         6    Stopped     1       0.000022           64           4 0.314889      0.000078    1.0          0.067471     5.202111
#         7    Stopped     1       0.000036          256           2 0.322525      0.000072    1.0          0.059242     8.663731
#         8    Stopped     1       0.000013          128           4 0.248407      0.000016    1.0          0.067023     5.882371
#         9    Stopped     4       0.000401           64           4 0.273571      0.000334    4.0          0.062108    15.215293
#        10    Stopped     1       0.000029          128           4 0.466806      0.000013    1.0          0.062618     5.870872
#        11    Stopped     1       0.000130          128           4 0.346852      0.000013    1.0          0.058911     5.862995
#        12    Stopped     3       0.000299          256           4 0.224803      0.000034    3.0          0.067583    33.634111
#        13    Stopped     2       0.000017          128           4 0.447270      0.000408    2.0          0.058818     9.745891
#        14 InProgress     0       0.000023           32           4 0.462013      0.000017      -                 -            -
# 1 trials running, 14 finished (3 until the end), 320.41s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:14:56] 🚀 Trial 15 started - config: learning_rate=0.00016846415596433366, num_hiddens=128, num_layers=2, dropout=0.23882349752874965, weight_decay=0.0002980967053717732
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025      9          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404     10          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349      1          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339      1          0.060465     5.048560
#         5  Completed    10       0.000402          128           4 0.348275      0.000473     10          0.065542    40.987182
#         6    Stopped     1       0.000022           64           4 0.314889      0.000078      1          0.067471     5.202111
#         7    Stopped     1       0.000036          256           2 0.322525      0.000072      1          0.059242     8.663731
#         8    Stopped     1       0.000013          128           4 0.248407      0.000016      1          0.067023     5.882371
#         9    Stopped     4       0.000401           64           4 0.273571      0.000334      4          0.062108    15.215293
#        10    Stopped     1       0.000029          128           4 0.466806      0.000013      1          0.062618     5.870872
#        11    Stopped     1       0.000130          128           4 0.346852      0.000013      1          0.058911     5.862995
#        12    Stopped     3       0.000299          256           4 0.224803      0.000034      3          0.067583    33.634111
#        13    Stopped     2       0.000017          128           4 0.447270      0.000408      2          0.058818     9.745891
#        14    Stopped     1       0.000023           32           4 0.462013      0.000017      1          0.192670     5.097313
#        15 InProgress     1       0.000168          128           2 0.238823      0.000298      1          0.057068     4.842526
# 1 trials running, 15 finished (3 until the end), 340.44s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025      9          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404     10          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349      1          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339      1          0.060465     5.048560
#         5  Completed    10       0.000402          128           4 0.348275      0.000473     10          0.065542    40.987182
#         6    Stopped     1       0.000022           64           4 0.314889      0.000078      1          0.067471     5.202111
#         7    Stopped     1       0.000036          256           2 0.322525      0.000072      1          0.059242     8.663731
#         8    Stopped     1       0.000013          128           4 0.248407      0.000016      1          0.067023     5.882371
#         9    Stopped     4       0.000401           64           4 0.273571      0.000334      4          0.062108    15.215293
#        10    Stopped     1       0.000029          128           4 0.466806      0.000013      1          0.062618     5.870872
#        11    Stopped     1       0.000130          128           4 0.346852      0.000013      1          0.058911     5.862995
#        12    Stopped     3       0.000299          256           4 0.224803      0.000034      3          0.067583    33.634111
#        13    Stopped     2       0.000017          128           4 0.447270      0.000408      2          0.058818     9.745891
#        14    Stopped     1       0.000023           32           4 0.462013      0.000017      1          0.192670     5.097313
#        15 InProgress     8       0.000168          128           2 0.238823      0.000298      8          0.060344    25.929747
# 1 trials running, 15 finished (3 until the end), 360.47s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:15:36] ✅ Trial 15 completed!
# [10:15:36] 🚀 Trial 16 started - config: learning_rate=2.0068129423182954e-05, num_hiddens=256, num_layers=2, dropout=0.42440019191357814, weight_decay=6.017120609941318e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025    9.0          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404   10.0          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349    1.0          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339    1.0          0.060465     5.048560
#         5  Completed    10       0.000402          128           4 0.348275      0.000473   10.0          0.065542    40.987182
#         6    Stopped     1       0.000022           64           4 0.314889      0.000078    1.0          0.067471     5.202111
#         7    Stopped     1       0.000036          256           2 0.322525      0.000072    1.0          0.059242     8.663731
#         8    Stopped     1       0.000013          128           4 0.248407      0.000016    1.0          0.067023     5.882371
#         9    Stopped     4       0.000401           64           4 0.273571      0.000334    4.0          0.062108    15.215293
#        10    Stopped     1       0.000029          128           4 0.466806      0.000013    1.0          0.062618     5.870872
#        11    Stopped     1       0.000130          128           4 0.346852      0.000013    1.0          0.058911     5.862995
#        12    Stopped     3       0.000299          256           4 0.224803      0.000034    3.0          0.067583    33.634111
#        13    Stopped     2       0.000017          128           4 0.447270      0.000408    2.0          0.058818     9.745891
#        14    Stopped     1       0.000023           32           4 0.462013      0.000017    1.0          0.192670     5.097313
#        15  Completed    10       0.000168          128           2 0.238823      0.000298   10.0          0.061877    32.046041
#        16 InProgress     0       0.000020          256           2 0.424400      0.000060      -                 -            -
# 1 trials running, 16 finished (4 until the end), 380.50s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:15:51] 🚀 Trial 17 started - config: learning_rate=0.00047325247467279414, num_hiddens=128, num_layers=2, dropout=0.3733042691715889, weight_decay=3.044966563462135e-05
# [10:16:06] 🚀 Trial 18 started - config: learning_rate=2.8414920550268807e-05, num_hiddens=32, num_layers=2, dropout=0.45134665901960885, weight_decay=7.603893621279741e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025    9.0          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404   10.0          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349    1.0          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339    1.0          0.060465     5.048560
#         5  Completed    10       0.000402          128           4 0.348275      0.000473   10.0          0.065542    40.987182
#         6    Stopped     1       0.000022           64           4 0.314889      0.000078    1.0          0.067471     5.202111
#         7    Stopped     1       0.000036          256           2 0.322525      0.000072    1.0          0.059242     8.663731
#         8    Stopped     1       0.000013          128           4 0.248407      0.000016    1.0          0.067023     5.882371
#         9    Stopped     4       0.000401           64           4 0.273571      0.000334    4.0          0.062108    15.215293
#        10    Stopped     1       0.000029          128           4 0.466806      0.000013    1.0          0.062618     5.870872
#        11    Stopped     1       0.000130          128           4 0.346852      0.000013    1.0          0.058911     5.862995
#        12    Stopped     3       0.000299          256           4 0.224803      0.000034    3.0          0.067583    33.634111
#        13    Stopped     2       0.000017          128           4 0.447270      0.000408    2.0          0.058818     9.745891
#        14    Stopped     1       0.000023           32           4 0.462013      0.000017    1.0          0.192670     5.097313
#        15  Completed    10       0.000168          128           2 0.238823      0.000298   10.0          0.061877    32.046041
#        16    Stopped     1       0.000020          256           2 0.424400      0.000060    1.0          0.060366     8.532554
#        17    Stopped     3       0.000473          128           2 0.373304      0.000030    3.0          0.072511    10.833931
#        18 InProgress     0       0.000028           32           2 0.451347      0.000076      -                 -            -
# 1 trials running, 18 finished (4 until the end), 400.56s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:16:16] 🚀 Trial 19 started - config: learning_rate=0.0002516072068033259, num_hiddens=64, num_layers=3, dropout=0.3310076174854853, weight_decay=6.146226852960192e-05
# [10:16:26] 🚀 Trial 20 started - config: learning_rate=0.00030446002380774906, num_hiddens=128, num_layers=2, dropout=0.23497776395756348, weight_decay=0.0001681666063242298
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025    9.0          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404   10.0          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349    1.0          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339    1.0          0.060465     5.048560
#         5  Completed    10       0.000402          128           4 0.348275      0.000473   10.0          0.065542    40.987182
#         6    Stopped     1       0.000022           64           4 0.314889      0.000078    1.0          0.067471     5.202111
#         7    Stopped     1       0.000036          256           2 0.322525      0.000072    1.0          0.059242     8.663731
#         8    Stopped     1       0.000013          128           4 0.248407      0.000016    1.0          0.067023     5.882371
#         9    Stopped     4       0.000401           64           4 0.273571      0.000334    4.0          0.062108    15.215293
#        10    Stopped     1       0.000029          128           4 0.466806      0.000013    1.0          0.062618     5.870872
#        11    Stopped     1       0.000130          128           4 0.346852      0.000013    1.0          0.058911     5.862995
#        12    Stopped     3       0.000299          256           4 0.224803      0.000034    3.0          0.067583    33.634111
#        13    Stopped     2       0.000017          128           4 0.447270      0.000408    2.0          0.058818     9.745891
#        14    Stopped     1       0.000023           32           4 0.462013      0.000017    1.0          0.192670     5.097313
#        15  Completed    10       0.000168          128           2 0.238823      0.000298   10.0          0.061877    32.046041
#        16    Stopped     1       0.000020          256           2 0.424400      0.000060    1.0          0.060366     8.532554
#        17    Stopped     3       0.000473          128           2 0.373304      0.000030    3.0          0.072511    10.833931
#        18    Stopped     1       0.000028           32           2 0.451347      0.000076    1.0          0.164916     4.516639
#        19    Stopped     1       0.000252           64           3 0.331008      0.000061    1.0          0.059863     4.874029
#        20 InProgress     0       0.000304          128           2 0.234978      0.000168      -                 -            -
# 1 trials running, 20 finished (4 until the end), 420.59s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:16:36] 🚀 Trial 21 started - config: learning_rate=8.25877674537818e-05, num_hiddens=64, num_layers=4, dropout=0.26925498229906963, weight_decay=1.8561870622492804e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025      9          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404     10          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349      1          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339      1          0.060465     5.048560
#         5  Completed    10       0.000402          128           4 0.348275      0.000473     10          0.065542    40.987182
#         6    Stopped     1       0.000022           64           4 0.314889      0.000078      1          0.067471     5.202111
#         7    Stopped     1       0.000036          256           2 0.322525      0.000072      1          0.059242     8.663731
#         8    Stopped     1       0.000013          128           4 0.248407      0.000016      1          0.067023     5.882371
#         9    Stopped     4       0.000401           64           4 0.273571      0.000334      4          0.062108    15.215293
#        10    Stopped     1       0.000029          128           4 0.466806      0.000013      1          0.062618     5.870872
#        11    Stopped     1       0.000130          128           4 0.346852      0.000013      1          0.058911     5.862995
#        12    Stopped     3       0.000299          256           4 0.224803      0.000034      3          0.067583    33.634111
#        13    Stopped     2       0.000017          128           4 0.447270      0.000408      2          0.058818     9.745891
#        14    Stopped     1       0.000023           32           4 0.462013      0.000017      1          0.192670     5.097313
#        15  Completed    10       0.000168          128           2 0.238823      0.000298     10          0.061877    32.046041
#        16    Stopped     1       0.000020          256           2 0.424400      0.000060      1          0.060366     8.532554
#        17    Stopped     3       0.000473          128           2 0.373304      0.000030      3          0.072511    10.833931
#        18    Stopped     1       0.000028           32           2 0.451347      0.000076      1          0.164916     4.516639
#        19    Stopped     1       0.000252           64           3 0.331008      0.000061      1          0.059863     4.874029
#        20    Stopped     1       0.000304          128           2 0.234978      0.000168      1          0.059063     4.816286
#        21 InProgress     1       0.000083           64           4 0.269255      0.000019      1          0.058375     5.262713
# 1 trials running, 21 finished (4 until the end), 440.63s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:16:56] 🚀 Trial 22 started - config: learning_rate=0.00044752273483065146, num_hiddens=64, num_layers=4, dropout=0.4863163110894086, weight_decay=5.037470506605151e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025      9          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404     10          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349      1          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339      1          0.060465     5.048560
#         5  Completed    10       0.000402          128           4 0.348275      0.000473     10          0.065542    40.987182
#         6    Stopped     1       0.000022           64           4 0.314889      0.000078      1          0.067471     5.202111
#         7    Stopped     1       0.000036          256           2 0.322525      0.000072      1          0.059242     8.663731
#         8    Stopped     1       0.000013          128           4 0.248407      0.000016      1          0.067023     5.882371
#         9    Stopped     4       0.000401           64           4 0.273571      0.000334      4          0.062108    15.215293
#        10    Stopped     1       0.000029          128           4 0.466806      0.000013      1          0.062618     5.870872
#        11    Stopped     1       0.000130          128           4 0.346852      0.000013      1          0.058911     5.862995
#        12    Stopped     3       0.000299          256           4 0.224803      0.000034      3          0.067583    33.634111
#        13    Stopped     2       0.000017          128           4 0.447270      0.000408      2          0.058818     9.745891
#        14    Stopped     1       0.000023           32           4 0.462013      0.000017      1          0.192670     5.097313
#        15  Completed    10       0.000168          128           2 0.238823      0.000298     10          0.061877    32.046041
#        16    Stopped     1       0.000020          256           2 0.424400      0.000060      1          0.060366     8.532554
#        17    Stopped     3       0.000473          128           2 0.373304      0.000030      3          0.072511    10.833931
#        18    Stopped     1       0.000028           32           2 0.451347      0.000076      1          0.164916     4.516639
#        19    Stopped     1       0.000252           64           3 0.331008      0.000061      1          0.059863     4.874029
#        20    Stopped     1       0.000304          128           2 0.234978      0.000168      1          0.059063     4.816286
#        21    Stopped     4       0.000083           64           4 0.269255      0.000019      4          0.060544    15.641965
#        22 InProgress     1       0.000448           64           4 0.486316      0.000050      1          0.058169     5.218924
# 1 trials running, 22 finished (4 until the end), 460.66s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:17:16] 🚀 Trial 23 started - config: learning_rate=2.5931076544382428e-05, num_hiddens=128, num_layers=3, dropout=0.265222162117547, weight_decay=0.0002991104468755614
# [10:17:26] 🚀 Trial 24 started - config: learning_rate=3.6340013732885185e-05, num_hiddens=128, num_layers=2, dropout=0.23053274378967076, weight_decay=1.1497525147163846e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025    9.0          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404   10.0          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349    1.0          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339    1.0          0.060465     5.048560
#         5  Completed    10       0.000402          128           4 0.348275      0.000473   10.0          0.065542    40.987182
#         6    Stopped     1       0.000022           64           4 0.314889      0.000078    1.0          0.067471     5.202111
#         7    Stopped     1       0.000036          256           2 0.322525      0.000
wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025      9          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404     10          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349      1          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339      1          0.060465     5.048560
#         5  Completed    10       0.000402          128           4 0.348275      0.000473     10          0.065542    40.987182
#         6    Stopped     1       0.000022           64           4 0.314889      0.000078      1          0.067471     5.202111
#         7    Stopped     1       0.000036          256           2 0.322525      0.000072      1          0.059242     8.663731
#         8    Stopped     1       0.000013          128           4 0.248407      0.000016      1          0.067023     5.882371
#         9    Stopped     4       0.000401           64           4 0.273571      0.000334      4          0.062108    15.215293
#        10    Stopped     1       0.000029          128           4 0.466806      0.000013      1          0.062618     5.870872
#        11    Stopped     1       0.000130          128           4 0.346852      0.000013      1          0.058911     5.862995
#        12    Stopped     3       0.000299          256           4 0.224803      0.000034      3          0.067583    33.634111
#        13    Stopped     2       0.000017          128           4 0.447270      0.000408      2          0.058818     9.745891
#        14    Stopped     1       0.000023           32           4 0.462013      0.000017      1          0.192670     5.097313
#        15  Completed    10       0.000168          128           2 0.238823      0.000298     10          0.061877    32.046041
#        16    Stopped     1       0.000020          256           2 0.424400      0.000060      1          0.060366     8.532554
#        17    Stopped     3       0.000473          128           2 0.373304      0.000030      3          0.072511    10.833931
#        18    Stopped     1       0.000028           32           2 0.451347      0.000076      1          0.164916     4.516639
#        19    Stopped     1       0.000252           64           3 0.331008      0.000061      1          0.059863     4.874029
#        20    Stopped     1       0.000304          128           2 0.234978      0.000168      1          0.059063     4.816286
#        21    Stopped     4       0.000083           64           4 0.269255      0.000019      4          0.060544    15.641965
#        22    Stopped     4       0.000448           64           4 0.486316      0.000050      4          0.068614    15.641838
#        23    Stopped     1       0.000026          128           3 0.265222      0.000299      1          0.058782     5.447007
#        24    Stopped     1       0.000036          128           2 0.230533      0.000011      1          0.060163     4.834101
#        25    Stopped     1       0.000012           32           4 0.294093      0.000464      1          0.351028     4.990795
#        26    Stopped     1       0.000024           32           2 0.274232      0.000015      1          0.165567     4.520358
#        27    Stopped     1       0.000029           64           2 0.328979      0.000036      1          0.066950     4.504519
#        28 InProgress     8       0.000046          256           2 0.233842      0.000011      8          0.068021    53.608916
# 1 trials running, 28 finished (4 until the end), 580.92s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:19:11] 🚀 Trial 29 started - config: learning_rate=3.6805417363379464e-05, num_hiddens=256, num_layers=2, dropout=0.46228629787384534, weight_decay=2.5507719003203497e-05
# [10:19:26] 🚀 Trial 30 started - config: learning_rate=1.245447954661598e-05, num_hiddens=256, num_layers=2, dropout=0.45502708330412855, weight_decay=1.60924073716067e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🎉🎉🎉 HYPERPARAMETER OPTIMIZATION COMPLETE!
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# --------------------
# Resource summary (last result is reported):
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056808    29.422723
#         1    Stopped     9       0.000118          128           3 0.204920      0.000025    9.0          0.078407    32.709403
#         2  Completed    10       0.000294           64           3 0.311451      0.000404   10.0          0.064559    32.503665
#         3    Stopped     1       0.000073           64           2 0.225782      0.000349    1.0          0.058708     4.503616
#         4    Stopped     1       0.000130           32           4 0.314332      0.000339    1.0          0.060465     5.048560
#         5  Completed    10       0.000402          128           4 0.348275      0.000473   10.0          0.065542    40.987182
#         6    Stopped     1       0.000022           64           4 0.314889      0.000078    1.0          0.067471     5.202111
#         7    Stopped     1       0.000036          256           2 0.322525      0.000072    1.0          0.059242     8.663731
#         8    Stopped     1       0.000013          128           4 0.248407      0.000016    1.0          0.067023     5.882371
#         9    Stopped     4       0.000401           64           4 0.273571      0.000334    4.0          0.062108    15.215293
#        10    Stopped     1       0.000029          128           4 0.466806      0.000013    1.0          0.062618     5.870872
#        11    Stopped     1       0.000130          128           4 0.346852      0.000013    1.0          0.058911     5.862995
#        12    Stopped     3       0.000299          256           4 0.224803      0.000034    3.0          0.067583    33.634111
#        13    Stopped     2       0.000017          128           4 0.447270      0.000408    2.0          0.058818     9.745891
#        14    Stopped     1       0.000023           32           4 0.462013      0.000017    1.0          0.192670     5.097313
#        15  Completed    10       0.000168          128           2 0.238823      0.000298   10.0          0.061877    32.046041
#        16    Stopped     1       0.000020          256           2 0.424400      0.000060    1.0          0.060366     8.532554
#        17    Stopped     3       0.000473          128           2 0.373304      0.000030    3.0          0.072511    10.833931
#        18    Stopped     1       0.000028           32           2 0.451347      0.000076    1.0          0.164916     4.516639
#        19    Stopped     1       0.000252           64           3 0.331008      0.000061    1.0          0.059863     4.874029
#        20    Stopped     1       0.000304          128           2 0.234978      0.000168    1.0          0.059063     4.816286
#        21    Stopped     4       0.000083           64           4 0.269255      0.000019    4.0          0.060544    15.641965
#        22    Stopped     4       0.000448           64           4 0.486316      0.000050    4.0          0.068614    15.641838
#        23    Stopped     1       0.000026          128           3 0.265222      0.000299    1.0          0.058782     5.447007
#        24    Stopped     1       0.000036          128           2 0.230533      0.000011    1.0          0.060163     4.834101
#        25    Stopped     1       0.000012           32           4 0.294093      0.000464    1.0          0.351028     4.990795
#        26    Stopped     1       0.000024           32           2 0.274232      0.000015    1.0          0.165567     4.520358
#        27    Stopped     1       0.000029           64           2 0.328979      0.000036    1.0          0.066950     4.504519
#        28    Stopped     9       0.000046          256           2 0.233842      0.000011    9.0          0.074959    60.048501
#        29    Stopped     1       0.000037          256           2 0.462286      0.000026    1.0          0.059572     8.729133
#        30 InProgress     0       0.000012          256           2 0.455027      0.000016      -                 -            -
# 1 trials running, 30 finished (4 until the end), 595.96s wallclock-time
#
# validation_error: best 0.0554426871240139 for trial-id 28
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-25-10-09-29-568
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-25-10-09-29-568
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##15. Load Results from Temperature HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
temperature_results_path = "/root/syne-tune/python-entrypoint-2026-03-25-10-09-29-568/results.csv.zip"

# Save the results to a Pandas DataFrame
temperature_results = pd.read_csv(temperature_results_path)

# %% [markdown]
# ##16. Save the Temperature HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
temperature_hpo_results_path = Path("/content/MILL BECK_WINDERMERE MUSEUM_E_202303_temperature_hpo_results.csv")

# Save the DataFrame to a csv file
temperature_results.to_csv(temperature_hpo_results_path, index=True)
