# %% [markdown]
# # 0. Station Information
# * Station Name: TILL_HAREHOPE_E_202202
# * Water Quality Data Link: https://environment.data.gov.uk/hydrology/station/E01530A

# %% [markdown]
# ## 0. Import the Relevant Libraries

# %%
# Force installation of Syne-Tune and a compatible NumPy version (may require restarting the session after running this cell before running below import cell)
# !pip install numpy==1.26.1 syne_tune --force-reinstall -q # ignore potential error messages if listed dependencies do not match imports
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 155.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.3/254.3 kB 28.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 135.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 173.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 180.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/131.7 MB 18.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 34.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 29.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 22.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 70.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.6/293.6 MB 8.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.1 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# datasets 4.0.0 requires dill<0.3.9,>=0.3.0, but you have dill 0.4.1 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.1 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.1 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.1 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.1 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.1 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.1 which is incompatible.
# torch 2.10.0+cu128 requires nvidia-nccl-cu12==2.27.5; platform_system == "Linux", but you have nvidia-nccl-cu12 2.29.7 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# music21 9.9.1 requires numpy>=1.26.4, but you have numpy 1.26.1 which is incompatible.

# %%
# Import relevant libraries (Note: May require running of above cell to ensure compatibility of NumPy and Syne-Tune)
import torch
import logging
logging.basicConfig(level=logging.INFO)
import numpy as np
import matplotlib.pyplot as plt
from syne_tune import StoppingCriterion, Tuner
from syne_tune.backend.python_backend.python_backend import PythonBackend
from syne_tune.config_space import loguniform, randint, choice, uniform
from syne_tune.experiments import load_experiment
from syne_tune.optimizer.baselines import ASHA
import pandas as pd
from pathlib import Path

# %% [markdown]
# ##1. Specify Epoch Ranges and Reduction Factor for Hyperparameter Optimisation (HPO)

# %%
# Specify the minimum and maximum number of epochs for which a trial is allowed to run during HPO
min_number_of_epochs = 2
max_number_of_epochs = 10

# Define the reduction factor for the Asynchronous Successive Halving Algorithm (ASHA)
eta = 2 # Set to 2 so that 50% of trials are stopped at each rung of the scheduler

# %% [markdown]
# ##2. Define the Tune Function to Optimise Hyperparameters for Ammonium Prediction

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on ammonium_t_96 targets
def ammonium_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Load the raw data from the project GitHub into a Pandas DataFrame and set index as DateTime
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/river_till/TILL_HAREHOPE_E_202202/df_parameters_preprocessed.zip")
    parameter_path = "/content" / data_path / "df_parameters_preprocessed.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "ammonium"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ## 3. Define the Configuration Space for Hyperparameter Search

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %% [markdown]
# ##4. Define the Resources Available for HPO

# %%
# Define the number of parallel workers available to evaluate trials concurrently
n_workers = max(1, torch.cuda.device_count()) # Uses all available GPUs for parallel trials or defaults to 1 worker if running on CPU

# Define the maximum number of trials to test
max_number_of_trials = 30

# Define the stopping criterion for HPO
stop_criterion = StoppingCriterion(max_num_trials_started=max_number_of_trials)

# %% [markdown]
# ##5. Define Asynchronous Successive Halving Algorithm (ASHA) for HPO

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %% [markdown]
# ##6. Initialise and Run the Tuner for Ammonium HPO

# %%
# Instruct the searcher to run each trial as a Python function
trial_backend = PythonBackend(
    tune_function=ammonium_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-17-10-46-00-280
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-17-10-46-00-280
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-17-10-46-00-280
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [10:46:01] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     3        0.00001           64           2      0.2       0.00001      3          0.031973    11.561729
# 1 trials running, 0 finished (0 until the end), 20.12s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:46:36] 🚀 Trial 1 started - config: learning_rate=0.00010439339659294313, num_hiddens=256, num_layers=4, dropout=0.3866495505489972, weight_decay=0.00024191353359914058
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2  0.20000      0.000010   10.0          0.029087    29.186431
#         1 InProgress     0       0.000104          256           4  0.38665      0.000242      -                 -            -
# 1 trials running, 1 finished (0 until the end), 40.13s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2  0.20000      0.000010     10          0.029087    29.186431
#         1 InProgress     1       0.000104          256           4  0.38665      0.000242      1          0.051852    14.812736
# 1 trials running, 1 finished (0 until the end), 60.14s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2  0.20000      0.000010     10          0.029087    29.186431
#         1 InProgress     2       0.000104          256           4  0.38665      0.000242      2          0.044004    27.845766
# 1 trials running, 1 finished (0 until the end), 80.15s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2  0.20000      0.000010     10          0.029087    29.186431
#         1 InProgress     4       0.000104          256           4  0.38665      0.000242      4          0.032979    53.677244
# 1 trials running, 1 finished (0 until the end), 100.16s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2  0.20000      0.000010     10          0.029087    29.186431
#         1 InProgress     5       0.000104          256           4  0.38665      0.000242      5          0.035676    66.510414
# 1 trials running, 1 finished (0 until the end), 120.16s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2  0.20000      0.000010     10          0.029087    29.186431
#         1 InProgress     7       0.000104          256           4  0.38665      0.000242      7          0.025444    92.424886
# 1 trials running, 1 finished (0 until the end), 140.17s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2  0.20000      0.000010     10          0.029087    29.186431
#         1 InProgress     8       0.000104          256           4  0.38665      0.000242      8          0.036337   105.456120
# 1 trials running, 1 finished (0 until the end), 160.18s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:48:51] ✅ Trial 1 completed!
# [10:48:51] 🚀 Trial 2 started - config: learning_rate=0.00013419058095121434, num_hiddens=256, num_layers=2, dropout=0.45616603680083956, weight_decay=5.132937624021993e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242   10.0          0.038907   131.158836
#         2 InProgress     0       0.000134          256           2 0.456166      0.000051      -                 -            -
# 1 trials running, 2 finished (1 until the end), 180.19s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242     10          0.038907   131.158836
#         2 InProgress     2       0.000134          256           2 0.456166      0.000051      2          0.024660    16.717688
# 1 trials running, 2 finished (1 until the end), 200.20s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:49:21] 🚀 Trial 3 started - config: learning_rate=1.026508777280447e-05, num_hiddens=256, num_layers=2, dropout=0.31266297922253883, weight_decay=0.00022170395794138617
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242     10          0.038907   131.158836
#         2    Stopped     3       0.000134          256           2 0.456166      0.000051      3          0.035507    24.219291
#         3 InProgress     1       0.000010          256           2 0.312663      0.000222      1          0.032220     9.118521
# 1 trials running, 3 finished (1 until the end), 220.22s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242     10          0.038907   131.158836
#         2    Stopped     3       0.000134          256           2 0.456166      0.000051      3          0.035507    24.219291
#         3 InProgress     4       0.000010          256           2 0.312663      0.000222      4          0.027052    32.369501
# 1 trials running, 3 finished (1 until the end), 240.23s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242     10          0.038907   131.158836
#         2    Stopped     3       0.000134          256           2 0.456166      0.000051      3          0.035507    24.219291
#         3 InProgress     6       0.000010          256           2 0.312663      0.000222      6          0.033489    48.110448
# 1 trials running, 3 finished (1 until the end), 260.24s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242     10          0.038907   131.158836
#         2    Stopped     3       0.000134          256           2 0.456166      0.000051      3          0.035507    24.219291
#         3 InProgress     9       0.000010          256           2 0.312663      0.000222      9          0.028220    70.780411
# 1 trials running, 3 finished (1 until the end), 280.25s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:50:46] ✅ Trial 3 completed!
# [10:50:46] 🚀 Trial 4 started - config: learning_rate=0.00038103046250884907, num_hiddens=128, num_layers=3, dropout=0.3463494329315544, weight_decay=0.00036167315356215867
# [10:50:56] 🚀 Trial 5 started - config: learning_rate=2.9379450396273602e-05, num_hiddens=32, num_layers=4, dropout=0.20410416953481836, weight_decay=0.0001636871766905489
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242   10.0          0.038907   131.158836
#         2    Stopped     3       0.000134          256           2 0.456166      0.000051    3.0          0.035507    24.219291
#         3  Completed    10       0.000010          256           2 0.312663      0.000222   10.0          0.031087    78.270102
#         4    Stopped     1       0.000381          128           3 0.346349      0.000362    1.0          0.046452     5.445282
#         5 InProgress     0       0.000029           32           4 0.204104      0.000164      -                 -            -
# 1 trials running, 5 finished (2 until the end), 300.27s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:51:06] 🚀 Trial 6 started - config: learning_rate=3.7531209941669e-05, num_hiddens=64, num_layers=2, dropout=0.47615210301166505, weight_decay=5.870978771380628e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242     10          0.038907   131.158836
#         2    Stopped     3       0.000134          256           2 0.456166      0.000051      3          0.035507    24.219291
#         3  Completed    10       0.000010          256           2 0.312663      0.000222     10          0.031087    78.270102
#         4    Stopped     1       0.000381          128           3 0.346349      0.000362      1          0.046452     5.445282
#         5    Stopped     2       0.000029           32           4 0.204104      0.000164      2          0.039861     6.898851
#         6 InProgress     2       0.000038           64           2 0.476152      0.000059      2          0.031028     6.027219
# 1 trials running, 6 finished (2 until the end), 320.28s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:51:21] 🚀 Trial 7 started - config: learning_rate=0.00013375175522971399, num_hiddens=64, num_layers=3, dropout=0.24735483004907893, weight_decay=5.795896492259766e-05
# [10:51:36] 🚀 Trial 8 started - config: learning_rate=3.402533741204251e-05, num_hiddens=256, num_layers=3, dropout=0.4636241692559461, weight_decay=0.00015122619625167037
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242   10.0          0.038907   131.158836
#         2    Stopped     3       0.000134          256           2 0.456166      0.000051    3.0          0.035507    24.219291
#         3  Completed    10       0.000010          256           2 0.312663      0.000222   10.0          0.031087    78.270102
#         4    Stopped     1       0.000381          128           3 0.346349      0.000362    1.0          0.046452     5.445282
#         5    Stopped     2       0.000029           32           4 0.204104      0.000164    2.0          0.039861     6.898851
#         6    Stopped     4       0.000038           64           2 0.476152      0.000059    4.0          0.028695    10.938199
#         7    Stopped     4       0.000134           64           3 0.247355      0.000058    4.0          0.036416    12.307648
#         8 InProgress     0       0.000034          256           3 0.463624      0.000151      -                 -            -
# 1 trials running, 8 finished (2 until the end), 340.29s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242     10          0.038907   131.158836
#         2    Stopped     3       0.000134          256           2 0.456166      0.000051      3          0.035507    24.219291
#         3  Completed    10       0.000010          256           2 0.312663      0.000222     10          0.031087    78.270102
#         4    Stopped     1       0.000381          128           3 0.346349      0.000362      1          0.046452     5.445282
#         5    Stopped     2       0.000029           32           4 0.204104      0.000164      2          0.039861     6.898851
#         6    Stopped     4       0.000038           64           2 0.476152      0.000059      4          0.028695    10.938199
#         7    Stopped     4       0.000134           64           3 0.247355      0.000058      4          0.036416    12.307648
#         8 InProgress     1       0.000034          256           3 0.463624      0.000151      1          0.026763    11.953346
# 1 trials running, 8 finished (2 until the end), 360.30s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:52:11] 🚀 Trial 9 started - config: learning_rate=2.484435954577638e-05, num_hiddens=128, num_layers=4, dropout=0.40150389705667, weight_decay=3.793229008372636e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242   10.0          0.038907   131.158836
#         2    Stopped     3       0.000134          256           2 0.456166      0.000051    3.0          0.035507    24.219291
#         3  Completed    10       0.000010          256           2 0.312663      0.000222   10.0          0.031087    78.270102
#         4    Stopped     1       0.000381          128           3 0.346349      0.000362    1.0          0.046452     5.445282
#         5    Stopped     2       0.000029           32           4 0.204104      0.000164    2.0          0.039861     6.898851
#         6    Stopped     4       0.000038           64           2 0.476152      0.000059    4.0          0.028695    10.938199
#         7    Stopped     4       0.000134           64           3 0.247355      0.000058    4.0          0.036416    12.307648
#         8    Stopped     3       0.000034          256           3 0.463624      0.000151    3.0          0.038468    32.602621
#         9 InProgress     0       0.000025          128           4 0.401504      0.000038      -                 -            -
# 1 trials running, 9 finished (2 until the end), 380.32s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:52:21] 🚀 Trial 10 started - config: learning_rate=0.00013183272149001955, num_hiddens=64, num_layers=4, dropout=0.4248013046953226, weight_decay=5.117528976381828e-05
# [10:52:31] 🚀 Trial 11 started - config: learning_rate=2.303388044478505e-05, num_hiddens=64, num_layers=3, dropout=0.4469528905765836, weight_decay=0.00026290842894447663
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242   10.0          0.038907   131.158836
#         2    Stopped     3       0.000134          256           2 0.456166      0.000051    3.0          0.035507    24.219291
#         3  Completed    10       0.000010          256           2 0.312663      0.000222   10.0          0.031087    78.270102
#         4    Stopped     1       0.000381          128           3 0.346349      0.000362    1.0          0.046452     5.445282
#         5    Stopped     2       0.000029           32           4 0.204104      0.000164    2.0          0.039861     6.898851
#         6    Stopped     4       0.000038           64           2 0.476152      0.000059    4.0          0.028695    10.938199
#         7    Stopped     4       0.000134           64           3 0.247355      0.000058    4.0          0.036416    12.307648
#         8    Stopped     3       0.000034          256           3 0.463624      0.000151    3.0          0.038468    32.602621
#         9    Stopped     1       0.000025          128           4 0.401504      0.000038    1.0          0.037259     6.509196
#        10    Stopped     2       0.000132           64           4 0.424801      0.000051    2.0          0.028319     7.430777
#        11 InProgress     0       0.000023           64           3 0.446953      0.000263      -                 -            -
# 1 trials running, 11 finished (2 until the end), 400.33s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242     10          0.038907   131.158836
#         2    Stopped     3       0.000134          256           2 0.456166      0.000051      3          0.035507    24.219291
#         3  Completed    10       0.000010          256           2 0.312663      0.000222     10          0.031087    78.270102
#         4    Stopped     1       0.000381          128           3 0.346349      0.000362      1          0.046452     5.445282
#         5    Stopped     2       0.000029           32           4 0.204104      0.000164      2          0.039861     6.898851
#         6    Stopped     4       0.000038           64           2 0.476152      0.000059      4          0.028695    10.938199
#         7    Stopped     4       0.000134           64           3 0.247355      0.000058      4          0.036416    12.307648
#         8    Stopped     3       0.000034          256           3 0.463624      0.000151      3          0.038468    32.602621
#         9    Stopped     1       0.000025          128           4 0.401504      0.000038      1          0.037259     6.509196
#        10    Stopped     2       0.000132           64           4 0.424801      0.000051      2          0.028319     7.430777
#        11 InProgress     7       0.000023           64           3 0.446953      0.000263      7          0.030416    20.882855
# 1 trials running, 11 finished (2 until the end), 420.34s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:53:06] ✅ Trial 11 completed!
# [10:53:06] 🚀 Trial 12 started - config: learning_rate=6.285084830055439e-05, num_hiddens=256, num_layers=2, dropout=0.21014252150854415, weight_decay=0.00033926756866295465
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242   10.0          0.038907   131.158836
#         2    Stopped     3       0.000134          256           2 0.456166      0.000051    3.0          0.035507    24.219291
#         3  Completed    10       0.000010          256           2 0.312663      0.000222   10.0          0.031087    78.270102
#         4    Stopped     1       0.000381          128           3 0.346349      0.000362    1.0          0.046452     5.445282
#         5    Stopped     2       0.000029           32           4 0.204104      0.000164    2.0          0.039861     6.898851
#         6    Stopped     4       0.000038           64           2 0.476152      0.000059    4.0          0.028695    10.938199
#         7    Stopped     4       0.000134           64           3 0.247355      0.000058    4.0          0.036416    12.307648
#         8    Stopped     3       0.000034          256           3 0.463624      0.000151    3.0          0.038468    32.602621
#         9    Stopped     1       0.000025          128           4 0.401504      0.000038    1.0          0.037259     6.509196
#        10    Stopped     2       0.000132           64           4 0.424801      0.000051    2.0          0.028319     7.430777
#        11  Completed    10       0.000023           64           3 0.446953      0.000263   10.0          0.029056    29.356029
#        12 InProgress     0       0.000063          256           2 0.210143      0.000339      -                 -            -
# 1 trials running, 12 finished (3 until the end), 440.36s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:53:21] 🚀 Trial 13 started - config: learning_rate=0.0001934500669972317, num_hiddens=256, num_layers=4, dropout=0.2605973227806496, weight_decay=0.0001680243606990487
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242   10.0          0.038907   131.158836
#         2    Stopped     3       0.000134          256           2 0.456166      0.000051    3.0          0.035507    24.219291
#         3  Completed    10       0.000010          256           2 0.312663      0.000222   10.0          0.031087    78.270102
#         4    Stopped     1       0.000381          128           3 0.346349      0.000362    1.0          0.046452     5.445282
#         5    Stopped     2       0.000029           32           4 0.204104      0.000164    2.0          0.039861     6.898851
#         6    Stopped     4       0.000038           64           2 0.476152      0.000059    4.0          0.028695    10.938199
#         7    Stopped     4       0.000134           64           3 0.247355      0.000058    4.0          0.036416    12.307648
#         8    Stopped     3       0.000034          256           3 0.463624      0.000151    3.0          0.038468    32.602621
#         9    Stopped     1       0.000025          128           4 0.401504      0.000038    1.0          0.037259     6.509196
#        10    Stopped     2       0.000132           64           4 0.424801      0.000051    2.0          0.028319     7.430777
#        11  Completed    10       0.000023           64           3 0.446953      0.000263   10.0          0.029056    29.356029
#        12    Stopped     1       0.000063          256           2 0.210143      0.000339    1.0          0.035012     9.000341
#        13 InProgress     0       0.000193          256           4 0.260597      0.000168      -                 -            -
# 1 trials running, 13 finished (3 until the end), 460.37s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:53:41] 🚀 Trial 14 started - config: learning_rate=7.245765194330079e-05, num_hiddens=256, num_layers=3, dropout=0.33921697077807667, weight_decay=4.693155059880638e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242     10          0.038907   131.158836
#         2    Stopped     3       0.000134          256           2 0.456166      0.000051      3          0.035507    24.219291
#         3  Completed    10       0.000010          256           2 0.312663      0.000222     10          0.031087    78.270102
#         4    Stopped     1       0.000381          128           3 0.346349      0.000362      1          0.046452     5.445282
#         5    Stopped     2       0.000029           32           4 0.204104      0.000164      2          0.039861     6.898851
#         6    Stopped     4       0.000038           64           2 0.476152      0.000059      4          0.028695    10.938199
#         7    Stopped     4       0.000134           64           3 0.247355      0.000058      4          0.036416    12.307648
#         8    Stopped     3       0.000034          256           3 0.463624      0.000151      3          0.038468    32.602621
#         9    Stopped     1       0.000025          128           4 0.401504      0.000038      1          0.037259     6.509196
#        10    Stopped     2       0.000132           64           4 0.424801      0.000051      2          0.028319     7.430777
#        11  Completed    10       0.000023           64           3 0.446953      0.000263     10          0.029056    29.356029
#        12    Stopped     1       0.000063          256           2 0.210143      0.000339      1          0.035012     9.000341
#        13    Stopped     1       0.000193          256           4 0.260597      0.000168      1          0.059105    14.719977
#        14 InProgress     1       0.000072          256           3 0.339217      0.000047      1          0.028520    11.944756
# 1 trials running, 14 finished (3 until the end), 480.39s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:54:16] 🚀 Trial 15 started - config: learning_rate=2.6218399860515076e-05, num_hiddens=64, num_layers=4, dropout=0.41438711772900916, weight_decay=9.504713253979243e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242   10.0          0.038907   131.158836
#         2    Stopped     3       0.000134          256           2 0.456166      0.000051    3.0          0.035507    24.219291
#         3  Completed    10       0.000010          256           2 0.312663      0.000222   10.0          0.031087    78.270102
#         4    Stopped     1       0.000381          128           3 0.346349      0.000362    1.0          0.046452     5.445282
#         5    Stopped     2       0.000029           32           4 0.204104      0.000164    2.0          0.039861     6.898851
#         6    Stopped     4       0.000038           64           2 0.476152      0.000059    4.0          0.028695    10.938199
#         7    Stopped     4       0.000134           64           3 0.247355      0.000058    4.0          0.036416    12.307648
#         8    Stopped     3       0.000034          256           3 0.463624      0.000151    3.0          0.038468    32.602621
#         9    Stopped     1       0.000025          128           4 0.401504      0.000038    1.0          0.037259     6.509196
#        10    Stopped     2       0.000132           64           4 0.424801      0.000051    2.0          0.028319     7.430777
#        11  Completed    10       0.000023           64           3 0.446953      0.000263   10.0          0.029056    29.356029
#        12    Stopped     1       0.000063          256           2 0.210143      0.000339    1.0          0.035012     9.000341
#        13    Stopped     1       0.000193          256           4 0.260597      0.000168    1.0          0.059105    14.719977
#        14    Stopped     3       0.000072          256           3 0.339217      0.000047    3.0          0.035230    32.583323
#        15 InProgress     0       0.000026           64           4 0.414387      0.000095      -                 -            -
# 1 trials running, 15 finished (3 until the end), 500.41s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:54:31] 🚀 Trial 16 started - config: learning_rate=0.00019399136829817258, num_hiddens=128, num_layers=2, dropout=0.3710845149079644, weight_decay=0.00036301184499671723
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242   10.0          0.038907   131.158836
#         2    Stopped     3       0.000134          256           2 0.456166      0.000051    3.0          0.035507    24.219291
#         3  Completed    10       0.000010          256           2 0.312663      0.000222   10.0          0.031087    78.270102
#         4    Stopped     1       0.000381          128           3 0.346349      0.000362    1.0          0.046452     5.445282
#         5    Stopped     2       0.000029           32           4 0.204104      0.000164    2.0          0.039861     6.898851
#         6    Stopped     4       0.000038           64           2 0.476152      0.000059    4.0          0.028695    10.938199
#         7    Stopped     4       0.000134           64           3 0.247355      0.000058    4.0          0.036416    12.307648
#         8    Stopped     3       0.000034          256           3 0.463624      0.000151    3.0          0.038468    32.602621
#         9    Stopped     1       0.000025          128           4 0.401504      0.000038    1.0          0.037259     6.509196
#        10    Stopped     2       0.000132           64           4 0.424801      0.000051    2.0          0.028319     7.430777
#        11  Completed    10       0.000023           64           3 0.446953      0.000263   10.0          0.029056    29.356029
#        12    Stopped     1       0.000063          256           2 0.210143      0.000339    1.0          0.035012     9.000341
#        13    Stopped     1       0.000193          256           4 0.260597      0.000168    1.0          0.059105    14.719977
#        14    Stopped     3       0.000072          256           3 0.339217      0.000047    3.0          0.035230    32.583323
#        15    Stopped     3       0.000026           64           4 0.414387      0.000095    3.0          0.029735    10.861585
#        16 InProgress     0       0.000194          128           2 0.371085      0.000363      -                 -            -
# 1 trials running, 16 finished (3 until the end), 520.42s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [10:54:41] 🚀 Trial 17 started - config: learning_rate=4.4232700982955194e-05, num_hiddens=256, num_layers=2, dropout=0.23889900056836105, weight_decay=7.670377818539678e-05
# [10:54:56] 🚀 Trial 18 started - config: learning_rate=0.00019239373992209342, num_hiddens=256, num_layers=3, dropout=0.2791717858829691, weight_decay=0.00021740399699767343
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242   10.0          0.038907   131.158836
#         2    Stopped     3       0.000134          256           2 0.456166      0.000
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🎉🎉🎉 HYPERPARAMETER OPTIMIZATION COMPLETE!
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# --------------------
# Resource summary (last result is reported):
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.029087    29.186431
#         1  Completed    10       0.000104          256           4 0.386650      0.000242   10.0          0.038907   131.158836
#         2    Stopped     3       0.000134          256           2 0.456166      0.000051    3.0          0.035507    24.219291
#         3  Completed    10       0.000010          256           2 0.312663      0.000222   10.0          0.031087    78.270102
#         4    Stopped     1       0.000381          128           3 0.346349      0.000362    1.0          0.046452     5.445282
#         5    Stopped     2       0.000029           32           4 0.204104      0.000164    2.0          0.039861     6.898851
#         6    Stopped     4       0.000038           64           2 0.476152      0.000059    4.0          0.028695    10.938199
#         7    Stopped     4       0.000134           64           3 0.247355      0.000058    4.0          0.036416    12.307648
#         8    Stopped     3       0.000034          256           3 0.463624      0.000151    3.0          0.038468    32.602621
#         9    Stopped     1       0.000025          128           4 0.401504      0.000038    1.0          0.037259     6.509196
#        10    Stopped     2       0.000132           64           4 0.424801      0.000051    2.0          0.028319     7.430777
#        11  Completed    10       0.000023           64           3 0.446953      0.000263   10.0          0.029056    29.356029
#        12    Stopped     1       0.000063          256           2 0.210143      0.000339    1.0          0.035012     9.000341
#        13    Stopped     1       0.000193          256           4 0.260597      0.000168    1.0          0.059105    14.719977
#        14    Stopped     3       0.000072          256           3 0.339217      0.000047    3.0          0.035230    32.583323
#        15    Stopped     3       0.000026           64           4 0.414387      0.000095    3.0          0.029735    10.861585
#        16    Stopped     1       0.000194          128           2 0.371085      0.000363    1.0          0.034063     4.530243
#        17    Stopped     1       0.000044          256           2 0.238899      0.000077    1.0          0.032302     9.112180
#        18    Stopped     3       0.000192          256           3 0.279172      0.000217    3.0          0.040115    32.387615
#        19    Stopped     2       0.000011           32           4 0.397303      0.000341    2.0          0.079992     6.953413
#        20    Stopped     1       0.000208          256           4 0.321594      0.000051    1.0          0.059452    14.842359
#        21    Stopped     4       0.000060           64           2 0.302889      0.000138    4.0          0.028418    11.014693
#        22    Stopped     3       0.000039          256           3 0.252186      0.000016    3.0          0.034697    32.370473
#        23    Stopped     2       0.000257           32           4 0.276417      0.000026    2.0          0.035442     7.002870
#        24    Stopped     9       0.000307          128           2 0.405142      0.000140    9.0          0.036235    31.589023
#        25    Stopped     3       0.000041          256           3 0.357086      0.000031    3.0          0.035551    32.223373
#        26    Stopped     1       0.000012          128           3 0.293616      0.000027    1.0          0.037479     5.576327
#        27    Stopped     1       0.000288          256           4 0.383972      0.000193    1.0          0.058143    14.751723
#        28    Stopped     1       0.000230          128           2 0.387764      0.000113    1.0          0.031810     4.524447
#        29    Stopped     3       0.000014          256           3 0.385982      0.000017    3.0          0.038612    32.939202
#        30 InProgress     0       0.000027          128           2 0.300225      0.000428      -                 -            -
# 1 trials running, 30 finished (3 until the end), 805.66s wallclock-time
#
# validation_error: best 0.024660492315888405 for trial-id 2
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-17-10-46-00-280
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-17-10-46-00-280
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##7. Load Results from HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
ammonium_results_path = "/root/syne-tune/python-entrypoint-2026-03-17-10-46-00-280/results.csv.zip"

# Save the results to a Pandas DataFrame
ammonium_results = pd.read_csv(ammonium_results_path)

# %% [markdown]
# ##8. Save the Ammonium HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
ammonium_hpo_results_path = Path("/content/TILL_HAREHOPE_E_202202_ammonium_HPO_results.csv")

# Save the DataFrame to a csv file
ammonium_results.to_csv(ammonium_hpo_results_path, index=True)

# %% [markdown]
# ## 9. Define the Config Space, Scheduler, and Tune Function for Dissolved Oxygen HPO

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on ammonium_t_96 targets
def oxygen_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Load the raw data from the project GitHub into a Pandas DataFrame and set index as DateTime
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/river_till/TILL_HAREHOPE_E_202202/df_parameters_preprocessed.zip")
    parameter_path = "/content" / data_path / "df_parameters_preprocessed.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "oxygen_conc"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ##10. Initialise and Run the Tuner for Oxygen HPO

# %%
# Instruct the searcher to run each trial as a Python function
oxygen_trial_backend = PythonBackend(
    tune_function=oxygen_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=oxygen_trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-17-11-00-35-111
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-17-11-00-35-111
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-17-11-00-35-111
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [11:00:35] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     4        0.00001           64           2      0.2       0.00001      4          0.060292    11.172865
# 1 trials running, 0 finished (0 until the end), 20.01s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:01:05] ✅ Trial 0 completed!
# [11:01:05] 🚀 Trial 1 started - config: learning_rate=6.013728916311444e-05, num_hiddens=256, num_layers=4, dropout=0.30171341390298284, weight_decay=0.00010038801124457438
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10        0.00001           64           2 0.200000       0.00001   10.0          0.058841    26.149546
#         1 InProgress     0        0.00006          256           4 0.301713       0.00010      -                 -            -
# 1 trials running, 1 finished (1 until the end), 40.02s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:01:25] 🚀 Trial 2 started - config: learning_rate=0.0004057008568158402, num_hiddens=64, num_layers=2, dropout=0.4790766462721863, weight_decay=3.1119576524481595e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100    1.0          0.085085    14.894356
#         2 InProgress     0       0.000406           64           2 0.479077      0.000031      -                 -            -
# 1 trials running, 2 finished (1 until the end), 60.03s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:01:40] 🚀 Trial 3 started - config: learning_rate=1.3402525352031324e-05, num_hiddens=64, num_layers=4, dropout=0.21634073202877652, weight_decay=1.2541464969497857e-05
# [11:01:50] 🚀 Trial 4 started - config: learning_rate=5.844715325602222e-05, num_hiddens=128, num_layers=3, dropout=0.20664989775042583, weight_decay=2.157865130224929e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100    1.0          0.085085    14.894356
#         2    Stopped     4       0.000406           64           2 0.479077      0.000031    4.0          0.062721    10.795423
#         3    Stopped     2       0.000013           64           4 0.216341      0.000013    2.0          0.083685     7.555069
#         4 InProgress     0       0.000058          128           3 0.206650      0.000022      -                 -            -
# 1 trials running, 4 finished (1 until the end), 80.04s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100      1          0.085085    14.894356
#         2    Stopped     4       0.000406           64           2 0.479077      0.000031      4          0.062721    10.795423
#         3    Stopped     2       0.000013           64           4 0.216341      0.000013      2          0.083685     7.555069
#         4 InProgress     3       0.000058          128           3 0.206650      0.000022      3          0.059426    14.141161
# 1 trials running, 4 finished (1 until the end), 100.05s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100      1          0.085085    14.894356
#         2    Stopped     4       0.000406           64           2 0.479077      0.000031      4          0.062721    10.795423
#         3    Stopped     2       0.000013           64           4 0.216341      0.000013      2          0.083685     7.555069
#         4 InProgress     8       0.000058          128           3 0.206650      0.000022      8          0.058282    35.551615
# 1 trials running, 4 finished (1 until the end), 120.07s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:02:40] ✅ Trial 4 completed!
# [11:02:40] 🚀 Trial 5 started - config: learning_rate=0.0002599324743959948, num_hiddens=64, num_layers=2, dropout=0.4187331336329376, weight_decay=0.00010541345552997384
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100      1          0.085085    14.894356
#         2    Stopped     4       0.000406           64           2 0.479077      0.000031      4          0.062721    10.795423
#         3    Stopped     2       0.000013           64           4 0.216341      0.000013      2          0.083685     7.555069
#         4  Completed    10       0.000058          128           3 0.206650      0.000022     10          0.060162    44.154220
#         5 InProgress     2       0.000260           64           2 0.418733      0.000105      2          0.055795     6.378710
# 1 trials running, 5 finished (2 until the end), 140.08s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:03:10] 🚀 Trial 6 started - config: learning_rate=0.00036966718798036766, num_hiddens=32, num_layers=2, dropout=0.3947600859692073, weight_decay=2.480932561811585e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100    1.0          0.085085    14.894356
#         2    Stopped     4       0.000406           64           2 0.479077      0.000031    4.0          0.062721    10.795423
#         3    Stopped     2       0.000013           64           4 0.216341      0.000013    2.0          0.083685     7.555069
#         4  Completed    10       0.000058          128           3 0.206650      0.000022   10.0          0.060162    44.154220
#         5    Stopped    10       0.000260           64           2 0.418733      0.000105   10.0          0.054999    27.904906
#         6 InProgress     0       0.000370           32           2 0.394760      0.000025      -                 -            -
# 1 trials running, 6 finished (2 until the end), 160.09s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:03:25] 🚀 Trial 7 started - config: learning_rate=0.0003296905909537193, num_hiddens=128, num_layers=4, dropout=0.20671916677156127, weight_decay=6.401380341926873e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100    1.0          0.085085    14.894356
#         2    Stopped     4       0.000406           64           2 0.479077      0.000031    4.0          0.062721    10.795423
#         3    Stopped     2       0.000013           64           4 0.216341      0.000013    2.0          0.083685     7.555069
#         4  Completed    10       0.000058          128           3 0.206650      0.000022   10.0          0.060162    44.154220
#         5    Stopped    10       0.000260           64           2 0.418733      0.000105   10.0          0.054999    27.904906
#         6    Stopped     5       0.000370           32           2 0.394760      0.000025    5.0          0.065292    12.871313
#         7 InProgress     0       0.000330          128           4 0.206719      0.000064      -                 -            -
# 1 trials running, 7 finished (2 until the end), 180.10s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:03:35] 🚀 Trial 8 started - config: learning_rate=7.822377946155024e-05, num_hiddens=128, num_layers=2, dropout=0.3126241876831575, weight_decay=0.00045825305238638185
# [11:03:50] 🚀 Trial 9 started - config: learning_rate=0.0001785184135632045, num_hiddens=64, num_layers=2, dropout=0.4548343715507914, weight_decay=7.87105325599945e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100    1.0          0.085085    14.894356
#         2    Stopped     4       0.000406           64           2 0.479077      0.000031    4.0          0.062721    10.795423
#         3    Stopped     2       0.000013           64           4 0.216341      0.000013    2.0          0.083685     7.555069
#         4  Completed    10       0.000058          128           3 0.206650      0.000022   10.0          0.060162    44.154220
#         5    Stopped    10       0.000260           64           2 0.418733      0.000105   10.0          0.054999    27.904906
#         6    Stopped     5       0.000370           32           2 0.394760      0.000025    5.0          0.065292    12.871313
#         7    Stopped     1       0.000330          128           4 0.206719      0.000064    1.0          0.065436     6.523087
#         8    Stopped     3       0.000078          128           2 0.312624      0.000458    3.0          0.061795    11.052734
#         9 InProgress     0       0.000179           64           2 0.454834      0.000079      -                 -            -
# 1 trials running, 9 finished (2 until the end), 200.12s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:04:00] 🚀 Trial 10 started - config: learning_rate=3.90171772584469e-05, num_hiddens=64, num_layers=4, dropout=0.44289071447320266, weight_decay=0.000183908220947303
# [11:04:10] 🚀 Trial 11 started - config: learning_rate=0.00024091358748868047, num_hiddens=256, num_layers=4, dropout=0.28978640466735467, weight_decay=0.00021246939670729209
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100    1.0          0.085085    14.894356
#         2    Stopped     4       0.000406           64           2 0.479077      0.000031    4.0          0.062721    10.795423
#         3    Stopped     2       0.000013           64           4 0.216341      0.000013    2.0          0.083685     7.555069
#         4  Completed    10       0.000058          128           3 0.206650      0.000022   10.0          0.060162    44.154220
#         5    Stopped    10       0.000260           64           2 0.418733      0.000105   10.0          0.054999    27.904906
#         6    Stopped     5       0.000370           32           2 0.394760      0.000025    5.0          0.065292    12.871313
#         7    Stopped     1       0.000330          128           4 0.206719      0.000064    1.0          0.065436     6.523087
#         8    Stopped     3       0.000078          128           2 0.312624      0.000458    3.0          0.061795    11.052734
#         9    Stopped     2       0.000179           64           2 0.454834      0.000079    2.0          0.056734     5.833454
#        10    Stopped     2       0.000039           64           4 0.442891      0.000184    2.0          0.088148     7.431406
#        11 InProgress     0       0.000241          256           4 0.289786      0.000212      -                 -            -
# 1 trials running, 11 finished (2 until the end), 220.14s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:04:30] 🚀 Trial 12 started - config: learning_rate=8.183402010595743e-05, num_hiddens=64, num_layers=4, dropout=0.47585867130253345, weight_decay=9.160597107597026e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100    1.0          0.085085    14.894356
#         2    Stopped     4       0.000406           64           2 0.479077      0.000031    4.0          0.062721    10.795423
#         3    Stopped     2       0.000013           64           4 0.216341      0.000013    2.0          0.083685     7.555069
#         4  Completed    10       0.000058          128           3 0.206650      0.000022   10.0          0.060162    44.154220
#         5    Stopped    10       0.000260           64           2 0.418733      0.000105   10.0          0.054999    27.904906
#         6    Stopped     5       0.000370           32           2 0.394760      0.000025    5.0          0.065292    12.871313
#         7    Stopped     1       0.000330          128           4 0.206719      0.000064    1.0          0.065436     6.523087
#         8    Stopped     3       0.000078          128           2 0.312624      0.000458    3.0          0.061795    11.052734
#         9    Stopped     2       0.000179           64           2 0.454834      0.000079    2.0          0.056734     5.833454
#        10    Stopped     2       0.000039           64           4 0.442891      0.000184    2.0          0.088148     7.431406
#        11    Stopped     1       0.000241          256           4 0.289786      0.000212    1.0          0.082112    14.677832
#        12 InProgress     0       0.000082           64           4 0.475859      0.000092      -                 -            -
# 1 trials running, 12 finished (2 until the end), 240.15s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:04:40] 🚀 Trial 13 started - config: learning_rate=0.00014662927614459478, num_hiddens=128, num_layers=4, dropout=0.33594268113557957, weight_decay=0.0004166878292928419
# [11:04:50] 🚀 Trial 14 started - config: learning_rate=0.0002622590053732097, num_hiddens=64, num_layers=4, dropout=0.33601987034556735, weight_decay=1.1481649446054846e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100    1.0          0.085085    14.894356
#         2    Stopped     4       0.000406           64           2 0.479077      0.000031    4.0          0.062721    10.795423
#         3    Stopped     2       0.000013           64           4 0.216341      0.000013    2.0          0.083685     7.555069
#         4  Completed    10       0.000058          128           3 0.206650      0.000022   10.0          0.060162    44.154220
#         5    Stopped    10       0.000260           64           2 0.418733      0.000105   10.0          0.054999    27.904906
#         6    Stopped     5       0.000370           32           2 0.394760      0.000025    5.0          0.065292    12.871313
#         7    Stopped     1       0.000330          128           4 0.206719      0.000064    1.0          0.065436     6.523087
#         8    Stopped     3       0.000078          128           2 0.312624      0.000458    3.0          0.061795    11.052734
#         9    Stopped     2       0.000179           64           2 0.454834      0.000079    2.0          0.056734     5.833454
#        10    Stopped     2       0.000039           64           4 0.442891      0.000184    2.0          0.088148     7.431406
#        11    Stopped     1       0.000241          256           4 0.289786      0.000212    1.0          0.082112    14.677832
#        12    Stopped     2       0.000082           64           4 0.475859      0.000092    2.0          0.089156     7.354838
#        13    Stopped     1       0.000147          128           4 0.335943      0.000417    1.0          0.083838     6.547625
#        14 InProgress     0       0.000262           64           4 0.336020      0.000011      -                 -            -
# 1 trials running, 14 finished (2 until the end), 260.17s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:05:00] 🚀 Trial 15 started - config: learning_rate=2.2581859283121558e-05, num_hiddens=256, num_layers=4, dropout=0.32732345827057097, weight_decay=5.450784093131121e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100    1.0          0.085085    14.894356
#         2    Stopped     4       0.000406           64           2 0.479077      0.000031    4.0          0.062721    10.795423
#         3    Stopped     2       0.000013           64           4 0.216341      0.000013    2.0          0.083685     7.555069
#         4  Completed    10       0.000058          128           3 0.206650      0.000022   10.0          0.060162    44.154220
#         5    Stopped    10       0.000260           64           2 0.418733      0.000105   10.0          0.054999    27.904906
#         6    Stopped     5       0.000370           32           2 0.394760      0.000025    5.0          0.065292    12.871313
#         7    Stopped     1       0.000330          128           4 0.206719      0.000064    1.0          0.065436     6.523087
#         8    Stopped     3       0.000078          128           2 0.312624      0.000458    3.0          0.061795    11.052734
#         9    Stopped     2       0.000179           64           2 0.454834      0.000079    2.0          0.056734     5.833454
#        10    Stopped     2       0.000039           64           4 0.442891      0.000184    2.0          0.088148     7.431406
#        11    Stopped     1       0.000241          256           4 0.289786      0.000212    1.0          0.082112    14.677832
#        12    Stopped     2       0.000082           64           4 0.475859      0.000092    2.0          0.089156     7.354838
#        13    Stopped     1       0.000147          128           4 0.335943      0.000417    1.0          0.083838     6.547625
#        14    Stopped     2       0.000262           64           4 0.336020      0.000011    2.0          0.062097     7.439358
#        15 InProgress     0       0.000023          256           4 0.327323      0.000055      -                 -            -
# 1 trials running, 15 finished (2 until the end), 280.17s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:05:20] 🚀 Trial 16 started - config: learning_rate=2.496644764007189e-05, num_hiddens=256, num_layers=4, dropout=0.2527446214010899, weight_decay=2.4913911015104402e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100    1.0          0.085085    14.894356
#         2    Stopped     4       0.000406           64           2 0.479077      0.000031    4.0          0.062721    10.795423
#         3    Stopped     2       0.000013           64           4 0.216341      0.000013    2.0          0.083685     7.555069
#         4  Completed    10       0.000058          128           3 0.206650      0.000022   10.0          0.060162    44.154220
#         5    Stopped    10       0.000260           64           2 0.418733      0.000105   10.0          0.054999    27.904906
#         6    Stopped     5       0.000370           32           2 0.394760      0.000025    5.0          0.065292    12.871313
#         7    Stopped     1       0.000330          128           4 0.206719      0.000064    1.0          0.065436     6.523087
#         8    Stopped     3       0.000078          128           2 0.312624      0.000458    3.0          0.061795    11.052734
#         9    Stopped     2       0.000179           64           2 0.454834      0.000079    2.0          0.056734     5.833454
#        10    Stopped     2       0.000039           64           4 0.442891      0.000184    2.0          0.088148     7.431406
#        11    Stopped     1       0.000241          256           4 0.289786      0.000212    1.0          0.082112    14.677832
#        12    Stopped     2       0.000082           64           4 0.475859      0.000092    2.0          0.089156     7.354838
#        13    Stopped     1       0.000147          128           4 0.335943      0.000417    1.0          0.083838     6.547625
#        14    Stopped     2       0.000262           64           4 0.336020      0.000011    2.0          0.062097     7.439358
#        15    Stopped     1       0.000023          256           4 0.327323      0.000055    1.0          0.085178    14.776601
#        16 InProgress     0       0.000025          256           4 0.252745      0.000025      -                 -            -
# 1 trials running, 16 finished (2 until the end), 300.19s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:05:40] 🚀 Trial 17 started - config: learning_rate=0.00019484505036795218, num_hiddens=64, num_layers=3, dropout=0.4065643111133038, weight_decay=2.0850640055901758e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100      1          0.085085    14.894356
#         2    Stopped     4       0.000406           64           2 0.479077      0.000031      4          0.062721    10.795423
#         3    Stopped     2       0.000013           64           4 0.216341      0.000013      2          0.083685     7.555069
#         4  Completed    10       0.000058          128           3 0.206650      0.000022     10          0.060162    44.154220
#         5    Stopped    10       0.000260           64           2 0.418733      0.000105     10          0.054999    27.904906
#         6    Stopped     5       0.000370           32           2 0.394760      0.000025      5          0.065292    12.871313
#         7    Stopped     1       0.000330          128           4 0.206719      0.000064      1          0.065436     6.523087
#         8    Stopped     3       0.000078          128           2 0.312624      0.000458      3          0.061795    11.052734
#         9    Stopped     2       0.000179           64           2 0.454834      0.000079      2          0.056734     5.833454
#        10    Stopped     2       0.000039           64           4 0.442891      0.000184      2          0.088148     7.431406
#        11    Stopped     1       0.000241          256           4 0.289786      0.000212      1          0.082112    14.677832
#        12    Stopped     2       0.000082           64           4 0.475859      0.000092      2          0.089156     7.354838
#        13    Stopped     1       0.000147          128           4 0.335943      0.000417      1          0.083838     6.547625
#        14    Stopped     2       0.000262           64           4 0.336020      0.000011      2          0.062097     7.439358
#        15    Stopped     1       0.000023          256           4 0.327323      0.000055      1          0.085178    14.776601
#        16    Stopped     1       0.000025          256           4 0.252745      0.000025      1          0.086743    14.830331
#        17 InProgress     2       0.000195           64           3 0.406564      0.000021      2          0.057896     6.784309
# 1 trials running, 17 finished (2 until the end), 320.20s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:06:10] 🚀 Trial 18 started - config: learning_rate=6.68120600447857e-05, num_hiddens=64, num_layers=2, dropout=0.29328941737172676, weight_decay=4.405321013492592e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100    1.0          0.085085    14.894356
#         2    Stopped     4       0.000406           64           2 0.479077      0.000031    4.0          0.062721    10.795423
#         3    Stopped     2       0.000013           64           4 0.216341      0.000013    2.0          0.083685     7.555069
#         4  Completed    10       0.000058          128           3 0.206650      0.000022   10.0          0.060162    44.154220
#         5    Stopped    10       0.000260           64           2 0.418733      0.000105   10.0          0.054999    27.904906
#         6    Stopped     5       0.000370           32           2 0.394760      0.000025    5.0          0.065292    12.871313
#         7    Stopped     1       0.000330          128           4 0.206719      0.000064    1.0          0.065436     6.523087
#         8    Stopped     3       0.000078          128           2 0.312624      0.000458    3.0          0.061795    11.052734
#         9    Stopped     2       0.000179           64           2 0.454834      0.000079    2.0          0.056734     5.833454
#        10    Stopped     2       0.000039           64           4 0.442891      0.000184    2.0          0.088148     7.431406
#        11    Stopped     1       0.000241          256           4 0.289786      0.000212    1.0          0.082112    14.677832
#        12    Stopped     2       0.000082           64           4 0.475859      0.000092    2.0          0.089156     7.354838
#        13    Stopped     1       0.000147          128           4 0.335943      0.000417    1.0          0.083838     6.547625
#        14    Stopped     2       0.000262           64           4 0.336020      0.000011    2.0          0.062097     7.439358
#        15    Stopped     1       0.000023          256           4 0.327323      0.000055    1.0          0.085178    14.776601
#        16    Stopped     1       0.000025          256           4 0.252745      0.000025    1.0          0.086743    14.830331
#        17    Stopped     9       0.000195           64           3 0.406564      0.000021    9.0          0.067082    26.766410
#        18 InProgress     0       0.000067           64           2 0.293289      0.000044      -                 -            -
# 1 trials running, 18 finished (2 until the end), 340.22s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100      1          0.085085    14.894356
#         2    Stopped     4       0.000406           64           2 0.479077      0.000031      4          0.062721    10.795423
#         3    Stopped     2       0.000013           64           4 0.216341      0.000013      2          0.083685     7.555069
#         4  Completed    10       0.000058          128           3 0.206650      0.000022     10          0.060162    44.154220
#         5    Stopped    10       0.000260           64           2 0.418733      0.000105     10          0.054999    27.904906
#         6    Stopped     5       0.000370           32           2 0.394760      0.000025      5          0.065292    12.871313
#         7    Stopped     1       0.000330          128           4 0.206719      0.000064      1          0.065436     6.523087
#         8    Stopped     3       0.000078          128           2 0.312624      0.000458      3          0.061795    11.052734
#         9    Stopped     2       0.000179           64           2 0.454834      0.000079      2          0.056734     5.833454
#        10    Stopped     2       0.000039           64           4 0.442891      0.000184      2          0.088148     7.431406
#        11    Stopped     1       0.000241          256           4 0.289786      0.000212      1          0.082112    14.677832
#        12    Stopped     2       0.000082           64           4 0.475859      0.000092      2          0.089156     7.354838
#        13    Stopped     1       0.000147          128           4 0.335943      0.000417      1          0.083838     6.547625
#        14    Stopped     2       0.000262           64           4 0.336020      0.000011      2          0.062097     7.439358
#        15    Stopped     1       0.000023          256           4 0.327323      0.000055      1          0.085178    14.776601
#        16    Stopped     1       0.000025          256           4 0.252745      0.000025      1          0.086743    14.830331
#        17    Stopped     9       0.000195           64           3 0.406564      0.000021      9          0.067082    26.766410
#        18 InProgress     6       0.000067           64           2 0.293289      0.000044      6          0.053315    16.836811
# 1 trials running, 18 finished (2 until the end), 360.24s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:06:41] 🚀 Trial 19 started - config: learning_rate=7.472467494058846e-05, num_hiddens=128, num_layers=4, dropout=0.4973265861050267, weight_decay=0.0004059671666935504
# [11:06:51] 🚀 Trial 20 started - config: learning_rate=0.0004429430840624391, num_hiddens=256, num_layers=3, dropout=0.44157837603639005, weight_decay=2.7681804207954856e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100    1.0          0.085085    14.894356
#         2    Stopped     4       0.000406           64           2 0.479077      0.000031    4.0          0.062721    10.795423
#         3    Stopped     2       0.000013           64           4 0.216341      0.000013    2.0          0.083685     7.555069
#         4  Completed    10       0.000058          128           3 0.206650      0.000
wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100      1          0.085085    14.894356
#         2    Stopped     4       0.000406           64           2 0.479077      0.000031      4          0.062721    10.795423
#         3    Stopped     2       0.000013           64           4 0.216341      0.000013      2          0.083685     7.555069
#         4  Completed    10       0.000058          128           3 0.206650      0.000022     10          0.060162    44.154220
# ...
#         9    Stopped     2       0.000179           64           2 0.454834      0.000079    2.0          0.056734     5.833454
#        10    Stopped     2       0.000039           64           4 0.442891      0.000184    2.0          0.088148     7.431406
#        11    Stopped     1       0.000241          256           4 0.289786      0.000212    1.0          0.082112    14.677832
#        12    Stopped     2       0.000082           64           4 0.475859      0.000092    2.0          0.089156     7.354838
#        13    Stopped     1       0.000147          128           4 0.335943      0.000417    1.0          0.083838     6.547625
#        14    Stopped     2       0.000262           64           4 0.336020      0.000011    2.0          0.062097     7.439358
#        15    Stopped     1       0.000023          256           4 0.327323      0.000055    1.0          0.085178    14.776601
#        16    Stopped     1       0.000025          256           4 0.252745      0.000025    1.0          0.086743    14.830331
#        17    Stopped     9       0.000195           64           3 0.406564      0.000021    9.0          0.067082    26.766410
#        18    Stopped    10       0.000067           64           2 0.293289      0.000044   10.0          0.056583    27.466326
#        19    Stopped     1       0.000075          128           4 0.497327      0.000406    1.0          0.084866     6.510778
#        20    Stopped     9       0.000443          256           3 0.441578      0.000028    9.0          0.059716    94.438603
#        21  Completed    10       0.000070          128           2 0.302105      0.000090   10.0          0.055541    34.984034
#        22    Stopped     1       0.000017          128           4 0.282013      0.000163    1.0          0.080091     6.527160
#        23    Stopped     1       0.000043          256           4 0.368533      0.000032    1.0          0.086691    14.730753
#        24    Stopped     2       0.000465           32           3 0.424236      0.000037    2.0          0.058696     6.220106
#        25 InProgress     0       0.000101           32           3 0.419685      0.000010      -                 -            -
# 1 trials running, 25 finished (3 until the end), 560.40s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:10:01] 🚀 Trial 26 started - config: learning_rate=0.0004321423813286081, num_hiddens=32, num_layers=2, dropout=0.48322723452902006, weight_decay=5.229229529415429e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100      1          0.085085    14.894356
#         2    Stopped     4       0.000406           64           2 0.479077      0.000031      4          0.062721    10.795423
#         3    Stopped     2       0.000013           64           4 0.216341      0.000013      2          0.083685     7.555069
#         4  Completed    10       0.000058          128           3 0.206650      0.000022     10          0.060162    44.154220
#         5    Stopped    10       0.000260           64           2 0.418733      0.000105     10          0.054999    27.904906
#         6    Stopped     5       0.000370           32           2 0.394760      0.000025      5          0.065292    12.871313
#         7    Stopped     1       0.000330          128           4 0.206719      0.000064      1          0.065436     6.523087
#         8    Stopped     3       0.000078          128           2 0.312624      0.000458      3          0.061795    11.052734
#         9    Stopped     2       0.000179           64           2 0.454834      0.000079      2          0.056734     5.833454
#        10    Stopped     2       0.000039           64           4 0.442891      0.000184      2          0.088148     7.431406
#        11    Stopped     1       0.000241          256           4 0.289786      0.000212      1          0.082112    14.677832
#        12    Stopped     2       0.000082           64           4 0.475859      0.000092      2          0.089156     7.354838
#        13    Stopped     1       0.000147          128           4 0.335943      0.000417      1          0.083838     6.547625
#        14    Stopped     2       0.000262           64           4 0.336020      0.000011      2          0.062097     7.439358
#        15    Stopped     1       0.000023          256           4 0.327323      0.000055      1          0.085178    14.776601
#        16    Stopped     1       0.000025          256           4 0.252745      0.000025      1          0.086743    14.830331
#        17    Stopped     9       0.000195           64           3 0.406564      0.000021      9          0.067082    26.766410
#        18    Stopped    10       0.000067           64           2 0.293289      0.000044     10          0.056583    27.466326
#        19    Stopped     1       0.000075          128           4 0.497327      0.000406      1          0.084866     6.510778
#        20    Stopped     9       0.000443          256           3 0.441578      0.000028      9          0.059716    94.438603
#        21  Completed    10       0.000070          128           2 0.302105      0.000090     10          0.055541    34.984034
#        22    Stopped     1       0.000017          128           4 0.282013      0.000163      1          0.080091     6.527160
#        23    Stopped     1       0.000043          256           4 0.368533      0.000032      1          0.086691    14.730753
#        24    Stopped     2       0.000465           32           3 0.424236      0.000037      2          0.058696     6.220106
#        25    Stopped     2       0.000101           32           3 0.419685      0.000010      2          0.071615     6.270128
#        26 InProgress     2       0.000432           32           2 0.483227      0.000052      2          0.066098     5.749368
# 1 trials running, 26 finished (3 until the end), 580.42s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:10:16] 🚀 Trial 27 started - config: learning_rate=7.204432885540287e-05, num_hiddens=32, num_layers=4, dropout=0.2752372710744966, weight_decay=0.00033268738476212057
# [11:10:26] 🚀 Trial 28 started - config: learning_rate=2.3895408471648264e-05, num_hiddens=128, num_layers=4, dropout=0.4229860989066746, weight_decay=8.630018304695566e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.058841    26.149546
#         1    Stopped     1       0.000060          256           4 0.301713      0.000100    1.0          0.085085    14.894356
#         2    Stopped     4       0.000406           64           2 0.479077      0.000
#        14    Stopped     2       0.000262           64           4 0.336020      0.000011    2.0          0.062097     7.439358
#        15    Stopped     1       0.000023          256           4 0.327323      0.000055    1.0          0.085178    14.776601
#        16    Stopped     1       0.000025          256           4 0.252745      0.000025    1.0          0.086743    14.830331
#        17    Stopped     9       0.000195           64           3 0.406564      0.000021    9.0          0.067082    26.766410
#        18    Stopped    10       0.000067           64           2 0.293289      0.000044   10.0          0.056583    27.466326
#        19    Stopped     1       0.000075          128           4 0.497327      0.000406    1.0          0.084866     6.510778
#        20    Stopped     9       0.000443          256           3 0.441578      0.000028    9.0          0.059716    94.438603
#        21  Completed    10       0.000070          128           2 0.302105      0.000090   10.0          0.055541    34.984034
#        22    Stopped     1       0.000017          128           4 0.282013      0.000163    1.0          0.080091     6.527160
#        23    Stopped     1       0.000043          256           4 0.368533      0.000032    1.0          0.086691    14.730753
#        24    Stopped     2       0.000465           32           3 0.424236      0.000037    2.0          0.058696     6.220106
#        25    Stopped     2       0.000101           32           3 0.419685      0.000010    2.0          0.071615     6.270128
#        26    Stopped     4       0.000432           32           2 0.483227      0.000052    4.0          0.060058    10.686746
#        27    Stopped     2       0.000072           32           4 0.275237      0.000333    2.0          0.088772     6.909340
#        28    Stopped     1       0.000024          128           4 0.422986      0.000086    1.0          0.080981     6.520529
#        29    Stopped     5       0.000096           32           2 0.395392      0.000268    5.0          0.059817    12.902732
#        30 InProgress     0       0.000103          256           4 0.399009      0.000015      -                 -            -
# 1 trials running, 30 finished (3 until the end), 615.46s wallclock-time
#
# validation_error: best 0.05228583887219429 for trial-id 20
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-17-11-00-35-111
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-17-11-00-35-111
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##11. Load Results from Dissolved Oxygen HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
oxygen_results_path = "/root/syne-tune/python-entrypoint-2026-03-17-11-00-35-111/results.csv.zip"

# Save the results to a Pandas DataFrame
oxygen_results = pd.read_csv(oxygen_results_path)

# %% [markdown]
# ##12. Save the Oxygen HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
oxygen_hpo_results_path = Path("/content/TILL_HAREHOPE_E_202202_oxygen_HPO_results.csv")

# Save the DataFrame to a csv file
oxygen_results.to_csv(oxygen_hpo_results_path, index=True)

# %% [markdown]
# ## 13. Define the Config Space, Scheduler, and Tune Function for Temperature HPO

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on temperature_t_96 targets
def temperature_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Load the raw data from the project GitHub into a Pandas DataFrame and set index as DateTime
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/river_till/TILL_HAREHOPE_E_202202/df_parameters_preprocessed.zip")
    parameter_path = "/content" / data_path / "df_parameters_preprocessed.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "temperature"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ##14. Initialise and Run the Tuner for Temperature HPO

# %%
# Instruct the searcher to run each trial as a Python function
temperature_trial_backend = PythonBackend(
    tune_function=temperature_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=temperature_trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-17-11-13-43-929
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-17-11-13-43-929
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-17-11-13-43-929
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [11:13:44] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     4        0.00001           64           2      0.2       0.00001      4          0.046089      11.0116
# 1 trials running, 0 finished (0 until the end), 20.01s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:14:14] ✅ Trial 0 completed!
# [11:14:14] 🚀 Trial 1 started - config: learning_rate=1.4497246292406483e-05, num_hiddens=64, num_layers=4, dropout=0.4914834297060284, weight_decay=0.00016079234933872455
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.045281    25.815247
#         1 InProgress     0       0.000014           64           4 0.491483      0.000161      -                 -            -
# 1 trials running, 1 finished (1 until the end), 40.02s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:14:24] 🚀 Trial 2 started - config: learning_rate=0.00013641637100394788, num_hiddens=32, num_layers=4, dropout=0.33486430626175523, weight_decay=0.00016961732377506164
# [11:14:39] 🚀 Trial 3 started - config: learning_rate=0.00011320523364581777, num_hiddens=128, num_layers=4, dropout=0.4041907399747341, weight_decay=1.5550519491699846e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161    2.0          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170    3.0          0.050796     9.802736
#         3 InProgress     0       0.000113          128           4 0.404191      0.000016      -                 -            -
# 1 trials running, 3 finished (1 until the end), 60.03s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161      2          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170      3          0.050796     9.802736
#         3 InProgress     3       0.000113          128           4 0.404191      0.000016      3          0.045560    16.947587
# 1 trials running, 3 finished (1 until the end), 80.04s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161      2          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170      3          0.050796     9.802736
#         3 InProgress     6       0.000113          128           4 0.404191      0.000016      6          0.048903    33.004269
# 1 trials running, 3 finished (1 until the end), 100.06s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:15:34] 🚀 Trial 4 started - config: learning_rate=3.940909497403652e-05, num_hiddens=32, num_layers=2, dropout=0.21950737016571087, weight_decay=4.242537830110798e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161    2.0          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170    3.0          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016    9.0          0.055546    48.817675
#         4 InProgress     0       0.000039           32           2 0.219507      0.000042      -                 -            -
# 1 trials running, 4 finished (1 until the end), 120.07s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161      2          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170      3          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016      9          0.055546    48.817675
#         4 InProgress     9       0.000039           32           2 0.219507      0.000042      9          0.047307    22.551034
# 1 trials running, 4 finished (1 until the end), 140.08s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:16:04] ✅ Trial 4 completed!
# [11:16:04] 🚀 Trial 5 started - config: learning_rate=0.00038674256751110195, num_hiddens=128, num_layers=4, dropout=0.45281135428852065, weight_decay=1.1071246047254263e-05
# [11:16:14] 🚀 Trial 6 started - config: learning_rate=4.269553853764782e-05, num_hiddens=64, num_layers=2, dropout=0.2873752147686701, weight_decay=0.00015115965103455276
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161    2.0          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170    3.0          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016    9.0          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042   10.0          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011    1.0          0.063736     6.531056
#         6 InProgress     0       0.000043           64           2 0.287375      0.000151      -                 -            -
# 1 trials running, 6 finished (2 until the end), 160.09s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161      2          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170      3          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016      9          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042     10          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011      1          0.063736     6.531056
#         6 InProgress     8       0.000043           64           2 0.287375      0.000151      8          0.043276    20.821042
# 1 trials running, 6 finished (2 until the end), 180.11s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:16:44] ✅ Trial 6 completed!
# [11:16:44] 🚀 Trial 7 started - config: learning_rate=1.598513064336813e-05, num_hiddens=32, num_layers=2, dropout=0.2314137616281587, weight_decay=0.00015832400135820041
# [11:16:54] 🚀 Trial 8 started - config: learning_rate=2.4377370028798706e-05, num_hiddens=256, num_layers=3, dropout=0.2289972941251435, weight_decay=0.00010243303171594045
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161    2.0          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170    3.0          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016    9.0          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042   10.0          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011    1.0          0.063736     6.531056
#         6  Completed    10       0.000043           64           2 0.287375      0.000151   10.0          0.043504    25.815861
#         7    Stopped     2       0.000016           32           2 0.231414      0.000158    2.0          0.048721     5.660421
#         8 InProgress     0       0.000024          256           3 0.228997      0.000102      -                 -            -
# 1 trials running, 8 finished (3 until the end), 200.12s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161      2          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170      3          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016      9          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042     10          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011      1          0.063736     6.531056
#         6  Completed    10       0.000043           64           2 0.287375      0.000151     10          0.043504    25.815861
#         7    Stopped     2       0.000016           32           2 0.231414      0.000158      2          0.048721     5.660421
#         8 InProgress     2       0.000024          256           3 0.228997      0.000102      2          0.045049    22.281662
# 1 trials running, 8 finished (3 until the end), 220.13s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161      2          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170      3          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016      9          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042     10          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011      1          0.063736     6.531056
#         6  Completed    10       0.000043           64           2 0.287375      0.000151     10          0.043504    25.815861
#         7    Stopped     2       0.000016           32           2 0.231414      0.000158      2          0.048721     5.660421
#         8 InProgress     3       0.000024          256           3 0.228997      0.000102      3          0.044487    32.472653
# 1 trials running, 8 finished (3 until the end), 240.14s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161      2          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170      3          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016      9          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042     10          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011      1          0.063736     6.531056
#         6  Completed    10       0.000043           64           2 0.287375      0.000151     10          0.043504    25.815861
#         7    Stopped     2       0.000016           32           2 0.231414      0.000158      2          0.048721     5.660421
#         8 InProgress     5       0.000024          256           3 0.228997      0.000102      5          0.045669    53.120654
# 1 trials running, 8 finished (3 until the end), 260.16s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161      2          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170      3          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016      9          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042     10          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011      1          0.063736     6.531056
#         6  Completed    10       0.000043           64           2 0.287375      0.000151     10          0.043504    25.815861
#         7    Stopped     2       0.000016           32           2 0.231414      0.000158      2          0.048721     5.660421
#         8 InProgress     7       0.000024          256           3 0.228997      0.000102      7          0.044723    73.725348
# 1 trials running, 8 finished (3 until the end), 280.17s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161      2          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170      3          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016      9          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042     10          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011      1          0.063736     6.531056
#         6  Completed    10       0.000043           64           2 0.287375      0.000151     10          0.043504    25.815861
#         7    Stopped     2       0.000016           32           2 0.231414      0.000158      2          0.048721     5.660421
#         8 InProgress     9       0.000024          256           3 0.228997      0.000102      9          0.045263    94.415287
# 1 trials running, 8 finished (3 until the end), 300.18s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:18:44] ✅ Trial 8 completed!
# [11:18:44] 🚀 Trial 9 started - config: learning_rate=0.0001717231263582274, num_hiddens=256, num_layers=4, dropout=0.3299783258929233, weight_decay=0.00012438306214975658
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161    2.0          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170    3.0          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016    9.0          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042   10.0          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011    1.0          0.063736     6.531056
#         6  Completed    10       0.000043           64           2 0.287375      0.000151   10.0          0.043504    25.815861
#         7    Stopped     2       0.000016           32           2 0.231414      0.000158    2.0          0.048721     5.660421
#         8  Completed    10       0.000024          256           3 0.228997      0.000102   10.0          0.044575   104.861553
#         9 InProgress     0       0.000172          256           4 0.329978      0.000124      -                 -            -
# 1 trials running, 9 finished (4 until the end), 320.19s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:19:04] 🚀 Trial 10 started - config: learning_rate=4.10686322168983e-05, num_hiddens=64, num_layers=3, dropout=0.25702106418833803, weight_decay=0.00031699183004773625
# [11:19:19] 🚀 Trial 11 started - config: learning_rate=0.0002739525233437443, num_hiddens=256, num_layers=4, dropout=0.2511822208628017, weight_decay=3.641391002397685e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161    2.0          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170    3.0          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016    9.0          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042   10.0          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011    1.0          0.063736     6.531056
#         6  Completed    10       0.000043           64           2 0.287375      0.000151   10.0          0.043504    25.815861
#         7    Stopped     2       0.000016           32           2 0.231414      0.000158    2.0          0.048721     5.660421
#         8  Completed    10       0.000024          256           3 0.228997      0.000102   10.0          0.044575   104.861553
#         9    Stopped     1       0.000172          256           4 0.329978      0.000124    1.0          0.082705    14.762361
#        10    Stopped     4       0.000041           64           3 0.257021      0.000317    4.0          0.047961    12.432484
#        11 InProgress     0       0.000274          256           4 0.251182      0.000036      -                 -            -
# 1 trials running, 11 finished (4 until the end), 340.21s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:19:39] 🚀 Trial 12 started - config: learning_rate=0.0001551582737094818, num_hiddens=64, num_layers=2, dropout=0.4130768754373122, weight_decay=0.0001607041462319031
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161    2.0          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170    3.0          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016    9.0          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042   10.0          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011    1.0          0.063736     6.531056
#         6  Completed    10       0.000043           64           2 0.287375      0.000151   10.0          0.043504    25.815861
#         7    Stopped     2       0.000016           32           2 0.231414      0.000158    2.0          0.048721     5.660421
#         8  Completed    10       0.000024          256           3 0.228997      0.000102   10.0          0.044575   104.861553
#         9    Stopped     1       0.000172          256           4 0.329978      0.000124    1.0          0.082705    14.762361
#        10    Stopped     4       0.000041           64           3 0.257021      0.000317    4.0          0.047961    12.432484
#        11    Stopped     1       0.000274          256           4 0.251182      0.000036    1.0          0.094395    14.785686
#        12 InProgress     0       0.000155           64           2 0.413077      0.000161      -                 -            -
# 1 trials running, 12 finished (4 until the end), 360.23s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:19:54] 🚀 Trial 13 started - config: learning_rate=2.5100192107124435e-05, num_hiddens=64, num_layers=2, dropout=0.3618417477230073, weight_decay=1.0770852620201298e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161    2.0          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170    3.0          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016    9.0          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042   10.0          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011    1.0          0.063736     6.531056
#         6  Completed    10       0.000043           64           2 0.287375      0.000151   10.0          0.043504    25.815861
#         7    Stopped     2       0.000016           32           2 0.231414      0.000158    2.0          0.048721     5.660421
#         8  Completed    10       0.000024          256           3 0.228997      0.000102   10.0          0.044575   104.861553
#         9    Stopped     1       0.000172          256           4 0.329978      0.000124    1.0          0.082705    14.762361
#        10    Stopped     4       0.000041           64           3 0.257021      0.000317    4.0          0.047961    12.432484
#        11    Stopped     1       0.000274          256           4 0.251182      0.000036    1.0          0.094395    14.785686
#        12    Stopped     4       0.000155           64           2 0.413077      0.000161    4.0          0.044073    11.079882
#        13 InProgress     0       0.000025           64           2 0.361842      0.000011      -                 -            -
# 1 trials running, 13 finished (4 until the end), 380.24s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161      2          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170      3          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016      9          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042     10          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011      1          0.063736     6.531056
#         6  Completed    10       0.000043           64           2 0.287375      0.000151     10          0.043504    25.815861
#         7    Stopped     2       0.000016           32           2 0.231414      0.000158      2          0.048721     5.660421
#         8  Completed    10       0.000024          256           3 0.228997      0.000102     10          0.044575   104.861553
#         9    Stopped     1       0.000172          256           4 0.329978      0.000124      1          0.082705    14.762361
#        10    Stopped     4       0.000041           64           3 0.257021      0.000317      4          0.047961    12.432484
#        11    Stopped     1       0.000274          256           4 0.251182      0.000036      1          0.094395    14.785686
#        12    Stopped     4       0.000155           64           2 0.413077      0.000161      4          0.044073    11.079882
#        13 InProgress     8       0.000025           64           2 0.361842      0.000011      8          0.044481    20.943446
# 1 trials running, 13 finished (4 until the end), 400.25s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:20:24] ✅ Trial 13 completed!
# [11:20:24] 🚀 Trial 14 started - config: learning_rate=0.00029585306820034945, num_hiddens=128, num_layers=4, dropout=0.4989458887265687, weight_decay=3.613309819576858e-05
# [11:20:34] 🚀 Trial 15 started - config: learning_rate=0.00018985859721771674, num_hiddens=256, num_layers=2, dropout=0.35100268274718993, weight_decay=4.7934011388945334e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161    2.0          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170    3.0          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016    9.0          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042   10.0          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011    1.0          0.063736     6.531056
#         6  Completed    10       0.000043           64           2 0.287375      0.000151   10.0          0.043504    25.815861
#         7    Stopped     2       0.000016           32           2 0.231414      0.000158    2.0          0.048721     5.660421
#         8  Completed    10       0.000024          256           3 0.228997      0.000102   10.0          0.044575   104.861553
#         9    Stopped     1       0.000172          256           4 0.329978      0.000124    1.0          0.082705    14.762361
#        10    Stopped     4       0.000041           64           3 0.257021      0.000317    4.0          0.047961    12.432484
#        11    Stopped     1       0.000274          256           4 0.251182      0.000036    1.0          0.094395    14.785686
#        12    Stopped     4       0.000155           64           2 0.413077      0.000161    4.0          0.044073    11.079882
#        13  Completed    10       0.000025           64           2 0.361842      0.000011   10.0          0.045642    25.730971
#        14    Stopped     1       0.000296          128           4 0.498946      0.000036    1.0          0.057262     6.530887
#        15 InProgress     0       0.000190          256           2 0.351003      0.000048      -                 -            -
# 1 trials running, 15 finished (5 until the end), 420.27s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161      2          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170      3          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016      9          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042     10          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011      1          0.063736     6.531056
#         6  Completed    10       0.000043           64           2 0.287375      0.000151     10          0.043504    25.815861
#         7    Stopped     2       0.000016           32           2 0.231414      0.000158      2          0.048721     5.660421
#         8  Completed    10       0.000024          256           3 0.228997      0.000102     10          0.044575   104.861553
#         9    Stopped     1       0.000172          256           4 0.329978      0.000124      1          0.082705    14.762361
#        10    Stopped     4       0.000041           64           3 0.257021      0.000317      4          0.047961    12.432484
#        11    Stopped     1       0.000274          256           4 0.251182      0.000036      1          0.094395    14.785686
#        12    Stopped     4       0.000155           64           2 0.413077      0.000161      4          0.044073    11.079882
#        13  Completed    10       0.000025           64           2 0.361842      0.000011     10          0.045642    25.730971
#        14    Stopped     1       0.000296          128           4 0.498946      0.000036      1          0.057262     6.530887
#        15 InProgress     2       0.000190          256           2 0.351003      0.000048      2          0.042778    16.619516
# 1 trials running, 15 finished (5 until the end), 440.28s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:21:04] 🚀 Trial 16 started - config: learning_rate=5.5164857605310134e-05, num_hiddens=32, num_layers=3, dropout=0.3498588011391114, weight_decay=3.858802978423857e-05
# [11:21:19] 🚀 Trial 17 started - config: learning_rate=6.9839272226966e-05, num_hiddens=32, num_layers=2, dropout=0.40768293711223375, weight_decay=0.0003329691270171378
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161    2.0          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170    3.0          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016    9.0          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042   10.0          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011    1.0          0.063736     6.531056
#         6  Completed    10       0.000043           64           2 0.287375      0.000151   10.0          0.043504    25.815861
#         7    Stopped     2       0.000016           32           2 0.231414      0.000158    2.0          0.048721     5.660421
#         8  Completed    10       0.000024          256           3 0.228997      0.000102   10.0          0.044575   104.861553
#         9    Stopped     1       0.000172          256           4 0.329978      0.000124    1.0          0.082705    14.762361
#        10    Stopped     4       0.000041           64           3 0.257021      0.000317    4.0          0.047961    12.432484
#        11    Stopped     1       0.000274          256           4 0.251182      0.000036    1.0          0.094395    14.785686
#        12    Stopped     4       0.000155           64           2 0.413077      0.000161    4.0          0.044073    11.079882
#        13  Completed    10       0.000025           64           2 0.361842      0.000011   10.0          0.045642    25.730971
#        14    Stopped     1       0.000296          128           4 0.498946      0.000036    1.0          0.057262     6.530887
#        15    Stopped     3       0.000190          256           2 0.351003      0.000048    3.0          0.055092    24.048399
#        16    Stopped     4       0.000055           32           3 0.349859      0.000039    4.0          0.046339    11.672734
#        17 InProgress     0       0.000070           32           2 0.407683      0.000333      -                 -            -
# 1 trials running, 17 finished (5 until the end), 460.31s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:21:29] 🚀 Trial 18 started - config: learning_rate=7.187576306473827e-05, num_hiddens=64, num_layers=2, dropout=0.49310267369836625, weight_decay=3.414920388729561e-05
# [11:21:39] 🚀 Trial 19 started - config: learning_rate=0.00034601459100333716, num_hiddens=256, num_layers=3, dropout=0.4392780546020572, weight_decay=7.94412565914097e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161    2.0          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170    3.0          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016    9.0          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042   10.0          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011    1.0          0.063736     6.531056
#         6  Completed    10       0.000043           64           2 0.287375      0.000151   10.0          0.043504    25.815861
#         7    Stopped     2       0.000016           32           2 0.231414      0.000158    2.0          0.048721     5.660421
#         8  Completed    10       0.000024          256           3 0.228997      0.000102   10.0          0.044575   104.861553
#         9    Stopped     1       0.000172          256           4 0.329978      0.000124    1.0          0.082705    14.762361
#        10    Stopped     4       0.000041           64           3 0.257021      0.000317    4.0          0.047961    12.432484
#        11    Stopped     1       0.000274          256           4 0.251182      0.000036    1.0          0.094395    14.785686
#        12    Stopped     4       0.000155           64           2 0.413077      0.000161    4.0          0.044073    11.079882
#        13  Completed    10       0.000025           64           2 0.361842      0.000011   10.0          0.045642    25.730971
#        14    Stopped     1       0.000296          128           4 0.498946      0.000036    1.0          0.057262     6.530887
#        15    Stopped     3       0.000190          256           2 0.351003      0.000048    3.0          0.055092    24.048399
#        16    Stopped     4       0.000055           32           3 0.349859      0.000039    4.0          0.046339    11.672734
#        17    Stopped     2       0.000070           32           2 0.407683      0.000333    2.0          0.046547     5.869751
#        18    Stopped     2       0.000072           64           2 0.493103      0.000034    2.0          0.048300     5.865605
#        19 InProgress     0       0.000346          256           3 0.439278      0.000079      -                 -            -
# 1 trials running, 19 finished (5 until the end), 480.33s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161      2          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170      3          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016      9          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042     10          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011      1          0.063736     6.531056
#         6  Completed    10       0.000043           64           2 0.287375      0.000151     10          0.043504    25.815861
#         7    Stopped     2       0.000016           32           2 0.231414      0.000158      2          0.048721     5.660421
#         8  Completed    10       0.000024          256           3 0.228997      0.000102     10          0.044575   104.861553
#         9    Stopped     1       0.000172          256           4 0.329978      0.000124      1          0.082705    14.762361
#        10    Stopped     4       0.000041           64           3 0.257021      0.000317      4          0.047961    12.432484
#        11    Stopped     1       0.000274          256           4 0.251182      0.000036      1          0.094395    14.785686
#        12    Stopped     4       0.000155           64           2 0.413077      0.000161      4          0.044073    11.079882
#        13  Completed    10       0.000025           64           2 0.361842      0.000011     10          0.045642    25.730971
#        14    Stopped     1       0.000296          128           4 0.498946      0.000036      1          0.057262     6.530887
#        15    Stopped     3       0.000190          256           2 0.351003      0.000048      3          0.055092    24.048399
#        16    Stopped     4       0.000055           32           3 0.349859      0.000039      4          0.046339    11.672734
#        17    Stopped     2       0.000070           32           2 0.407683      0.000333      2          0.046547     5.869751
#        18    Stopped     2       0.000072           64           2 0.493103      0.000034      2          0.048300     5.865605
#        19 InProgress     1       0.000346          256           3 0.439278      0.000079      1          0.045536    11.888498
# 1 trials running, 19 finished (5 until the end), 500.34s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:22:14] 🚀 Trial 20 started - config: learning_rate=0.0004408397362403272, num_hiddens=256, num_layers=4, dropout=0.20414307021708444, weight_decay=2.9552430620275194e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161    2.0          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170    3.0          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016    9.0          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042   10.0          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011    1.0          0.063736     6.531056
#         6  Completed    10       0.000043           64           2 0.287375      0.000
#        22    Stopped     3       0.000141          128           2 0.228448      0.000043      3          0.047846    11.132970
#        23    Stopped     3       0.000188          256           3 0.284266      0.000071      3          0.049314    32.455867
#        24    Stopped     1       0.000057          128           4 0.237196      0.000010      1          0.046366     6.562456
#        25    Stopped     1       0.000077          128           4 0.485011      0.000033      1          0.048243     6.505046
#        26    Stopped     1       0.000020          128           3 0.256711      0.000057      1          0.047251     5.448526
#        27 InProgress     7       0.000118          256           3 0.257381      0.000120      7          0.045545    72.860681
# 1 trials running, 27 finished (5 until the end), 800.59s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:27:15] 🚀 Trial 28 started - config: learning_rate=4.18622206954097e-05, num_hiddens=32, num_layers=4, dropout=0.4844189983346359, weight_decay=7.883017324001362e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161    2.0          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170    3.0          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016    9.0          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042   10.0          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011    1.0          0.063736     6.531056
#         6  Completed    10       0.000043           64           2 0.287375      0.000151   10.0          0.043504    25.815861
#         7    Stopped     2       0.000016           32           2 0.231414      0.000158    2.0          0.048721     5.660421
#         8  Completed    10       0.000024          256           3 0.228997      0.000102   10.0          0.044575   104.861553
#         9    Stopped     1       0.000172          256           4 0.329978      0.000124    1.0          0.082705    14.762361
#        10    Stopped     4       0.000041           64           3 0.257021      0.000317    4.0          0.047961    12.432484
#        11    Stopped     1       0.000274          256           4 0.251182      0.000036    1.0          0.094395    14.785686
#        12    Stopped     4       0.000155           64           2 0.413077      0.000161    4.0          0.044073    11.079882
#        13  Completed    10       0.000025           64           2 0.361842      0.000011   10.0          0.045642    25.730971
#        14    Stopped     1       0.000296          128           4 0.498946      0.000036    1.0          0.057262     6.530887
#        15    Stopped     3       0.000190          256           2 0.351003      0.000048    3.0          0.055092    24.048399
#        16    Stopped     4       0.000055           32           3 0.349859      0.000039    4.0          0.046339    11.672734
#        17    Stopped     2       0.000070           32           2 0.407683      0.000333    2.0          0.046547     5.869751
#        18    Stopped     2       0.000072           64           2 0.493103      0.000034    2.0          0.048300     5.865605
#        19    Stopped     3       0.000346          256           3 0.439278      0.000079    3.0          0.050442    32.378795
#        20    Stopped     1       0.000441          256           4 0.204143      0.000030    1.0          0.075157    14.867954
#        21    Stopped     9       0.000086          256           3 0.324557      0.000405    9.0          0.046596    94.783042
#        22    Stopped     3       0.000141          128           2 0.228448      0.000043    3.0          0.047846    11.132970
#        23    Stopped     3       0.000188          256           3 0.284266      0.000071    3.0          0.049314    32.455867
#        24    Stopped     1       0.000057          128           4 0.237196      0.000010    1.0          0.046366     6.562456
#        25    Stopped     1       0.000077          128           4 0.485011      0.000033    1.0          0.048243     6.505046
#        26    Stopped     1       0.000020          128           3 0.256711      0.000057    1.0          0.047251     5.448526
#        27    Stopped     9       0.000118          256           3 0.257381      0.000120    9.0          0.046462    93.154678
#        28 InProgress     0       0.000042           32           4 0.484419      0.000079      -                 -            -
# 1 trials running, 28 finished (5 until the end), 820.61s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:27:25] 🚀 Trial 29 started - config: learning_rate=0.00026420113761223, num_hiddens=64, num_layers=4, dropout=0.31270847136657004, weight_decay=1.9868581386963573e-05
# [11:27:35] 🚀 Trial 30 started - config: learning_rate=2.69116184109873e-05, num_hiddens=64, num_layers=3, dropout=0.3201809851702533, weight_decay=0.00032117659183462797
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🎉🎉🎉 HYPERPARAMETER OPTIMIZATION COMPLETE!
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# --------------------
# Resource summary (last result is reported):
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.045281    25.815247
#         1    Stopped     2       0.000014           64           4 0.491483      0.000161    2.0          0.056075     7.408579
#         2    Stopped     3       0.000136           32           4 0.334864      0.000170    3.0          0.050796     9.802736
#         3    Stopped     9       0.000113          128           4 0.404191      0.000016    9.0          0.055546    48.817675
#         4  Completed    10       0.000039           32           2 0.219507      0.000042   10.0          0.046874    24.862934
#         5    Stopped     1       0.000387          128           4 0.452811      0.000011    1.0          0.063736     6.531056
#         6  Completed    10       0.000043           64           2 0.287375      0.000151   10.0          0.043504    25.815861
#         7    Stopped     2       0.000016           32           2 0.231414      0.000158    2.0          0.048721     5.660421
#         8  Completed    10       0.000024          256           3 0.228997      0.000102   10.0          0.044575   104.861553
#         9    Stopped     1       0.000172          256           4 0.329978      0.000124    1.0          0.082705    14.762361
#        10    Stopped     4       0.000041           64           3 0.257021      0.000317    4.0          0.047961    12.432484
#        11    Stopped     1       0.000274          256           4 0.251182      0.000036    1.0          0.094395    14.785686
#        12    Stopped     4       0.000155           64           2 0.413077      0.000161    4.0          0.044073    11.079882
#        13  Completed    10       0.000025           64           2 0.361842      0.000011   10.0          0.045642    25.730971
#        14    Stopped     1       0.000296          128           4 0.498946      0.000036    1.0          0.057262     6.530887
#        15    Stopped     3       0.000190          256           2 0.351003      0.000048    3.0          0.055092    24.048399
#        16    Stopped     4       0.000055           32           3 0.349859      0.000039    4.0          0.046339    11.672734
#        17    Stopped     2       0.000070           32           2 0.407683      0.000333    2.0          0.046547     5.869751
#        18    Stopped     2       0.000072           64           2 0.493103      0.000034    2.0          0.048300     5.865605
#        19    Stopped     3       0.000346          256           3 0.439278      0.000079    3.0          0.050442    32.378795
#        20    Stopped     1       0.000441          256           4 0.204143      0.000030    1.0          0.075157    14.867954
#        21    Stopped     9       0.000086          256           3 0.324557      0.000405    9.0          0.046596    94.783042
#        22    Stopped     3       0.000141          128           2 0.228448      0.000043    3.0          0.047846    11.132970
#        23    Stopped     3       0.000188          256           3 0.284266      0.000071    3.0          0.049314    32.455867
#        24    Stopped     1       0.000057          128           4 0.237196      0.000010    1.0          0.046366     6.562456
#        25    Stopped     1       0.000077          128           4 0.485011      0.000033    1.0          0.048243     6.505046
#        26    Stopped     1       0.000020          128           3 0.256711      0.000057    1.0          0.047251     5.448526
#        27    Stopped     9       0.000118          256           3 0.257381      0.000120    9.0          0.046462    93.154678
#        28    Stopped     2       0.000042           32           4 0.484419      0.000079    2.0          0.060036     6.792959
#        29    Stopped     2       0.000264           64           4 0.312708      0.000020    2.0          0.048938     7.446046
#        30 InProgress     0       0.000027           64           3 0.320181      0.000321      -                 -            -
# 1 trials running, 30 finished (5 until the end), 830.63s wallclock-time
#
# validation_error: best 0.042777590453624725 for trial-id 15
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-17-11-13-43-929
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-17-11-13-43-929
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##15. Load Results from Temperature HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
temperature_results_path = "/root/syne-tune/python-entrypoint-2026-03-17-11-13-43-929/results.csv.zip"

# Save the results to a Pandas DataFrame
temperature_results = pd.read_csv(temperature_results_path)

# %% [markdown]
# ##16. Save the Temperature HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
temperature_hpo_results_path = Path("/content/TILL_HAREHOPE_E_202202_temperature_HPO_results.csv")

# Save the DataFrame to a csv file
temperature_results.to_csv(temperature_hpo_results_path, index=True)
