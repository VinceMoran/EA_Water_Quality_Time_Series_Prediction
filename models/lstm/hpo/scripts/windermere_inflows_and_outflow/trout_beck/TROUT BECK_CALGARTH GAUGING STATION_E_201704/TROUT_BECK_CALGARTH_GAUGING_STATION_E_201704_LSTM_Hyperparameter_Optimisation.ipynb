# %% [markdown]
# # Station Information
#
# * Station name: TROUT BECK_CALGARTH GAUGING STATION_E_201704
# * Water Quality Data link: https://environment.data.gov.uk/hydrology/station/E06072A

# %% [markdown]
# ## 0. Import the Relevant Libraries

# %%
# Force installation of Syne-Tune and a compatible NumPy version (may require restarting the session after running this cell before running below import cell)
# !pip install numpy==1.26.1 syne_tune --force-reinstall -q # ignore potential error messages if listed dependencies do not match imports
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 25.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.3/254.3 kB 28.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 151.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 131.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 152.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/131.7 MB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 30.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 27.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 25.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 76.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.6/293.6 MB 3.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.1 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.1 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# torch 2.10.0+cu128 requires nvidia-nccl-cu12==2.27.5; platform_system == "Linux", but you have nvidia-nccl-cu12 2.29.7 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.1 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# music21 9.9.1 requires numpy>=1.26.4, but you have numpy 1.26.1 which is incompatible.
# datasets 4.0.0 requires dill<0.3.9,>=0.3.0, but you have dill 0.4.1 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.1 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.1 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.1 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.1 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.

# %%
# Import relevant libraries (Note: May require running of above cell to ensure compatibility of NumPy and Syne-Tune)
import torch
import logging
logging.basicConfig(level=logging.INFO)
import numpy as np
import matplotlib.pyplot as plt
from syne_tune import StoppingCriterion, Tuner
from syne_tune.backend.python_backend.python_backend import PythonBackend
from syne_tune.config_space import loguniform, randint, choice, uniform
from syne_tune.experiments import load_experiment
from syne_tune.optimizer.baselines import ASHA
import pandas as pd
from pathlib import Path

# %% [markdown]
# ##1. Specify Epoch Ranges and Reduction Factor for Hyperparameter Optimisation (HPO)

# %%
# Specify the minimum and maximum number of epochs for which a trial is allowed to run during HPO
min_number_of_epochs = 2
max_number_of_epochs = 10

# Define the reduction factor for the Asynchronous Successive Halving Algorithm (ASHA)
eta = 2 # Set to 2 so that 50% of trials are stopped at each rung of the scheduler

# %% [markdown]
# ##2. Define the Tune Function to Optimise Hyperparameters for Ammonium Prediction

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on ammonium_t_96 targets
def ammonium_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Create the path to the directory containing the data in the Jupyter notebook environment
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/windermere_inflows_and_outflow/trout_beck/TROUT%20BECK_CALGARTH%20GAUGING%20STATION_E_201704/TROUT%20BECK_CALGARTH%20GAUGING%20STATION_E_201704_preprocessed_data.zip")
    # Assign the full filepath for the preprocessed data
    parameter_path = "/content" / data_path / "TROUT BECK_CALGARTH GAUGING STATION_E_201704_preprocessed_data.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "ammonium"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ## 3. Define the Configuration Space for Hyperparameter Search

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %% [markdown]
# ##4. Define the Resources Available for HPO

# %%
# Define the number of parallel workers available to evaluate trials concurrently
n_workers = max(1, torch.cuda.device_count()) # Uses all available GPUs for parallel trials or defaults to 1 worker if running on CPU

# Define the maximum number of trials to test
max_number_of_trials = 30

# Define the stopping criterion for HPO
stop_criterion = StoppingCriterion(max_num_trials_started=max_number_of_trials)

# %% [markdown]
# ##5. Define Asynchronous Successive Halving Algorithm (ASHA) for HPO

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %% [markdown]
# ##6. Initialise and Run the Tuner for Ammonium HPO

# %%
# Instruct the searcher to run each trial as a Python function
trial_backend = PythonBackend(
    tune_function=ammonium_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-23-15-56-35-052
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-23-15-56-35-052
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-23-15-56-35-052
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [15:56:37] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay
#         0 InProgress     0        0.00001           64           2      0.2       0.00001
# 1 trials running, 0 finished (0 until the end), 20.13s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     1        0.00001           64           2      0.2       0.00001      1          0.006604    19.303667
# 1 trials running, 0 finished (0 until the end), 40.15s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     3        0.00001           64           2      0.2       0.00001      3          0.005242    43.844107
# 1 trials running, 0 finished (0 until the end), 60.17s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     5        0.00001           64           2      0.2       0.00001      5          0.005322    68.147607
# 1 trials running, 0 finished (0 until the end), 80.19s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     6        0.00001           64           2      0.2       0.00001      6          0.005754    80.244463
# 1 trials running, 0 finished (0 until the end), 100.21s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     8        0.00001           64           2      0.2       0.00001      8           0.00691   104.377041
# 1 trials running, 0 finished (0 until the end), 120.22s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:58:52] 🚀 Trial 1 started - config: learning_rate=1.5660697582204155e-05, num_hiddens=64, num_layers=2, dropout=0.4185990044930291, weight_decay=0.00017719721184859458
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.006407   128.605508
#         1 InProgress     0       0.000016           64           2 0.418599      0.000177      -                 -            -
# 1 trials running, 1 finished (0 until the end), 140.24s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [15:59:12] 🚀 Trial 2 started - config: learning_rate=0.00028952684326409133, num_hiddens=128, num_layers=2, dropout=0.21325509914785148, weight_decay=0.00042862243513656836
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177    1.0          0.006903    14.745980
#         2 InProgress     0       0.000290          128           2 0.213255      0.000429      -                 -            -
# 1 trials running, 2 finished (0 until the end), 160.27s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177    1.0          0.006903    14.745980
#         2 InProgress     0       0.000290          128           2 0.213255      0.000429      -                 -            -
# 1 trials running, 2 finished (0 until the end), 180.28s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177      1          0.006903    14.745980
#         2 InProgress     2       0.000290          128           2 0.213255      0.000429      2          0.008095    29.422295
# 1 trials running, 2 finished (0 until the end), 200.30s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177      1          0.006903    14.745980
#         2 InProgress     3       0.000290          128           2 0.213255      0.000429      3          0.003495    42.451858
# 1 trials running, 2 finished (0 until the end), 220.32s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177      1          0.006903    14.745980
#         2 InProgress     5       0.000290          128           2 0.213255      0.000429      5          0.004897    69.152900
# 1 trials running, 2 finished (0 until the end), 240.34s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177      1          0.006903    14.745980
#         2 InProgress     6       0.000290          128           2 0.213255      0.000429      6          0.004405    82.395390
# 1 trials running, 2 finished (0 until the end), 260.36s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177      1          0.006903    14.745980
#         2 InProgress     8       0.000290          128           2 0.213255      0.000429      8          0.007560   108.601704
# 1 trials running, 2 finished (0 until the end), 280.38s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177      1          0.006903    14.745980
#         2 InProgress     9       0.000290          128           2 0.213255      0.000429      9          0.005949   121.999901
# 1 trials running, 2 finished (0 until the end), 300.40s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:01:37] ✅ Trial 2 completed!
# [16:01:37] 🚀 Trial 3 started - config: learning_rate=0.00016100494362062667, num_hiddens=256, num_layers=3, dropout=0.4590112879606971, weight_decay=0.0004343509880067989
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177    1.0          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429   10.0          0.007896   135.423810
#         3 InProgress     0       0.000161          256           3 0.459011      0.000434      -                 -            -
# 1 trials running, 3 finished (1 until the end), 320.42s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177    1.0          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429   10.0          0.007896   135.423810
#         3 InProgress     0       0.000161          256           3 0.459011      0.000434      -                 -            -
# 1 trials running, 3 finished (1 until the end), 340.43s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177      1          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429     10          0.007896   135.423810
#         3 InProgress     1       0.000161          256           3 0.459011      0.000434      1          0.003671    42.484995
# 1 trials running, 3 finished (1 until the end), 360.45s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177      1          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429     10          0.007896   135.423810
#         3 InProgress     1       0.000161          256           3 0.459011      0.000434      1          0.003671    42.484995
# 1 trials running, 3 finished (1 until the end), 380.45s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177      1          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429     10          0.007896   135.423810
#         3 InProgress     2       0.000161          256           3 0.459011      0.000434      2          0.006133    79.221365
# 1 trials running, 3 finished (1 until the end), 400.47s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177      1          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429     10          0.007896   135.423810
#         3 InProgress     2       0.000161          256           3 0.459011      0.000434      2          0.006133    79.221365
# 1 trials running, 3 finished (1 until the end), 420.48s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:03:42] 🚀 Trial 4 started - config: learning_rate=1.4292659169485315e-05, num_hiddens=256, num_layers=2, dropout=0.4314539742898976, weight_decay=4.648936330035208e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177    1.0          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429   10.0          0.007896   135.423810
#         3    Stopped     3       0.000161          256           3 0.459011      0.000434    3.0          0.006449   115.650672
#         4 InProgress     0       0.000014          256           2 0.431454      0.000046      -                 -            -
# 1 trials running, 4 finished (1 until the end), 440.51s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177    1.0          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429   10.0          0.007896   135.423810
#         3    Stopped     3       0.000161          256           3 0.459011      0.000434    3.0          0.006449   115.650672
#         4 InProgress     0       0.000014          256           2 0.431454      0.000046      -                 -            -
# 1 trials running, 4 finished (1 until the end), 460.52s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177      1          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429     10          0.007896   135.423810
#         3    Stopped     3       0.000161          256           3 0.459011      0.000434      3          0.006449   115.650672
#         4 InProgress     1       0.000014          256           2 0.431454      0.000046      1          0.005153    32.345992
# 1 trials running, 4 finished (1 until the end), 480.54s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177      1          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429     10          0.007896   135.423810
#         3    Stopped     3       0.000161          256           3 0.459011      0.000434      3          0.006449   115.650672
#         4 InProgress     2       0.000014          256           2 0.431454      0.000046      2          0.005641    60.216933
# 1 trials running, 4 finished (1 until the end), 500.56s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177      1          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429     10          0.007896   135.423810
#         3    Stopped     3       0.000161          256           3 0.459011      0.000434      3          0.006449   115.650672
#         4 InProgress     2       0.000014          256           2 0.431454      0.000046      2          0.005641    60.216933
# 1 trials running, 4 finished (1 until the end), 520.57s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:05:17] 🚀 Trial 5 started - config: learning_rate=1.8417956263665068e-05, num_hiddens=256, num_layers=3, dropout=0.27194941290802915, weight_decay=2.1018345015078787e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177    1.0          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429   10.0          0.007896   135.423810
#         3    Stopped     3       0.000161          256           3 0.459011      0.000434    3.0          0.006449   115.650672
#         4    Stopped     3       0.000014          256           2 0.431454      0.000046    3.0          0.009015    87.692661
#         5 InProgress     0       0.000018          256           3 0.271949      0.000021      -                 -            -
# 1 trials running, 5 finished (1 until the end), 540.59s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177    1.0          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429   10.0          0.007896   135.423810
#         3    Stopped     3       0.000161          256           3 0.459011      0.000434    3.0          0.006449   115.650672
#         4    Stopped     3       0.000014          256           2 0.431454      0.000046    3.0          0.009015    87.692661
#         5 InProgress     0       0.000018          256           3 0.271949      0.000021      -                 -            -
# 1 trials running, 5 finished (1 until the end), 560.60s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177      1          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429     10          0.007896   135.423810
#         3    Stopped     3       0.000161          256           3 0.459011      0.000434      3          0.006449   115.650672
#         4    Stopped     3       0.000014          256           2 0.431454      0.000046      3          0.009015    87.692661
#         5 InProgress     1       0.000018          256           3 0.271949      0.000021      1          0.003972    41.881188
# 1 trials running, 5 finished (1 until the end), 580.62s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177      1          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429     10          0.007896   135.423810
#         3    Stopped     3       0.000161          256           3 0.459011      0.000434      3          0.006449   115.650672
#         4    Stopped     3       0.000014          256           2 0.431454      0.000046      3          0.009015    87.692661
#         5 InProgress     1       0.000018          256           3 0.271949      0.000021      1          0.003972    41.881188
# 1 trials running, 5 finished (1 until the end), 600.63s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177      1          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429     10          0.007896   135.423810
#         3    Stopped     3       0.000161          256           3 0.459011      0.000434      3          0.006449   115.650672
#         4    Stopped     3       0.000014          256           2 0.431454      0.000046      3          0.009015    87.692661
#         5 InProgress     2       0.000018          256           3 0.271949      0.000021      2          0.004760    78.675447
# 1 trials running, 5 finished (1 until the end), 620.65s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177      1          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429     10          0.007896   135.423810
#         3    Stopped     3       0.000161          256           3 0.459011      0.000434      3          0.006449   115.650672
#         4    Stopped     3       0.000014          256           2 0.431454      0.000046      3          0.009015    87.692661
#         5 InProgress     2       0.000018          256           3 0.271949      0.000021      2          0.004760    78.675447
# 1 trials running, 5 finished (1 until the end), 640.66s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:07:22] 🚀 Trial 6 started - config: learning_rate=0.000115675492138624, num_hiddens=32, num_layers=2, dropout=0.31066458953014625, weight_decay=6.770448312503496e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177    1.0          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429   10.0          0.007896   135.423810
#         3    Stopped     3       0.000161          256           3 0.459011      0.000434    3.0          0.006449   115.650672
#         4    Stopped     3       0.000014          256           2 0.431454      0.000046    3.0          0.009015    87.692661
#         5    Stopped     3       0.000018          256           3 0.271949      0.000021    3.0          0.005471   115.859820
#         6 InProgress     0       0.000116           32           2 0.310665      0.000068      -                 -            -
# 1 trials running, 6 finished (1 until the end), 660.68s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:07:47] 🚀 Trial 7 started - config: learning_rate=2.4156066243421417e-05, num_hiddens=32, num_layers=2, dropout=0.21789368845254437, weight_decay=7.984210366618528e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177    1.0          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429   10.0          0.007896   135.423810
#         3    Stopped     3       0.000161          256           3 0.459011      0.000434    3.0          0.006449   115.650672
#         4    Stopped     3       0.000014          256           2 0.431454      0.000046    3.0          0.009015    87.692661
#         5    Stopped     3       0.000018          256           3 0.271949      0.000021    3.0          0.005471   115.859820
#         6    Stopped     1       0.000116           32           2 0.310665      0.000068    1.0          0.005489    14.895421
#         7 InProgress     0       0.000024           32           2 0.217894      0.000080      -                 -            -
# 1 trials running, 7 finished (1 until the end), 680.71s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:08:07] 🚀 Trial 8 started - config: learning_rate=4.4611991813586145e-05, num_hiddens=128, num_layers=2, dropout=0.3597658126628644, weight_decay=0.00046593621305988654
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177    1.0          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429   10.0          0.007896   135.423810
#         3    Stopped     3       0.000161          256           3 0.459011      0.000434    3.0          0.006449   115.650672
#         4    Stopped     3       0.000014          256           2 0.431454      0.000046    3.0          0.009015    87.692661
#         5    Stopped     3       0.000018          256           3 0.271949      0.000021    3.0          0.005471   115.859820
#         6    Stopped     1       0.000116           32           2 0.310665      0.000068    1.0          0.005489    14.895421
#         7    Stopped     1       0.000024           32           2 0.217894      0.000080    1.0          0.005677    14.733382
#         8 InProgress     0       0.000045          128           2 0.359766      0.000466      -                 -            -
# 1 trials running, 8 finished (1 until the end), 700.73s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [16:08:32] 🚀 Trial 9 started - config: learning_rate=0.00022333336416261156, num_hiddens=32, num_layers=4, dropout=0.25875017350777607, weight_decay=1.6016141572106798e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177    1.0          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429   10.0          0.007896   135.423810
#         3    Stopped     3       0.000161          256           3 0.459011      0.000434    3.0          0.006449   115.650672
#         4    Stopped     3       0.000014          256           2 0.431454      0.000046    3.0          0.009015    87.692661
#         5    Stopped     3       0.000018          256           3 0.271949      0.000021    3.0          0.005471   115.859820
#         6    Stopped     1       0.000116           32           2 0.310665      0.000068    1.0          0.005489    14.895421
#         7    Stopped     1       0.000024           32           2 0.217894      0.000080    1.0          0.005677    14.733382
#         8    Stopped     1       0.000045          128           2 0.359766      0.000466    1.0          0.007437    16.090671
#         9 InProgress     0       0.000223           32           4 0.258750      0.000016      -                 -            -
# 1 trials running, 9 finished (1 until the end), 720.75s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010   10.0          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177    1.0          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429   10.0          0.007896   135.423810
#         3    Stopped     3       0.000161          256           3 0.459011      0.000434    3.0          0.006449   115.650672
#         4    Stopped     3       0.000014          256           2 0.431454      0.000046    3.0          0.009015    87.692661
#         5    Stopped     3       0.000018          256           3 0.271949      0.000021    3.0          0.005471   115.859820
#         6    Stopped     1       0.000116           32           2 0.310665      0.000068    1.0          0.005489    14.895421
#         7    Stopped     1       0.000024           32           2 0.217894      0.000080    1.0          0.005677    14.733382
#         8    Stopped     1       0.000045          128           2 0.359766      0.000466    1.0          0.007437    16.090671
#         9 InProgress     0       0.000223           32           4 0.258750      0.000016      -                 -            -
# 1 trials running, 9 finished (1 until the end), 740.76s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0    Stopped    10       0.000010           64           2 0.200000      0.000010     10          0.006407   128.605508
#         1    Stopped     1       0.000016           64           2 0.418599      0.000177      1          0.006903    14.745980
#         2  Completed    10       0.000290          128           2 0.213255      0.000429     10          0.007896   135.423810
#         3    Stopped     3       0.000161          256           3 0.459011      0.000
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-23-15-56-35-052
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-23-15-56-35-052
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##7. Load Results from HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
ammonium_results_path = "/root/syne-tune/python-entrypoint-2026-03-23-15-56-35-052/results.csv.zip"

# Save the results to a Pandas DataFrame
ammonium_results = pd.read_csv(ammonium_results_path)

# %% [markdown]
# ##8. Save the Ammonium HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
ammonium_hpo_results_path = Path("/content/TROUT_BECK_CALGARTH_GAUGING_STATION_E_201704_ammonium_hpo_results.csv")

# Save the DataFrame to a csv file
ammonium_results.to_csv(ammonium_hpo_results_path, index=True)

# %% [markdown]
# ## 9. Define the Config Space, Scheduler, and Tune Function for Dissolved Oxygen HPO

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on ammonium_t_96 targets
def oxygen_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Create the path to the directory containing the data in the Jupyter notebook environment
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/windermere_inflows_and_outflow/trout_beck/TROUT%20BECK_CALGARTH%20GAUGING%20STATION_E_201704/TROUT%20BECK_CALGARTH%20GAUGING%20STATION_E_201704_preprocessed_data.zip")
    # Assign the full filepath for the preprocessed data
    parameter_path = "/content" / data_path / "TROUT BECK_CALGARTH GAUGING STATION_E_201704_preprocessed_data.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "oxygen_conc"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ##10. Initialise and Run the Tuner for Oxygen HPO

# %%
# Instruct the searcher to run each trial as a Python function
oxygen_trial_backend = PythonBackend(
    tune_function=oxygen_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=oxygen_trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-23-17-15-38-096
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-23-17-15-38-096
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-23-17-15-38-096
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [17:15:38] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay
#         0 InProgress     0        0.00001           64           2      0.2       0.00001
# 1 trials running, 0 finished (0 until the end), 20.01s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     2        0.00001           64           2      0.2       0.00001      2          0.028779    27.364318
# 1 trials running, 0 finished (0 until the end), 40.03s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     3        0.00001           64           2      0.2       0.00001      3          0.026906    39.317899
# 1 trials running, 0 finished (0 until the end), 60.04s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     5        0.00001           64           2      0.2       0.00001      5          0.025745    63.675365
# 1 trials running, 0 finished (0 until the end), 80.06s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     7        0.00001           64           2      0.2       0.00001      7          0.025718    88.190723
# 1 trials running, 0 finished (0 until the end), 100.08s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     8        0.00001           64           2      0.2       0.00001      8          0.026853   100.331612
# 1 trials running, 0 finished (0 until the end), 120.10s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [17:17:53] ✅ Trial 0 completed!
# [17:17:53] 🚀 Trial 1 started - config: learning_rate=4.2299023209438484e-05, num_hiddens=256, num_layers=2, dropout=0.4210392640234677, weight_decay=0.00011242428226928823
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.026367   124.964347
#         1 InProgress     0       0.000042          256           2 0.421039      0.000112      -                 -            -
# 1 trials running, 1 finished (1 until the end), 140.12s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.026367   124.964347
#         1 InProgress     0       0.000042          256           2 0.421039      0.000112      -                 -            -
# 1 trials running, 1 finished (1 until the end), 160.13s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1 InProgress     1       0.000042          256           2 0.421039      0.000112      1          0.027245    31.854425
# 1 trials running, 1 finished (1 until the end), 180.15s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1 InProgress     1       0.000042          256           2 0.421039      0.000112      1          0.027245    31.854425
# 1 trials running, 1 finished (1 until the end), 200.16s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1 InProgress     2       0.000042          256           2 0.421039      0.000112      2          0.025023    59.328865
# 1 trials running, 1 finished (1 until the end), 220.18s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1 InProgress     3       0.000042          256           2 0.421039      0.000112      3          0.025619    86.602065
# 1 trials running, 1 finished (1 until the end), 240.20s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1 InProgress     4       0.000042          256           2 0.421039      0.000112      4          0.026285   114.294019
# 1 trials running, 1 finished (1 until the end), 260.22s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1 InProgress     4       0.000042          256           2 0.421039      0.000112      4          0.026285   114.294019
# 1 trials running, 1 finished (1 until the end), 280.22s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1 InProgress     5       0.000042          256           2 0.421039      0.000112      5          0.026868   141.771706
# 1 trials running, 1 finished (1 until the end), 300.24s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1 InProgress     6       0.000042          256           2 0.421039      0.000112      6          0.026210   169.363856
# 1 trials running, 1 finished (1 until the end), 320.26s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1 InProgress     6       0.000042          256           2 0.421039      0.000112      6          0.026210   169.363856
# 1 trials running, 1 finished (1 until the end), 340.27s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1 InProgress     7       0.000042          256           2 0.421039      0.000112      7          0.025425   196.920087
# 1 trials running, 1 finished (1 until the end), 360.29s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1 InProgress     8       0.000042          256           2 0.421039      0.000112      8          0.026026   224.085617
# 1 trials running, 1 finished (1 until the end), 380.31s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1 InProgress     9       0.000042          256           2 0.421039      0.000112      9          0.025647   251.370885
# 1 trials running, 1 finished (1 until the end), 400.33s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1 InProgress     9       0.000042          256           2 0.421039      0.000112      9          0.025647   251.370885
# 1 trials running, 1 finished (1 until the end), 420.33s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [17:22:38] 🚀 Trial 2 started - config: learning_rate=0.00012531564928601653, num_hiddens=256, num_layers=2, dropout=0.25610065124792486, weight_decay=0.00011277579074815434
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112   10.0          0.025503   278.825990
#         2 InProgress     0       0.000125          256           2 0.256101      0.000113      -                 -            -
# 1 trials running, 2 finished (1 until the end), 440.35s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112   10.0          0.025503   278.825990
#         2 InProgress     0       0.000125          256           2 0.256101      0.000113      -                 -            -
# 1 trials running, 2 finished (1 until the end), 460.36s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [17:23:18] 🚀 Trial 3 started - config: learning_rate=0.00026547593610361464, num_hiddens=128, num_layers=3, dropout=0.2783747294110061, weight_decay=0.00015127563699249483
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112   10.0          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113    1.0          0.042323    31.719801
#         3 InProgress     0       0.000265          128           3 0.278375      0.000151      -                 -            -
# 1 trials running, 3 finished (1 until the end), 480.38s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112     10          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113      1          0.042323    31.719801
#         3 InProgress     1       0.000265          128           3 0.278375      0.000151      1          0.025827    17.791415
# 1 trials running, 3 finished (1 until the end), 500.40s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [17:24:14] 🚀 Trial 4 started - config: learning_rate=3.748482452939105e-05, num_hiddens=128, num_layers=3, dropout=0.2498597952095149, weight_decay=8.534465016750996e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112   10.0          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113    1.0          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151    3.0          0.026995    47.023326
#         4 InProgress     0       0.000037          128           3 0.249860      0.000085      -                 -            -
# 1 trials running, 4 finished (1 until the end), 520.44s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112   10.0          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113    1.0          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151    3.0          0.026995    47.023326
#         4 InProgress     0       0.000037          128           3 0.249860      0.000085      -                 -            -
# 1 trials running, 4 finished (1 until the end), 540.44s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [17:24:39] 🚀 Trial 5 started - config: learning_rate=0.00015269009467172015, num_hiddens=128, num_layers=2, dropout=0.4878332152415623, weight_decay=2.0446190998728766e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112   10.0          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113    1.0          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151    3.0          0.026995    47.023326
#         4    Stopped     1       0.000037          128           3 0.249860      0.000085    1.0          0.030707    17.880257
#         5 InProgress     0       0.000153          128           2 0.487833      0.000020      -                 -            -
# 1 trials running, 5 finished (1 until the end), 560.47s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112     10          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113      1          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151      3          0.026995    47.023326
#         4    Stopped     1       0.000037          128           3 0.249860      0.000085      1          0.030707    17.880257
#         5 InProgress     2       0.000153          128           2 0.487833      0.000020      2          0.027904    29.551427
# 1 trials running, 5 finished (1 until the end), 580.49s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [17:25:29] 🚀 Trial 6 started - config: learning_rate=0.00021599331045978867, num_hiddens=128, num_layers=2, dropout=0.3327485083521625, weight_decay=6.442012959313463e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112   10.0          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113    1.0          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151    3.0          0.026995    47.023326
#         4    Stopped     1       0.000037          128           3 0.249860      0.000085    1.0          0.030707    17.880257
#         5    Stopped     3       0.000153          128           2 0.487833      0.000020    3.0          0.031425    42.546345
#         6 InProgress     0       0.000216          128           2 0.332749      0.000064      -                 -            -
# 1 trials running, 6 finished (1 until the end), 600.51s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112   10.0          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113    1.0          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151    3.0          0.026995    47.023326
#         4    Stopped     1       0.000037          128           3 0.249860      0.000085    1.0          0.030707    17.880257
#         5    Stopped     3       0.000153          128           2 0.487833      0.000020    3.0          0.031425    42.546345
#         6 InProgress     0       0.000216          128           2 0.332749      0.000064      -                 -            -
# 1 trials running, 6 finished (1 until the end), 620.52s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112     10          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113      1          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151      3          0.026995    47.023326
#         4    Stopped     1       0.000037          128           3 0.249860      0.000085      1          0.030707    17.880257
#         5    Stopped     3       0.000153          128           2 0.487833      0.000020      3          0.031425    42.546345
#         6 InProgress     2       0.000216          128           2 0.332749      0.000064      2          0.026526    29.396153
# 1 trials running, 6 finished (1 until the end), 640.55s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [17:26:24] 🚀 Trial 7 started - config: learning_rate=0.00016177347772512106, num_hiddens=32, num_layers=4, dropout=0.27839480415978096, weight_decay=3.347337089024968e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112   10.0          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113    1.0          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151    3.0          0.026995    47.023326
#         4    Stopped     1       0.000037          128           3 0.249860      0.000085    1.0          0.030707    17.880257
#         5    Stopped     3       0.000153          128           2 0.487833      0.000020    3.0          0.031425    42.546345
#         6    Stopped     3       0.000216          128           2 0.332749      0.000064    3.0          0.029349    42.409639
#         7 InProgress     0       0.000162           32           4 0.278395      0.000033      -                 -            -
# 1 trials running, 7 finished (1 until the end), 660.57s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [17:26:49] 🚀 Trial 8 started - config: learning_rate=0.00016305032449477557, num_hiddens=256, num_layers=2, dropout=0.20016525297659296, weight_decay=4.9025288529419147e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112   10.0          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113    1.0          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151    3.0          0.026995    47.023326
#         4    Stopped     1       0.000037          128           3 0.249860      0.000085    1.0          0.030707    17.880257
#         5    Stopped     3       0.000153          128           2 0.487833      0.000020    3.0          0.031425    42.546345
#         6    Stopped     3       0.000216          128           2 0.332749      0.000064    3.0          0.029349    42.409639
#         7    Stopped     1       0.000162           32           4 0.278395      0.000033    1.0          0.029420    16.580550
#         8 InProgress     0       0.000163          256           2 0.200165      0.000049      -                 -            -
# 1 trials running, 8 finished (1 until the end), 680.60s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112   10.0          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113    1.0          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151    3.0          0.026995    47.023326
#         4    Stopped     1       0.000037          128           3 0.249860      0.000085    1.0          0.030707    17.880257
#         5    Stopped     3       0.000153          128           2 0.487833      0.000020    3.0          0.031425    42.546345
#         6    Stopped     3       0.000216          128           2 0.332749      0.000064    3.0          0.029349    42.409639
#         7    Stopped     1       0.000162           32           4 0.278395      0.000033    1.0          0.029420    16.580550
#         8 InProgress     0       0.000163          256           2 0.200165      0.000049      -                 -            -
# 1 trials running, 8 finished (1 until the end), 700.61s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [17:27:29] 🚀 Trial 9 started - config: learning_rate=9.678551783721904e-05, num_hiddens=64, num_layers=2, dropout=0.3411115561142663, weight_decay=3.808029956309169e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112   10.0          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113    1.0          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151    3.0          0.026995    47.023326
#         4    Stopped     1       0.000037          128           3 0.249860      0.000085    1.0          0.030707    17.880257
#         5    Stopped     3       0.000153          128           2 0.487833      0.000020    3.0          0.031425    42.546345
#         6    Stopped     3       0.000216          128           2 0.332749      0.000064    3.0          0.029349    42.409639
#         7    Stopped     1       0.000162           32           4 0.278395      0.000033    1.0          0.029420    16.580550
#         8    Stopped     1       0.000163          256           2 0.200165      0.000049    1.0          0.038940    31.464208
#         9 InProgress     0       0.000097           64           2 0.341112      0.000038      -                 -            -
# 1 trials running, 9 finished (1 until the end), 720.63s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112     10          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113      1          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151      3          0.026995    47.023326
#         4    Stopped     1       0.000037          128           3 0.249860      0.000085      1          0.030707    17.880257
#         5    Stopped     3       0.000153          128           2 0.487833      0.000020      3          0.031425    42.546345
#         6    Stopped     3       0.000216          128           2 0.332749      0.000064      3          0.029349    42.409639
#         7    Stopped     1       0.000162           32           4 0.278395      0.000033      1          0.029420    16.580550
#         8    Stopped     1       0.000163          256           2 0.200165      0.000049      1          0.038940    31.464208
#         9 InProgress     1       0.000097           64           2 0.341112      0.000038      1          0.026373    14.801244
# 1 trials running, 9 finished (1 until the end), 740.66s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112     10          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113      1          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151      3          0.026995    47.023326
#         4    Stopped     1       0.000037          128           3 0.249860      0.000085      1          0.030707    17.880257
#         5    Stopped     3       0.000153          128           2 0.487833      0.000020      3          0.031425    42.546345
#         6    Stopped     3       0.000216          128           2 0.332749      0.000064      3          0.029349    42.409639
#         7    Stopped     1       0.000162           32           4 0.278395      0.000033      1          0.029420    16.580550
#         8    Stopped     1       0.000163          256           2 0.200165      0.000049      1          0.038940    31.464208
#         9 InProgress     3       0.000097           64           2 0.341112      0.000038      3          0.026362    38.730825
# 1 trials running, 9 finished (1 until the end), 760.69s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112     10          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113      1          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151      3          0.026995    47.023326
#         4    Stopped     1       0.000037          128           3 0.249860      0.000085      1          0.030707    17.880257
#         5    Stopped     3       0.000153          128           2 0.487833      0.000020      3          0.031425    42.546345
#         6    Stopped     3       0.000216          128           2 0.332749      0.000064      3          0.029349    42.409639
#         7    Stopped     1       0.000162           32           4 0.278395      0.000033      1          0.029420    16.580550
#         8    Stopped     1       0.000163          256           2 0.200165      0.000049      1          0.038940    31.464208
#         9 InProgress     4       0.000097           64           2 0.341112      0.000038      4          0.026313    50.832772
# 1 trials running, 9 finished (1 until the end), 780.71s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112     10          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113      1          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151      3          0.026995    47.023326
#         4    Stopped     1       0.000037          128           3 0.249860      0.000085      1          0.030707    17.880257
#         5    Stopped     3       0.000153          128           2 0.487833      0.000020      3          0.031425    42.546345
#         6    Stopped     3       0.000216          128           2 0.332749      0.000064      3          0.029349    42.409639
#         7    Stopped     1       0.000162           32           4 0.278395      0.000033      1          0.029420    16.580550
#         8    Stopped     1       0.000163          256           2 0.200165      0.000049      1          0.038940    31.464208
#         9 InProgress     6       0.000097           64           2 0.341112      0.000038      6          0.026661    74.858350
# 1 trials running, 9 finished (1 until the end), 800.73s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112     10          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113      1          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151      3          0.026995    47.023326
#         4    Stopped     1       0.000037          128           3 0.249860      0.000085      1          0.030707    17.880257
#         5    Stopped     3       0.000153          128           2 0.487833      0.000020      3          0.031425    42.546345
#         6    Stopped     3       0.000216          128           2 0.332749      0.000064      3          0.029349    42.409639
#         7    Stopped     1       0.000162           32           4 0.278395      0.000033      1          0.029420    16.580550
#         8    Stopped     1       0.000163          256           2 0.200165      0.000049      1          0.038940    31.464208
#         9 InProgress     8       0.000097           64           2 0.341112      0.000038      8          0.026342    98.752807
# 1 trials running, 9 finished (1 until the end), 820.76s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112     10          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113      1          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151      3          0.026995    47.023326
#         4    Stopped     1       0.000037          128           3 0.249860      0.000085      1          0.030707    17.880257
#         5    Stopped     3       0.000153          128           2 0.487833      0.000020      3          0.031425    42.546345
#         6    Stopped     3       0.000216          128           2 0.332749      0.000064      3          0.029349    42.409639
#         7    Stopped     1       0.000162           32           4 0.278395      0.000033      1          0.029420    16.580550
#         8    Stopped     1       0.000163          256           2 0.200165      0.000049      1          0.038940    31.464208
#         9 InProgress     9       0.000097           64           2 0.341112      0.000038      9          0.025668   110.889961
# 1 trials running, 9 finished (1 until the end), 840.78s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [17:29:39] ✅ Trial 9 completed!
# [17:29:39] 🚀 Trial 10 started - config: learning_rate=0.00043770246171791324, num_hiddens=256, num_layers=2, dropout=0.27291246937390484, weight_decay=1.51691420354285e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112   10.0          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113    1.0          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151    3.0          0.026995    47.023326
#         4    Stopped     1       0.000037          128           3 0.249860      0.000085    1.0          0.030707    17.880257
#         5    Stopped     3       0.000153          128           2 0.487833      0.000020    3.0          0.031425    42.546345
#         6    Stopped     3       0.000216          128           2 0.332749      0.000064    3.0          0.029349    42.409639
#         7    Stopped     1       0.000162           32           4 0.278395      0.000033    1.0          0.029420    16.580550
#         8    Stopped     1       0.000163          256           2 0.200165      0.000049    1.0          0.038940    31.464208
#         9  Completed    10       0.000097           64           2 0.341112      0.000038   10.0          0.025515   123.013263
#        10 InProgress     0       0.000438          256           2 0.272912      0.000015      -                 -            -
# 1 trials running, 10 finished (2 until the end), 860.80s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112   10.0          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113    1.0          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151    3.0          0.026995    47.023326
#         4    Stopped     1       0.000037          128           3 0.249860      0.000085    1.0          0.030707    17.880257
#         5    Stopped     3       0.000153          128           2 0.487833      0.000020    3.0          0.031425    42.546345
#         6    Stopped     3       0.000216          128           2 0.332749      0.000064    3.0          0.029349    42.409639
#         7    Stopped     1       0.000162           32           4 0.278395      0.000033    1.0          0.029420    16.580550
#         8    Stopped     1       0.000163          256           2 0.200165      0.000049    1.0          0.038940    31.464208
#         9  Completed    10       0.000097           64           2 0.341112      0.000038   10.0          0.025515   123.013263
#        10 InProgress     0       0.000438          256           2 0.272912      0.000015      -                 -            -
# 1 trials running, 10 finished (2 until the end), 880.81s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [17:30:19] 🚀 Trial 11 started - config: learning_rate=3.559298569843671e-05, num_hiddens=256, num_layers=4, dropout=0.3772933446435053, weight_decay=3.0659008781964345e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112   10.0          0.025503   278.825990
# ...
#        12    Stopped     1       0.000086          256           2 0.449918      0.000393      1          0.028341    32.307972
#        13    Stopped     1       0.000081           32           2 0.395359      0.000032      1          0.033035    14.505847
#        14    Stopped     1       0.000431          256           4 0.438796      0.000333      1          0.028482    51.007268
#        15    Stopped     1       0.000022           64           3 0.374445      0.000097      1          0.036396    16.130298
#        16    Stopped     1       0.000053           64           4 0.447889      0.000014      1          0.033148    17.489303
#        17    Stopped     3       0.000435          256           3 0.218216      0.000082      3          0.029907   114.592586
#        18    Stopped     1       0.000093           32           4 0.310307      0.000421      1          0.030711    16.667912
#        19    Stopped     1       0.000015          128           4 0.323642      0.000024      1          0.030765    20.236401
#        20    Stopped     1       0.000071           32           2 0.346240      0.000120      1          0.032431    14.674190
#        21    Stopped     1       0.000475          256           2 0.421414      0.000303      1          0.028769    31.323489
#        22    Stopped     1       0.000025          256           4 0.452047      0.000042      1          0.036233    50.769491
#        23    Stopped     3       0.000192          256           3 0.371198      0.000010      3          0.028630   112.805767
#        24    Stopped     9       0.000171          128           3 0.475276      0.000340      9          0.026495   135.683093
#        25    Stopped     3       0.000172          128           2 0.239490      0.000015      3          0.030158    42.747701
#        26    Stopped     1       0.000038           64           3 0.236011      0.000251      1          0.030521    16.017528
#        27    Stopped     1       0.000023          128           3 0.305874      0.000395      1          0.031765    17.918798
#        28    Stopped     3       0.000168          256           4 0.248228      0.000065      3          0.027309   141.037518
#        29 InProgress     6       0.000057          128           4 0.249754      0.000205      6          0.026923   103.927180
# 1 trials running, 29 finished (2 until the end), 2042.32s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.026367   124.964347
#         1    Stopped    10       0.000042          256           2 0.421039      0.000112     10          0.025503   278.825990
#         2    Stopped     1       0.000125          256           2 0.256101      0.000113      1          0.042323    31.719801
#         3    Stopped     3       0.000265          128           3 0.278375      0.000151      3          0.026995    47.023326
#         4    Stopped     1       0.000037          128           3 0.249860      0.000085      1          0.030707    17.880257
#         5    Stopped     3       0.000153          128           2 0.487833      0.000020      3          0.031425    42.546345
#         6    Stopped     3       0.000216          128           2 0.332749      0.000064      3          0.029349    42.409639
#         7    Stopped     1       0.000162           32           4 0.278395      0.000
#        24    Stopped     9       0.000171          128           3 0.475276      0.000340    9.0          0.026495   135.683093
#        25    Stopped     3       0.000172          128           2 0.239490      0.000015    3.0          0.030158    42.747701
#        26    Stopped     1       0.000038           64           3 0.236011      0.000251    1.0          0.030521    16.017528
#        27    Stopped     1       0.000023          128           3 0.305874      0.000395    1.0          0.031765    17.918798
#        28    Stopped     3       0.000168          256           4 0.248228      0.000065    3.0          0.027309   141.037518
#        29    Stopped     9       0.000057          128           4 0.249754      0.000205    9.0          0.026864   154.133403
#        30 InProgress     0       0.000078           64           3 0.460985      0.000024      -                 -            -
# 1 trials running, 30 finished (2 until the end), 2082.43s wallclock-time
#
# validation_error: best 0.024964099749922752 for trial-id 25
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-23-17-15-38-096
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-23-17-15-38-096
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##11. Load Results from Dissolved Oxygen HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
oxygen_results_path = "/root/syne-tune/python-entrypoint-2026-03-23-17-15-38-096/results.csv.zip"

# Save the results to a Pandas DataFrame
oxygen_results = pd.read_csv(oxygen_results_path)

# %% [markdown]
# ##12. Save the Oxygen HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
oxygen_hpo_results_path = Path("/content/TROUT_BECK_CALGARTH_GAUGING_STATION_E_201704_oxygen_hpo_results.csv")

# Save the DataFrame to a csv file
oxygen_results.to_csv(oxygen_hpo_results_path, index=True)

# %% [markdown]
# ## 13. Define the Config Space, Scheduler, and Tune Function for Temperature HPO

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on temperature_t_96 targets
def temperature_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Create the path to the directory containing the data in the Jupyter notebook environment
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/windermere_inflows_and_outflow/trout_beck/TROUT%20BECK_CALGARTH%20GAUGING%20STATION_E_201704/TROUT%20BECK_CALGARTH%20GAUGING%20STATION_E_201704_preprocessed_data.zip")
    # Assign the full filepath for the preprocessed data
    parameter_path = "/content" / data_path / "TROUT BECK_CALGARTH GAUGING STATION_E_201704_preprocessed_data.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "temperature"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ##14. Initialise and Run the Tuner for Temperature HPO

# %%
# Instruct the searcher to run each trial as a Python function
temperature_trial_backend = PythonBackend(
    tune_function=temperature_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=temperature_trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-23-17-52-17-679
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-23-17-52-17-679
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-23-17-52-17-679
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [17:52:18] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay
#         0 InProgress     0        0.00001           64           2      0.2       0.00001
# 1 trials running, 0 finished (0 until the end), 20.01s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     2        0.00001           64           2      0.2       0.00001      2          0.053573    26.359038
# 1 trials running, 0 finished (0 until the end), 40.04s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     4        0.00001           64           2      0.2       0.00001      4          0.053004     49.80774
# 1 trials running, 0 finished (0 until the end), 60.05s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     5        0.00001           64           2      0.2       0.00001      5          0.052482    61.645251
# 1 trials running, 0 finished (0 until the end), 80.07s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     7        0.00001           64           2      0.2       0.00001      7          0.052453    85.113159
# 1 trials running, 0 finished (0 until the end), 100.09s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     9        0.00001           64           2      0.2       0.00001      9          0.052692   108.461029
# 1 trials running, 0 finished (0 until the end), 120.11s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [17:54:28] ✅ Trial 0 completed!
# [17:54:28] 🚀 Trial 1 started - config: learning_rate=0.00042195659702694, num_hiddens=256, num_layers=4, dropout=0.43171758352383754, weight_decay=8.454994656859954e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1 InProgress     0       0.000422          256           4 0.431718      0.000085      -                 -            -
# 1 trials running, 1 finished (1 until the end), 140.13s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1 InProgress     0       0.000422          256           4 0.431718      0.000085      -                 -            -
# 1 trials running, 1 finished (1 until the end), 160.13s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1 InProgress     0       0.000422          256           4 0.431718      0.000085      -                 -            -
# 1 trials running, 1 finished (1 until the end), 180.14s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [17:55:28] 🚀 Trial 2 started - config: learning_rate=0.0004457882363463263, num_hiddens=32, num_layers=4, dropout=0.3721727061920961, weight_decay=0.0001310413751866307
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085    1.0          0.057047    50.802991
#         2 InProgress     0       0.000446           32           4 0.372173      0.000131      -                 -            -
# 1 trials running, 2 finished (1 until the end), 200.16s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085      1          0.057047    50.802991
#         2 InProgress     1       0.000446           32           4 0.372173      0.000131      1          0.052420    16.510001
# 1 trials running, 2 finished (1 until the end), 220.18s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085      1          0.057047    50.802991
#         2 InProgress     2       0.000446           32           4 0.372173      0.000131      2          0.052163    30.351708
# 1 trials running, 2 finished (1 until the end), 240.20s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [17:56:18] 🚀 Trial 3 started - config: learning_rate=1.0816774910924956e-05, num_hiddens=256, num_layers=3, dropout=0.32660084346345986, weight_decay=0.00045046087878551215
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085    1.0          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131    3.0          0.052859    43.954682
#         3 InProgress     0       0.000011          256           3 0.326601      0.000450      -                 -            -
# 1 trials running, 3 finished (1 until the end), 260.21s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085    1.0          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131    3.0          0.052859    43.954682
#         3 InProgress     0       0.000011          256           3 0.326601      0.000450      -                 -            -
# 1 trials running, 3 finished (1 until the end), 280.22s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085      1          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131      3          0.052859    43.954682
#         3 InProgress     1       0.000011          256           3 0.326601      0.000450      1          0.052517    40.760023
# 1 trials running, 3 finished (1 until the end), 300.24s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085      1          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131      3          0.052859    43.954682
#         3 InProgress     1       0.000011          256           3 0.326601      0.000450      1          0.052517    40.760023
# 1 trials running, 3 finished (1 until the end), 320.25s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085      1          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131      3          0.052859    43.954682
#         3 InProgress     2       0.000011          256           3 0.326601      0.000450      2          0.054363    76.791672
# 1 trials running, 3 finished (1 until the end), 340.27s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085      1          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131      3          0.052859    43.954682
#         3 InProgress     2       0.000011          256           3 0.326601      0.000450      2          0.054363    76.791672
# 1 trials running, 3 finished (1 until the end), 360.28s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [17:58:18] 🚀 Trial 4 started - config: learning_rate=2.0493570371564095e-05, num_hiddens=32, num_layers=3, dropout=0.43650066336984206, weight_decay=0.00016286398767853479
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085    1.0          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131    3.0          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450    3.0          0.052953   112.898238
#         4 InProgress     0       0.000020           32           3 0.436501      0.000163      -                 -            -
# 1 trials running, 4 finished (1 until the end), 380.30s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [17:58:43] 🚀 Trial 5 started - config: learning_rate=0.0004051538697331802, num_hiddens=64, num_layers=4, dropout=0.43266897709722185, weight_decay=4.5464994810093084e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085    1.0          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131    3.0          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450    3.0          0.052953   112.898238
#         4    Stopped     1       0.000020           32           3 0.436501      0.000163    1.0          0.057750    15.708152
#         5 InProgress     0       0.000405           64           4 0.432669      0.000045      -                 -            -
# 1 trials running, 5 finished (1 until the end), 400.33s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085      1          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131      3          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450      3          0.052953   112.898238
#         4    Stopped     1       0.000020           32           3 0.436501      0.000163      1          0.057750    15.708152
#         5 InProgress     1       0.000405           64           4 0.432669      0.000045      1          0.052173    17.726095
# 1 trials running, 5 finished (1 until the end), 420.35s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085      1          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131      3          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450      3          0.052953   112.898238
#         4    Stopped     1       0.000020           32           3 0.436501      0.000163      1          0.057750    15.708152
#         5 InProgress     2       0.000405           64           4 0.432669      0.000045      2          0.052159    32.601501
# 1 trials running, 5 finished (1 until the end), 440.37s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [17:59:38] 🚀 Trial 6 started - config: learning_rate=1.4149128792681089e-05, num_hiddens=128, num_layers=3, dropout=0.4268475377382971, weight_decay=0.00045334096334255817
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085    1.0          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131    3.0          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450    3.0          0.052953   112.898238
#         4    Stopped     1       0.000020           32           3 0.436501      0.000163    1.0          0.057750    15.708152
#         5    Stopped     3       0.000405           64           4 0.432669      0.000045    3.0          0.055155    47.336268
#         6 InProgress     0       0.000014          128           3 0.426848      0.000453      -                 -            -
# 1 trials running, 6 finished (1 until the end), 460.40s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [18:00:03] 🚀 Trial 7 started - config: learning_rate=1.030935000344225e-05, num_hiddens=128, num_layers=4, dropout=0.43108177048680735, weight_decay=0.0002780946879992774
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085    1.0          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131    3.0          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450    3.0          0.052953   112.898238
#         4    Stopped     1       0.000020           32           3 0.436501      0.000163    1.0          0.057750    15.708152
#         5    Stopped     3       0.000405           64           4 0.432669      0.000045    3.0          0.055155    47.336268
#         6    Stopped     1       0.000014          128           3 0.426848      0.000453    1.0          0.053192    18.245895
#         7 InProgress     0       0.000010          128           4 0.431082      0.000278      -                 -            -
# 1 trials running, 7 finished (1 until the end), 480.42s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [18:00:33] 🚀 Trial 8 started - config: learning_rate=1.8758726234433504e-05, num_hiddens=256, num_layers=2, dropout=0.36951287810790456, weight_decay=1.1340723754743906e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085    1.0          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131    3.0          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450    3.0          0.052953   112.898238
#         4    Stopped     1       0.000020           32           3 0.436501      0.000163    1.0          0.057750    15.708152
#         5    Stopped     3       0.000405           64           4 0.432669      0.000045    3.0          0.055155    47.336268
#         6    Stopped     1       0.000014          128           3 0.426848      0.000453    1.0          0.053192    18.245895
#         7    Stopped     1       0.000010          128           4 0.431082      0.000278    1.0          0.054820    20.313141
#         8 InProgress     0       0.000019          256           2 0.369513      0.000011      -                 -            -
# 1 trials running, 8 finished (1 until the end), 500.45s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085    1.0          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131    3.0          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450    3.0          0.052953   112.898238
#         4    Stopped     1       0.000020           32           3 0.436501      0.000163    1.0          0.057750    15.708152
#         5    Stopped     3       0.000405           64           4 0.432669      0.000045    3.0          0.055155    47.336268
#         6    Stopped     1       0.000014          128           3 0.426848      0.000453    1.0          0.053192    18.245895
#         7    Stopped     1       0.000010          128           4 0.431082      0.000278    1.0          0.054820    20.313141
#         8 InProgress     0       0.000019          256           2 0.369513      0.000011      -                 -            -
# 1 trials running, 8 finished (1 until the end), 520.46s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [18:01:13] 🚀 Trial 9 started - config: learning_rate=0.00012418303212394956, num_hiddens=128, num_layers=4, dropout=0.3325600696007416, weight_decay=2.1184048387048944e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085    1.0          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131    3.0          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450    3.0          0.052953   112.898238
#         4    Stopped     1       0.000020           32           3 0.436501      0.000163    1.0          0.057750    15.708152
#         5    Stopped     3       0.000405           64           4 0.432669      0.000045    3.0          0.055155    47.336268
#         6    Stopped     1       0.000014          128           3 0.426848      0.000453    1.0          0.053192    18.245895
#         7    Stopped     1       0.000010          128           4 0.431082      0.000278    1.0          0.054820    20.313141
#         8    Stopped     1       0.000019          256           2 0.369513      0.000011    1.0          0.053836    32.038949
#         9 InProgress     0       0.000124          128           4 0.332560      0.000021      -                 -            -
# 1 trials running, 9 finished (1 until the end), 540.48s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085    1.0          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131    3.0          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450    3.0          0.052953   112.898238
#         4    Stopped     1       0.000020           32           3 0.436501      0.000163    1.0          0.057750    15.708152
#         5    Stopped     3       0.000405           64           4 0.432669      0.000045    3.0          0.055155    47.336268
#         6    Stopped     1       0.000014          128           3 0.426848      0.000453    1.0          0.053192    18.245895
#         7    Stopped     1       0.000010          128           4 0.431082      0.000278    1.0          0.054820    20.313141
#         8    Stopped     1       0.000019          256           2 0.369513      0.000011    1.0          0.053836    32.038949
#         9 InProgress     0       0.000124          128           4 0.332560      0.000021      -                 -            -
# 1 trials running, 9 finished (1 until the end), 560.49s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [18:01:43] 🚀 Trial 10 started - config: learning_rate=1.387225582379836e-05, num_hiddens=32, num_layers=2, dropout=0.3346211132306652, weight_decay=0.00015677119170247862
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085    1.0          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131    3.0          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450    3.0          0.052953   112.898238
#         4    Stopped     1       0.000020           32           3 0.436501      0.000163    1.0          0.057750    15.708152
#         5    Stopped     3       0.000405           64           4 0.432669      0.000045    3.0          0.055155    47.336268
#         6    Stopped     1       0.000014          128           3 0.426848      0.000453    1.0          0.053192    18.245895
#         7    Stopped     1       0.000010          128           4 0.431082      0.000278    1.0          0.054820    20.313141
#         8    Stopped     1       0.000019          256           2 0.369513      0.000011    1.0          0.053836    32.038949
#         9    Stopped     1       0.000124          128           4 0.332560      0.000021    1.0          0.056697    20.315819
#        10 InProgress     0       0.000014           32           2 0.334621      0.000157      -                 -            -
# 1 trials running, 10 finished (1 until the end), 580.51s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [18:02:03] 🚀 Trial 11 started - config: learning_rate=4.479056461170698e-05, num_hiddens=64, num_layers=3, dropout=0.43712091770348915, weight_decay=1.3225244137446778e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085    1.0          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131    3.0          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450    3.0          0.052953   112.898238
#         4    Stopped     1       0.000020           32           3 0.436501      0.000163    1.0          0.057750    15.708152
#         5    Stopped     3       0.000405           64           4 0.432669      0.000045    3.0          0.055155    47.336268
#         6    Stopped     1       0.000014          128           3 0.426848      0.000453    1.0          0.053192    18.245895
#         7    Stopped     1       0.000010          128           4 0.431082      0.000278    1.0          0.054820    20.313141
#         8    Stopped     1       0.000019          256           2 0.369513      0.000011    1.0          0.053836    32.038949
#         9    Stopped     1       0.000124          128           4 0.332560      0.000021    1.0          0.056697    20.315819
#        10    Stopped     1       0.000014           32           2 0.334621      0.000157    1.0          0.055867    14.613907
#        11 InProgress     0       0.000045           64           3 0.437121      0.000013      -                 -            -
# 1 trials running, 11 finished (1 until the end), 600.54s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [18:02:28] 🚀 Trial 12 started - config: learning_rate=3.3345099095781555e-05, num_hiddens=256, num_layers=3, dropout=0.22577834532676863, weight_decay=0.00022993979645380565
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085    1.0          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131    3.0          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450    3.0          0.052953   112.898238
#         4    Stopped     1       0.000020           32           3 0.436501      0.000163    1.0          0.057750    15.708152
#         5    Stopped     3       0.000405           64           4 0.432669      0.000045    3.0          0.055155    47.336268
#         6    Stopped     1       0.000014          128           3 0.426848      0.000453    1.0          0.053192    18.245895
#         7    Stopped     1       0.000010          128           4 0.431082      0.000278    1.0          0.054820    20.313141
#         8    Stopped     1       0.000019          256           2 0.369513      0.000011    1.0          0.053836    32.038949
#         9    Stopped     1       0.000124          128           4 0.332560      0.000021    1.0          0.056697    20.315819
#        10    Stopped     1       0.000014           32           2 0.334621      0.000157    1.0          0.055867    14.613907
#        11    Stopped     1       0.000045           64           3 0.437121      0.000013    1.0          0.053963    16.105989
#        12 InProgress     0       0.000033          256           3 0.225778      0.000230      -                 -            -
# 1 trials running, 12 finished (1 until the end), 620.56s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085    1.0          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131    3.0          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450    3.0          0.052953   112.898238
#         4    Stopped     1       0.000020           32           3 0.436501      0.000163    1.0          0.057750    15.708152
#         5    Stopped     3       0.000405           64           4 0.432669      0.000045    3.0          0.055155    47.336268
#         6    Stopped     1       0.000014          128           3 0.426848      0.000453    1.0          0.053192    18.245895
#         7    Stopped     1       0.000010          128           4 0.431082      0.000278    1.0          0.054820    20.313141
#         8    Stopped     1       0.000019          256           2 0.369513      0.000011    1.0          0.053836    32.038949
#         9    Stopped     1       0.000124          128           4 0.332560      0.000021    1.0          0.056697    20.315819
#        10    Stopped     1       0.000014           32           2 0.334621      0.000157    1.0          0.055867    14.613907
#        11    Stopped     1       0.000045           64           3 0.437121      0.000013    1.0          0.053963    16.105989
#        12 InProgress     0       0.000033          256           3 0.225778      0.000230      -                 -            -
# 1 trials running, 12 finished (1 until the end), 640.57s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085    1.0          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131    3.0          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450    3.0          0.052953   112.898238
#         4    Stopped     1       0.000020           32           3 0.436501      0.000163    1.0          0.057750    15.708152
#         5    Stopped     3       0.000405           64           4 0.432669      0.000045    3.0          0.055155    47.336268
#         6    Stopped     1       0.000014          128           3 0.426848      0.000453    1.0          0.053192    18.245895
#         7    Stopped     1       0.000010          128           4 0.431082      0.000278    1.0          0.054820    20.313141
#         8    Stopped     1       0.000019          256           2 0.369513      0.000011    1.0          0.053836    32.038949
#         9    Stopped     1       0.000124          128           4 0.332560      0.000021    1.0          0.056697    20.315819
#        10    Stopped     1       0.000014           32           2 0.334621      0.000157    1.0          0.055867    14.613907
#        11    Stopped     1       0.000045           64           3 0.437121      0.000013    1.0          0.053963    16.105989
#        12 InProgress     0       0.000033          256           3 0.225778      0.000230      -                 -            -
# 1 trials running, 12 finished (1 until the end), 660.58s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085      1          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131      3          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450      3          0.052953   112.898238
#         4    Stopped     1       0.000020           32           3 0.436501      0.000163      1          0.057750    15.708152
#         5    Stopped     3       0.000405           64           4 0.432669      0.000045      3          0.055155    47.336268
#         6    Stopped     1       0.000014          128           3 0.426848      0.000453      1          0.053192    18.245895
#         7    Stopped     1       0.000010          128           4 0.431082      0.000278      1          0.054820    20.313141
#         8    Stopped     1       0.000019          256           2 0.369513      0.000011      1          0.053836    32.038949
#         9    Stopped     1       0.000124          128           4 0.332560      0.000021      1          0.056697    20.315819
#        10    Stopped     1       0.000014           32           2 0.334621      0.000157      1          0.055867    14.613907
#        11    Stopped     1       0.000045           64           3 0.437121      0.000013      1          0.053963    16.105989
#        12 InProgress     1       0.000033          256           3 0.225778      0.000230      1          0.053016    41.495691
# 1 trials running, 12 finished (1 until the end), 680.61s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085      1          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131      3          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450      3          0.052953   112.898238
#         4    Stopped     1       0.000020           32           3 0.436501      0.000163      1          0.057750    15.708152
#         5    Stopped     3       0.000405           64           4 0.432669      0.000045      3          0.055155    47.336268
#         6    Stopped     1       0.000014          128           3 0.426848      0.000453      1          0.053192    18.245895
#         7    Stopped     1       0.000010          128           4 0.431082      0.000278      1          0.054820    20.313141
#         8    Stopped     1       0.000019          256           2 0.369513      0.000011      1          0.053836    32.038949
#         9    Stopped     1       0.000124          128           4 0.332560      0.000021      1          0.056697    20.315819
#        10    Stopped     1       0.000014           32           2 0.334621      0.000157      1          0.055867    14.613907
#        11    Stopped     1       0.000045           64           3 0.437121      0.000013      1          0.053963    16.105989
#        12 InProgress     2       0.000033          256           3 0.225778      0.000230      2          0.055454    77.900656
# 1 trials running, 12 finished (1 until the end), 700.63s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085      1          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131      3          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450      3          0.052953   112.898238
#         4    Stopped     1       0.000020           32           3 0.436501      0.000163      1          0.057750    15.708152
#         5    Stopped     3       0.000405           64           4 0.432669      0.000045      3          0.055155    47.336268
#         6    Stopped     1       0.000014          128           3 0.426848      0.000453      1          0.053192    18.245895
#         7    Stopped     1       0.000010          128           4 0.431082      0.000278      1          0.054820    20.313141
#         8    Stopped     1       0.000019          256           2 0.369513      0.000011      1          0.053836    32.038949
#         9    Stopped     1       0.000124          128           4 0.332560      0.000021      1          0.056697    20.315819
#        10    Stopped     1       0.000014           32           2 0.334621      0.000157      1          0.055867    14.613907
#        11    Stopped     1       0.000045           64           3 0.437121      0.000013      1          0.053963    16.105989
#        12 InProgress     2       0.000033          256           3 0.225778      0.000230      2          0.055454    77.900656
# 1 trials running, 12 finished (1 until the end), 720.64s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [18:04:29] 🚀 Trial 13 started - config: learning_rate=0.00032587269072799975, num_hiddens=256, num_layers=2, dropout=0.386909316200555, weight_decay=0.000278627270585222
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085    1.0          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131    3.0          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450    3.0          0.052953   112.898238
#         4    Stopped     1       0.000020           32           3 0.436501      0.000163    1.0          0.057750    15.708152
#         5    Stopped     3       0.000405           64           4 0.432669      0.000045    3.0          0.055155    47.336268
#         6    Stopped     1       0.000014          128           3 0.426848      0.000453    1.0          0.053192    18.245895
#         7    Stopped     1       0.000010          128           4 0.431082      0.000278    1.0          0.054820    20.313141
#         8    Stopped     1       0.000019          256           2 0.369513      0.000011    1.0          0.053836    32.038949
#         9    Stopped     1       0.000124          128           4 0.332560      0.000021    1.0          0.056697    20.315819
#        10    Stopped     1       0.000014           32           2 0.334621      0.000157    1.0          0.055867    14.613907
#        11    Stopped     1       0.000045           64           3 0.437121      0.000013    1.0          0.053963    16.105989
#        12    Stopped     3       0.000033          256           3 0.225778      0.000230    3.0          0.054223   114.244050
#        13 InProgress     0       0.000326          256           2 0.386909      0.000279      -                 -            -
# 1 trials running, 13 finished (1 until the end), 740.67s wallclock-time
#
# ...
#        12    Stopped     3       0.000033          256           3 0.225778      0.000230    3.0          0.054223   114.244050
#        13    Stopped     3       0.000326          256           2 0.386909      0.000279    3.0          0.054013    88.104750
#        14    Stopped     1       0.000026          256           2 0.229107      0.000027    1.0          0.054500    32.184885
#        15    Stopped     1       0.000229          128           3 0.419521      0.000246    1.0          0.053950    18.220167
#        16    Stopped     1       0.000084           64           2 0.470520      0.000416    1.0          0.053694    14.653687
#        17    Stopped     1       0.000011           32           4 0.361815      0.000021    1.0          0.061150    16.535393
#        18    Stopped     1       0.000355          128           4 0.468700      0.000041    1.0          0.061792    20.185170
#        19    Stopped     1       0.000414          256           4 0.477221      0.000014    1.0          0.054734    51.080048
0.054820    20.313141
#         8    Stopped     1       0.000019          256           2 0.369513      0.000011    1.0          0.053836    32.038949
#         9    Stopped     1       0.000124          128           4 0.332560      0.000021    1.0          0.056697    20.315819
#        10    Stopped     1       0.000014           32           2 0.334621      0.000157    1.0          0.055867    14.613907
#        11    Stopped     1       0.000045           64           3 0.437121      0.000013    1.0          0.053963    16.105989
#        12    Stopped     3       0.000033          256           3 0.225778      0.000230    3.0          0.054223   114.244050
#        13    Stopped     3       0.000326          256           2 0.386909      0.000279    3.0          0.054013    88.104750
#        14    Stopped     1       0.000026          256           2 0.229107      0.000027    1.0          0.054500    32.184885
#        15    Stopped     1       0.000229          128           3 0.419521      0.000246    1.0          0.053950    18.220167
#        16    Stopped     1       0.000084           64           2 0.470520      0.000416    1.0          0.053694    14.653687
#        17    Stopped     1       0.000011           32           4 0.361815      0.000021    1.0          0.061150    16.535393
#        18    Stopped     1       0.000355          128           4 0.468700      0.000041    1.0          0.061792    20.185170
#        19    Stopped     1       0.000414          256           4 0.477221      0.000014    1.0          0.054734    51.080048
#        20    Stopped     9       0.000016          128           2 0.435056      0.000095    9.0          0.053486   120.770123
#        21    Stopped     3       0.000307          256           3 0.349505      0.000481    3.0          0.055952   113.928053
#        22    Stopped     3       0.000080          128           3 0.209395      0.000251    3.0          0.053357    47.665053
#        23    Stopped     1       0.000038           64           2 0.443045      0.000164    1.0          0.053799    14.873992
#        24  Completed    10       0.000022          256           2 0.291535      0.000481   10.0          0.052182   286.874629
#        25    Stopped     3       0.000051          128           2 0.237025      0.000226    3.0          0.053922    43.296187
#        26    Stopped     1       0.000093           64           4 0.270041      0.000087    1.0          0.054283    17.697408
#        27    Stopped     1       0.000014           32           3 0.348453      0.000011    1.0          0.057494    15.671807
#        28    Stopped     1       0.000017          128           3 0.437465      0.000042    1.0          0.055501    18.170563
#        29 InProgress     0       0.000394          128           3 0.451316      0.000049      -                 -            -
# 1 trials running, 29 finished (2 until the end), 1802.05s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [18:22:20] 🚀 Trial 30 started - config: learning_rate=3.832643106369288e-05, num_hiddens=32, num_layers=2, dropout=0.4306967634253362, weight_decay=0.0001177048786392438
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🎉🎉🎉 HYPERPARAMETER OPTIMIZATION COMPLETE!
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# --------------------
# Resource summary (last result is reported):
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.053173   120.155517
#         1    Stopped     1       0.000422          256           4 0.431718      0.000085    1.0          0.057047    50.802991
#         2    Stopped     3       0.000446           32           4 0.372173      0.000131    3.0          0.052859    43.954682
#         3    Stopped     3       0.000011          256           3 0.326601      0.000450    3.0          0.052953   112.898238
#         4    Stopped     1       0.000020           32           3 0.436501      0.000163    1.0          0.057750    15.708152
#         5    Stopped     3       0.000405           64           4 0.432669      0.000045    3.0          0.055155    47.336268
#         6    Stopped     1       0.000014          128           3 0.426848      0.000453    1.0          0.053192    18.245895
#         7    Stopped     1       0.000010          128           4 0.431082      0.000278    1.0          0.054820    20.313141
#         8    Stopped     1       0.000019          256           2 0.369513      0.000011    1.0          0.053836    32.038949
#         9    Stopped     1       0.000124          128           4 0.332560      0.000021    1.0          0.056697    20.315819
#        10    Stopped     1       0.000014           32           2 0.334621      0.000157    1.0          0.055867    14.613907
#        11    Stopped     1       0.000045           64           3 0.437121      0.000013    1.0          0.053963    16.105989
#        12    Stopped     3       0.000033          256           3 0.225778      0.000230    3.0          0.054223   114.244050
#        13    Stopped     3       0.000326          256           2 0.386909      0.000279    3.0          0.054013    88.104750
#        14    Stopped     1       0.000026          256           2 0.229107      0.000027    1.0          0.054500    32.184885
#        15    Stopped     1       0.000229          128           3 0.419521      0.000246    1.0          0.053950    18.220167
#        16    Stopped     1       0.000084           64           2 0.470520      0.000416    1.0          0.053694    14.653687
#        17    Stopped     1       0.000011           32           4 0.361815      0.000021    1.0          0.061150    16.535393
#        18    Stopped     1       0.000355          128           4 0.468700      0.000041    1.0          0.061792    20.185170
#        19    Stopped     1       0.000414          256           4 0.477221      0.000014    1.0          0.054734    51.080048
#        20    Stopped     9       0.000016          128           2 0.435056      0.000095    9.0          0.053486   120.770123
#        21    Stopped     3       0.000307          256           3 0.349505      0.000481    3.0          0.055952   113.928053
#        22    Stopped     3       0.000080          128           3 0.209395      0.000251    3.0          0.053357    47.665053
#        23    Stopped     1       0.000038           64           2 0.443045      0.000164    1.0          0.053799    14.873992
#        24  Completed    10       0.000022          256           2 0.291535      0.000481   10.0          0.052182   286.874629
#        25    Stopped     3       0.000051          128           2 0.237025      0.000226    3.0          0.053922    43.296187
#        26    Stopped     1       0.000093           64           4 0.270041      0.000087    1.0          0.054283    17.697408
#        27    Stopped     1       0.000014           32           3 0.348453      0.000011    1.0          0.057494    15.671807
#        28    Stopped     1       0.000017          128           3 0.437465      0.000042    1.0          0.055501    18.170563
#        29    Stopped     1       0.000394          128           3 0.451316      0.000049    1.0          0.054811    18.035163
#        30 InProgress     0       0.000038           32           2 0.430697      0.000118      -                 -            -
# 1 trials running, 30 finished (2 until the end), 1802.08s wallclock-time
#
# validation_error: best 0.05031216889619827 for trial-id 13
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-23-17-52-17-679
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-23-17-52-17-679
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##15. Load Results from Temperature HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
temperature_results_path = "/root/syne-tune/python-entrypoint-2026-03-23-17-52-17-679/results.csv.zip"

# Save the results to a Pandas DataFrame
temperature_results = pd.read_csv(temperature_results_path)

# %% [markdown]
# ##16. Save the Temperature HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
temperature_hpo_results_path = Path("/content/TROUT BECK_CALGARTH GAUGING STATION_E_201704_temperature_hpo_results.csv")

# Save the DataFrame to a csv file
temperature_results.to_csv(temperature_hpo_results_path, index=True)
