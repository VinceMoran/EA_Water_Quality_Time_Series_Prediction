# %% [markdown]
# # Station Information
#
# * Station name: BLELHAM BECK_FOOTBRIDGE_E_202303
# * Water Quality Data link: https://environment.data.gov.uk/hydrology/station/E02614A

# %% [markdown]
# ## 0. Import the Relevant Libraries

# %%
from pathlib import Path
from urllib import request
import pandas as pd
import numpy as np
import xgboost as xgb
import torch
from sklearn.metrics import root_mean_squared_error
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Import Base Classes and Helper Functions from the Project GitHub and Set Random Seeds

# %%
# Import the Base Classes and Helper Functions from the Project GitHub
url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"

file_path = Path("base_classes_and_helper_functions.py")
if not file_path.exists():
    request.urlretrieve(url, file_path)
import base_classes_and_helper_functions as bchf

# %%
# Set the random seed for all PRNGs to ensure reproducibility
bchf.set_random_seed()

# %% [markdown]
# ## 2. Load the Raw Data from the Project GitHub into a Pandas DataFrame

# %%
# Create the path to the directory containing the data in the Jupyter notebook environment
data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/windermere_inflows_and_outflow/blelham_beck/BLELHAM%20BECK_FOOTBRIDGE_E_202303/BLELHAM%20BECK_FOOTBRIDGE_E_202303_preprocessed_data.zip")

# Assign the full filepath for the preprocessed data
parameter_path = "/content" / data_path / "BLELHAM BECK_FOOTBRIDGE_E_202303_preprocessed_data.csv"
# Out:
# [INFO] data/raw_data directory has been created.
# [INFO] Downloading data...
# [INFO] Data extracted to data/raw_data.
# [INFO] ZIP file removed.

# %%
# Load the data into a Pandas DataFrame
df_parameters = pd.read_csv(parameter_path)

# Inspect the first 5 rows of the DataFrame
df_parameters.head()
# Out:
#               dateTime  ammonium  conductivity  oxygen_conc  oxygen_perc  \
# 0  2023-03-24 14:44:12      0.08         75.58        11.26        98.03
# 1  2023-03-24 14:45:36      0.11         74.70        11.27        98.08
# 2  2023-03-24 14:58:13      0.06         74.53        11.30        98.42
# 3  2023-03-24 15:00:36      0.06         74.48        11.29        98.43
# 4  2023-03-24 16:00:36      0.05         73.88        11.30        98.94
#
#    temperature  turbidity  ammonium_impossible  conductivity_impossible  \
# 0        9.242       1.44                False                    False
# 1        9.255       1.45                False                    False
# 2        9.294       4.17                False                    False
# 3        9.308       3.55                False                    False
# 4        9.485       3.50                False                    False
#
#    oxygen_conc_impossible  oxygen_perc_impossible  temperature_impossible  \
# 0                   False                   False                   False
# 1                   False                   False                   False
# 2                   False                   False                   False
# 3                   False                   False                   False
# 4                   False                   False                   False
#
#    turbidity_impossible  ammonium_anomaly  conductivity_anomaly  \
# 0                 False             False                 False
# 1                 False             False                 False
# 2                 False             False                 False
# 3                 False             False                 False
# 4                 False             False                 False
#
#    oxygen_perc_anomaly  turbidity_anomaly  oxygen_conc_anomaly  \
# 0                False              False                False
# 1                False              False                False
# 2                False              False                False
# 3                False              False                False
# 4                False              False                False
#
#    temperature_anomaly
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False

# %%
# Investigate the unique value distributions of the DataFrame
bchf.unique_value_counts(df_parameters, "WATER QUALITY PARAMETER DATAFRAME")
# Out:
# DISTINCT VALUE COUNTS FOR WATER QUALITY PARAMETER DATAFRAME:
# Variable         Number of Distinct Value Counts
# dateTime                   45139
#
# ammonium                    970
#
# conductivity               10723
#
# oxygen_conc                1384
#
# oxygen_perc                8250
#
# temperature                15869
#
# turbidity                  3205
#
# ammonium_impossible             2
#
# conductivity_impossible             2
#
# oxygen_conc_impossible             1
#
# oxygen_perc_impossible             1
#
# temperature_impossible             2
#
# turbidity_impossible             2
#
# ammonium_anomaly             2
#
# conductivity_anomaly             2
#
# oxygen_perc_anomaly             2
#
# turbidity_anomaly             2
#
# oxygen_conc_anomaly             1
#
# temperature_anomaly             1

# %%
# Investigate the datatypes and numbers of missing values for each variable
bchf.datatypes_and_missing_values(df_parameters, "WATER QUALITY PARAMETER DATAFRAME")
# Out:
# DATATYPES AND MISSING VALUES FOR WATER QUALITY PARAMETER DATAFRAME
# Variable           Data Type      Number of Missing Values
# dateTime          , object        ,            0
# ammonium          , float64       ,            0
# conductivity      , float64       ,            0
# oxygen_conc       , float64       ,            0
# oxygen_perc       , float64       ,            0
# temperature       , float64       ,            0
# turbidity         , float64       ,            0
# ammonium_impossible, bool          ,            0
# conductivity_impossible, bool          ,            0
# oxygen_conc_impossible, bool          ,            0
# oxygen_perc_impossible, bool          ,            0
# temperature_impossible, bool          ,            0
# turbidity_impossible, bool          ,            0
# ammonium_anomaly  , bool          ,            0
# conductivity_anomaly, bool          ,            0
# oxygen_perc_anomaly, bool          ,            0
# turbidity_anomaly , bool          ,            0
# oxygen_conc_anomaly, bool          ,            0
# temperature_anomaly, bool          ,            0

# %% [markdown]
# ## 3. Reindex the DataFrame and Engineer Additional Features for Time Series Modelling

# %%
# Change the data type for the dateTime column to datetime64
df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)

# Set the datetime column as the index
df_parameters.set_index('dateTime', inplace=True)

# Investigate the first 5 rows of the reindexed DataFrame
df_parameters.head()
# Out:
#                      ammonium  conductivity  oxygen_conc  oxygen_perc  \
# dateTime
# 2023-03-24 14:44:12      0.08         75.58        11.26        98.03
# 2023-03-24 14:45:36      0.11         74.70        11.27        98.08
# 2023-03-24 14:58:13      0.06         74.53        11.30        98.42
# 2023-03-24 15:00:36      0.06         74.48        11.29        98.43
# 2023-03-24 16:00:36      0.05         73.88        11.30        98.94
#
#                      temperature  turbidity  ammonium_impossible  \
# dateTime
# 2023-03-24 14:44:12        9.242       1.44                False
# 2023-03-24 14:45:36        9.255       1.45                False
# 2023-03-24 14:58:13        9.294       4.17                False
# 2023-03-24 15:00:36        9.308       3.55                False
# 2023-03-24 16:00:36        9.485       3.50                False
#
#                      conductivity_impossible  oxygen_conc_impossible  \
# dateTime
# 2023-03-24 14:44:12                    False                   False
# 2023-03-24 14:45:36                    False                   False
# 2023-03-24 14:58:13                    False                   False
# 2023-03-24 15:00:36                    False                   False
# 2023-03-24 16:00:36                    False                   False
#
#                      oxygen_perc_impossible  temperature_impossible  \
# dateTime
# 2023-03-24 14:44:12                   False                   False
# 2023-03-24 14:45:36                   False                   False
# 2023-03-24 14:58:13                   False                   False
# 2023-03-24 15:00:36                   False                   False
# 2023-03-24 16:00:36                   False                   False
#
#                      turbidity_impossible  ammonium_anomaly  \
# dateTime
# 2023-03-24 14:44:12                 False             False
# 2023-03-24 14:45:36                 False             False
# 2023-03-24 14:58:13                 False             False
# 2023-03-24 15:00:36                 False             False
# 2023-03-24 16:00:36                 False             False
#
#                      conductivity_anomaly  oxygen_perc_anomaly  \
# dateTime
# 2023-03-24 14:44:12                 False                False
# 2023-03-24 14:45:36                 False                False
# 2023-03-24 14:58:13                 False                False
# 2023-03-24 15:00:36                 False                False
# 2023-03-24 16:00:36                 False                False
#
#                      turbidity_anomaly  oxygen_conc_anomaly  \
# dateTime
# 2023-03-24 14:44:12              False                False
# 2023-03-24 14:45:36              False                False
# 2023-03-24 14:58:13              False                False
# 2023-03-24 15:00:36              False                False
# 2023-03-24 16:00:36              False                False
#
#                      temperature_anomaly
# dateTime
# 2023-03-24 14:44:12                False
# 2023-03-24 14:45:36                False
# 2023-03-24 14:58:13                False
# 2023-03-24 15:00:36                False
# 2023-03-24 16:00:36                False

# %%
# Numerically encode date and time as features
df_parameters["day_of_year"] = df_parameters.index.dayofyear
df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))

df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))

# Remove redundant columns
df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)

# Inspect the first 5 rows of the DataFrame
df_parameters.head()
# Out:
#                      ammonium  conductivity  oxygen_conc  oxygen_perc  \
# dateTime
# 2023-03-24 14:44:12      0.08         75.58        11.26        98.03
# 2023-03-24 14:45:36      0.11         74.70        11.27        98.08
# 2023-03-24 14:58:13      0.06         74.53        11.30        98.42
# 2023-03-24 15:00:36      0.06         74.48        11.29        98.43
# 2023-03-24 16:00:36      0.05         73.88        11.30        98.94
#
#                      temperature  turbidity  ammonium_impossible  \
# dateTime
# 2023-03-24 14:44:12        9.242       1.44                False
# 2023-03-24 14:45:36        9.255       1.45                False
# 2023-03-24 14:58:13        9.294       4.17                False
# 2023-03-24 15:00:36        9.308       3.55                False
# 2023-03-24 16:00:36        9.485       3.50                False
#
#                      conductivity_impossible  oxygen_conc_impossible  \
# dateTime
# 2023-03-24 14:44:12                    False                   False
# 2023-03-24 14:45:36                    False                   False
# 2023-03-24 14:58:13                    False                   False
# 2023-03-24 15:00:36                    False                   False
# 2023-03-24 16:00:36                    False                   False
#
#                      oxygen_perc_impossible  ...  ammonium_anomaly  \
# dateTime                                     ...
# 2023-03-24 14:44:12                   False  ...             False
# 2023-03-24 14:45:36                   False  ...             False
# 2023-03-24 14:58:13                   False  ...             False
# 2023-03-24 15:00:36                   False  ...             False
# 2023-03-24 16:00:36                   False  ...             False
#
#                      conductivity_anomaly  oxygen_perc_anomaly  \
# dateTime
# 2023-03-24 14:44:12                 False                False
# 2023-03-24 14:45:36                 False                False
# 2023-03-24 14:58:13                 False                False
# 2023-03-24 15:00:36                 False                False
# 2023-03-24 16:00:36                 False                False
#
#                      turbidity_anomaly  oxygen_conc_anomaly  \
# dateTime
# 2023-03-24 14:44:12              False                False
# 2023-03-24 14:45:36              False                False
# 2023-03-24 14:58:13              False                False
# 2023-03-24 15:00:36              False                False
# 2023-03-24 16:00:36              False                False
#
#                      temperature_anomaly  day_of_year_sin  day_of_year_cos  \
# dateTime
# 2023-03-24 14:44:12                False         0.989932          0.14154
# 2023-03-24 14:45:36                False         0.989932          0.14154
# 2023-03-24 14:58:13                False         0.989932          0.14154
# 2023-03-24 15:00:36                False         0.989932          0.14154
# 2023-03-24 16:00:36                False         0.989932          0.14154
#
#                      minute_of_day_sin  minute_of_day_cos
# dateTime
# 2023-03-24 14:44:12          -0.656059          -0.754710
# 2023-03-24 14:45:36          -0.659346          -0.751840
# 2023-03-24 14:58:13          -0.700909          -0.713250
# 2023-03-24 15:00:36          -0.707107          -0.707107
# 2023-03-24 16:00:36          -0.866025          -0.500000
#
# [5 rows x 22 columns]

# %%
# Create lagged variables for each feature
variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]

for i in np.arange(1, 5):
  for variable in variables:
    df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)

# Inspect the first 5 rows of the DataFrame
df_parameters.head()
# Out:
#                      ammonium  conductivity  oxygen_conc  oxygen_perc  \
# dateTime
# 2023-03-24 14:44:12      0.08         75.58        11.26        98.03
# 2023-03-24 14:45:36      0.11         74.70        11.27        98.08
# 2023-03-24 14:58:13      0.06         74.53        11.30        98.42
# 2023-03-24 15:00:36      0.06         74.48        11.29        98.43
# 2023-03-24 16:00:36      0.05         73.88        11.30        98.94
#
#                      temperature  turbidity  ammonium_impossible  \
# dateTime
# 2023-03-24 14:44:12        9.242       1.44                False
# 2023-03-24 14:45:36        9.255       1.45                False
# 2023-03-24 14:58:13        9.294       4.17                False
# 2023-03-24 15:00:36        9.308       3.55                False
# 2023-03-24 16:00:36        9.485       3.50                False
#
#                      conductivity_impossible  oxygen_conc_impossible  \
# dateTime
# 2023-03-24 14:44:12                    False                   False
# 2023-03-24 14:45:36                    False                   False
# 2023-03-24 14:58:13                    False                   False
# 2023-03-24 15:00:36                    False                   False
# 2023-03-24 16:00:36                    False                   False
#
#                      oxygen_perc_impossible  ...  oxygen_conc_lag3  \
# dateTime                                     ...
# 2023-03-24 14:44:12                   False  ...               NaN
# 2023-03-24 14:45:36                   False  ...               NaN
# 2023-03-24 14:58:13                   False  ...               NaN
# 2023-03-24 15:00:36                   False  ...             11.26
# 2023-03-24 16:00:36                   False  ...             11.27
#
#                      oxygen_perc_lag3  temperature_lag3  turbidity_lag3  \
# dateTime
# 2023-03-24 14:44:12               NaN               NaN             NaN
# 2023-03-24 14:45:36               NaN               NaN             NaN
# 2023-03-24 14:58:13               NaN               NaN             NaN
# 2023-03-24 15:00:36             98.03             9.242            1.44
# 2023-03-24 16:00:36             98.08             9.255            1.45
#
#                      ammonium_lag4  conductivity_lag4  oxygen_conc_lag4  \
# dateTime
# 2023-03-24 14:44:12            NaN                NaN               NaN
# 2023-03-24 14:45:36            NaN                NaN               NaN
# 2023-03-24 14:58:13            NaN                NaN               NaN
# 2023-03-24 15:00:36            NaN                NaN               NaN
# 2023-03-24 16:00:36           0.08              75.58             11.26
#
#                      oxygen_perc_lag4  temperature_lag4  turbidity_lag4
# dateTime
# 2023-03-24 14:44:12               NaN               NaN             NaN
# 2023-03-24 14:45:36               NaN               NaN             NaN
# 2023-03-24 14:58:13               NaN               NaN             NaN
# 2023-03-24 15:00:36               NaN               NaN             NaN
# 2023-03-24 16:00:36             98.03             9.242            1.44
#
# [5 rows x 46 columns]

# %%
# Create moving averages for each water quality variable
moving_average_windows = np.array([6, 12, 24]) # hours
timestep_windows = moving_average_windows * 4 # number of timesteps

# Loop through creating moving averages from only past values to avoid temporal leakage
for i in timestep_windows:
  for variable in variables:
    df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()

# Inspect the first 5 rows of the DataFrame
df_parameters.head()
# Out:
#                      ammonium  conductivity  oxygen_conc  oxygen_perc  \
# dateTime
# 2023-03-24 14:44:12      0.08         75.58        11.26        98.03
# 2023-03-24 14:45:36      0.11         74.70        11.27        98.08
# 2023-03-24 14:58:13      0.06         74.53        11.30        98.42
# 2023-03-24 15:00:36      0.06         74.48        11.29        98.43
# 2023-03-24 16:00:36      0.05         73.88        11.30        98.94
#
#                      temperature  turbidity  ammonium_impossible  \
# dateTime
# 2023-03-24 14:44:12        9.242       1.44                False
# 2023-03-24 14:45:36        9.255       1.45                False
# 2023-03-24 14:58:13        9.294       4.17                False
# 2023-03-24 15:00:36        9.308       3.55                False
# 2023-03-24 16:00:36        9.485       3.50                False
#
#                      conductivity_impossible  oxygen_conc_impossible  \
# dateTime
# 2023-03-24 14:44:12                    False                   False
# 2023-03-24 14:45:36                    False                   False
# 2023-03-24 14:58:13                    False                   False
# 2023-03-24 15:00:36                    False                   False
# 2023-03-24 16:00:36                    False                   False
#
#                      oxygen_perc_impossible  ...  oxygen_conc_ma48  \
# dateTime                                     ...
# 2023-03-24 14:44:12                   False  ...         11.260000
# 2023-03-24 14:45:36                   False  ...         11.265000
# 2023-03-24 14:58:13                   False  ...         11.276667
# 2023-03-24 15:00:36                   False  ...         11.280000
# 2023-03-24 16:00:36                   False  ...         11.284000
#
#                      oxygen_perc_ma48  temperature_ma48  turbidity_ma48  \
# dateTime
# 2023-03-24 14:44:12         98.030000          9.242000        1.440000
# 2023-03-24 14:45:36         98.055000          9.248500        1.445000
# 2023-03-24 14:58:13         98.176667          9.263667        2.353333
# 2023-03-24 15:00:36         98.240000          9.274750        2.652500
# 2023-03-24 16:00:36         98.380000          9.316800        2.822000
#
#                      ammonium_ma96  conductivity_ma96  oxygen_conc_ma96  \
# dateTime
# 2023-03-24 14:44:12       0.080000          75.580000         11.260000
# 2023-03-24 14:45:36       0.095000          75.140000         11.265000
# 2023-03-24 14:58:13       0.083333          74.936667         11.276667
# 2023-03-24 15:00:36       0.077500          74.822500         11.280000
# 2023-03-24 16:00:36       0.072000          74.634000         11.284000
#
#                      oxygen_perc_ma96  temperature_ma96  turbidity_ma96
# dateTime
# 2023-03-24 14:44:12         98.030000          9.242000        1.440000
# 2023-03-24 14:45:36         98.055000          9.248500        1.445000
# 2023-03-24 14:58:13         98.176667          9.263667        2.353333
# 2023-03-24 15:00:36         98.240000          9.274750        2.652500
# 2023-03-24 16:00:36         98.380000          9.316800        2.822000
#
# [5 rows x 64 columns]

# %%
# Create seasonal lagged features
seasonality = 96 # 24 hours prior in 15 minute sensor data

target_vars = ["ammonium", "oxygen_conc", "temperature"]

for target in target_vars:
  df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)

# Inspect the first 5 rows of the DataFrame
df_parameters.head()
# Out:
#                      ammonium  conductivity  oxygen_conc  oxygen_perc  \
# dateTime
# 2023-03-24 14:44:12      0.08         75.58        11.26        98.03
# 2023-03-24 14:45:36      0.11         74.70        11.27        98.08
# 2023-03-24 14:58:13      0.06         74.53        11.30        98.42
# 2023-03-24 15:00:36      0.06         74.48        11.29        98.43
# 2023-03-24 16:00:36      0.05         73.88        11.30        98.94
#
#                      temperature  turbidity  ammonium_impossible  \
# dateTime
# 2023-03-24 14:44:12        9.242       1.44                False
# 2023-03-24 14:45:36        9.255       1.45                False
# 2023-03-24 14:58:13        9.294       4.17                False
# 2023-03-24 15:00:36        9.308       3.55                False
# 2023-03-24 16:00:36        9.485       3.50                False
#
#                      conductivity_impossible  oxygen_conc_impossible  \
# dateTime
# 2023-03-24 14:44:12                    False                   False
# 2023-03-24 14:45:36                    False                   False
# 2023-03-24 14:58:13                    False                   False
# 2023-03-24 15:00:36                    False                   False
# 2023-03-24 16:00:36                    False                   False
#
#                      oxygen_perc_impossible  ...  turbidity_ma48  \
# dateTime                                     ...
# 2023-03-24 14:44:12                   False  ...        1.440000
# 2023-03-24 14:45:36                   False  ...        1.445000
# 2023-03-24 14:58:13                   False  ...        2.353333
# 2023-03-24 15:00:36                   False  ...        2.652500
# 2023-03-24 16:00:36                   False  ...        2.822000
#
#                      ammonium_ma96  conductivity_ma96  oxygen_conc_ma96  \
# dateTime
# 2023-03-24 14:44:12       0.080000          75.580000         11.260000
# 2023-03-24 14:45:36       0.095000          75.140000         11.265000
# 2023-03-24 14:58:13       0.083333          74.936667         11.276667
# 2023-03-24 15:00:36       0.077500          74.822500         11.280000
# 2023-03-24 16:00:36       0.072000          74.634000         11.284000
#
#                      oxygen_perc_ma96  temperature_ma96  turbidity_ma96  \
# dateTime
# 2023-03-24 14:44:12         98.030000          9.242000        1.440000
# 2023-03-24 14:45:36         98.055000          9.248500        1.445000
# 2023-03-24 14:58:13         98.176667          9.263667        2.353333
# 2023-03-24 15:00:36         98.240000          9.274750        2.652500
# 2023-03-24 16:00:36         98.380000          9.316800        2.822000
#
#                      ammonium_seasonal_lag96  oxygen_conc_seasonal_lag96  \
# dateTime
# 2023-03-24 14:44:12                      NaN                         NaN
# 2023-03-24 14:45:36                      NaN                         NaN
# 2023-03-24 14:58:13                      NaN                         NaN
# 2023-03-24 15:00:36                      NaN                         NaN
# 2023-03-24 16:00:36                      NaN                         NaN
#
#                      temperature_seasonal_lag96
# dateTime
# 2023-03-24 14:44:12                         NaN
# 2023-03-24 14:45:36                         NaN
# 2023-03-24 14:58:13                         NaN
# 2023-03-24 15:00:36                         NaN
# 2023-03-24 16:00:36                         NaN
#
# [5 rows x 67 columns]

# %%
# Loop through creating moving averages from only past values to avoid temporal leakage
for i in timestep_windows:
  for variable in variables:
    df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()

# Inpect the first 5 rows of the DataFrame
df_parameters.head()
# Out:
#                      ammonium  conductivity  oxygen_conc  oxygen_perc  \
# dateTime
# 2023-03-24 14:44:12      0.08         75.58        11.26        98.03
# 2023-03-24 14:45:36      0.11         74.70        11.27        98.08
# 2023-03-24 14:58:13      0.06         74.53        11.30        98.42
# 2023-03-24 15:00:36      0.06         74.48        11.29        98.43
# 2023-03-24 16:00:36      0.05         73.88        11.30        98.94
#
#                      temperature  turbidity  ammonium_impossible  \
# dateTime
# 2023-03-24 14:44:12        9.242       1.44                False
# 2023-03-24 14:45:36        9.255       1.45                False
# 2023-03-24 14:58:13        9.294       4.17                False
# 2023-03-24 15:00:36        9.308       3.55                False
# 2023-03-24 16:00:36        9.485       3.50                False
#
#                      conductivity_impossible  oxygen_conc_impossible  \
# dateTime
# 2023-03-24 14:44:12                    False                   False
# 2023-03-24 14:45:36                    False                   False
# 2023-03-24 14:58:13                    False                   False
# 2023-03-24 15:00:36                    False                   False
# 2023-03-24 16:00:36                    False                   False
#
#                      oxygen_perc_impossible  ...  \
# dateTime                                     ...
# 2023-03-24 14:44:12                   False  ...
# 2023-03-24 14:45:36                   False  ...
# 2023-03-24 14:58:13                   False  ...
# 2023-03-24 15:00:36                   False  ...
# 2023-03-24 16:00:36                   False  ...
#
#                      oxygen_conc_imputed_count_48  \
# dateTime
# 2023-03-24 14:44:12                           0.0
# 2023-03-24 14:45:36                           0.0
# 2023-03-24 14:58:13                           0.0
# 2023-03-24 15:00:36                           0.0
# 2023-03-24 16:00:36                           0.0
#
#                      oxygen_perc_imputed_count_48  \
# dateTime
# 2023-03-24 14:44:12                           0.0
# 2023-03-24 14:45:36                           0.0
# 2023-03-24 14:58:13                           0.0
# 2023-03-24 15:00:36                           0.0
# 2023-03-24 16:00:36                           0.0
#
#                      temperature_imputed_count_48  turbidity_imputed_count_48  \
# dateTime
# 2023-03-24 14:44:12                           0.0                         0.0
# 2023-03-24 14:45:36                           0.0                         0.0
# 2023-03-24 14:58:13                           0.0                         0.0
# 2023-03-24 15:00:36                           0.0                         0.0
# 2023-03-24 16:00:36                           0.0                         0.0
#
#                      ammonium_imputed_count_96  conductivity_imputed_count_96  \
# dateTime
# 2023-03-24 14:44:12                        0.0                            0.0
# 2023-03-24 14:45:36                        0.0                            0.0
# 2023-03-24 14:58:13                        0.0                            0.0
# 2023-03-24 15:00:36                        0.0                            0.0
# 2023-03-24 16:00:36                        0.0                            0.0
#
#                      oxygen_conc_imputed_count_96  \
# dateTime
# 2023-03-24 14:44:12                           0.0
# 2023-03-24 14:45:36                           0.0
# 2023-03-24 14:58:13                           0.0
# 2023-03-24 15:00:36                           0.0
# 2023-03-24 16:00:36                           0.0
#
#                      oxygen_perc_imputed_count_96  \
# dateTime
# 2023-03-24 14:44:12                           0.0
# 2023-03-24 14:45:36                           0.0
# 2023-03-24 14:58:13                           0.0
# 2023-03-24 15:00:36                           0.0
# 2023-03-24 16:00:36                           0.0
#
#                      temperature_imputed_count_96  turbidity_imputed_count_96
# dateTime
# 2023-03-24 14:44:12                           0.0                         0.0
# 2023-03-24 14:45:36                           0.0                         0.0
# 2023-03-24 14:58:13                           0.0                         0.0
# 2023-03-24 15:00:36                           0.0                         0.0
# 2023-03-24 16:00:36                           0.0                         0.0
#
# [5 rows x 85 columns]

# %% [markdown]
# ##4. Create Target Variables for Time Series Prediction

# %%
# Create the target variables
timesteps = [1, 2, 4, 24, 48, 96]
for target in target_vars:
    for timestep in timesteps:
        df_parameters[f"{target}_target_t_{str(timestep)}"] = df_parameters[target].shift(periods=-timestep)

# Removed NaN rows added after shifting features and targets
df_parameters.dropna(inplace=True)

# Inspect the first 5 rows of the DataFrame
df_parameters.head()
# Out:
#                      ammonium  conductivity  oxygen_conc  oxygen_perc  \
# dateTime
# 2023-03-28 12:00:36      0.04         79.44        11.10        92.51
# 2023-03-28 13:00:36      0.04         79.30        11.15        93.14
# 2023-03-28 14:00:36      0.04         79.87        11.26        94.40
# 2023-03-28 15:00:36      0.04         79.61        11.33        95.25
# 2023-03-28 16:00:36      0.04         79.35        11.34        95.59
#
#                      temperature  turbidity  ammonium_impossible  \
# dateTime
# 2023-03-28 12:00:36        7.476       2.99                False
# 2023-03-28 13:00:36        7.570       3.13                False
# 2023-03-28 14:00:36        7.702       3.01                False
# 2023-03-28 15:00:36        7.807       2.99                False
# 2023-03-28 16:00:36        7.935       3.01                False
#
#                      conductivity_impossible  oxygen_conc_impossible  \
# dateTime
# 2023-03-28 12:00:36                    False                   False
# 2023-03-28 13:00:36                    False                   False
# 2023-03-28 14:00:36                    False                   False
# 2023-03-28 15:00:36                    False                   False
# 2023-03-28 16:00:36                    False                   False
#
#                      oxygen_perc_impossible  ...  oxygen_conc_target_t_4  \
# dateTime                                     ...
# 2023-03-28 12:00:36                   False  ...                   11.34
# 2023-03-28 13:00:36                   False  ...                   11.24
# 2023-03-28 14:00:36                   False  ...                   11.12
# 2023-03-28 15:00:36                   False  ...                   10.98
# 2023-03-28 16:00:36                   False  ...                   10.83
#
#                      oxygen_conc_target_t_24  oxygen_conc_target_t_48  \
# dateTime
# 2023-03-28 12:00:36                    11.15                    11.09
# 2023-03-28 13:00:36                    11.17                    11.14
# 2023-03-28 14:00:36                    11.16                    11.18
# 2023-03-28 15:00:36                    11.06                    11.17
# 2023-03-28 16:00:36                    10.97                    11.11
#
#                      oxygen_conc_target_t_96  temperature_target_t_1  \
# dateTime
# 2023-03-28 12:00:36                    11.14                   7.570
# 2023-03-28 13:00:36                    11.22                   7.702
# 2023-03-28 14:00:36                    11.27                   7.807
# 2023-03-28 15:00:36                    11.25                   7.935
# 2023-03-28 16:00:36                    11.19                   8.010
#
#                      temperature_target_t_2  temperature_target_t_4  \
# dateTime
# 2023-03-28 12:00:36                   7.702                   7.935
# 2023-03-28 13:00:36                   7.807                   8.010
# 2023-03-28 14:00:36                   7.935                   8.053
# 2023-03-28 15:00:36                   8.010                   8.056
# 2023-03-28 16:00:36                   8.053                   8.035
#
#                      temperature_target_t_24  temperature_target_t_48  \
# dateTime
# 2023-03-28 12:00:36                    8.697                    9.170
# 2023-03-28 13:00:36                    8.880                    9.365
# 2023-03-28 14:00:36                    9.002                    9.557
# 2023-03-28 15:00:36                    9.089                    9.706
# 2023-03-28 16:00:36                    9.156                    9.807
#
#                      temperature_target_t_96
# dateTime
# 2023-03-28 12:00:36                    8.603
# 2023-03-28 13:00:36                    8.941
# 2023-03-28 14:00:36                    9.249
# 2023-03-28 15:00:36                    9.442
# 2023-03-28 16:00:36                    9.482
#
# [5 rows x 103 columns]

# %% [markdown]
# ##5. Split Dataset Into Training/Validation/Testing Sets

# %%
# Split the DataFrame into training, validation, and testing sets
df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                      train_size=0.6,
                                                      val_size=0.2,
                                                      test_size=0.2)

# Save DataFrames as copies to enable in-place modifications
df_train, df_val, df_test = df_train.copy(), df_val.copy(), df_test.copy()

# %%
# Loop through DataFrames to convert columns to appropriate data types
for df in [df_train, df_val, df_test]:
    # Identify columns containing Boolean or 64 bit floating point data
    bool_cols = df.select_dtypes(include='bool').columns
    float_cols = df.select_dtypes(include='float64').columns
    # Convert data types to int8 or float32 to reduce memory usage and speed up training
    df[bool_cols] = df[bool_cols].astype('int8')
    df[float_cols] = df[float_cols].astype('float32')

# %%
# Investigate the datatype and number of missing values for each variable after preparing dataset for modelling
bchf.datatypes_and_missing_values(df_train, "WATER QUALITY PARAMETER DATAFRAME")
# Out:
# DATATYPES AND MISSING VALUES FOR WATER QUALITY PARAMETER DATAFRAME
# Variable           Data Type      Number of Missing Values
# ammonium          , float32       ,            0
# conductivity      , float32       ,            0
# oxygen_conc       , float32       ,            0
# oxygen_perc       , float32       ,            0
# temperature       , float32       ,            0
# turbidity         , float32       ,            0
# ammonium_impossible, int8          ,            0
# conductivity_impossible, int8          ,            0
# oxygen_conc_impossible, int8          ,            0
# oxygen_perc_impossible, int8          ,            0
# temperature_impossible, int8          ,            0
# turbidity_impossible, int8          ,            0
# ammonium_anomaly  , int8          ,            0
# conductivity_anomaly, int8          ,            0
# oxygen_perc_anomaly, int8          ,            0
# turbidity_anomaly , int8          ,            0
# oxygen_conc_anomaly, int8          ,            0
# temperature_anomaly, int8          ,            0
# day_of_year_sin   , float32       ,            0
# day_of_year_cos   , float32       ,            0
# minute_of_day_sin , float32       ,            0
# minute_of_day_cos , float32       ,            0
# ammonium_lag1     , float32       ,            0
# conductivity_lag1 , float32       ,            0
# oxygen_conc_lag1  , float32       ,            0
# oxygen_perc_lag1  , float32       ,            0
# temperature_lag1  , float32       ,            0
# turbidity_lag1    , float32       ,            0
# ammonium_lag2     , float32       ,            0
# conductivity_lag2 , float32       ,            0
# oxygen_conc_lag2  , float32       ,            0
# oxygen_perc_lag2  , float32       ,            0
# temperature_lag2  , float32       ,            0
# turbidity_lag2    , float32       ,            0
# ammonium_lag3     , float32       ,            0
# conductivity_lag3 , float32       ,            0
# oxygen_conc_lag3  , float32       ,            0
# oxygen_perc_lag3  , float32       ,            0
# temperature_lag3  , float32       ,            0
# turbidity_lag3    , float32       ,            0
# ammonium_lag4     , float32       ,            0
# conductivity_lag4 , float32       ,            0
# oxygen_conc_lag4  , float32       ,            0
# oxygen_perc_lag4  , float32       ,            0
# temperature_lag4  , float32       ,            0
# turbidity_lag4    , float32       ,            0
# ammonium_ma24     , float32       ,            0
# conductivity_ma24 , float32       ,            0
# oxygen_conc_ma24  , float32       ,            0
# oxygen_perc_ma24  , float32       ,            0
# temperature_ma24  , float32       ,            0
# turbidity_ma24    , float32       ,            0
# ammonium_ma48     , float32       ,            0
# conductivity_ma48 , float32       ,            0
# oxygen_conc_ma48  , float32       ,            0
# oxygen_perc_ma48  , float32       ,            0
# temperature_ma48  , float32       ,            0
# turbidity_ma48    , float32       ,            0
# ammonium_ma96     , float32       ,            0
# conductivity_ma96 , float32       ,            0
# oxygen_conc_ma96  , float32       ,            0
# oxygen_perc_ma96  , float32       ,            0
# temperature_ma96  , float32       ,            0
# turbidity_ma96    , float32       ,            0
# ammonium_seasonal_lag96, float32       ,            0
# oxygen_conc_seasonal_lag96, float32       ,            0
# temperature_seasonal_lag96, float32       ,            0
# ammonium_imputed_count_24, float32       ,            0
# conductivity_imputed_count_24, float32       ,            0
# oxygen_conc_imputed_count_24, float32       ,            0
# oxygen_perc_imputed_count_24, float32       ,            0
# temperature_imputed_count_24, float32       ,            0
# turbidity_imputed_count_24, float32       ,            0
# ammonium_imputed_count_48, float32       ,            0
# conductivity_imputed_count_48, float32       ,            0
# oxygen_conc_imputed_count_48, float32       ,            0
# oxygen_perc_imputed_count_48, float32       ,            0
# temperature_imputed_count_48, float32       ,            0
# turbidity_imputed_count_48, float32       ,            0
# ammonium_imputed_count_96, float32       ,            0
# conductivity_imputed_count_96, float32       ,            0
# oxygen_conc_imputed_count_96, float32       ,            0
# oxygen_perc_imputed_count_96, float32       ,            0
# temperature_imputed_count_96, float32       ,            0
# turbidity_imputed_count_96, float32       ,            0
# ammonium_target_t_1, float32       ,            0
# ammonium_target_t_2, float32       ,            0
# ammonium_target_t_4, float32       ,            0
# ammonium_target_t_24, float32       ,            0
# ammonium_target_t_48, float32       ,            0
# ammonium_target_t_96, float32       ,            0
# oxygen_conc_target_t_1, float32       ,            0
# oxygen_conc_target_t_2, float32       ,            0
# oxygen_conc_target_t_4, float32       ,            0
# oxygen_conc_target_t_24, float32       ,            0
# oxygen_conc_target_t_48, float32       ,            0
# oxygen_conc_target_t_96, float32       ,            0
# temperature_target_t_1, float32       ,            0
# temperature_target_t_2, float32       ,            0
# temperature_target_t_4, float32       ,            0
# temperature_target_t_24, float32       ,            0
# temperature_target_t_48, float32       ,            0
# temperature_target_t_96, float32       ,            0

# %% [markdown]
# ##6. Prepare Data for Forecasting Using Time-Lagged XGBoost

# %%
# Create list of target variables
targets = []
for target in target_vars:
    for timestep in timesteps:
        targets.append(f"{target}_target_t_{timestep}")

# Create list of features
features = df_train.columns.drop(targets)

print("Targets:", targets)
print("\nFeatures:", features)
# Out:
# Targets: ['ammonium_target_t_1', 'ammonium_target_t_2', 'ammonium_target_t_4', 'ammonium_target_t_24', 'ammonium_target_t_48', 'ammonium_target_t_96', 'oxygen_conc_target_t_1', 'oxygen_conc_target_t_2', 'oxygen_conc_target_t_4', 'oxygen_conc_target_t_24', 'oxygen_conc_target_t_48', 'oxygen_conc_target_t_96', 'temperature_target_t_1', 'temperature_target_t_2', 'temperature_target_t_4', 'temperature_target_t_24', 'temperature_target_t_48', 'temperature_target_t_96']
#
# Features: Index(['ammonium', 'conductivity', 'oxygen_conc', 'oxygen_perc', 'temperature',
#        'turbidity', 'ammonium_impossible', 'conductivity_impossible',
#        'oxygen_conc_impossible', 'oxygen_perc_impossible',
#        'temperature_impossible', 'turbidity_impossible', 'ammonium_anomaly',
#        'conductivity_anomaly', 'oxygen_perc_anomaly', 'turbidity_anomaly',
#        'oxygen_conc_anomaly', 'temperature_anomaly', 'day_of_year_sin',
#        'day_of_year_cos', 'minute_of_day_sin', 'minute_of_day_cos',
#        'ammonium_lag1', 'conductivity_lag1', 'oxygen_conc_lag1',
#        'oxygen_perc_lag1', 'temperature_lag1', 'turbidity_lag1',
#        'ammonium_lag2', 'conductivity_lag2', 'oxygen_conc_lag2',
#        'oxygen_perc_lag2', 'temperature_lag2', 'turbidity_lag2',
#        'ammonium_lag3', 'conductivity_lag3', 'oxygen_conc_lag3',
#        'oxygen_perc_lag3', 'temperature_lag3', 'turbidity_lag3',
#        'ammonium_lag4', 'conductivity_lag4', 'oxygen_conc_lag4',
#        'oxygen_perc_lag4', 'temperature_lag4', 'turbidity_lag4',
#        'ammonium_ma24', 'conductivity_ma24', 'oxygen_conc_ma24',
#        'oxygen_perc_ma24', 'temperature_ma24', 'turbidity_ma24',
#        'ammonium_ma48', 'conductivity_ma48', 'oxygen_conc_ma48',
#        'oxygen_perc_ma48', 'temperature_ma48', 'turbidity_ma48',
#        'ammonium_ma96', 'conductivity_ma96', 'oxygen_conc_ma96',
#        'oxygen_perc_ma96', 'temperature_ma96', 'turbidity_ma96',
#        'ammonium_seasonal_lag96', 'oxygen_conc_seasonal_lag96',
#        'temperature_seasonal_lag96', 'ammonium_imputed_count_24',
#        'conductivity_imputed_count_24', 'oxygen_conc_imputed_count_24',
#        'oxygen_perc_imputed_count_24', 'temperature_imputed_count_24',
#        'turbidity_imputed_count_24', 'ammonium_imputed_count_48',
#        'conductivity_imputed_count_48', 'oxygen_conc_imputed_count_48',
#        'oxygen_perc_imputed_count_48', 'temperature_imputed_count_48',
#        'turbidity_imputed_count_48', 'ammonium_imputed_count_96',
#        'conductivity_imputed_count_96', 'oxygen_conc_imputed_count_96',
#        'oxygen_perc_imputed_count_96', 'temperature_imputed_count_96',
#        'turbidity_imputed_count_96'],
#       dtype='object')

# %%
# Create array for training features
X_train = df_train[features].values
# Create training targets dictionary
y_train_dict = {}
# Populate training targets dictionary with training data
for target in targets:
    y_train_dict[target] = df_train[target].values

# Create array for validation features
X_val = df_val[features].values
# Create validation targets dictionary
y_val_dict = {}
# Populate validation targets dictionary with validation data
for target in targets:
    y_val_dict[target] = df_val[target].values

# Create array for testing features
X_test = df_test[features].values
# Create testing targets dictionary
y_test_dict = {}
# Populate testing targets dictionary with testing data
for target in targets:
    y_test_dict[target] = df_test[target].values

# %%
# Create dictionary containing DMatrices for training, validating, and testing XGBoost on each target variable
dmatrices_train_dict = {}
dmatrices_val_dict = {}
dmatrices_test_dict = {}

# Store training DMatrices in dictionary for each target variable
for target in targets:
    # Create training DMatrices and store in dictionary
    dmatrices_train_dict[target] = xgb.DMatrix(X_train, label=y_train_dict[target])
    # Create validation DMatrices and store in dictionary
    dmatrices_val_dict[target] = xgb.DMatrix(X_val, label=y_val_dict[target])
    # Create testing DMatrices and store in dictionary
    dmatrices_test_dict[target] = xgb.DMatrix(X_test, label=y_test_dict[target])

# %% [markdown]
# ##7. Optimise XGBoost Hyperparameters Using Random Search

# %%
# Create a function that creates a random dictionary of hyperparameter configurations
def random_sample_hparams_xgboost():
    """
    Creates a random dictionary of hyperparameters for the XGBoost algorithm
    that can be used for exploring hyperparameter configuration ranges using
    HPO methods such as random search.

    Args:
      - None.

    Returns:
      hparams (dict): A random dictionary of hyperparameters.

    Side effects:
      - None.
    """
    # Create a random dictionary of hyperparameters from predefined configuration ranges (early experiments determined search space)
    hparams = {
        "objective": "reg:squarederror", # training objective to be minimised (regression based on squared error)
        "eval_metric": "rmse", # evaluation metric minimise during training (root mean squared error as XGBoost does not directly support mean squared error)
        "tree_method": "hist", # algorithm used for constructing trees in XGBoost (histogram approimated greedy algorithm for faster training)
        "device": "cuda" if torch.cuda.is_available() else "cpu", # device used for computation (uses GPU acceleration if available or defaults to CPU if not)
        "eta": 10**np.random.uniform(-3.5, -1.5), # learning rate (explores a lognormal distribution between (approximately) 0.0003 and 0.03 where smaller values result in slower training but more stable convergence)
        "gamma": np.random.uniform(3, 5), # minimum loss reduction required to split a node (explores a uniform distribution between 3 and 5 where larger values can reduce overfitting)
        "max_depth": np.random.randint(3, 10), # maximum tree depth (explores a discrete uniform distribution between 3 and 9 where larger trees can capture more complex patterns but risk overfitting)
        "min_child_weight": np.random.randint(4, 9), # minimum sum of Hessians (second order loss derivatives) required in a child node to allow a split (explores a discrete uniform distribution between 4 and 8 where lower values allow more aggressive splitting that may increase both model complexity and overfitting risk)
        "subsample": np.random.uniform(0.5, 0.7), # proportion of training dataset to subsample per boosting iteration prior to growing new trees (explores a uniform distribution between 30% and 70% where smaller proportion can introduce randomness that reduces overfitting whilst larger samples can retain more information that helps capture rare events)
        "colsample_bytree": np.random.uniform(0.5, 0.7), # proportion of columns (features) sampled by each tree (explores a uniform distribution between 30% and 70% where smaller values can prevent overfitting whilst larger values can capture more complex interdepencies between features and targets)
        "lambda": 10**np.random.uniform(1, 3), # L2 regularisation term applied to weights (explores a lognormal distribution between 1 and 1000 where larger values can reduce model complexity and overfitting)
        "alpha": 10**np.random.uniform(1, 3) # L1 regularisation term applied to weights (explores a lognormal distribution between 1 and 1000 where larger values can reduce model complexity and overfitting)
        }

    # Return the random dictionary of hyperparameters
    return hparams

# %%
# Generate 30 random hyperparameter configurations
bchf.set_random_seed()
random_hparam_configs = []
for i in np.arange(0,30):
    random_hparam_configs.append(random_sample_hparams_xgboost())

# %%
# Create the list of targets that will be used for HPO
hpo_targets = ["ammonium_target_t_96", "oxygen_conc_target_t_96", "temperature_target_t_96"] # use longest forecast horizon for HPO as this is the most complex model

# Create empty dictionaries for holding the best alpha configuration and best validation mse
best_hparam_dict = {}
best_val_rmse_dict = {}

# Specify the maximum number of trees/boosting rounds for training XGBoost
NUM_BOOST_ROUND = 10000 # set to 10000 to allow high ceiling for model complexity when early stopping is also used to prevent overfitting and excessive resource use
EARLY_STOPPING_ROUNDS = 50 # set to 50 to stop training after 50 rounds with no validation improvement

# %%
# Loop through HPO targets and store best hyperparameters and configurations and validation errors
for target in hpo_targets:
    print("\n----------------------------------------------------------------")
    print("----------------------------------------------------------------")
    print("----------------------------------------------------------------")
    print(f"NOW PREDICTING {target}".upper())
    best_rmse_val = float("inf") # initialise as infinity to ensure replaced by first evaluated trial
    best_hparam_config = None # initialise as none to ensure replaced by first evaluated trial
    # Initialise a counter to track trial number
    trial_counter = 1
    # Loop through random hyperparameter configurations
    for config in random_hparam_configs:
        # Print the current hyperparameter configuration for tracking verbose evaluation
        print("----------------------------------------------------------")
        print(f"\nTRIAL NUMBER {str(trial_counter)} WITH HYPERPARAMETER CONFIGURATION: {config}")
        # Specify the data to be used for training and evaluation of the model
        evallist = [
            (dmatrices_train_dict[target], "training"),
             (dmatrices_val_dict[target], "validation")
             ]
        # Train the XGBoost model on the data using the current hyperparameter configuration
        xgboost_model = xgb.train(
            config, # use current hyperparameters
            dmatrices_train_dict[target], # use the dmatrix corresponding to the current target for training
            num_boost_round=NUM_BOOST_ROUND, # maximum number of trees/boosting rounds to train for (defaults to 1000 to allow high ceiling for model complexity when early stopping is also used)
            early_stopping_rounds=EARLY_STOPPING_ROUNDS, # number of rounds with no validation improvement to allow before stopping training (defaults to 10 to speed up training and prevent overfitting)
            evals=evallist, # maps to the data used for evaluation
            verbose_eval=EARLY_STOPPING_ROUNDS*6 # number of rounds after which to print performance
            )
        # Create predictions using validation data
        y_val_pred = xgboost_model.predict(dmatrices_val_dict[target])
        # Compute the root mean squared error on the validation data
        rmse_val = root_mean_squared_error(y_val_dict[target], y_val_pred)
        # Store the configuration and error in dictionaries if lower validation error than previous trials
        if rmse_val < best_rmse_val:
            best_rmse_val = rmse_val
            best_hparam_config = config
        # Add to the counter to track trials
        trial_counter += 1
    # Store the best hyperparameter configuration and root mean squared validation error in dictionaries for each target
    best_hparam_dict[target] = best_hparam_config
    best_val_rmse_dict[target] = best_rmse_val
# Out:
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# NOW PREDICTING AMMONIUM_TARGET_T_96
# ----------------------------------------------------------
#
# TRIAL NUMBER 1 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.026304775926427458, 'gamma': 4.399024099899152, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.5440134599565704, 'colsample_bytree': 0.5722112707928115, 'lambda': 301.7741118446677, 'alpha': 983.8104927455976}
# [0]	training-rmse:0.52500	validation-rmse:0.06218
# [50]	training-rmse:0.52500	validation-rmse:0.06218
# ----------------------------------------------------------
#
# TRIAL NUMBER 2 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.001357356589364695, 'gamma': 3.273089159647049, 'max_depth': 4, 'min_child_weight': 6, 'subsample': 0.573282950616703, 'colsample_bytree': 0.6419303125176254, 'lambda': 631.3713357594794, 'alpha': 117.01212822443404}
# [0]	training-rmse:0.52492	validation-rmse:0.06213
# [300]	training-rmse:0.50214	validation-rmse:0.05460
# [600]	training-rmse:0.48280	validation-rmse:0.05011
# [900]	training-rmse:0.46612	validation-rmse:0.04795
# [1200]	training-rmse:0.45161	validation-rmse:0.04720
# [1500]	training-rmse:0.43897	validation-rmse:0.04668
# [1800]	training-rmse:0.42772	validation-rmse:0.04646
# [2041]	training-rmse:0.41951	validation-rmse:0.04643
# ----------------------------------------------------------
#
# TRIAL NUMBER 3 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.000987614664347347, 'gamma': 4.3436131251541505, 'max_depth': 4, 'min_child_weight': 8, 'subsample': 0.6085119753419019, 'colsample_bytree': 0.6786895207389801, 'lambda': 484.79607956253017, 'alpha': 40.92843888846576}
# [0]	training-rmse:0.52492	validation-rmse:0.06215
# [300]	training-rmse:0.49970	validation-rmse:0.05461
# [600]	training-rmse:0.47771	validation-rmse:0.05108
# [900]	training-rmse:0.45842	validation-rmse:0.04969
# [949]	training-rmse:0.45551	validation-rmse:0.04977
# ----------------------------------------------------------
#
# TRIAL NUMBER 4 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.005785482108959772, 'gamma': 4.360477720892311, 'max_depth': 3, 'min_child_weight': 6, 'subsample': 0.6787134303841522, 'colsample_bytree': 0.6884851722721561, 'lambda': 192.5089664883095, 'alpha': 169.5490136762781}
# [0]	training-rmse:0.52431	validation-rmse:0.06200
# [300]	training-rmse:0.39506	validation-rmse:0.04579
# [594]	training-rmse:0.35006	validation-rmse:0.04551
# ----------------------------------------------------------
#
# TRIAL NUMBER 5 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0009023323105762767, 'gamma': 3.9720637379327455, 'max_depth': 8, 'min_child_weight': 8, 'subsample': 0.6688440307044725, 'colsample_bytree': 0.6069361732459915, 'lambda': 327.7903014835408, 'alpha': 99.85131120336136}
# [0]	training-rmse:0.52491	validation-rmse:0.06215
# [300]	training-rmse:0.49688	validation-rmse:0.05549
# [600]	training-rmse:0.47273	validation-rmse:0.05162
# [900]	training-rmse:0.45159	validation-rmse:0.04875
# [1200]	training-rmse:0.43299	validation-rmse:0.04710
# [1500]	training-rmse:0.41671	validation-rmse:0.04631
# [1800]	training-rmse:0.40270	validation-rmse:0.04594
# [2100]	training-rmse:0.39034	validation-rmse:0.04567
# [2396]	training-rmse:0.37990	validation-rmse:0.04558
# ----------------------------------------------------------
#
# TRIAL NUMBER 6 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.01587288220096692, 'gamma': 4.239393550712144, 'max_depth': 8, 'min_child_weight': 4, 'subsample': 0.5463394393298, 'colsample_bytree': 0.5804436829161542, 'lambda': 177.3168976808123, 'alpha': 19.322949184435128}
# [0]	training-rmse:0.52245	validation-rmse:0.06141
# [101]	training-rmse:0.35592	validation-rmse:0.05382
# ----------------------------------------------------------
#
# TRIAL NUMBER 7 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0005566689107452353, 'gamma': 3.8336598215250044, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.6882838350878844, 'colsample_bytree': 0.5818518045006461, 'lambda': 297.51091166418536, 'alpha': 979.2675166489886}
# [0]	training-rmse:0.52500	validation-rmse:0.06218
# [50]	training-rmse:0.52500	validation-rmse:0.06218
# ----------------------------------------------------------
#
# TRIAL NUMBER 8 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.02154411697428862, 'gamma': 3.0040465451881166, 'max_depth': 9, 'min_child_weight': 4, 'subsample': 0.6778096353397447, 'colsample_bytree': 0.6398977212474379, 'lambda': 15.669290676232025, 'alpha': 140.23553569724845}
# [0]	training-rmse:0.51986	validation-rmse:0.06149
# [162]	training-rmse:0.25893	validation-rmse:0.04684
# ----------------------------------------------------------
#
# TRIAL NUMBER 9 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.013806202297330629, 'gamma': 4.121782101291188, 'max_depth': 8, 'min_child_weight': 6, 'subsample': 0.608699951218771, 'colsample_bytree': 0.6759178183424241, 'lambda': 16.911928339597402, 'alpha': 11.557864825479399}
# [0]	training-rmse:0.52005	validation-rmse:0.06101
# [64]	training-rmse:0.30330	validation-rmse:0.09094
# ----------------------------------------------------------
#
# TRIAL NUMBER 10 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.02544603503208933, 'gamma': 3.5774869487201437, 'max_depth': 3, 'min_child_weight': 8, 'subsample': 0.6193782887454218, 'colsample_bytree': 0.6310572091954619, 'lambda': 35.59515769389978, 'alpha': 519.9300465674321}
# [0]	training-rmse:0.52350	validation-rmse:0.06182
# [141]	training-rmse:0.43998	validation-rmse:0.05396
# ----------------------------------------------------------
#
# TRIAL NUMBER 11 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.018942979652414954, 'gamma': 3.5701211821306353, 'max_depth': 7, 'min_child_weight': 8, 'subsample': 0.6778658497027522, 'colsample_bytree': 0.5365654852757945, 'lambda': 42.67267232310354, 'alpha': 14.064992246256807}
# [0]	training-rmse:0.51939	validation-rmse:0.06141
# [61]	training-rmse:0.29416	validation-rmse:0.08933
# ----------------------------------------------------------
#
# TRIAL NUMBER 12 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0014120455317728669, 'gamma': 4.869921674487493, 'max_depth': 7, 'min_child_weight': 6, 'subsample': 0.5167090045891891, 'colsample_bytree': 0.5390019038790702, 'lambda': 36.55132350725101, 'alpha': 23.218271417109722}
# [0]	training-rmse:0.52461	validation-rmse:0.06211
# [300]	training-rmse:0.42415	validation-rmse:0.05225
# [382]	training-rmse:0.40228	validation-rmse:0.05235
# ----------------------------------------------------------
#
# TRIAL NUMBER 13 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.019352667757515353, 'gamma': 4.339948403826172, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.5881994360395475, 'colsample_bytree': 0.6531102853377269, 'lambda': 10.604423594508907, 'alpha': 229.78725033401707}
# [0]	training-rmse:0.52128	validation-rmse:0.06173
# [300]	training-rmse:0.29665	validation-rmse:0.04371
# [465]	training-rmse:0.29126	validation-rmse:0.04353
# ----------------------------------------------------------
#
# TRIAL NUMBER 14 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0011251366715034938, 'gamma': 4.207959642515683, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.5419579621101566, 'colsample_bytree': 0.5272245507360163, 'lambda': 345.40230218081496, 'alpha': 88.95461926038584}
# [0]	training-rmse:0.52491	validation-rmse:0.06214
# [300]	training-rmse:0.49637	validation-rmse:0.05474
# [600]	training-rmse:0.47232	validation-rmse:0.05009
# [900]	training-rmse:0.45167	validation-rmse:0.04704
# [1200]	training-rmse:0.43395	validation-rmse:0.04531
# [1500]	training-rmse:0.41866	validation-rmse:0.04435
# [1800]	training-rmse:0.40559	validation-rmse:0.04403
# [2045]	training-rmse:0.39616	validation-rmse:0.04393
# ----------------------------------------------------------
#
# TRIAL NUMBER 15 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0034532366179095705, 'gamma': 4.888386091598631, 'max_depth': 8, 'min_child_weight': 4, 'subsample': 0.5876500745473832, 'colsample_bytree': 0.5927575415211481, 'lambda': 31.453060308002954, 'alpha': 32.62261261598607}
# [0]	training-rmse:0.52397	validation-rmse:0.06199
# [206]	training-rmse:0.36845	validation-rmse:0.05320
# ----------------------------------------------------------
#
# TRIAL NUMBER 16 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0003515508314559019, 'gamma': 4.864810174037409, 'max_depth': 3, 'min_child_weight': 6, 'subsample': 0.5713479051519654, 'colsample_bytree': 0.5220880796450866, 'lambda': 78.90715792894737, 'alpha': 86.6657845622521}
# [0]	training-rmse:0.52494	validation-rmse:0.06216
# [300]	training-rmse:0.50654	validation-rmse:0.05884
# [600]	training-rmse:0.48974	validation-rmse:0.05612
# [900]	training-rmse:0.47424	validation-rmse:0.05392
# [1200]	training-rmse:0.46013	validation-rmse:0.05222
# [1500]	training-rmse:0.44706	validation-rmse:0.05081
# [1800]	training-rmse:0.43515	validation-rmse:0.04972
# [2100]	training-rmse:0.42418	validation-rmse:0.04892
# [2400]	training-rmse:0.41410	validation-rmse:0.04837
# [2700]	training-rmse:0.40485	validation-rmse:0.04809
# [3000]	training-rmse:0.39636	validation-rmse:0.04788
# [3274]	training-rmse:0.38920	validation-rmse:0.04782
# ----------------------------------------------------------
#
# TRIAL NUMBER 17 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.00041332506602125485, 'gamma': 4.63320740509258, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.5307411234454134, 'colsample_bytree': 0.605654214749744, 'lambda': 231.36464671703783, 'alpha': 265.2156983378573}
# [0]	training-rmse:0.52497	validation-rmse:0.06217
# [300]	training-rmse:0.51644	validation-rmse:0.05983
# [600]	training-rmse:0.50848	validation-rmse:0.05788
# [900]	training-rmse:0.50104	validation-rmse:0.05624
# [1200]	training-rmse:0.49416	validation-rmse:0.05483
# [1500]	training-rmse:0.48773	validation-rmse:0.05354
# [1800]	training-rmse:0.48178	validation-rmse:0.05246
# [2100]	training-rmse:0.47625	validation-rmse:0.05177
# [2400]	training-rmse:0.47108	validation-rmse:0.05132
# [2700]	training-rmse:0.46624	validation-rmse:0.05097
# [3000]	training-rmse:0.46178	validation-rmse:0.05066
# [3300]	training-rmse:0.45757	validation-rmse:0.05042
# [3600]	training-rmse:0.45353	validation-rmse:0.05021
# [3900]	training-rmse:0.44970	validation-rmse:0.04999
# [4200]	training-rmse:0.44606	validation-rmse:0.04976
# [4500]	training-rmse:0.44268	validation-rmse:0.04950
# [4800]	training-rmse:0.43941	validation-rmse:0.04927
# [5100]	training-rmse:0.43639	validation-rmse:0.04903
# [5400]	training-rmse:0.43345	validation-rmse:0.04880
# [5700]	training-rmse:0.43063	validation-rmse:0.04857
# [6000]	training-rmse:0.42800	validation-rmse:0.04834
# [6300]	training-rmse:0.42534	validation-rmse:0.04813
# [6600]	training-rmse:0.42284	validation-rmse:0.04791
# [6900]	training-rmse:0.42036	validation-rmse:0.04772
# [7200]	training-rmse:0.41792	validation-rmse:0.04753
# [7500]	training-rmse:0.41538	validation-rmse:0.04738
# [7518]	training-rmse:0.41522	validation-rmse:0.04737
# ----------------------------------------------------------
#
# TRIAL NUMBER 18 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.009665701217859417, 'gamma': 4.157468736130296, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.5102472454598441, 'colsample_bytree': 0.6824672617307759, 'lambda': 74.83176890588808, 'alpha': 187.02641897079508}
# [0]	training-rmse:0.52364	validation-rmse:0.06195
# [300]	training-rmse:0.36541	validation-rmse:0.04570
# [408]	training-rmse:0.33143	validation-rmse:0.04514
# ----------------------------------------------------------
#
# TRIAL NUMBER 19 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.013894457261341336, 'gamma': 3.3524204271524183, 'max_depth': 6, 'min_child_weight': 6, 'subsample': 0.6096813211064539, 'colsample_bytree': 0.6840656158795637, 'lambda': 464.059636038384, 'alpha': 208.94791396742824}
# [0]	training-rmse:0.52414	validation-rmse:0.06186
# [300]	training-rmse:0.39308	validation-rmse:0.04543
# [401]	training-rmse:0.36960	validation-rmse:0.04490
# ----------------------------------------------------------
#
# TRIAL NUMBER 20 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.007575257411175687, 'gamma': 3.572491522671254, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.6389533078984858, 'colsample_bytree': 0.570476075689339, 'lambda': 398.8507449233046, 'alpha': 41.60410814493044}
# [0]	training-rmse:0.52426	validation-rmse:0.06181
# [188]	training-rmse:0.42160	validation-rmse:0.05102
# ----------------------------------------------------------
#
# TRIAL NUMBER 21 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0004326843778069658, 'gamma': 4.248471147584494, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.568636302410444, 'colsample_bytree': 0.620554013618193, 'lambda': 544.0268037762216, 'alpha': 715.9996767727415}
# [0]	training-rmse:0.52500	validation-rmse:0.06218
# [50]	training-rmse:0.52500	validation-rmse:0.06218
# ----------------------------------------------------------
#
# TRIAL NUMBER 22 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.008241562589070708, 'gamma': 4.84491302110139, 'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6478755577829862, 'colsample_bytree': 0.5019367899313311, 'lambda': 921.6923714311622, 'alpha': 12.353419949089313}
# [0]	training-rmse:0.52449	validation-rmse:0.06195
# [241]	training-rmse:0.43080	validation-rmse:0.04477
# ----------------------------------------------------------
#
# TRIAL NUMBER 23 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.004301403312373353, 'gamma': 3.1989046005339787, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.5788926925086382, 'colsample_bytree': 0.5774565728461267, 'lambda': 63.884918458063005, 'alpha': 724.1562632440496}
# [0]	training-rmse:0.52500	validation-rmse:0.06218
# [50]	training-rmse:0.52500	validation-rmse:0.06218
# ----------------------------------------------------------
#
# TRIAL NUMBER 24 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.02422564675378369, 'gamma': 3.3604807877659573, 'max_depth': 8, 'min_child_weight': 8, 'subsample': 0.6767796770587966, 'colsample_bytree': 0.6161750130396251, 'lambda': 249.7750061269193, 'alpha': 31.810422226372225}
# [0]	training-rmse:0.52152	validation-rmse:0.06131
# [91]	training-rmse:0.32945	validation-rmse:0.05275
# ----------------------------------------------------------
#
# TRIAL NUMBER 25 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.013360941882640115, 'gamma': 4.125816505802732, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.5749269053797221, 'colsample_bytree': 0.6643632603731875, 'lambda': 646.7540712476363, 'alpha': 686.2421686971913}
# [0]	training-rmse:0.52500	validation-rmse:0.06218
# [50]	training-rmse:0.52500	validation-rmse:0.06218
# ----------------------------------------------------------
#
# TRIAL NUMBER 26 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0009097061929806888, 'gamma': 3.299359812628243, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.5659888108029437, 'colsample_bytree': 0.6843786547365793, 'lambda': 63.02543792562041, 'alpha': 22.700159823609948}
# [0]	training-rmse:0.52480	validation-rmse:0.06212
# [300]	training-rmse:0.47085	validation-rmse:0.05465
# [574]	training-rmse:0.43228	validation-rmse:0.05359
# ----------------------------------------------------------
#
# TRIAL NUMBER 27 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0004966803387414822, 'gamma': 3.2473775008047014, 'max_depth': 4, 'min_child_weight': 6, 'subsample': 0.5951316822869007, 'colsample_bytree': 0.6404578126347855, 'lambda': 16.01495005828387, 'alpha': 15.32337067923462}
# [0]	training-rmse:0.52486	validation-rmse:0.06216
# [300]	training-rmse:0.48166	validation-rmse:0.05689
# [442]	training-rmse:0.46340	validation-rmse:0.05680
# ----------------------------------------------------------
#
# TRIAL NUMBER 28 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.00891403138135497, 'gamma': 3.7422932695653692, 'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6758853436024661, 'colsample_bytree': 0.5069193066555343, 'lambda': 10.87452689089059, 'alpha': 43.194782308013224}
# [0]	training-rmse:0.52189	validation-rmse:0.06178
# [102]	training-rmse:0.31002	validation-rmse:0.05900
# ----------------------------------------------------------
#
# TRIAL NUMBER 29 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0017793305062331066, 'gamma': 4.993824587590662, 'max_depth': 9, 'min_child_weight': 6, 'subsample': 0.6283007054013308, 'colsample_bytree': 0.5307181407561168, 'lambda': 292.4948933436166, 'alpha': 37.565251107760616}
# [0]	training-rmse:0.52478	validation-rmse:0.06211
# [300]	training-rmse:0.46514	validation-rmse:0.05040
# [600]	training-rmse:0.41964	validation-rmse:0.04807
# [785]	training-rmse:0.39706	validation-rmse:0.04780
# ----------------------------------------------------------
#
# TRIAL NUMBER 30 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0017308750303993488, 'gamma': 3.0334634985430124, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.5618981917335472, 'colsample_bytree': 0.6125854193436543, 'lambda': 15.200758200719811, 'alpha': 384.77173570346264}
# [0]	training-rmse:0.52481	validation-rmse:0.06215
# [300]	training-rmse:0.48178	validation-rmse:0.05570
# [600]	training-rmse:0.45756	validation-rmse:0.05255
# [900]	training-rmse:0.43968	validation-rmse:0.05090
# [1200]	training-rmse:0.41865	validation-rmse:0.04967
# [1333]	training-rmse:0.41089	validation-rmse:0.04961
#
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# NOW PREDICTING OXYGEN_CONC_TARGET_T_96
# ----------------------------------------------------------
#
# TRIAL NUMBER 1 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.026304775926427458, 'gamma': 4.399024099899152, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.5440134599565704, 'colsample_bytree': 0.5722112707928115, 'lambda': 301.7741118446677, 'alpha': 983.8104927455976}
# [0]	training-rmse:2.09582	validation-rmse:2.21117
# [300]	training-rmse:0.80594	validation-rmse:1.01252
# [476]	training-rmse:0.80215	validation-rmse:1.00971
# ----------------------------------------------------------
#
# TRIAL NUMBER 2 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.001357356589364695, 'gamma': 3.273089159647049, 'max_depth': 4, 'min_child_weight': 6, 'subsample': 0.573282950616703, 'colsample_bytree': 0.6419303125176254, 'lambda': 631.3713357594794, 'alpha': 117.01212822443404}
# [0]	training-rmse:2.12636	validation-rmse:2.23710
# [300]	training-rmse:1.69721	validation-rmse:1.86145
# [600]	training-rmse:1.40388	validation-rmse:1.62324
# [900]	training-rmse:1.19834	validation-rmse:1.43021
# [1200]	training-rmse:1.05022	validation-rmse:1.28635
# [1500]	training-rmse:0.94303	validation-rmse:1.18668
# [1800]	training-rmse:0.86177	validation-rmse:1.13817
# [2100]	training-rmse:0.79699	validation-rmse:1.11613
# [2400]	training-rmse:0.74544	validation-rmse:1.09726
# [2700]	training-rmse:0.70407	validation-rmse:1.08399
# [3000]	training-rmse:0.67037	validation-rmse:1.07735
# [3153]	training-rmse:0.65531	validation-rmse:1.07671
# ----------------------------------------------------------
#
# TRIAL NUMBER 3 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.000987614664347347, 'gamma': 4.3436131251541505, 'max_depth': 4, 'min_child_weight': 8, 'subsample': 0.6085119753419019, 'colsample_bytree': 0.6786895207389801, 'lambda': 484.79607956253017, 'alpha': 40.92843888846576}
# [0]	training-rmse:2.12674	validation-rmse:2.23743
# [300]	training-rmse:1.77524	validation-rmse:1.93688
# [600]	training-rmse:1.51041	validation-rmse:1.71854
# [900]	training-rmse:1.30811	validation-rmse:1.51967
# [1200]	training-rmse:1.15323	validation-rmse:1.37663
# [1500]	training-rmse:1.03317	validation-rmse:1.25987
# [1800]	training-rmse:0.93815	validation-rmse:1.18541
# [2100]	training-rmse:0.86093	validation-rmse:1.13855
# [2400]	training-rmse:0.79736	validation-rmse:1.10692
# [2700]	training-rmse:0.74472	validation-rmse:1.08744
# [3000]	training-rmse:0.70180	validation-rmse:1.07087
# [3300]	training-rmse:0.66666	validation-rmse:1.05789
# [3600]	training-rmse:0.63726	validation-rmse:1.04919
# [3900]	training-rmse:0.61233	validation-rmse:1.04553
# [4062]	training-rmse:0.60037	validation-rmse:1.04487
# ----------------------------------------------------------
#
# TRIAL NUMBER 4 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.005785482108959772, 'gamma': 4.360477720892311, 'max_depth': 3, 'min_child_weight': 6, 'subsample': 0.6787134303841522, 'colsample_bytree': 0.6884851722721561, 'lambda': 192.5089664883095, 'alpha': 169.5490136762781}
# [0]	training-rmse:2.11930	validation-rmse:2.23321
# [300]	training-rmse:0.87249	validation-rmse:1.12882
# [501]	training-rmse:0.67063	validation-rmse:1.08337
# ----------------------------------------------------------
#
# TRIAL NUMBER 5 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0009023323105762767, 'gamma': 3.9720637379327455, 'max_depth': 8, 'min_child_weight': 8, 'subsample': 0.6688440307044725, 'colsample_bytree': 0.6069361732459915, 'lambda': 327.7903014835408, 'alpha': 99.85131120336136}
# [0]	training-rmse:2.12677	validation-rmse:2.23747
# [300]	training-rmse:1.78084	validation-rmse:1.96061
# [600]	training-rmse:1.51500	validation-rmse:1.73292
# [900]	training-rmse:1.30858	validation-rmse:1.55195
# [1200]	training-rmse:1.14852	validation-rmse:1.41934
# [1500]	training-rmse:1.02223	validation-rmse:1.33819
# [1800]	training-rmse:0.92049	validation-rmse:1.28923
# [2100]	training-rmse:0.83775	validation-rmse:1.25156
# [2400]	training-rmse:0.76899	validation-rmse:1.21873
# [2700]	training-rmse:0.71197	validation-rmse:1.19680
# [3000]	training-rmse:0.66454	validation-rmse:1.18187
# [3300]	training-rmse:0.62466	validation-rmse:1.17313
# [3600]	training-rmse:0.59131	validation-rmse:1.16653
# [3900]	training-rmse:0.56337	validation-rmse:1.15993
# [4200]	training-rmse:0.54019	validation-rmse:1.15710
# [4500]	training-rmse:0.52035	validation-rmse:1.15452
# [4800]	training-rmse:0.50348	validation-rmse:1.15187
# [5100]	training-rmse:0.48875	validation-rmse:1.14960
# [5209]	training-rmse:0.48389	validation-rmse:1.14958
# ----------------------------------------------------------
#
# TRIAL NUMBER 6 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.01587288220096692, 'gamma': 4.239393550712144, 'max_depth': 8, 'min_child_weight': 4, 'subsample': 0.5463394393298, 'colsample_bytree': 0.5804436829161542, 'lambda': 177.3168976808123, 'alpha': 19.322949184435128}
# [0]	training-rmse:2.10340	validation-rmse:2.22468
# [270]	training-rmse:0.43036	validation-rmse:1.11416
# ----------------------------------------------------------
#
# TRIAL NUMBER 7 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0005566689107452353, 'gamma': 3.8336598215250044, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.6882838350878844, 'colsample_bytree': 0.5818518045006461, 'lambda': 297.51091166418536, 'alpha': 979.2675166489886}
# [0]	training-rmse:2.12736	validation-rmse:2.23770
# [300]	training-rmse:1.92807	validation-rmse:2.02474
# [600]	training-rmse:1.76125	validation-rmse:1.85420
# [900]	training-rmse:1.62141	validation-rmse:1.71942
# [1200]	training-rmse:1.50394	validation-rmse:1.61013
# [1500]	training-rmse:1.40507	validation-rmse:1.51763
# [1800]	training-rmse:1.32129	validation-rmse:1.44371
# [2100]	training-rmse:1.24972	validation-rmse:1.37360
# [2400]	training-rmse:1.18846	validation-rmse:1.31438
# [2700]	training-rmse:1.13607	validation-rmse:1.26230
# [3000]	training-rmse:1.09105	validation-rmse:1.21591
# [3300]	training-rmse:1.05200	validation-rmse:1.17458
# [3600]	training-rmse:1.01838	validation-rmse:1.13757
# [3900]	training-rmse:0.98895	validation-rmse:1.10543
# [4200]	training-rmse:0.96345	validation-rmse:1.07900
# [4500]	training-rmse:0.94128	validation-rmse:1.05696
# [4800]	training-rmse:0.92172	validation-rmse:1.03803
# [5100]	training-rmse:0.90476	validation-rmse:1.02284
# [5400]	training-rmse:0.89008	validation-rmse:1.00971
# [5700]	training-rmse:0.87708	validation-rmse:0.99875
# [6000]	training-rmse:0.86558	validation-rmse:0.98974
# [6300]	training-rmse:0.85519	validation-rmse:0.98230
# [6600]	training-rmse:0.84598	validation-rmse:0.97533
# [6900]	training-rmse:0.83765	validation-rmse:0.96973
# [7200]	training-rmse:0.83028	validation-rmse:0.96485
# [7500]	training-rmse:0.82355	validation-rmse:0.96082
# [7800]	training-rmse:0.81761	validation-rmse:0.95718
# [8100]	training-rmse:0.81213	validation-rmse:0.95427
# [8400]	training-rmse:0.80709	validation-rmse:0.95174
# [8700]	training-rmse:0.80246	validation-rmse:0.94950
# [9000]	training-rmse:0.79815	validation-rmse:0.94780
# [9300]	training-rmse:0.79420	validation-rmse:0.94629
# [9600]	training-rmse:0.79059	validation-rmse:0.94503
# [9900]	training-rmse:0.78726	validation-rmse:0.94406
# [9999]	training-rmse:0.78627	validation-rmse:0.94373
# ----------------------------------------------------------
#
# TRIAL NUMBER 8 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.02154411697428862, 'gamma': 3.0040465451881166, 'max_depth': 9, 'min_child_weight': 4, 'subsample': 0.6778096353397447, 'colsample_bytree': 0.6398977212474379, 'lambda': 15.669290676232025, 'alpha': 140.23553569724845}
# [0]	training-rmse:2.09024	validation-rmse:2.22190
# [300]	training-rmse:0.39529	validation-rmse:1.09410
# [569]	training-rmse:0.39084	validation-rmse:1.09207
# ----------------------------------------------------------
#
# TRIAL NUMBER 9 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.013806202297330629, 'gamma': 4.121782101291188, 'max_depth': 8, 'min_child_weight': 6, 'subsample': 0.608699951218771, 'colsample_bytree': 0.6759178183424241, 'lambda': 16.911928339597402, 'alpha': 11.557864825479399}
# [0]	training-rmse:2.10203	validation-rmse:2.21448
# [300]	training-rmse:0.31633	validation-rmse:1.05738
# [312]	training-rmse:0.31222	validation-rmse:1.05989
# ----------------------------------------------------------
#
# TRIAL NUMBER 10 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.02544603503208933, 'gamma': 3.5774869487201437, 'max_depth': 3, 'min_child_weight': 8, 'subsample': 0.6193782887454218, 'colsample_bytree': 0.6310572091954619, 'lambda': 35.59515769389978, 'alpha': 519.9300465674321}
# [0]	training-rmse:2.08960	validation-rmse:2.19713
# [300]	training-rmse:0.63188	validation-rmse:0.98660
# [303]	training-rmse:0.63072	validation-rmse:0.98627
# ----------------------------------------------------------
#
# TRIAL NUMBER 11 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.018942979652414954, 'gamma': 3.5701211821306353, 'max_depth': 7, 'min_child_weight': 8, 'subsample': 0.6778658497027522, 'colsample_bytree': 0.5365654852757945, 'lambda': 42.67267232310354, 'alpha': 14.064992246256807}
# [0]	training-rmse:2.09383	validation-rmse:2.21071
# [209]	training-rmse:0.34079	validation-rmse:1.13419
# ----------------------------------------------------------
#
# TRIAL NUMBER 12 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0014120455317728669, 'gamma': 4.869921674487493, 'max_depth': 7, 'min_child_weight': 6, 'subsample': 0.5167090045891891, 'colsample_bytree': 0.5390019038790702, 'lambda': 36.55132350725101, 'alpha': 23.218271417109722}
# [0]	training-rmse:2.12559	validation-rmse:2.23632
# [300]	training-rmse:1.51024	validation-rmse:1.77127
# [600]	training-rmse:1.10739	validation-rmse:1.45864
# [900]	training-rmse:0.84668	validation-rmse:1.26782
# [1200]	training-rmse:0.67791	validation-rmse:1.17398
# [1500]	training-rmse:0.56805	validation-rmse:1.12246
# [1800]	training-rmse:0.49615	validation-rmse:1.09719
# [2100]	training-rmse:0.44804	validation-rmse:1.08397
# [2242]	training-rmse:0.43042	validation-rmse:1.08221
# ----------------------------------------------------------
#
# TRIAL NUMBER 13 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.019352667757515353, 'gamma': 4.339948403826172, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.5881994360395475, 'colsample_bytree': 0.6531102853377269, 'lambda': 10.604423594508907, 'alpha': 229.78725033401707}
# [0]	training-rmse:2.09604	validation-rmse:2.22011
# [300]	training-rmse:0.48339	validation-rmse:1.12184
# [476]	training-rmse:0.47475	validation-rmse:1.11634
# ----------------------------------------------------------
#
# TRIAL NUMBER 14 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0011251366715034938, 'gamma': 4.207959642515683, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.5419579621101566, 'colsample_bytree': 0.5272245507360163, 'lambda': 345.40230218081496, 'alpha': 88.95461926038584}
# [0]	training-rmse:2.12652	validation-rmse:2.23755
# [300]	training-rmse:1.72412	validation-rmse:1.90263
# [600]	training-rmse:1.43311	validation-rmse:1.66104
# [900]	training-rmse:1.21916	validation-rmse:1.46638
# [1200]	training-rmse:1.06187	validation-rmse:1.33303
# [1500]	training-rmse:0.94232	validation-rmse:1.25524
# [1800]	training-rmse:0.84915	validation-rmse:1.20855
# [2100]	training-rmse:0.77428	validation-rmse:1.17417
# [2400]	training-rmse:0.71415	validation-rmse:1.15340
# [2700]	training-rmse:0.66566	validation-rmse:1.13884
# [3000]	training-rmse:0.62666	validation-rmse:1.12822
# [3300]	training-rmse:0.59525	validation-rmse:1.12067
# [3600]	training-rmse:0.56932	validation-rmse:1.11618
# [3632]	training-rmse:0.56680	validation-rmse:1.11610
# ----------------------------------------------------------
#
# TRIAL NUMBER 15 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0034532366179095705, 'gamma': 4.888386091598631, 'max_depth': 8, 'min_child_weight': 4, 'subsample': 0.5876500745473832, 'colsample_bytree': 0.5927575415211481, 'lambda': 31.453060308002954, 'alpha': 32.62261261598607}
# [0]	training-rmse:2.12186	validation-rmse:2.23588
# [300]	training-rmse:0.96411	validation-rmse:1.36557
# [600]	training-rmse:0.56593	validation-rmse:1.14463
# [900]	training-rmse:0.42654	validation-rmse:1.10091
# [983]	training-rmse:0.40559	validation-rmse:1.09943
# ----------------------------------------------------------
#
# TRIAL NUMBER 16 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0003515508314559019, 'gamma': 4.864810174037409, 'max_depth': 3, 'min_child_weight': 6, 'subsample': 0.5713479051519654, 'colsample_bytree': 0.5220880796450866, 'lambda': 78.90715792894737, 'alpha': 86.6657845622521}
# [0]	training-rmse:2.12753	validation-rmse:2.23784
# [300]	training-rmse:1.96446	validation-rmse:2.10737
# [600]	training-rmse:1.81844	validation-rmse:1.97655
# [900]	training-rmse:1.68735	validation-rmse:1.85399
# [1200]	training-rmse:1.56929	validation-rmse:1.73775
# [1500]	training-rmse:1.46269	validation-rmse:1.63478
# [1800]	training-rmse:1.36668	validation-rmse:1.54545
# [2100]	training-rmse:1.28029	validation-rmse:1.47013
# [2400]	training-rmse:1.20288	validation-rmse:1.40548
# [2700]	training-rmse:1.13355	validation-rmse:1.34728
# [3000]	training-rmse:1.07163	validation-rmse:1.29540
# [3300]	training-rmse:1.01616	validation-rmse:1.24958
# [3600]	training-rmse:0.96640	validation-rmse:1.21084
# [3900]	training-rmse:0.92185	validation-rmse:1.17662
# [4200]	training-rmse:0.88186	validation-rmse:1.14724
# [4500]	training-rmse:0.84618	validation-rmse:1.11993
# [4800]	training-rmse:0.81429	validation-rmse:1.09662
# [5100]	training-rmse:0.78574	validation-rmse:1.07706
# [5400]	training-rmse:0.76037	validation-rmse:1.06172
# [5700]	training-rmse:0.73768	validation-rmse:1.04970
# [6000]	training-rmse:0.71747	validation-rmse:1.04122
# [6300]	training-rmse:0.69923	validation-rmse:1.03510
# [6600]	training-rmse:0.68286	validation-rmse:1.03068
# [6900]	training-rmse:0.66801	validation-rmse:1.02698
# [7200]	training-rmse:0.65481	validation-rmse:1.02321
# [7500]	training-rmse:0.64284	validation-rmse:1.02073
# [7800]	training-rmse:0.63211	validation-rmse:1.01808
# [7890]	training-rmse:0.62907	validation-rmse:1.01782
# ----------------------------------------------------------
#
# TRIAL NUMBER 17 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.00041332506602125485, 'gamma': 4.63320740509258, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.5307411234454134, 'colsample_bytree': 0.605654214749744, 'lambda': 231.36464671703783, 'alpha': 265.2156983378573}
# [0]	training-rmse:2.12751	validation-rmse:2.23788
# [300]	training-rmse:1.96318	validation-rmse:2.06566
# [600]	training-rmse:1.81891	validation-rmse:1.92877
# [900]	training-rmse:1.69167	validation-rmse:1.81596
# [1200]	training-rmse:1.57879	validation-rmse:1.72205
# [1500]	training-rmse:1.47822	validation-rmse:1.63827
# [1800]	training-rmse:1.38870	validation-rmse:1.56357
# [2100]	training-rmse:1.30945	validation-rmse:1.49266
# [2400]	training-rmse:1.23943	validation-rmse:1.43249
# [2700]	training-rmse:1.17758	validation-rmse:1.37647
# [3000]	training-rmse:1.12286	validation-rmse:1.32399
# [3300]	training-rmse:1.07439	validation-rmse:1.27748
# [3600]	training-rmse:1.03143	validation-rmse:1.23772
# [3900]	training-rmse:0.99344	validation-rmse:1.20228
# [4200]	training-rmse:0.95971	validation-rmse:1.17245
# [4500]	training-rmse:0.92965	validation-rmse:1.14682
# [4800]	training-rmse:0.90250	validation-rmse:1.12848
# [5100]	training-rmse:0.87791	validation-rmse:1.11417
# [5400]	training-rmse:0.85563	validation-rmse:1.10303
# [5700]	training-rmse:0.83504	validation-rmse:1.09652
# [6000]	training-rmse:0.81632	validation-rmse:1.09108
# [6300]	training-rmse:0.79883	validation-rmse:1.08840
# [6600]	training-rmse:0.78282	validation-rmse:1.08553
# [6806]	training-rmse:0.77235	validation-rmse:1.08380
# ----------------------------------------------------------
#
# TRIAL NUMBER 18 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.009665701217859417, 'gamma': 4.157468736130296, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.5102472454598441, 'colsample_bytree': 0.6824672617307759, 'lambda': 74.83176890588808, 'alpha': 187.02641897079508}
# [0]	training-rmse:2.11298	validation-rmse:2.22939
# [300]	training-rmse:0.66489	validation-rmse:1.08198
# [600]	training-rmse:0.55229	validation-rmse:1.05970
# [663]	training-rmse:0.54323	validation-rmse:1.05950
# ----------------------------------------------------------
#
# TRIAL NUMBER 19 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.013894457261341336, 'gamma': 3.3524204271524183, 'max_depth': 6, 'min_child_weight': 6, 'subsample': 0.6096813211064539, 'colsample_bytree': 0.6840656158795637, 'lambda': 464.059636038384, 'alpha': 208.94791396742824}
# [0]	training-rmse:2.10938	validation-rmse:2.22339
# [300]	training-rmse:0.61902	validation-rmse:1.19583
# [360]	training-rmse:0.57057	validation-rmse:1.19351
# ----------------------------------------------------------
#
# TRIAL NUMBER 20 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.007575257411175687, 'gamma': 3.572491522671254, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.6389533078984858, 'colsample_bytree': 0.570476075689339, 'lambda': 398.8507449233046, 'alpha': 41.60410814493044}
# [0]	training-rmse:2.11738	validation-rmse:2.22660
# [300]	training-rmse:0.80272	validation-rmse:1.05273
# [449]	training-rmse:0.65672	validation-rmse:1.04016
# ----------------------------------------------------------
#
# TRIAL NUMBER 21 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0004326843778069658, 'gamma': 4.248471147584494, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.568636302410444, 'colsample_bytree': 0.620554013618193, 'lambda': 544.0268037762216, 'alpha': 715.9996767727415}
# [0]	training-rmse:2.12758	validation-rmse:2.23790
# [300]	training-rmse:1.98264	validation-rmse:2.07082
# [600]	training-rmse:1.85494	validation-rmse:1.93427
# [900]	training-rmse:1.74256	validation-rmse:1.81673
# [1200]	training-rmse:1.64366	validation-rmse:1.72026
# [1500]	training-rmse:1.55654	validation-rmse:1.63754
# [1800]	training-rmse:1.47966	validation-rmse:1.56332
# [2100]	training-rmse:1.41160	validation-rmse:1.49990
# [2400]	training-rmse:1.35159	validation-rmse:1.44596
# [2700]	training-rmse:1.29823	validation-rmse:1.38922
# [3000]	training-rmse:1.25053	validation-rmse:1.33747
# [3300]	training-rmse:1.20783	validation-rmse:1.29462
# [3600]	training-rmse:1.16901	validation-rmse:1.25528
# [3900]	training-rmse:1.13348	validation-rmse:1.22079
# [4200]	training-rmse:1.10135	validation-rmse:1.18698
# [4500]	training-rmse:1.07246	validation-rmse:1.15666
# [4800]	training-rmse:1.04620	validation-rmse:1.12925
# [5100]	training-rmse:1.02227	validation-rmse:1.10419
# [5400]	training-rmse:1.00075	validation-rmse:1.08310
# [5700]	training-rmse:0.98088	validation-rmse:1.06332
# [6000]	training-rmse:0.96310	validation-rmse:1.04708
# [6300]	training-rmse:0.94661	validation-rmse:1.03312
# [6600]	training-rmse:0.93170	validation-rmse:1.02043
# [6900]	training-rmse:0.91787	validation-rmse:1.00932
# [7200]	training-rmse:0.90532	validation-rmse:0.99952
# [7500]	training-rmse:0.89369	validation-rmse:0.99135
# [7800]	training-rmse:0.88318	validation-rmse:0.98411
# [8100]	training-rmse:0.87347	validation-rmse:0.97778
# [8400]	training-rmse:0.86445	validation-rmse:0.97193
# [8700]	training-rmse:0.85620	validation-rmse:0.96696
# [9000]	training-rmse:0.84853	validation-rmse:0.96223
# [9300]	training-rmse:0.84138	validation-rmse:0.95799
# [9600]	training-rmse:0.83470	validation-rmse:0.95432
# [9900]	training-rmse:0.82853	validation-rmse:0.95093
# [9999]	training-rmse:0.82660	validation-rmse:0.94984
# ----------------------------------------------------------
#
# TRIAL NUMBER 22 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.008241562589070708, 'gamma': 4.84491302110139, 'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6478755577829862, 'colsample_bytree': 0.5019367899313311, 'lambda': 921.6923714311622, 'alpha': 12.353419949089313}
# [0]	training-rmse:2.11796	validation-rmse:2.23018
# [300]	training-rmse:0.86248	validation-rmse:1.14522
# [600]	training-rmse:0.58652	validation-rmse:1.08729
# [639]	training-rmse:0.56674	validation-rmse:1.08995
# ----------------------------------------------------------
#
# TRIAL NUMBER 23 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.004301403312373353, 'gamma': 3.1989046005339787, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.5788926925086382, 'colsample_bytree': 0.5774565728461267, 'lambda': 63.884918458063005, 'alpha': 724.1562632440496}
# [0]	training-rmse:2.12186	validation-rmse:2.23368
# [300]	training-rmse:1.12613	validation-rmse:1.42414
# [600]	training-rmse:0.86455	validation-rmse:1.16473
# [900]	training-rmse:0.77993	validation-rmse:1.09602
# [1200]	training-rmse:0.74089	validation-rmse:1.07482
# [1500]	training-rmse:0.72031	validation-rmse:1.06671
# [1800]	training-rmse:0.71314	validation-rmse:1.06487
# [2100]	training-rmse:0.70993	validation-rmse:1.06370
# [2303]	training-rmse:0.70828	validation-rmse:1.06335
# ----------------------------------------------------------
#
# TRIAL NUMBER 24 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.02422564675378369, 'gamma': 3.3604807877659573, 'max_depth': 8, 'min_child_weight': 8, 'subsample': 0.6767796770587966, 'colsample_bytree': 0.6161750130396251, 'lambda': 249.7750061269193, 'alpha': 31.810422226372225}
# [0]	training-rmse:2.09099	validation-rmse:2.21724
# [237]	training-rmse:0.38432	validation-rmse:1.15559
# ----------------------------------------------------------
#
# TRIAL NUMBER 25 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.013360941882640115, 'gamma': 4.125816505802732, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.5749269053797221, 'colsample_bytree': 0.6643632603731875, 'lambda': 646.7540712476363, 'alpha': 686.2421686971913}
# [0]	training-rmse:2.11241	validation-rmse:2.22524
# [300]	training-rmse:0.82748	validation-rmse:1.08165
# [600]	training-rmse:0.71667	validation-rmse:1.04094
# [729]	training-rmse:0.70363	validation-rmse:1.04051
# ----------------------------------------------------------
#
# TRIAL NUMBER 26 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0009097061929806888, 'gamma': 3.299359812628243, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.5659888108029437, 'colsample_bytree': 0.6843786547365793, 'lambda': 63.02543792562041, 'alpha': 22.700159823609948}
# [0]	training-rmse:2.12657	validation-rmse:2.23703
# [300]	training-rmse:1.72307	validation-rmse:1.81844
# [600]	training-rmse:1.41660	validation-rmse:1.51091
# [900]	training-rmse:1.18481	validation-rmse:1.29753
# [1200]	training-rmse:1.01180	validation-rmse:1.15213
# [1500]	training-rmse:0.88403	validation-rmse:1.05174
# [1800]	training-rmse:0.79049	validation-rmse:0.98362
# [2100]	training-rmse:0.72165	validation-rmse:0.93878
# [2400]	training-rmse:0.67044	validation-rmse:0.91803
# [2700]	training-rmse:0.63210	validation-rmse:0.90855
# [2914]	training-rmse:0.61038	validation-rmse:0.90646
# ----------------------------------------------------------
#
# TRIAL NUMBER 27 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0004966803387414822, 'gamma': 3.2473775008047014, 'max_depth': 4, 'min_child_weight': 6, 'subsample': 0.5951316822869007, 'colsample_bytree': 0.6404578126347855, 'lambda': 16.01495005828387, 'alpha': 15.32337067923462}
# [0]	training-rmse:2.12717	validation-rmse:2.23762
# [300]	training-rmse:1.87121	validation-rmse:2.06297
# [600]	training-rmse:1.65179	validation-rmse:1.89178
# [900]	training-rmse:1.46418	validation-rmse:1.73789
# [1200]	training-rmse:1.30399	validation-rmse:1.60610
# [1500]	training-rmse:1.16745	validation-rmse:1.48996
# [1800]	training-rmse:1.05130	validation-rmse:1.39302
# [2100]	training-rmse:0.95283	validation-rmse:1.31203
# [2400]	training-rmse:0.86987	validation-rmse:1.24510
# [2700]	training-rmse:0.80050	validation-rmse:1.19002
# [3000]	training-rmse:0.74264	validation-rmse:1.14594
# [3300]	training-rmse:0.69404	validation-rmse:1.11205
# [3600]	training-rmse:0.65330	validation-rmse:1.08498
# [3900]	training-rmse:0.61904	validation-rmse:1.06257
# [4200]	training-rmse:0.59036	validation-rmse:1.04481
# [4500]	training-rmse:0.56610	validation-rmse:1.02992
# [4800]	training-rmse:0.54525	validation-rmse:1.01918
# [5100]	training-rmse:0.52681	validation-rmse:1.01320
# [5400]	training-rmse:0.51058	validation-rmse:1.00954
# [5605]	training-rmse:0.50055	validation-rmse:1.00880
# ----------------------------------------------------------
#
# TRIAL NUMBER 28 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.00891403138135497, 'gamma': 3.7422932695653692, 'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6758853436024661, 'colsample_bytree': 0.5069193066555343, 'lambda': 10.87452689089059, 'alpha': 43.194782308013224}
# [0]	training-rmse:2.11140	validation-rmse:2.22542
# [300]	training-rmse:0.45433	validation-rmse:1.15947
# [425]	training-rmse:0.37728	validation-rmse:1.14284
# ----------------------------------------------------------
#
# TRIAL NUMBER 29 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0017793305062331066, 'gamma': 4.993824587590662, 'max_depth': 9, 'min_child_weight': 6, 'subsample': 0.6283007054013308, 'colsample_bytree': 0.5307181407561168, 'lambda': 292.4948933436166, 'alpha': 37.565251107760616}
# [0]	training-rmse:2.12546	validation-rmse:2.23679
# [300]	training-rmse:1.50892	validation-rmse:1.71453
# [600]	training-rmse:1.13611	validation-rmse:1.39073
# [900]	training-rmse:0.90048	validation-rmse:1.24315
# [1200]	training-rmse:0.74465	validation-rmse:1.17166
# [1500]	training-rmse:0.63859	validation-rmse:1.13592
# ...
# [1500]	training-rmse:2.73527	validation-rmse:3.31667
# [1800]	training-rmse:2.51068	validation-rmse:3.08105
# [2100]	training-rmse:2.31371	validation-rmse:2.87405
# [2400]	training-rmse:2.14138	validation-rmse:2.68917
# [2700]	training-rmse:1.99084	validation-rmse:2.52654
# [3000]	training-rmse:1.85960	validation-rmse:2.38406
# [3300]	training-rmse:1.74524	validation-rmse:2.25651
# [3600]	training-rmse:1.64559	validation-rmse:2.14331
# [3900]	training-rmse:1.55848	validation-rmse:2.04095
# [4200]	training-rmse:1.48268	validation-rmse:1.95086
# [4500]	training-rmse:1.41686	validation-rmse:1.87180
# [4800]	training-rmse:1.35933	validation-rmse:1.80057
# [5100]	training-rmse:1.30926	validation-rmse:1.73752
# [5400]	training-rmse:1.26549	validation-rmse:1.68295
# [5700]	training-rmse:1.22728	validation-rmse:1.63651
# [6000]	training-rmse:1.19395	validation-rmse:1.59521
# [6300]	training-rmse:1.16469	validation-rmse:1.55967
# [6600]	training-rmse:1.13892	validation-rmse:1.52935
# [6900]	training-rmse:1.11614	validation-rmse:1.50381
# [7200]	training-rmse:1.09600	validation-rmse:1.48175
# [7500]	training-rmse:1.07832	validation-rmse:1.46358
# [7800]	training-rmse:1.06256	validation-rmse:1.44765
# [8100]	training-rmse:1.04869	validation-rmse:1.43427
# [8400]	training-rmse:1.03625	validation-rmse:1.42270
# [8700]	training-rmse:1.02503	validation-rmse:1.41257
# [9000]	training-rmse:1.01495	validation-rmse:1.40398
# [9300]	training-rmse:1.00574	validation-rmse:1.39633
# [9600]	training-rmse:0.99730	validation-rmse:1.39000
# [9900]	training-rmse:0.98967	validation-rmse:1.38439
# [9999]	training-rmse:0.98725	validation-rmse:1.38259
# ----------------------------------------------------------
#
# TRIAL NUMBER 18 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.009665701217859417, 'gamma': 4.157468736130296, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.5102472454598441, 'colsample_bytree': 0.6824672617307759, 'lambda': 74.83176890588808, 'alpha': 187.02641897079508}
# [0]	training-rmse:4.37764	validation-rmse:5.14143
# [300]	training-rmse:1.04463	validation-rmse:1.47183
# [600]	training-rmse:0.89132	validation-rmse:1.34617
# [900]	training-rmse:0.84340	validation-rmse:1.33768
# [911]	training-rmse:0.84228	validation-rmse:1.33729
# ----------------------------------------------------------
#
# TRIAL NUMBER 19 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.013894457261341336, 'gamma': 3.3524204271524183, 'max_depth': 6, 'min_child_weight': 6, 'subsample': 0.6096813211064539, 'colsample_bytree': 0.6840656158795637, 'lambda': 464.059636038384, 'alpha': 208.94791396742824}
# [0]	training-rmse:4.36586	validation-rmse:5.12913
# [300]	training-rmse:0.90021	validation-rmse:1.61740
# [600]	training-rmse:0.72200	validation-rmse:1.55249
# [808]	training-rmse:0.68360	validation-rmse:1.54291
# ----------------------------------------------------------
#
# TRIAL NUMBER 20 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.007575257411175687, 'gamma': 3.572491522671254, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.6389533078984858, 'colsample_bytree': 0.570476075689339, 'lambda': 398.8507449233046, 'alpha': 41.60410814493044}
# [0]	training-rmse:4.38736	validation-rmse:5.15240
# [300]	training-rmse:1.22927	validation-rmse:1.61089
# [600]	training-rmse:0.93408	validation-rmse:1.34001
# [900]	training-rmse:0.86559	validation-rmse:1.30878
# [1023]	training-rmse:0.84473	validation-rmse:1.30738
# ----------------------------------------------------------
#
# TRIAL NUMBER 21 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0004326843778069658, 'gamma': 4.248471147584494, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.568636302410444, 'colsample_bytree': 0.620554013618193, 'lambda': 544.0268037762216, 'alpha': 715.9996767727415}
# [0]	training-rmse:4.41334	validation-rmse:5.18120
# [300]	training-rmse:4.00836	validation-rmse:4.75018
# [600]	training-rmse:3.65047	validation-rmse:4.36111
# [900]	training-rmse:3.33392	validation-rmse:4.01333
# [1200]	training-rmse:3.05516	validation-rmse:3.70716
# [1500]	training-rmse:2.80917	validation-rmse:3.43604
# [1800]	training-rmse:2.59271	validation-rmse:3.19503
# [2100]	training-rmse:2.40254	validation-rmse:2.98645
# [2400]	training-rmse:2.23570	validation-rmse:2.80358
# [2700]	training-rmse:2.08954	validation-rmse:2.64450
# [3000]	training-rmse:1.96168	validation-rmse:2.50750
# [3300]	training-rmse:1.84981	validation-rmse:2.38650
# [3600]	training-rmse:1.75195	validation-rmse:2.27870
# [3900]	training-rmse:1.66657	validation-rmse:2.18280
# [4200]	training-rmse:1.59199	validation-rmse:2.09662
# [4500]	training-rmse:1.52731	validation-rmse:2.02198
# [4800]	training-rmse:1.47126	validation-rmse:1.95494
# [5100]	training-rmse:1.42249	validation-rmse:1.89523
# [5400]	training-rmse:1.37973	validation-rmse:1.84216
# [5700]	training-rmse:1.34226	validation-rmse:1.79557
# [6000]	training-rmse:1.30919	validation-rmse:1.75595
# [6300]	training-rmse:1.28008	validation-rmse:1.72249
# [6600]	training-rmse:1.25421	validation-rmse:1.69127
# [6900]	training-rmse:1.23091	validation-rmse:1.66266
# [7200]	training-rmse:1.21006	validation-rmse:1.63533
# [7500]	training-rmse:1.19140	validation-rmse:1.61041
# [7800]	training-rmse:1.17452	validation-rmse:1.58717
# [8100]	training-rmse:1.15941	validation-rmse:1.56668
# [8400]	training-rmse:1.14545	validation-rmse:1.54735
# [8700]	training-rmse:1.13270	validation-rmse:1.53028
# [9000]	training-rmse:1.12102	validation-rmse:1.51509
# [9300]	training-rmse:1.11025	validation-rmse:1.50113
# [9600]	training-rmse:1.10038	validation-rmse:1.48931
# [9900]	training-rmse:1.09121	validation-rmse:1.47839
# [9999]	training-rmse:1.08840	validation-rmse:1.47529
# ----------------------------------------------------------
#
# TRIAL NUMBER 22 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.008241562589070708, 'gamma': 4.84491302110139, 'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6478755577829862, 'colsample_bytree': 0.5019367899313311, 'lambda': 921.6923714311622, 'alpha': 12.353419949089313}
# [0]	training-rmse:4.38762	validation-rmse:5.15494
# [300]	training-rmse:1.23266	validation-rmse:1.78125
# [600]	training-rmse:0.81990	validation-rmse:1.54021
# [900]	training-rmse:0.67060	validation-rmse:1.51585
# [1133]	training-rmse:0.60609	validation-rmse:1.51048
# ----------------------------------------------------------
#
# TRIAL NUMBER 23 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.004301403312373353, 'gamma': 3.1989046005339787, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.5788926925086382, 'colsample_bytree': 0.5774565728461267, 'lambda': 63.884918458063005, 'alpha': 724.1562632440496}
# [0]	training-rmse:4.39868	validation-rmse:5.16478
# [300]	training-rmse:1.80675	validation-rmse:2.35130
# [600]	training-rmse:1.19121	validation-rmse:1.69224
# [900]	training-rmse:1.03132	validation-rmse:1.52433
# [1200]	training-rmse:0.97241	validation-rmse:1.47530
# [1500]	training-rmse:0.94416	validation-rmse:1.45730
# [1800]	training-rmse:0.93526	validation-rmse:1.45118
# [2100]	training-rmse:0.93285	validation-rmse:1.44944
# [2400]	training-rmse:0.93133	validation-rmse:1.44843
# [2511]	training-rmse:0.93099	validation-rmse:1.44820
# ----------------------------------------------------------
#
# TRIAL NUMBER 24 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.02422564675378369, 'gamma': 3.3604807877659573, 'max_depth': 8, 'min_child_weight': 8, 'subsample': 0.6767796770587966, 'colsample_bytree': 0.6161750130396251, 'lambda': 249.7750061269193, 'alpha': 31.810422226372225}
# [0]	training-rmse:4.32347	validation-rmse:5.08191
# [300]	training-rmse:0.48355	validation-rmse:1.57608
# [327]	training-rmse:0.46728	validation-rmse:1.57766
# ----------------------------------------------------------
#
# TRIAL NUMBER 25 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.013360941882640115, 'gamma': 4.125816505802732, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.5749269053797221, 'colsample_bytree': 0.6643632603731875, 'lambda': 646.7540712476363, 'alpha': 686.2421686971913}
# [0]	training-rmse:4.37111	validation-rmse:5.13724
# [300]	training-rmse:1.07094	validation-rmse:1.61391
# [600]	training-rmse:0.92162	validation-rmse:1.50297
# [900]	training-rmse:0.90362	validation-rmse:1.49134
# [1200]	training-rmse:0.90094	validation-rmse:1.48955
# [1319]	training-rmse:0.90062	validation-rmse:1.48934
# ----------------------------------------------------------
#
# TRIAL NUMBER 26 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0009097061929806888, 'gamma': 3.299359812628243, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.5659888108029437, 'colsample_bytree': 0.6843786547365793, 'lambda': 63.02543792562041, 'alpha': 22.700159823609948}
# [0]	training-rmse:4.41121	validation-rmse:5.17854
# [300]	training-rmse:3.47679	validation-rmse:4.08339
# [600]	training-rmse:2.77478	validation-rmse:3.28461
# [900]	training-rmse:2.25023	validation-rmse:2.71359
# [1200]	training-rmse:1.86323	validation-rmse:2.30720
# [1500]	training-rmse:1.58169	validation-rmse:2.01505
# [1800]	training-rmse:1.38055	validation-rmse:1.80707
# [2100]	training-rmse:1.23802	validation-rmse:1.66354
# [2400]	training-rmse:1.13767	validation-rmse:1.55846
# [2700]	training-rmse:1.06658	validation-rmse:1.48304
# [3000]	training-rmse:1.01535	validation-rmse:1.43099
# [3300]	training-rmse:0.97743	validation-rmse:1.39555
# [3600]	training-rmse:0.94860	validation-rmse:1.36953
# [3900]	training-rmse:0.92580	validation-rmse:1.35025
# [4200]	training-rmse:0.90665	validation-rmse:1.33546
# [4500]	training-rmse:0.89003	validation-rmse:1.32629
# [4800]	training-rmse:0.87540	validation-rmse:1.32044
# [5100]	training-rmse:0.86283	validation-rmse:1.31561
# [5400]	training-rmse:0.85161	validation-rmse:1.31177
# [5700]	training-rmse:0.84175	validation-rmse:1.30887
# [6000]	training-rmse:0.83264	validation-rmse:1.30677
# [6300]	training-rmse:0.82443	validation-rmse:1.30586
# [6600]	training-rmse:0.81697	validation-rmse:1.30409
# [6856]	training-rmse:0.81098	validation-rmse:1.30329
# ----------------------------------------------------------
#
# TRIAL NUMBER 27 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0004966803387414822, 'gamma': 3.2473775008047014, 'max_depth': 4, 'min_child_weight': 6, 'subsample': 0.5951316822869007, 'colsample_bytree': 0.6404578126347855, 'lambda': 16.01495005828387, 'alpha': 15.32337067923462}
# [0]	training-rmse:4.41276	validation-rmse:5.18027
# [300]	training-rmse:3.85024	validation-rmse:4.52189
# [600]	training-rmse:3.36853	validation-rmse:3.97502
# [900]	training-rmse:2.95647	validation-rmse:3.52305
# [1200]	training-rmse:2.60474	validation-rmse:3.14266
# [1500]	training-rmse:2.30479	validation-rmse:2.82316
# [1800]	training-rmse:2.04949	validation-rmse:2.55838
# [2100]	training-rmse:1.83280	validation-rmse:2.33955
# [2400]	training-rmse:1.64984	validation-rmse:2.15727
# [2700]	training-rmse:1.49597	validation-rmse:2.00762
# [3000]	training-rmse:1.36706	validation-rmse:1.88731
# [3300]	training-rmse:1.25933	validation-rmse:1.79075
# [3600]	training-rmse:1.16952	validation-rmse:1.71055
# [3900]	training-rmse:1.09453	validation-rmse:1.64151
# [4200]	training-rmse:1.03206	validation-rmse:1.58514
# [4500]	training-rmse:0.97995	validation-rmse:1.53824
# [4800]	training-rmse:0.93652	validation-rmse:1.49970
# [5100]	training-rmse:0.90013	validation-rmse:1.46748
# [5400]	training-rmse:0.86940	validation-rmse:1.43919
# [5700]	training-rmse:0.84320	validation-rmse:1.41664
# [6000]	training-rmse:0.82048	validation-rmse:1.39850
# [6300]	training-rmse:0.80090	validation-rmse:1.38409
# [6600]	training-rmse:0.78349	validation-rmse:1.37233
# [6900]	training-rmse:0.76818	validation-rmse:1.36326
# [7200]	training-rmse:0.75437	validation-rmse:1.35568
# [7500]	training-rmse:0.74185	validation-rmse:1.34976
# [7800]	training-rmse:0.73054	validation-rmse:1.34506
# [8100]	training-rmse:0.72037	validation-rmse:1.34149
# [8400]	training-rmse:0.71098	validation-rmse:1.33963
# [8700]	training-rmse:0.70259	validation-rmse:1.33811
# [8751]	training-rmse:0.70122	validation-rmse:1.33818
# ----------------------------------------------------------
#
# TRIAL NUMBER 28 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.00891403138135497, 'gamma': 3.7422932695653692, 'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6758853436024661, 'colsample_bytree': 0.5069193066555343, 'lambda': 10.87452689089059, 'alpha': 43.194782308013224}
# [0]	training-rmse:4.37829	validation-rmse:5.13993
# [300]	training-rmse:0.73757	validation-rmse:1.70276
# [600]	training-rmse:0.48286	validation-rmse:1.57814
# [769]	training-rmse:0.44972	validation-rmse:1.57659
# ----------------------------------------------------------
#
# TRIAL NUMBER 29 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0017793305062331066, 'gamma': 4.993824587590662, 'max_depth': 9, 'min_child_weight': 6, 'subsample': 0.6283007054013308, 'colsample_bytree': 0.5307181407561168, 'lambda': 292.4948933436166, 'alpha': 37.565251107760616}
# [0]	training-rmse:4.40816	validation-rmse:5.17541
# [300]	training-rmse:2.87839	validation-rmse:3.48288
# [600]	training-rmse:1.99156	validation-rmse:2.56502
# [900]	training-rmse:1.47835	validation-rmse:2.04941
# [1200]	training-rmse:1.17839	validation-rmse:1.80158
# [1500]	training-rmse:0.99235	validation-rmse:1.69644
# [1800]	training-rmse:0.86879	validation-rmse:1.63938
# [2100]	training-rmse:0.77817	validation-rmse:1.61159
# [2400]	training-rmse:0.70917	validation-rmse:1.59195
# [2700]	training-rmse:0.65554	validation-rmse:1.57879
# [3000]	training-rmse:0.61530	validation-rmse:1.57151
# [3300]	training-rmse:0.58466	validation-rmse:1.56485
# [3600]	training-rmse:0.56139	validation-rmse:1.56089
# [3601]	training-rmse:0.56128	validation-rmse:1.56083
# ----------------------------------------------------------
#
# TRIAL NUMBER 30 WITH HYPERPARAMETER CONFIGURATION: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0017308750303993488, 'gamma': 3.0334634985430124, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.5618981917335472, 'colsample_bytree': 0.6125854193436543, 'lambda': 15.200758200719811, 'alpha': 384.77173570346264}
# [0]	training-rmse:4.40806	validation-rmse:5.17528
# [300]	training-rmse:2.86423	validation-rmse:3.45544
# [600]	training-rmse:1.98052	validation-rmse:2.55238
# [900]	training-rmse:1.48750	validation-rmse:2.06797
# [1200]	training-rmse:1.21779	validation-rmse:1.81394
# [1500]	training-rmse:1.06756	validation-rmse:1.68653
# [1800]	training-rmse:0.98205	validation-rmse:1.61020
# [2100]	training-rmse:0.92901	validation-rmse:1.57103
# [2400]	training-rmse:0.89304	validation-rmse:1.54949
# [2700]	training-rmse:0.86724	validation-rmse:1.53605
# [3000]	training-rmse:0.84779	validation-rmse:1.52793
# [3300]	training-rmse:0.83324	validation-rmse:1.52147
# [3600]	training-rmse:0.82219	validation-rmse:1.51530
# [3900]	training-rmse:0.81321	validation-rmse:1.50961
# [4200]	training-rmse:0.80640	validation-rmse:1.50576
# [4500]	training-rmse:0.80263	validation-rmse:1.50377
# [4800]	training-rmse:0.80029	validation-rmse:1.50267
# [5100]	training-rmse:0.79903	validation-rmse:1.50196
# [5400]	training-rmse:0.79785	validation-rmse:1.50149
# [5507]	training-rmse:0.79747	validation-rmse:1.50136

# %%
# Print HPO results
print(f"The best hyperparameter configuration for ammonium predictions was {best_hparam_dict["ammonium_target_t_96"]} with mean squared validation error {best_val_rmse_dict["ammonium_target_t_96"]}")
print(f"The best hyperparameter configuration for dissolved oxygen predictions was {best_hparam_dict["oxygen_conc_target_t_96"]} with mean squared validation error {best_val_rmse_dict["oxygen_conc_target_t_96"]}")
print(f"The best hyperparameter configuration for temperature predictions was {best_hparam_dict["temperature_target_t_96"]} with mean squared validation error {best_val_rmse_dict["temperature_target_t_96"]}")
# Out:
# The best hyperparameter configuration for ammonium predictions was {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.019352667757515353, 'gamma': 4.339948403826172, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.5881994360395475, 'colsample_bytree': 0.6531102853377269, 'lambda': 10.604423594508907, 'alpha': 229.78725033401707} with mean squared validation error 0.04352967068552971
# The best hyperparameter configuration for dissolved oxygen predictions was {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0009097061929806888, 'gamma': 3.299359812628243, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.5659888108029437, 'colsample_bytree': 0.6843786547365793, 'lambda': 63.02543792562041, 'alpha': 22.700159823609948} with mean squared validation error 0.9064553380012512
# The best hyperparameter configuration for temperature predictions was {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'tree_method': 'hist', 'device': 'cuda', 'eta': 0.0009097061929806888, 'gamma': 3.299359812628243, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.5659888108029437, 'colsample_bytree': 0.6843786547365793, 'lambda': 63.02543792562041, 'alpha': 22.700159823609948} with mean squared validation error 1.303288221359253

# %% [markdown]
# ##8. Fit the XGBoost Models to Training Data

# %%
# Create a dictionary to hold XGBoost models
xgboost_model_dict = {}

# Create a mapping of each water quality variable name to the optimised hyperparameter config
hpo_target_mapping = {
    "ammonium": best_hparam_dict["ammonium_target_t_96"],
    "oxygen": best_hparam_dict["oxygen_conc_target_t_96"],
    "temperature": best_hparam_dict["temperature_target_t_96"]}

# %%
# Train the XGBoost models for each water quality variable and forecast horizon
for target in targets:
    print("\n----------------------------------------------------------------")
    print("----------------------------------------------------------------")
    print("----------------------------------------------------------------")
    print(f"NOW TRAINING TO PREDICT {target}".upper())
    # Obtain the name of the target water quality variable by splitting string on underscores
    var_name = target.split("_")[0] # returns "ammonium", "oxygen", or "temperature"
    # Specify the data to be used for training and evaluating the model
    evallist_target = [
        (dmatrices_train_dict[target], "training"),
        (dmatrices_val_dict[target], "validation")
    ]
    # Train the XGBoost model with the optimised hyperparameters for each target variable
    xgb_model = xgb.train(
        hpo_target_mapping[var_name], # use optimised hyperparameters that correspond to the correct target variable
        dmatrices_train_dict[target], # use the correct dmatrix for each target
        num_boost_round=NUM_BOOST_ROUND*10,
        early_stopping_rounds=EARLY_STOPPING_ROUNDS,
        evals=evallist_target, # maps to the data to be used for evaluation
        verbose_eval=EARLY_STOPPING_ROUNDS
        )
    # Add the trained XGBoost model to the dictionary of models
    xgboost_model_dict[target] = xgb_model
# Out:
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# NOW TRAINING TO PREDICT AMMONIUM_TARGET_T_1
# [0]	training-rmse:0.51961	validation-rmse:0.06048
# [50]	training-rmse:0.34494	validation-rmse:0.03644
# [100]	training-rmse:0.27201	validation-rmse:0.03284
# [150]	training-rmse:0.23639	validation-rmse:0.02605
# [200]	training-rmse:0.21927	validation-rmse:0.01766
# [250]	training-rmse:0.21365	validation-rmse:0.01570
# [300]	training-rmse:0.20876	validation-rmse:0.01547
# [303]	training-rmse:0.20855	validation-rmse:0.01548
#
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# NOW TRAINING TO PREDICT AMMONIUM_TARGET_T_2
# [0]	training-rmse:0.51960	validation-rmse:0.06049
# [50]	training-rmse:0.34523	validation-rmse:0.03664
# [100]	training-rmse:0.27359	validation-rmse:0.03310
# [150]	training-rmse:0.23857	validation-rmse:0.02691
# [200]	training-rmse:0.22242	validation-rmse:0.01872
# [250]	training-rmse:0.21672	validation-rmse:0.01658
# [287]	training-rmse:0.21230	validation-rmse:0.01662
#
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# NOW TRAINING TO PREDICT AMMONIUM_TARGET_T_4
# [0]	training-rmse:0.51968	validation-rmse:0.06053
# [50]	training-rmse:0.34644	validation-rmse:0.03745
# [100]	training-rmse:0.27505	validation-rmse:0.03357
# [150]	training-rmse:0.24083	validation-rmse:0.02735
# [200]	training-rmse:0.22475	validation-rmse:0.01952
# [250]	training-rmse:0.21948	validation-rmse:0.01817
# [287]	training-rmse:0.21507	validation-rmse:0.01821
#
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# NOW TRAINING TO PREDICT AMMONIUM_TARGET_T_24
# [0]	training-rmse:0.52029	validation-rmse:0.06092
# [50]	training-rmse:0.34989	validation-rmse:0.03936
# [100]	training-rmse:0.27789	validation-rmse:0.03562
# [150]	training-rmse:0.24423	validation-rmse:0.03257
# [200]	training-rmse:0.22877	validation-rmse:0.02875
# [250]	training-rmse:0.22184	validation-rmse:0.02842
# [300]	training-rmse:0.21850	validation-rmse:0.02829
# [316]	training-rmse:0.21786	validation-rmse:0.02829
#
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# NOW TRAINING TO PREDICT AMMONIUM_TARGET_T_48
# [0]	training-rmse:0.51961	validation-rmse:0.06108
# [50]	training-rmse:0.34687	validation-rmse:0.03919
# [100]	training-rmse:0.28003	validation-rmse:0.03336
# [150]	training-rmse:0.25185	validation-rmse:0.03116
# [200]	training-rmse:0.23773	validation-rmse:0.03119
# [212]	training-rmse:0.23502	validation-rmse:0.03124
#
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# NOW TRAINING TO PREDICT AMMONIUM_TARGET_T_96
# [0]	training-rmse:0.52128	validation-rmse:0.06173
# [50]	training-rmse:0.40990	validation-rmse:0.04968
# [100]	training-rmse:0.37297	validation-rmse:0.04610
# [150]	training-rmse:0.33890	validation-rmse:0.04474
# [200]	training-rmse:0.31561	validation-rmse:0.04412
# [250]	training-rmse:0.30456	validation-rmse:0.04387
# [300]	training-rmse:0.29665	validation-rmse:0.04371
# [350]	training-rmse:0.29559	validation-rmse:0.04369
# [400]	training-rmse:0.29321	validation-rmse:0.04356
# [450]	training-rmse:0.29126	validation-rmse:0.04353
# [465]	training-rmse:0.29126	validation-rmse:0.04353
#
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# NOW TRAINING TO PREDICT OXYGEN_CONC_TARGET_T_1
# [0]	training-rmse:2.12755	validation-rmse:2.24115
# [50]	training-rmse:2.04616	validation-rmse:2.15363
# [100]	training-rmse:1.96824	validation-rmse:2.07006
# [150]	training-rmse:1.89359	validation-rmse:1.98883
# [200]	training-rmse:1.82192	validation-rmse:1.91123
# [250]	training-rmse:1.75313	validation-rmse:1.83618
# [300]	training-rmse:1.68718	validation-rmse:1.76236
# [350]	training-rmse:1.62394	validation-rmse:1.69119
# [400]	training-rmse:1.56314	validation-rmse:1.62491
# [450]	training-rmse:1.50484	validation-rmse:1.56134
# [500]	training-rmse:1.44893	validation-rmse:1.49983
# [550]	training-rmse:1.39522	validation-rmse:1.44138
# [600]	training-rmse:1.34363	validation-rmse:1.38321
# [650]	training-rmse:1.29420	validation-rmse:1.32945
# [700]	training-rmse:1.24675	validation-rmse:1.27872
# [750]	training-rmse:1.20118	validation-rmse:1.22848
# [800]	training-rmse:1.15748	validation-rmse:1.18012
# [850]	training-rmse:1.11557	validation-rmse:1.13415
# [900]	training-rmse:1.07539	validation-rmse:1.09085
# [950]	training-rmse:1.03689	validation-rmse:1.04735
# [1000]	training-rmse:0.99990	validation-rmse:1.00747
# [1050]	training-rmse:0.96440	validation-rmse:0.97005
# [1100]	training-rmse:0.93037	validation-rmse:0.93353
# [1150]	training-rmse:0.89763	validation-rmse:0.89875
# [1200]	training-rmse:0.86622	validation-rmse:0.86512
# [1250]	training-rmse:0.83617	validation-rmse:0.83351
# [1300]	training-rmse:0.80725	validation-rmse:0.80273
# [1350]	training-rmse:0.77964	validation-rmse:0.77306
# [1400]	training-rmse:0.75315	validation-rmse:0.74503
# [1450]	training-rmse:0.72768	validation-rmse:0.71777
# [1500]	training-rmse:0.70324	validation-rmse:0.69195
# [1550]	training-rmse:0.67983	validation-rmse:0.66716
# [1600]	training-rmse:0.65739	validation-rmse:0.64390
# [1650]	training-rmse:0.63592	validation-rmse:0.62120
# [1700]	training-rmse:0.61532	validation-rmse:0.59864
# [1750]	training-rmse:0.59559	validation-rmse:0.57700
# [1800]	training-rmse:0.57671	validation-rmse:0.55824
# [1850]	training-rmse:0.55859	validation-rmse:0.53774
# [1900]	training-rmse:0.54127	validation-rmse:0.51966
# [1950]	training-rmse:0.52470	validation-rmse:0.50224
# [2000]	training-rmse:0.50879	validation-rmse:0.48592
# [2050]	training-rmse:0.49354	validation-rmse:0.47070
# [2100]	training-rmse:0.47894	validation-rmse:0.45557
# [2150]	training-rmse:0.46488	validation-rmse:0.44105
# [2200]	training-rmse:0.45137	validation-rmse:0.42777
# [2250]	training-rmse:0.43843	validation-rmse:0.41498
# [2300]	training-rmse:0.42605	validation-rmse:0.40244
# [2350]	training-rmse:0.41412	validation-rmse:0.39063
# [2400]	training-rmse:0.40271	validation-rmse:0.37947
# [2450]	training-rmse:0.39173	validation-rmse:0.36871
# [2500]	training-rmse:0.38120	validation-rmse:0.35815
# [2550]	training-rmse:0.37107	validation-rmse:0.34855
# [2600]	training-rmse:0.36138	validation-rmse:0.33923
# [2650]	training-rmse:0.35210	validation-rmse:0.33018
# [2700]	training-rmse:0.34319	validation-rmse:0.32173
# [2750]	training-rmse:0.33468	validation-rmse:0.31361
# [2800]	training-rmse:0.32650	validation-rmse:0.30553
# [2850]	training-rmse:0.31866	validation-rmse:0.29785
# [2900]	training-rmse:0.31116	validation-rmse:0.29048
# [2950]	training-rmse:0.30394	validation-rmse:0.28388
# [3000]	training-rmse:0.29704	validation-rmse:0.27747
# [3050]	training-rmse:0.29039	validation-rmse:0.27107
# [3100]	training-rmse:0.28399	validation-rmse:0.26496
# [3150]	training-rmse:0.27787	validation-rmse:0.25921
# [3200]	training-rmse:0.27200	validation-rmse:0.25377
# [3250]	training-rmse:0.26641	validation-rmse:0.24860
# [3300]	training-rmse:0.26104	validation-rmse:0.24355
# [3350]	training-rmse:0.25594	validation-rmse:0.23854
# [3400]	training-rmse:0.25103	validation-rmse:0.23401
# [3450]	training-rmse:0.24632	validation-rmse:0.22962
# [3500]	training-rmse:0.24177	validation-rmse:0.22544
# [3550]	training-rmse:0.23740	validation-rmse:0.22142
# [3600]	training-rmse:0.23322	validation-rmse:0.21769
# [3650]	training-rmse:0.22927	validation-rmse:0.21425
# [3700]	training-rmse:0.22547	validation-rmse:0.21086
# [3750]	training-rmse:0.22182	validation-rmse:0.20748
# [3800]	training-rmse:0.21833	validation-rmse:0.20447
# [3850]	training-rmse:0.21498	validation-rmse:0.20148
# [3900]	training-rmse:0.21177	validation-rmse:0.19859
# [3950]	training-rmse:0.20868	validation-rmse:0.19596
# [4000]	training-rmse:0.20573	validation-rmse:0.19350
# [4050]	training-rmse:0.20289	validation-rmse:0.19100
# [4100]	training-rmse:0.20017	validation-rmse:0.18854
# [4150]	training-rmse:0.19755	validation-rmse:0.18638
# [4200]	training-rmse:0.19506	validation-rmse:0.18436
# [4250]	training-rmse:0.19264	validation-rmse:0.18245
# [4300]	training-rmse:0.19034	validation-rmse:0.18075
# [4350]	training-rmse:0.18810	validation-rmse:0.17894
# [4400]	training-rmse:0.18595	validation-rmse:0.17727
# [4450]	training-rmse:0.18390	validation-rmse:0.17561
# [4500]	training-rmse:0.18196	validation-rmse:0.17409
# [4550]	training-rmse:0.18006	validation-rmse:0.17259
# [4600]	training-rmse:0.17823	validation-rmse:0.17115
# [4650]	training-rmse:0.17648	validation-rmse:0.16983
# [4700]	training-rmse:0.17477	validation-rmse:0.16870
# [4750]	training-rmse:0.17314	validation-rmse:0.16754
# [4800]	training-rmse:0.17159	validation-rmse:0.16635
# [4850]	training-rmse:0.17006	validation-rmse:0.16525
# [4900]	training-rmse:0.16861	validation-rmse:0.16415
# [4950]	training-rmse:0.16721	validation-rmse:0.16304
# [5000]	training-rmse:0.16584	validation-rmse:0.16210
# [5050]	training-rmse:0.16455	validation-rmse:0.16111
# [5100]	training-rmse:0.16329	validation-rmse:0.16025
# [5150]	training-rmse:0.16209	validation-rmse:0.15939
# [5200]	training-rmse:0.16095	validation-rmse:0.15862
# [5250]	training-rmse:0.15984	validation-rmse:0.15791
# [5300]	training-rmse:0.15876	validation-rmse:0.15723
# [5350]	training-rmse:0.15772	validation-rmse:0.15653
# [5400]	training-rmse:0.15674	validation-rmse:0.15577
# [5450]	training-rmse:0.15576	validation-rmse:0.15516
# [5500]	training-rmse:0.15484	validation-rmse:0.15454
# [5550]	training-rmse:0.15396	validation-rmse:0.15388
# [5600]	training-rmse:0.15311	validation-rmse:0.15323
# [5650]	training-rmse:0.15230	validation-rmse:0.15266
# [5700]	training-rmse:0.15155	validation-rmse:0.15197
# [5750]	training-rmse:0.15078	validation-rmse:0.15135
# [5800]	training-rmse:0.15009	validation-rmse:0.15080
# [5850]	training-rmse:0.14941	validation-rmse:0.15036
# [5900]	training-rmse:0.14876	validation-rmse:0.14991
# [5950]	training-rmse:0.14813	validation-rmse:0.14947
# [6000]	training-rmse:0.14754	validation-rmse:0.14904
# [6050]	training-rmse:0.14696	validation-rmse:0.14867
# [6100]	training-rmse:0.14641	validation-rmse:0.14826
# [6150]	training-rmse:0.14585	validation-rmse:0.14790
# [6200]	training-rmse:0.14532	validation-rmse:0.14753
# [6250]	training-rmse:0.14481	validation-rmse:0.14716
# [6300]	training-rmse:0.14433	validation-rmse:0.14681
# [6350]	training-rmse:0.14388	validation-rmse:0.14649
# [6400]	training-rmse:0.14346	validation-rmse:0.14614
# [6450]	training-rmse:0.14301	validation-rmse:0.14583
# [6500]	training-rmse:0.14259	validation-rmse:0.14551
# [6550]	training-rmse:0.14217	validation-rmse:0.14524
# [6600]	training-rmse:0.14179	validation-rmse:0.14490
# [6650]	training-rmse:0.14140	validation-rmse:0.14468
# [6700]	training-rmse:0.14102	validation-rmse:0.14441
# [6750]	training-rmse:0.14069	validation-rmse:0.14414
# [6800]	training-rmse:0.14033	validation-rmse:0.14390
# [6850]	training-rmse:0.14001	validation-rmse:0.14370
# [6900]	training-rmse:0.13970	validation-rmse:0.14348
# [6950]	training-rmse:0.13942	validation-rmse:0.14321
# [7000]	training-rmse:0.13913	validation-rmse:0.14299
# [7050]	training-rmse:0.13887	validation-rmse:0.14273
# [7100]	training-rmse:0.13862	validation-rmse:0.14252
# [7150]	training-rmse:0.13838	validation-rmse:0.14234
# [7200]	training-rmse:0.13813	validation-rmse:0.14219
# [7250]	training-rmse:0.13793	validation-rmse:0.14196
# [7300]	training-rmse:0.13771	validation-rmse:0.14184
# [7350]	training-rmse:0.13753	validation-rmse:0.14166
# [7400]	training-rmse:0.13735	validation-rmse:0.14151
# [7450]	training-rmse:0.13719	validation-rmse:0.14137
# [7500]	training-rmse:0.13702	validation-rmse:0.14121
# [7550]	training-rmse:0.13686	validation-rmse:0.14111
# [7600]	training-rmse:0.13669	validation-rmse:0.14097
# [7650]	training-rmse:0.13654	validation-rmse:0.14088
# [7700]	training-rmse:0.13641	validation-rmse:0.14081
# [7750]	training-rmse:0.13627	validation-rmse:0.14074
# [7800]	training-rmse:0.13616	validation-rmse:0.14066
# [7850]	training-rmse:0.13603	validation-rmse:0.14061
# [7900]	training-rmse:0.13592	validation-rmse:0.14053
# [7950]	training-rmse:0.13581	validation-rmse:0.14046
# [8000]	training-rmse:0.13571	validation-rmse:0.14041
# [8050]	training-rmse:0.13562	validation-rmse:0.14035
# [8100]	training-rmse:0.13552	validation-rmse:0.14031
# [8150]	training-rmse:0.13543	validation-rmse:0.14027
# [8200]	training-rmse:0.13536	validation-rmse:0.14025
# [8250]	training-rmse:0.13529	validation-rmse:0.14021
# [8300]	training-rmse:0.13520	validation-rmse:0.14020
# [8350]	training-rmse:0.13515	validation-rmse:0.14014
# [8400]	training-rmse:0.13509	validation-rmse:0.14012
# [8450]	training-rmse:0.13502	validation-rmse:0.14007
# [8500]	training-rmse:0.13496	validation-rmse:0.14003
# [8550]	training-rmse:0.13491	validation-rmse:0.14000
# [8600]	training-rmse:0.13484	validation-rmse:0.13998
# [8650]	training-rmse:0.13479	validation-rmse:0.13993
# [8700]	training-rmse:0.13474	validation-rmse:0.13993
# [8750]	training-rmse:0.13468	validation-rmse:0.13990
# [8774]	training-rmse:0.13464	validation-rmse:0.13990
#
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# NOW TRAINING TO PREDICT OXYGEN_CONC_TARGET_T_2
# [0]	training-rmse:2.12753	validation-rmse:2.24078
# [50]	training-rmse:2.04646	validation-rmse:2.15414
# [100]	training-rmse:1.96882	validation-rmse:2.07064
# [150]	training-rmse:1.89441	validation-rmse:1.98945
# [200]	training-rmse:1.82300	validation-rmse:1.91187
# [250]	training-rmse:1.75450	validation-rmse:1.83631
# [300]	training-rmse:1.68881	validation-rmse:1.76359
# [350]	training-rmse:1.62582	validation-rmse:1.69415
# [400]	training-rmse:1.56526	validation-rmse:1.62865
# [450]	training-rmse:1.50726	validation-rmse:1.56467
# [500]	training-rmse:1.45162	validation-rmse:1.50430
# [550]	training-rmse:1.39819	validation-rmse:1.44688
# [600]	training-rmse:1.34686	validation-rmse:1.39091
# [650]	training-rmse:1.29770	validation-rmse:1.33697
# [700]	training-rmse:1.25050	validation-rmse:1.28676
# [750]	training-rmse:1.20520	validation-rmse:1.23738
# [800]	training-rmse:1.16182	validation-rmse:1.18957
# [850]	training-rmse:1.12021	validation-rmse:1.14409
# [900]	training-rmse:1.08028	validation-rmse:1.10112
# [950]	training-rmse:1.04208	validation-rmse:1.05841
# [1000]	training-rmse:1.00539	validation-rmse:1.01914
# [1050]	training-rmse:0.97021	validation-rmse:0.98250
# [1100]	training-rmse:0.93648	validation-rmse:0.94660
# [1150]	training-rmse:0.90406	validation-rmse:0.91240
# [1200]	training-rmse:0.87294	validation-rmse:0.87929
# [1250]	training-rmse:0.84325	validation-rmse:0.84820
# [1300]	training-rmse:0.81468	validation-rmse:0.81792
# [1350]	training-rmse:0.78738	validation-rmse:0.78929
# [1400]	training-rmse:0.76122	validation-rmse:0.76167
# [1450]	training-rmse:0.73608	validation-rmse:0.73545
# [1500]	training-rmse:0.71199	validation-rmse:0.71016
# [1550]	training-rmse:0.68895	validation-rmse:0.68597
# [1600]	training-rmse:0.66688	validation-rmse:0.66294
# [1650]	training-rmse:0.64577	validation-rmse:0.64113
# [1700]	training-rmse:0.62555	validation-rmse:0.61921
# [1750]	training-rmse:0.60619	validation-rmse:0.59875
# [1800]	training-rmse:0.58767	validation-rmse:0.58075
# [1850]	training-rmse:0.56992	validation-rmse:0.56161
# [1900]	training-rmse:0.55297	validation-rmse:0.54489
# [1950]	training-rmse:0.53677	validation-rmse:0.52864
# [2000]	training-rmse:0.52121	validation-rmse:0.51342
# [2050]	training-rmse:0.50634	validation-rmse:0.49805
# [2100]	training-rmse:0.49211	validation-rmse:0.48374
# [2150]	training-rmse:0.47843	validation-rmse:0.47077
# [2200]	training-rmse:0.46532	validation-rmse:0.45831
# [2250]	training-rmse:0.45279	validation-rmse:0.44630
# [2300]	training-rmse:0.44085	validation-rmse:0.43500
# [2350]	training-rmse:0.42932	validation-rmse:0.42416
# [2400]	training-rmse:0.41832	validation-rmse:0.41392
# [2450]	training-rmse:0.40777	validation-rmse:0.40403
# [2500]	training-rmse:0.39766	validation-rmse:0.39438
# [2550]	training-rmse:0.38800	validation-rmse:0.38566
# [2600]	training-rmse:0.37876	validation-rmse:0.37709
# [2650]	training-rmse:0.36991	validation-rmse:0.36874
# [2700]	training-rmse:0.36144	validation-rmse:0.36082
# [2750]	training-rmse:0.35337	validation-rmse:0.35351
# [2800]	training-rmse:0.34560	validation-rmse:0.34617
# [2850]	training-rmse:0.33822	validation-rmse:0.33918
# [2900]	training-rmse:0.33114	validation-rmse:0.33227
# [2950]	training-rmse:0.32436	validation-rmse:0.32625
# [3000]	training-rmse:0.31787	validation-rmse:0.32045
# [3050]	training-rmse:0.31161	validation-rmse:0.31455
# [3100]	training-rmse:0.30560	validation-rmse:0.30897
# [3150]	training-rmse:0.29986	validation-rmse:0.30360
# [3200]	training-rmse:0.29435	validation-rmse:0.29863
# [3250]	training-rmse:0.28908	validation-rmse:0.29390
# [3300]	training-rmse:0.28405	validation-rmse:0.28937
# [3350]	training-rmse:0.27924	validation-rmse:0.28507
# [3400]	training-rmse:0.27459	validation-rmse:0.28092
# [3450]	training-rmse:0.27013	validation-rmse:0.27692
# [3500]	training-rmse:0.26586	validation-rmse:0.27309
# [3550]	training-rmse:0.26176	validation-rmse:0.26946
# [3600]	training-rmse:0.25778	validation-rmse:0.26609
# [3650]	training-rmse:0.25400	validation-rmse:0.26278
# [3700]	training-rmse:0.25037	validation-rmse:0.25965
# [3750]	training-rmse:0.24687	validation-rmse:0.25633
# [3800]	training-rmse:0.24349	validation-rmse:0.25336
# [3850]	training-rmse:0.24026	validation-rmse:0.25052
# [3900]	training-rmse:0.23716	validation-rmse:0.24781
# [3950]	training-rmse:0.23415	validation-rmse:0.24520
# [4000]	training-rmse:0.23126	validation-rmse:0.24275
# [4050]	training-rmse:0.22853	validation-rmse:0.24035
# [4100]	training-rmse:0.22587	validation-rmse:0.23801
# [4150]	training-rmse:0.22332	validation-rmse:0.23587
# [4200]	training-rmse:0.22089	validation-rmse:0.23378
# [4250]	training-rmse:0.21853	validation-rmse:0.23182
# [4300]	training-rmse:0.21630	validation-rmse:0.23003
# [4350]	training-rmse:0.21413	validation-rmse:0.22828
# [4400]	training-rmse:0.21201	validation-rmse:0.22657
# [4450]	training-rmse:0.21001	validation-rmse:0.22472
# [4500]	training-rmse:0.20811	validation-rmse:0.22319
# [4550]	training-rmse:0.20625	validation-rmse:0.22159
# [4600]	training-rmse:0.20449	validation-rmse:0.22013
# [4650]	training-rmse:0.20281	validation-rmse:0.21871
# [4700]	training-rmse:0.20116	validation-rmse:0.21756
# [4750]	training-rmse:0.19961	validation-rmse:0.21630
# [4800]	training-rmse:0.19811	validation-rmse:0.21509
# [4850]	training-rmse:0.19666	validation-rmse:0.21399
# [4900]	training-rmse:0.19526	validation-rmse:0.21285
# [4950]	training-rmse:0.19394	validation-rmse:0.21167
# [5000]	training-rmse:0.19264	validation-rmse:0.21063
# [5050]	training-rmse:0.19141	validation-rmse:0.20962
# [5100]	training-rmse:0.19022	validation-rmse:0.20870
# [5150]	training-rmse:0.18910	validation-rmse:0.20774
# [5200]	training-rmse:0.18802	validation-rmse:0.20693
# [5250]	training-rmse:0.18697	validation-rmse:0.20614
# [5300]	training-rmse:0.18597	validation-rmse:0.20536
# [5350]	training-rmse:0.18503	validation-rmse:0.20451
# [5400]	training-rmse:0.18412	validation-rmse:0.20380
# [5450]	training-rmse:0.18321	validation-rmse:0.20312
# [5500]	training-rmse:0.18235	validation-rmse:0.20240
# [5550]	training-rmse:0.18154	validation-rmse:0.20159
# [5600]	training-rmse:0.18075	validation-rmse:0.20091
# [5650]	training-rmse:0.17999	validation-rmse:0.20031
# [5700]	training-rmse:0.17927	validation-rmse:0.19960
# [5750]	training-rmse:0.17854	validation-rmse:0.19899
# [5800]	training-rmse:0.17785	validation-rmse:0.19833
# [5850]	training-rmse:0.17719	validation-rmse:0.19776
# [5900]	training-rmse:0.17656	validation-rmse:0.19712
# [5950]	training-rmse:0.17595	validation-rmse:0.19656
# [6000]	training-rmse:0.17535	validation-rmse:0.19603
# [6050]	training-rmse:0.17477	validation-rmse:0.19551
# [6100]	training-rmse:0.17423	validation-rmse:0.19501
# [6150]	training-rmse:0.17367	validation-rmse:0.19455
# [6200]	training-rmse:0.17314	validation-rmse:0.19403
# [6250]	training-rmse:0.17264	validation-rmse:0.19357
# [6300]	training-rmse:0.17212	validation-rmse:0.19308
# [6350]	training-rmse:0.17162	validation-rmse:0.19251
# [6400]	training-rmse:0.17115	validation-rmse:0.19200
# [6450]	training-rmse:0.17068	validation-rmse:0.19157
# [6500]	training-rmse:0.17022	validation-rmse:0.19108
# [6550]	training-rmse:0.16976	validation-rmse:0.19065
# [6600]	training-rmse:0.16933	validation-rmse:0.19022
# [6650]	training-rmse:0.16890	validation-rmse:0.18982
# [6700]	training-rmse:0.16850	validation-rmse:0.18943
# [6750]	training-rmse:0.16810	validation-rmse:0.18904
# [6800]	training-rmse:0.16772	validation-rmse:0.18870
# [6850]	training-rmse:0.16733	validation-rmse:0.18833
# [6900]	training-rmse:0.16699	validation-rmse:0.18801
# [6950]	training-rmse:0.16665	validation-rmse:0.18763
# [7000]	training-rmse:0.16630	validation-rmse:0.18727
# [7050]	training-rmse:0.16598	validation-rmse:0.18695
# [7100]	training-rmse:0.16567	validation-rmse:0.18664
# [7150]	training-rmse:0.16538	validation-rmse:0.18634
# [7200]	training-rmse:0.16510	validation-rmse:0.18616
# [7250]	training-rmse:0.16485	validation-rmse:0.18591
# [7300]	training-rmse:0.16460	validation-rmse:0.18573
# [7350]	training-rmse:0.16435	validation-rmse:0.18549
# [7400]	training-rmse:0.16413	validation-rmse:0.18527
# [7450]	training-rmse:0.16394	validation-rmse:0.18510
# [7500]	training-rmse:0.16375	validation-rmse:0.18490
# [7550]	training-rmse:0.16360	validation-rmse:0.18482
# [7600]	training-rmse:0.16342	validation-rmse:0.18468
# [7650]	training-rmse:0.16326	validation-rmse:0.18457
# [7700]	training-rmse:0.16313	validation-rmse:0.18451
# [7750]	training-rmse:0.16299	validation-rmse:0.18442
# [7800]	training-rmse:0.16285	validation-rmse:0.18426
# [7850]	training-rmse:0.16271	validation-rmse:0.18414
# [7900]	training-rmse:0.16260	validation-rmse:0.18405
# [7950]	training-rmse:0.16248	validation-rmse:0.18399
# [8000]	training-rmse:0.16239	validation-rmse:0.18392
# [8050]	training-rmse:0.16229	validation-rmse:0.18384
# [8100]	training-rmse:0.16218	validation-rmse:0.18375
# [8150]	training-rmse:0.16208	validation-rmse:0.18369
# [8200]	training-rmse:0.16201	validation-rmse:0.18365
# [8250]	training-rmse:0.16192	validation-rmse:0.18360
# [8300]	training-rmse:0.16184	validation-rmse:0.18357
# [8350]	training-rmse:0.16178	validation-rmse:0.18351
# [8400]	training-rmse:0.16173	validation-rmse:0.18349
# [8450]	training-rmse:0.16165	validation-rmse:0.18344
# [8500]	training-rmse:0.16160	validation-rmse:0.18342
# [8550]	training-rmse:0.16155	validation-rmse:0.18339
# [8600]	training-rmse:0.16150	validation-rmse:0.18336
# [8650]	training-rmse:0.16144	validation-rmse:0.18333
# [8700]	training-rmse:0.16137	validation-rmse:0.18329
# [8750]	training-rmse:0.16131	validation-rmse:0.18324
# [8800]	training-rmse:0.16125	validation-rmse:0.18320
# [8850]	training-rmse:0.16120	validation-rmse:0.18319
# [8900]	training-rmse:0.16116	validation-rmse:0.18316
# [8950]	training-rmse:0.16112	validation-rmse:0.18315
# [9000]	training-rmse:0.16107	validation-rmse:0.18312
# [9050]	training-rmse:0.16103	validation-rmse:0.18311
# [9100]	training-rmse:0.16099	validation-rmse:0.18307
# [9150]	training-rmse:0.16095	validation-rmse:0.18307
# [9200]	training-rmse:0.16092	validation-rmse:0.18306
# [9250]	training-rmse:0.16086	validation-rmse:0.18304
# [9300]	training-rmse:0.16082	validation-rmse:0.18304
# [9350]	training-rmse:0.16078	validation-rmse:0.18303
# [9400]	training-rmse:0.16075	validation-rmse:0.18302
# [9450]	training-rmse:0.16071	validation-rmse:0.18298
# [9500]	training-rmse:0.16067	validation-rmse:0.18297
# [9550]	training-rmse:0.16064	validation-rmse:0.18296
# [9600]	training-rmse:0.16061	validation-rmse:0.18293
# [9650]	training-rmse:0.16058	validation-rmse:0.18292
# [9700]	training-rmse:0.16055	validation-rmse:0.18288
# [9750]	training-rmse:0.16052	validation-rmse:0.18286
# [9800]	training-rmse:0.16047	validation-rmse:0.18283
# [9850]	training-rmse:0.16044	validation-rmse:0.18280
# [9900]	training-rmse:0.16042	validation-rmse:0.18280
# [9950]	training-rmse:0.16040	validation-rmse:0.18279
# [10000]	training-rmse:0.16037	validation-rmse:0.18277
# [10050]	training-rmse:0.16035	validation-rmse:0.18276
# [10100]	training-rmse:0.16032	validation-rmse:0.18275
# [10150]	training-rmse:0.16028	validation-rmse:0.18273
# [10200]	training-rmse:0.16027	validation-rmse:0.18272
# [10250]	training-rmse:0.16026	validation-rmse:0.18271
# [10300]	training-rmse:0.16025	validation-rmse:0.18271
# [10350]	training-rmse:0.16022	validation-rmse:0.18270
# [10400]	training-rmse:0.16020	validation-rmse:0.18270
# [10450]	training-rmse:0.16019	validation-rmse:0.18270
# [10500]	training-rmse:0.16017	validation-rmse:0.18270
# [10550]	training-rmse:0.16015	validation-rmse:0.18268
# [10591]	training-rmse:0.16014	validation-rmse:0.18268
#
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# NOW TRAINING TO PREDICT OXYGEN_CONC_TARGET_T_4
# [0]	training-rmse:2.12747	validation-rmse:2.24078
# [50]	training-rmse:2.04723	validation-rmse:2.15333
# [100]	training-rmse:1.97038	validation-rmse:2.06839
# [150]	training-rmse:1.89674	validation-rmse:1.98752
# [200]	training-rmse:1.82614	validation-rmse:1.90870
# [250]	training-rmse:1.75839	validation-rmse:1.83433
# [300]	training-rmse:1.69343	validation-rmse:1.76416
# [350]	training-rmse:1.63120	validation-rmse:1.69590
# [400]	training-rmse:1.57142	validation-rmse:1.63275
# [450]	training-rmse:1.51414	validation-rmse:1.57105
# [500]	training-rmse:1.45928	validation-rmse:1.51263
# [550]	training-rmse:1.40659	validation-rmse:1.45713
# [600]	training-rmse:1.35604	validation-rmse:1.40416
# [650]	training-rmse:1.30761	validation-rmse:1.35304
# [700]	training-rmse:1.26115	validation-rmse:1.30474
# [750]	training-rmse:1.21658	validation-rmse:1.25904
# [800]	training-rmse:1.17393	validation-rmse:1.21469
# [850]	training-rmse:1.13309	validation-rmse:1.17236
# [900]	training-rmse:1.09397	validation-rmse:1.13248
# [950]	training-rmse:1.05649	validation-rmse:1.09260
# [1000]	training-rmse:1.02061	validation-rmse:1.05638
# [1050]	training-rmse:0.98623	validation-rmse:1.02190
# [1100]	training-rmse:0.95334	validation-rmse:0.98857
# [1150]	training-rmse:0.92169	validation-rmse:0.95669
# [1200]	training-rmse:0.89140	validation-rmse:0.92574
# [1250]	training-rmse:0.86252	validation-rmse:0.89684
# [1300]	training-rmse:0.83479	validation-rmse:0.86887
# [1350]	training-rmse:0.80830	validation-rmse:0.84277
# [1400]	training-rmse:0.78294	validation-rmse:0.81731
# [1450]	training-rmse:0.75866	validation-rmse:0.79264
# [1500]	training-rmse:0.73542	validation-rmse:0.76961
# [1550]	training-rmse:0.71324	validation-rmse:0.74705
# [1600]	training-rmse:0.69203	validation-rmse:0.72576
# [1650]	training-rmse:0.67179	validation-rmse:0.70651
# [1700]	training-rmse:0.65245	validation-rmse:0.68691
# [1750]	training-rmse:0.63392	validation-rmse:0.66901
# [1800]	training-rmse:0.61627	validation-rmse:0.65290
# [1850]	training-rmse:0.59940	validation-rmse:0.63558
# [1900]	training-rmse:0.58330	validation-rmse:0.62097
# [1950]	training-rmse:0.56794	validation-rmse:0.60602
# [2000]	training-rmse:0.55323	validation-rmse:0.59191
# [2050]	training-rmse:0.53918	validation-rmse:0.57790
# [2100]	training-rmse:0.52574	validation-rmse:0.56559
# [2150]	training-rmse:0.51290	validation-rmse:0.55415
# [2200]	training-rmse:0.50061	validation-rmse:0.54293
# [2250]	training-rmse:0.48890	validation-rmse:0.53227
# [2300]	training-rmse:0.47774	validation-rmse:0.52216
# [2350]	training-rmse:0.46705	validation-rmse:0.51244
# [2400]	training-rmse:0.45677	validation-rmse:0.50309
# [2450]	training-rmse:0.44695	validation-rmse:0.49413
# [2500]	training-rmse:0.43753	validation-rmse:0.48542
# [2550]	training-rmse:0.42844	validation-rmse:0.47729
# [2600]	training-rmse:0.41979	validation-rmse:0.46932
# [2650]	training-rmse:0.41154	validation-rmse:0.46136
# [2700]	training-rmse:0.40356	validation-rmse:0.45389
# [2750]	training-rmse:0.39593	validation-rmse:0.44704
# [2800]	training-rmse:0.38866	validation-rmse:0.44013
# [2850]	training-rmse:0.38165	validation-rmse:0.43376
# [2900]	training-rmse:0.37499	validation-rmse:0.42769
# [2950]	training-rmse:0.36854	validation-rmse:0.42184
# [3000]	training-rmse:0.36237	validation-rmse:0.41609
# [3050]	training-rmse:0.35647	validation-rmse:0.41078
# [3100]	training-rmse:0.35079	validation-rmse:0.40550
# [3150]	training-rmse:0.34532	validation-rmse:0.40056
# [3200]	training-rmse:0.34010	validation-rmse:0.39567
# [3250]	training-rmse:0.33511	validation-rmse:0.39119
# [3300]	training-rmse:0.33032	validation-rmse:0.38667
# [3350]	training-rmse:0.32579	validation-rmse:0.38238
# [3400]	training-rmse:0.32139	validation-rmse:0.37832
# [3450]	training-rmse:0.31719	validation-rmse:0.37439
# [3500]	training-rmse:0.31314	validation-rmse:0.37065
# [3550]	training-rmse:0.30928	validation-rmse:0.36710
# [3600]	training-rmse:0.30555	validation-rmse:0.36384
# [3650]	training-rmse:0.30199	validation-rmse:0.36057
# [3700]	training-rmse:0.29858	validation-rmse:0.35766
# [3750]	training-rmse:0.29532	validation-rmse:0.35441
# [3800]	training-rmse:0.29216	validation-rmse:0.35131
# [3850]	training-rmse:0.28914	validation-rmse:0.34866
# [3900]	training-rmse:0.28628	validation-rmse:0.34611
# [3950]	training-rmse:0.28349	validation-rmse:0.34357
# [4000]	training-rmse:0.28082	validation-rmse:0.34122
# [4050]	training-rmse:0.27828	validation-rmse:0.33884
# [4100]	training-rmse:0.27582	validation-rmse:0.33658
# [4150]	training-rmse:0.27347	validation-rmse:0.33441
# [4200]	training-rmse:0.27124	validation-rmse:0.33227
# [4250]	training-rmse:0.26908	validation-rmse:0.33020
# [4300]	training-rmse:0.26703	validation-rmse:0.32832
# [4350]	training-rmse:0.26503	validation-rmse:0.32642
# [4400]	training-rmse:0.26311	validation-rmse:0.32456
# [4450]	training-rmse:0.26126	validation-rmse:0.32267
# [4500]	training-rmse:0.25950	validation-rmse:0.32100
# [4550]	training-rmse:0.25781	validation-rmse:0.31933
# [4600]	training-rmse:0.25620	validation-rmse:0.31785
# [4650]	training-rmse:0.25464	validation-rmse:0.31629
# [4700]	training-rmse:0.25313	validation-rmse:0.31494
# [4750]	training-rmse:0.25167	validation-rmse:0.31350
# [4800]	training-rmse:0.25026	validation-rmse:0.31207
# [4850]	training-rmse:0.24889	validation-rmse:0.31074
# [4900]	training-rmse:0.24761	validation-rmse:0.30933
# [4950]	training-rmse:0.24636	validation-rmse:0.30810
# [5000]	training-rmse:0.24513	validation-rmse:0.30698
# [5050]	training-rmse:0.24395	validation-rmse:0.30585
# [5100]	training-rmse:0.24281	validation-rmse:0.30481
# [5150]	training-rmse:0.24168	validation-rmse:0.30356
# [5200]	training-rmse:0.24059	validation-rmse:0.30237
# [5250]	training-rmse:0.23955	validation-rmse:0.30123
# [5300]	training-rmse:0.23853	validation-rmse:0.30021
# [5350]	training-rmse:0.23751	validation-rmse:0.29913
# [5400]	training-rmse:0.23659	validation-rmse:0.29821
# [5450]	training-rmse:0.23564	validation-rmse:0.29720
# [5500]	training-rmse:0.23468	validation-rmse:0.29607
# [5550]	training-rmse:0.23379	validation-rmse:0.29509
# [5600]	training-rmse:0.23293	validation-rmse:0.29405
# [5650]	training-rmse:0.23207	validation-rmse:0.29311
# [5700]	training-rmse:0.23125	validation-rmse:0.29224
# [5750]	training-rmse:0.23044	validation-rmse:0.29134
# [5800]	training-rmse:0.22967	validation-rmse:0.29051
# [5850]	training-rmse:0.22889	validation-rmse:0.28973
# [5900]	training-rmse:0.22819	validation-rmse:0.28896
# [5950]	training-rmse:0.22747	validation-rmse:0.28826
# [6000]	training-rmse:0.22681	validation-rmse:0.28768
# [6050]	training-rmse:0.22615	validation-rmse:0.28706
# [6100]	training-rmse:0.22554	validation-rmse:0.28643
# [6150]	training-rmse:0.22490	validation-rmse:0.28580
# [6200]	training-rmse:0.22429	validation-rmse:0.28513
# [6250]	training-rmse:0.22371	validation-rmse:0.28456
# [6300]	training-rmse:0.22312	validation-rmse:0.28394
# [6350]	training-rmse:0.22255	validation-rmse:0.28334
# [6400]	training-rmse:0.22201	validation-rmse:0.28274
# [6450]	training-rmse:0.22147	validation-rmse:0.28214
# [6500]	training-rmse:0.22096	validation-rmse:0.28165
# [6550]	training-rmse:0.22045	validation-rmse:0.28113
# [6600]	training-rmse:0.21995	validation-rmse:0.28055
# [6650]	training-rmse:0.21946	validation-rmse:0.28002
# [6700]	training-rmse:0.21900	validation-rmse:0.27950
# [6750]	training-rmse:0.21853	validation-rmse:0.27906
# [6800]	training-rmse:0.21806	validation-rmse:0.27853
# [6850]	training-rmse:0.21762	validation-rmse:0.27811
# [6900]	training-rmse:0.21719	validation-rmse:0.27772
# [6950]	training-rmse:0.21679	validation-rmse:0.27724
# [7000]	training-rmse:0.21638	validation-rmse:0.27682
# [7050]	training-rmse:0.21598	validation-rmse:0.27635
# [7100]	training-rmse:0.21562	validation-rmse:0.27590
# [7150]	training-rmse:0.21529	validation-rmse:0.27552
# [7200]	training-rmse:0.21494	validation-rmse:0.27526
# [7250]	training-rmse:0.21460	validation-rmse:0.27499
# [7300]	training-rmse:0.21425	validation-rmse:0.27464
# [7350]	training-rmse:0.21395	validation-rmse:0.27433
# [7400]	training-rmse:0.21367	validation-rmse:0.27401
# [7450]	training-rmse:0.21336	validation-rmse:0.27370
# [7500]	training-rmse:0.21304	validation-rmse:0.27335
# [7550]	training-rmse:0.21278	validation-rmse:0.27314
# [7600]	training-rmse:0.21249	validation-rmse:0.27288
# [7650]	training-rmse:0.21224	validation-rmse:0.27261
# [7700]	training-rmse:0.21199	validation-rmse:0.27235
# [7750]	training-rmse:0.21178	validation-rmse:0.27220
# [7800]	training-rmse:0.21154	validation-rmse:0.27195
# [7850]	training-rmse:0.21131	validation-rmse:0.27171
# [7900]	training-rmse:0.21112	validation-rmse:0.27153
# [7950]	training-rmse:0.21097	validation-rmse:0.27141
# [8000]	training-rmse:0.21076	validation-rmse:0.27120
# [8050]	training-rmse:0.21059	validation-rmse:0.27109
# [8100]	training-rmse:0.21043	validation-rmse:0.27093
# [8150]	training-rmse:0.21028	validation-rmse:0.27081
# [8200]	training-rmse:0.21015	validation-rmse:0.27070
# [8250]	training-rmse:0.20999	validation-rmse:0.27058
# [8300]	training-rmse:0.20986	validation-rmse:0.27048
# [8350]	training-rmse:0.20975	validation-rmse:0.27036
# [8400]	training-rmse:0.20965	validation-rmse:0.27023
# [8450]	training-rmse:0.20953	validation-rmse:0.27012
# [8500]	training-rmse:0.20944	validation-rmse:0.27007
# [8550]	training-rmse:0.20936	validation-rmse:0.27002
# [8600]	training-rmse:0.20926	validation-rmse:0.26996
# [8650]	training-rmse:0.20919	validation-rmse:0.26995
# [8672]	training-rmse:0.20916	validation-rmse:0.26994
#
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# NOW TRAINING TO PREDICT OXYGEN_CONC_TARGET_T_24
# [0]	training-rmse:2.12716	validation-rmse:2.24045
# [50]	training-rmse:2.04932	validation-rmse:2.16097
# [100]	training-rmse:1.97488	validation-rmse:2.08502
# [150]	training-rmse:1.90363	validation-rmse:2.01245
# [200]	training-rmse:1.83547	validation-rmse:1.94293
# [250]	training-rmse:1.77013	validation-rmse:1.87720
# [300]	training-rmse:1.70771	validation-rmse:1.81419
# [350]	training-rmse:1.64805	validation-rmse:1.75394
# [400]	training-rmse:1.59096	validation-rmse:1.69530
# [450]	training-rmse:1.53639	validation-rmse:1.64004
# [500]	training-rmse:1.48422	validation-rmse:1.58737
# [550]	training-rmse:1.43445	validation-rmse:1.53697
# [600]	training-rmse:1.38682	validation-rmse:1.48816
# [650]	training-rmse:1.34126	validation-rmse:1.44144
# [700]	training-rmse:1.29776	validation-rmse:1.39749
# [750]	training-rmse:1.25593	validation-rmse:1.35584
# [800]	training-rmse:1.21604	validation-rmse:1.31542
# [850]	training-rmse:1.17782	validation-rmse:1.27721
# [900]	training-rmse:1.14137	validation-rmse:1.24127
# [950]	training-rmse:1.10657	validation-rmse:1.20703
# [1000]	training-rmse:1.07331	validation-rmse:1.17450
# [1050]	training-rmse:1.04169	validation-rmse:1.14392
# [1100]	training-rmse:1.01149	validation-rmse:1.11491
# [1150]	training-rmse:0.98267	validation-rmse:1.08752
# [1200]	training-rmse:0.95516	validation-rmse:1.06156
# [1250]	training-rmse:0.92886	validation-rmse:1.03704
# [1300]	training-rmse:0.90384	validation-rmse:1.01377
# [1350]	training-rmse:0.88006	validation-rmse:0.99205
# [1400]	training-rmse:0.85736	validation-rmse:0.97140
# [1450]	training-rmse:0.83577	validation-rmse:0.95246
# [1500]	training-rmse:0.81519	validation-rmse:0.93395
# [1550]	training-rmse:0.79562	validation-rmse:0.91687
# [1600]	training-rmse:0.77695	validation-rmse:0.90046
# [1650]	training-rmse:0.75922	validation-rmse:0.88521
# [1700]	training-rmse:0.74233	validation-rmse:0.87114
# [1750]	training-rmse:0.72627	validation-rmse:0.85766
# [1800]	training-rmse:0.71095	validation-rmse:0.84509
# [1850]	training-rmse:0.69643	validation-rmse:0.83279
# [1900]	training-rmse:0.68258	validation-rmse:0.82152
# [1950]	training-rmse:0.66942	validation-rmse:0.81074
# [2000]	training-rmse:0.65691	validation-rmse:0.80047
# [2050]	training-rmse:0.64497	validation-rmse:0.79086
# [2100]	training-rmse:0.63359	validation-rmse:0.78061
# [2150]	training-rmse:0.62275	validation-rmse:0.77190
# [2200]	training-rmse:0.61243	validation-rmse:0.76308
# [2250]	training-rmse:0.60267	validation-rmse:0.75508
# [2300]	training-rmse:0.59333	validation-rmse:0.74756
# [2350]	training-rmse:0.58441	validation-rmse:0.74032
# [2400]	training-rmse:0.57596	validation-rmse:0.73338
# [2450]	training-rmse:0.56796	validation-rmse:0.72672
# [2500]	training-rmse:0.56029	validation-rmse:0.72013
# [2550]	training-rmse:0.55301	validation-rmse:0.71436
# [2600]	training-rmse:0.54608	validation-rmse:0.70883
# [2650]	training-rmse:0.53946	validation-rmse:0.70315
# [2700]	training-rmse:0.53320	validation-rmse:0.69786
# [2750]	training-rmse:0.52724	validation-rmse:0.69296
# [2800]	training-rmse:0.52162	validation-rmse:0.68812
# [2850]	training-rmse:0.51620	validation-rmse:0.68377
# [2900]	training-rmse:0.51108	validation-rmse:0.67930
# [2950]	training-rmse:0.50619	validation-rmse:0.67514
# [3000]	training-rmse:0.50148	validation-rmse:0.67110
# [3050]	training-rmse:0.49701	validation-rmse:0.66733
# [3100]	training-rmse:0.49275	validation-rmse:0.66352
# [3150]	training-rmse:0.48870	validation-rmse:0.66005
# [3200]	training-rmse:0.48487	validation-rmse:0.65653
# [3250]	training-rmse:0.48123	validation-rmse:0.65360
# [3300]	training-rmse:0.47772	validation-rmse:0.65055
# [3350]	training-rmse:0.47442	validation-rmse:0.64798
# [3400]	training-rmse:0.47119	validation-rmse:0.64555
# [3450]	training-rmse:0.46816	validation-rmse:0.64316
# [3500]	training-rmse:0.46527	validation-rmse:0.64107
# [3550]	training-rmse:0.46249	validation-rmse:0.63915
# [3600]	training-rmse:0.45981	validation-rmse:0.63760
# [3650]	training-rmse:0.45727	validation-rmse:0.63596
# [3700]	training-rmse:0.45481	validation-rmse:0.63429
# [3750]	training-rmse:0.45248	validation-rmse:0.63275
# [3800]	training-rmse:0.45016	validation-rmse:0.63149
# [3850]	training-rmse:0.44797	validation-rmse:0.63021
# [3900]	training-rmse:0.44587	validation-rmse:0.62919
# [3950]	training-rmse:0.44386	validation-rmse:0.62772
# [4000]	training-rmse:0.44193	validation-rmse:0.62649
# [4050]	training-rmse:0.44007	validation-rmse:0.62515
# [4100]	training-rmse:0.43831	validation-rmse:0.62386
# [4150]	training-rmse:0.43656	validation-rmse:0.62293
# [4200]	training-rmse:0.43487	validation-rmse:0.62203
# [4250]	training-rmse:0.43329	validation-rmse:0.62115
# [4300]	training-rmse:0.43168	validation-rmse:0.62051
# [4350]	training-rmse:0.43016	validation-rmse:0.61987
# [4400]	training-rmse:0.42871	validation-rmse:0.61910
# [4450]	training-rmse:0.42730	validation-rmse:0.61832
# [4500]	training-rmse:0.42592	validation-rmse:0.61782
# [4550]	training-rmse:0.42463	validation-rmse:0.61690
# [4600]	training-rmse:0.42336	validation-rmse:0.61623
# [4650]	training-rmse:0.42208	validation-rmse:0.61570
# [4700]	training-rmse:0.42086	validation-rmse:0.61499
# [4750]	training-rmse:0.41967	validation-rmse:0.61442
# [4800]	training-rmse:0.41855	validation-rmse:0.61389
# [4850]	training-rmse:0.41746	validation-rmse:0.61320
# [4900]	training-rmse:0.41637	validation-rmse:0.61245
# [4950]	training-rmse:0.41533	validation-rmse:0.61213
# [5000]	training-rmse:0.41431	validation-rmse:0.61158
# [5050]	training-rmse:0.41327	validation-rmse:0.61158
# [5056]	training-rmse:0.41315	validation-rmse:0.61152
#
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# NOW TRAINING TO PREDICT OXYGEN_CONC_TARGET_T_48
# [0]	training-rmse:2.12695	validation-rmse:2.23933
# [50]	training-rmse:2.04875	validation-rmse:2.15810
# [100]	training-rmse:1.97400	validation-rmse:2.08067
# [150]	training-rmse:1.90253	validation-rmse:2.00535
# [200]	training-rmse:1.83409	validation-rmse:1.93426
# [250]	training-rmse:1.76853	validation-rmse:1.86621
# [300]	training-rmse:1.70586	validation-rmse:1.80028
# [350]	training-rmse:1.64596	validation-rmse:1.73675
# [400]	training-rmse:1.58864	validation-rmse:1.67698
# [450]	training-rmse:1.53371	validation-rmse:1.61888
# [500]	training-rmse:1.48118	validation-rmse:1.56227
# [550]	training-rmse:1.43096	validation-rmse:1.50926
# [600]	training-rmse:1.38287	validation-rmse:1.45927
# [650]	training-rmse:1.33693	validation-rmse:1.41141
# [700]	training-rmse:1.29308	validation-rmse:1.36684
# [750]	training-rmse:1.25115	validation-rmse:1.32307
# [800]	training-rmse:1.21113	validation-rmse:1.28220
# [850]	training-rmse:1.17283	validation-rmse:1.24380
# [900]	training-rmse:1.13628	validation-rmse:1.20720
# [950]	training-rmse:1.10138	validation-rmse:1.17290
# [1000]	training-rmse:1.06809	validation-rmse:1.14023
# [1050]	training-rmse:1.03632	validation-rmse:1.10966
# [1100]	training-rmse:1.00596	validation-rmse:1.08045
# [1150]	training-rmse:0.97694	validation-rmse:1.05224
# [1200]	training-rmse:0.94930	validation-rmse:1.02611
# [1250]	training-rmse:0.92297	validation-rmse:1.00161
# [1300]	training-rmse:0.89782	validation-rmse:0.97800
# [1350]	training-rmse:0.87386	validation-rmse:0.95614
# [1400]	training-rmse:0.85100	validation-rmse:0.93481
# [1450]	training-rmse:0.82924	validation-rmse:0.91506
# [1500]	training-rmse:0.80850	validation-rmse:0.89546
# [1550]	training-rmse:0.78875	validation-rmse:0.87682
# [1600]	training-rmse:0.76993	validation-rmse:0.86021
# [1650]	training-rmse:0.75206	validation-rmse:0.84400
# [1700]	training-rmse:0.73503	validation-rmse:0.82890
# [1750]	training-rmse:0.71879	validation-rmse:0.81400
# [1800]	training-rmse:0.70330	validation-rmse:0.80121
# [1850]	training-rmse:0.68862	validation-rmse:0.78858
# [1900]	training-rmse:0.67461	validation-rmse:0.77690
# [1950]	training-rmse:0.66132	validation-rmse:0.76573
# [2000]	training-rmse:0.64867	validation-rmse:0.75549
# [2050]	training-rmse:0.63669	validation-rmse:0.74641
# [2100]	training-rmse:0.62529	validation-rmse:0.73777
# [2150]	training-rmse:0.61443	validation-rmse:0.72911
# [2200]	training-rmse:0.60414	validation-rmse:0.72145
# [2250]	training-rmse:0.59438	validation-rmse:0.71392
# [2300]	training-rmse:0.58513	validation-rmse:0.70728
# [2350]	training-rmse:0.57635	validation-rmse:0.70088
# [2400]	training-rmse:0.56800	validation-rmse:0.69422
# [2450]	training-rmse:0.56008	validation-rmse:0.68864
# [2500]	training-rmse:0.55252	validation-rmse:0.68385
# [2550]	training-rmse:0.54539	validation-rmse:0.67940
# [2600]	training-rmse:0.53862	validation-rmse:0.67561
# [2650]	training-rmse:0.53213	validation-rmse:0.67182
# [2700]	training-rmse:0.52600	validation-rmse:0.66851
# [2750]	training-rmse:0.52023	validation-rmse:0.66507
# [2800]	training-rmse:0.51472	validation-rmse:0.66207
# [2850]	training-rmse:0.50943	validation-rmse:0.65937
# [2900]	training-rmse:0.50439	validation-rmse:0.65713
# [2950]	training-rmse:0.49963	validation-rmse:0.65457
# [3000]	training-rmse:0.49509	validation-rmse:0.65208
# [3050]	training-rmse:0.49077	validation-rmse:0.65016
# [3100]	training-rmse:0.48657	validation-rmse:0.64800
# [3150]	training-rmse:0.48271	validation-rmse:0.64551
# [3200]	training-rmse:0.47896	validation-rmse:0.64400
# [3250]	training-rmse:0.47541	validation-rmse:0.64238
# [3300]	training-rmse:0.47205	validation-rmse:0.64122
# [3350]	training-rmse:0.46881	validation-rmse:0.64015
# [3400]	training-rmse:0.46568	validation-rmse:0.63921
# [3450]	training-rmse:0.46270	validation-rmse:0.63857
# [3500]	training-rmse:0.45991	validation-rmse:0.63780
# [3550]	training-rmse:0.45725	validation-rmse:0.63706
# [3600]	training-rmse:0.45467	validation-rmse:0.63642
# [3650]	training-rmse:0.45226	validation-rmse:0.63579
# [3700]	training-rmse:0.44995	validation-rmse:0.63497
# [3750]	training-rmse:0.44772	validation-rmse:0.63464
# [3800]	training-rmse:0.44554	validation-rmse:0.63403
# [3850]	training-rmse:0.44344	validation-rmse:0.63369
# [3900]	training-rmse:0.44147	validation-rmse:0.63342
# [3950]	training-rmse:0.43955	validation-rmse:0.63298
# [4000]	training-rmse:0.43772	validation-rmse:0.63274
# [4050]	training-rmse:0.43593	validation-rmse:0.63238
# [4100]	training-rmse:0.43421	validation-rmse:0.63240
# [4103]	training-rmse:0.43411	validation-rmse:0.63246
#
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# NOW TRAINING TO PREDICT OXYGEN_CONC_TARGET_T_96
# [0]	training-rmse:2.12657	validation-rmse:2.23703
# [50]	training-rmse:2.05137	validation-rmse:2.15937
# [100]	training-rmse:1.97963	validation-rmse:2.08480
# [150]	training-rmse:1.91111	validation-rmse:2.01393
# [200]	training-rmse:1.84565	validation-rmse:1.94533
# [250]	training-rmse:1.78293	validation-rmse:1.87991
# [300]	training-rmse:1.72307	validation-rmse:1.81844
# [350]	training-rmse:1.66595	validation-rmse:1.75965
# [400]	training-rmse:1.61147	validation-rmse:1.70458
# [450]	training-rmse:1.55934	validation-rmse:1.65184
# [500]	training-rmse:1.50960	validation-rmse:1.60177
# [550]	training-rmse:1.46206	validation-rmse:1.55479
# [600]	training-rmse:1.41660	validation-rmse:1.51091
# [650]	training-rmse:1.37336	validation-rmse:1.46957
# [700]	training-rmse:1.33205	validation-rmse:1.43066
# [750]	training-rmse:1.29259	validation-rmse:1.39348
# [800]	training-rmse:1.25503	validation-rmse:1.35966
# [850]	training-rmse:1.21913	validation-rmse:1.32733
# [900]	training-rmse:1.18481	validation-rmse:1.29753
# [950]	training-rmse:1.15226	validation-rmse:1.26951
# [1000]	training-rmse:1.12135	validation-rmse:1.24261
# [1050]	training-rmse:1.09188	validation-rmse:1.21782
# [1100]	training-rmse:1.06384	validation-rmse:1.19496
# [1150]	training-rmse:1.03713	validation-rmse:1.17266
# [1200]	training-rmse:1.01180	validation-rmse:1.15213
# [1250]	training-rmse:0.98775	validation-rmse:1.13293
# [1300]	training-rmse:0.96487	validation-rmse:1.11478
# [1350]	training-rmse:0.94309	validation-rmse:1.09764
# [1400]	training-rmse:0.92243	validation-rmse:1.08171
# [1450]	training-rmse:0.90275	validation-rmse:1.06588
# [1500]	training-rmse:0.88403	validation-rmse:1.05174
# [1550]	training-rmse:0.86630	validation-rmse:1.03856
# [1600]	training-rmse:0.84955	validation-rmse:1.02588
# [1650]	training-rmse:0.83362	validation-rmse:1.01394
# [1700]	training-rmse:0.81848	validation-rmse:1.00308
# [1750]	training-rmse:0.80418	validation-rmse:0.99268
# [1800]	training-rmse:0.79049	validation-rmse:0.98362
# [1850]	training-rmse:0.77758	validation-rmse:0.97359
# [1900]	training-rmse:0.76530	validation-rmse:0.96513
# [1950]	training-rmse:0.75360	validation-rmse:0.95711
# [2000]	training-rmse:0.74242	validation-rmse:0.95007
# [2050]	training-rmse:0.73183	validation-rmse:0.94411
# [2100]	training-rmse:0.72165	validation-rmse:0.93878
# [2150]	training-rmse:0.71197	validation-rmse:0.93401
# [2200]	training-rmse:0.70280	validation-rmse:0.93056
# [2250]	training-rmse:0.69412	validation-rmse:0.92676
# [2300]	training-rmse:0.68581	validation-rmse:0.92369
# [2350]	training-rmse:0.67793	validation-rmse:0.92095
# [2400]	training-rmse:0.67044	validation-rmse:0.91803
# [2450]	training-rmse:0.66327	validation-rmse:0.91568
# [2500]	training-rmse:0.65645	validation-rmse:0.91390
# [2550]	training-rmse:0.64991	validation-rmse:0.91230
# [2600]	training-rmse:0.64377	validation-rmse:0.91056
# [2650]	training-rmse:0.63768	validation-rmse:0.90955
# [2700]	training-rmse:0.63210	validation-rmse:0.90855
# ...
# [9600]	training-rmse:0.58523	validation-rmse:0.88928
# [9650]	training-rmse:0.58478	validation-rmse:0.88914
# [9700]	training-rmse:0.58434	validation-rmse:0.88890
# [9750]	training-rmse:0.58388	validation-rmse:0.88880
# [9800]	training-rmse:0.58345	validation-rmse:0.88864
# [9850]	training-rmse:0.58301	validation-rmse:0.88849
# [9900]	training-rmse:0.58253	validation-rmse:0.88829
# [9950]	training-rmse:0.58211	validation-rmse:0.88807
# [10000]	training-rmse:0.58167	validation-rmse:0.88792
# [10050]	training-rmse:0.58122	validation-rmse:0.88779
# [10100]	training-rmse:0.58078	validation-rmse:0.88768
# [10150]	training-rmse:0.58035	validation-rmse:0.88748
# [10200]	training-rmse:0.57991	validation-rmse:0.88736
# [10250]	training-rmse:0.57947	validation-rmse:0.88725
# [10300]	training-rmse:0.57902	validation-rmse:0.88725
# [10320]	training-rmse:0.57884	validation-rmse:0.88718
#
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# NOW TRAINING TO PREDICT TEMPERATURE_TARGET_T_48
# [0]	training-rmse:4.40463	validation-rmse:5.18826
# [50]	training-rmse:4.22591	validation-rmse:4.97577
# [100]	training-rmse:4.05520	validation-rmse:4.77255
# [150]	training-rmse:3.89212	validation-rmse:4.57857
# [200]	training-rmse:3.73642	validation-rmse:4.39317
# [250]	training-rmse:3.58760	validation-rmse:4.21571
# [300]	training-rmse:3.44548	validation-rmse:4.04730
# [350]	training-rmse:3.30976	validation-rmse:3.88734
# [400]	training-rmse:3.18016	validation-rmse:3.73493
# [450]	training-rmse:3.05629	validation-rmse:3.59011
# [500]	training-rmse:2.93804	validation-rmse:3.45277
# [550]	training-rmse:2.82513	validation-rmse:3.32228
# [600]	training-rmse:2.71722	validation-rmse:3.19766
# [650]	training-rmse:2.61424	validation-rmse:3.07859
# [700]	training-rmse:2.51611	validation-rmse:2.96609
# [750]	training-rmse:2.42242	validation-rmse:2.85876
# [800]	training-rmse:2.33312	validation-rmse:2.75660
# [850]	training-rmse:2.24798	validation-rmse:2.65925
# [900]	training-rmse:2.16683	validation-rmse:2.56610
# [950]	training-rmse:2.08965	validation-rmse:2.47705
# [1000]	training-rmse:2.01616	validation-rmse:2.39305
# [1050]	training-rmse:1.94611	validation-rmse:2.31207
# [1100]	training-rmse:1.87954	validation-rmse:2.23679
# [1150]	training-rmse:1.81617	validation-rmse:2.16450
# [1200]	training-rmse:1.75586	validation-rmse:2.09528
# [1250]	training-rmse:1.69859	validation-rmse:2.02998
# [1300]	training-rmse:1.64403	validation-rmse:1.96809
# [1350]	training-rmse:1.59223	validation-rmse:1.90961
# [1400]	training-rmse:1.54304	validation-rmse:1.85567
# [1450]	training-rmse:1.49630	validation-rmse:1.80467
# [1500]	training-rmse:1.45189	validation-rmse:1.75643
# [1550]	training-rmse:1.40978	validation-rmse:1.71023
# [1600]	training-rmse:1.36987	validation-rmse:1.66720
# [1650]	training-rmse:1.33200	validation-rmse:1.62653
# [1700]	training-rmse:1.29619	validation-rmse:1.58813
# [1750]	training-rmse:1.26222	validation-rmse:1.55269
# [1800]	training-rmse:1.23008	validation-rmse:1.51807
# [1850]	training-rmse:1.19970	validation-rmse:1.48636
# [1900]	training-rmse:1.17095	validation-rmse:1.45648
# [1950]	training-rmse:1.14373	validation-rmse:1.42807
# [2000]	training-rmse:1.11804	validation-rmse:1.40083
# [2050]	training-rmse:1.09378	validation-rmse:1.37564
# [2100]	training-rmse:1.07088	validation-rmse:1.35119
# [2150]	training-rmse:1.04935	validation-rmse:1.32810
# [2200]	training-rmse:1.02903	validation-rmse:1.30698
# [2250]	training-rmse:1.00992	validation-rmse:1.28691
# [2300]	training-rmse:0.99184	validation-rmse:1.26743
# [2350]	training-rmse:0.97480	validation-rmse:1.24959
# [2400]	training-rmse:0.95879	validation-rmse:1.23271
# [2450]	training-rmse:0.94367	validation-rmse:1.21692
# [2500]	training-rmse:0.92948	validation-rmse:1.20240
# [2550]	training-rmse:0.91610	validation-rmse:1.18902
# [2600]	training-rmse:0.90354	validation-rmse:1.17589
# [2650]	training-rmse:0.89161	validation-rmse:1.16377
# [2700]	training-rmse:0.88045	validation-rmse:1.15249
# [2750]	training-rmse:0.86991	validation-rmse:1.14133
# [2800]	training-rmse:0.85998	validation-rmse:1.13141
# [2850]	training-rmse:0.85063	validation-rmse:1.12187
# [2900]	training-rmse:0.84179	validation-rmse:1.11287
# [2950]	training-rmse:0.83341	validation-rmse:1.10376
# [3000]	training-rmse:0.82552	validation-rmse:1.09545
# [3050]	training-rmse:0.81808	validation-rmse:1.08778
# [3100]	training-rmse:0.81107	validation-rmse:1.08075
# [3150]	training-rmse:0.80445	validation-rmse:1.07382
# [3200]	training-rmse:0.79823	validation-rmse:1.06757
# [3250]	training-rmse:0.79235	validation-rmse:1.06154
# [3300]	training-rmse:0.78678	validation-rmse:1.05592
# [3350]	training-rmse:0.78152	validation-rmse:1.05069
# [3400]	training-rmse:0.77654	validation-rmse:1.04572
# [3450]	training-rmse:0.77181	validation-rmse:1.04137
# [3500]	training-rmse:0.76731	validation-rmse:1.03708
# [3550]	training-rmse:0.76308	validation-rmse:1.03309
# [3600]	training-rmse:0.75906	validation-rmse:1.02962
# [3650]	training-rmse:0.75523	validation-rmse:1.02645
# [3700]	training-rmse:0.75160	validation-rmse:1.02321
# [3750]	training-rmse:0.74817	validation-rmse:1.02014
# [3800]	training-rmse:0.74485	validation-rmse:1.01727
# [3850]	training-rmse:0.74169	validation-rmse:1.01481
# [3900]	training-rmse:0.73870	validation-rmse:1.01239
# [3950]	training-rmse:0.73581	validation-rmse:1.01012
# [4000]	training-rmse:0.73304	validation-rmse:1.00761
# [4050]	training-rmse:0.73040	validation-rmse:1.00550
# [4100]	training-rmse:0.72782	validation-rmse:1.00389
# [4150]	training-rmse:0.72539	validation-rmse:1.00199
# [4200]	training-rmse:0.72305	validation-rmse:1.00041
# [4250]	training-rmse:0.72078	validation-rmse:0.99856
# [4300]	training-rmse:0.71859	validation-rmse:0.99709
# [4350]	training-rmse:0.71641	validation-rmse:0.99559
# [4400]	training-rmse:0.71438	validation-rmse:0.99399
# [4450]	training-rmse:0.71236	validation-rmse:0.99240
# [4500]	training-rmse:0.71042	validation-rmse:0.99135
# [4550]	training-rmse:0.70855	validation-rmse:0.98996
# [4600]	training-rmse:0.70671	validation-rmse:0.98891
# [4650]	training-rmse:0.70491	validation-rmse:0.98779
# [4700]	training-rmse:0.70315	validation-rmse:0.98661
# [4750]	training-rmse:0.70143	validation-rmse:0.98604
# [4800]	training-rmse:0.69980	validation-rmse:0.98510
# [4850]	training-rmse:0.69817	validation-rmse:0.98426
# [4900]	training-rmse:0.69664	validation-rmse:0.98336
# [4950]	training-rmse:0.69512	validation-rmse:0.98260
# [5000]	training-rmse:0.69363	validation-rmse:0.98191
# [5050]	training-rmse:0.69216	validation-rmse:0.98108
# [5100]	training-rmse:0.69074	validation-rmse:0.98017
# [5150]	training-rmse:0.68937	validation-rmse:0.97947
# [5200]	training-rmse:0.68803	validation-rmse:0.97884
# [5250]	training-rmse:0.68674	validation-rmse:0.97818
# [5300]	training-rmse:0.68548	validation-rmse:0.97772
# [5350]	training-rmse:0.68428	validation-rmse:0.97709
# [5400]	training-rmse:0.68309	validation-rmse:0.97661
# [5450]	training-rmse:0.68195	validation-rmse:0.97596
# [5500]	training-rmse:0.68081	validation-rmse:0.97546
# [5550]	training-rmse:0.67969	validation-rmse:0.97492
# [5600]	training-rmse:0.67862	validation-rmse:0.97458
# [5650]	training-rmse:0.67764	validation-rmse:0.97420
# [5700]	training-rmse:0.67663	validation-rmse:0.97386
# [5750]	training-rmse:0.67566	validation-rmse:0.97341
# [5800]	training-rmse:0.67465	validation-rmse:0.97322
# [5850]	training-rmse:0.67370	validation-rmse:0.97261
# [5900]	training-rmse:0.67275	validation-rmse:0.97229
# [5950]	training-rmse:0.67183	validation-rmse:0.97186
# [6000]	training-rmse:0.67098	validation-rmse:0.97140
# [6050]	training-rmse:0.67013	validation-rmse:0.97097
# [6100]	training-rmse:0.66928	validation-rmse:0.97051
# [6150]	training-rmse:0.66841	validation-rmse:0.97021
# [6200]	training-rmse:0.66758	validation-rmse:0.96989
# [6250]	training-rmse:0.66675	validation-rmse:0.96972
# [6300]	training-rmse:0.66594	validation-rmse:0.96943
# [6350]	training-rmse:0.66517	validation-rmse:0.96912
# [6400]	training-rmse:0.66443	validation-rmse:0.96888
# [6450]	training-rmse:0.66365	validation-rmse:0.96865
# [6500]	training-rmse:0.66290	validation-rmse:0.96844
# [6550]	training-rmse:0.66213	validation-rmse:0.96823
# [6600]	training-rmse:0.66137	validation-rmse:0.96796
# [6650]	training-rmse:0.66055	validation-rmse:0.96783
# [6700]	training-rmse:0.65980	validation-rmse:0.96765
# [6750]	training-rmse:0.65911	validation-rmse:0.96747
# [6800]	training-rmse:0.65839	validation-rmse:0.96737
# [6843]	training-rmse:0.65775	validation-rmse:0.96744
#
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# NOW TRAINING TO PREDICT TEMPERATURE_TARGET_T_96
# [0]	training-rmse:4.41121	validation-rmse:5.17854
# [50]	training-rmse:4.23652	validation-rmse:4.97422
# [100]	training-rmse:4.06993	validation-rmse:4.77905
# [150]	training-rmse:3.91096	validation-rmse:4.59231
# [200]	training-rmse:3.75942	validation-rmse:4.41448
# [250]	training-rmse:3.61477	validation-rmse:4.24416
# [300]	training-rmse:3.47679	validation-rmse:4.08339
# [350]	training-rmse:3.34532	validation-rmse:3.92931
# [400]	training-rmse:3.21999	validation-rmse:3.78527
# [450]	training-rmse:3.10052	validation-rmse:3.64911
# [500]	training-rmse:2.98666	validation-rmse:3.52145
# [550]	training-rmse:2.87817	validation-rmse:3.39903
# [600]	training-rmse:2.77478	validation-rmse:3.28461
# [650]	training-rmse:2.67622	validation-rmse:3.17467
# [700]	training-rmse:2.58247	validation-rmse:3.07164
# [750]	training-rmse:2.49319	validation-rmse:2.97357
# [800]	training-rmse:2.40812	validation-rmse:2.88171
# [850]	training-rmse:2.32723	validation-rmse:2.79458
# [900]	training-rmse:2.25023	validation-rmse:2.71359
# [950]	training-rmse:2.17720	validation-rmse:2.63632
# [1000]	training-rmse:2.10776	validation-rmse:2.56300
# [1050]	training-rmse:2.04183	validation-rmse:2.49367
# [1100]	training-rmse:1.97920	validation-rmse:2.42774
# [1150]	training-rmse:1.91969	validation-rmse:2.36575
# [1200]	training-rmse:1.86323	validation-rmse:2.30720
# [1250]	training-rmse:1.80980	validation-rmse:2.25174
# [1300]	training-rmse:1.75900	validation-rmse:2.19935
# [1350]	training-rmse:1.71101	validation-rmse:2.14981
# [1400]	training-rmse:1.66554	validation-rmse:2.10223
# [1450]	training-rmse:1.62243	validation-rmse:2.05752
# [1500]	training-rmse:1.58169	validation-rmse:2.01505
# [1550]	training-rmse:1.54322	validation-rmse:1.97502
# [1600]	training-rmse:1.50685	validation-rmse:1.93707
# [1650]	training-rmse:1.47245	validation-rmse:1.90155
# [1700]	training-rmse:1.44005	validation-rmse:1.86873
# [1750]	training-rmse:1.40943	validation-rmse:1.83733
# [1800]	training-rmse:1.38055	validation-rmse:1.80707
# [1850]	training-rmse:1.35332	validation-rmse:1.77933
# [1900]	training-rmse:1.32747	validation-rmse:1.75359
# [1950]	training-rmse:1.30307	validation-rmse:1.72949
# [2000]	training-rmse:1.28016	validation-rmse:1.70622
# [2050]	training-rmse:1.25850	validation-rmse:1.68440
# [2100]	training-rmse:1.23802	validation-rmse:1.66354
# [2150]	training-rmse:1.21886	validation-rmse:1.64309
# [2200]	training-rmse:1.20069	validation-rmse:1.62391
# [2250]	training-rmse:1.18352	validation-rmse:1.60666
# [2300]	training-rmse:1.16732	validation-rmse:1.58945
# [2350]	training-rmse:1.15204	validation-rmse:1.57358
# [2400]	training-rmse:1.13767	validation-rmse:1.55846
# [2450]	training-rmse:1.12412	validation-rmse:1.54401
# [2500]	training-rmse:1.11128	validation-rmse:1.53055
# [2550]	training-rmse:1.09913	validation-rmse:1.51783
# [2600]	training-rmse:1.08770	validation-rmse:1.50505
# [2650]	training-rmse:1.07684	validation-rmse:1.49387
# [2700]	training-rmse:1.06658	validation-rmse:1.48304
# [2750]	training-rmse:1.05681	validation-rmse:1.47333
# [2800]	training-rmse:1.04769	validation-rmse:1.46333
# [2850]	training-rmse:1.03900	validation-rmse:1.45418
# [2900]	training-rmse:1.03073	validation-rmse:1.44584
# [2950]	training-rmse:1.02278	validation-rmse:1.43819
# [3000]	training-rmse:1.01535	validation-rmse:1.43099
# [3050]	training-rmse:1.00822	validation-rmse:1.42431
# [3100]	training-rmse:1.00145	validation-rmse:1.41795
# [3150]	training-rmse:0.99499	validation-rmse:1.41186
# [3200]	training-rmse:0.98889	validation-rmse:1.40633
# [3250]	training-rmse:0.98302	validation-rmse:1.40058
# [3300]	training-rmse:0.97743	validation-rmse:1.39555
# [3350]	training-rmse:0.97213	validation-rmse:1.39050
# [3400]	training-rmse:0.96698	validation-rmse:1.38568
# [3450]	training-rmse:0.96212	validation-rmse:1.38158
# [3500]	training-rmse:0.95743	validation-rmse:1.37740
# [3550]	training-rmse:0.95291	validation-rmse:1.37322
# [3600]	training-rmse:0.94860	validation-rmse:1.36953
# [3650]	training-rmse:0.94449	validation-rmse:1.36593
# [3700]	training-rmse:0.94055	validation-rmse:1.36257
# [3750]	training-rmse:0.93669	validation-rmse:1.35944
# [3800]	training-rmse:0.93293	validation-rmse:1.35611
# [3850]	training-rmse:0.92930	validation-rmse:1.35320
# [3900]	training-rmse:0.92580	validation-rmse:1.35025
# [3950]	training-rmse:0.92248	validation-rmse:1.34750
# [4000]	training-rmse:0.91913	validation-rmse:1.34493
# [4050]	training-rmse:0.91588	validation-rmse:1.34238
# [4100]	training-rmse:0.91268	validation-rmse:1.33999
# [4150]	training-rmse:0.90961	validation-rmse:1.33767
# [4200]	training-rmse:0.90665	validation-rmse:1.33546
# [4250]	training-rmse:0.90372	validation-rmse:1.33390
# [4300]	training-rmse:0.90090	validation-rmse:1.33253
# [4350]	training-rmse:0.89810	validation-rmse:1.33073
# [4400]	training-rmse:0.89533	validation-rmse:1.32920
# [4450]	training-rmse:0.89268	validation-rmse:1.32763
# [4500]	training-rmse:0.89003	validation-rmse:1.32629
# [4550]	training-rmse:0.88746	validation-rmse:1.32530
# [4600]	training-rmse:0.88500	validation-rmse:1.32427
# [4650]	training-rmse:0.88251	validation-rmse:1.32310
# [4700]	training-rmse:0.88010	validation-rmse:1.32232
# [4750]	training-rmse:0.87770	validation-rmse:1.32139
# [4800]	training-rmse:0.87540	validation-rmse:1.32044
# [4850]	training-rmse:0.87320	validation-rmse:1.31946
# [4900]	training-rmse:0.87105	validation-rmse:1.31891
# [4950]	training-rmse:0.86890	validation-rmse:1.31805
# [5000]	training-rmse:0.86680	validation-rmse:1.31737
# [5050]	training-rmse:0.86482	validation-rmse:1.31645
# [5100]	training-rmse:0.86283	validation-rmse:1.31561
# [5150]	training-rmse:0.86081	validation-rmse:1.31486
# [5200]	training-rmse:0.85879	validation-rmse:1.31413
# [5250]	training-rmse:0.85700	validation-rmse:1.31363
# [5300]	training-rmse:0.85515	validation-rmse:1.31306
# [5350]	training-rmse:0.85334	validation-rmse:1.31228
# [5400]	training-rmse:0.85161	validation-rmse:1.31177
# [5450]	training-rmse:0.84983	validation-rmse:1.31109
# [5500]	training-rmse:0.84809	validation-rmse:1.31054
# [5550]	training-rmse:0.84642	validation-rmse:1.31012
# [5600]	training-rmse:0.84491	validation-rmse:1.30954
# [5650]	training-rmse:0.84336	validation-rmse:1.30903
# [5700]	training-rmse:0.84175	validation-rmse:1.30887
# [5750]	training-rmse:0.84022	validation-rmse:1.30831
# [5800]	training-rmse:0.83861	validation-rmse:1.30822
# [5850]	training-rmse:0.83710	validation-rmse:1.30795
# [5900]	training-rmse:0.83555	validation-rmse:1.30773
# [5950]	training-rmse:0.83407	validation-rmse:1.30723
# [6000]	training-rmse:0.83264	validation-rmse:1.30677
# [6050]	training-rmse:0.83127	validation-rmse:1.30663
# [6100]	training-rmse:0.82988	validation-rmse:1.30636
# [6150]	training-rmse:0.82850	validation-rmse:1.30621
# [6200]	training-rmse:0.82713	validation-rmse:1.30604
# [6250]	training-rmse:0.82572	validation-rmse:1.30597
# [6300]	training-rmse:0.82443	validation-rmse:1.30586
# [6350]	training-rmse:0.82308	validation-rmse:1.30562
# [6400]	training-rmse:0.82187	validation-rmse:1.30518
# [6450]	training-rmse:0.82062	validation-rmse:1.30492
# [6500]	training-rmse:0.81943	validation-rmse:1.30466
# [6550]	training-rmse:0.81815	validation-rmse:1.30443
# [6600]	training-rmse:0.81697	validation-rmse:1.30409
# [6650]	training-rmse:0.81582	validation-rmse:1.30383
# [6700]	training-rmse:0.81467	validation-rmse:1.30373
# [6750]	training-rmse:0.81352	validation-rmse:1.30341
# [6800]	training-rmse:0.81233	validation-rmse:1.30330
# [6850]	training-rmse:0.81113	validation-rmse:1.30336
# [6856]	training-rmse:0.81098	validation-rmse:1.30329

# %% [markdown]
# ## 9. Generate Predictions and Evaluate Performance

# %%
# Create a dictionary containing training predictions
y_pred_train_dict = {}
for target in targets:
    y_pred_train_dict[target] = xgboost_model_dict[target].predict(dmatrices_train_dict[target])

# Create a dictionary containing validation predictions
y_pred_val_dict = {}
for target in targets:
    y_pred_val_dict[target] = xgboost_model_dict[target].predict(dmatrices_val_dict[target])

# Create a dictionary containing testing predictions
y_pred_test_dict = {}
for target in targets:
    y_pred_test_dict[target] = xgboost_model_dict[target].predict(dmatrices_test_dict[target])

# %%
# Evaluate predictions against targets for each water quality variable and forecast horizon on training, validation, and testing sets
for target in targets:
    print(f"\nTRAINING PERFORMANCE FOR {target.upper()}:")
    print(bchf.compute_performance_metrics(y_obs=y_train_dict[target],
                                           y_pred=y_pred_train_dict[target]))
    print(f"VALIDATION PERFORMANCE FOR {target.upper()}:")
    print(bchf.compute_performance_metrics(y_obs=y_val_dict[target],
                                           y_pred=y_pred_val_dict[target]))
    print(f"TEST PERFORMANCE FOR {target.upper()}:")
    print(bchf.compute_performance_metrics(y_obs=y_test_dict[target],
                                           y_pred=y_pred_test_dict[target]))
    print("---------------------------------------------------------------")
# Out:
# TRAINING PERFORMANCE FOR AMMONIUM_TARGET_T_1:
# {'MSE': 0.04349208250641823, 'RMSE': 0.20854754745960236, 'MAE': 0.0430632010102272, 'r^2': 0.8422492742538452, 'NSE': np.float32(0.8422493)}
# VALIDATION PERFORMANCE FOR AMMONIUM_TARGET_T_1:
# {'MSE': 0.00023950253671500832, 'RMSE': 0.015475869178771973, 'MAE': 0.010351194068789482, 'r^2': 0.913816511631012, 'NSE': np.float32(0.9138165)}
# TEST PERFORMANCE FOR AMMONIUM_TARGET_T_1:
# {'MSE': 0.0003400336136110127, 'RMSE': 0.01844000071287155, 'MAE': 0.011951280757784843, 'r^2': 0.7870752215385437, 'NSE': np.float32(0.7870752)}
# ---------------------------------------------------------------
#
# TRAINING PERFORMANCE FOR AMMONIUM_TARGET_T_2:
# {'MSE': 0.0450732484459877, 'RMSE': 0.21230460703372955, 'MAE': 0.044465504586696625, 'r^2': 0.8365138173103333, 'NSE': np.float32(0.8365138)}
# VALIDATION PERFORMANCE FOR AMMONIUM_TARGET_T_2:
# {'MSE': 0.0002761228824965656, 'RMSE': 0.0166169460862875, 'MAE': 0.011086646467447281, 'r^2': 0.9006342887878418, 'NSE': np.float32(0.9006343)}
# TEST PERFORMANCE FOR AMMONIUM_TARGET_T_2:
# {'MSE': 0.00038796276203356683, 'RMSE': 0.01969677023589611, 'MAE': 0.012830648571252823, 'r^2': 0.7571011781692505, 'NSE': np.float32(0.7571012)}
# ---------------------------------------------------------------
#
# TRAINING PERFORMANCE FOR AMMONIUM_TARGET_T_4:
# {'MSE': 0.04625368490815163, 'RMSE': 0.21506670117378235, 'MAE': 0.04608220234513283, 'r^2': 0.832231342792511, 'NSE': np.float32(0.83223134)}
# VALIDATION PERFORMANCE FOR AMMONIUM_TARGET_T_4:
# {'MSE': 0.0003315796493552625, 'RMSE': 0.01820932887494564, 'MAE': 0.011897414922714233, 'r^2': 0.8806664943695068, 'NSE': np.float32(0.8806665)}
# TEST PERFORMANCE FOR AMMONIUM_TARGET_T_4:
# {'MSE': 0.0005253700073808432, 'RMSE': 0.02292095124721527, 'MAE': 0.01423716451972723, 'r^2': 0.6711766719818115, 'NSE': np.float32(0.6711767)}
# ---------------------------------------------------------------
#
# TRAINING PERFORMANCE FOR AMMONIUM_TARGET_T_24:
# {'MSE': 0.04746215417981148, 'RMSE': 0.21785810589790344, 'MAE': 0.05220457538962364, 'r^2': 0.8278390169143677, 'NSE': np.float32(0.827839)}
# VALIDATION PERFORMANCE FOR AMMONIUM_TARGET_T_24:
# {'MSE': 0.000800096895545721, 'RMSE': 0.028285983949899673, 'MAE': 0.017628908157348633, 'r^2': 0.7116672396659851, 'NSE': np.float32(0.71166724)}
# TEST PERFORMANCE FOR AMMONIUM_TARGET_T_24:
# {'MSE': 0.023294921964406967, 'RMSE': 0.15262673795223236, 'MAE': 0.05082792043685913, 'r^2': -13.533425331115723, 'NSE': np.float32(-13.533425)}
# ---------------------------------------------------------------
#
# TRAINING PERFORMANCE FOR AMMONIUM_TARGET_T_48:
# {'MSE': 0.055236078798770905, 'RMSE': 0.23502357304096222, 'MAE': 0.06038782000541687, 'r^2': 0.7996262311935425, 'NSE': np.float32(0.79962623)}
# VALIDATION PERFORMANCE FOR AMMONIUM_TARGET_T_48:
# {'MSE': 0.000975799688603729, 'RMSE': 0.03123779222369194, 'MAE': 0.019754737615585327, 'r^2': 0.6477519273757935, 'NSE': np.float32(0.6477519)}
# TEST PERFORMANCE FOR AMMONIUM_TARGET_T_48:
# {'MSE': 0.10830830037593842, 'RMSE': 0.3291022777557373, 'MAE': 0.09161273390054703, 'r^2': -66.35350799560547, 'NSE': np.float32(-66.35351)}
# ---------------------------------------------------------------
#
# TRAINING PERFORMANCE FOR AMMONIUM_TARGET_T_96:
# {'MSE': 0.0848330557346344, 'RMSE': 0.29126113653182983, 'MAE': 0.07594508677721024, 'r^2': 0.6922200918197632, 'NSE': np.float32(0.6922201)}
# VALIDATION PERFORMANCE FOR AMMONIUM_TARGET_T_96:
# {'MSE': 0.0018948321230709553, 'RMSE': 0.04352967068552971, 'MAE': 0.03218049183487892, 'r^2': 0.3132537007331848, 'NSE': np.float32(0.3132537)}
# TEST PERFORMANCE FOR AMMONIUM_TARGET_T_96:
# {'MSE': 0.03965495899319649, 'RMSE': 0.19913552701473236, 'MAE': 0.06419184803962708, 'r^2': -23.550479888916016, 'NSE': np.float32(-23.55048)}
# ---------------------------------------------------------------
#
# TRAINING PERFORMANCE FOR OXYGEN_CONC_TARGET_T_1:
# {'MSE': 0.018126502633094788, 'RMSE': 0.13463470339775085, 'MAE': 0.06294839084148407, 'r^2': 0.996001660823822, 'NSE': np.float32(0.99600166)}
# VALIDATION PERFORMANCE FOR OXYGEN_CONC_TARGET_T_1:
# {'MSE': 0.019572261720895767, 'RMSE': 0.13990089297294617, 'MAE': 0.08346544951200485, 'r^2': 0.9956327676773071, 'NSE': np.float32(0.99563277)}
# TEST PERFORMANCE FOR OXYGEN_CONC_TARGET_T_1:
# {'MSE': 0.006452829111367464, 'RMSE': 0.08032950013875961, 'MAE': 0.04181917384266853, 'r^2': 0.9977099299430847, 'NSE': np.float32(0.99770993)}
# ---------------------------------------------------------------
#
# TRAINING PERFORMANCE FOR OXYGEN_CONC_TARGET_T_2:
# {'MSE': 0.02564583532512188, 'RMSE': 0.1601431667804718, 'MAE': 0.08363235741853714, 'r^2': 0.9943428635597229, 'NSE': np.float32(0.99434286)}
# VALIDATION PERFORMANCE FOR OXYGEN_CONC_TARGET_T_2:
# {'MSE': 0.0333760604262352, 'RMSE': 0.18269115686416626, 'MAE': 0.11260264366865158, 'r^2': 0.9925528168678284, 'NSE': np.float32(0.9925528)}
# TEST PERFORMANCE FOR OXYGEN_CONC_TARGET_T_2:
# {'MSE': 0.00983450561761856, 'RMSE': 0.09916907548904419, 'MAE': 0.05738792195916176, 'r^2': 0.9965102672576904, 'NSE': np.float32(0.99651027)}
# ---------------------------------------------------------------
#
# TRAINING PERFORMANCE FOR OXYGEN_CONC_TARGET_T_4:
# {'MSE': 0.04374938830733299, 'RMSE': 0.20916354656219482, 'MAE': 0.12343215197324753, 'r^2': 0.9903488755226135, 'NSE': np.float32(0.9903489)}
# VALIDATION PERFORMANCE FOR OXYGEN_CONC_TARGET_T_4:
# {'MSE': 0.07286915183067322, 'RMSE': 0.26994287967681885, 'MAE': 0.1764110028743744, 'r^2': 0.9837411046028137, 'NSE': np.float32(0.9837411)}
# TEST PERFORMANCE FOR OXYGEN_CONC_TARGET_T_4:
# {'MSE': 0.02216915972530842, 'RMSE': 0.14889311790466309, 'MAE': 0.09413818269968033, 'r^2': 0.9921354651451111, 'NSE': np.float32(0.99213547)}
# ---------------------------------------------------------------
#
# TRAINING PERFORMANCE FOR OXYGEN_CONC_TARGET_T_24:
# {'MSE': 0.17069612443447113, 'RMSE': 0.41315388679504395, 'MAE': 0.2940260171890259, 'r^2': 0.9623318314552307, 'NSE': np.float32(0.96233183)}
# VALIDATION PERFORMANCE FOR OXYGEN_CONC_TARGET_T_24:
# {'MSE': 0.373945415019989, 'RMSE': 0.6115107536315918, 'MAE': 0.4488656222820282, 'r^2': 0.9166584014892578, 'NSE': np.float32(0.9166584)}
# TEST PERFORMANCE FOR OXYGEN_CONC_TARGET_T_24:
# {'MSE': 0.11696352064609528, 'RMSE': 0.3419992923736572, 'MAE': 0.25016650557518005, 'r^2': 0.958524227142334, 'NSE': np.float32(0.9585242)}
# ---------------------------------------------------------------
#
# TRAINING PERFORMANCE FOR OXYGEN_CONC_TARGET_T_48:
# {'MSE': 0.1884477585554123, 'RMSE': 0.43410569429397583, 'MAE': 0.2991560101509094, 'r^2': 0.9584059119224548, 'NSE': np.float32(0.9584059)}
# VALIDATION PERFORMANCE FOR OXYGEN_CONC_TARGET_T_48:
# {'MSE': 0.39999720454216003, 'RMSE': 0.6324533224105835, 'MAE': 0.45577022433280945, 'r^2': 0.9110081195831299, 'NSE': np.float32(0.9110081)}
# TEST PERFORMANCE FOR OXYGEN_CONC_TARGET_T_48:
# {'MSE': 0.17280352115631104, 'RMSE': 0.4156964421272278, 'MAE': 0.2937980592250824, 'r^2': 0.9387083649635315, 'NSE': np.float32(0.93870836)}
# ---------------------------------------------------------------
#
# TRAINING PERFORMANCE FOR OXYGEN_CONC_TARGET_T_96:
# {'MSE': 0.37256038188934326, 'RMSE': 0.6103772521018982, 'MAE': 0.41647714376449585, 'r^2': 0.9177349209785461, 'NSE': np.float32(0.9177349)}
# VALIDATION PERFORMANCE FOR OXYGEN_CONC_TARGET_T_96:
# {'MSE': 0.8216612935066223, 'RMSE': 0.9064553380012512, 'MAE': 0.6724413633346558, 'r^2': 0.817658543586731, 'NSE': np.float32(0.81765854)}
# TEST PERFORMANCE FOR OXYGEN_CONC_TARGET_T_96:
# {'MSE': 0.36213254928588867, 'RMSE': 0.6017745137214661, 'MAE': 0.4443245530128479, 'r^2': 0.8717283606529236, 'NSE': np.float32(0.87172836)}
# ---------------------------------------------------------------
#
# TRAINING PERFORMANCE FOR TEMPERATURE_TARGET_T_1:
# {'MSE': 0.015766168013215065, 'RMSE': 0.12556339800357819, 'MAE': 0.06823798269033432, 'r^2': 0.9991862177848816, 'NSE': np.float32(0.9991862)}
# VALIDATION PERFORMANCE FOR TEMPERATURE_TARGET_T_1:
# {'MSE': 0.06872370094060898, 'RMSE': 0.2621520459651947, 'MAE': 0.10400664061307907, 'r^2': 0.9974240064620972, 'NSE': np.float32(0.997424)}
# TEST PERFORMANCE FOR TEMPERATURE_TARGET_T_1:
# {'MSE': 0.008931760676205158, 'RMSE': 0.09450799226760864, 'MAE': 0.05813288316130638, 'r^2': 0.9995498657226562, 'NSE': np.float32(0.99954987)}
# ---------------------------------------------------------------
#
# TRAINING PERFORMANCE FOR TEMPERATURE_TARGET_T_2:
# {'MSE': 0.029602468013763428, 'RMSE': 0.17205367982387543, 'MAE': 0.10070856660604477, 'r^2': 0.9984720945358276, 'NSE': np.float32(0.9984721)}
# VALIDATION PERFORMANCE FOR TEMPERATURE_TARGET_T_2:
# {'MSE': 0.08568874001502991, 'RMSE': 0.29272639751434326, 'MAE': 0.14145907759666443, 'r^2': 0.9967880249023438, 'NSE': np.float32(0.996788)}
# TEST PERFORMANCE FOR TEMPERATURE_TARGET_T_2:
# {'MSE': 0.01590799354016781, 'RMSE': 0.12612690031528473, 'MAE': 0.08500336110591888, 'r^2': 0.9991980791091919, 'NSE': np.float32(0.9991981)}
# ---------------------------------------------------------------
#
# TRAINING PERFORMANCE FOR TEMPERATURE_TARGET_T_4:
# {'MSE': 0.06321324408054352, 'RMSE': 0.2514224350452423, 'MAE': 0.16125373542308807, 'r^2': 0.9967375993728638, 'NSE': np.float32(0.9967376)}
# VALIDATION PERFORMANCE FOR TEMPERATURE_TARGET_T_4:
# {'MSE': 0.1352711319923401, 'RMSE': 0.3677922487258911, 'MAE': 0.21857422590255737, 'r^2': 0.994929313659668, 'NSE': np.float32(0.9949293)}
# TEST PERFORMANCE FOR TEMPERATURE_TARGET_T_4:
# {'MSE': 0.03685653954744339, 'RMSE': 0.19198057055473328, 'MAE': 0.13837015628814697, 'r^2': 0.9981412291526794, 'NSE': np.float32(0.9981412)}
# ---------------------------------------------------------------
#
# TRAINING PERFORMANCE FOR TEMPERATURE_TARGET_T_24:
# {'MSE': 0.3350623548030853, 'RMSE': 0.5788456797599792, 'MAE': 0.43301334977149963, 'r^2': 0.9827259182929993, 'NSE': np.float32(0.9827259)}
# VALIDATION PERFORMANCE FOR TEMPERATURE_TARGET_T_24:
# {'MSE': 0.7870911359786987, 'RMSE': 0.8871815800666809, 'MAE': 0.6662527918815613, 'r^2': 0.9704911708831787, 'NSE': np.float32(0.9704912)}
# TEST PERFORMANCE FOR TEMPERATURE_TARGET_T_24:
# {'MSE': 0.3370543122291565, 'RMSE': 0.5805637836456299, 'MAE': 0.4532533288002014, 'r^2': 0.9829149842262268, 'NSE': np.float32(0.982915)}
# ---------------------------------------------------------------
#
# TRAINING PERFORMANCE FOR TEMPERATURE_TARGET_T_48:
# {'MSE': 0.432634562253952, 'RMSE': 0.657749593257904, 'MAE': 0.4945754110813141, 'r^2': 0.9777370095252991, 'NSE': np.float32(0.977737)}
# VALIDATION PERFORMANCE FOR TEMPERATURE_TARGET_T_48:
# {'MSE': 0.9359325170516968, 'RMSE': 0.9674360752105713, 'MAE': 0.7422043681144714, 'r^2': 0.9648474454879761, 'NSE': np.float32(0.96484745)}
# TEST PERFORMANCE FOR TEMPERATURE_TARGET_T_48:
# {'MSE': 0.5531226992607117, 'RMSE': 0.7437222003936768, 'MAE': 0.5835347175598145, 'r^2': 0.9718191623687744, 'NSE': np.float32(0.97181916)}
# ---------------------------------------------------------------
#
# TRAINING PERFORMANCE FOR TEMPERATURE_TARGET_T_96:
# {'MSE': 0.6576862335205078, 'RMSE': 0.8109785914421082, 'MAE': 0.6192312836647034, 'r^2': 0.9662556648254395, 'NSE': np.float32(0.96625566)}
# VALIDATION PERFORMANCE FOR TEMPERATURE_TARGET_T_96:
# {'MSE': 1.698560118675232, 'RMSE': 1.303288221359253, 'MAE': 1.0316925048828125, 'r^2': 0.9361342191696167, 'NSE': np.float32(0.9361342)}
# TEST PERFORMANCE FOR TEMPERATURE_TARGET_T_96:
# {'MSE': 1.060253381729126, 'RMSE': 1.0296860933303833, 'MAE': 0.8175638318061829, 'r^2': 0.9452933073043823, 'NSE': np.float32(0.9452933)}
# ---------------------------------------------------------------

# %% [markdown]
# ##10. Plot XGBoost Model Predictions Against Observations

# %%
# Create a list of ammonium_targets
NUM_VARIABLES = 3 # 3 target variables: ammonium, dissolved oxygen, and temperature
ammonium_targets = targets[:int(len(targets)/3)]

# Create a figure and sets of axes to plot ammonium predictions against observations
N_ROWS = 2
fig, axes = plt.subplots(nrows=N_ROWS, ncols=int(len(ammonium_targets)/N_ROWS), figsize=(40, 20))
axes = axes.flatten()  # flatten 2D array of axes for indexing

# Loop through ammonium targets for plotting
for i, target in enumerate(ammonium_targets):
    ax = axes[i]

    # Compute the forecast horizon for offsetting prediction plots to match time index
    horizon = int(target.split('_')[-1])

    # Plot observed data
    ax.scatter(df_train.index, y_train_dict[target], color='gray', s=10, alpha=0.5, label='Observed (Training Data)')
    ax.scatter(df_val.index, y_val_dict[target], color='gray', s=10, alpha=0.5, label='Observed (Validation Data)')
    ax.scatter(df_test.index, y_test_dict[target], color='gray', s=10, alpha=0.5, label='Observed (Testing Data)')

    # Plot predictions
    ax.plot(df_train.index[horizon:], y_pred_train_dict[target][:-horizon], color="tab:blue", label="Predicted (Training Data)")
    ax.plot(df_val.index[horizon:], y_pred_val_dict[target][:-horizon], color="tab:orange", label="Predicted (Validation Data)")
    ax.plot(df_test.index[horizon:], y_pred_test_dict[target][:-horizon], color="tab:green", label="Predicted (Testing Data)")

    # Customize the plot
    horizon = target.split('_')[-1]
    ax.set_title(f"Observed vs Predicted Ammonium (t+{horizon})")
    ax.set_xlabel("DateTime")
    ax.set_ylabel("Ammonium (mg/L)")
    ax.legend()
    ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Create a list of dissolved oxygen targets
oxygen_targets = targets[int(len(targets)/3):int(2*len(targets)/3)]

# Create a figure and sets of axes to plot ammonium predictions against observations
N_ROWS = 2
fig, axes = plt.subplots(nrows=N_ROWS, ncols=int(len(oxygen_targets)/N_ROWS), figsize=(40, 20))
axes = axes.flatten()  # flatten 2D array of axes for indexing

# Loop through ammonium targets for plotting
for i, target in enumerate(oxygen_targets):
    ax = axes[i]

    # Compute the forecast horizon for offsetting prediction plots to match time index
    horizon = int(target.split('_')[-1])

    # Plot observed data
    ax.scatter(df_train.index, y_train_dict[target], color='gray', s=10, alpha=0.5, label='Observed (Training Data)')
    ax.scatter(df_val.index, y_val_dict[target], color='gray', s=10, alpha=0.5, label='Observed (Validation Data)')
    ax.scatter(df_test.index, y_test_dict[target], color='gray', s=10, alpha=0.5, label='Observed (Testing Data)')

    # Plot predictions
    ax.plot(df_train.index[horizon:], y_pred_train_dict[target][:-horizon], color="tab:blue", label="Predicted (Training Data)")
    ax.plot(df_val.index[horizon:], y_pred_val_dict[target][:-horizon], color="tab:orange", label="Predicted (Validation Data)")
    ax.plot(df_test.index[horizon:], y_pred_test_dict[target][:-horizon], color="tab:green", label="Predicted (Testing Data)")

    # Customize the plot
    horizon = target.split('_')[-1]
    ax.set_title(f"Observed vs Predicted Dissolved Oxygen (t+{horizon})")
    ax.set_xlabel("DateTime")
    ax.set_ylabel("Dissolved Oxygen (mg/L)")
    ax.legend()
    ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Create a list of temperature targets
temperature_targets = targets[-int(len(targets)/3):]

# Create a figure and sets of axes to plot ammonium predictions against observations
N_ROWS = 2
fig, axes = plt.subplots(nrows=N_ROWS, ncols=int(len(temperature_targets)/N_ROWS), figsize=(40, 20))
axes = axes.flatten()  # flatten 2D array of axes for indexing

# Loop through temperature targets for plotting
for i, target in enumerate(temperature_targets):
    ax = axes[i]

    # Compute the forecast horizon for offsetting prediction plots to match time index
    horizon = int(target.split('_')[-1])

    # Plot observed data
    ax.scatter(df_train.index, y_train_dict[target], color='gray', s=10, alpha=0.5, label='Observed (Training Data)')
    ax.scatter(df_val.index, y_val_dict[target], color='gray', s=10, alpha=0.5, label='Observed (Validation Data)')
    ax.scatter(df_test.index, y_test_dict[target], color='gray', s=10, alpha=0.5, label='Observed (Testing Data)')

    # Plot predictions
    ax.plot(df_train.index[horizon:], y_pred_train_dict[target][:-horizon], color="tab:blue", label="Predicted (Training Data)")
    ax.plot(df_val.index[horizon:], y_pred_val_dict[target][:-horizon], color="tab:orange", label="Predicted (Validation Data)")
    ax.plot(df_test.index[horizon:], y_pred_test_dict[target][:-horizon], color="tab:green", label="Predicted (Testing Data)")

    # Customize the plot
    horizon = target.split('_')[-1]
    ax.set_title(f"Observed vs Predicted Temperature (t+{horizon})")
    ax.set_xlabel("DateTime")
    ax.set_ylabel("Temperature (°C)")
    ax.legend()
    ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()
