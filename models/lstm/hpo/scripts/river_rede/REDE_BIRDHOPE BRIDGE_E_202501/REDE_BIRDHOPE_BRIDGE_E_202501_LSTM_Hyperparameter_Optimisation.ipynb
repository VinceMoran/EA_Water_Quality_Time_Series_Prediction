# %% [markdown]
# # 0. Station Information
#
# * Station name: REDE_BIRDHOPE BRIDGE_E_202501
# * Water Quality Data link: https://environment.data.gov.uk/hydrology/station/E96999A

# %% [markdown]
# ## 0. Import the Relevant Libraries

# %%
# Force installation of Syne-Tune and a compatible NumPy version (may require restarting the session after running this cell before running below import cell)
# !pip install numpy==1.26.1 syne_tune --force-reinstall -q # ignore potential error messages if listed dependencies do not match imports
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 26.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.3/254.3 kB 26.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 69.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 112.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 129.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/131.7 MB 17.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 31.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 27.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 27.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 56.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.6/293.6 MB 3.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.1 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.1 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# music21 9.9.1 requires numpy>=1.26.4, but you have numpy 1.26.1 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.1 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# datasets 4.0.0 requires dill<0.3.9,>=0.3.0, but you have dill 0.4.1 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.1 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.1 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.1 which is incompatible.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.1 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.1 which is incompatible.
# torch 2.10.0+cu128 requires nvidia-nccl-cu12==2.27.5; platform_system == "Linux", but you have nvidia-nccl-cu12 2.29.7 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.1 which is incompatible.

# %%
# Import relevant libraries (Note: May require running of above cell to ensure compatibility of NumPy and Syne-Tune)
import torch
import logging
logging.basicConfig(level=logging.INFO)
import numpy as np
import matplotlib.pyplot as plt
from syne_tune import StoppingCriterion, Tuner
from syne_tune.backend.python_backend.python_backend import PythonBackend
from syne_tune.config_space import loguniform, randint, choice, uniform
from syne_tune.experiments import load_experiment
from syne_tune.optimizer.baselines import ASHA
import pandas as pd
from pathlib import Path

# %% [markdown]
# ##1. Specify Epoch Ranges and Reduction Factor for Hyperparameter Optimisation (HPO)

# %%
# Specify the minimum and maximum number of epochs for which a trial is allowed to run during HPO
min_number_of_epochs = 2
max_number_of_epochs = 10

# Define the reduction factor for the Asynchronous Successive Halving Algorithm (ASHA)
eta = 2 # Set to 2 so that 50% of trials are stopped at each rung of the scheduler

# %% [markdown]
# ##2. Define the Tune Function to Optimise Hyperparameters for Ammonium Prediction

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on ammonium_t_96 targets
def ammonium_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Load the raw data from the project GitHub into a Pandas DataFrame and set index as DateTime
    # Create the path to the directory containing the data in the Jupyter notebook environment
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/river_rede/REDE_BIRDHOPE%20BRIDGE_E_202501/REDE_BIRDHOPE%20BRIDGE_E_202501_preprocessed_data.zip")
    # Assign the full filepath for the preprocessed data
    parameter_path = "/content" / data_path / "REDE_BIRDHOPE BRIDGE_E_202501_preprocessed_data.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "ammonium"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ## 3. Define the Configuration Space for Hyperparameter Search

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %% [markdown]
# ##4. Define the Resources Available for HPO

# %%
# Define the number of parallel workers available to evaluate trials concurrently
n_workers = max(1, torch.cuda.device_count()) # Uses all available GPUs for parallel trials or defaults to 1 worker if running on CPU

# Define the maximum number of trials to test
max_number_of_trials = 30

# Define the stopping criterion for HPO
stop_criterion = StoppingCriterion(max_num_trials_started=max_number_of_trials)

# %% [markdown]
# ##5. Define Asynchronous Successive Halving Algorithm (ASHA) for HPO

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %% [markdown]
# ##6. Initialise and Run the Tuner for Ammonium HPO

# %%
# Instruct the searcher to run each trial as a Python function
trial_backend = PythonBackend(
    tune_function=ammonium_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-20-11-08-37-789
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-20-11-08-37-789
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-20-11-08-37-789
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [11:08:44] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     1        0.00001           64           2      0.2       0.00001      1          0.096778     8.244313
# 1 trials running, 0 finished (0 until the end), 20.14s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:09:19] ✅ Trial 0 completed!
# [11:09:19] 🚀 Trial 1 started - config: learning_rate=1.590979997380116e-05, num_hiddens=128, num_layers=3, dropout=0.20059915807159914, weight_decay=8.489140148554235e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.072613    25.344761
#         1 InProgress     0       0.000016          128           3 0.200599      0.000085      -                 -            -
# 1 trials running, 1 finished (1 until the end), 40.17s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.072613    25.344761
#         1 InProgress     6       0.000016          128           3 0.200599      0.000085      6          0.060585    15.840828
# 1 trials running, 1 finished (1 until the end), 60.19s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:09:49] 🚀 Trial 2 started - config: learning_rate=5.990063769678054e-05, num_hiddens=32, num_layers=2, dropout=0.24095077056943603, weight_decay=0.00042317557972539727
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085     10          0.056295    25.512719
#         2 InProgress     2       0.000060           32           2 0.240951      0.000423      2          0.075117     5.680855
# 1 trials running, 2 finished (1 until the end), 80.23s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:10:19] ✅ Trial 2 completed!
# [11:10:19] 🚀 Trial 3 started - config: learning_rate=5.042325857097877e-05, num_hiddens=64, num_layers=2, dropout=0.222225940037871, weight_decay=0.00029691106704218237
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085   10.0          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423   10.0          0.061698    21.142078
#         3 InProgress     0       0.000050           64           2 0.222226      0.000297      -                 -            -
# 1 trials running, 3 finished (2 until the end), 100.25s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:10:29] 🚀 Trial 4 started - config: learning_rate=9.607569219065732e-05, num_hiddens=128, num_layers=4, dropout=0.4221222425530798, weight_decay=6.790135775781374e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085     10          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423     10          0.061698    21.142078
#         3    Stopped     2       0.000050           64           2 0.222226      0.000297      2          0.079817     5.366509
#         4 InProgress     1       0.000096          128           4 0.422122      0.000068      1          0.064614     4.450118
# 1 trials running, 4 finished (2 until the end), 120.27s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085     10          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423     10          0.061698    21.142078
#         3    Stopped     2       0.000050           64           2 0.222226      0.000297      2          0.079817     5.366509
#         4 InProgress     9       0.000096          128           4 0.422122      0.000068      9          0.057437    25.892886
# 1 trials running, 4 finished (2 until the end), 140.31s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:11:04] ✅ Trial 4 completed!
# [11:11:04] 🚀 Trial 5 started - config: learning_rate=1.4679439406829051e-05, num_hiddens=256, num_layers=3, dropout=0.3237268071793888, weight_decay=0.00029504495997266576
# [11:11:19] 🚀 Trial 6 started - config: learning_rate=2.0718138190764357e-05, num_hiddens=32, num_layers=4, dropout=0.4993335393001823, weight_decay=3.495265989801926e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085   10.0          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423   10.0          0.061698    21.142078
#         3    Stopped     2       0.000050           64           2 0.222226      0.000297    2.0          0.079817     5.366509
#         4  Completed    10       0.000096          128           4 0.422122      0.000068   10.0          0.057906    28.587044
#         5    Stopped     1       0.000015          256           3 0.323727      0.000295    1.0          0.098646     7.719277
#         6 InProgress     0       0.000021           32           4 0.499334      0.000035      -                 -            -
# 1 trials running, 6 finished (3 until the end), 160.34s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:11:34] 🚀 Trial 7 started - config: learning_rate=1.639259779226197e-05, num_hiddens=64, num_layers=3, dropout=0.45376289128597236, weight_decay=5.530614612694427e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085   10.0          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423   10.0          0.061698    21.142078
#         3    Stopped     2       0.000050           64           2 0.222226      0.000297    2.0          0.079817     5.366509
#         4  Completed    10       0.000096          128           4 0.422122      0.000068   10.0          0.057906    28.587044
#         5    Stopped     1       0.000015          256           3 0.323727      0.000295    1.0          0.098646     7.719277
#         6    Stopped     4       0.000021           32           4 0.499334      0.000035    4.0          0.098065    10.350353
#         7 InProgress     0       0.000016           64           3 0.453763      0.000055      -                 -            -
# 1 trials running, 7 finished (3 until the end), 180.36s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:11:44] 🚀 Trial 8 started - config: learning_rate=1.0256421653604186e-05, num_hiddens=64, num_layers=2, dropout=0.4129838282206304, weight_decay=6.61269862630649e-05
# [11:11:54] 🚀 Trial 9 started - config: learning_rate=0.00026669744520350566, num_hiddens=32, num_layers=2, dropout=0.21155894588460697, weight_decay=1.9279240287807182e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085   10.0          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423   10.0          0.061698    21.142078
#         3    Stopped     2       0.000050           64           2 0.222226      0.000297    2.0          0.079817     5.366509
#         4  Completed    10       0.000096          128           4 0.422122      0.000068   10.0          0.057906    28.587044
#         5    Stopped     1       0.000015          256           3 0.323727      0.000295    1.0          0.098646     7.719277
#         6    Stopped     4       0.000021           32           4 0.499334      0.000035    4.0          0.098065    10.350353
#         7    Stopped     2       0.000016           64           3 0.453763      0.000055    2.0          0.101640     5.847695
#         8    Stopped     2       0.000010           64           2 0.412984      0.000066    2.0          0.104427     5.384960
#         9 InProgress     0       0.000267           32           2 0.211559      0.000019      -                 -            -
# 1 trials running, 9 finished (3 until the end), 200.39s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:12:19] 🚀 Trial 10 started - config: learning_rate=1.0455786756220823e-05, num_hiddens=64, num_layers=2, dropout=0.37593008403549505, weight_decay=0.00013267506483002707
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085   10.0          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423   10.0          0.061698    21.142078
#         3    Stopped     2       0.000050           64           2 0.222226      0.000297    2.0          0.079817     5.366509
#         4  Completed    10       0.000096          128           4 0.422122      0.000068   10.0          0.057906    28.587044
#         5    Stopped     1       0.000015          256           3 0.323727      0.000295    1.0          0.098646     7.719277
#         6    Stopped     4       0.000021           32           4 0.499334      0.000035    4.0          0.098065    10.350353
#         7    Stopped     2       0.000016           64           3 0.453763      0.000055    2.0          0.101640     5.847695
#         8    Stopped     2       0.000010           64           2 0.412984      0.000066    2.0          0.104427     5.384960
#         9    Stopped    10       0.000267           32           2 0.211559      0.000019   10.0          0.051095    20.445382
#        10 InProgress     0       0.000010           64           2 0.375930      0.000133      -                 -            -
# 1 trials running, 10 finished (3 until the end), 220.42s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:12:29] 🚀 Trial 11 started - config: learning_rate=1.0632719506085787e-05, num_hiddens=256, num_layers=4, dropout=0.31959075108159124, weight_decay=1.1487605218388005e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085   10.0          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423   10.0          0.061698    21.142078
#         3    Stopped     2       0.000050           64           2 0.222226      0.000297    2.0          0.079817     5.366509
#         4  Completed    10       0.000096          128           4 0.422122      0.000068   10.0          0.057906    28.587044
#         5    Stopped     1       0.000015          256           3 0.323727      0.000295    1.0          0.098646     7.719277
#         6    Stopped     4       0.000021           32           4 0.499334      0.000035    4.0          0.098065    10.350353
#         7    Stopped     2       0.000016           64           3 0.453763      0.000055    2.0          0.101640     5.847695
#         8    Stopped     2       0.000010           64           2 0.412984      0.000066    2.0          0.104427     5.384960
#         9    Stopped    10       0.000267           32           2 0.211559      0.000019   10.0          0.051095    20.445382
#        10    Stopped     2       0.000010           64           2 0.375930      0.000133    2.0          0.104472     5.353315
#        11 InProgress     0       0.000011          256           4 0.319591      0.000011      -                 -            -
# 1 trials running, 11 finished (3 until the end), 240.45s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:12:44] 🚀 Trial 12 started - config: learning_rate=5.494056371554791e-05, num_hiddens=256, num_layers=4, dropout=0.472402700679085, weight_decay=1.409821415885957e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085     10          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423     10          0.061698    21.142078
#         3    Stopped     2       0.000050           64           2 0.222226      0.000297      2          0.079817     5.366509
#         4  Completed    10       0.000096          128           4 0.422122      0.000068     10          0.057906    28.587044
#         5    Stopped     1       0.000015          256           3 0.323727      0.000295      1          0.098646     7.719277
#         6    Stopped     4       0.000021           32           4 0.499334      0.000035      4          0.098065    10.350353
#         7    Stopped     2       0.000016           64           3 0.453763      0.000055      2          0.101640     5.847695
#         8    Stopped     2       0.000010           64           2 0.412984      0.000066      2          0.104427     5.384960
#         9    Stopped    10       0.000267           32           2 0.211559      0.000019     10          0.051095    20.445382
#        10    Stopped     2       0.000010           64           2 0.375930      0.000133      2          0.104472     5.353315
#        11    Stopped     1       0.000011          256           4 0.319591      0.000011      1          0.100511     9.110962
#        12 InProgress     1       0.000055          256           4 0.472403      0.000014      1          0.062550     9.122448
# 1 trials running, 12 finished (3 until the end), 260.50s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085     10          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423     10          0.061698    21.142078
#         3    Stopped     2       0.000050           64           2 0.222226      0.000297      2          0.079817     5.366509
#         4  Completed    10       0.000096          128           4 0.422122      0.000068     10          0.057906    28.587044
#         5    Stopped     1       0.000015          256           3 0.323727      0.000295      1          0.098646     7.719277
#         6    Stopped     4       0.000021           32           4 0.499334      0.000035      4          0.098065    10.350353
#         7    Stopped     2       0.000016           64           3 0.453763      0.000055      2          0.101640     5.847695
#         8    Stopped     2       0.000010           64           2 0.412984      0.000066      2          0.104427     5.384960
#         9    Stopped    10       0.000267           32           2 0.211559      0.000019     10          0.051095    20.445382
#        10    Stopped     2       0.000010           64           2 0.375930      0.000133      2          0.104472     5.353315
#        11    Stopped     1       0.000011          256           4 0.319591      0.000011      1          0.100511     9.110962
#        12 InProgress     4       0.000055          256           4 0.472403      0.000014      4          0.060547    29.796088
# 1 trials running, 12 finished (3 until the end), 280.53s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085     10          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423     10          0.061698    21.142078
#         3    Stopped     2       0.000050           64           2 0.222226      0.000297      2          0.079817     5.366509
#         4  Completed    10       0.000096          128           4 0.422122      0.000068     10          0.057906    28.587044
#         5    Stopped     1       0.000015          256           3 0.323727      0.000295      1          0.098646     7.719277
#         6    Stopped     4       0.000021           32           4 0.499334      0.000035      4          0.098065    10.350353
#         7    Stopped     2       0.000016           64           3 0.453763      0.000055      2          0.101640     5.847695
#         8    Stopped     2       0.000010           64           2 0.412984      0.000066      2          0.104427     5.384960
#         9    Stopped    10       0.000267           32           2 0.211559      0.000019     10          0.051095    20.445382
#        10    Stopped     2       0.000010           64           2 0.375930      0.000133      2          0.104472     5.353315
#        11    Stopped     1       0.000011          256           4 0.319591      0.000011      1          0.100511     9.110962
#        12 InProgress     7       0.000055          256           4 0.472403      0.000014      7          0.048880    50.683495
# 1 trials running, 12 finished (3 until the end), 300.56s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085     10          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423     10          0.061698    21.142078
#         3    Stopped     2       0.000050           64           2 0.222226      0.000297      2          0.079817     5.366509
#         4  Completed    10       0.000096          128           4 0.422122      0.000068     10          0.057906    28.587044
#         5    Stopped     1       0.000015          256           3 0.323727      0.000295      1          0.098646     7.719277
#         6    Stopped     4       0.000021           32           4 0.499334      0.000035      4          0.098065    10.350353
#         7    Stopped     2       0.000016           64           3 0.453763      0.000055      2          0.101640     5.847695
#         8    Stopped     2       0.000010           64           2 0.412984      0.000066      2          0.104427     5.384960
#         9    Stopped    10       0.000267           32           2 0.211559      0.000019     10          0.051095    20.445382
#        10    Stopped     2       0.000010           64           2 0.375930      0.000133      2          0.104472     5.353315
#        11    Stopped     1       0.000011          256           4 0.319591      0.000011      1          0.100511     9.110962
#        12 InProgress     9       0.000055          256           4 0.472403      0.000014      9          0.049166    64.604549
# 1 trials running, 12 finished (3 until the end), 320.58s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:14:04] ✅ Trial 12 completed!
# [11:14:04] 🚀 Trial 13 started - config: learning_rate=8.874562740068007e-05, num_hiddens=256, num_layers=4, dropout=0.3397920854286568, weight_decay=0.00019323599495558907
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085     10          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423     10          0.061698    21.142078
#         3    Stopped     2       0.000050           64           2 0.222226      0.000297      2          0.079817     5.366509
#         4  Completed    10       0.000096          128           4 0.422122      0.000068     10          0.057906    28.587044
#         5    Stopped     1       0.000015          256           3 0.323727      0.000295      1          0.098646     7.719277
#         6    Stopped     4       0.000021           32           4 0.499334      0.000035      4          0.098065    10.350353
#         7    Stopped     2       0.000016           64           3 0.453763      0.000055      2          0.101640     5.847695
#         8    Stopped     2       0.000010           64           2 0.412984      0.000066      2          0.104427     5.384960
#         9    Stopped    10       0.000267           32           2 0.211559      0.000019     10          0.051095    20.445382
#        10    Stopped     2       0.000010           64           2 0.375930      0.000133      2          0.104472     5.353315
#        11    Stopped     1       0.000011          256           4 0.319591      0.000011      1          0.100511     9.110962
#        12  Completed    10       0.000055          256           4 0.472403      0.000014     10          0.051055    71.540276
#        13 InProgress     1       0.000089          256           4 0.339792      0.000193      1          0.058802     9.327168
# 1 trials running, 13 finished (4 until the end), 340.63s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:14:35] 🚀 Trial 14 started - config: learning_rate=8.661257484446848e-05, num_hiddens=128, num_layers=3, dropout=0.208147867287582, weight_decay=2.759015173831358e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085   10.0          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423   10.0          0.061698    21.142078
#         3    Stopped     2       0.000050           64           2 0.222226      0.000297    2.0          0.079817     5.366509
#         4  Completed    10       0.000096          128           4 0.422122      0.000068   10.0          0.057906    28.587044
#         5    Stopped     1       0.000015          256           3 0.323727      0.000295    1.0          0.098646     7.719277
#         6    Stopped     4       0.000021           32           4 0.499334      0.000035    4.0          0.098065    10.350353
#         7    Stopped     2       0.000016           64           3 0.453763      0.000055    2.0          0.101640     5.847695
#         8    Stopped     2       0.000010           64           2 0.412984      0.000066    2.0          0.104427     5.384960
#         9    Stopped    10       0.000267           32           2 0.211559      0.000019   10.0          0.051095    20.445382
#        10    Stopped     2       0.000010           64           2 0.375930      0.000133    2.0          0.104472     5.353315
#        11    Stopped     1       0.000011          256           4 0.319591      0.000011    1.0          0.100511     9.110962
#        12  Completed    10       0.000055          256           4 0.472403      0.000014   10.0          0.051055    71.540276
#        13    Stopped     3       0.000089          256           4 0.339792      0.000193    3.0          0.059722    23.346469
#        14 InProgress     0       0.000087          128           3 0.208148      0.000028      -                 -            -
# 1 trials running, 14 finished (4 until the end), 360.66s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085     10          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423     10          0.061698    21.142078
#         3    Stopped     2       0.000050           64           2 0.222226      0.000297      2          0.079817     5.366509
#         4  Completed    10       0.000096          128           4 0.422122      0.000068     10          0.057906    28.587044
#         5    Stopped     1       0.000015          256           3 0.323727      0.000295      1          0.098646     7.719277
#         6    Stopped     4       0.000021           32           4 0.499334      0.000035      4          0.098065    10.350353
#         7    Stopped     2       0.000016           64           3 0.453763      0.000055      2          0.101640     5.847695
#         8    Stopped     2       0.000010           64           2 0.412984      0.000066      2          0.104427     5.384960
#         9    Stopped    10       0.000267           32           2 0.211559      0.000019     10          0.051095    20.445382
#        10    Stopped     2       0.000010           64           2 0.375930      0.000133      2          0.104472     5.353315
#        11    Stopped     1       0.000011          256           4 0.319591      0.000011      1          0.100511     9.110962
#        12  Completed    10       0.000055          256           4 0.472403      0.000014     10          0.051055    71.540276
#        13    Stopped     3       0.000089          256           4 0.339792      0.000193      3          0.059722    23.346469
#        14 InProgress     8       0.000087          128           3 0.208148      0.000028      8          0.060326    20.788744
# 1 trials running, 14 finished (4 until the end), 380.71s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:15:05] 🚀 Trial 15 started - config: learning_rate=2.3651414905122792e-05, num_hiddens=128, num_layers=2, dropout=0.27852256179762264, weight_decay=0.00029982106313025924
# [11:15:15] 🚀 Trial 16 started - config: learning_rate=1.5497117779766287e-05, num_hiddens=64, num_layers=3, dropout=0.316600332843908, weight_decay=4.381717735326023e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085   10.0          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423   10.0          0.061698    21.142078
#         3    Stopped     2       0.000050           64           2 0.222226      0.000297    2.0          0.079817     5.366509
#         4  Completed    10       0.000096          128           4 0.422122      0.000068   10.0          0.057906    28.587044
#         5    Stopped     1       0.000015          256           3 0.323727      0.000295    1.0          0.098646     7.719277
#         6    Stopped     4       0.000021           32           4 0.499334      0.000035    4.0          0.098065    10.350353
#         7    Stopped     2       0.000016           64           3 0.453763      0.000055    2.0          0.101640     5.847695
#         8    Stopped     2       0.000010           64           2 0.412984      0.000066    2.0          0.104427     5.384960
#         9    Stopped    10       0.000267           32           2 0.211559      0.000019   10.0          0.051095    20.445382
#        10    Stopped     2       0.000010           64           2 0.375930      0.000133    2.0          0.104472     5.353315
#        11    Stopped     1       0.000011          256           4 0.319591      0.000011    1.0          0.100511     9.110962
#        12  Completed    10       0.000055          256           4 0.472403      0.000014   10.0          0.051055    71.540276
#        13    Stopped     3       0.000089          256           4 0.339792      0.000193    3.0          0.059722    23.346469
#        14    Stopped    10       0.000087          128           3 0.208148      0.000028   10.0          0.059392    25.618613
#        15    Stopped     2       0.000024          128           2 0.278523      0.000300    2.0          0.078055     5.779171
#        16 InProgress     0       0.000015           64           3 0.316600      0.000044      -                 -            -
# 1 trials running, 16 finished (4 until the end), 400.74s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:15:25] 🚀 Trial 17 started - config: learning_rate=2.4925176984659488e-05, num_hiddens=128, num_layers=3, dropout=0.3364323672399273, weight_decay=0.00013636791676593018
# [11:15:35] 🚀 Trial 18 started - config: learning_rate=2.1331070638913802e-05, num_hiddens=32, num_layers=4, dropout=0.478503468246784, weight_decay=0.00011043031075006369
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085   10.0          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423   10.0          0.061698    21.142078
#         3    Stopped     2       0.000050           64           2 0.222226      0.000297    2.0          0.079817     5.366509
#         4  Completed    10       0.000096          128           4 0.422122      0.000068   10.0          0.057906    28.587044
#         5    Stopped     1       0.000015          256           3 0.323727      0.000295    1.0          0.098646     7.719277
#         6    Stopped     4       0.000021           32           4 0.499334      0.000035    4.0          0.098065    10.350353
#         7    Stopped     2       0.000016           64           3 0.453763      0.000055    2.0          0.101640     5.847695
#         8    Stopped     2       0.000010           64           2 0.412984      0.000066    2.0          0.104427     5.384960
#         9    Stopped    10       0.000267           32           2 0.211559      0.000019   10.0          0.051095    20.445382
#        10    Stopped     2       0.000010           64           2 0.375930      0.000133    2.0          0.104472     5.353315
#        11    Stopped     1       0.000011          256           4 0.319591      0.000011    1.0          0.100511     9.110962
#        12  Completed    10       0.000055          256           4 0.472403      0.000014   10.0          0.051055    71.540276
#        13    Stopped     3       0.000089          256           4 0.339792      0.000193    3.0          0.059722    23.346469
#        14    Stopped    10       0.000087          128           3 0.208148      0.000028   10.0          0.059392    25.618613
#        15    Stopped     2       0.000024          128           2 0.278523      0.000300    2.0          0.078055     5.779171
#        16    Stopped     2       0.000015           64           3 0.316600      0.000044    2.0          0.101244     5.865849
#        17    Stopped     1       0.000025          128           3 0.336432      0.000136    1.0          0.091460     4.157329
#        18 InProgress     0       0.000021           32           4 0.478503      0.000110      -                 -            -
# 1 trials running, 18 finished (4 until the end), 420.77s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:15:45] 🚀 Trial 19 started - config: learning_rate=1.9609938717056264e-05, num_hiddens=256, num_layers=3, dropout=0.40794933908011055, weight_decay=1.0494199914169437e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085     10          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423     10          0.061698    21.142078
#         3    Stopped     2       0.000050           64           2 0.222226      0.000297      2          0.079817     5.366509
#         4  Completed    10       0.000096          128           4 0.422122      0.000068     10          0.057906    28.587044
#         5    Stopped     1       0.000015          256           3 0.323727      0.000295      1          0.098646     7.719277
#         6    Stopped     4       0.000021           32           4 0.499334      0.000035      4          0.098065    10.350353
#         7    Stopped     2       0.000016           64           3 0.453763      0.000055      2          0.101640     5.847695
#         8    Stopped     2       0.000010           64           2 0.412984      0.000066      2          0.104427     5.384960
#         9    Stopped    10       0.000267           32           2 0.211559      0.000019     10          0.051095    20.445382
#        10    Stopped     2       0.000010           64           2 0.375930      0.000133      2          0.104472     5.353315
#        11    Stopped     1       0.000011          256           4 0.319591      0.000011      1          0.100511     9.110962
#        12  Completed    10       0.000055          256           4 0.472403      0.000014     10          0.051055    71.540276
#        13    Stopped     3       0.000089          256           4 0.339792      0.000193      3          0.059722    23.346469
#        14    Stopped    10       0.000087          128           3 0.208148      0.000028     10          0.059392    25.618613
#        15    Stopped     2       0.000024          128           2 0.278523      0.000300      2          0.078055     5.779171
#        16    Stopped     2       0.000015           64           3 0.316600      0.000044      2          0.101244     5.865849
#        17    Stopped     1       0.000025          128           3 0.336432      0.000136      1          0.091460     4.157329
#        18    Stopped     2       0.000021           32           4 0.478503      0.000110      2          0.107172     5.993201
#        19 InProgress     1       0.000020          256           3 0.407949      0.000010      1          0.090033     7.722468
# 1 trials running, 19 finished (4 until the end), 440.83s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:16:10] 🚀 Trial 20 started - config: learning_rate=0.00015659321320845895, num_hiddens=32, num_layers=2, dropout=0.35521994899361625, weight_decay=1.5262634243335105e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085     10          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423     10          0.061698    21.142078
#         3    Stopped     2       0.000050           64           2 0.222226      0.000297      2          0.079817     5.366509
#         4  Completed    10       0.000096          128           4 0.422122      0.000068     10          0.057906    28.587044
#         5    Stopped     1       0.000015          256           3 0.323727      0.000295      1          0.098646     7.719277
#         6    Stopped     4       0.000021           32           4 0.499334      0.000035      4          0.098065    10.350353
#         7    Stopped     2       0.000016           64           3 0.453763      0.000055      2          0.101640     5.847695
#         8    Stopped     2       0.000010           64           2 0.412984      0.000066      2          0.104427     5.384960
#         9    Stopped    10       0.000267           32           2 0.211559      0.000019     10          0.051095    20.445382
#        10    Stopped     2       0.000010           64           2 0.375930      0.000133      2          0.104472     5.353315
#        11    Stopped     1       0.000011          256           4 0.319591      0.000011      1          0.100511     9.110962
#        12  Completed    10       0.000055          256           4 0.472403      0.000014     10          0.051055    71.540276
#        13    Stopped     3       0.000089          256           4 0.339792      0.000193      3          0.059722    23.346469
#        14    Stopped    10       0.000087          128           3 0.208148      0.000028     10          0.059392    25.618613
#        15    Stopped     2       0.000024          128           2 0.278523      0.000300      2          0.078055     5.779171
#        16    Stopped     2       0.000015           64           3 0.316600      0.000044      2          0.101244     5.865849
#        17    Stopped     1       0.000025          128           3 0.336432      0.000136      1          0.091460     4.157329
#        18    Stopped     2       0.000021           32           4 0.478503      0.000110      2          0.107172     5.993201
#        19    Stopped     3       0.000020          256           3 0.407949      0.000010      3          0.062832    18.921640
#        20 InProgress     2       0.000157           32           2 0.355220      0.000015      2          0.058517     5.399769
# 1 trials running, 20 finished (4 until the end), 460.86s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:16:35] 🚀 Trial 21 started - config: learning_rate=0.00019932203738016205, num_hiddens=128, num_layers=2, dropout=0.20277726773591448, weight_decay=1.0858353380028363e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.072613    25.344761
#         1    Stopped    10       0.000016          128           3 0.200599      0.000085   10.0          0.056295    25.512719
#         2  Completed    10       0.000060           32           2 0.240951      0.000423   10.0          0.061698    21.142078
#         3    Stopped     2       0.000050           64           2 0.222226      0.000297    2.0          0.079817     5.366509
#         4  Completed    10       0.000096          128           4 0.422122      0.000068   10.0          0.057906    28.587044
#         5    Stopped     1       0.000015          256           3 0.323727      0.000295    1.0          0.098646     7.719277
#         6    Stopped     4       0.000021           32           4 0.499334      0.000035    4.0          0.098065    10.350353
#         7    Stopped     2       0.000016           64           3 0.453763      0.000055    2.0          0.101640     5.847695
#         8    Stopped     2       0.000010           64           2 0.412984      0.000066    2.0          0.104427     5.384960
#         9    Stopped    10       0.000267           32           2 0.211559      0.000019   10.0          0.051095    20.445382
#        10    Stopped     2       0.000010           64           2 0.375930      0.000133    2.0          0.104472     5.353315
#        11    Stopped     1       0.000011          256           4 0.319591      0.000011    1.0          0.100511     9.110962
#        12  Completed    10       0.000055          256           4 0.472403      0.000014   10.0          0.051055    71.540276
#        13    Stopped     3       0.000089          256           4 0.339792      0.000193    3.0          0.059722    23.346469
#        14    Stopped    10       0.000087          128           3 0.208148      0.000028   10.0          0.059392    25.618613
#        15    Stopped     2       0.000024          128           2 0.278523      0.000300    2.0          0.078055     5.779171
#        16    Stopped     2       0.000015           64           3 0.316600      0.000044    2.0          0.101244     5.865849
#        17    Stopped     1       0.000025          128           3 0.336432      0.000136    1.0          0.091460     4.157329
#        18    Stopped     2       0.000021           32           4 0.478503      0.000110    2.0          0.107172     5.993201
#        19    Stopped     3       0.000020          256           3 0.407949      0.000010    3.0          0.062832    18.921640
#        20    Stopped    10       0.000157           32           2 0.355220      0.000015   10.0          0.052132    20.680630
#        21 InProgress     0       0.000199          128           2 0.202777      0.000011      -                 -            -
# 1 trials running, 21 finished (4 until the end), 480.90s wallclock-time
#        11    Stopped     1       0.000011          256           4 0.319591      0.000011    1.0          0.100511     9.110962
#        12  Completed    10       0.000055          256           4 0.472403      0.000014   10.0          0.051055    71.540276
#        13    Stopped     3       0.000089          256           4 0.339792      0.000193    3.0          0.059722    23.346469
#        14    Stopped    10       0.000087          128           3 0.208148      0.000028   10.0          0.059392    25.618613
#        15    Stopped     2       0.000024          128           2 0.278523      0.000300    2.0          0.078055     5.779171
#        16    Stopped     2       0.000015           64           3 0.316600      0.000044    2.0          0.101244     5.865849
#        17    Stopped     1       0.000025          128           3 0.336432      0.000136    1.0          0.091460     4.157329
#        18    Stopped     2       0.000021           32           4 0.478503      0.000110    2.0          0.107172     5.993201
#        19    Stopped     3       0.000020          256           3 0.407949      0.000010    3.0          0.062832    18.921640
#        20    Stopped    10       0.000157           32           2 0.355220      0.000015   10.0          0.052132    20.680630
#        21    Stopped     4       0.000199          128           2 0.202777      0.000011    4.0          0.052522     9.709850
#        22    Stopped     1       0.000013          256           4 0.382774      0.000427    1.0          0.106478     9.190019
#        23    Stopped     3       0.000190          128           3 0.227056      0.000166    3.0          0.059631     8.806613
#        24  Completed    10       0.000216           64           4 0.496424      0.000053   10.0          0.055264    24.893903
#        25    Stopped     2       0.000015           32           2 0.374589      0.000364    2.0          0.094527     5.408609
#        26    Stopped     2       0.000043           32           2 0.468886      0.000202    2.0          0.080735     5.365901
#        27    Stopped     4       0.000201           64           4 0.462180      0.000118    4.0          0.052163    10.775639
#        28    Stopped     2       0.000040           64           2 0.239524      0.000054    2.0          0.081155     5.357353
#        29    Stopped     9       0.000036          256           2 0.249118      0.000077    9.0          0.067381    40.936980
#        30 InProgress     0       0.000011          128           2 0.408619      0.000060      -                 -            -
# 1 trials running, 30 finished (5 until the end), 636.28s wallclock-time
#
# validation_error: best 0.04887957498431206 for trial-id 12
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-20-11-08-37-789
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-20-11-08-37-789
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##7. Load Results from HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
ammonium_results_path = "/root/syne-tune/python-entrypoint-2026-03-20-11-08-37-789/results.csv.zip"

# Save the results to a Pandas DataFrame
ammonium_results = pd.read_csv(ammonium_results_path)

# %% [markdown]
# ##8. Save the Ammonium HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
ammonium_hpo_results_path = Path("/content/REDE_BIRDHOPE BRIDGE_E_202501_ammonium_hpo_results.csv")

# Save the DataFrame to a csv file
ammonium_results.to_csv(ammonium_hpo_results_path, index=True)

# %% [markdown]
# ## 9. Define the Config Space, Scheduler, and Tune Function for Dissolved Oxygen HPO

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on ammonium_t_96 targets
def oxygen_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Load the raw data from the project GitHub into a Pandas DataFrame and set index as DateTime
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/river_rede/REDE_BIRDHOPE%20BRIDGE_E_202501/REDE_BIRDHOPE%20BRIDGE_E_202501_preprocessed_data.zip")
    # Assign the full filepath for the preprocessed data
    parameter_path = "/content" / data_path / "REDE_BIRDHOPE BRIDGE_E_202501_preprocessed_data.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "oxygen_conc"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ##10. Initialise and Run the Tuner for Oxygen HPO

# %%
# Instruct the searcher to run each trial as a Python function
oxygen_trial_backend = PythonBackend(
    tune_function=oxygen_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=oxygen_trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-20-11-21-49-909
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-20-11-21-49-909
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-20-11-21-49-909
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [11:21:50] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     4        0.00001           64           2      0.2       0.00001      4          0.110579     9.243448
# 1 trials running, 0 finished (0 until the end), 20.02s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:22:20] ✅ Trial 0 completed!
# [11:22:20] 🚀 Trial 1 started - config: learning_rate=0.00013132979357061925, num_hiddens=64, num_layers=3, dropout=0.2924556064988414, weight_decay=0.0001316594479576609
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.054838    21.090533
#         1 InProgress     0       0.000131           64           3 0.292456      0.000132      -                 -            -
# 1 trials running, 1 finished (1 until the end), 40.04s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.054838    21.090533
#         1 InProgress     9       0.000131           64           3 0.292456      0.000132      9          0.050431    20.559377
# 1 trials running, 1 finished (1 until the end), 60.06s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:22:50] ✅ Trial 1 completed!
# [11:22:50] 🚀 Trial 2 started - config: learning_rate=0.00021751723911083587, num_hiddens=256, num_layers=2, dropout=0.3291902827664436, weight_decay=4.9767728365506336e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.054838    21.090533
#         1  Completed    10       0.000131           64           3 0.292456      0.000132     10          0.050046    22.689732
#         2 InProgress     2       0.000218          256           2 0.329190      0.000050      2          0.049254    10.507532
# 1 trials running, 2 finished (2 until the end), 80.09s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.054838    21.090533
#         1  Completed    10       0.000131           64           3 0.292456      0.000132     10          0.050046    22.689732
#         2 InProgress     6       0.000218          256           2 0.329190      0.000050      6          0.072434    27.650696
# 1 trials running, 2 finished (2 until the end), 100.11s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:23:35] 🚀 Trial 3 started - config: learning_rate=0.00014177107690979687, num_hiddens=128, num_layers=3, dropout=0.49903788629598184, weight_decay=0.0001057468984368445
# [11:23:45] 🚀 Trial 4 started - config: learning_rate=0.0002743670759927051, num_hiddens=128, num_layers=2, dropout=0.35606605234492184, weight_decay=0.0004170277179328411
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.054838    21.090533
#         1  Completed    10       0.000131           64           3 0.292456      0.000132   10.0          0.050046    22.689732
#         2    Stopped     9       0.000218          256           2 0.329190      0.000050    9.0          0.083117    40.758078
#         3    Stopped     1       0.000142          128           3 0.499038      0.000106    1.0          0.064623     4.093693
#         4 InProgress     0       0.000274          128           2 0.356066      0.000417      -                 -            -
# 1 trials running, 4 finished (2 until the end), 120.14s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.054838    21.090533
#         1  Completed    10       0.000131           64           3 0.292456      0.000132     10          0.050046    22.689732
#         2    Stopped     9       0.000218          256           2 0.329190      0.000050      9          0.083117    40.758078
#         3    Stopped     1       0.000142          128           3 0.499038      0.000106      1          0.064623     4.093693
#         4 InProgress     7       0.000274          128           2 0.356066      0.000417      7          0.055815    16.010655
# 1 trials running, 4 finished (2 until the end), 140.16s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:24:10] 🚀 Trial 5 started - config: learning_rate=0.00029592126197069545, num_hiddens=64, num_layers=4, dropout=0.24719726146001167, weight_decay=1.8730821943724185e-05
# [11:24:20] 🚀 Trial 6 started - config: learning_rate=0.00027127064839217355, num_hiddens=64, num_layers=2, dropout=0.44676305217331813, weight_decay=0.00012124708176323368
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.054838    21.090533
#         1  Completed    10       0.000131           64           3 0.292456      0.000132   10.0          0.050046    22.689732
#         2    Stopped     9       0.000218          256           2 0.329190      0.000050    9.0          0.083117    40.758078
#         3    Stopped     1       0.000142          128           3 0.499038      0.000106    1.0          0.064623     4.093693
#         4    Stopped     9       0.000274          128           2 0.356066      0.000417    9.0          0.084457    20.098052
#         5    Stopped     1       0.000296           64           4 0.247197      0.000019    1.0          0.053793     4.014325
#         6 InProgress     0       0.000271           64           2 0.446763      0.000121      -                 -            -
# 1 trials running, 6 finished (2 until the end), 160.19s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:24:35] 🚀 Trial 7 started - config: learning_rate=0.00012059727226611139, num_hiddens=128, num_layers=2, dropout=0.31354977492003566, weight_decay=4.5695252158449315e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.054838    21.090533
#         1  Completed    10       0.000131           64           3 0.292456      0.000132     10          0.050046    22.689732
#         2    Stopped     9       0.000218          256           2 0.329190      0.000050      9          0.083117    40.758078
#         3    Stopped     1       0.000142          128           3 0.499038      0.000106      1          0.064623     4.093693
#         4    Stopped     9       0.000274          128           2 0.356066      0.000417      9          0.084457    20.098052
#         5    Stopped     1       0.000296           64           4 0.247197      0.000019      1          0.053793     4.014325
#         6    Stopped     5       0.000271           64           2 0.446763      0.000121      5          0.083927    11.002010
#         7 InProgress     2       0.000121          128           2 0.313550      0.000046      2          0.046461     5.696755
# 1 trials running, 7 finished (2 until the end), 180.23s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:24:50] 🚀 Trial 8 started - config: learning_rate=4.878973287662997e-05, num_hiddens=64, num_layers=4, dropout=0.2510745049098321, weight_decay=2.2600108577118715e-05
# [11:25:00] 🚀 Trial 9 started - config: learning_rate=0.0004901085665935473, num_hiddens=32, num_layers=4, dropout=0.3823648578125659, weight_decay=3.240027319680113e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.054838    21.090533
#         1  Completed    10       0.000131           64           3 0.292456      0.000132   10.0          0.050046    22.689732
#         2    Stopped     9       0.000218          256           2 0.329190      0.000050    9.0          0.083117    40.758078
#         3    Stopped     1       0.000142          128           3 0.499038      0.000106    1.0          0.064623     4.093693
#         4    Stopped     9       0.000274          128           2 0.356066      0.000417    9.0          0.084457    20.098052
#         5    Stopped     1       0.000296           64           4 0.247197      0.000019    1.0          0.053793     4.014325
#         6    Stopped     5       0.000271           64           2 0.446763      0.000121    5.0          0.083927    11.002010
#         7    Stopped     4       0.000121          128           2 0.313550      0.000046    4.0          0.046830     9.675146
#         8    Stopped     1       0.000049           64           4 0.251075      0.000023    1.0          0.060955     4.022012
#         9 InProgress     0       0.000490           32           4 0.382365      0.000032      -                 -            -
# 1 trials running, 9 finished (2 until the end), 200.27s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:25:10] 🚀 Trial 10 started - config: learning_rate=1.873795733470471e-05, num_hiddens=32, num_layers=2, dropout=0.25277734914595207, weight_decay=0.0001945144012997803
# [11:25:20] 🚀 Trial 11 started - config: learning_rate=0.00034113079029312053, num_hiddens=32, num_layers=4, dropout=0.31169154407878175, weight_decay=0.00015206613398287782
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.054838    21.090533
#         1  Completed    10       0.000131           64           3 0.292456      0.000132   10.0          0.050046    22.689732
#         2    Stopped     9       0.000218          256           2 0.329190      0.000050    9.0          0.083117    40.758078
#         3    Stopped     1       0.000142          128           3 0.499038      0.000106    1.0          0.064623     4.093693
#         4    Stopped     9       0.000274          128           2 0.356066      0.000417    9.0          0.084457    20.098052
#         5    Stopped     1       0.000296           64           4 0.247197      0.000019    1.0          0.053793     4.014325
#         6    Stopped     5       0.000271           64           2 0.446763      0.000121    5.0          0.083927    11.002010
#         7    Stopped     4       0.000121          128           2 0.313550      0.000046    4.0          0.046830     9.675146
#         8    Stopped     1       0.000049           64           4 0.251075      0.000023    1.0          0.060955     4.022012
#         9    Stopped     2       0.000490           32           4 0.382365      0.000032    2.0          0.062304     6.059541
#        10    Stopped     2       0.000019           32           2 0.252777      0.000195    2.0          0.141903     5.408071
#        11 InProgress     0       0.000341           32           4 0.311692      0.000152      -                 -            -
# 1 trials running, 11 finished (2 until the end), 220.31s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:25:30] 🚀 Trial 12 started - config: learning_rate=0.0001297123049837034, num_hiddens=32, num_layers=4, dropout=0.473952650864312, weight_decay=0.000346691891370976
# [11:25:40] 🚀 Trial 13 started - config: learning_rate=8.350881343776162e-05, num_hiddens=64, num_layers=3, dropout=0.47909077059247085, weight_decay=0.00015666164153017796
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.054838    21.090533
#         1  Completed    10       0.000131           64           3 0.292456      0.000132   10.0          0.050046    22.689732
#         2    Stopped     9       0.000218          256           2 0.329190      0.000050    9.0          0.083117    40.758078
#         3    Stopped     1       0.000142          128           3 0.499038      0.000106    1.0          0.064623     4.093693
#         4    Stopped     9       0.000274          128           2 0.356066      0.000417    9.0          0.084457    20.098052
#         5    Stopped     1       0.000296           64           4 0.247197      0.000019    1.0          0.053793     4.014325
#         6    Stopped     5       0.000271           64           2 0.446763      0.000121    5.0          0.083927    11.002010
#         7    Stopped     4       0.000121          128           2 0.313550      0.000046    4.0          0.046830     9.675146
#         8    Stopped     1       0.000049           64           4 0.251075      0.000023    1.0          0.060955     4.022012
#         9    Stopped     2       0.000490           32           4 0.382365      0.000032    2.0          0.062304     6.059541
#        10    Stopped     2       0.000019           32           2 0.252777      0.000195    2.0          0.141903     5.408071
#        11    Stopped     2       0.000341           32           4 0.311692      0.000152    2.0          0.059342     6.041671
#        12    Stopped     2       0.000130           32           4 0.473953      0.000347    2.0          0.061005     6.026281
#        13 InProgress     0       0.000084           64           3 0.479091      0.000157      -                 -            -
# 1 trials running, 13 finished (2 until the end), 240.34s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:25:50] 🚀 Trial 14 started - config: learning_rate=1.458334528910133e-05, num_hiddens=128, num_layers=3, dropout=0.2721510472995348, weight_decay=0.0004411306534329188
# [11:26:00] 🚀 Trial 15 started - config: learning_rate=1.868847174013562e-05, num_hiddens=32, num_layers=3, dropout=0.36466274397593346, weight_decay=6.378737475108083e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.054838    21.090533
#         1  Completed    10       0.000131           64           3 0.292456      0.000132   10.0          0.050046    22.689732
#         2    Stopped     9       0.000218          256           2 0.329190      0.000050    9.0          0.083117    40.758078
#         3    Stopped     1       0.000142          128           3 0.499038      0.000106    1.0          0.064623     4.093693
#         4    Stopped     9       0.000274          128           2 0.356066      0.000417    9.0          0.084457    20.098052
#         5    Stopped     1       0.000296           64           4 0.247197      0.000019    1.0          0.053793     4.014325
#         6    Stopped     5       0.000271           64           2 0.446763      0.000121    5.0          0.083927    11.002010
#         7    Stopped     4       0.000121          128           2 0.313550      0.000046    4.0          0.046830     9.675146
#         8    Stopped     1       0.000049           64           4 0.251075      0.000023    1.0          0.060955     4.022012
#         9    Stopped     2       0.000490           32           4 0.382365      0.000032    2.0          0.062304     6.059541
#        10    Stopped     2       0.000019           32           2 0.252777      0.000195    2.0          0.141903     5.408071
#        11    Stopped     2       0.000341           32           4 0.311692      0.000152    2.0          0.059342     6.041671
#        12    Stopped     2       0.000130           32           4 0.473953      0.000347    2.0          0.061005     6.026281
#        13    Stopped     2       0.000084           64           3 0.479091      0.000157    2.0          0.053241     5.736822
#        14    Stopped     1       0.000015          128           3 0.272151      0.000441    1.0          0.101962     4.114319
#        15 InProgress     0       0.000019           32           3 0.364663      0.000064      -                 -            -
# 1 trials running, 15 finished (2 until the end), 260.37s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:26:10] 🚀 Trial 16 started - config: learning_rate=2.917905694080622e-05, num_hiddens=32, num_layers=4, dropout=0.28234463206893545, weight_decay=0.000337715685346101
# [11:26:20] 🚀 Trial 17 started - config: learning_rate=0.00018087774079559747, num_hiddens=256, num_layers=2, dropout=0.30297869972922564, weight_decay=9.708401966431204e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.054838    21.090533
#         1  Completed    10       0.000131           64           3 0.292456      0.000132   10.0          0.050046    22.689732
#         2    Stopped     9       0.000218          256           2 0.329190      0.000050    9.0          0.083117    40.758078
#         3    Stopped     1       0.000142          128           3 0.499038      0.000106    1.0          0.064623     4.093693
#         4    Stopped     9       0.000274          128           2 0.356066      0.000417    9.0          0.084457    20.098052
#         5    Stopped     1       0.000296           64           4 0.247197      0.000019    1.0          0.053793     4.014325
#         6    Stopped     5       0.000271           64           2 0.446763      0.000121    5.0          0.083927    11.002010
#         7    Stopped     4       0.000121          128           2 0.313550      0.000046    4.0          0.046830     9.675146
#         8    Stopped     1       0.000049           64           4 0.251075      0.000023    1.0          0.060955     4.022012
#         9    Stopped     2       0.000490           32           4 0.382365      0.000032    2.0          0.062304     6.059541
#        10    Stopped     2       0.000019           32           2 0.252777      0.000195    2.0          0.141903     5.408071
#        11    Stopped     2       0.000341           32           4 0.311692      0.000152    2.0          0.059342     6.041671
#        12    Stopped     2       0.000130           32           4 0.473953      0.000347    2.0          0.061005     6.026281
#        13    Stopped     2       0.000084           64           3 0.479091      0.000157    2.0          0.053241     5.736822
#        14    Stopped     1       0.000015          128           3 0.272151      0.000441    1.0          0.101962     4.114319
#        15    Stopped     2       0.000019           32           3 0.364663      0.000064    2.0          0.111748     5.820748
#        16    Stopped     2       0.000029           32           4 0.282345      0.000338    2.0          0.104351     6.074580
#        17 InProgress     0       0.000181          256           2 0.302979      0.000097      -                 -            -
# 1 trials running, 17 finished (2 until the end), 280.41s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.054838    21.090533
#         1  Completed    10       0.000131           64           3 0.292456      0.000132     10          0.050046    22.689732
#         2    Stopped     9       0.000218          256           2 0.329190      0.000050      9          0.083117    40.758078
#         3    Stopped     1       0.000142          128           3 0.499038      0.000106      1          0.064623     4.093693
#         4    Stopped     9       0.000274          128           2 0.356066      0.000417      9          0.084457    20.098052
#         5    Stopped     1       0.000296           64           4 0.247197      0.000019      1          0.053793     4.014325
#         6    Stopped     5       0.000271           64           2 0.446763      0.000121      5          0.083927    11.002010
#         7    Stopped     4       0.000121          128           2 0.313550      0.000046      4          0.046830     9.675146
#         8    Stopped     1       0.000049           64           4 0.251075      0.000023      1          0.060955     4.022012
#         9    Stopped     2       0.000490           32           4 0.382365      0.000032      2          0.062304     6.059541
#        10    Stopped     2       0.000019           32           2 0.252777      0.000195      2          0.141903     5.408071
#        11    Stopped     2       0.000341           32           4 0.311692      0.000152      2          0.059342     6.041671
#        12    Stopped     2       0.000130           32           4 0.473953      0.000347      2          0.061005     6.026281
#        13    Stopped     2       0.000084           64           3 0.479091      0.000157      2          0.053241     5.736822
#        14    Stopped     1       0.000015          128           3 0.272151      0.000441      1          0.101962     4.114319
#        15    Stopped     2       0.000019           32           3 0.364663      0.000064      2          0.111748     5.820748
#        16    Stopped     2       0.000029           32           4 0.282345      0.000338      2          0.104351     6.074580
#        17 InProgress     4       0.000181          256           2 0.302979      0.000097      4          0.048873    19.028219
# 1 trials running, 17 finished (2 until the end), 300.43s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:27:05] 🚀 Trial 18 started - config: learning_rate=1.6653015452775474e-05, num_hiddens=32, num_layers=3, dropout=0.2517559144632207, weight_decay=0.0001911994564752866
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.054838    21.090533
#         1  Completed    10       0.000131           64           3 0.292456      0.000132   10.0          0.050046    22.689732
#         2    Stopped     9       0.000218          256           2 0.329190      0.000050    9.0          0.083117    40.758078
#         3    Stopped     1       0.000142          128           3 0.499038      0.000106    1.0          0.064623     4.093693
#         4    Stopped     9       0.000274          128           2 0.356066      0.000417    9.0          0.084457    20.098052
#         5    Stopped     1       0.000296           64           4 0.247197      0.000019    1.0          0.053793     4.014325
#         6    Stopped     5       0.000271           64           2 0.446763      0.000121    5.0          0.083927    11.002010
#         7    Stopped     4       0.000121          128           2 0.313550      0.000046    4.0          0.046830     9.675146
#         8    Stopped     1       0.000049           64           4 0.251075      0.000023    1.0          0.060955     4.022012
#         9    Stopped     2       0.000490           32           4 0.382365      0.000032    2.0          0.062304     6.059541
#        10    Stopped     2       0.000019           32           2 0.252777      0.000195    2.0          0.141903     5.408071
#        11    Stopped     2       0.000341           32           4 0.311692      0.000152    2.0          0.059342     6.041671
#        12    Stopped     2       0.000130           32           4 0.473953      0.000347    2.0          0.061005     6.026281
#        13    Stopped     2       0.000084           64           3 0.479091      0.000157    2.0          0.053241     5.736822
#        14    Stopped     1       0.000015          128           3 0.272151      0.000441    1.0          0.101962     4.114319
#        15    Stopped     2       0.000019           32           3 0.364663      0.000064    2.0          0.111748     5.820748
#        16    Stopped     2       0.000029           32           4 0.282345      0.000338    2.0          0.104351     6.074580
#        17    Stopped     9       0.000181          256           2 0.302979      0.000097    9.0          0.081138    40.490622
#        18 InProgress     0       0.000017           32           3 0.251756      0.000191      -                 -            -
# 1 trials running, 18 finished (2 until the end), 320.49s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:27:15] 🚀 Trial 19 started - config: learning_rate=1.3733731794709415e-05, num_hiddens=256, num_layers=3, dropout=0.203169653354207, weight_decay=2.2529458698174117e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.054838    21.090533
#         1  Completed    10       0.000131           64           3 0.292456      0.000132   10.0          0.050046    22.689732
#         2    Stopped     9       0.000218          256           2 0.329190      0.000050    9.0          0.083117    40.758078
#         3    Stopped     1       0.000142          128           3 0.499038      0.000106    1.0          0.064623     4.093693
#         4    Stopped     9       0.000274          128           2 0.356066      0.000417    9.0          0.084457    20.098052
#         5    Stopped     1       0.000296           64           4 0.247197      0.000019    1.0          0.053793     4.014325
#         6    Stopped     5       0.000271           64           2 0.446763      0.000121    5.0          0.083927    11.002010
#         7    Stopped     4       0.000121          128           2 0.313550      0.000046    4.0          0.046830     9.675146
#         8    Stopped     1       0.000049           64           4 0.251075      0.000023    1.0          0.060955     4.022012
#         9    Stopped     2       0.000490           32           4 0.382365      0.000032    2.0          0.062304     6.059541
#        10    Stopped     2       0.000019           32           2 0.252777      0.000195    2.0          0.141903     5.408071
#        11    Stopped     2       0.000341           32           4 0.311692      0.000152    2.0          0.059342     6.041671
#        12    Stopped     2       0.000130           32           4 0.473953      0.000347    2.0          0.061005     6.026281
#        13    Stopped     2       0.000084           64           3 0.479091      0.000157    2.0          0.053241     5.736822
#        14    Stopped     1       0.000015          128           3 0.272151      0.000441    1.0          0.101962     4.114319
#        15    Stopped     2       0.000019           32           3 0.364663      0.000064    2.0          0.111748     5.820748
#        16    Stopped     2       0.000029           32           4 0.282345      0.000338    2.0          0.104351     6.074580
#        17    Stopped     9       0.000181          256           2 0.302979      0.000097    9.0          0.081138    40.490622
#        18    Stopped     1       0.000017           32           3 0.251756      0.000191    1.0          0.385379     3.750153
#        19 InProgress     0       0.000014          256           3 0.203170      0.000023      -                 -            -
# 1 trials running, 19 finished (2 until the end), 340.50s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:27:30] 🚀 Trial 20 started - config: learning_rate=2.8841668268523388e-05, num_hiddens=256, num_layers=2, dropout=0.36033042138910104, weight_decay=2.508928206676643e-05
# [11:27:46] 🚀 Trial 21 started - config: learning_rate=0.00016372036363827657, num_hiddens=128, num_layers=3, dropout=0.34081754795984043, weight_decay=0.0004181139344949815
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.054838    21.090533
#         1  Completed    10       0.000131           64           3 0.292456      0.000132   10.0          0.050046    22.689732
#         2    Stopped     9       0.000218          256           2 0.329190      0.000050    9.0          0.083117    40.758078
#         3    Stopped     1       0.000142          128           3 0.499038      0.000106    1.0          0.064623     4.093693
#         4    Stopped     9       0.000274          128           2 0.356066      0.000417    9.0          0.084457    20.098052
#         5    Stopped     1       0.000296           64           4 0.247197      0.000019    1.0          0.053793     4.014325
#         6    Stopped     5       0.000271           64           2 0.446763      0.000121    5.0          0.083927    11.002010
#         7    Stopped     4       0.000121          128           2 0.313550      0.000046    4.0          0.046830     9.675146
#         8    Stopped     1       0.000049           64           4 0.251075      0.000023    1.0          0.060955     4.022012
#         9    Stopped     2       0.000490           32           4 0.382365      0.000032    2.0          0.062304     6.059541
#        10    Stopped     2       0.000019           32           2 0.252777      0.000195    2.0          0.141903     5.408071
#        11    Stopped     2       0.000341           32           4 0.311692      0.000152    2.0          0.059342     6.041671
#        12    Stopped     2       0.000130           32           4 0.473953      0.000
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-20-11-21-49-909
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-20-11-21-49-909
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##11. Load Results from Dissolved Oxygen HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
oxygen_results_path = "/root/syne-tune/python-entrypoint-2026-03-20-11-21-49-909/results.csv.zip"

# Save the results to a Pandas DataFrame
oxygen_results = pd.read_csv(oxygen_results_path)

# %% [markdown]
# ##12. Save the Oxygen HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
oxygen_hpo_results_path = Path("/content/REDE_BIRDHOPE BRIDGE_E_202501_oxygen_hpo_results.csv")

# Save the DataFrame to a csv file
oxygen_results.to_csv(oxygen_hpo_results_path, index=True)

# %% [markdown]
# ## 13. Define the Config Space, Scheduler, and Tune Function for Temperature HPO

# %%
# Create a dictionary defining the space of hyperparameters to explore
config_space = {
    "learning_rate": loguniform(1e-5, 5e-4), # explores learning rates sampled from a lognormal distribution between 0.00001 and 0.0005 (biases lower rates since higher learning rates were often unstable)
    "num_hiddens": choice([32, 64, 128, 256]), # explores a range of hidden units between 32 and 256 (multiples of 8 for computational efficiency)
    "num_layers": randint(2, 4), # explores 2 to 4 hidden layers (initial trials showed optimal configurations were usually in this range)
    "dropout": uniform(0.2, 0.5), # explores moderate to slightly aggressive dropout rates from a uniform distribution between 0.2 and 0.5
    "weight_decay": loguniform(1e-5, 5e-4), # explores weight decay coefficients sampled from a lognormal distribution between 0.00001 and 0.0005
}

# Define the initial configuration for the HPO searcher to try first (this was found to be a very strong baseline for most stations)
initial_config = {
    "learning_rate": 0.00001,
    "num_hiddens": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "weight_decay": 0.00001
}

# %%
# Define ASHA configurations for HPO
minimise_mode = True # ASHA seeks to minimise the metric if True
metric = "validation_error" # The metric to be optimised during HPO is validation error
resource_attr = "epoch" # ASHA should track optimisation over epochs and stop low-performing trials early

# Initialise the ASHA HPO scheduler
scheduler = ASHA(
    config_space, # search over the defined hyperparameter space
    metric=metric, # optimise the chosen metric (validation error)
    do_minimize=minimise_mode, # ASHA should minimise the metric
    points_to_evaluate=[initial_config], # seed the search with an initial baseline configuration
    max_t=max_number_of_epochs, # maximum number of epochs per trial
    time_attr=resource_attr # track trial progress by epochs
    )
# Out:
# WARNING:syne_tune.optimizer.schedulers.searchers.last_value_multi_fidelity_searcher:points_to_evaluate is passed in searcher_kwargs, but is set to f[{'learning_rate': 1e-05, 'num_hiddens': 64, 'num_layers': 2, 'dropout': 0.2, 'weight_decay': 1e-05}] in the constructor. I will use the one from the constructor.

# %%
# Define the tune function for optimising LSTM hyperparameters using ASHA on temperature_t_96 targets
def temperature_hpo_objective_lstm_synetune(learning_rate, num_hiddens, num_layers, dropout, weight_decay):
    """
    Defines a function for optimising the hyperparameters of an LSTM model.

    Args:
      - learning_rate (float): The learning rate for the model.
      - num_hiddens (int): The number of hidden units per layer in the model.
      - num_layers (int): The number of hidden layers in the model.
      - dropout (float): The dropout regularisation rate for the model.
      - weight_decay (float): The weight decay regularisation rate for the model.

    Side effects:
      - Trains an LSTM for specified hyperparameter configuration and reports validation performance.
    """
    # Import reporter from Syne Tune
    from syne_tune import Reporter

    # Import base scripts within function for compatibility with Python Backend
    import pandas as pd
    import numpy as np
    import urllib.request
    import sys
    from pathlib import Path
    import io
    from sklearn.preprocessing import MinMaxScaler
    import torch

    # Import the Base Classes and Helper Functions from the Project GitHub
    url = "https://raw.githubusercontent.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/main/base_classes_and_helper_functions.py"
    file_path = Path("base_classes_and_helper_functions.py")
    if not file_path.exists():
        urllib.request.urlretrieve(url, file_path)
    sys.path.append(str(file_path.parent))
    import base_classes_and_helper_functions as bchf

    # Set the random seed for all PNRGs to ensure reproducibility
    bchf.set_random_seed()

    ### NOTE: DATA LOADING AND PREPROCESSING MUST BE DEFINED WITHIN THE SAME FUNCTION AS MODELLING CODE FOR COMPATIBILITY WITH SYNE-TUNE BACKEND!!!!!
    # Load the raw data from the project GitHub into a Pandas DataFrame and set index as DateTime
    data_path = bchf.load_raw_data(url="https://github.com/VinceMoran/EA_Water_Quality_Time_Series_Prediction/raw/main/data/processed_data/river_rede/REDE_BIRDHOPE%20BRIDGE_E_202501/REDE_BIRDHOPE%20BRIDGE_E_202501_preprocessed_data.zip")
    # Assign the full filepath for the preprocessed data
    parameter_path = "/content" / data_path / "REDE_BIRDHOPE BRIDGE_E_202501_preprocessed_data.csv"
    df_parameters = pd.read_csv(parameter_path)
    # Change the data type for the dateTime column to datetime64
    df_parameters["dateTime"] = pd.to_datetime(df_parameters["dateTime"], dayfirst=False)
    # Set the datetime column as the index
    df_parameters.set_index('dateTime', inplace=True)
    # Numerically encode date and time as features
    df_parameters["day_of_year"] = df_parameters.index.dayofyear
    df_parameters["day_of_year_sin"] = np.sin(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["day_of_year_cos"] = np.cos(2*np.pi*(df_parameters["day_of_year"]/365))
    df_parameters["minute_of_day"] = df_parameters.index.hour*60 + df_parameters.index.minute
    df_parameters["minute_of_day_sin"] = np.sin(2*np.pi*(df_parameters["minute_of_day"]/1440))
    df_parameters["minute_of_day_cos"] = np.cos(2*np.pi*(df_parameters["minute_of_day"]/1440))
    # Remove redundant columns
    df_parameters.drop(["day_of_year", "minute_of_day"], axis=1, inplace=True)
    # Create lagged variables for each feature
    variables = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for i in np.arange(1, 5):
        for variable in variables:
            df_parameters[f"{variable}_lag{i}"] = df_parameters[variable].shift(periods=i)
    # Create moving averages for each water quality variable
    moving_average_windows = np.array([6, 12, 24]) # hours
    timestep_windows = moving_average_windows * 4 # number of timesteps
    # Loop through creating moving averages from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_ma{i}"] = df_parameters[variable].rolling(window=i, min_periods=1).mean()
    # Create seasonal lagged features
    target_vars = ["ammonium", "oxygen_conc", "temperature"]
    seasonality = 96 # 24 hours prior in 15 minute sensor data
    for target in target_vars:
        df_parameters[f"{target}_seasonal_lag{seasonality}"] = df_parameters[target].shift(periods=seasonality)
    # Loop through creating moving averages of imputed value counts from only past values to avoid temporal leakage
    for i in timestep_windows:
        for variable in variables:
            df_parameters[f"{variable}_imputed_count_{i}"] = (df_parameters[f"{variable}_impossible"] + df_parameters[f"{variable}_anomaly"]).rolling(window=i, min_periods=1).sum()
    # Create the target variable for HPO
    target_var = "temperature"
    target_timestep = 96
    df_parameters[f"{target_var}_target_t_{str(target_timestep)}"] = df_parameters[target_var].shift(periods=-target_timestep)
    # Remove NaN rows added after shifting features and targets
    df_parameters.dropna(inplace=True)
    # Split the DataFrame into training, validation, and testing sets
    df_train, df_val, df_test = bchf.train_val_test_split(df_parameters,
                                                          train_size=0.6,
                                                          val_size=0.2,
                                                          test_size=0.2)
    # Initialise the scaler using min-max normalisation (avoid temporal leakage by splitting into training, validation, and testing before fitting the scaler)
    feature_scaler = MinMaxScaler()
    # Create copies of the DataFrames for scaling
    df_train_scaled, df_val_scaled, df_test_scaled = df_train.copy(), df_val.copy(), df_test.copy()
    # Create a list of features for scaling
    features_to_scale = df_train.columns
    # Drop anomaly and impossible flags from the features to be scaled list using loop
    var_sub_names = ["ammonium", "conductivity", "oxygen_conc", "oxygen_perc", "temperature", "turbidity"]
    for var in var_sub_names:
        features_to_scale = features_to_scale.drop(f"{var}_impossible")
        features_to_scale = features_to_scale.drop(f"{var}_anomaly")
    # Drop temporal features from the list of features to be scaled
    features_to_scale = features_to_scale.drop("day_of_year_sin")
    features_to_scale = features_to_scale.drop("day_of_year_cos")
    features_to_scale = features_to_scale.drop("minute_of_day_sin")
    features_to_scale = features_to_scale.drop("minute_of_day_cos")
    # Remove target from the list of features for scaling
    features_to_scale = features_to_scale.drop(f"{target_var}_target_t_{target_timestep}")
    # Fit the scaler to the features during training
    feature_scaler.fit(df_train_scaled[features_to_scale])
    # Transform the features using min-max normalisation
    df_train_scaled[features_to_scale] = feature_scaler.transform(df_train_scaled[features_to_scale])
    df_val_scaled[features_to_scale] = feature_scaler.transform(df_val_scaled[features_to_scale])
    df_test_scaled[features_to_scale] = feature_scaler.transform(df_test_scaled[features_to_scale])
    # Change data types to float32 and int8 to reduce memory and speed up training
    float_cols = df_train_scaled.select_dtypes(include='float64').columns # identify column names containing 64 bit floating point data
    bool_cols = df_train_scaled.select_dtypes(include='bool').columns # identify column names containing Boolean data
    # Loop through DataFrames to convert columns to appropriate data types
    for df in [df_train_scaled, df_val_scaled, df_test_scaled]:
        df[float_cols] = df[float_cols].astype('float32')
        df[bool_cols] = df[bool_cols].astype('int8')
    # Obtain a mapping to the HPO target
    hpo_target = f"{target_var}_target_t_{str(target_timestep)}"
    # Create list of features
    features = df_train_scaled.columns.drop(hpo_target)
    # Create array for training features
    X_train = df_train_scaled[features].values
    # Create array for training targets
    y_train = df_train_scaled[hpo_target].values
    # Create array for validation features
    X_val = df_val_scaled[features].values
    # Create array for validation targets
    y_val = df_val_scaled[hpo_target].values
    # Create array for testing features
    X_test = df_test_scaled[features].values
    # Create array for testing targets
    y_test = df_test_scaled[hpo_target].values
    # Instantiate the target scaler object
    target_scaler = MinMaxScaler()
    # Fit the scaler to the training targets
    target_scaler.fit(y_train.reshape(-1, 1))
    # Scale training targets
    y_train = target_scaler.transform(y_train.reshape(-1, 1))
    # Scale the validation targets
    y_val = target_scaler.transform(y_val.reshape(-1, 1))
    # Scale the testing targets
    y_test = target_scaler.transform(y_test.reshape(-1, 1))
    # Instantiate the TimeSeries data class for HPO
    data = bchf.TimeSeries(batch_size=32, # minibatch size defaults to 32 to balance convergence speed with gradient estimation accuracy
                           num_steps=96, # sliding window of 96 represents 24hrs of 15 minute resolution data
                           X_train=X_train,
                           y_train=y_train,
                           X_val=X_val,
                           y_val=y_val,
                           X_test=X_test,
                           y_test=y_test)

    ### NOTE: MODELLING CODE BEGINS HERE!!!!!
    # Specify the maximum number of epochs for which a trial is allowed to run during HPO
    MAX_NUMBER_OF_EPOCHS = 10

    # Obtain the shape of the input tensor to be passed into the LSTM
    num_inputs = next(iter(data.train_dataloader()))[0].shape[2]
    # Specify the model hyperparameters
    lstm = bchf.LSTM(num_inputs=num_inputs,
                     num_hiddens=num_hiddens,
                     num_layers=num_layers,
                     dropout=dropout)
    # Create an instance of the model class
    model = bchf.RNNWQ(rnn=lstm,
                       out_features=1,
                       lr=learning_rate,
                       weight_decay=weight_decay)
    # Create an instance of the HPOTrainer class
    trainer = bchf.HPOTrainer(max_epochs=1, num_gpus=1) # `max_epochs` set to 1 so that each call to `fit_epoch()` in the below loop runs for 1 epoch per iteration
    # Create the reporting object to send metrics to syne tune during training
    report = Reporter()
    # Loop through each epoch up until the specified number of maximum epochs
    for epoch in range(1, MAX_NUMBER_OF_EPOCHS + 1):
        # Initialise the trainer on the first epoch
        if epoch == 1:
            # Initialize the state of Trainer
            trainer.fit(model=model, data=data)
        # Fit for an additional epoch after the first epoch
        else:
            trainer.fit_epoch()
        # Compute the validation error
        validation_error = trainer.validation_error().cpu().detach().numpy()
        # Report the validation error from each epoch
        report(epoch=epoch, validation_error=float(validation_error))

# %% [markdown]
# ##14. Initialise and Run the Tuner for Temperature HPO

# %%
# Instruct the searcher to run each trial as a Python function
temperature_trial_backend = PythonBackend(
    tune_function=temperature_hpo_objective_lstm_synetune, # use the predefined hpo_objective_lstm_synetune function to optimise hyperparameters
    config_space=config_space) # sample hyperparameters from the predefined configuration space

# %%
# Initialise the tuner object for HPO
tuner = Tuner(
    trial_backend=temperature_trial_backend, # pass the predefined backend function (`hpo_objective_lstm_synetune`) for running each hyperparameter trial
    scheduler=scheduler, # pass the predefined scheduler (ASHA)
    stop_criterion=stop_criterion, # pass the stopping criterion (`max_number_of_trials`)
    n_workers=n_workers, # pass the number of parallel workers available for use
    print_update_interval=int(max_number_of_trials * 0.5), # print updates after 50% of the maximum number of trials have been started
)

# %%
# Run the HPO experiment
tuner.run()
# Out:
# 🚀 Syne Tune - Hyperparameter Optimization
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Experiment Configuration
# ├─ Name: python-entrypoint-2026-03-20-11-33-49-494
# ├─ Backend: PythonBackend
# ├─ Workers: 1
# ├─ Scheduler: ASHA
# ├─ Results Path: /root/syne-tune/python-entrypoint-2026-03-20-11-33-49-494
# └─ Log Path: /root/syne-tune/python-entrypoint-2026-03-20-11-33-49-494
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 🏁 Starting hyperparameter optimization...
# [11:33:50] 🚀 Trial 0 started - config: learning_rate=1e-05, num_hiddens=64, num_layers=2, dropout=0.2, weight_decay=1e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0 InProgress     4        0.00001           64           2      0.2       0.00001      4          0.059474     9.187014
# 1 trials running, 0 finished (0 until the end), 20.02s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:34:20] ✅ Trial 0 completed!
# [11:34:20] 🚀 Trial 1 started - config: learning_rate=0.00014897324424424812, num_hiddens=256, num_layers=3, dropout=0.22662752345596796, weight_decay=1.0275306607988609e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000       0.00001   10.0          0.056878    20.893487
#         1 InProgress     0       0.000149          256           3 0.226628       0.00001      -                 -            -
# 1 trials running, 1 finished (1 until the end), 40.04s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000       0.00001     10          0.056878    20.893487
#         1 InProgress     3       0.000149          256           3 0.226628       0.00001      3          0.057668    18.672607
# 1 trials running, 1 finished (1 until the end), 60.06s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000       0.00001     10          0.056878    20.893487
#         1 InProgress     7       0.000149          256           3 0.226628       0.00001      7          0.064646    40.935862
# 1 trials running, 1 finished (1 until the end), 80.09s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:35:20] 🚀 Trial 2 started - config: learning_rate=1.9302078068624528e-05, num_hiddens=256, num_layers=2, dropout=0.33930907997850374, weight_decay=4.740553929872277e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010    9.0          0.065650    52.314478
#         2 InProgress     0       0.000019          256           2 0.339309      0.000047      -                 -            -
# 1 trials running, 2 finished (1 until the end), 100.11s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010      9          0.065650    52.314478
#         2 InProgress     4       0.000019          256           2 0.339309      0.000047      4          0.057231    18.832419
# 1 trials running, 2 finished (1 until the end), 120.13s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010      9          0.065650    52.314478
#         2 InProgress     9       0.000019          256           2 0.339309      0.000047      9          0.057217    40.246949
# 1 trials running, 2 finished (1 until the end), 140.16s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:36:10] ✅ Trial 2 completed!
# [11:36:10] 🚀 Trial 3 started - config: learning_rate=0.00013016400010937043, num_hiddens=128, num_layers=4, dropout=0.33280359979109186, weight_decay=0.0001419427047257095
# [11:36:20] 🚀 Trial 4 started - config: learning_rate=6.235076586334346e-05, num_hiddens=64, num_layers=3, dropout=0.48165061491717015, weight_decay=2.716328341841499e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010    9.0          0.065650    52.314478
#         2  Completed    10       0.000019          256           2 0.339309      0.000047   10.0          0.057540    44.565692
#         3    Stopped     1       0.000130          128           4 0.332804      0.000142    1.0          0.066722     4.474597
#         4 InProgress     0       0.000062           64           3 0.481651      0.000027      -                 -            -
# 1 trials running, 4 finished (2 until the end), 160.19s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:36:30] 🚀 Trial 5 started - config: learning_rate=0.00024647243015341356, num_hiddens=256, num_layers=4, dropout=0.39797930116274327, weight_decay=0.0003160684629519442
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010      9          0.065650    52.314478
#         2  Completed    10       0.000019          256           2 0.339309      0.000047     10          0.057540    44.565692
#         3    Stopped     1       0.000130          128           4 0.332804      0.000142      1          0.066722     4.474597
#         4    Stopped     2       0.000062           64           3 0.481651      0.000027      2          0.062338     5.825630
#         5 InProgress     1       0.000246          256           4 0.397979      0.000316      1          0.060349     9.231043
# 1 trials running, 5 finished (2 until the end), 180.22s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:37:00] 🚀 Trial 6 started - config: learning_rate=0.00014369906113361687, num_hiddens=32, num_layers=4, dropout=0.4912814599276264, weight_decay=6.548140096511673e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010    9.0          0.065650    52.314478
#         2  Completed    10       0.000019          256           2 0.339309      0.000047   10.0          0.057540    44.565692
#         3    Stopped     1       0.000130          128           4 0.332804      0.000142    1.0          0.066722     4.474597
#         4    Stopped     2       0.000062           64           3 0.481651      0.000027    2.0          0.062338     5.825630
#         5    Stopped     3       0.000246          256           4 0.397979      0.000316    3.0          0.059400    23.090295
#         6 InProgress     0       0.000144           32           4 0.491281      0.000065      -                 -            -
# 1 trials running, 6 finished (2 until the end), 200.24s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:37:10] 🚀 Trial 7 started - config: learning_rate=0.00047439370887681606, num_hiddens=256, num_layers=4, dropout=0.4545313247989292, weight_decay=0.00017133585557130992
# [11:37:25] 🚀 Trial 8 started - config: learning_rate=1.7554356068752606e-05, num_hiddens=256, num_layers=4, dropout=0.4696382696814787, weight_decay=3.503019362992596e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010    9.0          0.065650    52.314478
#         2  Completed    10       0.000019          256           2 0.339309      0.000047   10.0          0.057540    44.565692
#         3    Stopped     1       0.000130          128           4 0.332804      0.000142    1.0          0.066722     4.474597
#         4    Stopped     2       0.000062           64           3 0.481651      0.000027    2.0          0.062338     5.825630
#         5    Stopped     3       0.000246          256           4 0.397979      0.000316    3.0          0.059400    23.090295
#         6    Stopped     2       0.000144           32           4 0.491281      0.000065    2.0          0.097383     6.083744
#         7    Stopped     1       0.000474          256           4 0.454531      0.000171    1.0          0.060582     9.146092
#         8 InProgress     0       0.000018          256           4 0.469638      0.000035      -                 -            -
# 1 trials running, 8 finished (2 until the end), 220.28s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010      9          0.065650    52.314478
#         2  Completed    10       0.000019          256           2 0.339309      0.000047     10          0.057540    44.565692
#         3    Stopped     1       0.000130          128           4 0.332804      0.000142      1          0.066722     4.474597
#         4    Stopped     2       0.000062           64           3 0.481651      0.000027      2          0.062338     5.825630
#         5    Stopped     3       0.000246          256           4 0.397979      0.000316      3          0.059400    23.090295
#         6    Stopped     2       0.000144           32           4 0.491281      0.000065      2          0.097383     6.083744
#         7    Stopped     1       0.000474          256           4 0.454531      0.000171      1          0.060582     9.146092
#         8 InProgress     2       0.000018          256           4 0.469638      0.000035      2          0.062409    16.022567
# 1 trials running, 8 finished (2 until the end), 240.30s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:37:55] 🚀 Trial 9 started - config: learning_rate=2.1568185436050454e-05, num_hiddens=32, num_layers=3, dropout=0.21674920339301984, weight_decay=0.00041269623085436654
# [11:38:05] 🚀 Trial 10 started - config: learning_rate=0.0003191553648780724, num_hiddens=128, num_layers=4, dropout=0.46652471153988717, weight_decay=4.730941767538034e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010    9.0          0.065650    52.314478
#         2  Completed    10       0.000019          256           2 0.339309      0.000047   10.0          0.057540    44.565692
#         3    Stopped     1       0.000130          128           4 0.332804      0.000142    1.0          0.066722     4.474597
#         4    Stopped     2       0.000062           64           3 0.481651      0.000027    2.0          0.062338     5.825630
#         5    Stopped     3       0.000246          256           4 0.397979      0.000316    3.0          0.059400    23.090295
#         6    Stopped     2       0.000144           32           4 0.491281      0.000065    2.0          0.097383     6.083744
#         7    Stopped     1       0.000474          256           4 0.454531      0.000171    1.0          0.060582     9.146092
#         8    Stopped     3       0.000018          256           4 0.469638      0.000035    3.0          0.061929    22.869862
#         9    Stopped     2       0.000022           32           3 0.216749      0.000413    2.0          0.097290     5.663421
#        10 InProgress     0       0.000319          128           4 0.466525      0.000047      -                 -            -
# 1 trials running, 10 finished (2 until the end), 260.33s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:38:15] 🚀 Trial 11 started - config: learning_rate=0.00034537613518286555, num_hiddens=256, num_layers=3, dropout=0.3472715057238361, weight_decay=1.7349194258389454e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010    9.0          0.065650    52.314478
#         2  Completed    10       0.000019          256           2 0.339309      0.000047   10.0          0.057540    44.565692
#         3    Stopped     1       0.000130          128           4 0.332804      0.000142    1.0          0.066722     4.474597
#         4    Stopped     2       0.000062           64           3 0.481651      0.000027    2.0          0.062338     5.825630
#         5    Stopped     3       0.000246          256           4 0.397979      0.000316    3.0          0.059400    23.090295
#         6    Stopped     2       0.000144           32           4 0.491281      0.000065    2.0          0.097383     6.083744
#         7    Stopped     1       0.000474          256           4 0.454531      0.000171    1.0          0.060582     9.146092
#         8    Stopped     3       0.000018          256           4 0.469638      0.000035    3.0          0.061929    22.869862
#         9    Stopped     2       0.000022           32           3 0.216749      0.000413    2.0          0.097290     5.663421
#        10    Stopped     1       0.000319          128           4 0.466525      0.000047    1.0          0.068410     4.460590
#        11 InProgress     0       0.000345          256           3 0.347272      0.000017      -                 -            -
# 1 trials running, 11 finished (2 until the end), 280.36s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:38:40] 🚀 Trial 12 started - config: learning_rate=0.00011641070205779179, num_hiddens=64, num_layers=3, dropout=0.291955053287348, weight_decay=0.00038376387742195477
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010    9.0          0.065650    52.314478
#         2  Completed    10       0.000019          256           2 0.339309      0.000047   10.0          0.057540    44.565692
#         3    Stopped     1       0.000130          128           4 0.332804      0.000142    1.0          0.066722     4.474597
#         4    Stopped     2       0.000062           64           3 0.481651      0.000027    2.0          0.062338     5.825630
#         5    Stopped     3       0.000246          256           4 0.397979      0.000316    3.0          0.059400    23.090295
#         6    Stopped     2       0.000144           32           4 0.491281      0.000065    2.0          0.097383     6.083744
#         7    Stopped     1       0.000474          256           4 0.454531      0.000171    1.0          0.060582     9.146092
#         8    Stopped     3       0.000018          256           4 0.469638      0.000035    3.0          0.061929    22.869862
#         9    Stopped     2       0.000022           32           3 0.216749      0.000413    2.0          0.097290     5.663421
#        10    Stopped     1       0.000319          128           4 0.466525      0.000047    1.0          0.068410     4.460590
#        11    Stopped     3       0.000345          256           3 0.347272      0.000017    3.0          0.059807    18.882709
#        12 InProgress     0       0.000116           64           3 0.291955      0.000384      -                 -            -
# 1 trials running, 12 finished (2 until the end), 300.39s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:38:50] 🚀 Trial 13 started - config: learning_rate=1.4397148847775839e-05, num_hiddens=128, num_layers=3, dropout=0.42410331212714614, weight_decay=4.714892034258111e-05
# [11:39:00] 🚀 Trial 14 started - config: learning_rate=0.00013850120740713036, num_hiddens=64, num_layers=4, dropout=0.30873963777638874, weight_decay=1.9987965512479643e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010    9.0          0.065650    52.314478
#         2  Completed    10       0.000019          256           2 0.339309      0.000047   10.0          0.057540    44.565692
#         3    Stopped     1       0.000130          128           4 0.332804      0.000142    1.0          0.066722     4.474597
#         4    Stopped     2       0.000062           64           3 0.481651      0.000027    2.0          0.062338     5.825630
#         5    Stopped     3       0.000246          256           4 0.397979      0.000316    3.0          0.059400    23.090295
#         6    Stopped     2       0.000144           32           4 0.491281      0.000065    2.0          0.097383     6.083744
#         7    Stopped     1       0.000474          256           4 0.454531      0.000171    1.0          0.060582     9.146092
#         8    Stopped     3       0.000018          256           4 0.469638      0.000035    3.0          0.061929    22.869862
#         9    Stopped     2       0.000022           32           3 0.216749      0.000413    2.0          0.097290     5.663421
#        10    Stopped     1       0.000319          128           4 0.466525      0.000047    1.0          0.068410     4.460590
#        11    Stopped     3       0.000345          256           3 0.347272      0.000017    3.0          0.059807    18.882709
#        12    Stopped     2       0.000116           64           3 0.291955      0.000384    2.0          0.060148     5.925162
#        13    Stopped     1       0.000014          128           3 0.424103      0.000047    1.0          0.079493     4.098692
#        14 InProgress     0       0.000139           64           4 0.308740      0.000020      -                 -            -
# 1 trials running, 14 finished (2 until the end), 320.42s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:39:10] 🚀 Trial 15 started - config: learning_rate=1.685293241063087e-05, num_hiddens=128, num_layers=2, dropout=0.3749494346553433, weight_decay=6.825543441131672e-05
# [11:39:20] 🚀 Trial 16 started - config: learning_rate=0.00038717416091419083, num_hiddens=256, num_layers=2, dropout=0.40974627046954976, weight_decay=5.4480900978918954e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010    9.0          0.065650    52.314478
#         2  Completed    10       0.000019          256           2 0.339309      0.000047   10.0          0.057540    44.565692
#         3    Stopped     1       0.000130          128           4 0.332804      0.000142    1.0          0.066722     4.474597
#         4    Stopped     2       0.000062           64           3 0.481651      0.000027    2.0          0.062338     5.825630
#         5    Stopped     3       0.000246          256           4 0.397979      0.000316    3.0          0.059400    23.090295
#         6    Stopped     2       0.000144           32           4 0.491281      0.000065    2.0          0.097383     6.083744
#         7    Stopped     1       0.000474          256           4 0.454531      0.000171    1.0          0.060582     9.146092
#         8    Stopped     3       0.000018          256           4 0.469638      0.000035    3.0          0.061929    22.869862
#         9    Stopped     2       0.000022           32           3 0.216749      0.000413    2.0          0.097290     5.663421
#        10    Stopped     1       0.000319          128           4 0.466525      0.000047    1.0          0.068410     4.460590
#        11    Stopped     3       0.000345          256           3 0.347272      0.000017    3.0          0.059807    18.882709
#        12    Stopped     2       0.000116           64           3 0.291955      0.000384    2.0          0.060148     5.925162
#        13    Stopped     1       0.000014          128           3 0.424103      0.000047    1.0          0.079493     4.098692
#        14    Stopped     1       0.000139           64           4 0.308740      0.000020    1.0          0.071010     4.012008
#        15    Stopped     2       0.000017          128           2 0.374949      0.000068    2.0          0.080089     5.762897
#        16 InProgress     0       0.000387          256           2 0.409746      0.000054      -                 -            -
# 1 trials running, 16 finished (2 until the end), 340.46s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:39:35] 🚀 Trial 17 started - config: learning_rate=1.4853769873119506e-05, num_hiddens=64, num_layers=2, dropout=0.20316674885633887, weight_decay=9.651083251052263e-05
# [11:39:45] 🚀 Trial 18 started - config: learning_rate=1.4092258021487873e-05, num_hiddens=32, num_layers=4, dropout=0.3890021215438674, weight_decay=0.00018143395218553525
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010    9.0          0.065650    52.314478
#         2  Completed    10       0.000019          256           2 0.339309      0.000047   10.0          0.057540    44.565692
#         3    Stopped     1       0.000130          128           4 0.332804      0.000142    1.0          0.066722     4.474597
#         4    Stopped     2       0.000062           64           3 0.481651      0.000027    2.0          0.062338     5.825630
#         5    Stopped     3       0.000246          256           4 0.397979      0.000316    3.0          0.059400    23.090295
#         6    Stopped     2       0.000144           32           4 0.491281      0.000065    2.0          0.097383     6.083744
#         7    Stopped     1       0.000474          256           4 0.454531      0.000171    1.0          0.060582     9.146092
#         8    Stopped     3       0.000018          256           4 0.469638      0.000035    3.0          0.061929    22.869862
#         9    Stopped     2       0.000022           32           3 0.216749      0.000413    2.0          0.097290     5.663421
#        10    Stopped     1       0.000319          128           4 0.466525      0.000047    1.0          0.068410     4.460590
#        11    Stopped     3       0.000345          256           3 0.347272      0.000017    3.0          0.059807    18.882709
#        12    Stopped     2       0.000116           64           3 0.291955      0.000384    2.0          0.060148     5.925162
#        13    Stopped     1       0.000014          128           3 0.424103      0.000047    1.0          0.079493     4.098692
#        14    Stopped     1       0.000139           64           4 0.308740      0.000020    1.0          0.071010     4.012008
#        15    Stopped     2       0.000017          128           2 0.374949      0.000068    2.0          0.080089     5.762897
#        16    Stopped     2       0.000387          256           2 0.409746      0.000054    2.0          0.056440    10.420550
#        17    Stopped     2       0.000015           64           2 0.203167      0.000097    2.0          0.062009     5.364068
#        18 InProgress     0       0.000014           32           4 0.389002      0.000181      -                 -            -
# 1 trials running, 18 finished (2 until the end), 360.49s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:39:55] 🚀 Trial 19 started - config: learning_rate=6.260790268220641e-05, num_hiddens=128, num_layers=4, dropout=0.3144416736237868, weight_decay=1.861057006839829e-05
# [11:40:05] 🚀 Trial 20 started - config: learning_rate=3.4447682426069515e-05, num_hiddens=32, num_layers=2, dropout=0.3137615548797566, weight_decay=1.9449692276745602e-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010    9.0          0.065650    52.314478
#         2  Completed    10       0.000019          256           2 0.339309      0.000047   10.0          0.057540    44.565692
#         3    Stopped     1       0.000130          128           4 0.332804      0.000142    1.0          0.066722     4.474597
#         4    Stopped     2       0.000062           64           3 0.481651      0.000027    2.0          0.062338     5.825630
#         5    Stopped     3       0.000246          256           4 0.397979      0.000316    3.0          0.059400    23.090295
#         6    Stopped     2       0.000144           32           4 0.491281      0.000065    2.0          0.097383     6.083744
#         7    Stopped     1       0.000474          256           4 0.454531      0.000171    1.0          0.060582     9.146092
#         8    Stopped     3       0.000018          256           4 0.469638      0.000035    3.0          0.061929    22.869862
#         9    Stopped     2       0.000022           32           3 0.216749      0.000413    2.0          0.097290     5.663421
#        10    Stopped     1       0.000319          128           4 0.466525      0.000047    1.0          0.068410     4.460590
#        11    Stopped     3       0.000345          256           3 0.347272      0.000017    3.0          0.059807    18.882709
#        12    Stopped     2       0.000116           64           3 0.291955      0.000384    2.0          0.060148     5.925162
#        13    Stopped     1       0.000014          128           3 0.424103      0.000047    1.0          0.079493     4.098692
#        14    Stopped     1       0.000139           64           4 0.308740      0.000020    1.0          0.071010     4.012008
#        15    Stopped     2       0.000017          128           2 0.374949      0.000068    2.0          0.080089     5.762897
#        16    Stopped     2       0.000387          256           2 0.409746      0.000054    2.0          0.056440    10.420550
#        17    Stopped     2       0.000015           64           2 0.203167      0.000097    2.0          0.062009     5.364068
#        18    Stopped     2       0.000014           32           4 0.389002      0.000181    2.0          0.091164     6.048157
#        19    Stopped     1       0.000063          128           4 0.314442      0.000019    1.0          0.068145     4.447675
#        20 InProgress     0       0.000034           32           2 0.313762      0.000019      -                 -            -
# 1 trials running, 20 finished (2 until the end), 380.53s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:40:15] 🚀 Trial 21 started - config: learning_rate=6.49111077702113e-05, num_hiddens=256, num_layers=3, dropout=0.34536713554125664, weight_decay=0.00033184376466691075
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010    9.0          0.065650    52.314478
#         2  Completed    10       0.000019          256           2 0.339309      0.000047   10.0          0.057540    44.565692
#         3    Stopped     1       0.000130          128           4 0.332804      0.000142    1.0          0.066722     4.474597
#         4    Stopped     2       0.000062           64           3 0.481651      0.000027    2.0          0.062338     5.825630
#         5    Stopped     3       0.000246          256           4 0.397979      0.000316    3.0          0.059400    23.090295
#         6    Stopped     2       0.000144           32           4 0.491281      0.000065    2.0          0.097383     6.083744
#         7    Stopped     1       0.000474          256           4 0.454531      0.000171    1.0          0.060582     9.146092
#         8    Stopped     3       0.000018          256           4 0.469638      0.000035    3.0          0.061929    22.869862
#         9    Stopped     2       0.000022           32           3 0.216749      0.000413    2.0          0.097290     5.663421
#        10    Stopped     1       0.000319          128           4 0.466525      0.000047    1.0          0.068410     4.460590
#        11    Stopped     3       0.000345          256           3 0.347272      0.000017    3.0          0.059807    18.882709
#        12    Stopped     2       0.000116           64           3 0.291955      0.000384    2.0          0.060148     5.925162
#        13    Stopped     1       0.000014          128           3 0.424103      0.000047    1.0          0.079493     4.098692
#        14    Stopped     1       0.000139           64           4 0.308740      0.000020    1.0          0.071010     4.012008
#        15    Stopped     2       0.000017          128           2 0.374949      0.000068    2.0          0.080089     5.762897
#        16    Stopped     2       0.000387          256           2 0.409746      0.000054    2.0          0.056440    10.420550
#        17    Stopped     2       0.000015           64           2 0.203167      0.000097    2.0          0.062009     5.364068
#        18    Stopped     2       0.000014           32           4 0.389002      0.000181    2.0          0.091164     6.048157
#        19    Stopped     1       0.000063          128           4 0.314442      0.000019    1.0          0.068145     4.447675
#        20    Stopped     2       0.000034           32           2 0.313762      0.000019    2.0          0.076233     5.369508
#        21 InProgress     0       0.000065          256           3 0.345367      0.000332      -                 -            -
# 1 trials running, 21 finished (2 until the end), 400.56s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010      9          0.065650    52.314478
#         2  Completed    10       0.000019          256           2 0.339309      0.000047     10          0.057540    44.565692
#         3    Stopped     1       0.000130          128           4 0.332804      0.000142      1          0.066722     4.474597
#         4    Stopped     2       0.000062           64           3 0.481651      0.000027      2          0.062338     5.825630
#         5    Stopped     3       0.000246          256           4 0.397979      0.000316      3          0.059400    23.090295
#         6    Stopped     2       0.000144           32           4 0.491281      0.000065      2          0.097383     6.083744
#         7    Stopped     1       0.000474          256           4 0.454531      0.000171      1          0.060582     9.146092
#         8    Stopped     3       0.000018          256           4 0.469638      0.000035      3          0.061929    22.869862
#         9    Stopped     2       0.000022           32           3 0.216749      0.000413      2          0.097290     5.663421
#        10    Stopped     1       0.000319          128           4 0.466525      0.000
wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# [11:41:30] 🚀 Trial 23 started - config: learning_rate=0.00017925558448895305, num_hiddens=128, num_layers=2, dropout=0.47398410301302885, weight_decay=5.449501569915947e-05
# [11:41:45] 🚀 Trial 24 started - config: learning_rate=2.8218817856360628e-05, num_hiddens=256, num_layers=4, dropout=0.3052646470646668, weight_decay=0.00020327887696571992
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010    9.0          0.065650    52.314478
#         2  Completed    10       0.000019          256           2 0.339309      0.000047   10.0          0.057540    44.565692
#         3    Stopped     1       0.000130          128           4 0.332804      0.000142    1.0          0.066722     4.474597
#         4    Stopped     2       0.000062           64           3 0.481651      0.000027    2.0          0.062338     5.825630
#         5    Stopped     3       0.000246          256           4 0.397979      0.000316    3.0          0.059400    23.090295
#         6    Stopped     2       0.000144           32           4 0.491281      0.000065    2.0          0.097383     6.083744
#         7    Stopped     1       0.000474          256           4 0.454531      0.000171    1.0          0.060582     9.146092
#         8    Stopped     3       0.000018          256           4 0.469638      0.000035    3.0          0.061929    22.869862
#         9    Stopped     2       0.000022           32           3 0.216749      0.000413    2.0          0.097290     5.663421
#        10    Stopped     1       0.000319          128           4 0.466525      0.000047    1.0          0.068410     4.460590
#        11    Stopped     3       0.000345          256           3 0.347272      0.000017    3.0          0.059807    18.882709
#        12    Stopped     2       0.000116           64           3 0.291955      0.000384    2.0          0.060148     5.925162
# ...
#        12    Stopped     2       0.000116           64           3 0.291955      0.000384    2.0          0.060148     5.925162
#        13    Stopped     1       0.000014          128           3 0.424103      0.000047    1.0          0.079493     4.098692
#        14    Stopped     1       0.000139           64           4 0.308740      0.000020    1.0          0.071010     4.012008
#        15    Stopped     2       0.000017          128           2 0.374949      0.000068    2.0          0.080089     5.762897
#        16    Stopped     2       0.000387          256           2 0.409746      0.000054    2.0          0.056440    10.420550
#        17    Stopped     2       0.000015           64           2 0.203167      0.000097    2.0          0.062009     5.364068
#        18    Stopped     2       0.000014           32           4 0.389002      0.000181    2.0          0.091164     6.048157
#        19    Stopped     1       0.000063          128           4 0.314442      0.000019    1.0          0.068145     4.447675
#        20    Stopped     2       0.000034           32           2 0.313762      0.000019    2.0          0.076233     5.369508
#        21    Stopped     9       0.000065          256           3 0.345367      0.000332    9.0          0.060644    52.581533
#        22    Stopped     4       0.000300           32           2 0.338480      0.000241    4.0          0.081129     9.085119
#        23    Stopped     4       0.000179          128           2 0.473984      0.000054    4.0          0.058841     9.838785
#        24    Stopped     3       0.000028          256           4 0.305265      0.000203    3.0          0.060156    23.194278
#        25    Stopped     2       0.000161           64           3 0.476893      0.000187    2.0          0.063253     5.850337
#        26    Stopped     2       0.000016           32           2 0.211166      0.000093    2.0          0.090454     5.351568
#        27    Stopped     3       0.000018          256           4 0.354808      0.000038    3.0          0.061746    23.162001
#        28    Stopped     1       0.000044          128           4 0.261879      0.000196    1.0          0.068761     4.450832
#        29 InProgress     0       0.000063          256           3 0.299998      0.000265      -                 -            -
# 1 trials running, 29 finished (2 until the end), 580.94s wallclock-time
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 📊 Tuning Status (last metric is reported)
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010     10          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010      9          0.065650    52.314478
#         2  Completed    10       0.000019          256           2 0.339309      0.000047     10          0.057540    44.565692
#         3    Stopped     1       0.000130          128           4 0.332804      0.000142      1          0.066722     4.474597
#         4    Stopped     2       0.000062           64           3 0.481651      0.000027      2          0.062338     5.825630
#         5    Stopped     3       0.000246          256           4 0.397979      0.000316      3          0.059400    23.090295
#         6    Stopped     2       0.000144           32           4 0.491281      0.000065      2          0.097383     6.083744
#         7    Stopped     1       0.000474          256           4 0.454531      0.000171      1          0.060582     9.146092
#         8    Stopped     3       0.000018          256           4 0.469638      0.000035      3          0.061929    22.869862
#         9    Stopped     2       0.000022           32           3 0.216749      0.000413      2          0.097290     5.663421
#        10    Stopped     1       0.000319          128           4 0.466525      0.000047      1          0.068410     4.460590
#        11    Stopped     3       0.000345          256           3 0.347272      0.000017      3          0.059807    18.882709
#        12    Stopped     2       0.000116           64           3 0.291955      0.000384      2          0.060148     5.925162
#        13    Stopped     1       0.000014          128           3 0.424103      0.000047      1          0.079493     4.098692
#        14    Stopped     1       0.000139           64           4 0.308740      0.000020      1          0.071010     4.012008
#        15    Stopped     2       0.000017          128           2 0.374949      0.000068      2          0.080089     5.762897
#        16    Stopped     2       0.000387          256           2 0.409746      0.000054      2          0.056440    10.420550
#        17    Stopped     2       0.000015           64           2 0.203167      0.000097      2          0.062009     5.364068
-05
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🎉🎉🎉 HYPERPARAMETER OPTIMIZATION COMPLETE!
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# --------------------
# Resource summary (last result is reported):
#  trial_id     status  iter  learning_rate  num_hiddens  num_layers  dropout  weight_decay  epoch  validation_error  worker-time
#         0  Completed    10       0.000010           64           2 0.200000      0.000010   10.0          0.056878    20.893487
#         1    Stopped     9       0.000149          256           3 0.226628      0.000010    9.0          0.065650    52.314478
#         2  Completed    10       0.000019          256           2 0.339309      0.000047   10.0          0.057540    44.565692
#         3    Stopped     1       0.000130          128           4 0.332804      0.000142    1.0          0.066722     4.474597
#         4    Stopped     2       0.000062           64           3 0.481651      0.000027    2.0          0.062338     5.825630
#         5    Stopped     3       0.000246          256           4 0.397979      0.000316    3.0          0.059400    23.090295
#         6    Stopped     2       0.000144           32           4 0.491281      0.000065    2.0          0.097383     6.083744
#         7    Stopped     1       0.000474          256           4 0.454531      0.000171    1.0          0.060582     9.146092
#         8    Stopped     3       0.000018          256           4 0.469638      0.000035    3.0          0.061929    22.869862
#         9    Stopped     2       0.000022           32           3 0.216749      0.000413    2.0          0.097290     5.663421
#        10    Stopped     1       0.000319          128           4 0.466525      0.000047    1.0          0.068410     4.460590
#        11    Stopped     3       0.000345          256           3 0.347272      0.000017    3.0          0.059807    18.882709
#        12    Stopped     2       0.000116           64           3 0.291955      0.000384    2.0          0.060148     5.925162
#        13    Stopped     1       0.000014          128           3 0.424103      0.000047    1.0          0.079493     4.098692
#        14    Stopped     1       0.000139           64           4 0.308740      0.000020    1.0          0.071010     4.012008
#        15    Stopped     2       0.000017          128           2 0.374949      0.000068    2.0          0.080089     5.762897
#        16    Stopped     2       0.000387          256           2 0.409746      0.000054    2.0          0.056440    10.420550
#        17    Stopped     2       0.000015           64           2 0.203167      0.000097    2.0          0.062009     5.364068
#        18    Stopped     2       0.000014           32           4 0.389002      0.000181    2.0          0.091164     6.048157
#        19    Stopped     1       0.000063          128           4 0.314442      0.000019    1.0          0.068145     4.447675
#        20    Stopped     2       0.000034           32           2 0.313762      0.000019    2.0          0.076233     5.369508
#        21    Stopped     9       0.000065          256           3 0.345367      0.000332    9.0          0.060644    52.581533
#        22    Stopped     4       0.000300           32           2 0.338480      0.000241    4.0          0.081129     9.085119
#        23    Stopped     4       0.000179          128           2 0.473984      0.000054    4.0          0.058841     9.838785
#        24    Stopped     3       0.000028          256           4 0.305265      0.000203    3.0          0.060156    23.194278
#        25    Stopped     2       0.000161           64           3 0.476893      0.000187    2.0          0.063253     5.850337
#        26    Stopped     2       0.000016           32           2 0.211166      0.000093    2.0          0.090454     5.351568
#        27    Stopped     3       0.000018          256           4 0.354808      0.000038    3.0          0.061746    23.162001
#        28    Stopped     1       0.000044          128           4 0.261879      0.000196    1.0          0.068761     4.450832
#        29    Stopped     9       0.000063          256           3 0.299998      0.000265    9.0          0.060728    52.440211
#        30 InProgress     0       0.000245          256           2 0.398457      0.000016      -                 -            -
# 1 trials running, 30 finished (2 until the end), 626.08s wallclock-time
#
# validation_error: best 0.05644027143716812 for trial-id 16
# --------------------
# 🛑 Stopping trials that may still be running.
# ✅ Tuning finished, results of trials can be found at /root/syne-tune/python-entrypoint-2026-03-20-11-33-49-494
#
# 💾 Results saved to: /root/syne-tune/python-entrypoint-2026-03-20-11-33-49-494
# ✨ Happy training with your optimized hyperparameters!

# %% [markdown]
# ##15. Load Results from Temperature HPO Experiment to a Pandas DataFrame

# %%
# Assign the filepath for the results of the HPO experiment
temperature_results_path = "/root/syne-tune/python-entrypoint-2026-03-20-11-33-49-494/results.csv.zip"

# Save the results to a Pandas DataFrame
temperature_results = pd.read_csv(temperature_results_path)

# %% [markdown]
# ##16. Save the Temperature HPO Results as a .csv File

# %%
# Specify the file path for saving the DataFrame as a csv file
temperature_hpo_results_path = Path("/content/REDE_BIRDHOPE BRIDGE_E_202501_temperature_hpo_results.csv")

# Save the DataFrame to a csv file
temperature_results.to_csv(temperature_hpo_results_path, index=True)
